# %% [markdown]
# - imbalance data: https://www.linkedin.com/pulse/some-tricks-handling-imbalanced-dataset-image-m-farhan-tandia
# - base model: https://www.youtube.com/watch?v=t8eSPbvl0vU
# - https://www.kaggle.com/code/hongjae6/simple-baseline-using-keras-resnet50

# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, Activation, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')
######################################################################################################
from keras_tuner import RandomSearch, HyperParameters
from tensorflow.keras.applications import Xception, DenseNet121
import keras_tuner as kt

# %%
model_name = 'Ensemble3'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 
# FNAME_TUNER_REPORT = 'Report_tune_'+ model_name
################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_SAVE_RESULT, 'saved_tuner_model')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\Ensemble3
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\Ensemble3\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\Ensemble3\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':  
            print("Here in basic")
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set


                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Here in basic
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=15, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING
#
# Trial 15 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 9
# Score: 0.7056062817573547
#
# Trial 11 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 5
# Score: 0.705497920513153179205131531

# %%
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.1,
#                       activation='relu',
#                       units= 1024,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy", 
#                       retrain_backbone_network=False,
#                       learning_rate = 0.001,
#                       global_pooling = 'avg',
#                       filters=7,
#                       name='ensemble2'):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Concatenate features
#     concatenated_features = Concatenate()([Xception_features, densenet_features])

#     if filters==3:
#         filters = (3,3)
#     elif filters==5:
#         filters = (5,5)
#     elif filters==7:
#         filters = (7,7)
#     elif filters==9:
#         filters = (9,9)

#     # # Add a tunable dropout layer
#     # x = Dropout(dropout)(concatenated_features)

#     # # A fully connected layer with a tunable number of units
#     # x = Dense(units)(x)

#     #     # Add a tunable dropout layer
#     # x = Dropout(dropout)(x)

#     # # A fully connected layer with a tunable number of units
#     # x = Dense(units)(x)
#         # Add a tunable dropout layer
#     x = Dropout(dropout)(concatenated_features)

#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Add a tunable dropout layer
#     x = Dropout(dropout)(x)

#     # A fully connected layer with a tunable number of units again
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)


#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create and compile the model
#     model = Model(inputs=inputs, outputs=predictions)
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate),
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %%
from tensorflow.keras.applications import Xception, DenseNet121, InceptionResNetV2
# Function to build the model with an ensemble of feature extractors
def get_ensemble3_model(input_shape=MODEL_INPUT_SIZE,
                      dropout= 0.2,
                      activation='relu',
                      units= 512,
                      nr_classes=NUM_CLASSES,
                      loss = "categorical_crossentropy",
                      retrain_backbone_network=False,
                      filters=7):


    inputs = Input(shape=input_shape)

    # Feature extraction from DenseNet121
    densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
    densenet_features = densenet_base(inputs)
    densenet_features = GlobalAveragePooling2D()(densenet_features)

    # Feature extraction from Xception
    Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    Xception_features = Xception_base(inputs)
    Xception_features = GlobalAveragePooling2D()(Xception_features)


        # Feature extraction from Xception
    InceptionResNetV2_base = InceptionResNetV2(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    InceptionResNetV2_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    InceptionResNetV2_features = InceptionResNetV2_base(inputs)
    InceptionResNetV2_features = GlobalAveragePooling2D()(InceptionResNetV2_features)


    # Concatenate the features
    concatenated_features = Concatenate()([densenet_features, Xception_features, InceptionResNetV2_features])

    x = Dropout(dropout)(concatenated_features)
    # A fully connected layer with a tunable number of units
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)

    # Output layer
    predictions = Dense( nr_classes, activation='softmax')(x)

    # Create the final ensemble model
    model = Model(inputs=inputs, outputs=predictions)
    optimizer = Adam(learning_rate=0.001 )
    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy', f1_score]
    )

    return model

# %% [markdown]
# # Train and Results
# - DOES NOT WORK---EfficientNetV2, Nasnet, Resnet, VGG16,
# - DOES NOT WORK--InceptionV3--ERROR: No matching distribution found for tensorflow-directml (checked with colab)
# - DOES NOT WORK--InceptionResNetV2--slighly works
# - original models selected: DenseNet121, -mobilenet X-ception, ,-Inception
# - My models selected: 'ensemble2' (70), Basic CNN v1(91), Basic CNN v2 (92), transfer_mobilenet (85), ensembleXception
# - tuned vit models:  T2TViT(47)",---Cait (26), 16

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN() 
model = get_ensemble3_model()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7303 - accuracy: 0.4743 - f1_score: 0.4318
# Epoch 1: val_f1_score improved from -inf to 0.51795, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 1.7303 - accuracy: 0.4743 - f1_score: 0.4318 - val_loss: 1.3938 - val_accuracy: 0.5481 - val_f1_score: 0.5180 - lr: 0.0010
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2433 - accuracy: 0.6011 - f1_score: 0.5764
# Epoch 2: val_f1_score improved from 0.51795 to 0.58227, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 97s 932ms/step - loss: 1.2433 - accuracy: 0.6011 - f1_score: 0.5764 - val_loss: 1.2017 - val_accuracy: 0.6098 - val_f1_score: 0.5823 - lr: 0.0010
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0842 - accuracy: 0.6488 - f1_score: 0.6313
# Epoch 3: val_f1_score improved from 0.58227 to 0.63447, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 96s 920ms/step - loss: 1.0842 - accuracy: 0.6488 - f1_score: 0.6313 - val_loss: 1.0727 - val_accuracy: 0.6584 - val_f1_score: 0.6345 - lr: 0.0010
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0048 - accuracy: 0.6815 - f1_score: 0.6638
# Epoch 4: val_f1_score improved from 0.63447 to 0.64608, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 198s 2s/step - loss: 1.0048 - accuracy: 0.6815 - f1_score: 0.6638 - val_loss: 0.9959 - val_accuracy: 0.6631 - val_f1_score: 0.6461 - lr: 0.0010
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9302 - accuracy: 0.7006 - f1_score: 0.6880
# Epoch 5: val_f1_score improved from 0.64608 to 0.68519, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 390s 4s/step - loss: 0.9302 - accuracy: 0.7006 - f1_score: 0.6880 - val_loss: 0.9447 - val_accuracy: 0.6959 - val_f1_score: 0.6852 - lr: 0.0010
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8901 - accuracy: 0.7116 - f1_score: 0.6943
# Epoch 6: val_f1_score improved from 0.68519 to 0.69610, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 394s 4s/step - loss: 0.8901 - accuracy: 0.7116 - f1_score: 0.6943 - val_loss: 0.8861 - val_accuracy: 0.7183 - val_f1_score: 0.6961 - lr: 0.0010
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8383 - accuracy: 0.7284 - f1_score: 0.7186
# Epoch 7: val_f1_score did not improve from 0.69610
# 104/104 [==============================] - 409s 4s/step - loss: 0.8383 - accuracy: 0.7284 - f1_score: 0.7186 - val_loss: 0.9453 - val_accuracy: 0.6882 - val_f1_score: 0.6681 - lr: 0.0010
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7883 - accuracy: 0.7436 - f1_score: 0.7367
# Epoch 8: val_f1_score improved from 0.69610 to 0.72424, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 416s 4s/step - loss: 0.7883 - accuracy: 0.7436 - f1_score: 0.7367 - val_loss: 0.8292 - val_accuracy: 0.7395 - val_f1_score: 0.7242 - lr: 0.0010
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7753 - accuracy: 0.7484 - f1_score: 0.7420
# Epoch 9: val_f1_score did not improve from 0.72424
# 104/104 [==============================] - 384s 4s/step - loss: 0.7753 - accuracy: 0.7484 - f1_score: 0.7420 - val_loss: 0.8119 - val_accuracy: 0.7283 - val_f1_score: 0.7239 - lr: 0.0010
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7426 - accuracy: 0.7605 - f1_score: 0.7537
# Epoch 10: val_f1_score did not improve from 0.72424
# 104/104 [==============================] - 395s 4s/step - loss: 0.7426 - accuracy: 0.7605 - f1_score: 0.7537 - val_loss: 0.8751 - val_accuracy: 0.7125 - val_f1_score: 0.7036 - lr: 0.0010
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6987 - accuracy: 0.7732 - f1_score: 0.7661
# Epoch 11: val_f1_score improved from 0.72424 to 0.76098, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 395s 4s/step - loss: 0.6987 - accuracy: 0.7732 - f1_score: 0.7661 - val_loss: 0.7722 - val_accuracy: 0.7634 - val_f1_score: 0.7610 - lr: 0.0010
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.7704 - f1_score: 0.7666
# Epoch 12: val_f1_score did not improve from 0.76098
# 104/104 [==============================] - 387s 4s/step - loss: 0.7078 - accuracy: 0.7704 - f1_score: 0.7666 - val_loss: 0.7979 - val_accuracy: 0.7603 - val_f1_score: 0.7504 - lr: 0.0010
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6740 - accuracy: 0.7828 - f1_score: 0.7753
# Epoch 13: val_f1_score improved from 0.76098 to 0.76391, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 405s 4s/step - loss: 0.6740 - accuracy: 0.7828 - f1_score: 0.7753 - val_loss: 0.7339 - val_accuracy: 0.7750 - val_f1_score: 0.7639 - lr: 0.0010
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6557 - accuracy: 0.7877 - f1_score: 0.7817
# Epoch 14: val_f1_score did not improve from 0.76391
# 104/104 [==============================] - 417s 4s/step - loss: 0.6557 - accuracy: 0.7877 - f1_score: 0.7817 - val_loss: 0.7855 - val_accuracy: 0.7433 - val_f1_score: 0.7416 - lr: 0.0010
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6251 - accuracy: 0.7958 - f1_score: 0.7901
# Epoch 15: val_f1_score improved from 0.76391 to 0.78559, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 444s 4s/step - loss: 0.6251 - accuracy: 0.7958 - f1_score: 0.7901 - val_loss: 0.6579 - val_accuracy: 0.7870 - val_f1_score: 0.7856 - lr: 0.0010
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6105 - accuracy: 0.8017 - f1_score: 0.7920
# Epoch 16: val_f1_score did not improve from 0.78559
# 104/104 [==============================] - 435s 4s/step - loss: 0.6105 - accuracy: 0.8017 - f1_score: 0.7920 - val_loss: 0.7276 - val_accuracy: 0.7700 - val_f1_score: 0.7683 - lr: 0.0010
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.8071 - f1_score: 0.7996
# Epoch 17: val_f1_score did not improve from 0.78559
# 104/104 [==============================] - 432s 4s/step - loss: 0.5956 - accuracy: 0.8071 - f1_score: 0.7996 - val_loss: 0.6859 - val_accuracy: 0.7900 - val_f1_score: 0.7811 - lr: 0.0010
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.8083 - f1_score: 0.8038
# Epoch 18: val_f1_score did not improve from 0.78559
# 104/104 [==============================] - 436s 4s/step - loss: 0.5888 - accuracy: 0.8083 - f1_score: 0.8038 - val_loss: 0.6963 - val_accuracy: 0.7816 - val_f1_score: 0.7634 - lr: 0.0010
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5705 - accuracy: 0.8137 - f1_score: 0.8054
# Epoch 19: val_f1_score did not improve from 0.78559
# 104/104 [==============================] - 439s 4s/step - loss: 0.5705 - accuracy: 0.8137 - f1_score: 0.8054 - val_loss: 0.7410 - val_accuracy: 0.7584 - val_f1_score: 0.7524 - lr: 0.0010
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.8143 - f1_score: 0.8079
# Epoch 20: val_f1_score did not improve from 0.78559
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 438s 4s/step - loss: 0.5707 - accuracy: 0.8143 - f1_score: 0.8079 - val_loss: 0.7190 - val_accuracy: 0.7634 - val_f1_score: 0.7625 - lr: 0.0010
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5080 - accuracy: 0.8353 - f1_score: 0.8307
# Epoch 21: val_f1_score improved from 0.78559 to 0.83166, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 467s 4s/step - loss: 0.5080 - accuracy: 0.8353 - f1_score: 0.8307 - val_loss: 0.5402 - val_accuracy: 0.8337 - val_f1_score: 0.8317 - lr: 5.0000e-04
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.8418 - f1_score: 0.8367
# Epoch 22: val_f1_score did not improve from 0.83166
# 104/104 [==============================] - 480s 5s/step - loss: 0.4787 - accuracy: 0.8418 - f1_score: 0.8367 - val_loss: 0.5369 - val_accuracy: 0.8232 - val_f1_score: 0.8211 - lr: 5.0000e-04
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4737 - accuracy: 0.8467 - f1_score: 0.8450
# Epoch 23: val_f1_score did not improve from 0.83166
# 104/104 [==============================] - 484s 5s/step - loss: 0.4737 - accuracy: 0.8467 - f1_score: 0.8450 - val_loss: 0.5299 - val_accuracy: 0.8263 - val_f1_score: 0.8215 - lr: 5.0000e-04
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4544 - accuracy: 0.8534 - f1_score: 0.8490
# Epoch 24: val_f1_score improved from 0.83166 to 0.84380, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 475s 5s/step - loss: 0.4544 - accuracy: 0.8534 - f1_score: 0.8490 - val_loss: 0.4938 - val_accuracy: 0.8456 - val_f1_score: 0.8438 - lr: 5.0000e-04
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4358 - accuracy: 0.8600 - f1_score: 0.8566
# Epoch 25: val_f1_score did not improve from 0.84380
# 104/104 [==============================] - 486s 5s/step - loss: 0.4358 - accuracy: 0.8600 - f1_score: 0.8566 - val_loss: 0.5179 - val_accuracy: 0.8360 - val_f1_score: 0.8356 - lr: 5.0000e-04
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4225 - accuracy: 0.8637 - f1_score: 0.8616
# Epoch 26: val_f1_score improved from 0.84380 to 0.84698, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 502s 5s/step - loss: 0.4225 - accuracy: 0.8637 - f1_score: 0.8616 - val_loss: 0.5037 - val_accuracy: 0.8472 - val_f1_score: 0.8470 - lr: 5.0000e-04
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.8561 - f1_score: 0.8521
# Epoch 27: val_f1_score did not improve from 0.84698
# 104/104 [==============================] - 503s 5s/step - loss: 0.4244 - accuracy: 0.8561 - f1_score: 0.8521 - val_loss: 0.5005 - val_accuracy: 0.8472 - val_f1_score: 0.8420 - lr: 5.0000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.8644 - f1_score: 0.8599
# Epoch 28: val_f1_score did not improve from 0.84698
# 104/104 [==============================] - 522s 5s/step - loss: 0.4130 - accuracy: 0.8644 - f1_score: 0.8599 - val_loss: 0.5015 - val_accuracy: 0.8406 - val_f1_score: 0.8339 - lr: 5.0000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4107 - accuracy: 0.8677 - f1_score: 0.8633
# Epoch 29: val_f1_score did not improve from 0.84698
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 492s 5s/step - loss: 0.4107 - accuracy: 0.8677 - f1_score: 0.8633 - val_loss: 0.4967 - val_accuracy: 0.8506 - val_f1_score: 0.8467 - lr: 5.0000e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3706 - accuracy: 0.8818 - f1_score: 0.8806
# Epoch 30: val_f1_score improved from 0.84698 to 0.86014, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 496s 5s/step - loss: 0.3706 - accuracy: 0.8818 - f1_score: 0.8806 - val_loss: 0.4494 - val_accuracy: 0.8549 - val_f1_score: 0.8601 - lr: 2.5000e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8811 - f1_score: 0.8786
# Epoch 31: val_f1_score improved from 0.86014 to 0.86088, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 467s 4s/step - loss: 0.3657 - accuracy: 0.8811 - f1_score: 0.8786 - val_loss: 0.4504 - val_accuracy: 0.8599 - val_f1_score: 0.8609 - lr: 2.5000e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3599 - accuracy: 0.8851 - f1_score: 0.8825
# Epoch 32: val_f1_score improved from 0.86088 to 0.86495, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 493s 5s/step - loss: 0.3599 - accuracy: 0.8851 - f1_score: 0.8825 - val_loss: 0.4268 - val_accuracy: 0.8661 - val_f1_score: 0.8650 - lr: 2.5000e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8849 - f1_score: 0.8829
# Epoch 33: val_f1_score did not improve from 0.86495
# 104/104 [==============================] - 467s 4s/step - loss: 0.3545 - accuracy: 0.8849 - f1_score: 0.8829 - val_loss: 0.4271 - val_accuracy: 0.8645 - val_f1_score: 0.8643 - lr: 2.5000e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8855 - f1_score: 0.8832
# Epoch 34: val_f1_score improved from 0.86495 to 0.86933, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 490s 5s/step - loss: 0.3468 - accuracy: 0.8855 - f1_score: 0.8832 - val_loss: 0.4128 - val_accuracy: 0.8726 - val_f1_score: 0.8693 - lr: 2.5000e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.8906 - f1_score: 0.8890
# Epoch 35: val_f1_score did not improve from 0.86933
# 104/104 [==============================] - 500s 5s/step - loss: 0.3406 - accuracy: 0.8906 - f1_score: 0.8890 - val_loss: 0.4225 - val_accuracy: 0.8730 - val_f1_score: 0.8645 - lr: 2.5000e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8856 - f1_score: 0.8813
# Epoch 36: val_f1_score did not improve from 0.86933
# 104/104 [==============================] - 502s 5s/step - loss: 0.3469 - accuracy: 0.8856 - f1_score: 0.8813 - val_loss: 0.4326 - val_accuracy: 0.8630 - val_f1_score: 0.8564 - lr: 2.5000e-04
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8877 - f1_score: 0.8860
# Epoch 37: val_f1_score did not improve from 0.86933
# 104/104 [==============================] - 534s 5s/step - loss: 0.3419 - accuracy: 0.8877 - f1_score: 0.8860 - val_loss: 0.4343 - val_accuracy: 0.8668 - val_f1_score: 0.8630 - lr: 2.5000e-04
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 0.8933 - f1_score: 0.8899
# Epoch 38: val_f1_score improved from 0.86933 to 0.87181, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 509s 5s/step - loss: 0.3305 - accuracy: 0.8933 - f1_score: 0.8899 - val_loss: 0.4144 - val_accuracy: 0.8753 - val_f1_score: 0.8718 - lr: 2.5000e-04
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8888 - f1_score: 0.8857
# Epoch 39: val_f1_score improved from 0.87181 to 0.87252, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 478s 5s/step - loss: 0.3444 - accuracy: 0.8888 - f1_score: 0.8857 - val_loss: 0.4087 - val_accuracy: 0.8726 - val_f1_score: 0.8725 - lr: 2.5000e-04
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8938 - f1_score: 0.8921
# Epoch 40: val_f1_score did not improve from 0.87252
# 104/104 [==============================] - 496s 5s/step - loss: 0.3289 - accuracy: 0.8938 - f1_score: 0.8921 - val_loss: 0.4173 - val_accuracy: 0.8622 - val_f1_score: 0.8568 - lr: 2.5000e-04
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.8953 - f1_score: 0.8938
# Epoch 41: val_f1_score improved from 0.87252 to 0.87626, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 503s 5s/step - loss: 0.3285 - accuracy: 0.8953 - f1_score: 0.8938 - val_loss: 0.3947 - val_accuracy: 0.8784 - val_f1_score: 0.8763 - lr: 2.5000e-04
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3202 - accuracy: 0.8985 - f1_score: 0.8970
# Epoch 42: val_f1_score did not improve from 0.87626
# 104/104 [==============================] - 330s 3s/step - loss: 0.3202 - accuracy: 0.8985 - f1_score: 0.8970 - val_loss: 0.4205 - val_accuracy: 0.8719 - val_f1_score: 0.8667 - lr: 2.5000e-04
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3167 - accuracy: 0.8983 - f1_score: 0.8973
# Epoch 43: val_f1_score did not improve from 0.87626
# 104/104 [==============================] - 277s 3s/step - loss: 0.3167 - accuracy: 0.8983 - f1_score: 0.8973 - val_loss: 0.3987 - val_accuracy: 0.8703 - val_f1_score: 0.8685 - lr: 2.5000e-04
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.9027 - f1_score: 0.9035
# Epoch 44: val_f1_score improved from 0.87626 to 0.87670, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 163s 2s/step - loss: 0.3054 - accuracy: 0.9027 - f1_score: 0.9035 - val_loss: 0.4004 - val_accuracy: 0.8742 - val_f1_score: 0.8767 - lr: 2.5000e-04
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 0.8997 - f1_score: 0.8970
# Epoch 45: val_f1_score did not improve from 0.87670
# 104/104 [==============================] - 322s 3s/step - loss: 0.3067 - accuracy: 0.8997 - f1_score: 0.8970 - val_loss: 0.4176 - val_accuracy: 0.8730 - val_f1_score: 0.8746 - lr: 2.5000e-04
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.9011 - f1_score: 0.8990
# Epoch 46: val_f1_score did not improve from 0.87670
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 479s 5s/step - loss: 0.3012 - accuracy: 0.9011 - f1_score: 0.8990 - val_loss: 0.4033 - val_accuracy: 0.8761 - val_f1_score: 0.8743 - lr: 2.5000e-04
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9090 - f1_score: 0.9077
# Epoch 47: val_f1_score improved from 0.87670 to 0.88254, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 485s 5s/step - loss: 0.2902 - accuracy: 0.9090 - f1_score: 0.9077 - val_loss: 0.3863 - val_accuracy: 0.8834 - val_f1_score: 0.8825 - lr: 1.2500e-04
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.9046 - f1_score: 0.9014
# Epoch 48: val_f1_score did not improve from 0.88254
# 104/104 [==============================] - 506s 5s/step - loss: 0.2925 - accuracy: 0.9046 - f1_score: 0.9014 - val_loss: 0.3892 - val_accuracy: 0.8773 - val_f1_score: 0.8811 - lr: 1.2500e-04
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9098 - f1_score: 0.9073
# Epoch 49: val_f1_score improved from 0.88254 to 0.88378, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 535s 5s/step - loss: 0.2852 - accuracy: 0.9098 - f1_score: 0.9073 - val_loss: 0.3678 - val_accuracy: 0.8850 - val_f1_score: 0.8838 - lr: 1.2500e-04
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9058 - f1_score: 0.9039
# Epoch 50: val_f1_score did not improve from 0.88378
# 104/104 [==============================] - 504s 5s/step - loss: 0.2902 - accuracy: 0.9058 - f1_score: 0.9039 - val_loss: 0.3770 - val_accuracy: 0.8796 - val_f1_score: 0.8760 - lr: 1.2500e-04
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9089 - f1_score: 0.9073
# Epoch 51: val_f1_score did not improve from 0.88378
# 104/104 [==============================] - 496s 5s/step - loss: 0.2796 - accuracy: 0.9089 - f1_score: 0.9073 - val_loss: 0.3727 - val_accuracy: 0.8796 - val_f1_score: 0.8800 - lr: 1.2500e-04
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.9109 - f1_score: 0.9097
# Epoch 52: val_f1_score improved from 0.88378 to 0.88800, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 499s 5s/step - loss: 0.2817 - accuracy: 0.9109 - f1_score: 0.9097 - val_loss: 0.3589 - val_accuracy: 0.8927 - val_f1_score: 0.8880 - lr: 1.2500e-04
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.9093 - f1_score: 0.9064
# Epoch 53: val_f1_score did not improve from 0.88800
# 104/104 [==============================] - 483s 5s/step - loss: 0.2740 - accuracy: 0.9093 - f1_score: 0.9064 - val_loss: 0.3736 - val_accuracy: 0.8842 - val_f1_score: 0.8838 - lr: 1.2500e-04
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9126 - f1_score: 0.9119
# Epoch 54: val_f1_score improved from 0.88800 to 0.88890, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 484s 5s/step - loss: 0.2666 - accuracy: 0.9126 - f1_score: 0.9119 - val_loss: 0.3764 - val_accuracy: 0.8900 - val_f1_score: 0.8889 - lr: 1.2500e-04
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.9109 - f1_score: 0.9107
# Epoch 55: val_f1_score did not improve from 0.88890
# 104/104 [==============================] - 495s 5s/step - loss: 0.2735 - accuracy: 0.9109 - f1_score: 0.9107 - val_loss: 0.3759 - val_accuracy: 0.8854 - val_f1_score: 0.8815 - lr: 1.2500e-04
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9140 - f1_score: 0.9112
# Epoch 56: val_f1_score did not improve from 0.88890
# 104/104 [==============================] - 527s 5s/step - loss: 0.2687 - accuracy: 0.9140 - f1_score: 0.9112 - val_loss: 0.3744 - val_accuracy: 0.8861 - val_f1_score: 0.8859 - lr: 1.2500e-04
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9122 - f1_score: 0.9093
# Epoch 57: val_f1_score did not improve from 0.88890
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 491s 5s/step - loss: 0.2737 - accuracy: 0.9122 - f1_score: 0.9093 - val_loss: 0.3719 - val_accuracy: 0.8869 - val_f1_score: 0.8858 - lr: 1.2500e-04
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9143 - f1_score: 0.9114
# Epoch 58: val_f1_score improved from 0.88890 to 0.89022, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 518s 5s/step - loss: 0.2677 - accuracy: 0.9143 - f1_score: 0.9114 - val_loss: 0.3591 - val_accuracy: 0.8954 - val_f1_score: 0.8902 - lr: 6.2500e-05
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.9130 - f1_score: 0.9119
# Epoch 59: val_f1_score improved from 0.89022 to 0.89115, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 546s 5s/step - loss: 0.2637 - accuracy: 0.9130 - f1_score: 0.9119 - val_loss: 0.3556 - val_accuracy: 0.8881 - val_f1_score: 0.8912 - lr: 6.2500e-05
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9159 - f1_score: 0.9151
# Epoch 60: val_f1_score did not improve from 0.89115
# 104/104 [==============================] - 546s 5s/step - loss: 0.2614 - accuracy: 0.9159 - f1_score: 0.9151 - val_loss: 0.3617 - val_accuracy: 0.8865 - val_f1_score: 0.8865 - lr: 6.2500e-05
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.9131 - f1_score: 0.9120
# Epoch 61: val_f1_score did not improve from 0.89115
# 104/104 [==============================] - 334s 3s/step - loss: 0.2620 - accuracy: 0.9131 - f1_score: 0.9120 - val_loss: 0.3652 - val_accuracy: 0.8865 - val_f1_score: 0.8848 - lr: 6.2500e-05
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9160 - f1_score: 0.9142
# Epoch 62: val_f1_score did not improve from 0.89115
# 104/104 [==============================] - 298s 3s/step - loss: 0.2585 - accuracy: 0.9160 - f1_score: 0.9142 - val_loss: 0.3560 - val_accuracy: 0.8919 - val_f1_score: 0.8900 - lr: 6.2500e-05
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2530 - accuracy: 0.9194 - f1_score: 0.9182
# Epoch 63: val_f1_score improved from 0.89115 to 0.90235, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 306s 3s/step - loss: 0.2530 - accuracy: 0.9194 - f1_score: 0.9182 - val_loss: 0.3248 - val_accuracy: 0.9016 - val_f1_score: 0.9023 - lr: 6.2500e-05
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2559 - accuracy: 0.9188 - f1_score: 0.9166
# Epoch 64: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 277s 3s/step - loss: 0.2559 - accuracy: 0.9188 - f1_score: 0.9166 - val_loss: 0.3782 - val_accuracy: 0.8827 - val_f1_score: 0.8798 - lr: 6.2500e-05
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.9199 - f1_score: 0.9179
# Epoch 65: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 284s 3s/step - loss: 0.2473 - accuracy: 0.9199 - f1_score: 0.9179 - val_loss: 0.3429 - val_accuracy: 0.8908 - val_f1_score: 0.8900 - lr: 6.2500e-05
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9189 - f1_score: 0.9183
# Epoch 66: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 302s 3s/step - loss: 0.2531 - accuracy: 0.9189 - f1_score: 0.9183 - val_loss: 0.3426 - val_accuracy: 0.8896 - val_f1_score: 0.8863 - lr: 6.2500e-05
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.9187 - f1_score: 0.9183
# Epoch 67: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 310s 3s/step - loss: 0.2498 - accuracy: 0.9187 - f1_score: 0.9183 - val_loss: 0.3566 - val_accuracy: 0.8900 - val_f1_score: 0.8881 - lr: 6.2500e-05
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9212 - f1_score: 0.9209
# Epoch 68: val_f1_score did not improve from 0.90235
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 304s 3s/step - loss: 0.2468 - accuracy: 0.9212 - f1_score: 0.9209 - val_loss: 0.3374 - val_accuracy: 0.8908 - val_f1_score: 0.8913 - lr: 6.2500e-05
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9180 - f1_score: 0.9181
# Epoch 69: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 299s 3s/step - loss: 0.2541 - accuracy: 0.9180 - f1_score: 0.9181 - val_loss: 0.3431 - val_accuracy: 0.8989 - val_f1_score: 0.8991 - lr: 3.1250e-05
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9221 - f1_score: 0.9204
# Epoch 70: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 310s 3s/step - loss: 0.2494 - accuracy: 0.9221 - f1_score: 0.9204 - val_loss: 0.3509 - val_accuracy: 0.8877 - val_f1_score: 0.8844 - lr: 3.1250e-05
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9204 - f1_score: 0.9203
# Epoch 71: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 309s 3s/step - loss: 0.2504 - accuracy: 0.9204 - f1_score: 0.9203 - val_loss: 0.3449 - val_accuracy: 0.9000 - val_f1_score: 0.8999 - lr: 3.1250e-05
# Epoch 72/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.9201 - f1_score: 0.9205
# Epoch 72: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 296s 3s/step - loss: 0.2407 - accuracy: 0.9201 - f1_score: 0.9205 - val_loss: 0.3380 - val_accuracy: 0.8973 - val_f1_score: 0.8958 - lr: 3.1250e-05
# Epoch 73/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9179 - f1_score: 0.9157
# Epoch 73: val_f1_score did not improve from 0.90235
# 104/104 [==============================] - 280s 3s/step - loss: 0.2493 - accuracy: 0.9179 - f1_score: 0.9157 - val_loss: 0.3213 - val_accuracy: 0.8993 - val_f1_score: 0.9009 - lr: 3.1250e-05
# Epoch 74/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9229 - f1_score: 0.9210
# Epoch 74: val_f1_score improved from 0.90235 to 0.90530, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 281s 3s/step - loss: 0.2428 - accuracy: 0.9229 - f1_score: 0.9210 - val_loss: 0.3331 - val_accuracy: 0.9054 - val_f1_score: 0.9053 - lr: 3.1250e-05
# Epoch 75/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9218 - f1_score: 0.9212
# Epoch 75: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 284s 3s/step - loss: 0.2414 - accuracy: 0.9218 - f1_score: 0.9212 - val_loss: 0.3343 - val_accuracy: 0.9043 - val_f1_score: 0.9015 - lr: 3.1250e-05
# Epoch 76/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9224 - f1_score: 0.9208
# Epoch 76: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 274s 3s/step - loss: 0.2400 - accuracy: 0.9224 - f1_score: 0.9208 - val_loss: 0.3382 - val_accuracy: 0.8993 - val_f1_score: 0.9017 - lr: 3.1250e-05
# Epoch 77/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9243 - f1_score: 0.9225
# Epoch 77: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 268s 3s/step - loss: 0.2408 - accuracy: 0.9243 - f1_score: 0.9225 - val_loss: 0.3476 - val_accuracy: 0.8912 - val_f1_score: 0.8912 - lr: 3.1250e-05
# Epoch 78/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9240 - f1_score: 0.9226
# Epoch 78: val_f1_score did not improve from 0.90530
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 263s 3s/step - loss: 0.2361 - accuracy: 0.9240 - f1_score: 0.9226 - val_loss: 0.3424 - val_accuracy: 0.8993 - val_f1_score: 0.8967 - lr: 3.1250e-05
# Epoch 79/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9204 - f1_score: 0.9194
# Epoch 79: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 255s 2s/step - loss: 0.2505 - accuracy: 0.9204 - f1_score: 0.9194 - val_loss: 0.3458 - val_accuracy: 0.8981 - val_f1_score: 0.8954 - lr: 1.5625e-05
# Epoch 80/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.9196 - f1_score: 0.9185
# Epoch 80: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 273s 3s/step - loss: 0.2500 - accuracy: 0.9196 - f1_score: 0.9185 - val_loss: 0.3351 - val_accuracy: 0.8977 - val_f1_score: 0.8978 - lr: 1.5625e-05
# Epoch 81/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2396 - accuracy: 0.9235 - f1_score: 0.9232
# Epoch 81: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 272s 3s/step - loss: 0.2396 - accuracy: 0.9235 - f1_score: 0.9232 - val_loss: 0.3468 - val_accuracy: 0.8977 - val_f1_score: 0.8965 - lr: 1.5625e-05
# Epoch 82/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9219 - f1_score: 0.9202
# Epoch 82: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 284s 3s/step - loss: 0.2413 - accuracy: 0.9219 - f1_score: 0.9202 - val_loss: 0.3319 - val_accuracy: 0.8946 - val_f1_score: 0.8912 - lr: 1.5625e-05
# Epoch 83/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9207 - f1_score: 0.9196
# Epoch 83: val_f1_score did not improve from 0.90530
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 287s 3s/step - loss: 0.2435 - accuracy: 0.9207 - f1_score: 0.9196 - val_loss: 0.3318 - val_accuracy: 0.9008 - val_f1_score: 0.9023 - lr: 1.5625e-05
# Epoch 84/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.9223 - f1_score: 0.9221
# Epoch 84: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 271s 3s/step - loss: 0.2417 - accuracy: 0.9223 - f1_score: 0.9221 - val_loss: 0.3460 - val_accuracy: 0.8942 - val_f1_score: 0.8962 - lr: 7.8125e-06
# Epoch 85/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9258 - f1_score: 0.9249
# Epoch 85: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 294s 3s/step - loss: 0.2413 - accuracy: 0.9258 - f1_score: 0.9249 - val_loss: 0.3514 - val_accuracy: 0.8888 - val_f1_score: 0.8880 - lr: 7.8125e-06
# Epoch 86/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9219 - f1_score: 0.9217
# Epoch 86: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 310s 3s/step - loss: 0.2357 - accuracy: 0.9219 - f1_score: 0.9217 - val_loss: 0.3216 - val_accuracy: 0.8985 - val_f1_score: 0.8987 - lr: 7.8125e-06
# Epoch 87/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9208 - f1_score: 0.9195
# Epoch 87: val_f1_score did not improve from 0.90530
# 104/104 [==============================] - 305s 3s/step - loss: 0.2428 - accuracy: 0.9208 - f1_score: 0.9195 - val_loss: 0.3427 - val_accuracy: 0.8877 - val_f1_score: 0.8880 - lr: 7.8125e-06
# Epoch 88/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.9229 - f1_score: 0.9223
# Epoch 88: val_f1_score improved from 0.90530 to 0.90532, saving model to saved_outputs_basic_augment\Ensemble3\saved_models\best_Ensemble3.h5
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 104/104 [==============================] - 307s 3s/step - loss: 0.2328 - accuracy: 0.9229 - f1_score: 0.9223 - val_loss: 0.3287 - val_accuracy: 0.9078 - val_f1_score: 0.9053 - lr: 7.8125e-06

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 87s 2s/step - loss: 0.2723 - accuracy: 0.9149 - f1_score: 0.9125
#   model_name  test_loss  test_accuracy  test_f1_score
# 0  Ensemble3    0.27232       0.914946       0.912479

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 92s 3s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.874016  0.853846  0.863813   130.000000
# 1              0.931373  0.950000  0.940594   100.000000
# 2              0.987179  0.855556  0.916667    90.000000
# 3              0.965909  0.841584  0.899471   101.000000
# 4              0.919492  0.923404  0.921444   470.000000
# 5              0.876866  0.928854  0.902111   253.000000
# 6              0.860215  0.919540  0.888889   174.000000
# 7              0.894009  0.900232  0.897110   431.000000
# 8              0.921951  0.863014  0.891509   219.000000
# 9              0.931818  0.937630  0.934715   481.000000
# 10             0.918575  0.925641  0.922095   390.000000
# 11             0.951417  0.925197  0.938124   254.000000
# 12             0.919255  0.973684  0.945687   152.000000
# accuracy       0.914946  0.914946  0.914946     0.914946
# macro avg      0.919390  0.907552  0.912479  3245.000000
# weighted avg   0.915842  0.914946  0.914890  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#   Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  Ensemble3  0.914946          0.91939      0.907552        0.912479
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score     Loss
# 0            0.915842         0.914946            0.91489  0.27232

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.91495
# 1      Macro Precision  0.91939
# 2         Macro Recall  0.90755
# 3       Macro F1-Score  0.91248
# 4            Macro FPR  0.00729
# 5            Macro FNR  0.09245
# 6            Macro FDR  0.08061
# 7            Macro NPV  0.99275
# 8   Weighted Precision  0.91584
# 9      Weighted Recall  0.91495
# 10   Weighted F1-Score  0.91489
# 11        Weighted FPR  0.00977
# 12        Weighted FNR  0.08505
# 13        Weighted FDR  0.08416
# 14        Weighted NPV  0.99075
