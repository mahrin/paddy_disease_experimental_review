# %% [markdown]
# - imbalance data: https://www.linkedin.com/pulse/some-tricks-handling-imbalanced-dataset-image-m-farhan-tandia
# - base model: https://www.youtube.com/watch?v=t8eSPbvl0vU
# - https://www.kaggle.com/code/hongjae6/simple-baseline-using-keras-resnet50

# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, Activation, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')
######################################################################################################
from keras_tuner import RandomSearch, HyperParameters
from tensorflow.keras.applications import Xception, DenseNet121
import keras_tuner as kt

# %%
model_name = 'Ensemble2_v4'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 
# FNAME_TUNER_REPORT = 'Report_tune_'+ model_name
################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_SAVE_RESULT, 'saved_tuner_model')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_all_augment\Ensemble2_v4
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment\Ensemble2_v4\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment\Ensemble2_v4\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_12068\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=12, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING
#
# Trial 15 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 9
# Score: 0.7056062817573547
#
# Trial 11 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 5
# Score: 0.705497920513153179205131531

# %%
# Function to build the model with an ensemble of feature extractors
def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
                      dropout= 0.1,
                      activation='relu',
                      units= 1024,
                      nr_classes=NUM_CLASSES,
                      loss = "categorical_crossentropy", 
                      retrain_backbone_network=False,
                      learning_rate = 0.001,
                      global_pooling = 'avg',
                      filters=7,
                      name='ensemble2'):


    inputs = Input(shape=input_shape)

    # Feature extraction from Xception
    Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    Xception_features = Xception_base(inputs)
    Xception_features = GlobalAveragePooling2D()(Xception_features)

    # Feature extraction from DenseNet121
    densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
    densenet_features = densenet_base(inputs)
    densenet_features = GlobalAveragePooling2D()(densenet_features)

    # Concatenate features
    concatenated_features = Concatenate()([Xception_features, densenet_features])

    if filters==3:
        filters = (3,3)
    elif filters==5:
        filters = (5,5)
    elif filters==7:
        filters = (7,7)
    elif filters==9:
        filters = (9,9)

    # # Add a tunable dropout layer
    # x = Dropout(dropout)(concatenated_features)

    # # A fully connected layer with a tunable number of units
    # x = Dense(units)(x)

    #     # Add a tunable dropout layer
    # x = Dropout(dropout)(x)

    # # A fully connected layer with a tunable number of units
    # x = Dense(units)(x)
        # Add a tunable dropout layer
    x = Dropout(dropout)(concatenated_features)

    # A fully connected layer with a tunable number of units
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)

    # Add a tunable dropout layer
    x = Dropout(dropout)(x)

    # A fully connected layer with a tunable number of units again
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)


    # Output layer
    predictions = Dense( nr_classes, activation='softmax')(x)

    # Create and compile the model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=loss,
        metrics=['accuracy', f1_score]
    )

    return model

# %%
# from tensorflow.keras.applications import Xception, DenseNet121, InceptionResNetV2
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble3_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.2,
#                       activation='relu',
#                       units= 512,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy",
#                       retrain_backbone_network=False,
#                       filters=7):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)


#         # Feature extraction from Xception
#     InceptionResNetV2_base = InceptionResNetV2(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     InceptionResNetV2_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     InceptionResNetV2_features = InceptionResNetV2_base(inputs)
#     InceptionResNetV2_features = GlobalAveragePooling2D()(InceptionResNetV2_features)


#     # Concatenate the features
#     concatenated_features = Concatenate()([densenet_features, Xception_features, InceptionResNetV2_features])

#     x = Dropout(dropout)(concatenated_features)
#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create the final ensemble model
#     model = Model(inputs=inputs, outputs=predictions)
#     optimizer = Adam(learning_rate=0.0001 )
#     model.compile(
#         optimizer=optimizer,
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %% [markdown]
# # Train and Results
# - DOES NOT WORK---EfficientNetV2, Nasnet, Resnet, VGG16,
# - DOES NOT WORK--InceptionV3--ERROR: No matching distribution found for tensorflow-directml (checked with colab)
# - DOES NOT WORK--InceptionResNetV2--slighly works
# - original models selected: DenseNet121, -mobilenet X-ception, ,-Inception
# - My models selected: 'ensemble2' (70), Basic CNN v1(91), Basic CNN v2 (92), transfer_mobilenet (85), ensembleXception
# - tuned vit models:  T2TViT(47)",---Cait (26), 16

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN() 
model = get_ensemble2_model()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 1.9294 - accuracy: 0.4338 - f1_score: 0.3878
# Epoch 1: val_f1_score improved from -inf to 0.44098, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 115s 1s/step - loss: 1.9294 - accuracy: 0.4338 - f1_score: 0.3878 - val_loss: 1.6007 - val_accuracy: 0.4952 - val_f1_score: 0.4410 - lr: 0.0010
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3388 - accuracy: 0.5706 - f1_score: 0.5389
# Epoch 2: val_f1_score improved from 0.44098 to 0.56432, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 97s 926ms/step - loss: 1.3388 - accuracy: 0.5706 - f1_score: 0.5389 - val_loss: 1.2768 - val_accuracy: 0.6040 - val_f1_score: 0.5643 - lr: 0.0010
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1846 - accuracy: 0.6221 - f1_score: 0.6013
# Epoch 3: val_f1_score improved from 0.56432 to 0.58990, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 96s 919ms/step - loss: 1.1846 - accuracy: 0.6221 - f1_score: 0.6013 - val_loss: 1.2336 - val_accuracy: 0.6063 - val_f1_score: 0.5899 - lr: 0.0010
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0667 - accuracy: 0.6544 - f1_score: 0.6347
# Epoch 4: val_f1_score did not improve from 0.58990
# 104/104 [==============================] - 92s 882ms/step - loss: 1.0667 - accuracy: 0.6544 - f1_score: 0.6347 - val_loss: 1.2122 - val_accuracy: 0.6113 - val_f1_score: 0.5862 - lr: 0.0010
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9751 - accuracy: 0.6857 - f1_score: 0.6689
# Epoch 5: val_f1_score improved from 0.58990 to 0.63765, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 96s 916ms/step - loss: 0.9751 - accuracy: 0.6857 - f1_score: 0.6689 - val_loss: 1.0864 - val_accuracy: 0.6573 - val_f1_score: 0.6376 - lr: 0.0010
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.7111 - f1_score: 0.6968
# Epoch 6: val_f1_score improved from 0.63765 to 0.63915, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 97s 934ms/step - loss: 0.8939 - accuracy: 0.7111 - f1_score: 0.6968 - val_loss: 1.0754 - val_accuracy: 0.6523 - val_f1_score: 0.6392 - lr: 0.0010
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8442 - accuracy: 0.7189 - f1_score: 0.7059
# Epoch 7: val_f1_score improved from 0.63915 to 0.69538, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 98s 934ms/step - loss: 0.8442 - accuracy: 0.7189 - f1_score: 0.7059 - val_loss: 0.8895 - val_accuracy: 0.7063 - val_f1_score: 0.6954 - lr: 0.0010
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7955 - accuracy: 0.7415 - f1_score: 0.7297
# Epoch 8: val_f1_score did not improve from 0.69538
# 104/104 [==============================] - 90s 867ms/step - loss: 0.7955 - accuracy: 0.7415 - f1_score: 0.7297 - val_loss: 0.9588 - val_accuracy: 0.6905 - val_f1_score: 0.6869 - lr: 0.0010
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7497 - accuracy: 0.7534 - f1_score: 0.7415
# Epoch 9: val_f1_score improved from 0.69538 to 0.72243, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 97s 932ms/step - loss: 0.7497 - accuracy: 0.7534 - f1_score: 0.7415 - val_loss: 0.8391 - val_accuracy: 0.7321 - val_f1_score: 0.7224 - lr: 0.0010
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7151 - accuracy: 0.7619 - f1_score: 0.7554
# Epoch 10: val_f1_score did not improve from 0.72243
# 104/104 [==============================] - 86s 823ms/step - loss: 0.7151 - accuracy: 0.7619 - f1_score: 0.7554 - val_loss: 0.9234 - val_accuracy: 0.7071 - val_f1_score: 0.6894 - lr: 0.0010
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.7734 - f1_score: 0.7625
# Epoch 11: val_f1_score improved from 0.72243 to 0.73533, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 92s 879ms/step - loss: 0.6933 - accuracy: 0.7734 - f1_score: 0.7625 - val_loss: 0.7847 - val_accuracy: 0.7526 - val_f1_score: 0.7353 - lr: 0.0010
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6567 - accuracy: 0.7826 - f1_score: 0.7733
# Epoch 12: val_f1_score improved from 0.73533 to 0.76205, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 94s 898ms/step - loss: 0.6567 - accuracy: 0.7826 - f1_score: 0.7733 - val_loss: 0.7172 - val_accuracy: 0.7727 - val_f1_score: 0.7620 - lr: 0.0010
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6360 - accuracy: 0.7914 - f1_score: 0.7866
# Epoch 13: val_f1_score did not improve from 0.76205
# 104/104 [==============================] - 89s 855ms/step - loss: 0.6360 - accuracy: 0.7914 - f1_score: 0.7866 - val_loss: 0.8727 - val_accuracy: 0.7213 - val_f1_score: 0.7189 - lr: 0.0010
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6104 - accuracy: 0.7950 - f1_score: 0.7897
# Epoch 14: val_f1_score did not improve from 0.76205
# 104/104 [==============================] - 86s 824ms/step - loss: 0.6104 - accuracy: 0.7950 - f1_score: 0.7897 - val_loss: 0.7434 - val_accuracy: 0.7642 - val_f1_score: 0.7530 - lr: 0.0010
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6189 - accuracy: 0.7909 - f1_score: 0.7807
# Epoch 15: val_f1_score did not improve from 0.76205
# 104/104 [==============================] - 88s 845ms/step - loss: 0.6189 - accuracy: 0.7909 - f1_score: 0.7807 - val_loss: 0.7896 - val_accuracy: 0.7638 - val_f1_score: 0.7527 - lr: 0.0010
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5900 - accuracy: 0.8041 - f1_score: 0.7957
# Epoch 16: val_f1_score did not improve from 0.76205
# 104/104 [==============================] - 89s 846ms/step - loss: 0.5900 - accuracy: 0.8041 - f1_score: 0.7957 - val_loss: 0.7652 - val_accuracy: 0.7646 - val_f1_score: 0.7580 - lr: 0.0010
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5675 - accuracy: 0.8120 - f1_score: 0.8056
# Epoch 17: val_f1_score improved from 0.76205 to 0.76562, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 92s 877ms/step - loss: 0.5675 - accuracy: 0.8120 - f1_score: 0.8056 - val_loss: 0.7386 - val_accuracy: 0.7761 - val_f1_score: 0.7656 - lr: 0.0010
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8436 - f1_score: 0.8399
# Epoch 18: val_f1_score improved from 0.76562 to 0.83439, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 93s 892ms/step - loss: 0.4802 - accuracy: 0.8436 - f1_score: 0.8399 - val_loss: 0.5435 - val_accuracy: 0.8387 - val_f1_score: 0.8344 - lr: 5.0000e-04
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8572 - f1_score: 0.8526
# Epoch 19: val_f1_score did not improve from 0.83439
# 104/104 [==============================] - 88s 844ms/step - loss: 0.4256 - accuracy: 0.8572 - f1_score: 0.8526 - val_loss: 0.4988 - val_accuracy: 0.8421 - val_f1_score: 0.8332 - lr: 5.0000e-04
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.8646 - f1_score: 0.8601
# Epoch 20: val_f1_score did not improve from 0.83439
# 104/104 [==============================] - 83s 790ms/step - loss: 0.4178 - accuracy: 0.8646 - f1_score: 0.8601 - val_loss: 0.5125 - val_accuracy: 0.8360 - val_f1_score: 0.8285 - lr: 5.0000e-04
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3978 - accuracy: 0.8690 - f1_score: 0.8669
# Epoch 21: val_f1_score improved from 0.83439 to 0.84929, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 91s 873ms/step - loss: 0.3978 - accuracy: 0.8690 - f1_score: 0.8669 - val_loss: 0.4819 - val_accuracy: 0.8468 - val_f1_score: 0.8493 - lr: 5.0000e-04
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.8708 - f1_score: 0.8689
# Epoch 22: val_f1_score improved from 0.84929 to 0.85479, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 91s 870ms/step - loss: 0.3832 - accuracy: 0.8708 - f1_score: 0.8689 - val_loss: 0.4600 - val_accuracy: 0.8549 - val_f1_score: 0.8548 - lr: 5.0000e-04
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8807 - f1_score: 0.8773
# Epoch 23: val_f1_score improved from 0.85479 to 0.85635, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 91s 867ms/step - loss: 0.3627 - accuracy: 0.8807 - f1_score: 0.8773 - val_loss: 0.4541 - val_accuracy: 0.8603 - val_f1_score: 0.8563 - lr: 5.0000e-04
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3604 - accuracy: 0.8823 - f1_score: 0.8802
# Epoch 24: val_f1_score did not improve from 0.85635
# 104/104 [==============================] - 85s 810ms/step - loss: 0.3604 - accuracy: 0.8823 - f1_score: 0.8802 - val_loss: 0.4610 - val_accuracy: 0.8514 - val_f1_score: 0.8553 - lr: 5.0000e-04
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3585 - accuracy: 0.8804 - f1_score: 0.8766
# Epoch 25: val_f1_score did not improve from 0.85635
# 104/104 [==============================] - 85s 816ms/step - loss: 0.3585 - accuracy: 0.8804 - f1_score: 0.8766 - val_loss: 0.4839 - val_accuracy: 0.8421 - val_f1_score: 0.8404 - lr: 5.0000e-04
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3431 - accuracy: 0.8897 - f1_score: 0.8878
# Epoch 26: val_f1_score did not improve from 0.85635
# 104/104 [==============================] - 83s 791ms/step - loss: 0.3431 - accuracy: 0.8897 - f1_score: 0.8878 - val_loss: 0.4576 - val_accuracy: 0.8580 - val_f1_score: 0.8540 - lr: 5.0000e-04
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3436 - accuracy: 0.8864 - f1_score: 0.8856
# Epoch 27: val_f1_score did not improve from 0.85635
# 104/104 [==============================] - 84s 804ms/step - loss: 0.3436 - accuracy: 0.8864 - f1_score: 0.8856 - val_loss: 0.4634 - val_accuracy: 0.8572 - val_f1_score: 0.8558 - lr: 5.0000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8819 - f1_score: 0.8794
# Epoch 28: val_f1_score improved from 0.85635 to 0.86197, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 87s 839ms/step - loss: 0.3465 - accuracy: 0.8819 - f1_score: 0.8794 - val_loss: 0.4490 - val_accuracy: 0.8599 - val_f1_score: 0.8620 - lr: 5.0000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3341 - accuracy: 0.8907 - f1_score: 0.8921
# Epoch 29: val_f1_score improved from 0.86197 to 0.86457, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 87s 833ms/step - loss: 0.3341 - accuracy: 0.8907 - f1_score: 0.8921 - val_loss: 0.4327 - val_accuracy: 0.8665 - val_f1_score: 0.8646 - lr: 5.0000e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3182 - accuracy: 0.8958 - f1_score: 0.8931
# Epoch 30: val_f1_score improved from 0.86457 to 0.87233, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 90s 861ms/step - loss: 0.3182 - accuracy: 0.8958 - f1_score: 0.8931 - val_loss: 0.4265 - val_accuracy: 0.8711 - val_f1_score: 0.8723 - lr: 5.0000e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8974 - f1_score: 0.8953
# Epoch 31: val_f1_score did not improve from 0.87233
# 104/104 [==============================] - 84s 801ms/step - loss: 0.3005 - accuracy: 0.8974 - f1_score: 0.8953 - val_loss: 0.4490 - val_accuracy: 0.8626 - val_f1_score: 0.8558 - lr: 5.0000e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.8930 - f1_score: 0.8905
# Epoch 32: val_f1_score improved from 0.87233 to 0.87332, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 89s 854ms/step - loss: 0.3091 - accuracy: 0.8930 - f1_score: 0.8905 - val_loss: 0.4140 - val_accuracy: 0.8699 - val_f1_score: 0.8733 - lr: 5.0000e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8980 - f1_score: 0.8968
# Epoch 33: val_f1_score improved from 0.87332 to 0.87672, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 90s 861ms/step - loss: 0.2988 - accuracy: 0.8980 - f1_score: 0.8968 - val_loss: 0.4014 - val_accuracy: 0.8773 - val_f1_score: 0.8767 - lr: 5.0000e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.9044 - f1_score: 0.9037
# Epoch 34: val_f1_score did not improve from 0.87672
# 104/104 [==============================] - 83s 796ms/step - loss: 0.2921 - accuracy: 0.9044 - f1_score: 0.9037 - val_loss: 0.4108 - val_accuracy: 0.8630 - val_f1_score: 0.8637 - lr: 5.0000e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.9041 - f1_score: 0.9057
# Epoch 35: val_f1_score did not improve from 0.87672
# 104/104 [==============================] - 85s 816ms/step - loss: 0.2949 - accuracy: 0.9041 - f1_score: 0.9057 - val_loss: 0.3927 - val_accuracy: 0.8780 - val_f1_score: 0.8742 - lr: 5.0000e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.9027 - f1_score: 0.9006
# Epoch 36: val_f1_score improved from 0.87672 to 0.87722, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 87s 830ms/step - loss: 0.2953 - accuracy: 0.9027 - f1_score: 0.9006 - val_loss: 0.4115 - val_accuracy: 0.8746 - val_f1_score: 0.8772 - lr: 5.0000e-04
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.9041 - f1_score: 0.9021
# Epoch 37: val_f1_score did not improve from 0.87722
# 104/104 [==============================] - 85s 816ms/step - loss: 0.2887 - accuracy: 0.9041 - f1_score: 0.9021 - val_loss: 0.3903 - val_accuracy: 0.8746 - val_f1_score: 0.8696 - lr: 5.0000e-04
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.9069 - f1_score: 0.9061
# Epoch 38: val_f1_score improved from 0.87722 to 0.87765, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 89s 851ms/step - loss: 0.2831 - accuracy: 0.9069 - f1_score: 0.9061 - val_loss: 0.3885 - val_accuracy: 0.8792 - val_f1_score: 0.8777 - lr: 5.0000e-04
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.9046 - f1_score: 0.9015
# Epoch 39: val_f1_score did not improve from 0.87765
# 104/104 [==============================] - 83s 796ms/step - loss: 0.2810 - accuracy: 0.9046 - f1_score: 0.9015 - val_loss: 0.4011 - val_accuracy: 0.8726 - val_f1_score: 0.8654 - lr: 5.0000e-04
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9064 - f1_score: 0.9045
# Epoch 40: val_f1_score improved from 0.87765 to 0.87847, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 93s 894ms/step - loss: 0.2700 - accuracy: 0.9064 - f1_score: 0.9045 - val_loss: 0.3890 - val_accuracy: 0.8811 - val_f1_score: 0.8785 - lr: 5.0000e-04
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.9111 - f1_score: 0.9107
# Epoch 41: val_f1_score improved from 0.87847 to 0.88268, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 104s 995ms/step - loss: 0.2699 - accuracy: 0.9111 - f1_score: 0.9107 - val_loss: 0.3818 - val_accuracy: 0.8819 - val_f1_score: 0.8827 - lr: 5.0000e-04
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9091 - f1_score: 0.9071
# Epoch 42: val_f1_score improved from 0.88268 to 0.88372, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 102s 978ms/step - loss: 0.2708 - accuracy: 0.9091 - f1_score: 0.9071 - val_loss: 0.3795 - val_accuracy: 0.8827 - val_f1_score: 0.8837 - lr: 5.0000e-04
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9197 - f1_score: 0.9191
# Epoch 43: val_f1_score did not improve from 0.88372
# 104/104 [==============================] - 93s 891ms/step - loss: 0.2466 - accuracy: 0.9197 - f1_score: 0.9191 - val_loss: 0.3983 - val_accuracy: 0.8765 - val_f1_score: 0.8785 - lr: 5.0000e-04
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9117 - f1_score: 0.9108
# Epoch 44: val_f1_score improved from 0.88372 to 0.89030, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 103s 989ms/step - loss: 0.2663 - accuracy: 0.9117 - f1_score: 0.9108 - val_loss: 0.3603 - val_accuracy: 0.8869 - val_f1_score: 0.8903 - lr: 5.0000e-04
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.9112 - f1_score: 0.9095
# Epoch 45: val_f1_score did not improve from 0.89030
# 104/104 [==============================] - 94s 901ms/step - loss: 0.2618 - accuracy: 0.9112 - f1_score: 0.9095 - val_loss: 0.3727 - val_accuracy: 0.8861 - val_f1_score: 0.8868 - lr: 5.0000e-04
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.9168 - f1_score: 0.9167
# Epoch 46: val_f1_score did not improve from 0.89030
# 104/104 [==============================] - 90s 863ms/step - loss: 0.2481 - accuracy: 0.9168 - f1_score: 0.9167 - val_loss: 0.4219 - val_accuracy: 0.8715 - val_f1_score: 0.8684 - lr: 5.0000e-04
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9221 - f1_score: 0.9205
# Epoch 47: val_f1_score did not improve from 0.89030
# 104/104 [==============================] - 94s 905ms/step - loss: 0.2336 - accuracy: 0.9221 - f1_score: 0.9205 - val_loss: 0.3766 - val_accuracy: 0.8915 - val_f1_score: 0.8891 - lr: 5.0000e-04
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.9204 - f1_score: 0.9180
# Epoch 48: val_f1_score did not improve from 0.89030
# 104/104 [==============================] - 96s 922ms/step - loss: 0.2407 - accuracy: 0.9204 - f1_score: 0.9180 - val_loss: 0.3770 - val_accuracy: 0.8904 - val_f1_score: 0.8887 - lr: 5.0000e-04
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9170 - f1_score: 0.9135
# Epoch 49: val_f1_score did not improve from 0.89030
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 97s 930ms/step - loss: 0.2476 - accuracy: 0.9170 - f1_score: 0.9135 - val_loss: 0.3851 - val_accuracy: 0.8827 - val_f1_score: 0.8794 - lr: 5.0000e-04
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9286 - f1_score: 0.9282
# Epoch 50: val_f1_score improved from 0.89030 to 0.90396, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 101s 968ms/step - loss: 0.2189 - accuracy: 0.9286 - f1_score: 0.9282 - val_loss: 0.3189 - val_accuracy: 0.9027 - val_f1_score: 0.9040 - lr: 2.5000e-04
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9365 - f1_score: 0.9374
# Epoch 51: val_f1_score did not improve from 0.90396
# 104/104 [==============================] - 96s 920ms/step - loss: 0.1958 - accuracy: 0.9365 - f1_score: 0.9374 - val_loss: 0.3183 - val_accuracy: 0.9054 - val_f1_score: 0.9020 - lr: 2.5000e-04
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9411 - f1_score: 0.9390
# Epoch 52: val_f1_score improved from 0.90396 to 0.90757, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 99s 944ms/step - loss: 0.1846 - accuracy: 0.9411 - f1_score: 0.9390 - val_loss: 0.3205 - val_accuracy: 0.9074 - val_f1_score: 0.9076 - lr: 2.5000e-04
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9337 - f1_score: 0.9344
# Epoch 53: val_f1_score did not improve from 0.90757
# 104/104 [==============================] - 97s 929ms/step - loss: 0.1947 - accuracy: 0.9337 - f1_score: 0.9344 - val_loss: 0.3059 - val_accuracy: 0.9047 - val_f1_score: 0.9038 - lr: 2.5000e-04
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9382 - f1_score: 0.9379
# Epoch 54: val_f1_score improved from 0.90757 to 0.91213, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 99s 954ms/step - loss: 0.1837 - accuracy: 0.9382 - f1_score: 0.9379 - val_loss: 0.3153 - val_accuracy: 0.9128 - val_f1_score: 0.9121 - lr: 2.5000e-04
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1747 - accuracy: 0.9411 - f1_score: 0.9411
# Epoch 55: val_f1_score did not improve from 0.91213
# 104/104 [==============================] - 94s 899ms/step - loss: 0.1747 - accuracy: 0.9411 - f1_score: 0.9411 - val_loss: 0.3396 - val_accuracy: 0.9012 - val_f1_score: 0.9000 - lr: 2.5000e-04
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1781 - accuracy: 0.9391 - f1_score: 0.9364
# Epoch 56: val_f1_score improved from 0.91213 to 0.91855, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 103s 983ms/step - loss: 0.1781 - accuracy: 0.9391 - f1_score: 0.9364 - val_loss: 0.2924 - val_accuracy: 0.9182 - val_f1_score: 0.9186 - lr: 2.5000e-04
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9392 - f1_score: 0.9373
# Epoch 57: val_f1_score did not improve from 0.91855
# 104/104 [==============================] - 94s 903ms/step - loss: 0.1784 - accuracy: 0.9392 - f1_score: 0.9373 - val_loss: 0.2969 - val_accuracy: 0.9108 - val_f1_score: 0.9104 - lr: 2.5000e-04
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9437 - f1_score: 0.9430
# Epoch 58: val_f1_score did not improve from 0.91855
# 104/104 [==============================] - 92s 877ms/step - loss: 0.1742 - accuracy: 0.9437 - f1_score: 0.9430 - val_loss: 0.3262 - val_accuracy: 0.9101 - val_f1_score: 0.9155 - lr: 2.5000e-04
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9444 - f1_score: 0.9447
# Epoch 59: val_f1_score did not improve from 0.91855
# 104/104 [==============================] - 83s 791ms/step - loss: 0.1640 - accuracy: 0.9444 - f1_score: 0.9447 - val_loss: 0.2944 - val_accuracy: 0.9143 - val_f1_score: 0.9141 - lr: 2.5000e-04
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9406 - f1_score: 0.9400
# Epoch 60: val_f1_score did not improve from 0.91855
# 104/104 [==============================] - 90s 859ms/step - loss: 0.1731 - accuracy: 0.9406 - f1_score: 0.9400 - val_loss: 0.3008 - val_accuracy: 0.9120 - val_f1_score: 0.9114 - lr: 2.5000e-04
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9422 - f1_score: 0.9409
# Epoch 61: val_f1_score did not improve from 0.91855
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 93s 892ms/step - loss: 0.1711 - accuracy: 0.9422 - f1_score: 0.9409 - val_loss: 0.3098 - val_accuracy: 0.9120 - val_f1_score: 0.9111 - lr: 2.5000e-04
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9483 - f1_score: 0.9472
# Epoch 62: val_f1_score did not improve from 0.91855
# 104/104 [==============================] - 94s 905ms/step - loss: 0.1567 - accuracy: 0.9483 - f1_score: 0.9472 - val_loss: 0.2932 - val_accuracy: 0.9151 - val_f1_score: 0.9184 - lr: 1.2500e-04
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9481 - f1_score: 0.9483
# Epoch 63: val_f1_score did not improve from 0.91855
# 104/104 [==============================] - 94s 896ms/step - loss: 0.1572 - accuracy: 0.9481 - f1_score: 0.9483 - val_loss: 0.2881 - val_accuracy: 0.9143 - val_f1_score: 0.9153 - lr: 1.2500e-04
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9506 - f1_score: 0.9492
# Epoch 64: val_f1_score improved from 0.91855 to 0.92851, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 100s 954ms/step - loss: 0.1521 - accuracy: 0.9506 - f1_score: 0.9492 - val_loss: 0.2605 - val_accuracy: 0.9247 - val_f1_score: 0.9285 - lr: 1.2500e-04
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9514 - f1_score: 0.9509
# Epoch 65: val_f1_score did not improve from 0.92851
# 104/104 [==============================] - 94s 906ms/step - loss: 0.1511 - accuracy: 0.9514 - f1_score: 0.9509 - val_loss: 0.2952 - val_accuracy: 0.9228 - val_f1_score: 0.9266 - lr: 1.2500e-04
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9496 - f1_score: 0.9478
# Epoch 66: val_f1_score did not improve from 0.92851
# 104/104 [==============================] - 95s 905ms/step - loss: 0.1504 - accuracy: 0.9496 - f1_score: 0.9478 - val_loss: 0.2644 - val_accuracy: 0.9232 - val_f1_score: 0.9232 - lr: 1.2500e-04
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9530 - f1_score: 0.9533
# Epoch 67: val_f1_score did not improve from 0.92851
# 104/104 [==============================] - 95s 910ms/step - loss: 0.1373 - accuracy: 0.9530 - f1_score: 0.9533 - val_loss: 0.2789 - val_accuracy: 0.9132 - val_f1_score: 0.9137 - lr: 1.2500e-04
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9553 - f1_score: 0.9537
# Epoch 68: val_f1_score improved from 0.92851 to 0.92918, saving model to saved_outputs_all_augment\Ensemble2_v4\saved_models\best_Ensemble2_v4.h5
# 104/104 [==============================] - 101s 969ms/step - loss: 0.1434 - accuracy: 0.9553 - f1_score: 0.9537 - val_loss: 0.2566 - val_accuracy: 0.9294 - val_f1_score: 0.9292 - lr: 1.2500e-04
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.9545 - f1_score: 0.9554
# Epoch 69: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 912ms/step - loss: 0.1433 - accuracy: 0.9545 - f1_score: 0.9554 - val_loss: 0.2585 - val_accuracy: 0.9201 - val_f1_score: 0.9207 - lr: 1.2500e-04
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9498 - f1_score: 0.9488
# Epoch 70: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 906ms/step - loss: 0.1484 - accuracy: 0.9498 - f1_score: 0.9488 - val_loss: 0.2722 - val_accuracy: 0.9201 - val_f1_score: 0.9214 - lr: 1.2500e-04
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9570 - f1_score: 0.9567
# Epoch 71: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 905ms/step - loss: 0.1352 - accuracy: 0.9570 - f1_score: 0.9567 - val_loss: 0.2839 - val_accuracy: 0.9182 - val_f1_score: 0.9208 - lr: 1.2500e-04
# Epoch 72/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9518 - f1_score: 0.9517
# Epoch 72: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 94s 905ms/step - loss: 0.1455 - accuracy: 0.9518 - f1_score: 0.9517 - val_loss: 0.2865 - val_accuracy: 0.9263 - val_f1_score: 0.9251 - lr: 1.2500e-04
# Epoch 73/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9545 - f1_score: 0.9552
# Epoch 73: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 99s 950ms/step - loss: 0.1332 - accuracy: 0.9545 - f1_score: 0.9552 - val_loss: 0.2489 - val_accuracy: 0.9240 - val_f1_score: 0.9264 - lr: 1.2500e-04
# Epoch 74/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9581 - f1_score: 0.9574
# Epoch 74: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 94s 898ms/step - loss: 0.1318 - accuracy: 0.9581 - f1_score: 0.9574 - val_loss: 0.2578 - val_accuracy: 0.9251 - val_f1_score: 0.9260 - lr: 1.2500e-04
# Epoch 75/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9551 - f1_score: 0.9542
# Epoch 75: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 908ms/step - loss: 0.1390 - accuracy: 0.9551 - f1_score: 0.9542 - val_loss: 0.2578 - val_accuracy: 0.9251 - val_f1_score: 0.9248 - lr: 1.2500e-04
# Epoch 76/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9579 - f1_score: 0.9573
# Epoch 76: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 94s 900ms/step - loss: 0.1260 - accuracy: 0.9579 - f1_score: 0.9573 - val_loss: 0.2724 - val_accuracy: 0.9240 - val_f1_score: 0.9258 - lr: 1.2500e-04
# Epoch 77/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9546 - f1_score: 0.9543
# Epoch 77: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 93s 892ms/step - loss: 0.1366 - accuracy: 0.9546 - f1_score: 0.9543 - val_loss: 0.2551 - val_accuracy: 0.9263 - val_f1_score: 0.9287 - lr: 1.2500e-04
# Epoch 78/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9569 - f1_score: 0.9570
# Epoch 78: val_f1_score did not improve from 0.92918
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 96s 922ms/step - loss: 0.1284 - accuracy: 0.9569 - f1_score: 0.9570 - val_loss: 0.2747 - val_accuracy: 0.9174 - val_f1_score: 0.9196 - lr: 1.2500e-04
# Epoch 79/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9547 - f1_score: 0.9542
# Epoch 79: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 911ms/step - loss: 0.1363 - accuracy: 0.9547 - f1_score: 0.9542 - val_loss: 0.2800 - val_accuracy: 0.9193 - val_f1_score: 0.9223 - lr: 6.2500e-05
# Epoch 80/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9566 - f1_score: 0.9576
# Epoch 80: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 91s 871ms/step - loss: 0.1299 - accuracy: 0.9566 - f1_score: 0.9576 - val_loss: 0.2622 - val_accuracy: 0.9290 - val_f1_score: 0.9289 - lr: 6.2500e-05
# Epoch 81/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9605 - f1_score: 0.9604
# Epoch 81: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 89s 850ms/step - loss: 0.1203 - accuracy: 0.9605 - f1_score: 0.9604 - val_loss: 0.2509 - val_accuracy: 0.9271 - val_f1_score: 0.9282 - lr: 6.2500e-05
# Epoch 82/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9609 - f1_score: 0.9605
# Epoch 82: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 915ms/step - loss: 0.1193 - accuracy: 0.9609 - f1_score: 0.9605 - val_loss: 0.2707 - val_accuracy: 0.9244 - val_f1_score: 0.9216 - lr: 6.2500e-05
# Epoch 83/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9597 - f1_score: 0.9589
# Epoch 83: val_f1_score did not improve from 0.92918
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 94s 904ms/step - loss: 0.1230 - accuracy: 0.9597 - f1_score: 0.9589 - val_loss: 0.2768 - val_accuracy: 0.9182 - val_f1_score: 0.9179 - lr: 6.2500e-05
# Epoch 84/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9603 - f1_score: 0.9599
# Epoch 84: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 95s 916ms/step - loss: 0.1221 - accuracy: 0.9603 - f1_score: 0.9599 - val_loss: 0.2576 - val_accuracy: 0.9244 - val_f1_score: 0.9237 - lr: 3.1250e-05
# Epoch 85/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9600 - f1_score: 0.9599
# Epoch 85: val_f1_score did not improve from 0.92918
# 104/104 [==============================] - 97s 929ms/step - loss: 0.1200 - accuracy: 0.9600 - f1_score: 0.9599 - val_loss: 0.2524 - val_accuracy: 0.9251 - val_f1_score: 0.9249 - lr: 3.1250e-05

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 23s 550ms/step - loss: 0.2714 - accuracy: 0.9227 - f1_score: 0.9197
#      model_name  test_loss  test_accuracy  test_f1_score
# 0  Ensemble2_v4   0.271355        0.92265       0.919742

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 22s 545ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score     support
# 0              0.868613  0.915385  0.891386   130.00000
# 1              0.894231  0.930000  0.911765   100.00000
# 2              0.953488  0.911111  0.931818    90.00000
# 3              0.978495  0.900990  0.938144   101.00000
# 4              0.936842  0.946809  0.941799   470.00000
# 5              0.886447  0.956522  0.920152   253.00000
# 6              0.860335  0.885057  0.872521   174.00000
# 7              0.930521  0.870070  0.899281   431.00000
# 8              0.910377  0.881279  0.895592   219.00000
# 9              0.939959  0.943867  0.941909   481.00000
# 10             0.923664  0.930769  0.927203   390.00000
# 11             0.937500  0.944882  0.941176   254.00000
# 12             0.947020  0.940789  0.943894   152.00000
# accuracy       0.922650  0.922650  0.922650     0.92265
# macro avg      0.920576  0.919810  0.919742  3245.00000
# weighted avg   0.923303  0.922650  0.922606  3245.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#      Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  Ensemble2_v4   0.92265         0.920576       0.91981        0.919742
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.923303          0.92265           0.922606  0.271355

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.92265
# 1      Macro Precision  0.92058
# 2         Macro Recall  0.91981
# 3       Macro F1-Score  0.91974
# 4            Macro FPR  0.00659
# 5            Macro FNR  0.08019
# 6            Macro FDR  0.07942
# 7            Macro NPV  0.99340
# 8   Weighted Precision  0.92330
# 9      Weighted Recall  0.92265
# 10   Weighted F1-Score  0.92261
# 11        Weighted FPR  0.00831
# 12        Weighted FNR  0.07735
# 13        Weighted FDR  0.07670
# 14        Weighted NPV  0.99139
