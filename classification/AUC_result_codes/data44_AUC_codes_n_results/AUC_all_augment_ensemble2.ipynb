# %% [markdown]
# ## Imports

# %%
# !pip install tensorflow-addons

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense
from tensorflow.keras.layers import BatchNormalization, Concatenate, GlobalAveragePooling2D, Activation
# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=4, average='macro')

# %% [markdown]
# ## Setting the paths

# %%
model_name = 'ensemble2'

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
# PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/classification'
sys.path.append(PATH_TO_CODE)
# DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/classification/data44_resized_splited'
DATASET_PATH = r'data44_resized_splited'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')


if not os.path.exists(PATH_TO_SAVE_RESULT):
    # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################


IMG_HEIGHT = 200
IMG_WIDTH = 200
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.3
NUM_CLASSES = 4

BATCH_SIZE = 64
EPOCHS = 150

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'all' #'all'## basic, advanced,
################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.



PATIENCE_EARLY_STOP = 12 # With no improvement in Loss, will stop training

# # Checkpoint parameters
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
PATIENCE_LR_REDUCE=3      # Number of epochs with no improvement after which learning rate will be reduced
COOLDOWN_EPOCHS  = 2              # How many epochs to wait after learning rate reduction before it can be reduced again
MIN_LR = 1e-9
INITIAL_LR = 0.0001 # with 0.001 got 99 percent

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_SAVE_TIME ", PATH_SAVE_TIME )
print("PATH_SAVE_HISTORY", PATH_SAVE_HISTORY)
print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH data44_resized_splited
# DATASET_PATH_TRAIN data44_resized_splited\train
# DATASET_PATH_TEST data44_resized_splited\test
# PATH_SAVE_TIME  saved_outputs_all_augment\ensemble2\ensemble2_training_time.csv
# PATH_SAVE_HISTORY saved_outputs_all_augment\ensemble2\ensemble2_training_history.csv
# PATH_TO_SAVE_RESULT saved_outputs_all_augment\ensemble2
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment\ensemble2\ensemble2_saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment\ensemble2\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_13360\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([
    iaa.ElasticTransformation(alpha=10, sigma=5)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
def create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                      dataset_path_test=DATASET_PATH_TEST,
                      valid_ratio=VALIDATION_SPLIT,
                      augment= False,
                      augment_type='basic'):

    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=10,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.2,  # fraction of total height
                shear_range=0.2,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically

                # Pixel-Level Transformations
                brightness_range=[0.8, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.2,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                # rotation_range=10,  # degrees
                zoom_range=0.2,  # zoom range for random zoom
                # vertical_flip=True,  # randomly flip images vertically
                horizontal_flip=True,  # randomly flip images horizontally
            )
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )

    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )

    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )

    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        seed = SEED,
        shuffle = False,
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)

    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 3324 images belonging to 4 classes.
# Found 1421 images belonging to 4 classes.
# Found 1187 images belonging to 4 classes.

# %%
def plot_images(images, labels, classes=None):
    fig = plt.figure(figsize=(10, 10))
    for i in range(15):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)

        # If class labels are provided, add them to the subplot
        if classes is not None:
            label = classes[np.argmax(labels[i])]
            plt.xlabel(label)
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_visualization.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()


train_images, train_labels = next(train_generator)  # Fetch a batch of images and labels
plot_images(train_images, train_labels)

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)

    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)


    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR,   # Lower bound on the learning rate.
        cooldown = COOLDOWN_EPOCHS
    )

    my_callbacks = [best_model_callback , reduce_LR , EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)

    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)

    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)

        # Calculate support for each class
        support = TP + FN

        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []

    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)

    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)

    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)

    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator)

    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")

    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)


    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Loss': test_loss
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

    del report_df, test_results

# %% [markdown]
# # MODEL CREATING

# %%
from tensorflow.keras.applications import Xception, DenseNet121
# Function to build the model with an ensemble of feature extractors
def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
                      dropout= 0.1,
                      activation='relu',
                      units= 1024,
                      nr_classes=NUM_CLASSES,
                      loss = "categorical_crossentropy",
                      retrain_backbone_network=False,
                      global_pooling = 'avg',
                      filters=7,
                      name='ensemble2'):


    inputs = Input(shape=input_shape)

    # Feature extraction from Xception
    Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    Xception_features = Xception_base(inputs)
    Xception_features = GlobalAveragePooling2D()(Xception_features)

    # Feature extraction from DenseNet121
    densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
    densenet_features = densenet_base(inputs)
    densenet_features = GlobalAveragePooling2D()(densenet_features)

    # Concatenate features
    concatenated_features = Concatenate()([Xception_features, densenet_features])

    if filters==3:
        filters = (3,3)
    elif filters==5:
        filters = (5,5)
    elif filters==7:
        filters = (7,7)
    elif filters==9:
        filters = (9,9)

    x = Dropout(dropout)(concatenated_features)

    # A fully connected layer with a tunable number of units
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)

    # Add a tunable dropout layer
    x = Dropout(dropout)(x)

    # A fully connected layer with a tunable number of units again
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)


    # Output layer
    predictions = Dense( nr_classes, activation='softmax')(x)

    # Create and compile the model
    model = Model(inputs=inputs, outputs=predictions)
    optimizer = Adam(learning_rate=INITIAL_LR )
    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy', f1_score]
    )

    return model

# %% [markdown]
# # Train and Results

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()
model = get_ensemble2_model()

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/150
# 52/52 [==============================] - ETA: 0s - loss: 0.5672 - accuracy: 0.7897 - f1_score: 0.7884
# Epoch 1: val_f1_score improved from -inf to 0.90551, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 61s 917ms/step - loss: 0.5672 - accuracy: 0.7897 - f1_score: 0.7884 - val_loss: 0.4983 - val_accuracy: 0.9036 - val_f1_score: 0.9055 - lr: 1.0000e-04
# Epoch 2/150
# 52/52 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9242 - f1_score: 0.9259
# Epoch 2: val_f1_score improved from 0.90551 to 0.95001, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 45s 865ms/step - loss: 0.2184 - accuracy: 0.9242 - f1_score: 0.9259 - val_loss: 0.2691 - val_accuracy: 0.9493 - val_f1_score: 0.9500 - lr: 1.0000e-04
# Epoch 3/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9455 - f1_score: 0.9463
# Epoch 3: val_f1_score improved from 0.95001 to 0.96903, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 44s 849ms/step - loss: 0.1578 - accuracy: 0.9455 - f1_score: 0.9463 - val_loss: 0.1514 - val_accuracy: 0.9683 - val_f1_score: 0.9690 - lr: 1.0000e-04
# Epoch 4/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9555 - f1_score: 0.9564
# Epoch 4: val_f1_score improved from 0.96903 to 0.97674, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 43s 823ms/step - loss: 0.1286 - accuracy: 0.9555 - f1_score: 0.9564 - val_loss: 0.1021 - val_accuracy: 0.9761 - val_f1_score: 0.9767 - lr: 1.0000e-04
# Epoch 5/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9675 - f1_score: 0.9683
# Epoch 5: val_f1_score improved from 0.97674 to 0.97800, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 48s 924ms/step - loss: 0.0985 - accuracy: 0.9675 - f1_score: 0.9683 - val_loss: 0.0718 - val_accuracy: 0.9775 - val_f1_score: 0.9780 - lr: 1.0000e-04
# Epoch 6/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9732 - f1_score: 0.9737
# Epoch 6: val_f1_score improved from 0.97800 to 0.98352, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 45s 858ms/step - loss: 0.0806 - accuracy: 0.9732 - f1_score: 0.9737 - val_loss: 0.0552 - val_accuracy: 0.9831 - val_f1_score: 0.9835 - lr: 1.0000e-04
# Epoch 7/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9765 - f1_score: 0.9771
# Epoch 7: val_f1_score improved from 0.98352 to 0.99323, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 45s 869ms/step - loss: 0.0763 - accuracy: 0.9765 - f1_score: 0.9771 - val_loss: 0.0333 - val_accuracy: 0.9930 - val_f1_score: 0.9932 - lr: 1.0000e-04
# Epoch 8/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9744 - f1_score: 0.9749
# Epoch 8: val_f1_score did not improve from 0.99323
# 52/52 [==============================] - 40s 761ms/step - loss: 0.0686 - accuracy: 0.9744 - f1_score: 0.9749 - val_loss: 0.0333 - val_accuracy: 0.9909 - val_f1_score: 0.9912 - lr: 1.0000e-04
# Epoch 9/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9750 - f1_score: 0.9755
# Epoch 9: val_f1_score did not improve from 0.99323
# 52/52 [==============================] - 38s 728ms/step - loss: 0.0666 - accuracy: 0.9750 - f1_score: 0.9755 - val_loss: 0.0393 - val_accuracy: 0.9859 - val_f1_score: 0.9862 - lr: 1.0000e-04
# Epoch 10/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9798 - f1_score: 0.9803
# Epoch 10: val_f1_score improved from 0.99323 to 0.99381, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 48s 922ms/step - loss: 0.0542 - accuracy: 0.9798 - f1_score: 0.9803 - val_loss: 0.0252 - val_accuracy: 0.9937 - val_f1_score: 0.9938 - lr: 1.0000e-04
# Epoch 11/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9847 - f1_score: 0.9849
# Epoch 11: val_f1_score improved from 0.99381 to 0.99446, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 41s 776ms/step - loss: 0.0457 - accuracy: 0.9847 - f1_score: 0.9849 - val_loss: 0.0260 - val_accuracy: 0.9944 - val_f1_score: 0.9945 - lr: 1.0000e-04
# Epoch 12/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9844 - f1_score: 0.9847
# Epoch 12: val_f1_score did not improve from 0.99446
# 52/52 [==============================] - 43s 828ms/step - loss: 0.0448 - accuracy: 0.9844 - f1_score: 0.9847 - val_loss: 0.0197 - val_accuracy: 0.9930 - val_f1_score: 0.9932 - lr: 1.0000e-04
# Epoch 13/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9886 - f1_score: 0.9888
# Epoch 13: val_f1_score improved from 0.99446 to 0.99586, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 45s 874ms/step - loss: 0.0368 - accuracy: 0.9886 - f1_score: 0.9888 - val_loss: 0.0134 - val_accuracy: 0.9958 - val_f1_score: 0.9959 - lr: 1.0000e-04
# Epoch 14/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9856 - f1_score: 0.9858
# Epoch 14: val_f1_score did not improve from 0.99586
# 52/52 [==============================] - 38s 729ms/step - loss: 0.0406 - accuracy: 0.9856 - f1_score: 0.9858 - val_loss: 0.0263 - val_accuracy: 0.9894 - val_f1_score: 0.9898 - lr: 1.0000e-04
# Epoch 15/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9853 - f1_score: 0.9857
# Epoch 15: val_f1_score improved from 0.99586 to 0.99652, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 45s 860ms/step - loss: 0.0420 - accuracy: 0.9853 - f1_score: 0.9857 - val_loss: 0.0138 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 1.0000e-04
# Epoch 16/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9904 - f1_score: 0.9906
# Epoch 16: val_f1_score did not improve from 0.99652
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 52/52 [==============================] - 36s 695ms/step - loss: 0.0336 - accuracy: 0.9904 - f1_score: 0.9906 - val_loss: 0.0154 - val_accuracy: 0.9930 - val_f1_score: 0.9930 - lr: 1.0000e-04
# Epoch 17/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9889 - f1_score: 0.9891
# Epoch 17: val_f1_score did not improve from 0.99652
# 52/52 [==============================] - 39s 748ms/step - loss: 0.0324 - accuracy: 0.9889 - f1_score: 0.9891 - val_loss: 0.0149 - val_accuracy: 0.9937 - val_f1_score: 0.9937 - lr: 5.0000e-05
# Epoch 18/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9862 - f1_score: 0.9863
# Epoch 18: val_f1_score did not improve from 0.99652
# 52/52 [==============================] - 40s 757ms/step - loss: 0.0348 - accuracy: 0.9862 - f1_score: 0.9863 - val_loss: 0.0173 - val_accuracy: 0.9930 - val_f1_score: 0.9930 - lr: 5.0000e-05
# Epoch 19/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9880 - f1_score: 0.9883
# Epoch 19: val_f1_score did not improve from 0.99652
# 52/52 [==============================] - 37s 717ms/step - loss: 0.0331 - accuracy: 0.9880 - f1_score: 0.9883 - val_loss: 0.0144 - val_accuracy: 0.9937 - val_f1_score: 0.9938 - lr: 5.0000e-05
# Epoch 20/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9886 - f1_score: 0.9889
# Epoch 20: val_f1_score did not improve from 0.99652
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 52/52 [==============================] - 39s 746ms/step - loss: 0.0360 - accuracy: 0.9886 - f1_score: 0.9889 - val_loss: 0.0148 - val_accuracy: 0.9930 - val_f1_score: 0.9932 - lr: 5.0000e-05
# Epoch 21/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9901 - f1_score: 0.9903
# Epoch 21: val_f1_score improved from 0.99652 to 0.99788, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 44s 854ms/step - loss: 0.0305 - accuracy: 0.9901 - f1_score: 0.9903 - val_loss: 0.0087 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 2.5000e-05
# Epoch 22/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9901 - f1_score: 0.9902
# Epoch 22: val_f1_score did not improve from 0.99788
# 52/52 [==============================] - 39s 751ms/step - loss: 0.0283 - accuracy: 0.9901 - f1_score: 0.9902 - val_loss: 0.0128 - val_accuracy: 0.9965 - val_f1_score: 0.9966 - lr: 2.5000e-05
# Epoch 23/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9886 - f1_score: 0.9888
# Epoch 23: val_f1_score improved from 0.99788 to 0.99793, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 41s 788ms/step - loss: 0.0301 - accuracy: 0.9886 - f1_score: 0.9888 - val_loss: 0.0113 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 2.5000e-05
# Epoch 24/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9898 - f1_score: 0.9899
# Epoch 24: val_f1_score improved from 0.99793 to 0.99796, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 52/52 [==============================] - 43s 819ms/step - loss: 0.0284 - accuracy: 0.9898 - f1_score: 0.9899 - val_loss: 0.0094 - val_accuracy: 0.9979 - val_f1_score: 0.9980 - lr: 2.5000e-05
# Epoch 25/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9910 - f1_score: 0.9912
# Epoch 25: val_f1_score improved from 0.99796 to 0.99934, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 44s 845ms/step - loss: 0.0256 - accuracy: 0.9910 - f1_score: 0.9912 - val_loss: 0.0054 - val_accuracy: 0.9993 - val_f1_score: 0.9993 - lr: 1.2500e-05
# Epoch 26/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9898 - f1_score: 0.9899
# Epoch 26: val_f1_score did not improve from 0.99934
# 52/52 [==============================] - 40s 761ms/step - loss: 0.0278 - accuracy: 0.9898 - f1_score: 0.9899 - val_loss: 0.0109 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 1.2500e-05
# Epoch 27/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9919 - f1_score: 0.9920
# Epoch 27: val_f1_score did not improve from 0.99934
# 52/52 [==============================] - 39s 752ms/step - loss: 0.0230 - accuracy: 0.9919 - f1_score: 0.9920 - val_loss: 0.0077 - val_accuracy: 0.9993 - val_f1_score: 0.9993 - lr: 1.2500e-05
# Epoch 28/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9934 - f1_score: 0.9935
# Epoch 28: val_f1_score did not improve from 0.99934
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 52/52 [==============================] - 40s 759ms/step - loss: 0.0222 - accuracy: 0.9934 - f1_score: 0.9935 - val_loss: 0.0082 - val_accuracy: 0.9979 - val_f1_score: 0.9980 - lr: 1.2500e-05
# Epoch 29/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9937 - f1_score: 0.9938
# Epoch 29: val_f1_score did not improve from 0.99934
# 52/52 [==============================] - 38s 730ms/step - loss: 0.0180 - accuracy: 0.9937 - f1_score: 0.9938 - val_loss: 0.0110 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 6.2500e-06
# Epoch 30/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9940 - f1_score: 0.9940
# Epoch 30: val_f1_score did not improve from 0.99934
# 52/52 [==============================] - 37s 719ms/step - loss: 0.0176 - accuracy: 0.9940 - f1_score: 0.9940 - val_loss: 0.0128 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 6.2500e-06
# Epoch 31/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9946 - f1_score: 0.9947
# Epoch 31: val_f1_score improved from 0.99934 to 1.00000, saving model to saved_outputs_all_augment\ensemble2\saved_models\best_ensemble2.h5
# 52/52 [==============================] - 41s 794ms/step - loss: 0.0188 - accuracy: 0.9946 - f1_score: 0.9947 - val_loss: 0.0066 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - lr: 6.2500e-06
# Epoch 32/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9943 - f1_score: 0.9944
# Epoch 32: val_f1_score did not improve from 1.00000
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 52/52 [==============================] - 40s 767ms/step - loss: 0.0181 - accuracy: 0.9943 - f1_score: 0.9944 - val_loss: 0.0108 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 6.2500e-06
# Epoch 33/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9889 - f1_score: 0.9890
# Epoch 33: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 39s 752ms/step - loss: 0.0277 - accuracy: 0.9889 - f1_score: 0.9890 - val_loss: 0.0069 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - lr: 3.1250e-06
# Epoch 34/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9940 - f1_score: 0.9941
# Epoch 34: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 40s 765ms/step - loss: 0.0204 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.0087 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 3.1250e-06
# Epoch 35/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9937 - f1_score: 0.9938
# Epoch 35: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 39s 753ms/step - loss: 0.0200 - accuracy: 0.9937 - f1_score: 0.9938 - val_loss: 0.0108 - val_accuracy: 0.9965 - val_f1_score: 0.9966 - lr: 3.1250e-06
# Epoch 36/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9943 - f1_score: 0.9943
# Epoch 36: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 40s 770ms/step - loss: 0.0195 - accuracy: 0.9943 - f1_score: 0.9943 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - lr: 3.1250e-06
# Epoch 37/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9931 - f1_score: 0.9933
# Epoch 37: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 39s 754ms/step - loss: 0.0206 - accuracy: 0.9931 - f1_score: 0.9933 - val_loss: 0.0082 - val_accuracy: 0.9979 - val_f1_score: 0.9980 - lr: 3.1250e-06
# Epoch 38/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9916 - f1_score: 0.9918
# Epoch 38: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 37s 701ms/step - loss: 0.0229 - accuracy: 0.9916 - f1_score: 0.9918 - val_loss: 0.0128 - val_accuracy: 0.9944 - val_f1_score: 0.9946 - lr: 3.1250e-06
# Epoch 39/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9928 - f1_score: 0.9930
# Epoch 39: val_f1_score did not improve from 1.00000
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 52/52 [==============================] - 39s 752ms/step - loss: 0.0223 - accuracy: 0.9928 - f1_score: 0.9930 - val_loss: 0.0111 - val_accuracy: 0.9965 - val_f1_score: 0.9966 - lr: 3.1250e-06
# Epoch 40/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9934 - f1_score: 0.9934
# Epoch 40: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 40s 770ms/step - loss: 0.0222 - accuracy: 0.9934 - f1_score: 0.9934 - val_loss: 0.0116 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 1.5625e-06
# Epoch 41/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9928 - f1_score: 0.9930
# Epoch 41: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 39s 741ms/step - loss: 0.0220 - accuracy: 0.9928 - f1_score: 0.9930 - val_loss: 0.0075 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 1.5625e-06
# Epoch 42/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 42: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 37s 719ms/step - loss: 0.0216 - accuracy: 0.9937 - f1_score: 0.9937 - val_loss: 0.0086 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 1.5625e-06
# Epoch 43/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 43: val_f1_score did not improve from 1.00000
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 52/52 [==============================] - 40s 760ms/step - loss: 0.0223 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.0127 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 1.5625e-06
# Epoch 44/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9916 - f1_score: 0.9918
# Epoch 44: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 40s 772ms/step - loss: 0.0226 - accuracy: 0.9916 - f1_score: 0.9918 - val_loss: 0.0071 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 7.8125e-07
# Epoch 45/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9946 - f1_score: 0.9947
# Epoch 45: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 39s 757ms/step - loss: 0.0181 - accuracy: 0.9946 - f1_score: 0.9947 - val_loss: 0.0065 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 7.8125e-07
# Epoch 46/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9907 - f1_score: 0.9909
# Epoch 46: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 40s 759ms/step - loss: 0.0257 - accuracy: 0.9907 - f1_score: 0.9909 - val_loss: 0.0087 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 7.8125e-07
# Epoch 47/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 47: val_f1_score did not improve from 1.00000
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 52/52 [==============================] - 38s 733ms/step - loss: 0.0242 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.0054 - val_accuracy: 0.9986 - val_f1_score: 0.9987 - lr: 7.8125e-07
# Epoch 48/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9925 - f1_score: 0.9925
# Epoch 48: val_f1_score did not improve from 1.00000
# 52/52 [==============================] - 40s 775ms/step - loss: 0.0228 - accuracy: 0.9925 - f1_score: 0.9925 - val_loss: 0.0079 - val_accuracy: 0.9972 - val_f1_score: 0.9973 - lr: 3.9062e-07

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Now, load the best model
best_model = ks.models.load_model("", custom_objects={'F1Score': F1Score})

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test
############################################################################################################]
# Out:
# 19/19 [==============================] - 12s 501ms/step

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

def bootstrap_auc_ci(true_labels, predicted_probs, num_classes=NUM_CLASSES, n_iterations=100, seed=SEED, save_path=None):
    """
    Computes bootstrapped AUC with 95% confidence interval for multi-class classification.

    Args:
        true_labels (np.array): Ground truth class labels (e.g., [0, 1, 2, ...])
        predicted_probs (np.array): Predicted probabilities, shape = (n_samples, n_classes)
        num_classes (int): Number of classes
        n_iterations (int): Number of bootstrap iterations
        seed (int): Random seed for reproducibility
        save_path (str): Optional path to save AUC scores as CSV

    Returns:
        Prints mean AUC, std, and 95% CI
    """
    np.random.seed(seed)
    auc_scores = []

    # One-hot encode true labels
    true_labels_bin = label_binarize(true_labels, classes=np.arange(num_classes))

    for _ in range(n_iterations):
        indices = np.random.choice(len(true_labels), size=len(true_labels), replace=True)
        y_true_sample = true_labels_bin[indices]
        y_pred_sample = predicted_probs[indices]

        try:
            auc = roc_auc_score(y_true_sample, y_pred_sample, multi_class='ovr', average='macro')
            auc_scores.append(auc)
        except ValueError:
            continue  # Skip if a class is missing in the sample

    auc_scores = np.array(auc_scores)
    mean_auc = np.mean(auc_scores)
    std_auc = np.std(auc_scores)
    ci_lower = np.percentile(auc_scores, 2.5)
    ci_upper = np.percentile(auc_scores, 97.5)

    print(f"\nBootstrapped Macro AUC ({n_iterations} runs):")
    print(f"Mean AUC     : {mean_auc:.5f}")
    print(f"Std Deviation: {std_auc:.5f}")
    print(f"95% CI       : ({ci_lower:.5f}, {ci_upper:.5f})")

    if save_path:
        df = pd.DataFrame({'AUC Score': auc_scores})
        df.to_csv(save_path, index=False)

    return mean_auc, std_auc, (ci_lower, ci_upper)

# Call the function
bootstrap_auc_ci(
    true_labels=true_labels_y_test,
    predicted_probs=predictions,
    save_path=os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_bootstrapped_auc.csv")
)
