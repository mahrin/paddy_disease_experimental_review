# %% [markdown]
# ## Imports

# %%
# !pip install tensorflow-addons

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %% [markdown]
# ## Setting the paths

# %%
model_name = 'parallel_vit_ap01'#'Xception'#'DenseNet121'#    'InceptionV3'##  'MobileNet', 'Xception', ensemble2, ensemble3, 'parallel_vit'

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')

PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')


if not os.path.exists(PATH_TO_SAVE_RESULT):
    # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################

IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10


################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'all' #'all'## basic, advanced,
################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.


PATIENCE_EARLY_STOP = 12 # With no improvement in Loss, will stop training

# # Checkpoint parameters
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
PATIENCE_LR_REDUCE=5      # Number of epochs with no improvement after which learning rate will be reduced
# COOLDOWN_EPOCHS  = 2              # How many epochs to wait after learning rate reduction before it can be reduced again
MIN_LR = 1e-9
INITIAL_LR = 0.0001 # with 0.001 got 99 percent

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_SAVE_TIME ", PATH_SAVE_TIME )
print("PATH_SAVE_HISTORY", PATH_SAVE_HISTORY)
print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_SAVE_TIME  saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_training_time.csv
# PATH_SAVE_HISTORY saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_training_history.csv
# PATH_TO_SAVE_RESULT saved_outputs_all_augment\parallel_vit_ap01
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment\parallel_vit_ap01\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_15088\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Visualization

# %%
def plot_images(images, labels, classes=None):
    plt.figure(figsize=(8, 8))
    for i in range(15):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)

        # If class labels are provided, add them to the subplot
        if classes is not None:
            label = classes[np.argmax(labels[i])]
            plt.xlabel(label)
    plt.show()


train_images, train_labels = next(train_generator)  # Fetch a batch of images and labels


plot_images(train_images, train_labels)

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    ##########################################################################################################

    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)
    ##########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR,   # Lower bound on the learning rate.
        # cooldown = COOLDOWN_EPOCHS
    )

    my_callbacks = [best_weight_callback , reduce_LR , EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return  PATH_BEST_WEIGHT_SAVE, train_history , total_time#model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)

    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)

    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)

        # Calculate support for each class
        support = TP + FN

        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []

    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)

    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)

    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)

    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator)

    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")

    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)


    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Loss': test_loss
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

    del report_df, test_results

# %% [markdown]
# # MODEL CREATING

# %%
from parallel_vit import ViT as parallelViT
from tensorflow.keras.losses import CategoricalCrossentropy

def get_parallel_vit(): 
    model = parallelViT( #v4 --Improving gradually with each epoch val_loss: 2.2053 - val_accuracy: 0.2600 - val_f1_score: 0.1379
        image_size = max(MODEL_INPUT_SIZE[0], MODEL_INPUT_SIZE[1]),
        patch_size = 16, # original 16
        num_classes = NUM_CLASSES,
        dim = 512,#original 512
        depth = 6,
        heads = 20, # original 8
        mlp_dim = 1024,#original 1024
        num_parallel_branches = 2,  # in paper, they claimed 2 was optimal
        dropout = 0.2,
        emb_dropout = 0.2
    )

    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss=CategoricalCrossentropy(from_logits=True), 
                  run_eagerly=True,
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)

    return model

# %% [markdown]
# # Train and Results

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()
# model = get_ensemble2_model()
# model = get_original_vit()
model = get_parallel_vit()

# %%
# training the model and saving the best model as a check point
PATH_BEST_WEIGHT_SAVE, train_history , total_time = fit_and_save_best_model_vit(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 2.6417 - accuracy: 0.1332 - f1_score: 0.0710
# Epoch 1: val_f1_score improved from -inf to 0.04158, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 323s 3s/step - loss: 2.6417 - accuracy: 0.1332 - f1_score: 0.0710 - val_loss: 2.4164 - val_accuracy: 0.1401 - val_f1_score: 0.0416 - lr: 1.0000e-04
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 2.4219 - accuracy: 0.1497 - f1_score: 0.0841
# Epoch 2: val_f1_score improved from 0.04158 to 0.06215, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 310s 3s/step - loss: 2.4219 - accuracy: 0.1497 - f1_score: 0.0841 - val_loss: 2.3916 - val_accuracy: 0.1636 - val_f1_score: 0.0622 - lr: 1.0000e-04
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 2.4093 - accuracy: 0.1552 - f1_score: 0.0860
# Epoch 3: val_f1_score improved from 0.06215 to 0.07766, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 318s 3s/step - loss: 2.4093 - accuracy: 0.1552 - f1_score: 0.0860 - val_loss: 2.3500 - val_accuracy: 0.1768 - val_f1_score: 0.0777 - lr: 1.0000e-04
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 2.3734 - accuracy: 0.1805 - f1_score: 0.1034
# Epoch 4: val_f1_score improved from 0.07766 to 0.11480, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 321s 3s/step - loss: 2.3734 - accuracy: 0.1805 - f1_score: 0.1034 - val_loss: 2.2671 - val_accuracy: 0.2250 - val_f1_score: 0.1148 - lr: 1.0000e-04
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 2.2909 - accuracy: 0.2144 - f1_score: 0.1211
# Epoch 5: val_f1_score did not improve from 0.11480
# 104/104 [==============================] - 322s 3s/step - loss: 2.2909 - accuracy: 0.2144 - f1_score: 0.1211 - val_loss: 2.2785 - val_accuracy: 0.2312 - val_f1_score: 0.1104 - lr: 1.0000e-04
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 2.2315 - accuracy: 0.2480 - f1_score: 0.1480
# Epoch 6: val_f1_score improved from 0.11480 to 0.14812, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 327s 3s/step - loss: 2.2315 - accuracy: 0.2480 - f1_score: 0.1480 - val_loss: 2.1913 - val_accuracy: 0.2709 - val_f1_score: 0.1481 - lr: 1.0000e-04
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 2.1723 - accuracy: 0.2745 - f1_score: 0.1698
# Epoch 7: val_f1_score improved from 0.14812 to 0.16809, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 340s 3s/step - loss: 2.1723 - accuracy: 0.2745 - f1_score: 0.1698 - val_loss: 2.1451 - val_accuracy: 0.2945 - val_f1_score: 0.1681 - lr: 1.0000e-04
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 2.1272 - accuracy: 0.2874 - f1_score: 0.1825
# Epoch 8: val_f1_score improved from 0.16809 to 0.17667, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 342s 3s/step - loss: 2.1272 - accuracy: 0.2874 - f1_score: 0.1825 - val_loss: 2.0956 - val_accuracy: 0.2922 - val_f1_score: 0.1767 - lr: 1.0000e-04
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 2.0912 - accuracy: 0.3027 - f1_score: 0.1990
# Epoch 9: val_f1_score improved from 0.17667 to 0.19733, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 398s 4s/step - loss: 2.0912 - accuracy: 0.3027 - f1_score: 0.1990 - val_loss: 2.0559 - val_accuracy: 0.2995 - val_f1_score: 0.1973 - lr: 1.0000e-04
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 2.0444 - accuracy: 0.3127 - f1_score: 0.2211
# Epoch 10: val_f1_score improved from 0.19733 to 0.24116, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 481s 5s/step - loss: 2.0444 - accuracy: 0.3127 - f1_score: 0.2211 - val_loss: 1.9908 - val_accuracy: 0.3458 - val_f1_score: 0.2412 - lr: 1.0000e-04
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 1.9981 - accuracy: 0.3314 - f1_score: 0.2381
# Epoch 11: val_f1_score improved from 0.24116 to 0.27739, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 509s 5s/step - loss: 1.9981 - accuracy: 0.3314 - f1_score: 0.2381 - val_loss: 1.9463 - val_accuracy: 0.3582 - val_f1_score: 0.2774 - lr: 1.0000e-04
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 1.9622 - accuracy: 0.3365 - f1_score: 0.2525
# Epoch 12: val_f1_score improved from 0.27739 to 0.28824, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 518s 5s/step - loss: 1.9622 - accuracy: 0.3365 - f1_score: 0.2525 - val_loss: 1.8906 - val_accuracy: 0.3663 - val_f1_score: 0.2882 - lr: 1.0000e-04
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 1.9215 - accuracy: 0.3538 - f1_score: 0.2726
# Epoch 13: val_f1_score improved from 0.28824 to 0.30378, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 542s 5s/step - loss: 1.9215 - accuracy: 0.3538 - f1_score: 0.2726 - val_loss: 1.8491 - val_accuracy: 0.3883 - val_f1_score: 0.3038 - lr: 1.0000e-04
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 1.8781 - accuracy: 0.3696 - f1_score: 0.2977
# Epoch 14: val_f1_score did not improve from 0.30378
# 104/104 [==============================] - 536s 5s/step - loss: 1.8781 - accuracy: 0.3696 - f1_score: 0.2977 - val_loss: 1.9177 - val_accuracy: 0.3709 - val_f1_score: 0.2953 - lr: 1.0000e-04
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 1.8510 - accuracy: 0.3813 - f1_score: 0.3151
# Epoch 15: val_f1_score improved from 0.30378 to 0.31841, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 581s 6s/step - loss: 1.8510 - accuracy: 0.3813 - f1_score: 0.3151 - val_loss: 1.7948 - val_accuracy: 0.4068 - val_f1_score: 0.3184 - lr: 1.0000e-04
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 1.8054 - accuracy: 0.3925 - f1_score: 0.3300
# Epoch 16: val_f1_score improved from 0.31841 to 0.37271, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 619s 6s/step - loss: 1.8054 - accuracy: 0.3925 - f1_score: 0.3300 - val_loss: 1.7231 - val_accuracy: 0.4276 - val_f1_score: 0.3727 - lr: 1.0000e-04
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7581 - accuracy: 0.4088 - f1_score: 0.3546
# Epoch 17: val_f1_score did not improve from 0.37271
# 104/104 [==============================] - 666s 6s/step - loss: 1.7581 - accuracy: 0.4088 - f1_score: 0.3546 - val_loss: 1.7436 - val_accuracy: 0.4211 - val_f1_score: 0.3668 - lr: 1.0000e-04
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7103 - accuracy: 0.4281 - f1_score: 0.3717
# Epoch 18: val_f1_score improved from 0.37271 to 0.39523, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 683s 7s/step - loss: 1.7103 - accuracy: 0.4281 - f1_score: 0.3717 - val_loss: 1.6588 - val_accuracy: 0.4473 - val_f1_score: 0.3952 - lr: 1.0000e-04
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 1.6734 - accuracy: 0.4351 - f1_score: 0.3861
# Epoch 19: val_f1_score did not improve from 0.39523
# 104/104 [==============================] - 735s 7s/step - loss: 1.6734 - accuracy: 0.4351 - f1_score: 0.3861 - val_loss: 1.6408 - val_accuracy: 0.4523 - val_f1_score: 0.3851 - lr: 1.0000e-04
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 1.6321 - accuracy: 0.4477 - f1_score: 0.4138
# Epoch 20: val_f1_score improved from 0.39523 to 0.45504, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 823s 8s/step - loss: 1.6321 - accuracy: 0.4477 - f1_score: 0.4138 - val_loss: 1.5955 - val_accuracy: 0.4766 - val_f1_score: 0.4550 - lr: 1.0000e-04
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 1.6123 - accuracy: 0.4542 - f1_score: 0.4086
# Epoch 21: val_f1_score did not improve from 0.45504
# 104/104 [==============================] - 851s 8s/step - loss: 1.6123 - accuracy: 0.4542 - f1_score: 0.4086 - val_loss: 1.5797 - val_accuracy: 0.4759 - val_f1_score: 0.4332 - lr: 1.0000e-04
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5484 - accuracy: 0.4769 - f1_score: 0.4393
# Epoch 22: val_f1_score improved from 0.45504 to 0.45700, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 947s 9s/step - loss: 1.5484 - accuracy: 0.4769 - f1_score: 0.4393 - val_loss: 1.4983 - val_accuracy: 0.4990 - val_f1_score: 0.4570 - lr: 1.0000e-04
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5120 - accuracy: 0.5009 - f1_score: 0.4640
# Epoch 23: val_f1_score improved from 0.45700 to 0.49714, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1006s 10s/step - loss: 1.5120 - accuracy: 0.5009 - f1_score: 0.4640 - val_loss: 1.4607 - val_accuracy: 0.5203 - val_f1_score: 0.4971 - lr: 1.0000e-04
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4930 - accuracy: 0.5006 - f1_score: 0.4710
# Epoch 24: val_f1_score improved from 0.49714 to 0.50093, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1095s 11s/step - loss: 1.4930 - accuracy: 0.5006 - f1_score: 0.4710 - val_loss: 1.4016 - val_accuracy: 0.5376 - val_f1_score: 0.5009 - lr: 1.0000e-04
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4318 - accuracy: 0.5219 - f1_score: 0.4937
# Epoch 25: val_f1_score improved from 0.50093 to 0.53077, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1177s 11s/step - loss: 1.4318 - accuracy: 0.5219 - f1_score: 0.4937 - val_loss: 1.3600 - val_accuracy: 0.5542 - val_f1_score: 0.5308 - lr: 1.0000e-04
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4035 - accuracy: 0.5296 - f1_score: 0.5043
# Epoch 26: val_f1_score did not improve from 0.53077
# 104/104 [==============================] - 1249s 12s/step - loss: 1.4035 - accuracy: 0.5296 - f1_score: 0.5043 - val_loss: 1.4252 - val_accuracy: 0.5330 - val_f1_score: 0.5181 - lr: 1.0000e-04
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3586 - accuracy: 0.5423 - f1_score: 0.5177
# Epoch 27: val_f1_score did not improve from 0.53077
# 104/104 [==============================] - 1308s 13s/step - loss: 1.3586 - accuracy: 0.5423 - f1_score: 0.5177 - val_loss: 1.3431 - val_accuracy: 0.5554 - val_f1_score: 0.5271 - lr: 1.0000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3362 - accuracy: 0.5476 - f1_score: 0.5264
# Epoch 28: val_f1_score improved from 0.53077 to 0.55004, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1374s 13s/step - loss: 1.3362 - accuracy: 0.5476 - f1_score: 0.5264 - val_loss: 1.2644 - val_accuracy: 0.5789 - val_f1_score: 0.5500 - lr: 1.0000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3095 - accuracy: 0.5609 - f1_score: 0.5379
# Epoch 29: val_f1_score improved from 0.55004 to 0.55400, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1444s 14s/step - loss: 1.3095 - accuracy: 0.5609 - f1_score: 0.5379 - val_loss: 1.2815 - val_accuracy: 0.5793 - val_f1_score: 0.5540 - lr: 1.0000e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2900 - accuracy: 0.5666 - f1_score: 0.5459
# Epoch 30: val_f1_score improved from 0.55400 to 0.59795, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1480s 14s/step - loss: 1.2900 - accuracy: 0.5666 - f1_score: 0.5459 - val_loss: 1.1735 - val_accuracy: 0.6133 - val_f1_score: 0.5980 - lr: 1.0000e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2410 - accuracy: 0.5857 - f1_score: 0.5706
# Epoch 31: val_f1_score did not improve from 0.59795
# 104/104 [==============================] - 1646s 16s/step - loss: 1.2410 - accuracy: 0.5857 - f1_score: 0.5706 - val_loss: 1.2176 - val_accuracy: 0.5986 - val_f1_score: 0.5754 - lr: 1.0000e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2054 - accuracy: 0.6001 - f1_score: 0.5828
# Epoch 32: val_f1_score did not improve from 0.59795
# 104/104 [==============================] - 1691s 16s/step - loss: 1.2054 - accuracy: 0.6001 - f1_score: 0.5828 - val_loss: 1.2057 - val_accuracy: 0.6094 - val_f1_score: 0.5824 - lr: 1.0000e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1743 - accuracy: 0.6052 - f1_score: 0.5871
# Epoch 33: val_f1_score did not improve from 0.59795
# 104/104 [==============================] - 1700s 16s/step - loss: 1.1743 - accuracy: 0.6052 - f1_score: 0.5871 - val_loss: 1.1898 - val_accuracy: 0.6113 - val_f1_score: 0.5921 - lr: 1.0000e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1423 - accuracy: 0.6177 - f1_score: 0.6019
# Epoch 34: val_f1_score did not improve from 0.59795
# 104/104 [==============================] - 1764s 17s/step - loss: 1.1423 - accuracy: 0.6177 - f1_score: 0.6019 - val_loss: 1.1781 - val_accuracy: 0.6117 - val_f1_score: 0.5915 - lr: 1.0000e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1068 - accuracy: 0.6300 - f1_score: 0.6179
# Epoch 35: val_f1_score improved from 0.59795 to 0.62354, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1088s 10s/step - loss: 1.1068 - accuracy: 0.6300 - f1_score: 0.6179 - val_loss: 1.1259 - val_accuracy: 0.6391 - val_f1_score: 0.6235 - lr: 1.0000e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1121 - accuracy: 0.6278 - f1_score: 0.6177
# Epoch 36: val_f1_score improved from 0.62354 to 0.64057, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1504s 14s/step - loss: 1.1121 - accuracy: 0.6278 - f1_score: 0.6177 - val_loss: 1.0749 - val_accuracy: 0.6476 - val_f1_score: 0.6406 - lr: 1.0000e-04
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0631 - accuracy: 0.6504 - f1_score: 0.6436
# Epoch 37: val_f1_score improved from 0.64057 to 0.64755, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 1948s 19s/step - loss: 1.0631 - accuracy: 0.6504 - f1_score: 0.6436 - val_loss: 1.0397 - val_accuracy: 0.6700 - val_f1_score: 0.6476 - lr: 1.0000e-04
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0513 - accuracy: 0.6465 - f1_score: 0.6342
# Epoch 38: val_f1_score improved from 0.64755 to 0.64776, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2076s 20s/step - loss: 1.0513 - accuracy: 0.6465 - f1_score: 0.6342 - val_loss: 1.0336 - val_accuracy: 0.6523 - val_f1_score: 0.6478 - lr: 1.0000e-04
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0032 - accuracy: 0.6639 - f1_score: 0.6565
# Epoch 39: val_f1_score improved from 0.64776 to 0.65502, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2123s 20s/step - loss: 1.0032 - accuracy: 0.6639 - f1_score: 0.6565 - val_loss: 1.0088 - val_accuracy: 0.6708 - val_f1_score: 0.6550 - lr: 1.0000e-04
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0015 - accuracy: 0.6677 - f1_score: 0.6567
# Epoch 40: val_f1_score did not improve from 0.65502
# 104/104 [==============================] - 2189s 21s/step - loss: 1.0015 - accuracy: 0.6677 - f1_score: 0.6567 - val_loss: 1.0332 - val_accuracy: 0.6646 - val_f1_score: 0.6500 - lr: 1.0000e-04
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9706 - accuracy: 0.6719 - f1_score: 0.6629
# Epoch 41: val_f1_score improved from 0.65502 to 0.68148, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2173s 21s/step - loss: 0.9706 - accuracy: 0.6719 - f1_score: 0.6629 - val_loss: 0.9449 - val_accuracy: 0.6870 - val_f1_score: 0.6815 - lr: 1.0000e-04
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9531 - accuracy: 0.6763 - f1_score: 0.6690
# Epoch 42: val_f1_score did not improve from 0.68148
# 104/104 [==============================] - 2354s 23s/step - loss: 0.9531 - accuracy: 0.6763 - f1_score: 0.6690 - val_loss: 0.9518 - val_accuracy: 0.6889 - val_f1_score: 0.6702 - lr: 1.0000e-04
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9302 - accuracy: 0.6896 - f1_score: 0.6819
# Epoch 43: val_f1_score did not improve from 0.68148
# 104/104 [==============================] - 2266s 22s/step - loss: 0.9302 - accuracy: 0.6896 - f1_score: 0.6819 - val_loss: 0.9471 - val_accuracy: 0.6932 - val_f1_score: 0.6802 - lr: 1.0000e-04
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9143 - accuracy: 0.6937 - f1_score: 0.6839
# Epoch 44: val_f1_score improved from 0.68148 to 0.69511, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2478s 24s/step - loss: 0.9143 - accuracy: 0.6937 - f1_score: 0.6839 - val_loss: 0.9167 - val_accuracy: 0.7059 - val_f1_score: 0.6951 - lr: 1.0000e-04
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9009 - accuracy: 0.6998 - f1_score: 0.6926
# Epoch 45: val_f1_score improved from 0.69511 to 0.69873, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2408s 23s/step - loss: 0.9009 - accuracy: 0.6998 - f1_score: 0.6926 - val_loss: 0.9211 - val_accuracy: 0.7067 - val_f1_score: 0.6987 - lr: 1.0000e-04
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8751 - accuracy: 0.7086 - f1_score: 0.7034
# Epoch 46: val_f1_score improved from 0.69873 to 0.70437, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2529s 24s/step - loss: 0.8751 - accuracy: 0.7086 - f1_score: 0.7034 - val_loss: 0.8677 - val_accuracy: 0.7229 - val_f1_score: 0.7044 - lr: 1.0000e-04
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8549 - accuracy: 0.7112 - f1_score: 0.7038
# Epoch 47: val_f1_score did not improve from 0.70437
# 104/104 [==============================] - 2622s 25s/step - loss: 0.8549 - accuracy: 0.7112 - f1_score: 0.7038 - val_loss: 0.9413 - val_accuracy: 0.6939 - val_f1_score: 0.6863 - lr: 1.0000e-04
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8463 - accuracy: 0.7173 - f1_score: 0.7126
# Epoch 48: val_f1_score improved from 0.70437 to 0.71277, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2741s 26s/step - loss: 0.8463 - accuracy: 0.7173 - f1_score: 0.7126 - val_loss: 0.8469 - val_accuracy: 0.7267 - val_f1_score: 0.7128 - lr: 1.0000e-04
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8251 - accuracy: 0.7231 - f1_score: 0.7177
# Epoch 49: val_f1_score improved from 0.71277 to 0.72179, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2694s 26s/step - loss: 0.8251 - accuracy: 0.7231 - f1_score: 0.7177 - val_loss: 0.8446 - val_accuracy: 0.7341 - val_f1_score: 0.7218 - lr: 1.0000e-04
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8056 - accuracy: 0.7264 - f1_score: 0.7214
# Epoch 50: val_f1_score improved from 0.72179 to 0.72665, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2815s 27s/step - loss: 0.8056 - accuracy: 0.7264 - f1_score: 0.7214 - val_loss: 0.8381 - val_accuracy: 0.7310 - val_f1_score: 0.7266 - lr: 1.0000e-04
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7759 - accuracy: 0.7439 - f1_score: 0.7409
# Epoch 51: val_f1_score did not improve from 0.72665
# 104/104 [==============================] - 2891s 28s/step - loss: 0.7759 - accuracy: 0.7439 - f1_score: 0.7409 - val_loss: 0.8090 - val_accuracy: 0.7376 - val_f1_score: 0.7214 - lr: 1.0000e-04
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.7444 - f1_score: 0.7377
# Epoch 52: val_f1_score improved from 0.72665 to 0.74651, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2781s 27s/step - loss: 0.7637 - accuracy: 0.7444 - f1_score: 0.7377 - val_loss: 0.8119 - val_accuracy: 0.7534 - val_f1_score: 0.7465 - lr: 1.0000e-04
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.7509 - f1_score: 0.7471
# Epoch 53: val_f1_score did not improve from 0.74651
# 104/104 [==============================] - 2830s 27s/step - loss: 0.7444 - accuracy: 0.7509 - f1_score: 0.7471 - val_loss: 0.7730 - val_accuracy: 0.7476 - val_f1_score: 0.7439 - lr: 1.0000e-04
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7362 - accuracy: 0.7539 - f1_score: 0.7522
# Epoch 54: val_f1_score improved from 0.74651 to 0.75168, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 2908s 28s/step - loss: 0.7362 - accuracy: 0.7539 - f1_score: 0.7522 - val_loss: 0.7514 - val_accuracy: 0.7545 - val_f1_score: 0.7517 - lr: 1.0000e-04
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7281 - accuracy: 0.7597 - f1_score: 0.7576
# Epoch 55: val_f1_score did not improve from 0.75168
# 104/104 [==============================] - 2917s 28s/step - loss: 0.7281 - accuracy: 0.7597 - f1_score: 0.7576 - val_loss: 0.8018 - val_accuracy: 0.7584 - val_f1_score: 0.7509 - lr: 1.0000e-04
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.7588 - f1_score: 0.7541
# Epoch 56: val_f1_score improved from 0.75168 to 0.75544, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 3228s 31s/step - loss: 0.7169 - accuracy: 0.7588 - f1_score: 0.7541 - val_loss: 0.7749 - val_accuracy: 0.7638 - val_f1_score: 0.7554 - lr: 1.0000e-04
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.7718 - f1_score: 0.7706
# Epoch 57: val_f1_score improved from 0.75544 to 0.76927, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 3277s 31s/step - loss: 0.6780 - accuracy: 0.7718 - f1_score: 0.7706 - val_loss: 0.7383 - val_accuracy: 0.7700 - val_f1_score: 0.7693 - lr: 1.0000e-04
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.7695 - f1_score: 0.7673
# Epoch 58: val_f1_score did not improve from 0.76927
# 104/104 [==============================] - 3152s 30s/step - loss: 0.6856 - accuracy: 0.7695 - f1_score: 0.7673 - val_loss: 0.7616 - val_accuracy: 0.7576 - val_f1_score: 0.7517 - lr: 1.0000e-04
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.7743 - f1_score: 0.7719
# Epoch 59: val_f1_score did not improve from 0.76927
# 104/104 [==============================] - 3329s 32s/step - loss: 0.6682 - accuracy: 0.7743 - f1_score: 0.7719 - val_loss: 0.7788 - val_accuracy: 0.7572 - val_f1_score: 0.7508 - lr: 1.0000e-04
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6653 - accuracy: 0.7754 - f1_score: 0.7735
# Epoch 60: val_f1_score did not improve from 0.76927
# 104/104 [==============================] - 3398s 33s/step - loss: 0.6653 - accuracy: 0.7754 - f1_score: 0.7735 - val_loss: 0.7563 - val_accuracy: 0.7626 - val_f1_score: 0.7503 - lr: 1.0000e-04
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.7790 - f1_score: 0.7759
# Epoch 61: val_f1_score improved from 0.76927 to 0.78721, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 3500s 34s/step - loss: 0.6553 - accuracy: 0.7790 - f1_score: 0.7759 - val_loss: 0.6837 - val_accuracy: 0.7839 - val_f1_score: 0.7872 - lr: 1.0000e-04
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6333 - accuracy: 0.7834 - f1_score: 0.7815
# Epoch 62: val_f1_score did not improve from 0.78721
# 104/104 [==============================] - 3242s 31s/step - loss: 0.6333 - accuracy: 0.7834 - f1_score: 0.7815 - val_loss: 0.7207 - val_accuracy: 0.7657 - val_f1_score: 0.7608 - lr: 1.0000e-04
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6305 - accuracy: 0.7896 - f1_score: 0.7876
# Epoch 63: val_f1_score improved from 0.78721 to 0.80027, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 3460s 33s/step - loss: 0.6305 - accuracy: 0.7896 - f1_score: 0.7876 - val_loss: 0.6473 - val_accuracy: 0.7978 - val_f1_score: 0.8003 - lr: 1.0000e-04
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.7947 - f1_score: 0.7913
# Epoch 64: val_f1_score did not improve from 0.80027
# 104/104 [==============================] - 3695s 35s/step - loss: 0.6146 - accuracy: 0.7947 - f1_score: 0.7913 - val_loss: 0.7162 - val_accuracy: 0.7777 - val_f1_score: 0.7785 - lr: 1.0000e-04
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6096 - accuracy: 0.7980 - f1_score: 0.7986
# Epoch 65: val_f1_score did not improve from 0.80027
# 104/104 [==============================] - 3716s 36s/step - loss: 0.6096 - accuracy: 0.7980 - f1_score: 0.7986 - val_loss: 0.6527 - val_accuracy: 0.7966 - val_f1_score: 0.7929 - lr: 1.0000e-04
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5743 - accuracy: 0.8066 - f1_score: 0.8032
# Epoch 66: val_f1_score did not improve from 0.80027
# 104/104 [==============================] - 3844s 37s/step - loss: 0.5743 - accuracy: 0.8066 - f1_score: 0.8032 - val_loss: 0.6381 - val_accuracy: 0.7916 - val_f1_score: 0.7880 - lr: 1.0000e-04
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5919 - accuracy: 0.8035 - f1_score: 0.8027
# Epoch 67: val_f1_score did not improve from 0.80027
# 104/104 [==============================] - 3183s 31s/step - loss: 0.5919 - accuracy: 0.8035 - f1_score: 0.8027 - val_loss: 0.6355 - val_accuracy: 0.7920 - val_f1_score: 0.7925 - lr: 1.0000e-04
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5714 - accuracy: 0.8094 - f1_score: 0.8063
# Epoch 68: val_f1_score did not improve from 0.80027
# 104/104 [==============================] - 3132s 30s/step - loss: 0.5714 - accuracy: 0.8094 - f1_score: 0.8063 - val_loss: 0.6316 - val_accuracy: 0.7954 - val_f1_score: 0.7889 - lr: 1.0000e-04
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.8043 - f1_score: 0.8037
# Epoch 69: val_f1_score improved from 0.80027 to 0.80646, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 3582s 34s/step - loss: 0.5708 - accuracy: 0.8043 - f1_score: 0.8037 - val_loss: 0.6315 - val_accuracy: 0.8082 - val_f1_score: 0.8065 - lr: 1.0000e-04
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5277 - accuracy: 0.8195 - f1_score: 0.8191
# Epoch 70: val_f1_score did not improve from 0.80646
# 104/104 [==============================] - 3769s 36s/step - loss: 0.5277 - accuracy: 0.8195 - f1_score: 0.8191 - val_loss: 0.6665 - val_accuracy: 0.7897 - val_f1_score: 0.7820 - lr: 1.0000e-04
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.8181 - f1_score: 0.8136
# Epoch 71: val_f1_score improved from 0.80646 to 0.80887, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 3927s 38s/step - loss: 0.5415 - accuracy: 0.8181 - f1_score: 0.8136 - val_loss: 0.5963 - val_accuracy: 0.8070 - val_f1_score: 0.8089 - lr: 1.0000e-04
# Epoch 72/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.8163 - f1_score: 0.8147
# Epoch 72: val_f1_score did not improve from 0.80887
# 104/104 [==============================] - 3690s 35s/step - loss: 0.5346 - accuracy: 0.8163 - f1_score: 0.8147 - val_loss: 0.6423 - val_accuracy: 0.8059 - val_f1_score: 0.7992 - lr: 1.0000e-04
# Epoch 73/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5209 - accuracy: 0.8226 - f1_score: 0.8243
# Epoch 73: val_f1_score did not improve from 0.80887
# 104/104 [==============================] - 4067s 39s/step - loss: 0.5209 - accuracy: 0.8226 - f1_score: 0.8243 - val_loss: 0.6236 - val_accuracy: 0.8066 - val_f1_score: 0.8049 - lr: 1.0000e-04
# Epoch 74/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.8249 - f1_score: 0.8273
# Epoch 74: val_f1_score improved from 0.80887 to 0.81712, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4093s 39s/step - loss: 0.5186 - accuracy: 0.8249 - f1_score: 0.8273 - val_loss: 0.6179 - val_accuracy: 0.8132 - val_f1_score: 0.8171 - lr: 1.0000e-04
# Epoch 75/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4855 - accuracy: 0.8356 - f1_score: 0.8365
# Epoch 75: val_f1_score did not improve from 0.81712
# 104/104 [==============================] - 4077s 39s/step - loss: 0.4855 - accuracy: 0.8356 - f1_score: 0.8365 - val_loss: 0.5994 - val_accuracy: 0.8198 - val_f1_score: 0.8144 - lr: 1.0000e-04
# Epoch 76/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8392 - f1_score: 0.8384
# Epoch 76: val_f1_score did not improve from 0.81712
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 104/104 [==============================] - 4142s 40s/step - loss: 0.4803 - accuracy: 0.8392 - f1_score: 0.8384 - val_loss: 0.5984 - val_accuracy: 0.8190 - val_f1_score: 0.8167 - lr: 1.0000e-04
# Epoch 77/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.8573 - f1_score: 0.8558
# Epoch 77: val_f1_score improved from 0.81712 to 0.82237, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4278s 41s/step - loss: 0.4123 - accuracy: 0.8573 - f1_score: 0.8558 - val_loss: 0.5463 - val_accuracy: 0.8271 - val_f1_score: 0.8224 - lr: 5.0000e-05
# Epoch 78/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4026 - accuracy: 0.8690 - f1_score: 0.8691
# Epoch 78: val_f1_score improved from 0.82237 to 0.84616, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4112s 40s/step - loss: 0.4026 - accuracy: 0.8690 - f1_score: 0.8691 - val_loss: 0.5165 - val_accuracy: 0.8452 - val_f1_score: 0.8462 - lr: 5.0000e-05
# Epoch 79/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.8636 - f1_score: 0.8630
# Epoch 79: val_f1_score improved from 0.84616 to 0.84974, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4497s 43s/step - loss: 0.4061 - accuracy: 0.8636 - f1_score: 0.8630 - val_loss: 0.4953 - val_accuracy: 0.8499 - val_f1_score: 0.8497 - lr: 5.0000e-05
# Epoch 80/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3920 - accuracy: 0.8702 - f1_score: 0.8691
# Epoch 80: val_f1_score did not improve from 0.84974
# 104/104 [==============================] - 4512s 43s/step - loss: 0.3920 - accuracy: 0.8702 - f1_score: 0.8691 - val_loss: 0.4999 - val_accuracy: 0.8452 - val_f1_score: 0.8494 - lr: 5.0000e-05
# Epoch 81/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8747 - f1_score: 0.8746
# Epoch 81: val_f1_score improved from 0.84974 to 0.86070, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4017s 39s/step - loss: 0.3759 - accuracy: 0.8747 - f1_score: 0.8746 - val_loss: 0.4577 - val_accuracy: 0.8603 - val_f1_score: 0.8607 - lr: 5.0000e-05
# Epoch 82/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3820 - accuracy: 0.8693 - f1_score: 0.8691
# Epoch 82: val_f1_score did not improve from 0.86070
# 104/104 [==============================] - 3887s 37s/step - loss: 0.3820 - accuracy: 0.8693 - f1_score: 0.8691 - val_loss: 0.5239 - val_accuracy: 0.8406 - val_f1_score: 0.8389 - lr: 5.0000e-05
# Epoch 83/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8759 - f1_score: 0.8768
# Epoch 83: val_f1_score improved from 0.86070 to 0.86284, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4808s 46s/step - loss: 0.3657 - accuracy: 0.8759 - f1_score: 0.8768 - val_loss: 0.4665 - val_accuracy: 0.8630 - val_f1_score: 0.8628 - lr: 5.0000e-05
# Epoch 84/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3635 - accuracy: 0.8761 - f1_score: 0.8746
# Epoch 84: val_f1_score did not improve from 0.86284
# 104/104 [==============================] - 4624s 44s/step - loss: 0.3635 - accuracy: 0.8761 - f1_score: 0.8746 - val_loss: 0.4733 - val_accuracy: 0.8557 - val_f1_score: 0.8573 - lr: 5.0000e-05
# Epoch 85/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3505 - accuracy: 0.8811 - f1_score: 0.8816
# Epoch 85: val_f1_score did not improve from 0.86284
# 104/104 [==============================] - 4979s 48s/step - loss: 0.3505 - accuracy: 0.8811 - f1_score: 0.8816 - val_loss: 0.5198 - val_accuracy: 0.8506 - val_f1_score: 0.8536 - lr: 5.0000e-05
# Epoch 86/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.8790 - f1_score: 0.8808
# Epoch 86: val_f1_score did not improve from 0.86284
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 104/104 [==============================] - 5034s 48s/step - loss: 0.3541 - accuracy: 0.8790 - f1_score: 0.8808 - val_loss: 0.4913 - val_accuracy: 0.8560 - val_f1_score: 0.8548 - lr: 5.0000e-05
# Epoch 87/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3202 - accuracy: 0.8933 - f1_score: 0.8912
# Epoch 87: val_f1_score did not improve from 0.86284
# 104/104 [==============================] - 5113s 49s/step - loss: 0.3202 - accuracy: 0.8933 - f1_score: 0.8912 - val_loss: 0.4642 - val_accuracy: 0.8622 - val_f1_score: 0.8611 - lr: 2.5000e-05
# Epoch 88/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3071 - accuracy: 0.8965 - f1_score: 0.8958
# Epoch 88: val_f1_score improved from 0.86284 to 0.86836, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4860s 47s/step - loss: 0.3071 - accuracy: 0.8965 - f1_score: 0.8958 - val_loss: 0.4616 - val_accuracy: 0.8634 - val_f1_score: 0.8684 - lr: 2.5000e-05
# Epoch 89/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3114 - accuracy: 0.8953 - f1_score: 0.8972
# Epoch 89: val_f1_score did not improve from 0.86836
# 104/104 [==============================] - 4903s 47s/step - loss: 0.3114 - accuracy: 0.8953 - f1_score: 0.8972 - val_loss: 0.4774 - val_accuracy: 0.8614 - val_f1_score: 0.8577 - lr: 2.5000e-05
# Epoch 90/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.8968 - f1_score: 0.8984
# Epoch 90: val_f1_score did not improve from 0.86836
# 104/104 [==============================] - 5230s 50s/step - loss: 0.2982 - accuracy: 0.8968 - f1_score: 0.8984 - val_loss: 0.4636 - val_accuracy: 0.8676 - val_f1_score: 0.8625 - lr: 2.5000e-05
# Epoch 91/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8946 - f1_score: 0.8950
# Epoch 91: val_f1_score did not improve from 0.86836
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 104/104 [==============================] - 5445s 52s/step - loss: 0.3069 - accuracy: 0.8946 - f1_score: 0.8950 - val_loss: 0.4634 - val_accuracy: 0.8580 - val_f1_score: 0.8558 - lr: 2.5000e-05
# Epoch 92/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2686 - accuracy: 0.9095 - f1_score: 0.9107
# Epoch 92: val_f1_score did not improve from 0.86836
# 104/104 [==============================] - 5448s 52s/step - loss: 0.2686 - accuracy: 0.9095 - f1_score: 0.9107 - val_loss: 0.4297 - val_accuracy: 0.8684 - val_f1_score: 0.8676 - lr: 1.2500e-05
# Epoch 93/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9089 - f1_score: 0.9091
# Epoch 93: val_f1_score improved from 0.86836 to 0.87125, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 5597s 54s/step - loss: 0.2729 - accuracy: 0.9089 - f1_score: 0.9091 - val_loss: 0.4325 - val_accuracy: 0.8699 - val_f1_score: 0.8712 - lr: 1.2500e-05
# Epoch 94/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9128 - f1_score: 0.9138
# Epoch 94: val_f1_score did not improve from 0.87125
# 104/104 [==============================] - 5822s 56s/step - loss: 0.2665 - accuracy: 0.9128 - f1_score: 0.9138 - val_loss: 0.4236 - val_accuracy: 0.8746 - val_f1_score: 0.8681 - lr: 1.2500e-05
# Epoch 95/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.9157 - f1_score: 0.9179
# Epoch 95: val_f1_score improved from 0.87125 to 0.87505, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 4176s 40s/step - loss: 0.2626 - accuracy: 0.9157 - f1_score: 0.9179 - val_loss: 0.4252 - val_accuracy: 0.8742 - val_f1_score: 0.8751 - lr: 1.2500e-05
# Epoch 96/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9132 - f1_score: 0.9122
# Epoch 96: val_f1_score improved from 0.87505 to 0.87825, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 5631s 54s/step - loss: 0.2597 - accuracy: 0.9132 - f1_score: 0.9122 - val_loss: 0.4283 - val_accuracy: 0.8765 - val_f1_score: 0.8783 - lr: 1.2500e-05
# Epoch 97/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2719 - accuracy: 0.9060 - f1_score: 0.9066
# Epoch 97: val_f1_score did not improve from 0.87825
# 104/104 [==============================] - 5529s 53s/step - loss: 0.2719 - accuracy: 0.9060 - f1_score: 0.9066 - val_loss: 0.4378 - val_accuracy: 0.8742 - val_f1_score: 0.8702 - lr: 1.2500e-05
# Epoch 98/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9146 - f1_score: 0.9158
# Epoch 98: val_f1_score did not improve from 0.87825
# 104/104 [==============================] - 5842s 56s/step - loss: 0.2547 - accuracy: 0.9146 - f1_score: 0.9158 - val_loss: 0.4310 - val_accuracy: 0.8711 - val_f1_score: 0.8730 - lr: 1.2500e-05
# Epoch 99/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.9078 - f1_score: 0.9084
# Epoch 99: val_f1_score improved from 0.87825 to 0.88390, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 5940s 57s/step - loss: 0.2738 - accuracy: 0.9078 - f1_score: 0.9084 - val_loss: 0.4015 - val_accuracy: 0.8807 - val_f1_score: 0.8839 - lr: 1.2500e-05
# Epoch 100/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9082 - f1_score: 0.9095
# Epoch 100: val_f1_score did not improve from 0.88390
# 104/104 [==============================] - 5631s 54s/step - loss: 0.2606 - accuracy: 0.9082 - f1_score: 0.9095 - val_loss: 0.4042 - val_accuracy: 0.8815 - val_f1_score: 0.8832 - lr: 1.2500e-05
# Epoch 101/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9148 - f1_score: 0.9142
# Epoch 101: val_f1_score did not improve from 0.88390
# 104/104 [==============================] - 5702s 55s/step - loss: 0.2458 - accuracy: 0.9148 - f1_score: 0.9142 - val_loss: 0.4243 - val_accuracy: 0.8707 - val_f1_score: 0.8697 - lr: 1.2500e-05
# Epoch 102/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9119 - f1_score: 0.9123
# Epoch 102: val_f1_score did not improve from 0.88390
# 104/104 [==============================] - 5104s 49s/step - loss: 0.2593 - accuracy: 0.9119 - f1_score: 0.9123 - val_loss: 0.4051 - val_accuracy: 0.8811 - val_f1_score: 0.8811 - lr: 1.2500e-05
# Epoch 103/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9135 - f1_score: 0.9141
# Epoch 103: val_f1_score improved from 0.88390 to 0.88608, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 5810s 56s/step - loss: 0.2588 - accuracy: 0.9135 - f1_score: 0.9141 - val_loss: 0.4142 - val_accuracy: 0.8846 - val_f1_score: 0.8861 - lr: 1.2500e-05
# Epoch 104/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.9182 - f1_score: 0.9204
# Epoch 104: val_f1_score did not improve from 0.88608
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 104/104 [==============================] - 6360s 61s/step - loss: 0.2449 - accuracy: 0.9182 - f1_score: 0.9204 - val_loss: 0.4257 - val_accuracy: 0.8753 - val_f1_score: 0.8784 - lr: 1.2500e-05
# Epoch 105/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9174 - f1_score: 0.9167
# Epoch 105: val_f1_score improved from 0.88608 to 0.88841, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 6486s 62s/step - loss: 0.2402 - accuracy: 0.9174 - f1_score: 0.9167 - val_loss: 0.3986 - val_accuracy: 0.8900 - val_f1_score: 0.8884 - lr: 6.2500e-06
# Epoch 106/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9187 - f1_score: 0.9204
# Epoch 106: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 6561s 63s/step - loss: 0.2399 - accuracy: 0.9187 - f1_score: 0.9204 - val_loss: 0.4101 - val_accuracy: 0.8834 - val_f1_score: 0.8872 - lr: 6.2500e-06
# Epoch 107/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2420 - accuracy: 0.9188 - f1_score: 0.9194
# Epoch 107: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 6075s 58s/step - loss: 0.2420 - accuracy: 0.9188 - f1_score: 0.9194 - val_loss: 0.4216 - val_accuracy: 0.8815 - val_f1_score: 0.8827 - lr: 6.2500e-06
# Epoch 108/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2378 - accuracy: 0.9181 - f1_score: 0.9198
# Epoch 108: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 6382s 61s/step - loss: 0.2378 - accuracy: 0.9181 - f1_score: 0.9198 - val_loss: 0.3921 - val_accuracy: 0.8827 - val_f1_score: 0.8797 - lr: 6.2500e-06
# Epoch 109/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.9201 - f1_score: 0.9179
# Epoch 109: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 6440s 62s/step - loss: 0.2290 - accuracy: 0.9201 - f1_score: 0.9179 - val_loss: 0.4030 - val_accuracy: 0.8827 - val_f1_score: 0.8857 - lr: 6.2500e-06
# Epoch 110/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9216 - f1_score: 0.9231
# Epoch 110: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 6798s 65s/step - loss: 0.2380 - accuracy: 0.9216 - f1_score: 0.9231 - val_loss: 0.4009 - val_accuracy: 0.8850 - val_f1_score: 0.8811 - lr: 6.2500e-06
# Epoch 111/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2370 - accuracy: 0.9176 - f1_score: 0.9178
# Epoch 111: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 7041s 68s/step - loss: 0.2370 - accuracy: 0.9176 - f1_score: 0.9178 - val_loss: 0.4246 - val_accuracy: 0.8777 - val_f1_score: 0.8755 - lr: 6.2500e-06
# Epoch 112/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9163 - f1_score: 0.9176
# Epoch 112: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 7062s 68s/step - loss: 0.2484 - accuracy: 0.9163 - f1_score: 0.9176 - val_loss: 0.4312 - val_accuracy: 0.8711 - val_f1_score: 0.8681 - lr: 6.2500e-06
# Epoch 113/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9215 - f1_score: 0.9213
# Epoch 113: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 6998s 67s/step - loss: 0.2354 - accuracy: 0.9215 - f1_score: 0.9213 - val_loss: 0.3855 - val_accuracy: 0.8904 - val_f1_score: 0.8882 - lr: 6.2500e-06
# Epoch 114/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9236 - f1_score: 0.9252
# Epoch 114: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 7318s 70s/step - loss: 0.2263 - accuracy: 0.9236 - f1_score: 0.9252 - val_loss: 0.4014 - val_accuracy: 0.8865 - val_f1_score: 0.8882 - lr: 6.2500e-06
# Epoch 115/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9256 - f1_score: 0.9267
# Epoch 115: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 7302s 70s/step - loss: 0.2178 - accuracy: 0.9256 - f1_score: 0.9267 - val_loss: 0.4128 - val_accuracy: 0.8850 - val_f1_score: 0.8828 - lr: 6.2500e-06
# Epoch 116/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9158 - f1_score: 0.9137
# Epoch 116: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 5619s 54s/step - loss: 0.2399 - accuracy: 0.9158 - f1_score: 0.9137 - val_loss: 0.3971 - val_accuracy: 0.8773 - val_f1_score: 0.8739 - lr: 6.2500e-06
# Epoch 117/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9277 - f1_score: 0.9274
# Epoch 117: val_f1_score did not improve from 0.88841
# 104/104 [==============================] - 7560s 73s/step - loss: 0.2176 - accuracy: 0.9277 - f1_score: 0.9274 - val_loss: 0.4176 - val_accuracy: 0.8765 - val_f1_score: 0.8822 - lr: 6.2500e-06
# Epoch 118/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9203 - f1_score: 0.9201
# Epoch 118: val_f1_score did not improve from 0.88841
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 104/104 [==============================] - 7481s 72s/step - loss: 0.2301 - accuracy: 0.9203 - f1_score: 0.9201 - val_loss: 0.4228 - val_accuracy: 0.8761 - val_f1_score: 0.8769 - lr: 6.2500e-06
# Epoch 119/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9264 - f1_score: 0.9251
# Epoch 119: val_f1_score improved from 0.88841 to 0.88845, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 7632s 73s/step - loss: 0.2219 - accuracy: 0.9264 - f1_score: 0.9251 - val_loss: 0.4028 - val_accuracy: 0.8834 - val_f1_score: 0.8885 - lr: 3.1250e-06
# Epoch 120/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9218 - f1_score: 0.9227
# Epoch 120: val_f1_score did not improve from 0.88845
# 104/104 [==============================] - 7707s 74s/step - loss: 0.2283 - accuracy: 0.9218 - f1_score: 0.9227 - val_loss: 0.4438 - val_accuracy: 0.8800 - val_f1_score: 0.8779 - lr: 3.1250e-06
# Epoch 121/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9243 - f1_score: 0.9241
# Epoch 121: val_f1_score did not improve from 0.88845
# 104/104 [==============================] - 7648s 73s/step - loss: 0.2166 - accuracy: 0.9243 - f1_score: 0.9241 - val_loss: 0.4118 - val_accuracy: 0.8777 - val_f1_score: 0.8800 - lr: 3.1250e-06
# Epoch 122/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2263 - accuracy: 0.9214 - f1_score: 0.9222
# Epoch 122: val_f1_score did not improve from 0.88845
# 104/104 [==============================] - 7866s 76s/step - loss: 0.2263 - accuracy: 0.9214 - f1_score: 0.9222 - val_loss: 0.4015 - val_accuracy: 0.8838 - val_f1_score: 0.8846 - lr: 3.1250e-06
# Epoch 123/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9272 - f1_score: 0.9236
# Epoch 123: val_f1_score did not improve from 0.88845
# 104/104 [==============================] - 7864s 76s/step - loss: 0.2117 - accuracy: 0.9272 - f1_score: 0.9236 - val_loss: 0.3837 - val_accuracy: 0.8838 - val_f1_score: 0.8850 - lr: 3.1250e-06
# Epoch 124/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9242 - f1_score: 0.9264
# Epoch 124: val_f1_score improved from 0.88845 to 0.89194, saving model to saved_outputs_all_augment\parallel_vit_ap01\parallel_vit_ap01_saved_weights\best_parallel_vit_ap01_weights
# 104/104 [==============================] - 7810s 75s/step - loss: 0.2254 - accuracy: 0.9242 - f1_score: 0.9264 - val_loss: 0.3878 - val_accuracy: 0.8877 - val_f1_score: 0.8919 - lr: 3.1250e-06
# Epoch 125/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9275 - f1_score: 0.9262
# Epoch 125: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 6383s 61s/step - loss: 0.2124 - accuracy: 0.9275 - f1_score: 0.9262 - val_loss: 0.3767 - val_accuracy: 0.8888 - val_f1_score: 0.8878 - lr: 3.1250e-06
# Epoch 126/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9235 - f1_score: 0.9232
# Epoch 126: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 8010s 77s/step - loss: 0.2217 - accuracy: 0.9235 - f1_score: 0.9232 - val_loss: 0.4204 - val_accuracy: 0.8761 - val_f1_score: 0.8736 - lr: 3.1250e-06
# Epoch 127/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9262 - f1_score: 0.9258
# Epoch 127: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 8619s 83s/step - loss: 0.2224 - accuracy: 0.9262 - f1_score: 0.9258 - val_loss: 0.4017 - val_accuracy: 0.8885 - val_f1_score: 0.8860 - lr: 3.1250e-06
# Epoch 128/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9222 - f1_score: 0.9234
# Epoch 128: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 8315s 80s/step - loss: 0.2242 - accuracy: 0.9222 - f1_score: 0.9234 - val_loss: 0.3989 - val_accuracy: 0.8865 - val_f1_score: 0.8886 - lr: 3.1250e-06
# Epoch 129/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9258 - f1_score: 0.9269
# Epoch 129: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 8031s 77s/step - loss: 0.2223 - accuracy: 0.9258 - f1_score: 0.9269 - val_loss: 0.3938 - val_accuracy: 0.8896 - val_f1_score: 0.8887 - lr: 3.1250e-06
# Epoch 130/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9249 - f1_score: 0.9263
# Epoch 130: val_f1_score did not improve from 0.89194
#
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 104/104 [==============================] - 8170s 79s/step - loss: 0.2185 - accuracy: 0.9249 - f1_score: 0.9263 - val_loss: 0.3902 - val_accuracy: 0.8888 - val_f1_score: 0.8887 - lr: 3.1250e-06
# Epoch 131/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9253 - f1_score: 0.9251
# Epoch 131: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 8245s 79s/step - loss: 0.2150 - accuracy: 0.9253 - f1_score: 0.9251 - val_loss: 0.3913 - val_accuracy: 0.8842 - val_f1_score: 0.8851 - lr: 1.5625e-06
# Epoch 132/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9264 - f1_score: 0.9247
# Epoch 132: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 9060s 87s/step - loss: 0.2150 - accuracy: 0.9264 - f1_score: 0.9247 - val_loss: 0.3911 - val_accuracy: 0.8892 - val_f1_score: 0.8889 - lr: 1.5625e-06
# Epoch 133/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9298 - f1_score: 0.9299
# Epoch 133: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 9318s 90s/step - loss: 0.2162 - accuracy: 0.9298 - f1_score: 0.9299 - val_loss: 0.3922 - val_accuracy: 0.8854 - val_f1_score: 0.8896 - lr: 1.5625e-06
# Epoch 134/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9242 - f1_score: 0.9258
# Epoch 134: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 9288s 89s/step - loss: 0.2214 - accuracy: 0.9242 - f1_score: 0.9258 - val_loss: 0.3890 - val_accuracy: 0.8908 - val_f1_score: 0.8907 - lr: 1.5625e-06
# Epoch 135/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9264 - f1_score: 0.9268
# Epoch 135: val_f1_score did not improve from 0.89194
#
# Epoch 135: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 104/104 [==============================] - 8466s 81s/step - loss: 0.2201 - accuracy: 0.9264 - f1_score: 0.9268 - val_loss: 0.3892 - val_accuracy: 0.8858 - val_f1_score: 0.8917 - lr: 1.5625e-06
# Epoch 136/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.9315 - f1_score: 0.9357
# Epoch 136: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 8651s 83s/step - loss: 0.2130 - accuracy: 0.9315 - f1_score: 0.9357 - val_loss: 0.3970 - val_accuracy: 0.8904 - val_f1_score: 0.8894 - lr: 7.8125e-07
# Epoch 137/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9255 - f1_score: 0.9268
# Epoch 137: val_f1_score did not improve from 0.89194
# 104/104 [==============================] - 9451s 91s/step - loss: 0.2175 - accuracy: 0.9255 - f1_score: 0.9268 - val_loss: 0.3785 - val_accuracy: 0.8858 - val_f1_score: 0.8823 - lr: 7.8125e-07

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
best_model = get_parallel_vit()

best_model.load_weights(PATH_BEST_WEIGHT_SAVE)

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 285s 8s/step - loss: 0.2473 - accuracy: 0.9371 - f1_score: 0.9114
#           model_name  test_loss  test_accuracy  test_f1_score
# 0  parallel_vit_ap01   0.247341       0.937134       0.911417

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test
############################################################################################################]
# Out:
# 33/33 [==============================] - 304s 9s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.950820  0.892308  0.920635   130.000000
# 1              0.938776  0.920000  0.929293   100.000000
# 2              0.926316  0.977778  0.951351    90.000000
# 3              0.888889  0.950495  0.918660   101.000000
# 4              0.944915  0.948936  0.946921   470.000000
# 5              0.911538  0.936759  0.923977   253.000000
# 6              0.896175  0.942529  0.918768   174.000000
# 7              0.902715  0.925754  0.914089   431.000000
# 8              0.940594  0.867580  0.902613   219.000000
# 9              0.974082  0.937630  0.955508   481.000000
# 10             0.963636  0.951282  0.957419   390.000000
# 11             0.931298  0.960630  0.945736   254.000000
# 12             0.960784  0.967105  0.963934   152.000000
# accuracy       0.937134  0.937134  0.937134     0.937134
# macro avg      0.933118  0.936830  0.934531  3245.000000
# weighted avg   0.937841  0.937134  0.937157  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels,
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#           Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  parallel_vit_ap01  0.937134         0.933118       0.93683        0.934531
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.937841         0.937134           0.937157  0.247341

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.93713
# 1      Macro Precision  0.93312
# 2         Macro Recall  0.93683
# 3       Macro F1-Score  0.93453
# 4            Macro FPR  0.00535
# 5            Macro FNR  0.06317
# 6            Macro FDR  0.06688
# 7            Macro NPV  0.99462
# 8   Weighted Precision  0.93784
# 9      Weighted Recall  0.93713
# 10   Weighted F1-Score  0.93716
# 11        Weighted FPR  0.00670
# 12        Weighted FNR  0.06287
# 13        Weighted FDR  0.06216
# 14        Weighted NPV  0.99293
