# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files


import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report

import time
from tqdm import tqdm

import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'MobileNet_v4' #'Xception'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment_3RD_RUN', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_all_augment_3RD_RUN\MobileNet_v4
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_8\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=12, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:      
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:        
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %%
from tensorflow.keras.applications import MobileNet#### WORKING
def get_MobileNet_original(): 
 
    # model = Sequential()
    # base_model = MobileNet(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)

    model = MobileNet(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 2.2887 - accuracy: 0.2204 - f1_score: 0.1357
# Epoch 1: val_f1_score improved from -inf to 0.00973, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 91s 820ms/step - loss: 2.2887 - accuracy: 0.2204 - f1_score: 0.1357 - val_loss: 2.5687 - val_accuracy: 0.0675 - val_f1_score: 0.0097 - lr: 0.0010
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 2.0105 - accuracy: 0.3155 - f1_score: 0.2406
# Epoch 2: val_f1_score did not improve from 0.00973
# 104/104 [==============================] - 76s 728ms/step - loss: 2.0105 - accuracy: 0.3155 - f1_score: 0.2406 - val_loss: 2.8943 - val_accuracy: 0.0675 - val_f1_score: 0.0097 - lr: 0.0010
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7664 - accuracy: 0.4010 - f1_score: 0.3483
# Epoch 3: val_f1_score improved from 0.00973 to 0.01102, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 80s 768ms/step - loss: 1.7664 - accuracy: 0.4010 - f1_score: 0.3483 - val_loss: 3.0750 - val_accuracy: 0.0772 - val_f1_score: 0.0110 - lr: 0.0010
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5558 - accuracy: 0.4809 - f1_score: 0.4389
# Epoch 4: val_f1_score did not improve from 0.01102
# 104/104 [==============================] - 77s 733ms/step - loss: 1.5558 - accuracy: 0.4809 - f1_score: 0.4389 - val_loss: 3.2611 - val_accuracy: 0.0772 - val_f1_score: 0.0110 - lr: 0.0010
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3556 - accuracy: 0.5498 - f1_score: 0.5116
# Epoch 5: val_f1_score did not improve from 0.01102
# 104/104 [==============================] - 80s 765ms/step - loss: 1.3556 - accuracy: 0.5498 - f1_score: 0.5116 - val_loss: 2.9957 - val_accuracy: 0.0772 - val_f1_score: 0.0110 - lr: 0.0010
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1641 - accuracy: 0.6169 - f1_score: 0.5859
# Epoch 6: val_f1_score improved from 0.01102 to 0.09904, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 85s 811ms/step - loss: 1.1641 - accuracy: 0.6169 - f1_score: 0.5859 - val_loss: 3.0416 - val_accuracy: 0.2219 - val_f1_score: 0.0990 - lr: 0.0010
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9356 - accuracy: 0.6916 - f1_score: 0.6656
# Epoch 7: val_f1_score improved from 0.09904 to 0.24127, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 84s 804ms/step - loss: 0.9356 - accuracy: 0.6916 - f1_score: 0.6656 - val_loss: 2.3428 - val_accuracy: 0.3284 - val_f1_score: 0.2413 - lr: 5.0000e-04
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8139 - accuracy: 0.7308 - f1_score: 0.7109
# Epoch 8: val_f1_score improved from 0.24127 to 0.58164, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 82s 787ms/step - loss: 0.8139 - accuracy: 0.7308 - f1_score: 0.7109 - val_loss: 1.1890 - val_accuracy: 0.6144 - val_f1_score: 0.5816 - lr: 5.0000e-04
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7164 - accuracy: 0.7645 - f1_score: 0.7472
# Epoch 9: val_f1_score did not improve from 0.58164
# 104/104 [==============================] - 78s 749ms/step - loss: 0.7164 - accuracy: 0.7645 - f1_score: 0.7472 - val_loss: 1.3293 - val_accuracy: 0.5936 - val_f1_score: 0.5585 - lr: 5.0000e-04
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6450 - accuracy: 0.7852 - f1_score: 0.7765
# Epoch 10: val_f1_score improved from 0.58164 to 0.64519, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 82s 783ms/step - loss: 0.6450 - accuracy: 0.7852 - f1_score: 0.7765 - val_loss: 1.0617 - val_accuracy: 0.6662 - val_f1_score: 0.6452 - lr: 5.0000e-04
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5844 - accuracy: 0.8069 - f1_score: 0.7953
# Epoch 11: val_f1_score improved from 0.64519 to 0.64787, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 82s 787ms/step - loss: 0.5844 - accuracy: 0.8069 - f1_score: 0.7953 - val_loss: 0.9777 - val_accuracy: 0.6951 - val_f1_score: 0.6479 - lr: 5.0000e-04
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5325 - accuracy: 0.8221 - f1_score: 0.8146
# Epoch 12: val_f1_score improved from 0.64787 to 0.74217, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 80s 767ms/step - loss: 0.5325 - accuracy: 0.8221 - f1_score: 0.8146 - val_loss: 0.7893 - val_accuracy: 0.7514 - val_f1_score: 0.7422 - lr: 5.0000e-04
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4795 - accuracy: 0.8427 - f1_score: 0.8325
# Epoch 13: val_f1_score did not improve from 0.74217
# 104/104 [==============================] - 77s 744ms/step - loss: 0.4795 - accuracy: 0.8427 - f1_score: 0.8325 - val_loss: 0.9623 - val_accuracy: 0.6990 - val_f1_score: 0.6906 - lr: 5.0000e-04
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4917 - accuracy: 0.8357 - f1_score: 0.8269
# Epoch 14: val_f1_score did not improve from 0.74217
# 104/104 [==============================] - 98s 947ms/step - loss: 0.4917 - accuracy: 0.8357 - f1_score: 0.8269 - val_loss: 1.0395 - val_accuracy: 0.6897 - val_f1_score: 0.6607 - lr: 5.0000e-04
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4034 - accuracy: 0.8656 - f1_score: 0.8610
# Epoch 15: val_f1_score did not improve from 0.74217
# 104/104 [==============================] - 76s 726ms/step - loss: 0.4034 - accuracy: 0.8656 - f1_score: 0.8610 - val_loss: 1.0080 - val_accuracy: 0.7024 - val_f1_score: 0.6767 - lr: 5.0000e-04
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8787 - f1_score: 0.8712
# Epoch 16: val_f1_score did not improve from 0.74217
# 104/104 [==============================] - 80s 764ms/step - loss: 0.3779 - accuracy: 0.8787 - f1_score: 0.8712 - val_loss: 1.2587 - val_accuracy: 0.6530 - val_f1_score: 0.6470 - lr: 5.0000e-04
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.8758 - f1_score: 0.8704
# Epoch 17: val_f1_score did not improve from 0.74217
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 83s 795ms/step - loss: 0.3769 - accuracy: 0.8758 - f1_score: 0.8704 - val_loss: 1.0898 - val_accuracy: 0.6704 - val_f1_score: 0.6483 - lr: 5.0000e-04
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2649 - accuracy: 0.9139 - f1_score: 0.9118
# Epoch 18: val_f1_score improved from 0.74217 to 0.85501, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 81s 779ms/step - loss: 0.2649 - accuracy: 0.9139 - f1_score: 0.9118 - val_loss: 0.4371 - val_accuracy: 0.8626 - val_f1_score: 0.8550 - lr: 2.5000e-04
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9313 - f1_score: 0.9278
# Epoch 19: val_f1_score did not improve from 0.85501
# 104/104 [==============================] - 76s 726ms/step - loss: 0.2158 - accuracy: 0.9313 - f1_score: 0.9278 - val_loss: 0.4748 - val_accuracy: 0.8503 - val_f1_score: 0.8388 - lr: 2.5000e-04
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9330 - f1_score: 0.9324
# Epoch 20: val_f1_score did not improve from 0.85501
# 104/104 [==============================] - 80s 760ms/step - loss: 0.2081 - accuracy: 0.9330 - f1_score: 0.9324 - val_loss: 0.4697 - val_accuracy: 0.8522 - val_f1_score: 0.8455 - lr: 2.5000e-04
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9359 - f1_score: 0.9318
# Epoch 21: val_f1_score improved from 0.85501 to 0.86436, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 82s 787ms/step - loss: 0.1960 - accuracy: 0.9359 - f1_score: 0.9318 - val_loss: 0.4135 - val_accuracy: 0.8723 - val_f1_score: 0.8644 - lr: 2.5000e-04
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1798 - accuracy: 0.9415 - f1_score: 0.9398
# Epoch 22: val_f1_score did not improve from 0.86436
# 104/104 [==============================] - 80s 768ms/step - loss: 0.1798 - accuracy: 0.9415 - f1_score: 0.9398 - val_loss: 0.5898 - val_accuracy: 0.8259 - val_f1_score: 0.8193 - lr: 2.5000e-04
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1785 - accuracy: 0.9418 - f1_score: 0.9398
# Epoch 23: val_f1_score did not improve from 0.86436
# 104/104 [==============================] - 71s 677ms/step - loss: 0.1785 - accuracy: 0.9418 - f1_score: 0.9398 - val_loss: 0.4570 - val_accuracy: 0.8568 - val_f1_score: 0.8490 - lr: 2.5000e-04
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9495 - f1_score: 0.9471
# Epoch 24: val_f1_score improved from 0.86436 to 0.87951, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 65s 620ms/step - loss: 0.1634 - accuracy: 0.9495 - f1_score: 0.9471 - val_loss: 0.3768 - val_accuracy: 0.8842 - val_f1_score: 0.8795 - lr: 2.5000e-04
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9462 - f1_score: 0.9442
# Epoch 25: val_f1_score improved from 0.87951 to 0.88296, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 67s 646ms/step - loss: 0.1567 - accuracy: 0.9462 - f1_score: 0.9442 - val_loss: 0.3563 - val_accuracy: 0.8861 - val_f1_score: 0.8830 - lr: 2.5000e-04
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9503 - f1_score: 0.9488
# Epoch 26: val_f1_score did not improve from 0.88296
# 104/104 [==============================] - 74s 713ms/step - loss: 0.1539 - accuracy: 0.9503 - f1_score: 0.9488 - val_loss: 0.4683 - val_accuracy: 0.8557 - val_f1_score: 0.8489 - lr: 2.5000e-04
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9472 - f1_score: 0.9454
# Epoch 27: val_f1_score did not improve from 0.88296
# 104/104 [==============================] - 78s 743ms/step - loss: 0.1576 - accuracy: 0.9472 - f1_score: 0.9454 - val_loss: 0.5098 - val_accuracy: 0.8483 - val_f1_score: 0.8371 - lr: 2.5000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9502 - f1_score: 0.9489
# Epoch 28: val_f1_score did not improve from 0.88296
# 104/104 [==============================] - 78s 745ms/step - loss: 0.1462 - accuracy: 0.9502 - f1_score: 0.9489 - val_loss: 0.4052 - val_accuracy: 0.8807 - val_f1_score: 0.8775 - lr: 2.5000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9513 - f1_score: 0.9503
# Epoch 29: val_f1_score did not improve from 0.88296
# 104/104 [==============================] - 79s 755ms/step - loss: 0.1410 - accuracy: 0.9513 - f1_score: 0.9503 - val_loss: 0.4125 - val_accuracy: 0.8792 - val_f1_score: 0.8759 - lr: 2.5000e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9550 - f1_score: 0.9537
# Epoch 30: val_f1_score did not improve from 0.88296
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 78s 750ms/step - loss: 0.1376 - accuracy: 0.9550 - f1_score: 0.9537 - val_loss: 0.3930 - val_accuracy: 0.8765 - val_f1_score: 0.8686 - lr: 2.5000e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9686 - f1_score: 0.9684
# Epoch 31: val_f1_score improved from 0.88296 to 0.91606, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 74s 707ms/step - loss: 0.1010 - accuracy: 0.9686 - f1_score: 0.9684 - val_loss: 0.2708 - val_accuracy: 0.9178 - val_f1_score: 0.9161 - lr: 1.2500e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9741 - f1_score: 0.9739
# Epoch 32: val_f1_score did not improve from 0.91606
# 104/104 [==============================] - 68s 648ms/step - loss: 0.0823 - accuracy: 0.9741 - f1_score: 0.9739 - val_loss: 0.2663 - val_accuracy: 0.9178 - val_f1_score: 0.9135 - lr: 1.2500e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9767 - f1_score: 0.9767
# Epoch 33: val_f1_score did not improve from 0.91606
# 104/104 [==============================] - 69s 661ms/step - loss: 0.0750 - accuracy: 0.9767 - f1_score: 0.9767 - val_loss: 0.2817 - val_accuracy: 0.9186 - val_f1_score: 0.9134 - lr: 1.2500e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9762 - f1_score: 0.9763
# Epoch 34: val_f1_score did not improve from 0.91606
# 104/104 [==============================] - 61s 586ms/step - loss: 0.0747 - accuracy: 0.9762 - f1_score: 0.9763 - val_loss: 0.2766 - val_accuracy: 0.9190 - val_f1_score: 0.9156 - lr: 1.2500e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9787 - f1_score: 0.9785
# Epoch 35: val_f1_score improved from 0.91606 to 0.92735, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 65s 620ms/step - loss: 0.0709 - accuracy: 0.9787 - f1_score: 0.9785 - val_loss: 0.2568 - val_accuracy: 0.9263 - val_f1_score: 0.9274 - lr: 1.2500e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9783 - f1_score: 0.9771
# Epoch 36: val_f1_score did not improve from 0.92735
# 104/104 [==============================] - 62s 595ms/step - loss: 0.0685 - accuracy: 0.9783 - f1_score: 0.9771 - val_loss: 0.2837 - val_accuracy: 0.9190 - val_f1_score: 0.9150 - lr: 1.2500e-04
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9766 - f1_score: 0.9756
# Epoch 37: val_f1_score improved from 0.92735 to 0.93329, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 64s 618ms/step - loss: 0.0739 - accuracy: 0.9766 - f1_score: 0.9756 - val_loss: 0.2496 - val_accuracy: 0.9344 - val_f1_score: 0.9333 - lr: 1.2500e-04
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9785 - f1_score: 0.9773
# Epoch 38: val_f1_score did not improve from 0.93329
# 104/104 [==============================] - 67s 647ms/step - loss: 0.0671 - accuracy: 0.9785 - f1_score: 0.9773 - val_loss: 0.3055 - val_accuracy: 0.9105 - val_f1_score: 0.9116 - lr: 1.2500e-04
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9778 - f1_score: 0.9774
# Epoch 39: val_f1_score did not improve from 0.93329
# 104/104 [==============================] - 63s 605ms/step - loss: 0.0701 - accuracy: 0.9778 - f1_score: 0.9774 - val_loss: 0.3134 - val_accuracy: 0.9128 - val_f1_score: 0.9064 - lr: 1.2500e-04
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9775 - f1_score: 0.9783
# Epoch 40: val_f1_score did not improve from 0.93329
# 104/104 [==============================] - 63s 599ms/step - loss: 0.0695 - accuracy: 0.9775 - f1_score: 0.9783 - val_loss: 0.3083 - val_accuracy: 0.9132 - val_f1_score: 0.9101 - lr: 1.2500e-04
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9796 - f1_score: 0.9801
# Epoch 41: val_f1_score did not improve from 0.93329
# 104/104 [==============================] - 65s 623ms/step - loss: 0.0621 - accuracy: 0.9796 - f1_score: 0.9801 - val_loss: 0.2730 - val_accuracy: 0.9232 - val_f1_score: 0.9215 - lr: 1.2500e-04
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9799 - f1_score: 0.9799
# Epoch 42: val_f1_score did not improve from 0.93329
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 65s 620ms/step - loss: 0.0664 - accuracy: 0.9799 - f1_score: 0.9799 - val_loss: 0.2719 - val_accuracy: 0.9244 - val_f1_score: 0.9238 - lr: 1.2500e-04
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9833 - f1_score: 0.9825
# Epoch 43: val_f1_score improved from 0.93329 to 0.93523, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0522 - accuracy: 0.9833 - f1_score: 0.9825 - val_loss: 0.2264 - val_accuracy: 0.9371 - val_f1_score: 0.9352 - lr: 6.2500e-05
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9836 - f1_score: 0.9833
# Epoch 44: val_f1_score improved from 0.93523 to 0.94067, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 71s 681ms/step - loss: 0.0514 - accuracy: 0.9836 - f1_score: 0.9833 - val_loss: 0.2080 - val_accuracy: 0.9460 - val_f1_score: 0.9407 - lr: 6.2500e-05
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9842 - f1_score: 0.9839
# Epoch 45: val_f1_score did not improve from 0.94067
# 104/104 [==============================] - 64s 612ms/step - loss: 0.0487 - accuracy: 0.9842 - f1_score: 0.9839 - val_loss: 0.2129 - val_accuracy: 0.9421 - val_f1_score: 0.9397 - lr: 6.2500e-05
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9856 - f1_score: 0.9857
# Epoch 46: val_f1_score did not improve from 0.94067
# 104/104 [==============================] - 71s 675ms/step - loss: 0.0445 - accuracy: 0.9856 - f1_score: 0.9857 - val_loss: 0.2462 - val_accuracy: 0.9355 - val_f1_score: 0.9317 - lr: 6.2500e-05
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9881 - f1_score: 0.9879
# Epoch 47: val_f1_score did not improve from 0.94067
# 104/104 [==============================] - 66s 629ms/step - loss: 0.0408 - accuracy: 0.9881 - f1_score: 0.9879 - val_loss: 0.2121 - val_accuracy: 0.9402 - val_f1_score: 0.9378 - lr: 6.2500e-05
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9878 - f1_score: 0.9878
# Epoch 48: val_f1_score improved from 0.94067 to 0.94346, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 72s 691ms/step - loss: 0.0371 - accuracy: 0.9878 - f1_score: 0.9878 - val_loss: 0.2152 - val_accuracy: 0.9429 - val_f1_score: 0.9435 - lr: 6.2500e-05
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9885 - f1_score: 0.9882
# Epoch 49: val_f1_score improved from 0.94346 to 0.94512, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 73s 701ms/step - loss: 0.0361 - accuracy: 0.9885 - f1_score: 0.9882 - val_loss: 0.2249 - val_accuracy: 0.9464 - val_f1_score: 0.9451 - lr: 6.2500e-05
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9878 - f1_score: 0.9873
# Epoch 50: val_f1_score did not improve from 0.94512
# 104/104 [==============================] - 62s 594ms/step - loss: 0.0385 - accuracy: 0.9878 - f1_score: 0.9873 - val_loss: 0.2226 - val_accuracy: 0.9406 - val_f1_score: 0.9374 - lr: 3.1250e-05
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9907 - f1_score: 0.9901
# Epoch 51: val_f1_score did not improve from 0.94512
# 104/104 [==============================] - 66s 631ms/step - loss: 0.0333 - accuracy: 0.9907 - f1_score: 0.9901 - val_loss: 0.2093 - val_accuracy: 0.9452 - val_f1_score: 0.9444 - lr: 3.1250e-05
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9883 - f1_score: 0.9875
# Epoch 52: val_f1_score did not improve from 0.94512
# 104/104 [==============================] - 72s 681ms/step - loss: 0.0369 - accuracy: 0.9883 - f1_score: 0.9875 - val_loss: 0.2102 - val_accuracy: 0.9456 - val_f1_score: 0.9432 - lr: 3.1250e-05
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9883 - f1_score: 0.9879
# Epoch 53: val_f1_score did not improve from 0.94512
# 104/104 [==============================] - 63s 605ms/step - loss: 0.0376 - accuracy: 0.9883 - f1_score: 0.9879 - val_loss: 0.2267 - val_accuracy: 0.9429 - val_f1_score: 0.9393 - lr: 3.1250e-05
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9902 - f1_score: 0.9902
# Epoch 54: val_f1_score did not improve from 0.94512
# 104/104 [==============================] - 61s 586ms/step - loss: 0.0329 - accuracy: 0.9902 - f1_score: 0.9902 - val_loss: 0.2037 - val_accuracy: 0.9406 - val_f1_score: 0.9380 - lr: 3.1250e-05
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9912 - f1_score: 0.9910
# Epoch 55: val_f1_score improved from 0.94512 to 0.94667, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 67s 646ms/step - loss: 0.0305 - accuracy: 0.9912 - f1_score: 0.9910 - val_loss: 0.2068 - val_accuracy: 0.9483 - val_f1_score: 0.9467 - lr: 3.1250e-05
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9905 - f1_score: 0.9901
# Epoch 56: val_f1_score did not improve from 0.94667
# 104/104 [==============================] - 65s 617ms/step - loss: 0.0332 - accuracy: 0.9905 - f1_score: 0.9901 - val_loss: 0.2114 - val_accuracy: 0.9440 - val_f1_score: 0.9415 - lr: 3.1250e-05
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9885 - f1_score: 0.9875
# Epoch 57: val_f1_score did not improve from 0.94667
# 104/104 [==============================] - 69s 658ms/step - loss: 0.0341 - accuracy: 0.9885 - f1_score: 0.9875 - val_loss: 0.2177 - val_accuracy: 0.9425 - val_f1_score: 0.9409 - lr: 3.1250e-05
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9896 - f1_score: 0.9897
# Epoch 58: val_f1_score did not improve from 0.94667
# 104/104 [==============================] - 78s 745ms/step - loss: 0.0332 - accuracy: 0.9896 - f1_score: 0.9897 - val_loss: 0.2075 - val_accuracy: 0.9467 - val_f1_score: 0.9445 - lr: 3.1250e-05
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9915 - f1_score: 0.9909
# Epoch 59: val_f1_score improved from 0.94667 to 0.94772, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 67s 641ms/step - loss: 0.0275 - accuracy: 0.9915 - f1_score: 0.9909 - val_loss: 0.1821 - val_accuracy: 0.9494 - val_f1_score: 0.9477 - lr: 3.1250e-05
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9902 - f1_score: 0.9898
# Epoch 60: val_f1_score did not improve from 0.94772
# 104/104 [==============================] - 66s 637ms/step - loss: 0.0295 - accuracy: 0.9902 - f1_score: 0.9898 - val_loss: 0.1921 - val_accuracy: 0.9460 - val_f1_score: 0.9439 - lr: 3.1250e-05
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9901 - f1_score: 0.9897
# Epoch 61: val_f1_score did not improve from 0.94772
# 104/104 [==============================] - 64s 614ms/step - loss: 0.0318 - accuracy: 0.9901 - f1_score: 0.9897 - val_loss: 0.1956 - val_accuracy: 0.9471 - val_f1_score: 0.9474 - lr: 3.1250e-05
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9912 - f1_score: 0.9905
# Epoch 62: val_f1_score did not improve from 0.94772
# 104/104 [==============================] - 91s 875ms/step - loss: 0.0290 - accuracy: 0.9912 - f1_score: 0.9905 - val_loss: 0.2188 - val_accuracy: 0.9452 - val_f1_score: 0.9434 - lr: 3.1250e-05
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9911 - f1_score: 0.9911
# Epoch 63: val_f1_score did not improve from 0.94772
# 104/104 [==============================] - 70s 674ms/step - loss: 0.0288 - accuracy: 0.9911 - f1_score: 0.9911 - val_loss: 0.2098 - val_accuracy: 0.9371 - val_f1_score: 0.9365 - lr: 3.1250e-05
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9923 - f1_score: 0.9920
# Epoch 64: val_f1_score did not improve from 0.94772
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 66s 632ms/step - loss: 0.0265 - accuracy: 0.9923 - f1_score: 0.9920 - val_loss: 0.2037 - val_accuracy: 0.9437 - val_f1_score: 0.9412 - lr: 3.1250e-05
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9928 - f1_score: 0.9928
# Epoch 65: val_f1_score did not improve from 0.94772
# 104/104 [==============================] - 90s 868ms/step - loss: 0.0268 - accuracy: 0.9928 - f1_score: 0.9928 - val_loss: 0.2152 - val_accuracy: 0.9433 - val_f1_score: 0.9425 - lr: 1.5625e-05
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9913 - f1_score: 0.9905
# Epoch 66: val_f1_score did not improve from 0.94772
# 104/104 [==============================] - 74s 709ms/step - loss: 0.0284 - accuracy: 0.9913 - f1_score: 0.9905 - val_loss: 0.2041 - val_accuracy: 0.9429 - val_f1_score: 0.9377 - lr: 1.5625e-05
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9924 - f1_score: 0.9918
# Epoch 67: val_f1_score improved from 0.94772 to 0.94924, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 67s 638ms/step - loss: 0.0251 - accuracy: 0.9924 - f1_score: 0.9918 - val_loss: 0.1975 - val_accuracy: 0.9494 - val_f1_score: 0.9492 - lr: 1.5625e-05
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9920 - f1_score: 0.9915
# Epoch 68: val_f1_score improved from 0.94924 to 0.95100, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0253 - accuracy: 0.9920 - f1_score: 0.9915 - val_loss: 0.2058 - val_accuracy: 0.9510 - val_f1_score: 0.9510 - lr: 1.5625e-05
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9924 - f1_score: 0.9925
# Epoch 69: val_f1_score did not improve from 0.95100
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 83s 796ms/step - loss: 0.0261 - accuracy: 0.9924 - f1_score: 0.9925 - val_loss: 0.1905 - val_accuracy: 0.9498 - val_f1_score: 0.9474 - lr: 1.5625e-05
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9922 - f1_score: 0.9922
# Epoch 70: val_f1_score did not improve from 0.95100
# 104/104 [==============================] - 77s 740ms/step - loss: 0.0250 - accuracy: 0.9922 - f1_score: 0.9922 - val_loss: 0.2023 - val_accuracy: 0.9421 - val_f1_score: 0.9397 - lr: 7.8125e-06
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9926 - f1_score: 0.9925
# Epoch 71: val_f1_score improved from 0.95100 to 0.95341, saving model to saved_outputs_all_augment_3RD_RUN\MobileNet_v4\saved_models\best_MobileNet_v4.h5
# 104/104 [==============================] - 77s 734ms/step - loss: 0.0253 - accuracy: 0.9926 - f1_score: 0.9925 - val_loss: 0.1842 - val_accuracy: 0.9541 - val_f1_score: 0.9534 - lr: 7.8125e-06

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 9s 242ms/step - loss: 0.6545 - accuracy: 0.8247 - f1_score: 0.8167
#      model_name  test_loss  test_accuracy  test_f1_score
# 0  MobileNet_v4   0.654521       0.824653       0.816688

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 6s 174ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                            target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.625767  0.784615  0.696246   130.000000
# 1              0.824074  0.890000  0.855769   100.000000
# 2              0.984615  0.711111  0.825806    90.000000
# 3              0.873563  0.752475  0.808511   101.000000
# 4              0.854077  0.846809  0.850427   470.000000
# 5              0.790984  0.762846  0.776660   253.000000
# 6              0.836735  0.706897  0.766355   174.000000
# 7              0.865526  0.821346  0.842857   431.000000
# 8              0.766990  0.721461  0.743529   219.000000
# 9              0.781197  0.950104  0.857411   481.000000
# 10             0.812987  0.802564  0.807742   390.000000
# 11             0.906780  0.842520  0.873469   254.000000
# 12             0.937500  0.888158  0.912162   152.000000
# accuracy       0.824653  0.824653  0.824653     0.824653
# macro avg      0.835446  0.806223  0.816688  3245.000000
# weighted avg   0.830319  0.824653  0.824549  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#      Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  MobileNet_v4  0.824653         0.835446      0.806223        0.816688
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.830319         0.824653           0.824549  0.654521

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.82465
# 1      Macro Precision  0.83545
# 2         Macro Recall  0.80622
# 3       Macro F1-Score  0.81669
# 4            Macro FPR  0.01508
# 5            Macro FNR  0.19378
# 6            Macro FDR  0.16455
# 7            Macro NPV  0.98515
# 8   Weighted Precision  0.83032
# 9      Weighted Recall  0.82465
# 10   Weighted F1-Score  0.82455
# 11        Weighted FPR  0.02066
# 12        Weighted FNR  0.17535
# 13        Weighted FDR  0.16968
# 14        Weighted NPV  0.98203
