# %% [markdown]
# - imbalance data: https://www.linkedin.com/pulse/some-tricks-handling-imbalanced-dataset-image-m-farhan-tandia
# - base model: https://www.youtube.com/watch?v=t8eSPbvl0vU
# - https://www.kaggle.com/code/hongjae6/simple-baseline-using-keras-resnet50

# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, Activation, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')
######################################################################################################
from keras_tuner import RandomSearch, HyperParameters
from tensorflow.keras.applications import Xception, DenseNet121
import keras_tuner as kt

# %%
model_name = 'Ensemble3'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 
# FNAME_TUNER_REPORT = 'Report_tune_'+ model_name
################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_SAVE_RESULT, 'saved_tuner_model')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_all_augment\Ensemble3
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment\Ensemble3\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment\Ensemble3\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_7048\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=15, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING
#
# Trial 15 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 9
# Score: 0.7056062817573547
#
# Trial 11 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 5
# Score: 0.705497920513153179205131531

# %%
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.1,
#                       activation='relu',
#                       units= 1024,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy", 
#                       retrain_backbone_network=False,
#                       learning_rate = 0.001,
#                       global_pooling = 'avg',
#                       filters=7,
#                       name='ensemble2'):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Concatenate features
#     concatenated_features = Concatenate()([Xception_features, densenet_features])

#     if filters==3:
#         filters = (3,3)
#     elif filters==5:
#         filters = (5,5)
#     elif filters==7:
#         filters = (7,7)
#     elif filters==9:
#         filters = (9,9)

#     # # Add a tunable dropout layer
#     # x = Dropout(dropout)(concatenated_features)

#     # # A fully connected layer with a tunable number of units
#     # x = Dense(units)(x)

#     #     # Add a tunable dropout layer
#     # x = Dropout(dropout)(x)

#     # # A fully connected layer with a tunable number of units
#     # x = Dense(units)(x)
#         # Add a tunable dropout layer
#     x = Dropout(dropout)(concatenated_features)

#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Add a tunable dropout layer
#     x = Dropout(dropout)(x)

#     # A fully connected layer with a tunable number of units again
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)


#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create and compile the model
#     model = Model(inputs=inputs, outputs=predictions)
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate),
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %%
from tensorflow.keras.applications import Xception, DenseNet121, InceptionResNetV2
# Function to build the model with an ensemble of feature extractors
def get_ensemble3_model(input_shape=MODEL_INPUT_SIZE,
                      dropout= 0.2,
                      activation='relu',
                      units= 512,
                      nr_classes=NUM_CLASSES,
                      loss = "categorical_crossentropy",
                      retrain_backbone_network=False,
                      filters=7):


    inputs = Input(shape=input_shape)

    # Feature extraction from DenseNet121
    densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
    densenet_features = densenet_base(inputs)
    densenet_features = GlobalAveragePooling2D()(densenet_features)

    # Feature extraction from Xception
    Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    Xception_features = Xception_base(inputs)
    Xception_features = GlobalAveragePooling2D()(Xception_features)


        # Feature extraction from Xception
    InceptionResNetV2_base = InceptionResNetV2(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    InceptionResNetV2_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    InceptionResNetV2_features = InceptionResNetV2_base(inputs)
    InceptionResNetV2_features = GlobalAveragePooling2D()(InceptionResNetV2_features)


    # Concatenate the features
    concatenated_features = Concatenate()([densenet_features, Xception_features, InceptionResNetV2_features])

    x = Dropout(dropout)(concatenated_features)
    # A fully connected layer with a tunable number of units
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)

    # Output layer
    predictions = Dense( nr_classes, activation='softmax')(x)

    # Create the final ensemble model
    model = Model(inputs=inputs, outputs=predictions)
    optimizer = Adam(learning_rate=0.0001 )
    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=['accuracy', f1_score]
    )

    return model

# %% [markdown]
# # Train and Results
# - DOES NOT WORK---EfficientNetV2, Nasnet, Resnet, VGG16,
# - DOES NOT WORK--InceptionV3--ERROR: No matching distribution found for tensorflow-directml (checked with colab)
# - DOES NOT WORK--InceptionResNetV2--slighly works
# - original models selected: DenseNet121, -mobilenet X-ception, ,-Inception
# - My models selected: 'ensemble2' (70), Basic CNN v1(91), Basic CNN v2 (92), transfer_mobilenet (85), ensembleXception
# - tuned vit models:  T2TViT(47)",---Cait (26), 16

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN() 
model = get_ensemble3_model()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 2.2975 - accuracy: 0.3039 - f1_score: 0.2559
# Epoch 1: val_f1_score improved from -inf to 0.40424, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 167s 1s/step - loss: 2.2975 - accuracy: 0.3039 - f1_score: 0.2559 - val_loss: 1.8131 - val_accuracy: 0.4585 - val_f1_score: 0.4042 - lr: 1.0000e-04
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7181 - accuracy: 0.4675 - f1_score: 0.4146
# Epoch 2: val_f1_score improved from 0.40424 to 0.47961, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 130s 1s/step - loss: 1.7181 - accuracy: 0.4675 - f1_score: 0.4146 - val_loss: 1.5325 - val_accuracy: 0.5191 - val_f1_score: 0.4796 - lr: 1.0000e-04
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5041 - accuracy: 0.5272 - f1_score: 0.4824
# Epoch 3: val_f1_score improved from 0.47961 to 0.55736, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 1.5041 - accuracy: 0.5272 - f1_score: 0.4824 - val_loss: 1.3370 - val_accuracy: 0.5963 - val_f1_score: 0.5574 - lr: 1.0000e-04
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3673 - accuracy: 0.5690 - f1_score: 0.5324
# Epoch 4: val_f1_score improved from 0.55736 to 0.60509, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 1.3673 - accuracy: 0.5690 - f1_score: 0.5324 - val_loss: 1.2688 - val_accuracy: 0.6260 - val_f1_score: 0.6051 - lr: 1.0000e-04
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2831 - accuracy: 0.5942 - f1_score: 0.5649
# Epoch 5: val_f1_score improved from 0.60509 to 0.61560, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 135s 1s/step - loss: 1.2831 - accuracy: 0.5942 - f1_score: 0.5649 - val_loss: 1.1543 - val_accuracy: 0.6457 - val_f1_score: 0.6156 - lr: 1.0000e-04
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2068 - accuracy: 0.6159 - f1_score: 0.5910
# Epoch 6: val_f1_score improved from 0.61560 to 0.63015, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 130s 1s/step - loss: 1.2068 - accuracy: 0.6159 - f1_score: 0.5910 - val_loss: 1.1135 - val_accuracy: 0.6515 - val_f1_score: 0.6301 - lr: 1.0000e-04
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1482 - accuracy: 0.6396 - f1_score: 0.6162
# Epoch 7: val_f1_score did not improve from 0.63015
# 104/104 [==============================] - 121s 1s/step - loss: 1.1482 - accuracy: 0.6396 - f1_score: 0.6162 - val_loss: 1.1030 - val_accuracy: 0.6557 - val_f1_score: 0.6300 - lr: 1.0000e-04
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0925 - accuracy: 0.6512 - f1_score: 0.6269
# Epoch 8: val_f1_score improved from 0.63015 to 0.66786, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 128s 1s/step - loss: 1.0925 - accuracy: 0.6512 - f1_score: 0.6269 - val_loss: 1.0223 - val_accuracy: 0.6874 - val_f1_score: 0.6679 - lr: 1.0000e-04
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0525 - accuracy: 0.6645 - f1_score: 0.6444
# Epoch 9: val_f1_score did not improve from 0.66786
# 104/104 [==============================] - 123s 1s/step - loss: 1.0525 - accuracy: 0.6645 - f1_score: 0.6444 - val_loss: 0.9949 - val_accuracy: 0.6893 - val_f1_score: 0.6643 - lr: 1.0000e-04
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0224 - accuracy: 0.6741 - f1_score: 0.6544
# Epoch 10: val_f1_score improved from 0.66786 to 0.67090, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 1.0224 - accuracy: 0.6741 - f1_score: 0.6544 - val_loss: 0.9551 - val_accuracy: 0.6936 - val_f1_score: 0.6709 - lr: 1.0000e-04
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0063 - accuracy: 0.6810 - f1_score: 0.6587
# Epoch 11: val_f1_score improved from 0.67090 to 0.68178, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 129s 1s/step - loss: 1.0063 - accuracy: 0.6810 - f1_score: 0.6587 - val_loss: 0.9423 - val_accuracy: 0.7102 - val_f1_score: 0.6818 - lr: 1.0000e-04
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9565 - accuracy: 0.7006 - f1_score: 0.6830
# Epoch 12: val_f1_score improved from 0.68178 to 0.71462, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 0.9565 - accuracy: 0.7006 - f1_score: 0.6830 - val_loss: 0.9070 - val_accuracy: 0.7248 - val_f1_score: 0.7146 - lr: 1.0000e-04
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9366 - accuracy: 0.6980 - f1_score: 0.6797
# Epoch 13: val_f1_score improved from 0.71462 to 0.72821, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 0.9366 - accuracy: 0.6980 - f1_score: 0.6797 - val_loss: 0.8910 - val_accuracy: 0.7383 - val_f1_score: 0.7282 - lr: 1.0000e-04
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9133 - accuracy: 0.7093 - f1_score: 0.6939
# Epoch 14: val_f1_score did not improve from 0.72821
# 104/104 [==============================] - 120s 1s/step - loss: 0.9133 - accuracy: 0.7093 - f1_score: 0.6939 - val_loss: 0.8718 - val_accuracy: 0.7321 - val_f1_score: 0.7114 - lr: 1.0000e-04
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8887 - accuracy: 0.7193 - f1_score: 0.7062
# Epoch 15: val_f1_score improved from 0.72821 to 0.72948, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 130s 1s/step - loss: 0.8887 - accuracy: 0.7193 - f1_score: 0.7062 - val_loss: 0.8563 - val_accuracy: 0.7379 - val_f1_score: 0.7295 - lr: 1.0000e-04
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.7234 - f1_score: 0.7120
# Epoch 16: val_f1_score did not improve from 0.72948
# 104/104 [==============================] - 122s 1s/step - loss: 0.8629 - accuracy: 0.7234 - f1_score: 0.7120 - val_loss: 0.8522 - val_accuracy: 0.7349 - val_f1_score: 0.7235 - lr: 1.0000e-04
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8487 - accuracy: 0.7337 - f1_score: 0.7234
# Epoch 17: val_f1_score did not improve from 0.72948
# 104/104 [==============================] - 122s 1s/step - loss: 0.8487 - accuracy: 0.7337 - f1_score: 0.7234 - val_loss: 0.8395 - val_accuracy: 0.7287 - val_f1_score: 0.7173 - lr: 1.0000e-04
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8131 - accuracy: 0.7445 - f1_score: 0.7343
# Epoch 18: val_f1_score improved from 0.72948 to 0.73222, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 130s 1s/step - loss: 0.8131 - accuracy: 0.7445 - f1_score: 0.7343 - val_loss: 0.7926 - val_accuracy: 0.7487 - val_f1_score: 0.7322 - lr: 1.0000e-04
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8116 - accuracy: 0.7400 - f1_score: 0.7276
# Epoch 19: val_f1_score improved from 0.73222 to 0.74959, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 0.8116 - accuracy: 0.7400 - f1_score: 0.7276 - val_loss: 0.7733 - val_accuracy: 0.7572 - val_f1_score: 0.7496 - lr: 1.0000e-04
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7887 - accuracy: 0.7500 - f1_score: 0.7396
# Epoch 20: val_f1_score improved from 0.74959 to 0.75162, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 133s 1s/step - loss: 0.7887 - accuracy: 0.7500 - f1_score: 0.7396 - val_loss: 0.7655 - val_accuracy: 0.7677 - val_f1_score: 0.7516 - lr: 1.0000e-04
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7753 - accuracy: 0.7494 - f1_score: 0.7410
# Epoch 21: val_f1_score did not improve from 0.75162
# 104/104 [==============================] - 117s 1s/step - loss: 0.7753 - accuracy: 0.7494 - f1_score: 0.7410 - val_loss: 0.7781 - val_accuracy: 0.7603 - val_f1_score: 0.7476 - lr: 1.0000e-04
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7514 - accuracy: 0.7598 - f1_score: 0.7504
# Epoch 22: val_f1_score improved from 0.75162 to 0.76411, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 133s 1s/step - loss: 0.7514 - accuracy: 0.7598 - f1_score: 0.7504 - val_loss: 0.7421 - val_accuracy: 0.7792 - val_f1_score: 0.7641 - lr: 1.0000e-04
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7326 - accuracy: 0.7630 - f1_score: 0.7544
# Epoch 23: val_f1_score did not improve from 0.76411
# 104/104 [==============================] - 121s 1s/step - loss: 0.7326 - accuracy: 0.7630 - f1_score: 0.7544 - val_loss: 0.7296 - val_accuracy: 0.7700 - val_f1_score: 0.7611 - lr: 1.0000e-04
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7340 - accuracy: 0.7664 - f1_score: 0.7572
# Epoch 24: val_f1_score improved from 0.76411 to 0.76891, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 128s 1s/step - loss: 0.7340 - accuracy: 0.7664 - f1_score: 0.7572 - val_loss: 0.7391 - val_accuracy: 0.7707 - val_f1_score: 0.7689 - lr: 1.0000e-04
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7210 - accuracy: 0.7668 - f1_score: 0.7583
# Epoch 25: val_f1_score improved from 0.76891 to 0.78249, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 136s 1s/step - loss: 0.7210 - accuracy: 0.7668 - f1_score: 0.7583 - val_loss: 0.6927 - val_accuracy: 0.7920 - val_f1_score: 0.7825 - lr: 1.0000e-04
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.7812 - f1_score: 0.7714
# Epoch 26: val_f1_score did not improve from 0.78249
# 104/104 [==============================] - 117s 1s/step - loss: 0.6953 - accuracy: 0.7812 - f1_score: 0.7714 - val_loss: 0.7006 - val_accuracy: 0.7835 - val_f1_score: 0.7777 - lr: 1.0000e-04
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6836 - accuracy: 0.7828 - f1_score: 0.7755
# Epoch 27: val_f1_score improved from 0.78249 to 0.79509, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 138s 1s/step - loss: 0.6836 - accuracy: 0.7828 - f1_score: 0.7755 - val_loss: 0.6690 - val_accuracy: 0.7993 - val_f1_score: 0.7951 - lr: 1.0000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6763 - accuracy: 0.7871 - f1_score: 0.7810
# Epoch 28: val_f1_score did not improve from 0.79509
# 104/104 [==============================] - 120s 1s/step - loss: 0.6763 - accuracy: 0.7871 - f1_score: 0.7810 - val_loss: 0.6738 - val_accuracy: 0.7943 - val_f1_score: 0.7869 - lr: 1.0000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6595 - accuracy: 0.7859 - f1_score: 0.7773
# Epoch 29: val_f1_score did not improve from 0.79509
# 104/104 [==============================] - 117s 1s/step - loss: 0.6595 - accuracy: 0.7859 - f1_score: 0.7773 - val_loss: 0.6756 - val_accuracy: 0.7966 - val_f1_score: 0.7844 - lr: 1.0000e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6484 - accuracy: 0.7938 - f1_score: 0.7872
# Epoch 30: val_f1_score did not improve from 0.79509
# 104/104 [==============================] - 120s 1s/step - loss: 0.6484 - accuracy: 0.7938 - f1_score: 0.7872 - val_loss: 0.6687 - val_accuracy: 0.7985 - val_f1_score: 0.7942 - lr: 1.0000e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6486 - accuracy: 0.7932 - f1_score: 0.7877
# Epoch 31: val_f1_score did not improve from 0.79509
# 104/104 [==============================] - 124s 1s/step - loss: 0.6486 - accuracy: 0.7932 - f1_score: 0.7877 - val_loss: 0.6601 - val_accuracy: 0.7900 - val_f1_score: 0.7824 - lr: 1.0000e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.7939 - f1_score: 0.7896
# Epoch 32: val_f1_score improved from 0.79509 to 0.79729, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 134s 1s/step - loss: 0.6411 - accuracy: 0.7939 - f1_score: 0.7896 - val_loss: 0.6200 - val_accuracy: 0.8039 - val_f1_score: 0.7973 - lr: 1.0000e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.8023 - f1_score: 0.7949
# Epoch 33: val_f1_score did not improve from 0.79729
# 104/104 [==============================] - 118s 1s/step - loss: 0.6198 - accuracy: 0.8023 - f1_score: 0.7949 - val_loss: 0.6306 - val_accuracy: 0.8016 - val_f1_score: 0.7957 - lr: 1.0000e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.8030 - f1_score: 0.7962
# Epoch 34: val_f1_score did not improve from 0.79729
# 104/104 [==============================] - 115s 1s/step - loss: 0.6223 - accuracy: 0.8030 - f1_score: 0.7962 - val_loss: 0.6512 - val_accuracy: 0.7935 - val_f1_score: 0.7826 - lr: 1.0000e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6099 - accuracy: 0.8029 - f1_score: 0.7979
# Epoch 35: val_f1_score improved from 0.79729 to 0.79928, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 123s 1s/step - loss: 0.6099 - accuracy: 0.8029 - f1_score: 0.7979 - val_loss: 0.6238 - val_accuracy: 0.8090 - val_f1_score: 0.7993 - lr: 1.0000e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.8142 - f1_score: 0.8089
# Epoch 36: val_f1_score improved from 0.79928 to 0.80472, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 128s 1s/step - loss: 0.5891 - accuracy: 0.8142 - f1_score: 0.8089 - val_loss: 0.5993 - val_accuracy: 0.8101 - val_f1_score: 0.8047 - lr: 1.0000e-04
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.8128 - f1_score: 0.8095
# Epoch 37: val_f1_score did not improve from 0.80472
# 104/104 [==============================] - 113s 1s/step - loss: 0.5848 - accuracy: 0.8128 - f1_score: 0.8095 - val_loss: 0.6175 - val_accuracy: 0.8078 - val_f1_score: 0.8032 - lr: 1.0000e-04
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.8178 - f1_score: 0.8110
# Epoch 38: val_f1_score improved from 0.80472 to 0.81691, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 133s 1s/step - loss: 0.5819 - accuracy: 0.8178 - f1_score: 0.8110 - val_loss: 0.5905 - val_accuracy: 0.8232 - val_f1_score: 0.8169 - lr: 1.0000e-04
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5718 - accuracy: 0.8195 - f1_score: 0.8124
# Epoch 39: val_f1_score did not improve from 0.81691
# 104/104 [==============================] - 118s 1s/step - loss: 0.5718 - accuracy: 0.8195 - f1_score: 0.8124 - val_loss: 0.6026 - val_accuracy: 0.8086 - val_f1_score: 0.8024 - lr: 1.0000e-04
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.8191 - f1_score: 0.8136
# Epoch 40: val_f1_score improved from 0.81691 to 0.82172, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 126s 1s/step - loss: 0.5616 - accuracy: 0.8191 - f1_score: 0.8136 - val_loss: 0.5919 - val_accuracy: 0.8221 - val_f1_score: 0.8217 - lr: 1.0000e-04
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5611 - accuracy: 0.8224 - f1_score: 0.8175
# Epoch 41: val_f1_score did not improve from 0.82172
# 104/104 [==============================] - 117s 1s/step - loss: 0.5611 - accuracy: 0.8224 - f1_score: 0.8175 - val_loss: 0.5955 - val_accuracy: 0.8097 - val_f1_score: 0.8066 - lr: 1.0000e-04
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5404 - accuracy: 0.8264 - f1_score: 0.8191
# Epoch 42: val_f1_score improved from 0.82172 to 0.82741, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 0.5404 - accuracy: 0.8264 - f1_score: 0.8191 - val_loss: 0.5726 - val_accuracy: 0.8283 - val_f1_score: 0.8274 - lr: 1.0000e-04
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5354 - accuracy: 0.8276 - f1_score: 0.8220
# Epoch 43: val_f1_score did not improve from 0.82741
# 104/104 [==============================] - 117s 1s/step - loss: 0.5354 - accuracy: 0.8276 - f1_score: 0.8220 - val_loss: 0.5912 - val_accuracy: 0.8124 - val_f1_score: 0.8058 - lr: 1.0000e-04
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5240 - accuracy: 0.8327 - f1_score: 0.8269
# Epoch 44: val_f1_score did not improve from 0.82741
# 104/104 [==============================] - 122s 1s/step - loss: 0.5240 - accuracy: 0.8327 - f1_score: 0.8269 - val_loss: 0.5598 - val_accuracy: 0.8275 - val_f1_score: 0.8251 - lr: 1.0000e-04
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5122 - accuracy: 0.8375 - f1_score: 0.8287
# Epoch 45: val_f1_score did not improve from 0.82741
# 104/104 [==============================] - 116s 1s/step - loss: 0.5122 - accuracy: 0.8375 - f1_score: 0.8287 - val_loss: 0.5666 - val_accuracy: 0.8167 - val_f1_score: 0.8149 - lr: 1.0000e-04
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5139 - accuracy: 0.8388 - f1_score: 0.8364
# Epoch 46: val_f1_score improved from 0.82741 to 0.82789, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 124s 1s/step - loss: 0.5139 - accuracy: 0.8388 - f1_score: 0.8364 - val_loss: 0.5633 - val_accuracy: 0.8317 - val_f1_score: 0.8279 - lr: 1.0000e-04
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5031 - accuracy: 0.8425 - f1_score: 0.8390
# Epoch 47: val_f1_score improved from 0.82789 to 0.83795, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 0.5031 - accuracy: 0.8425 - f1_score: 0.8390 - val_loss: 0.5354 - val_accuracy: 0.8433 - val_f1_score: 0.8380 - lr: 1.0000e-04
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.8387 - f1_score: 0.8346
# Epoch 48: val_f1_score did not improve from 0.83795
# 104/104 [==============================] - 117s 1s/step - loss: 0.4922 - accuracy: 0.8387 - f1_score: 0.8346 - val_loss: 0.5370 - val_accuracy: 0.8325 - val_f1_score: 0.8301 - lr: 1.0000e-04
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.8402 - f1_score: 0.8359
# Epoch 49: val_f1_score did not improve from 0.83795
# 104/104 [==============================] - 116s 1s/step - loss: 0.4958 - accuracy: 0.8402 - f1_score: 0.8359 - val_loss: 0.5420 - val_accuracy: 0.8383 - val_f1_score: 0.8275 - lr: 1.0000e-04
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.8468 - f1_score: 0.8441
# Epoch 50: val_f1_score did not improve from 0.83795
# 104/104 [==============================] - 117s 1s/step - loss: 0.4810 - accuracy: 0.8468 - f1_score: 0.8441 - val_loss: 0.5397 - val_accuracy: 0.8356 - val_f1_score: 0.8350 - lr: 1.0000e-04
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.8452 - f1_score: 0.8426
# Epoch 51: val_f1_score did not improve from 0.83795
# 104/104 [==============================] - 117s 1s/step - loss: 0.4805 - accuracy: 0.8452 - f1_score: 0.8426 - val_loss: 0.5563 - val_accuracy: 0.8209 - val_f1_score: 0.8127 - lr: 1.0000e-04
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8504 - f1_score: 0.8468
# Epoch 52: val_f1_score did not improve from 0.83795
# 104/104 [==============================] - 122s 1s/step - loss: 0.4726 - accuracy: 0.8504 - f1_score: 0.8468 - val_loss: 0.5257 - val_accuracy: 0.8364 - val_f1_score: 0.8329 - lr: 1.0000e-04
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.8545 - f1_score: 0.8481
# Epoch 53: val_f1_score did not improve from 0.83795
# 104/104 [==============================] - 117s 1s/step - loss: 0.4676 - accuracy: 0.8545 - f1_score: 0.8481 - val_loss: 0.5270 - val_accuracy: 0.8379 - val_f1_score: 0.8352 - lr: 1.0000e-04
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4546 - accuracy: 0.8576 - f1_score: 0.8535
# Epoch 54: val_f1_score improved from 0.83795 to 0.84525, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 0.4546 - accuracy: 0.8576 - f1_score: 0.8535 - val_loss: 0.4928 - val_accuracy: 0.8499 - val_f1_score: 0.8452 - lr: 1.0000e-04
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.8549 - f1_score: 0.8532
# Epoch 55: val_f1_score did not improve from 0.84525
# 104/104 [==============================] - 116s 1s/step - loss: 0.4543 - accuracy: 0.8549 - f1_score: 0.8532 - val_loss: 0.5239 - val_accuracy: 0.8425 - val_f1_score: 0.8442 - lr: 1.0000e-04
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.8549 - f1_score: 0.8501
# Epoch 56: val_f1_score did not improve from 0.84525
# 104/104 [==============================] - 117s 1s/step - loss: 0.4490 - accuracy: 0.8549 - f1_score: 0.8501 - val_loss: 0.5188 - val_accuracy: 0.8387 - val_f1_score: 0.8364 - lr: 1.0000e-04
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4537 - accuracy: 0.8548 - f1_score: 0.8517
# Epoch 57: val_f1_score did not improve from 0.84525
# 104/104 [==============================] - 115s 1s/step - loss: 0.4537 - accuracy: 0.8548 - f1_score: 0.8517 - val_loss: 0.5146 - val_accuracy: 0.8383 - val_f1_score: 0.8300 - lr: 1.0000e-04
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4494 - accuracy: 0.8550 - f1_score: 0.8513
# Epoch 58: val_f1_score did not improve from 0.84525
# 104/104 [==============================] - 113s 1s/step - loss: 0.4494 - accuracy: 0.8550 - f1_score: 0.8513 - val_loss: 0.5046 - val_accuracy: 0.8483 - val_f1_score: 0.8418 - lr: 1.0000e-04
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4335 - accuracy: 0.8612 - f1_score: 0.8556
# Epoch 59: val_f1_score did not improve from 0.84525
# 104/104 [==============================] - 122s 1s/step - loss: 0.4335 - accuracy: 0.8612 - f1_score: 0.8556 - val_loss: 0.4820 - val_accuracy: 0.8433 - val_f1_score: 0.8426 - lr: 1.0000e-04
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.8654 - f1_score: 0.8630
# Epoch 60: val_f1_score improved from 0.84525 to 0.84548, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 125s 1s/step - loss: 0.4223 - accuracy: 0.8654 - f1_score: 0.8630 - val_loss: 0.4881 - val_accuracy: 0.8495 - val_f1_score: 0.8455 - lr: 1.0000e-04
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4273 - accuracy: 0.8648 - f1_score: 0.8622
# Epoch 61: val_f1_score improved from 0.84548 to 0.85486, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 133s 1s/step - loss: 0.4273 - accuracy: 0.8648 - f1_score: 0.8622 - val_loss: 0.4739 - val_accuracy: 0.8568 - val_f1_score: 0.8549 - lr: 1.0000e-04
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8685 - f1_score: 0.8683
# Epoch 62: val_f1_score did not improve from 0.85486
# 104/104 [==============================] - 116s 1s/step - loss: 0.4154 - accuracy: 0.8685 - f1_score: 0.8683 - val_loss: 0.4982 - val_accuracy: 0.8452 - val_f1_score: 0.8428 - lr: 1.0000e-04
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8637 - f1_score: 0.8627
# Epoch 63: val_f1_score improved from 0.85486 to 0.85548, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 0.4246 - accuracy: 0.8637 - f1_score: 0.8627 - val_loss: 0.4687 - val_accuracy: 0.8595 - val_f1_score: 0.8555 - lr: 1.0000e-04
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8672 - f1_score: 0.8638
# Epoch 64: val_f1_score improved from 0.85548 to 0.85781, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 130s 1s/step - loss: 0.4160 - accuracy: 0.8672 - f1_score: 0.8638 - val_loss: 0.4673 - val_accuracy: 0.8618 - val_f1_score: 0.8578 - lr: 1.0000e-04
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3935 - accuracy: 0.8753 - f1_score: 0.8721
# Epoch 65: val_f1_score did not improve from 0.85781
# 104/104 [==============================] - 117s 1s/step - loss: 0.3935 - accuracy: 0.8753 - f1_score: 0.8721 - val_loss: 0.4745 - val_accuracy: 0.8549 - val_f1_score: 0.8519 - lr: 1.0000e-04
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4017 - accuracy: 0.8719 - f1_score: 0.8679
# Epoch 66: val_f1_score did not improve from 0.85781
# 104/104 [==============================] - 116s 1s/step - loss: 0.4017 - accuracy: 0.8719 - f1_score: 0.8679 - val_loss: 0.4675 - val_accuracy: 0.8599 - val_f1_score: 0.8534 - lr: 1.0000e-04
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3996 - accuracy: 0.8676 - f1_score: 0.8645
# Epoch 67: val_f1_score improved from 0.85781 to 0.85876, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 0.3996 - accuracy: 0.8676 - f1_score: 0.8645 - val_loss: 0.4554 - val_accuracy: 0.8607 - val_f1_score: 0.8588 - lr: 1.0000e-04
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3995 - accuracy: 0.8698 - f1_score: 0.8668
# Epoch 68: val_f1_score improved from 0.85876 to 0.86256, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 0.3995 - accuracy: 0.8698 - f1_score: 0.8668 - val_loss: 0.4420 - val_accuracy: 0.8657 - val_f1_score: 0.8626 - lr: 1.0000e-04
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3853 - accuracy: 0.8760 - f1_score: 0.8762
# Epoch 69: val_f1_score did not improve from 0.86256
# 104/104 [==============================] - 116s 1s/step - loss: 0.3853 - accuracy: 0.8760 - f1_score: 0.8762 - val_loss: 0.4593 - val_accuracy: 0.8533 - val_f1_score: 0.8520 - lr: 1.0000e-04
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.8742 - f1_score: 0.8711
# Epoch 70: val_f1_score did not improve from 0.86256
# 104/104 [==============================] - 114s 1s/step - loss: 0.3836 - accuracy: 0.8742 - f1_score: 0.8711 - val_loss: 0.4566 - val_accuracy: 0.8584 - val_f1_score: 0.8599 - lr: 1.0000e-04
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8757 - f1_score: 0.8725
# Epoch 71: val_f1_score improved from 0.86256 to 0.87422, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 132s 1s/step - loss: 0.3882 - accuracy: 0.8757 - f1_score: 0.8725 - val_loss: 0.4388 - val_accuracy: 0.8761 - val_f1_score: 0.8742 - lr: 1.0000e-04
# Epoch 72/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3798 - accuracy: 0.8797 - f1_score: 0.8760
# Epoch 72: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 124s 1s/step - loss: 0.3798 - accuracy: 0.8797 - f1_score: 0.8760 - val_loss: 0.4382 - val_accuracy: 0.8661 - val_f1_score: 0.8665 - lr: 1.0000e-04
# Epoch 73/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3713 - accuracy: 0.8796 - f1_score: 0.8775
# Epoch 73: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 117s 1s/step - loss: 0.3713 - accuracy: 0.8796 - f1_score: 0.8775 - val_loss: 0.4516 - val_accuracy: 0.8553 - val_f1_score: 0.8534 - lr: 1.0000e-04
# Epoch 74/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3601 - accuracy: 0.8834 - f1_score: 0.8832
# Epoch 74: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 117s 1s/step - loss: 0.3601 - accuracy: 0.8834 - f1_score: 0.8832 - val_loss: 0.4397 - val_accuracy: 0.8657 - val_f1_score: 0.8646 - lr: 1.0000e-04
# Epoch 75/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8842 - f1_score: 0.8799
# Epoch 75: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 117s 1s/step - loss: 0.3688 - accuracy: 0.8842 - f1_score: 0.8799 - val_loss: 0.4500 - val_accuracy: 0.8618 - val_f1_score: 0.8607 - lr: 1.0000e-04
# Epoch 76/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3664 - accuracy: 0.8837 - f1_score: 0.8800
# Epoch 76: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 125s 1s/step - loss: 0.3664 - accuracy: 0.8837 - f1_score: 0.8800 - val_loss: 0.4198 - val_accuracy: 0.8672 - val_f1_score: 0.8637 - lr: 1.0000e-04
# Epoch 77/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8877 - f1_score: 0.8859
# Epoch 77: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 117s 1s/step - loss: 0.3488 - accuracy: 0.8877 - f1_score: 0.8859 - val_loss: 0.4211 - val_accuracy: 0.8719 - val_f1_score: 0.8696 - lr: 1.0000e-04
# Epoch 78/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.8904 - f1_score: 0.8885
# Epoch 78: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 115s 1s/step - loss: 0.3424 - accuracy: 0.8904 - f1_score: 0.8885 - val_loss: 0.4425 - val_accuracy: 0.8665 - val_f1_score: 0.8607 - lr: 1.0000e-04
# Epoch 79/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8878 - f1_score: 0.8840
# Epoch 79: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 118s 1s/step - loss: 0.3478 - accuracy: 0.8878 - f1_score: 0.8840 - val_loss: 0.4328 - val_accuracy: 0.8684 - val_f1_score: 0.8656 - lr: 1.0000e-04
# Epoch 80/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3362 - accuracy: 0.8912 - f1_score: 0.8897
# Epoch 80: val_f1_score did not improve from 0.87422
# 104/104 [==============================] - 117s 1s/step - loss: 0.3362 - accuracy: 0.8912 - f1_score: 0.8897 - val_loss: 0.4340 - val_accuracy: 0.8626 - val_f1_score: 0.8597 - lr: 1.0000e-04
# Epoch 81/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3426 - accuracy: 0.8907 - f1_score: 0.8883
# Epoch 81: val_f1_score did not improve from 0.87422
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 104/104 [==============================] - 116s 1s/step - loss: 0.3426 - accuracy: 0.8907 - f1_score: 0.8883 - val_loss: 0.4465 - val_accuracy: 0.8638 - val_f1_score: 0.8606 - lr: 1.0000e-04
# Epoch 82/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.8953 - f1_score: 0.8945
# Epoch 82: val_f1_score improved from 0.87422 to 0.87871, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 134s 1s/step - loss: 0.3285 - accuracy: 0.8953 - f1_score: 0.8945 - val_loss: 0.3987 - val_accuracy: 0.8800 - val_f1_score: 0.8787 - lr: 5.0000e-05
# Epoch 83/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9051 - f1_score: 0.9042
# Epoch 83: val_f1_score did not improve from 0.87871
# 104/104 [==============================] - 117s 1s/step - loss: 0.3069 - accuracy: 0.9051 - f1_score: 0.9042 - val_loss: 0.3991 - val_accuracy: 0.8777 - val_f1_score: 0.8749 - lr: 5.0000e-05
# Epoch 84/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.8988 - f1_score: 0.8972
# Epoch 84: val_f1_score did not improve from 0.87871
# 104/104 [==============================] - 116s 1s/step - loss: 0.3251 - accuracy: 0.8988 - f1_score: 0.8972 - val_loss: 0.4030 - val_accuracy: 0.8726 - val_f1_score: 0.8701 - lr: 5.0000e-05
# Epoch 85/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9042 - f1_score: 0.9019
# Epoch 85: val_f1_score did not improve from 0.87871
# 104/104 [==============================] - 124s 1s/step - loss: 0.3069 - accuracy: 0.9042 - f1_score: 0.9019 - val_loss: 0.3812 - val_accuracy: 0.8796 - val_f1_score: 0.8782 - lr: 5.0000e-05
# Epoch 86/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.9011 - f1_score: 0.8986
# Epoch 86: val_f1_score did not improve from 0.87871
# 104/104 [==============================] - 118s 1s/step - loss: 0.3040 - accuracy: 0.9011 - f1_score: 0.8986 - val_loss: 0.3994 - val_accuracy: 0.8796 - val_f1_score: 0.8770 - lr: 5.0000e-05
# Epoch 87/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.9044 - f1_score: 0.9011
# Epoch 87: val_f1_score improved from 0.87871 to 0.88814, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 133s 1s/step - loss: 0.3099 - accuracy: 0.9044 - f1_score: 0.9011 - val_loss: 0.3709 - val_accuracy: 0.8896 - val_f1_score: 0.8881 - lr: 5.0000e-05
# Epoch 88/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.9050 - f1_score: 0.9024
# Epoch 88: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 117s 1s/step - loss: 0.3056 - accuracy: 0.9050 - f1_score: 0.9024 - val_loss: 0.3840 - val_accuracy: 0.8846 - val_f1_score: 0.8786 - lr: 5.0000e-05
# Epoch 89/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2942 - accuracy: 0.9051 - f1_score: 0.9018
# Epoch 89: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 117s 1s/step - loss: 0.2942 - accuracy: 0.9051 - f1_score: 0.9018 - val_loss: 0.3728 - val_accuracy: 0.8873 - val_f1_score: 0.8824 - lr: 5.0000e-05
# Epoch 90/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.9061 - f1_score: 0.9047
# Epoch 90: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 115s 1s/step - loss: 0.3020 - accuracy: 0.9061 - f1_score: 0.9047 - val_loss: 0.3962 - val_accuracy: 0.8711 - val_f1_score: 0.8734 - lr: 5.0000e-05
# Epoch 91/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.9056 - f1_score: 0.9031
# Epoch 91: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 117s 1s/step - loss: 0.2955 - accuracy: 0.9056 - f1_score: 0.9031 - val_loss: 0.3843 - val_accuracy: 0.8892 - val_f1_score: 0.8859 - lr: 5.0000e-05
# Epoch 92/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.9067 - f1_score: 0.9060
# Epoch 92: val_f1_score did not improve from 0.88814
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 104/104 [==============================] - 118s 1s/step - loss: 0.2964 - accuracy: 0.9067 - f1_score: 0.9060 - val_loss: 0.3716 - val_accuracy: 0.8854 - val_f1_score: 0.8845 - lr: 5.0000e-05
# Epoch 93/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2857 - accuracy: 0.9143 - f1_score: 0.9133
# Epoch 93: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 118s 1s/step - loss: 0.2857 - accuracy: 0.9143 - f1_score: 0.9133 - val_loss: 0.3800 - val_accuracy: 0.8861 - val_f1_score: 0.8875 - lr: 2.5000e-05
# Epoch 94/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.9107 - f1_score: 0.9103
# Epoch 94: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 122s 1s/step - loss: 0.2889 - accuracy: 0.9107 - f1_score: 0.9103 - val_loss: 0.3697 - val_accuracy: 0.8831 - val_f1_score: 0.8804 - lr: 2.5000e-05
# Epoch 95/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.9084 - f1_score: 0.9088
# Epoch 95: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 114s 1s/step - loss: 0.2906 - accuracy: 0.9084 - f1_score: 0.9088 - val_loss: 0.3840 - val_accuracy: 0.8780 - val_f1_score: 0.8738 - lr: 2.5000e-05
# Epoch 96/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9127 - f1_score: 0.9115
# Epoch 96: val_f1_score did not improve from 0.88814
# 104/104 [==============================] - 124s 1s/step - loss: 0.2826 - accuracy: 0.9127 - f1_score: 0.9115 - val_loss: 0.3540 - val_accuracy: 0.8846 - val_f1_score: 0.8824 - lr: 2.5000e-05
# Epoch 97/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.9098 - f1_score: 0.9115
# Epoch 97: val_f1_score improved from 0.88814 to 0.89444, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 136s 1s/step - loss: 0.2869 - accuracy: 0.9098 - f1_score: 0.9115 - val_loss: 0.3532 - val_accuracy: 0.8954 - val_f1_score: 0.8944 - lr: 2.5000e-05
# Epoch 98/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2794 - accuracy: 0.9111 - f1_score: 0.9094
# Epoch 98: val_f1_score did not improve from 0.89444
# 104/104 [==============================] - 118s 1s/step - loss: 0.2794 - accuracy: 0.9111 - f1_score: 0.9094 - val_loss: 0.3787 - val_accuracy: 0.8842 - val_f1_score: 0.8805 - lr: 2.5000e-05
# Epoch 99/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.9108 - f1_score: 0.9132
# Epoch 99: val_f1_score did not improve from 0.89444
# 104/104 [==============================] - 118s 1s/step - loss: 0.2899 - accuracy: 0.9108 - f1_score: 0.9132 - val_loss: 0.3670 - val_accuracy: 0.8892 - val_f1_score: 0.8880 - lr: 2.5000e-05
# Epoch 100/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.9130 - f1_score: 0.9124
# Epoch 100: val_f1_score did not improve from 0.89444
# 104/104 [==============================] - 117s 1s/step - loss: 0.2743 - accuracy: 0.9130 - f1_score: 0.9124 - val_loss: 0.3644 - val_accuracy: 0.8885 - val_f1_score: 0.8868 - lr: 2.5000e-05
# Epoch 101/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.9162 - f1_score: 0.9161
# Epoch 101: val_f1_score did not improve from 0.89444
# 104/104 [==============================] - 119s 1s/step - loss: 0.2713 - accuracy: 0.9162 - f1_score: 0.9161 - val_loss: 0.3654 - val_accuracy: 0.8846 - val_f1_score: 0.8823 - lr: 2.5000e-05
# Epoch 102/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9134 - f1_score: 0.9111
# Epoch 102: val_f1_score did not improve from 0.89444
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 104/104 [==============================] - 118s 1s/step - loss: 0.2700 - accuracy: 0.9134 - f1_score: 0.9111 - val_loss: 0.3954 - val_accuracy: 0.8819 - val_f1_score: 0.8778 - lr: 2.5000e-05
# Epoch 103/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9145 - f1_score: 0.9111
# Epoch 103: val_f1_score did not improve from 0.89444
# 104/104 [==============================] - 115s 1s/step - loss: 0.2706 - accuracy: 0.9145 - f1_score: 0.9111 - val_loss: 0.3736 - val_accuracy: 0.8861 - val_f1_score: 0.8873 - lr: 1.2500e-05
# Epoch 104/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.9186 - f1_score: 0.9150
# Epoch 104: val_f1_score did not improve from 0.89444
# 104/104 [==============================] - 118s 1s/step - loss: 0.2674 - accuracy: 0.9186 - f1_score: 0.9150 - val_loss: 0.3625 - val_accuracy: 0.8831 - val_f1_score: 0.8807 - lr: 1.2500e-05
# Epoch 105/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9142 - f1_score: 0.9126
# Epoch 105: val_f1_score improved from 0.89444 to 0.89455, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 126s 1s/step - loss: 0.2693 - accuracy: 0.9142 - f1_score: 0.9126 - val_loss: 0.3620 - val_accuracy: 0.8958 - val_f1_score: 0.8946 - lr: 1.2500e-05
# Epoch 106/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.9171 - f1_score: 0.9163
# Epoch 106: val_f1_score did not improve from 0.89455
# 104/104 [==============================] - 115s 1s/step - loss: 0.2692 - accuracy: 0.9171 - f1_score: 0.9163 - val_loss: 0.3561 - val_accuracy: 0.8939 - val_f1_score: 0.8937 - lr: 1.2500e-05
# Epoch 107/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9146 - f1_score: 0.9123
# Epoch 107: val_f1_score did not improve from 0.89455
#
# Epoch 107: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 104/104 [==============================] - 116s 1s/step - loss: 0.2693 - accuracy: 0.9146 - f1_score: 0.9123 - val_loss: 0.3725 - val_accuracy: 0.8861 - val_f1_score: 0.8883 - lr: 1.2500e-05
# Epoch 108/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9173 - f1_score: 0.9165
# Epoch 108: val_f1_score did not improve from 0.89455
# 104/104 [==============================] - 122s 1s/step - loss: 0.2646 - accuracy: 0.9173 - f1_score: 0.9165 - val_loss: 0.3507 - val_accuracy: 0.8912 - val_f1_score: 0.8905 - lr: 6.2500e-06
# Epoch 109/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9165 - f1_score: 0.9161
# Epoch 109: val_f1_score did not improve from 0.89455
# 104/104 [==============================] - 122s 1s/step - loss: 0.2646 - accuracy: 0.9165 - f1_score: 0.9161 - val_loss: 0.3490 - val_accuracy: 0.8973 - val_f1_score: 0.8937 - lr: 6.2500e-06
# Epoch 110/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9178 - f1_score: 0.9165
# Epoch 110: val_f1_score did not improve from 0.89455
# 104/104 [==============================] - 123s 1s/step - loss: 0.2663 - accuracy: 0.9178 - f1_score: 0.9165 - val_loss: 0.3437 - val_accuracy: 0.8939 - val_f1_score: 0.8912 - lr: 6.2500e-06
# Epoch 111/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2590 - accuracy: 0.9170 - f1_score: 0.9158
# Epoch 111: val_f1_score did not improve from 0.89455
# 104/104 [==============================] - 114s 1s/step - loss: 0.2590 - accuracy: 0.9170 - f1_score: 0.9158 - val_loss: 0.3609 - val_accuracy: 0.8885 - val_f1_score: 0.8900 - lr: 6.2500e-06
# Epoch 112/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.9183 - f1_score: 0.9178
# Epoch 112: val_f1_score improved from 0.89455 to 0.90037, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 131s 1s/step - loss: 0.2607 - accuracy: 0.9183 - f1_score: 0.9178 - val_loss: 0.3392 - val_accuracy: 0.9016 - val_f1_score: 0.9004 - lr: 6.2500e-06
# Epoch 113/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9133 - f1_score: 0.9120
# Epoch 113: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 117s 1s/step - loss: 0.2693 - accuracy: 0.9133 - f1_score: 0.9120 - val_loss: 0.3510 - val_accuracy: 0.8892 - val_f1_score: 0.8883 - lr: 6.2500e-06
# Epoch 114/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.9127 - f1_score: 0.9119
# Epoch 114: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 116s 1s/step - loss: 0.2660 - accuracy: 0.9127 - f1_score: 0.9119 - val_loss: 0.3526 - val_accuracy: 0.8869 - val_f1_score: 0.8869 - lr: 6.2500e-06
# Epoch 115/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.9174 - f1_score: 0.9153
# Epoch 115: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 117s 1s/step - loss: 0.2629 - accuracy: 0.9174 - f1_score: 0.9153 - val_loss: 0.3404 - val_accuracy: 0.8981 - val_f1_score: 0.8962 - lr: 6.2500e-06
# Epoch 116/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2649 - accuracy: 0.9160 - f1_score: 0.9150
# Epoch 116: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 117s 1s/step - loss: 0.2649 - accuracy: 0.9160 - f1_score: 0.9150 - val_loss: 0.3614 - val_accuracy: 0.8873 - val_f1_score: 0.8835 - lr: 6.2500e-06
# Epoch 117/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2675 - accuracy: 0.9128 - f1_score: 0.9104
# Epoch 117: val_f1_score did not improve from 0.90037
#
# Epoch 117: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 104/104 [==============================] - 116s 1s/step - loss: 0.2675 - accuracy: 0.9128 - f1_score: 0.9104 - val_loss: 0.3653 - val_accuracy: 0.8896 - val_f1_score: 0.8872 - lr: 6.2500e-06
# Epoch 118/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9217 - f1_score: 0.9207
# Epoch 118: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 115s 1s/step - loss: 0.2622 - accuracy: 0.9217 - f1_score: 0.9207 - val_loss: 0.3515 - val_accuracy: 0.8908 - val_f1_score: 0.8880 - lr: 3.1250e-06
# Epoch 119/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2702 - accuracy: 0.9143 - f1_score: 0.9122
# Epoch 119: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 115s 1s/step - loss: 0.2702 - accuracy: 0.9143 - f1_score: 0.9122 - val_loss: 0.3444 - val_accuracy: 0.8946 - val_f1_score: 0.8918 - lr: 3.1250e-06
# Epoch 120/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9134 - f1_score: 0.9122
# Epoch 120: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 116s 1s/step - loss: 0.2661 - accuracy: 0.9134 - f1_score: 0.9122 - val_loss: 0.3694 - val_accuracy: 0.8846 - val_f1_score: 0.8828 - lr: 3.1250e-06
# Epoch 121/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9163 - f1_score: 0.9161
# Epoch 121: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 116s 1s/step - loss: 0.2664 - accuracy: 0.9163 - f1_score: 0.9161 - val_loss: 0.3419 - val_accuracy: 0.8977 - val_f1_score: 0.8933 - lr: 3.1250e-06
# Epoch 122/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9175 - f1_score: 0.9165
# Epoch 122: val_f1_score did not improve from 0.90037
#
# Epoch 122: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 104/104 [==============================] - 116s 1s/step - loss: 0.2641 - accuracy: 0.9175 - f1_score: 0.9165 - val_loss: 0.3473 - val_accuracy: 0.8966 - val_f1_score: 0.8986 - lr: 3.1250e-06
# Epoch 123/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9169 - f1_score: 0.9154
# Epoch 123: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 117s 1s/step - loss: 0.2628 - accuracy: 0.9169 - f1_score: 0.9154 - val_loss: 0.3491 - val_accuracy: 0.8950 - val_f1_score: 0.8950 - lr: 1.5625e-06
# Epoch 124/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.9179 - f1_score: 0.9164
# Epoch 124: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 116s 1s/step - loss: 0.2604 - accuracy: 0.9179 - f1_score: 0.9164 - val_loss: 0.3612 - val_accuracy: 0.8958 - val_f1_score: 0.8935 - lr: 1.5625e-06
# Epoch 125/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9185 - f1_score: 0.9161
# Epoch 125: val_f1_score did not improve from 0.90037
# 104/104 [==============================] - 117s 1s/step - loss: 0.2597 - accuracy: 0.9185 - f1_score: 0.9161 - val_loss: 0.3517 - val_accuracy: 0.8923 - val_f1_score: 0.8912 - lr: 1.5625e-06
# Epoch 126/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.9178 - f1_score: 0.9182
# Epoch 126: val_f1_score improved from 0.90037 to 0.90196, saving model to saved_outputs_all_augment\Ensemble3\saved_models\best_Ensemble3.h5
# 104/104 [==============================] - 133s 1s/step - loss: 0.2646 - accuracy: 0.9178 - f1_score: 0.9182 - val_loss: 0.3373 - val_accuracy: 0.9031 - val_f1_score: 0.9020 - lr: 1.5625e-06
# Epoch 127/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.9201 - f1_score: 0.9186
# Epoch 127: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 117s 1s/step - loss: 0.2529 - accuracy: 0.9201 - f1_score: 0.9186 - val_loss: 0.3411 - val_accuracy: 0.8927 - val_f1_score: 0.8914 - lr: 1.5625e-06
# Epoch 128/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.9159 - f1_score: 0.9140
# Epoch 128: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 112s 1s/step - loss: 0.2643 - accuracy: 0.9159 - f1_score: 0.9140 - val_loss: 0.3588 - val_accuracy: 0.8892 - val_f1_score: 0.8870 - lr: 1.5625e-06
# Epoch 129/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2582 - accuracy: 0.9187 - f1_score: 0.9171
# Epoch 129: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 115s 1s/step - loss: 0.2582 - accuracy: 0.9187 - f1_score: 0.9171 - val_loss: 0.3449 - val_accuracy: 0.8923 - val_f1_score: 0.8881 - lr: 1.5625e-06
# Epoch 130/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2555 - accuracy: 0.9219 - f1_score: 0.9224
# Epoch 130: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 117s 1s/step - loss: 0.2555 - accuracy: 0.9219 - f1_score: 0.9224 - val_loss: 0.3491 - val_accuracy: 0.8900 - val_f1_score: 0.8896 - lr: 1.5625e-06
# Epoch 131/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9195 - f1_score: 0.9191
# Epoch 131: val_f1_score did not improve from 0.90196
#
# Epoch 131: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 104/104 [==============================] - 115s 1s/step - loss: 0.2614 - accuracy: 0.9195 - f1_score: 0.9191 - val_loss: 0.3684 - val_accuracy: 0.8827 - val_f1_score: 0.8811 - lr: 1.5625e-06
# Epoch 132/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.9130 - f1_score: 0.9107
# Epoch 132: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 113s 1s/step - loss: 0.2680 - accuracy: 0.9130 - f1_score: 0.9107 - val_loss: 0.3565 - val_accuracy: 0.8904 - val_f1_score: 0.8888 - lr: 7.8125e-07
# Epoch 133/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.9200 - f1_score: 0.9184
# Epoch 133: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 112s 1s/step - loss: 0.2526 - accuracy: 0.9200 - f1_score: 0.9184 - val_loss: 0.3563 - val_accuracy: 0.8997 - val_f1_score: 0.8984 - lr: 7.8125e-07
# Epoch 134/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.9196 - f1_score: 0.9197
# Epoch 134: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 116s 1s/step - loss: 0.2553 - accuracy: 0.9196 - f1_score: 0.9197 - val_loss: 0.3488 - val_accuracy: 0.8946 - val_f1_score: 0.8922 - lr: 7.8125e-07
# Epoch 135/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9193 - f1_score: 0.9177
# Epoch 135: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 120s 1s/step - loss: 0.2606 - accuracy: 0.9193 - f1_score: 0.9177 - val_loss: 0.3649 - val_accuracy: 0.8935 - val_f1_score: 0.8946 - lr: 7.8125e-07
# Epoch 136/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.9172 - f1_score: 0.9155
# Epoch 136: val_f1_score did not improve from 0.90196
#
# Epoch 136: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 104/104 [==============================] - 118s 1s/step - loss: 0.2607 - accuracy: 0.9172 - f1_score: 0.9155 - val_loss: 0.3826 - val_accuracy: 0.8919 - val_f1_score: 0.8900 - lr: 7.8125e-07
# Epoch 137/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9181 - f1_score: 0.9182
# Epoch 137: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 119s 1s/step - loss: 0.2606 - accuracy: 0.9181 - f1_score: 0.9182 - val_loss: 0.3499 - val_accuracy: 0.8927 - val_f1_score: 0.8907 - lr: 3.9062e-07
# Epoch 138/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.9173 - f1_score: 0.9175
# Epoch 138: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 119s 1s/step - loss: 0.2605 - accuracy: 0.9173 - f1_score: 0.9175 - val_loss: 0.3524 - val_accuracy: 0.8931 - val_f1_score: 0.8885 - lr: 3.9062e-07
# Epoch 139/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9159 - f1_score: 0.9147
# Epoch 139: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 116s 1s/step - loss: 0.2665 - accuracy: 0.9159 - f1_score: 0.9147 - val_loss: 0.3456 - val_accuracy: 0.8939 - val_f1_score: 0.8879 - lr: 3.9062e-07
# Epoch 140/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9217 - f1_score: 0.9204
# Epoch 140: val_f1_score did not improve from 0.90196
# 104/104 [==============================] - 119s 1s/step - loss: 0.2531 - accuracy: 0.9217 - f1_score: 0.9204 - val_loss: 0.3595 - val_accuracy: 0.8927 - val_f1_score: 0.8891 - lr: 3.9062e-07
# Epoch 141/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.9203 - f1_score: 0.9188
# Epoch 141: val_f1_score did not improve from 0.90196
#
# Epoch 141: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 104/104 [==============================] - 114s 1s/step - loss: 0.2535 - accuracy: 0.9203 - f1_score: 0.9188 - val_loss: 0.3601 - val_accuracy: 0.8942 - val_f1_score: 0.8877 - lr: 3.9062e-07

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 38s 856ms/step - loss: 0.3063 - accuracy: 0.9091 - f1_score: 0.9081
#   model_name  test_loss  test_accuracy  test_f1_score
# 0  Ensemble3   0.306283       0.909091       0.908079

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 36s 868ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.839695  0.846154  0.842912   130.000000
# 1              0.932039  0.960000  0.945813   100.000000
# 2              0.987952  0.911111  0.947977    90.000000
# 3              0.954023  0.821782  0.882979   101.000000
# 4              0.936819  0.914894  0.925727   470.000000
# 5              0.867424  0.905138  0.885880   253.000000
# 6              0.873626  0.913793  0.893258   174.000000
# 7              0.884706  0.872390  0.878505   431.000000
# 8              0.900943  0.872146  0.886311   219.000000
# 9              0.920570  0.939709  0.930041   481.000000
# 10             0.896296  0.930769  0.913208   390.000000
# 11             0.962810  0.917323  0.939516   254.000000
# 12             0.906832  0.960526  0.932907   152.000000
# accuracy       0.909091  0.909091  0.909091     0.909091
# macro avg      0.912595  0.905057  0.908079  3245.000000
# weighted avg   0.909944  0.909091  0.909085  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#   Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  Ensemble3  0.909091         0.912595      0.905057        0.908079
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.909944         0.909091           0.909085  0.306283

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.90909
# 1      Macro Precision  0.91260
# 2         Macro Recall  0.90506
# 3       Macro F1-Score  0.90808
# 4            Macro FPR  0.00779
# 5            Macro FNR  0.09494
# 6            Macro FDR  0.08740
# 7            Macro NPV  0.99224
# 8   Weighted Precision  0.90994
# 9      Weighted Recall  0.90909
# 10   Weighted F1-Score  0.90909
# 11        Weighted FPR  0.01032
# 12        Weighted FNR  0.09091
# 13        Weighted FDR  0.09006
# 14        Weighted NPV  0.98993
