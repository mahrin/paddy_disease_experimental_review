# %% [markdown]
# ## Imports

# %%
# !pip install tensorflow-addons

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %% [markdown]
# ## Setting the paths

# %%
model_name = 'original_vit'#'Xception'#'DenseNet121'#    'InceptionV3'##  'MobileNet', 'Xception', ensemble2, ensemble3, 'parallel_vit'

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')

PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')


if not os.path.exists(PATH_TO_SAVE_RESULT):
    # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################

IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10


################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic' #'all'## basic, advanced,
################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.


PATIENCE_EARLY_STOP = 12 # With no improvement in Loss, will stop training

# # Checkpoint parameters
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
PATIENCE_LR_REDUCE=3      # Number of epochs with no improvement after which learning rate will be reduced
COOLDOWN_EPOCHS  = 2              # How many epochs to wait after learning rate reduction before it can be reduced again
MIN_LR = 1e-9
INITIAL_LR = 0.001 # with 0.001 got 99 percent

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_SAVE_TIME ", PATH_SAVE_TIME )
print("PATH_SAVE_HISTORY", PATH_SAVE_HISTORY)
print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_SAVE_TIME  saved_outputs_basic_augment\original_vit\original_vit_training_time.csv
# PATH_SAVE_HISTORY saved_outputs_basic_augment\original_vit\original_vit_training_history.csv
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\original_vit
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\original_vit\original_vit_saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\original_vit\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_3192\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([
    iaa.ElasticTransformation(alpha=10, sigma=5)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
def create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                      dataset_path_test=DATASET_PATH_TEST,
                      valid_ratio=VALIDATION_SPLIT,
                      augment= False,
                      augment_type='basic'):

    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=10,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.2,  # fraction of total height
                shear_range=0.2,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically

                # Pixel-Level Transformations
                brightness_range=[0.8, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.2,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                # rotation_range=10,  # degrees
                zoom_range=0.2,  # zoom range for random zoom
                # vertical_flip=True,  # randomly flip images vertically
                horizontal_flip=True,  # randomly flip images horizontally
            )
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )

    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )

    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )

    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        seed = SEED,
        shuffle = False,
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)

    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Visualization

# %%
def plot_images(images, labels, classes=None):
    plt.figure(figsize=(8, 8))
    for i in range(15):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)

        # If class labels are provided, add them to the subplot
        if classes is not None:
            label = classes[np.argmax(labels[i])]
            plt.xlabel(label)
    plt.show()


train_images, train_labels = next(train_generator)  # Fetch a batch of images and labels


plot_images(train_images, train_labels)

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    ##########################################################################################################

    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)
    ##########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR,   # Lower bound on the learning rate.
        cooldown = COOLDOWN_EPOCHS
    )

    my_callbacks = [best_weight_callback , reduce_LR , EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return  PATH_BEST_WEIGHT_SAVE, train_history , total_time#model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)

    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)

    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)

        # Calculate support for each class
        support = TP + FN

        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []

    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)

    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)

    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)

    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator)

    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")

    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)


    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Loss': test_loss
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

    del report_df, test_results

# %% [markdown]
# # MODEL CREATING

# %% [markdown]
# ### Original Vit models

# %%
from vit import ViT
from tensorflow.keras.losses import CategoricalCrossentropy

def get_original_vit():
    model = ViT( # v1 val_accuracy: 0.3172 - val_f1_score: 0.1981
    image_size = 128,
    patch_size = 16,
    num_classes = NUM_CLASSES,
    dim = 512,
    depth = 6,
    heads = 16,
    mlp_dim = 1024,
    dropout = 0.1,
    emb_dropout = 0.1
    )

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss=CategoricalCrossentropy(from_logits=True),
                  run_eagerly=True,
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)

    return model

# %% [markdown]
# # Train and Results

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()
# model = get_ensemble2_model()
model = get_original_vit()

# %%
# training the model and saving the best model as a check point
PATH_BEST_WEIGHT_SAVE, train_history , total_time = fit_and_save_best_model_vit(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 2.8728 - accuracy: 0.1393 - f1_score: 0.0661
# Epoch 1: val_f1_score improved from -inf to 0.02542, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 482s 5s/step - loss: 2.8728 - accuracy: 0.1393 - f1_score: 0.0661 - val_loss: 2.4597 - val_accuracy: 0.1289 - val_f1_score: 0.0254 - lr: 0.0010
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 2.4442 - accuracy: 0.1600 - f1_score: 0.0653
# Epoch 2: val_f1_score improved from 0.02542 to 0.07727, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 515s 5s/step - loss: 2.4442 - accuracy: 0.1600 - f1_score: 0.0653 - val_loss: 2.3528 - val_accuracy: 0.2393 - val_f1_score: 0.0773 - lr: 0.0010
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 2.3424 - accuracy: 0.2125 - f1_score: 0.1039
# Epoch 3: val_f1_score improved from 0.07727 to 0.11893, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 540s 5s/step - loss: 2.3424 - accuracy: 0.2125 - f1_score: 0.1039 - val_loss: 2.2400 - val_accuracy: 0.2563 - val_f1_score: 0.1189 - lr: 0.0010
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 2.2645 - accuracy: 0.2405 - f1_score: 0.1380
# Epoch 4: val_f1_score did not improve from 0.11893
# 104/104 [==============================] - 551s 5s/step - loss: 2.2645 - accuracy: 0.2405 - f1_score: 0.1380 - val_loss: 2.2067 - val_accuracy: 0.2331 - val_f1_score: 0.1100 - lr: 0.0010
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 2.2022 - accuracy: 0.2646 - f1_score: 0.1667
# Epoch 5: val_f1_score improved from 0.11893 to 0.20834, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 554s 5s/step - loss: 2.2022 - accuracy: 0.2646 - f1_score: 0.1667 - val_loss: 2.0847 - val_accuracy: 0.3111 - val_f1_score: 0.2083 - lr: 0.0010
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 2.1297 - accuracy: 0.2852 - f1_score: 0.1935
# Epoch 6: val_f1_score did not improve from 0.20834
# 104/104 [==============================] - 546s 5s/step - loss: 2.1297 - accuracy: 0.2852 - f1_score: 0.1935 - val_loss: 2.0994 - val_accuracy: 0.2898 - val_f1_score: 0.1706 - lr: 0.0010
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 2.0810 - accuracy: 0.2973 - f1_score: 0.2164
# Epoch 7: val_f1_score improved from 0.20834 to 0.21766, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 553s 5s/step - loss: 2.0810 - accuracy: 0.2973 - f1_score: 0.2164 - val_loss: 2.0389 - val_accuracy: 0.3227 - val_f1_score: 0.2177 - lr: 0.0010
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 2.0466 - accuracy: 0.3033 - f1_score: 0.2339
# Epoch 8: val_f1_score improved from 0.21766 to 0.24677, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 548s 5s/step - loss: 2.0466 - accuracy: 0.3033 - f1_score: 0.2339 - val_loss: 1.9918 - val_accuracy: 0.3296 - val_f1_score: 0.2468 - lr: 0.0010
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 1.9910 - accuracy: 0.3289 - f1_score: 0.2732
# Epoch 9: val_f1_score improved from 0.24677 to 0.26085, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 552s 5s/step - loss: 1.9910 - accuracy: 0.3289 - f1_score: 0.2732 - val_loss: 1.9338 - val_accuracy: 0.3466 - val_f1_score: 0.2608 - lr: 0.0010
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 1.9606 - accuracy: 0.3381 - f1_score: 0.2790
# Epoch 10: val_f1_score improved from 0.26085 to 0.29222, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 566s 5s/step - loss: 1.9606 - accuracy: 0.3381 - f1_score: 0.2790 - val_loss: 1.9771 - val_accuracy: 0.3338 - val_f1_score: 0.2922 - lr: 0.0010
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 1.8887 - accuracy: 0.3671 - f1_score: 0.3166
# Epoch 11: val_f1_score improved from 0.29222 to 0.31742, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 557s 5s/step - loss: 1.8887 - accuracy: 0.3671 - f1_score: 0.3166 - val_loss: 1.8324 - val_accuracy: 0.3906 - val_f1_score: 0.3174 - lr: 0.0010
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 1.8356 - accuracy: 0.3910 - f1_score: 0.3382
# Epoch 12: val_f1_score improved from 0.31742 to 0.35652, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 586s 6s/step - loss: 1.8356 - accuracy: 0.3910 - f1_score: 0.3382 - val_loss: 1.7433 - val_accuracy: 0.4242 - val_f1_score: 0.3565 - lr: 0.0010
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7927 - accuracy: 0.3978 - f1_score: 0.3462
# Epoch 13: val_f1_score did not improve from 0.35652
# 104/104 [==============================] - 582s 6s/step - loss: 1.7927 - accuracy: 0.3978 - f1_score: 0.3462 - val_loss: 1.7311 - val_accuracy: 0.4188 - val_f1_score: 0.3483 - lr: 0.0010
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 1.8212 - accuracy: 0.3943 - f1_score: 0.3406
# Epoch 14: val_f1_score did not improve from 0.35652
# 104/104 [==============================] - 586s 6s/step - loss: 1.8212 - accuracy: 0.3943 - f1_score: 0.3406 - val_loss: 1.7872 - val_accuracy: 0.3983 - val_f1_score: 0.3179 - lr: 0.0010
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7186 - accuracy: 0.4292 - f1_score: 0.3780
# Epoch 15: val_f1_score improved from 0.35652 to 0.41039, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 600s 6s/step - loss: 1.7186 - accuracy: 0.4292 - f1_score: 0.3780 - val_loss: 1.6192 - val_accuracy: 0.4527 - val_f1_score: 0.4104 - lr: 0.0010
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 1.6630 - accuracy: 0.4473 - f1_score: 0.4003
# Epoch 16: val_f1_score did not improve from 0.41039
# 104/104 [==============================] - 577s 6s/step - loss: 1.6630 - accuracy: 0.4473 - f1_score: 0.4003 - val_loss: 1.6599 - val_accuracy: 0.4608 - val_f1_score: 0.3760 - lr: 0.0010
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 1.6466 - accuracy: 0.4531 - f1_score: 0.4042
# Epoch 17: val_f1_score improved from 0.41039 to 0.42234, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 586s 6s/step - loss: 1.6466 - accuracy: 0.4531 - f1_score: 0.4042 - val_loss: 1.5742 - val_accuracy: 0.4797 - val_f1_score: 0.4223 - lr: 0.0010
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 1.6101 - accuracy: 0.4681 - f1_score: 0.4269
# Epoch 18: val_f1_score did not improve from 0.42234
# 104/104 [==============================] - 585s 6s/step - loss: 1.6101 - accuracy: 0.4681 - f1_score: 0.4269 - val_loss: 1.5804 - val_accuracy: 0.4794 - val_f1_score: 0.4219 - lr: 0.0010
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5466 - accuracy: 0.4872 - f1_score: 0.4461
# Epoch 19: val_f1_score improved from 0.42234 to 0.42441, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 552s 5s/step - loss: 1.5466 - accuracy: 0.4872 - f1_score: 0.4461 - val_loss: 1.5687 - val_accuracy: 0.4774 - val_f1_score: 0.4244 - lr: 0.0010
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5204 - accuracy: 0.4922 - f1_score: 0.4591
# Epoch 20: val_f1_score improved from 0.42441 to 0.49147, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 544s 5s/step - loss: 1.5204 - accuracy: 0.4922 - f1_score: 0.4591 - val_loss: 1.4375 - val_accuracy: 0.5276 - val_f1_score: 0.4915 - lr: 0.0010
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4778 - accuracy: 0.5108 - f1_score: 0.4729
# Epoch 21: val_f1_score did not improve from 0.49147
# 104/104 [==============================] - 547s 5s/step - loss: 1.4778 - accuracy: 0.5108 - f1_score: 0.4729 - val_loss: 1.5511 - val_accuracy: 0.4739 - val_f1_score: 0.4213 - lr: 0.0010
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 1.5042 - accuracy: 0.5015 - f1_score: 0.4657
# Epoch 22: val_f1_score did not improve from 0.49147
# 104/104 [==============================] - 539s 5s/step - loss: 1.5042 - accuracy: 0.5015 - f1_score: 0.4657 - val_loss: 1.4668 - val_accuracy: 0.4998 - val_f1_score: 0.4706 - lr: 0.0010
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4493 - accuracy: 0.5186 - f1_score: 0.4809
# Epoch 23: val_f1_score did not improve from 0.49147
# 104/104 [==============================] - 522s 5s/step - loss: 1.4493 - accuracy: 0.5186 - f1_score: 0.4809 - val_loss: 1.4329 - val_accuracy: 0.5114 - val_f1_score: 0.4868 - lr: 0.0010
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4109 - accuracy: 0.5317 - f1_score: 0.4999
# Epoch 24: val_f1_score improved from 0.49147 to 0.49871, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 527s 5s/step - loss: 1.4109 - accuracy: 0.5317 - f1_score: 0.4999 - val_loss: 1.4158 - val_accuracy: 0.5268 - val_f1_score: 0.4987 - lr: 0.0010
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4244 - accuracy: 0.5238 - f1_score: 0.4884
# Epoch 25: val_f1_score did not improve from 0.49871
# 104/104 [==============================] - 522s 5s/step - loss: 1.4244 - accuracy: 0.5238 - f1_score: 0.4884 - val_loss: 1.4729 - val_accuracy: 0.5133 - val_f1_score: 0.4564 - lr: 0.0010
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4413 - accuracy: 0.5238 - f1_score: 0.4869
# Epoch 26: val_f1_score did not improve from 0.49871
# 104/104 [==============================] - 539s 5s/step - loss: 1.4413 - accuracy: 0.5238 - f1_score: 0.4869 - val_loss: 1.4083 - val_accuracy: 0.5334 - val_f1_score: 0.4889 - lr: 0.0010
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4015 - accuracy: 0.5324 - f1_score: 0.5032
# Epoch 27: val_f1_score improved from 0.49871 to 0.50354, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 539s 5s/step - loss: 1.4015 - accuracy: 0.5324 - f1_score: 0.5032 - val_loss: 1.4226 - val_accuracy: 0.5388 - val_f1_score: 0.5035 - lr: 0.0010
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3707 - accuracy: 0.5447 - f1_score: 0.5123
# Epoch 28: val_f1_score improved from 0.50354 to 0.52154, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 543s 5s/step - loss: 1.3707 - accuracy: 0.5447 - f1_score: 0.5123 - val_loss: 1.3790 - val_accuracy: 0.5446 - val_f1_score: 0.5215 - lr: 0.0010
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4599 - accuracy: 0.5155 - f1_score: 0.4747
# Epoch 29: val_f1_score improved from 0.52154 to 0.53852, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 565s 5s/step - loss: 1.4599 - accuracy: 0.5155 - f1_score: 0.4747 - val_loss: 1.3173 - val_accuracy: 0.5650 - val_f1_score: 0.5385 - lr: 0.0010
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3430 - accuracy: 0.5565 - f1_score: 0.5227
# Epoch 30: val_f1_score improved from 0.53852 to 0.54388, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 317s 3s/step - loss: 1.3430 - accuracy: 0.5565 - f1_score: 0.5227 - val_loss: 1.2990 - val_accuracy: 0.5704 - val_f1_score: 0.5439 - lr: 0.0010
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3735 - accuracy: 0.5426 - f1_score: 0.5114
# Epoch 31: val_f1_score did not improve from 0.54388
# 104/104 [==============================] - 359s 3s/step - loss: 1.3735 - accuracy: 0.5426 - f1_score: 0.5114 - val_loss: 1.4186 - val_accuracy: 0.5253 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 1.3494 - accuracy: 0.5562 - f1_score: 0.5240
# Epoch 32: val_f1_score did not improve from 0.54388
# 104/104 [==============================] - 365s 4s/step - loss: 1.3494 - accuracy: 0.5562 - f1_score: 0.5240 - val_loss: 1.2766 - val_accuracy: 0.5654 - val_f1_score: 0.5361 - lr: 0.0010
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2672 - accuracy: 0.5788 - f1_score: 0.5563
# Epoch 33: val_f1_score did not improve from 0.54388
# 104/104 [==============================] - 367s 4s/step - loss: 1.2672 - accuracy: 0.5788 - f1_score: 0.5563 - val_loss: 1.2878 - val_accuracy: 0.5673 - val_f1_score: 0.5276 - lr: 0.0010
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2211 - accuracy: 0.5973 - f1_score: 0.5708
# Epoch 34: val_f1_score improved from 0.54388 to 0.58763, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 390s 4s/step - loss: 1.2211 - accuracy: 0.5973 - f1_score: 0.5708 - val_loss: 1.2154 - val_accuracy: 0.6017 - val_f1_score: 0.5876 - lr: 0.0010
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2002 - accuracy: 0.6012 - f1_score: 0.5806
# Epoch 35: val_f1_score did not improve from 0.58763
# 104/104 [==============================] - 406s 4s/step - loss: 1.2002 - accuracy: 0.6012 - f1_score: 0.5806 - val_loss: 1.2422 - val_accuracy: 0.5874 - val_f1_score: 0.5721 - lr: 0.0010
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1369 - accuracy: 0.6209 - f1_score: 0.5987
# Epoch 36: val_f1_score did not improve from 0.58763
# 104/104 [==============================] - 418s 4s/step - loss: 1.1369 - accuracy: 0.6209 - f1_score: 0.5987 - val_loss: 1.1981 - val_accuracy: 0.6063 - val_f1_score: 0.5788 - lr: 0.0010
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1282 - accuracy: 0.6202 - f1_score: 0.5984
# Epoch 37: val_f1_score improved from 0.58763 to 0.60250, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 438s 4s/step - loss: 1.1282 - accuracy: 0.6202 - f1_score: 0.5984 - val_loss: 1.1511 - val_accuracy: 0.6187 - val_f1_score: 0.6025 - lr: 0.0010
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1453 - accuracy: 0.6235 - f1_score: 0.6054
# Epoch 38: val_f1_score improved from 0.60250 to 0.60727, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 473s 5s/step - loss: 1.1453 - accuracy: 0.6235 - f1_score: 0.6054 - val_loss: 1.1306 - val_accuracy: 0.6303 - val_f1_score: 0.6073 - lr: 0.0010
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1359 - accuracy: 0.6183 - f1_score: 0.6009
# Epoch 39: val_f1_score did not improve from 0.60727
# 104/104 [==============================] - 470s 5s/step - loss: 1.1359 - accuracy: 0.6183 - f1_score: 0.6009 - val_loss: 1.1792 - val_accuracy: 0.6160 - val_f1_score: 0.5932 - lr: 0.0010
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0695 - accuracy: 0.6448 - f1_score: 0.6267
# Epoch 40: val_f1_score improved from 0.60727 to 0.62066, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 536s 5s/step - loss: 1.0695 - accuracy: 0.6448 - f1_score: 0.6267 - val_loss: 1.1157 - val_accuracy: 0.6345 - val_f1_score: 0.6207 - lr: 0.0010
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0247 - accuracy: 0.6568 - f1_score: 0.6411
# Epoch 41: val_f1_score improved from 0.62066 to 0.63942, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 494s 5s/step - loss: 1.0247 - accuracy: 0.6568 - f1_score: 0.6411 - val_loss: 1.0712 - val_accuracy: 0.6445 - val_f1_score: 0.6394 - lr: 0.0010
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0204 - accuracy: 0.6620 - f1_score: 0.6487
# Epoch 42: val_f1_score improved from 0.63942 to 0.64838, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 521s 5s/step - loss: 1.0204 - accuracy: 0.6620 - f1_score: 0.6487 - val_loss: 1.0507 - val_accuracy: 0.6577 - val_f1_score: 0.6484 - lr: 0.0010
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0470 - accuracy: 0.6434 - f1_score: 0.6288
# Epoch 43: val_f1_score did not improve from 0.64838
# 104/104 [==============================] - 545s 5s/step - loss: 1.0470 - accuracy: 0.6434 - f1_score: 0.6288 - val_loss: 1.0483 - val_accuracy: 0.6615 - val_f1_score: 0.6400 - lr: 0.0010
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0080 - accuracy: 0.6604 - f1_score: 0.6480
# Epoch 44: val_f1_score improved from 0.64838 to 0.65026, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 583s 6s/step - loss: 1.0080 - accuracy: 0.6604 - f1_score: 0.6480 - val_loss: 1.0321 - val_accuracy: 0.6635 - val_f1_score: 0.6503 - lr: 0.0010
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9915 - accuracy: 0.6650 - f1_score: 0.6507
# Epoch 45: val_f1_score improved from 0.65026 to 0.65774, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 607s 6s/step - loss: 0.9915 - accuracy: 0.6650 - f1_score: 0.6507 - val_loss: 1.0316 - val_accuracy: 0.6665 - val_f1_score: 0.6577 - lr: 0.0010
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9619 - accuracy: 0.6799 - f1_score: 0.6736
# Epoch 46: val_f1_score improved from 0.65774 to 0.66532, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 576s 6s/step - loss: 0.9619 - accuracy: 0.6799 - f1_score: 0.6736 - val_loss: 1.0069 - val_accuracy: 0.6723 - val_f1_score: 0.6653 - lr: 0.0010
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9340 - accuracy: 0.6877 - f1_score: 0.6772
# Epoch 47: val_f1_score improved from 0.66532 to 0.68041, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 604s 6s/step - loss: 0.9340 - accuracy: 0.6877 - f1_score: 0.6772 - val_loss: 0.9595 - val_accuracy: 0.6901 - val_f1_score: 0.6804 - lr: 0.0010
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9149 - accuracy: 0.6975 - f1_score: 0.6869
# Epoch 48: val_f1_score improved from 0.68041 to 0.68638, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 640s 6s/step - loss: 0.9149 - accuracy: 0.6975 - f1_score: 0.6869 - val_loss: 0.9369 - val_accuracy: 0.6970 - val_f1_score: 0.6864 - lr: 0.0010
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8938 - accuracy: 0.6981 - f1_score: 0.6882
# Epoch 49: val_f1_score did not improve from 0.68638
# 104/104 [==============================] - 664s 6s/step - loss: 0.8938 - accuracy: 0.6981 - f1_score: 0.6882 - val_loss: 0.9354 - val_accuracy: 0.6959 - val_f1_score: 0.6794 - lr: 0.0010
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8835 - accuracy: 0.7089 - f1_score: 0.6989
# Epoch 50: val_f1_score did not improve from 0.68638
# 104/104 [==============================] - 703s 7s/step - loss: 0.8835 - accuracy: 0.7089 - f1_score: 0.6989 - val_loss: 0.9303 - val_accuracy: 0.6970 - val_f1_score: 0.6804 - lr: 0.0010
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8671 - accuracy: 0.7102 - f1_score: 0.7045
# Epoch 51: val_f1_score did not improve from 0.68638
# 104/104 [==============================] - 656s 6s/step - loss: 0.8671 - accuracy: 0.7102 - f1_score: 0.7045 - val_loss: 0.9176 - val_accuracy: 0.6951 - val_f1_score: 0.6840 - lr: 0.0010
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8501 - accuracy: 0.7138 - f1_score: 0.7087
# Epoch 52: val_f1_score improved from 0.68638 to 0.70934, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 704s 7s/step - loss: 0.8501 - accuracy: 0.7138 - f1_score: 0.7087 - val_loss: 0.8812 - val_accuracy: 0.7186 - val_f1_score: 0.7093 - lr: 0.0010
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8156 - accuracy: 0.7255 - f1_score: 0.7179
# Epoch 53: val_f1_score improved from 0.70934 to 0.71342, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 759s 7s/step - loss: 0.8156 - accuracy: 0.7255 - f1_score: 0.7179 - val_loss: 0.8708 - val_accuracy: 0.7190 - val_f1_score: 0.7134 - lr: 0.0010
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7968 - accuracy: 0.7326 - f1_score: 0.7298
# Epoch 54: val_f1_score did not improve from 0.71342
# 104/104 [==============================] - 758s 7s/step - loss: 0.7968 - accuracy: 0.7326 - f1_score: 0.7298 - val_loss: 0.9254 - val_accuracy: 0.7017 - val_f1_score: 0.6957 - lr: 0.0010
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8048 - accuracy: 0.7310 - f1_score: 0.7239
# Epoch 55: val_f1_score did not improve from 0.71342
# 104/104 [==============================] - 805s 8s/step - loss: 0.8048 - accuracy: 0.7310 - f1_score: 0.7239 - val_loss: 0.9123 - val_accuracy: 0.7179 - val_f1_score: 0.7053 - lr: 0.0010
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7788 - accuracy: 0.7376 - f1_score: 0.7354
# Epoch 56: val_f1_score improved from 0.71342 to 0.72901, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 756s 7s/step - loss: 0.7788 - accuracy: 0.7376 - f1_score: 0.7354 - val_loss: 0.8243 - val_accuracy: 0.7364 - val_f1_score: 0.7290 - lr: 0.0010
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7780 - accuracy: 0.7395 - f1_score: 0.7312
# Epoch 57: val_f1_score did not improve from 0.72901
# 104/104 [==============================] - 826s 8s/step - loss: 0.7780 - accuracy: 0.7395 - f1_score: 0.7312 - val_loss: 0.8554 - val_accuracy: 0.7244 - val_f1_score: 0.7137 - lr: 0.0010
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.7604 - f1_score: 0.7545
# Epoch 58: val_f1_score improved from 0.72901 to 0.73874, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 902s 9s/step - loss: 0.7216 - accuracy: 0.7604 - f1_score: 0.7545 - val_loss: 0.8096 - val_accuracy: 0.7437 - val_f1_score: 0.7387 - lr: 0.0010
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.7596 - f1_score: 0.7558
# Epoch 59: val_f1_score did not improve from 0.73874
# 104/104 [==============================] - 880s 8s/step - loss: 0.7156 - accuracy: 0.7596 - f1_score: 0.7558 - val_loss: 0.8341 - val_accuracy: 0.7352 - val_f1_score: 0.7241 - lr: 0.0010
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.7588 - f1_score: 0.7526
# Epoch 60: val_f1_score did not improve from 0.73874
# 104/104 [==============================] - 861s 8s/step - loss: 0.7156 - accuracy: 0.7588 - f1_score: 0.7526 - val_loss: 0.8283 - val_accuracy: 0.7302 - val_f1_score: 0.7207 - lr: 0.0010
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7266 - accuracy: 0.7571 - f1_score: 0.7527
# Epoch 61: val_f1_score did not improve from 0.73874
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 881s 8s/step - loss: 0.7266 - accuracy: 0.7571 - f1_score: 0.7527 - val_loss: 0.8764 - val_accuracy: 0.7179 - val_f1_score: 0.7082 - lr: 0.0010
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6050 - accuracy: 0.7961 - f1_score: 0.7941
# Epoch 62: val_f1_score improved from 0.73874 to 0.76066, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 927s 9s/step - loss: 0.6050 - accuracy: 0.7961 - f1_score: 0.7941 - val_loss: 0.7449 - val_accuracy: 0.7657 - val_f1_score: 0.7607 - lr: 5.0000e-04
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5608 - accuracy: 0.8118 - f1_score: 0.8123
# Epoch 63: val_f1_score improved from 0.76066 to 0.76855, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1232s 12s/step - loss: 0.5608 - accuracy: 0.8118 - f1_score: 0.8123 - val_loss: 0.7122 - val_accuracy: 0.7680 - val_f1_score: 0.7686 - lr: 5.0000e-04
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5481 - accuracy: 0.8166 - f1_score: 0.8163
# Epoch 64: val_f1_score improved from 0.76855 to 0.79657, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1393s 13s/step - loss: 0.5481 - accuracy: 0.8166 - f1_score: 0.8163 - val_loss: 0.6769 - val_accuracy: 0.7981 - val_f1_score: 0.7966 - lr: 5.0000e-04
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5293 - accuracy: 0.8221 - f1_score: 0.8199
# Epoch 65: val_f1_score did not improve from 0.79657
# 104/104 [==============================] - 1405s 13s/step - loss: 0.5293 - accuracy: 0.8221 - f1_score: 0.8199 - val_loss: 0.6759 - val_accuracy: 0.7962 - val_f1_score: 0.7934 - lr: 5.0000e-04
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.8260 - f1_score: 0.8257
# Epoch 66: val_f1_score did not improve from 0.79657
# 104/104 [==============================] - 1466s 14s/step - loss: 0.5185 - accuracy: 0.8260 - f1_score: 0.8257 - val_loss: 0.6659 - val_accuracy: 0.8008 - val_f1_score: 0.7949 - lr: 5.0000e-04
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5128 - accuracy: 0.8282 - f1_score: 0.8264
# Epoch 67: val_f1_score did not improve from 0.79657
# 104/104 [==============================] - 1533s 15s/step - loss: 0.5128 - accuracy: 0.8282 - f1_score: 0.8264 - val_loss: 0.6504 - val_accuracy: 0.7877 - val_f1_score: 0.7883 - lr: 5.0000e-04
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.8296 - f1_score: 0.8290
# Epoch 68: val_f1_score improved from 0.79657 to 0.80145, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1594s 15s/step - loss: 0.4928 - accuracy: 0.8296 - f1_score: 0.8290 - val_loss: 0.6301 - val_accuracy: 0.8036 - val_f1_score: 0.8015 - lr: 5.0000e-04
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4756 - accuracy: 0.8356 - f1_score: 0.8333
# Epoch 69: val_f1_score did not improve from 0.80145
# 104/104 [==============================] - 1637s 16s/step - loss: 0.4756 - accuracy: 0.8356 - f1_score: 0.8333 - val_loss: 0.6499 - val_accuracy: 0.7985 - val_f1_score: 0.7918 - lr: 5.0000e-04
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.8386 - f1_score: 0.8383
# Epoch 70: val_f1_score did not improve from 0.80145
# 104/104 [==============================] - 1722s 17s/step - loss: 0.4958 - accuracy: 0.8386 - f1_score: 0.8383 - val_loss: 0.6521 - val_accuracy: 0.7954 - val_f1_score: 0.7941 - lr: 5.0000e-04
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.8404 - f1_score: 0.8400
# Epoch 71: val_f1_score improved from 0.80145 to 0.80424, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1781s 17s/step - loss: 0.4749 - accuracy: 0.8404 - f1_score: 0.8400 - val_loss: 0.6134 - val_accuracy: 0.8090 - val_f1_score: 0.8042 - lr: 5.0000e-04
# Epoch 72/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.8417 - f1_score: 0.8412
# Epoch 72: val_f1_score improved from 0.80424 to 0.80654, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1818s 17s/step - loss: 0.4681 - accuracy: 0.8417 - f1_score: 0.8412 - val_loss: 0.6025 - val_accuracy: 0.8086 - val_f1_score: 0.8065 - lr: 5.0000e-04
# Epoch 73/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8503 - f1_score: 0.8494
# Epoch 73: val_f1_score improved from 0.80654 to 0.81028, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1941s 19s/step - loss: 0.4479 - accuracy: 0.8503 - f1_score: 0.8494 - val_loss: 0.6271 - val_accuracy: 0.8090 - val_f1_score: 0.8103 - lr: 5.0000e-04
# Epoch 74/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4328 - accuracy: 0.8507 - f1_score: 0.8491
# Epoch 74: val_f1_score improved from 0.81028 to 0.82124, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 1980s 19s/step - loss: 0.4328 - accuracy: 0.8507 - f1_score: 0.8491 - val_loss: 0.6028 - val_accuracy: 0.8213 - val_f1_score: 0.8212 - lr: 5.0000e-04
# Epoch 75/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.8480 - f1_score: 0.8465
# Epoch 75: val_f1_score did not improve from 0.82124
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 2082s 20s/step - loss: 0.4464 - accuracy: 0.8480 - f1_score: 0.8465 - val_loss: 0.6152 - val_accuracy: 0.8198 - val_f1_score: 0.8187 - lr: 5.0000e-04
# Epoch 76/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8694 - f1_score: 0.8680
# Epoch 76: val_f1_score improved from 0.82124 to 0.82262, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2217s 21s/step - loss: 0.3874 - accuracy: 0.8694 - f1_score: 0.8680 - val_loss: 0.5742 - val_accuracy: 0.8221 - val_f1_score: 0.8226 - lr: 2.5000e-04
# Epoch 77/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3695 - accuracy: 0.8796 - f1_score: 0.8781
# Epoch 77: val_f1_score improved from 0.82262 to 0.82447, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2312s 22s/step - loss: 0.3695 - accuracy: 0.8796 - f1_score: 0.8781 - val_loss: 0.5439 - val_accuracy: 0.8267 - val_f1_score: 0.8245 - lr: 2.5000e-04
# Epoch 78/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3679 - accuracy: 0.8732 - f1_score: 0.8739
# Epoch 78: val_f1_score improved from 0.82447 to 0.82923, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2421s 23s/step - loss: 0.3679 - accuracy: 0.8732 - f1_score: 0.8739 - val_loss: 0.5491 - val_accuracy: 0.8348 - val_f1_score: 0.8292 - lr: 2.5000e-04
# Epoch 79/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8794 - f1_score: 0.8788
# Epoch 79: val_f1_score did not improve from 0.82923
# 104/104 [==============================] - 2502s 24s/step - loss: 0.3574 - accuracy: 0.8794 - f1_score: 0.8788 - val_loss: 0.5724 - val_accuracy: 0.8255 - val_f1_score: 0.8203 - lr: 2.5000e-04
# Epoch 80/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.8886 - f1_score: 0.8905
# Epoch 80: val_f1_score did not improve from 0.82923
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 2553s 25s/step - loss: 0.3304 - accuracy: 0.8886 - f1_score: 0.8905 - val_loss: 0.5502 - val_accuracy: 0.8302 - val_f1_score: 0.8255 - lr: 2.5000e-04
# Epoch 81/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.8926 - f1_score: 0.8916
# Epoch 81: val_f1_score improved from 0.82923 to 0.84608, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2679s 26s/step - loss: 0.3173 - accuracy: 0.8926 - f1_score: 0.8916 - val_loss: 0.5144 - val_accuracy: 0.8468 - val_f1_score: 0.8461 - lr: 1.2500e-04
# Epoch 82/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3013 - accuracy: 0.8989 - f1_score: 0.8989
# Epoch 82: val_f1_score improved from 0.84608 to 0.84904, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2667s 26s/step - loss: 0.3013 - accuracy: 0.8989 - f1_score: 0.8989 - val_loss: 0.5344 - val_accuracy: 0.8483 - val_f1_score: 0.8490 - lr: 1.2500e-04
# Epoch 83/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.9025 - f1_score: 0.9029
# Epoch 83: val_f1_score did not improve from 0.84904
# 104/104 [==============================] - 2429s 23s/step - loss: 0.2944 - accuracy: 0.9025 - f1_score: 0.9029 - val_loss: 0.5277 - val_accuracy: 0.8425 - val_f1_score: 0.8448 - lr: 1.2500e-04
# Epoch 84/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8987 - f1_score: 0.8981
# Epoch 84: val_f1_score improved from 0.84904 to 0.84913, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2405s 23s/step - loss: 0.2896 - accuracy: 0.8987 - f1_score: 0.8981 - val_loss: 0.5063 - val_accuracy: 0.8549 - val_f1_score: 0.8491 - lr: 1.2500e-04
# Epoch 85/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9025 - f1_score: 0.9019
# Epoch 85: val_f1_score did not improve from 0.84913
# 104/104 [==============================] - 2375s 23s/step - loss: 0.2835 - accuracy: 0.9025 - f1_score: 0.9019 - val_loss: 0.5337 - val_accuracy: 0.8452 - val_f1_score: 0.8455 - lr: 1.2500e-04
# Epoch 86/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.9048 - f1_score: 0.9069
# Epoch 86: val_f1_score did not improve from 0.84913
# 104/104 [==============================] - 2380s 23s/step - loss: 0.2771 - accuracy: 0.9048 - f1_score: 0.9069 - val_loss: 0.5211 - val_accuracy: 0.8425 - val_f1_score: 0.8405 - lr: 1.2500e-04
# Epoch 87/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.9017 - f1_score: 0.9018
# Epoch 87: val_f1_score improved from 0.84913 to 0.84960, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 2435s 23s/step - loss: 0.2853 - accuracy: 0.9017 - f1_score: 0.9018 - val_loss: 0.5326 - val_accuracy: 0.8491 - val_f1_score: 0.8496 - lr: 1.2500e-04
# Epoch 88/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9113 - f1_score: 0.9104
# Epoch 88: val_f1_score improved from 0.84960 to 0.85530, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2888s 28s/step - loss: 0.2664 - accuracy: 0.9113 - f1_score: 0.9104 - val_loss: 0.5132 - val_accuracy: 0.8541 - val_f1_score: 0.8553 - lr: 6.2500e-05
# Epoch 89/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.9090 - f1_score: 0.9092
# Epoch 89: val_f1_score improved from 0.85530 to 0.85843, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 3179s 31s/step - loss: 0.2682 - accuracy: 0.9090 - f1_score: 0.9092 - val_loss: 0.4762 - val_accuracy: 0.8607 - val_f1_score: 0.8584 - lr: 6.2500e-05
# Epoch 90/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2556 - accuracy: 0.9138 - f1_score: 0.9155
# Epoch 90: val_f1_score did not improve from 0.85843
# 104/104 [==============================] - 3248s 31s/step - loss: 0.2556 - accuracy: 0.9138 - f1_score: 0.9155 - val_loss: 0.5174 - val_accuracy: 0.8495 - val_f1_score: 0.8474 - lr: 6.2500e-05
# Epoch 91/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9126 - f1_score: 0.9144
# Epoch 91: val_f1_score did not improve from 0.85843
# 104/104 [==============================] - 2563s 25s/step - loss: 0.2650 - accuracy: 0.9126 - f1_score: 0.9144 - val_loss: 0.4887 - val_accuracy: 0.8549 - val_f1_score: 0.8517 - lr: 6.2500e-05
# Epoch 92/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.9183 - f1_score: 0.9201
# Epoch 92: val_f1_score did not improve from 0.85843
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 3341s 32s/step - loss: 0.2473 - accuracy: 0.9183 - f1_score: 0.9201 - val_loss: 0.5127 - val_accuracy: 0.8495 - val_f1_score: 0.8447 - lr: 6.2500e-05
# Epoch 93/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2557 - accuracy: 0.9153 - f1_score: 0.9144
# Epoch 93: val_f1_score improved from 0.85843 to 0.86342, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2545s 24s/step - loss: 0.2557 - accuracy: 0.9153 - f1_score: 0.9144 - val_loss: 0.4845 - val_accuracy: 0.8672 - val_f1_score: 0.8634 - lr: 3.1250e-05
# Epoch 94/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.9191 - f1_score: 0.9202
# Epoch 94: val_f1_score improved from 0.86342 to 0.86442, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2630s 25s/step - loss: 0.2459 - accuracy: 0.9191 - f1_score: 0.9202 - val_loss: 0.4897 - val_accuracy: 0.8657 - val_f1_score: 0.8644 - lr: 3.1250e-05
# Epoch 95/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9216 - f1_score: 0.9220
# Epoch 95: val_f1_score improved from 0.86442 to 0.86762, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 104/104 [==============================] - 2656s 26s/step - loss: 0.2342 - accuracy: 0.9216 - f1_score: 0.9220 - val_loss: 0.4781 - val_accuracy: 0.8672 - val_f1_score: 0.8676 - lr: 3.1250e-05
# Epoch 96/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9188 - f1_score: 0.9205
# Epoch 96: val_f1_score improved from 0.86762 to 0.86795, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 2659s 26s/step - loss: 0.2395 - accuracy: 0.9188 - f1_score: 0.9205 - val_loss: 0.4768 - val_accuracy: 0.8692 - val_f1_score: 0.8679 - lr: 3.1250e-05
# Epoch 97/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9187 - f1_score: 0.9186
# Epoch 97: val_f1_score did not improve from 0.86795
# 104/104 [==============================] - 2650s 25s/step - loss: 0.2405 - accuracy: 0.9187 - f1_score: 0.9186 - val_loss: 0.4904 - val_accuracy: 0.8630 - val_f1_score: 0.8608 - lr: 1.5625e-05
# Epoch 98/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.9208 - f1_score: 0.9216
# Epoch 98: val_f1_score did not improve from 0.86795
# 104/104 [==============================] - 3492s 34s/step - loss: 0.2381 - accuracy: 0.9208 - f1_score: 0.9216 - val_loss: 0.4912 - val_accuracy: 0.8630 - val_f1_score: 0.8628 - lr: 1.5625e-05
# Epoch 99/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2323 - accuracy: 0.9205 - f1_score: 0.9208
# Epoch 99: val_f1_score did not improve from 0.86795
# 104/104 [==============================] - 3618s 35s/step - loss: 0.2323 - accuracy: 0.9205 - f1_score: 0.9208 - val_loss: 0.4872 - val_accuracy: 0.8645 - val_f1_score: 0.8598 - lr: 1.5625e-05
# Epoch 100/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9205 - f1_score: 0.9217
# Epoch 100: val_f1_score did not improve from 0.86795
#
# Epoch 100: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 3638s 35s/step - loss: 0.2347 - accuracy: 0.9205 - f1_score: 0.9217 - val_loss: 0.4833 - val_accuracy: 0.8595 - val_f1_score: 0.8576 - lr: 1.5625e-05
# Epoch 101/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9211 - f1_score: 0.9202
# Epoch 101: val_f1_score did not improve from 0.86795
# 104/104 [==============================] - 3740s 36s/step - loss: 0.2371 - accuracy: 0.9211 - f1_score: 0.9202 - val_loss: 0.4965 - val_accuracy: 0.8641 - val_f1_score: 0.8658 - lr: 7.8125e-06

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
best_model = get_original_vit()

best_model.load_weights(PATH_BEST_WEIGHT_SAVE)

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 521s 16s/step - loss: 0.3877 - accuracy: 0.8924 - f1_score: 0.8801
#      model_name  test_loss  test_accuracy  test_f1_score
# 0  original_vit   0.387732        0.89245       0.880069

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test
############################################################################################################]
# Out:
# 33/33 [==============================] - 531s 16s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score     support
# 0              0.875000  0.807692  0.840000   130.00000
# 1              0.947917  0.910000  0.928571   100.00000
# 2              0.930233  0.888889  0.909091    90.00000
# 3              0.905263  0.851485  0.877551   101.00000
# 4              0.903640  0.897872  0.900747   470.00000
# 5              0.874510  0.881423  0.877953   253.00000
# 6              0.858696  0.908046  0.882682   174.00000
# 7              0.851111  0.888631  0.869467   431.00000
# 8              0.861244  0.821918  0.841121   219.00000
# 9              0.894523  0.916840  0.905544   481.00000
# 10             0.924084  0.905128  0.914508   390.00000
# 11             0.909804  0.913386  0.911591   254.00000
# 12             0.928105  0.934211  0.931148   152.00000
# accuracy       0.892450  0.892450  0.892450     0.89245
# macro avg      0.897241  0.886579  0.891536  3245.00000
# weighted avg   0.892860  0.892450  0.892393  3245.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels,
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#      Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  original_vit   0.89245         0.897241      0.886579        0.891536
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0             0.89286          0.89245           0.892393  0.387732

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.89245
# 1      Macro Precision  0.89724
# 2         Macro Recall  0.88658
# 3       Macro F1-Score  0.89154
# 4            Macro FPR  0.00924
# 5            Macro FNR  0.11342
# 6            Macro FDR  0.10276
# 7            Macro NPV  0.99082
# 8   Weighted Precision  0.89286
# 9      Weighted Recall  0.89245
# 10   Weighted F1-Score  0.89239
# 11        Weighted FPR  0.01261
# 12        Weighted FNR  0.10755
# 13        Weighted FDR  0.10714
# 14        Weighted NPV  0.98821
