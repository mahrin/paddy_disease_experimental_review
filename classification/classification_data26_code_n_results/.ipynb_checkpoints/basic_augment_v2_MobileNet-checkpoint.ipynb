# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'MobileNet'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 120 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 


# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\MobileNet
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\MobileNet\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\MobileNet\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_16544\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':  
            print("Here in basic")
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Here in basic
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    ## Criteria for early stopping
#    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %%
from tensorflow.keras.applications import MobileNet#### WORKING
def get_MobileNet_original(): 
 
    # model = Sequential()
    # base_model = MobileNet(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)

    model = MobileNet(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %%
# from cait import CaiT
# from tensorflow.keras.losses import CategoricalCrossentropy

# def get_cait(): 
#     model = CaiT( # v2   val_loss: 1.9624 - val_accuracy: 0.3500 - val_f1_score: 0.2683
#         image_size = max(MODEL_INPUT_SIZE[0], MODEL_INPUT_SIZE[1]),
#         patch_size = 16,
#         num_classes = NUM_CLASSES,
#         dim = 512,
#         depth = 6,             # depth of transformer for patch to patch attention only
#         cls_depth = 3,          # depth of cross attention of CLS tokens to patch
#         heads = 16,
#         mlp_dim = 1024,
#         dropout = 0.1,
#         emb_dropout = 0.1,
#         layer_dropout = 0.05    # randomly dropout 5% of the layers
#     )
    
#     optimizer = Adam(learning_rate=0.001)
#     model.compile(loss=CategoricalCrossentropy(from_logits=True), 
#                   run_eagerly=True,
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)

#     return model

# %%
# from t2t import T2TViT

# def get_T2TViT(): 
#     model_T2TViT = T2TViT( # v1  # v1 accuracy: 0.4868 - f1_score: 0.4481 - val_loss: 1.3953 - val_accuracy: 0.5293 - val_f1_score: 0.4776
#         dim = 512,
#         image_size = max(MODEL_INPUT_SIZE[0], MODEL_INPUT_SIZE[1]),
#         depth = 5,
#         heads = 8,
#         mlp_dim = 512,
#         num_classes = NUM_CLASSES,
#         t2t_layers = ((7, 4), (3, 2), (3, 2)) # tuples of the kernel size and stride of each consecutive layers of the initial token to token module
#     )
    
#     optimizer = Adam(learning_rate=0.001)
#     model.compile(loss=CategoricalCrossentropy(from_logits=True), 
#                   run_eagerly=True,
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)

#     return model

# %%
# from tensorflow.keras.applications import MobileNet#### WORKING
# def get_MobileNet_original(): 
 
#     model = Sequential()
#     base_model = MobileNet(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)#57%
    
#     # Global average pooling and additional dense layers
#     x = Flatten()(base_model.output)
#     # x = Dense(512, activation='relu')(x)
#     predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
#     # Build the functional model
#     model = Model(inputs=base_model.input, outputs=predictions)

#     optimizer = Adam(learning_rate=0.001)
#     model.compile(loss="categorical_crossentropy", 
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
model= get_MobileNet_original()
# model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/120
# 104/104 [==============================] - ETA: 0s - loss: 2.2996 - accuracy: 0.2241 - f1_score: 0.1357
# Epoch 1: val_f1_score improved from -inf to 0.01653, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 78s 717ms/step - loss: 2.2996 - accuracy: 0.2241 - f1_score: 0.1357 - val_loss: 2.6884 - val_accuracy: 0.1204 - val_f1_score: 0.0165 - lr: 0.0010
# Epoch 2/120
# 104/104 [==============================] - ETA: 0s - loss: 2.0281 - accuracy: 0.3094 - f1_score: 0.2106
# Epoch 2: val_f1_score improved from 0.01653 to 0.01986, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 72s 688ms/step - loss: 2.0281 - accuracy: 0.3094 - f1_score: 0.2106 - val_loss: 3.3023 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 0.0010
# Epoch 3/120
# 104/104 [==============================] - ETA: 0s - loss: 1.7666 - accuracy: 0.3976 - f1_score: 0.3298
# Epoch 3: val_f1_score did not improve from 0.01986
# 104/104 [==============================] - 63s 597ms/step - loss: 1.7666 - accuracy: 0.3976 - f1_score: 0.3298 - val_loss: 3.8050 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 0.0010
# Epoch 4/120
# 104/104 [==============================] - ETA: 0s - loss: 1.5508 - accuracy: 0.4843 - f1_score: 0.4381
# Epoch 4: val_f1_score did not improve from 0.01986
# 104/104 [==============================] - 63s 601ms/step - loss: 1.5508 - accuracy: 0.4843 - f1_score: 0.4381 - val_loss: 4.3282 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 0.0010
# Epoch 5/120
# 104/104 [==============================] - ETA: 0s - loss: 1.3389 - accuracy: 0.5508 - f1_score: 0.5170
# Epoch 5: val_f1_score did not improve from 0.01986
# 104/104 [==============================] - 65s 619ms/step - loss: 1.3389 - accuracy: 0.5508 - f1_score: 0.5170 - val_loss: 4.2490 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 0.0010
# Epoch 6/120
# 104/104 [==============================] - ETA: 0s - loss: 1.1522 - accuracy: 0.6247 - f1_score: 0.6042
# Epoch 6: val_f1_score improved from 0.01986 to 0.03088, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 65s 629ms/step - loss: 1.1522 - accuracy: 0.6247 - f1_score: 0.6042 - val_loss: 5.0086 - val_accuracy: 0.1146 - val_f1_score: 0.0309 - lr: 0.0010
# Epoch 7/120
# 104/104 [==============================] - ETA: 0s - loss: 0.8755 - accuracy: 0.7105 - f1_score: 0.6910
# Epoch 7: val_f1_score improved from 0.03088 to 0.33090, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 68s 652ms/step - loss: 0.8755 - accuracy: 0.7105 - f1_score: 0.6910 - val_loss: 1.9643 - val_accuracy: 0.4068 - val_f1_score: 0.3309 - lr: 5.0000e-04
# Epoch 8/120
# 104/104 [==============================] - ETA: 0s - loss: 0.7582 - accuracy: 0.7519 - f1_score: 0.7378
# Epoch 8: val_f1_score improved from 0.33090 to 0.36344, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 64s 615ms/step - loss: 0.7582 - accuracy: 0.7519 - f1_score: 0.7378 - val_loss: 1.9455 - val_accuracy: 0.4365 - val_f1_score: 0.3634 - lr: 5.0000e-04
# Epoch 9/120
# 104/104 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.7719 - f1_score: 0.7588
# Epoch 9: val_f1_score improved from 0.36344 to 0.47188, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 66s 630ms/step - loss: 0.6929 - accuracy: 0.7719 - f1_score: 0.7588 - val_loss: 1.5251 - val_accuracy: 0.5581 - val_f1_score: 0.4719 - lr: 5.0000e-04
# Epoch 10/120
# 104/104 [==============================] - ETA: 0s - loss: 0.6079 - accuracy: 0.8002 - f1_score: 0.7895
# Epoch 10: val_f1_score improved from 0.47188 to 0.48995, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 72s 687ms/step - loss: 0.6079 - accuracy: 0.8002 - f1_score: 0.7895 - val_loss: 1.5963 - val_accuracy: 0.5519 - val_f1_score: 0.4900 - lr: 5.0000e-04
# Epoch 11/120
# 104/104 [==============================] - ETA: 0s - loss: 0.5060 - accuracy: 0.8368 - f1_score: 0.8328
# Epoch 11: val_f1_score did not improve from 0.48995
# 104/104 [==============================] - 78s 751ms/step - loss: 0.5060 - accuracy: 0.8368 - f1_score: 0.8328 - val_loss: 1.8084 - val_accuracy: 0.5168 - val_f1_score: 0.4614 - lr: 5.0000e-04
# Epoch 12/120
# 104/104 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.8399 - f1_score: 0.8282
# Epoch 12: val_f1_score did not improve from 0.48995
# 104/104 [==============================] - 73s 704ms/step - loss: 0.4871 - accuracy: 0.8399 - f1_score: 0.8282 - val_loss: 1.8013 - val_accuracy: 0.5114 - val_f1_score: 0.4434 - lr: 5.0000e-04
# Epoch 13/120
# 104/104 [==============================] - ETA: 0s - loss: 0.4453 - accuracy: 0.8548 - f1_score: 0.8462
# Epoch 13: val_f1_score did not improve from 0.48995
# 104/104 [==============================] - 89s 856ms/step - loss: 0.4453 - accuracy: 0.8548 - f1_score: 0.8462 - val_loss: 2.7321 - val_accuracy: 0.3902 - val_f1_score: 0.3186 - lr: 5.0000e-04
# Epoch 14/120
# 104/104 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.8581 - f1_score: 0.8502
# Epoch 14: val_f1_score improved from 0.48995 to 0.62025, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 76s 729ms/step - loss: 0.4255 - accuracy: 0.8581 - f1_score: 0.8502 - val_loss: 1.2156 - val_accuracy: 0.6434 - val_f1_score: 0.6202 - lr: 5.0000e-04
# Epoch 15/120
# 104/104 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8732 - f1_score: 0.8674
# Epoch 15: val_f1_score did not improve from 0.62025
# 104/104 [==============================] - 74s 705ms/step - loss: 0.3880 - accuracy: 0.8732 - f1_score: 0.8674 - val_loss: 2.0150 - val_accuracy: 0.4963 - val_f1_score: 0.4455 - lr: 5.0000e-04
# Epoch 16/120
# 104/104 [==============================] - ETA: 0s - loss: 0.3639 - accuracy: 0.8759 - f1_score: 0.8720
# Epoch 16: val_f1_score improved from 0.62025 to 0.64729, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 69s 659ms/step - loss: 0.3639 - accuracy: 0.8759 - f1_score: 0.8720 - val_loss: 1.1345 - val_accuracy: 0.6573 - val_f1_score: 0.6473 - lr: 5.0000e-04
# Epoch 17/120
# 104/104 [==============================] - ETA: 0s - loss: 0.3162 - accuracy: 0.8991 - f1_score: 0.8936
# Epoch 17: val_f1_score did not improve from 0.64729
# 104/104 [==============================] - 68s 650ms/step - loss: 0.3162 - accuracy: 0.8991 - f1_score: 0.8936 - val_loss: 1.3681 - val_accuracy: 0.6287 - val_f1_score: 0.5841 - lr: 5.0000e-04
# Epoch 18/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.9062 - f1_score: 0.9014
# Epoch 18: val_f1_score improved from 0.64729 to 0.65787, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 71s 678ms/step - loss: 0.2830 - accuracy: 0.9062 - f1_score: 0.9014 - val_loss: 1.0236 - val_accuracy: 0.6993 - val_f1_score: 0.6579 - lr: 5.0000e-04
# Epoch 19/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.9109 - f1_score: 0.9061
# Epoch 19: val_f1_score improved from 0.65787 to 0.69103, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 68s 649ms/step - loss: 0.2670 - accuracy: 0.9109 - f1_score: 0.9061 - val_loss: 1.0808 - val_accuracy: 0.6951 - val_f1_score: 0.6910 - lr: 5.0000e-04
# Epoch 20/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2517 - accuracy: 0.9180 - f1_score: 0.9166
# Epoch 20: val_f1_score improved from 0.69103 to 0.79455, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 68s 646ms/step - loss: 0.2517 - accuracy: 0.9180 - f1_score: 0.9166 - val_loss: 0.6697 - val_accuracy: 0.8070 - val_f1_score: 0.7945 - lr: 5.0000e-04
# Epoch 21/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9238 - f1_score: 0.9209
# Epoch 21: val_f1_score did not improve from 0.79455
# 104/104 [==============================] - 66s 634ms/step - loss: 0.2347 - accuracy: 0.9238 - f1_score: 0.9209 - val_loss: 0.8596 - val_accuracy: 0.7437 - val_f1_score: 0.7254 - lr: 5.0000e-04
# Epoch 22/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9264 - f1_score: 0.9245
# Epoch 22: val_f1_score did not improve from 0.79455
# 104/104 [==============================] - 62s 594ms/step - loss: 0.2231 - accuracy: 0.9264 - f1_score: 0.9245 - val_loss: 0.8908 - val_accuracy: 0.7487 - val_f1_score: 0.7448 - lr: 5.0000e-04
# Epoch 23/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9281 - f1_score: 0.9258
# Epoch 23: val_f1_score did not improve from 0.79455
# 104/104 [==============================] - 69s 659ms/step - loss: 0.2201 - accuracy: 0.9281 - f1_score: 0.9258 - val_loss: 2.0390 - val_accuracy: 0.5021 - val_f1_score: 0.4775 - lr: 5.0000e-04
# Epoch 24/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9259 - f1_score: 0.9240
# Epoch 24: val_f1_score did not improve from 0.79455
# 104/104 [==============================] - 73s 698ms/step - loss: 0.2201 - accuracy: 0.9259 - f1_score: 0.9240 - val_loss: 0.9432 - val_accuracy: 0.7337 - val_f1_score: 0.7296 - lr: 5.0000e-04
# Epoch 25/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9340 - f1_score: 0.9325
# Epoch 25: val_f1_score did not improve from 0.79455
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 72s 689ms/step - loss: 0.1996 - accuracy: 0.9340 - f1_score: 0.9325 - val_loss: 1.1700 - val_accuracy: 0.7132 - val_f1_score: 0.6786 - lr: 5.0000e-04
# Epoch 26/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9641 - f1_score: 0.9633
# Epoch 26: val_f1_score improved from 0.79455 to 0.89672, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 75s 719ms/step - loss: 0.1170 - accuracy: 0.9641 - f1_score: 0.9633 - val_loss: 0.3086 - val_accuracy: 0.9031 - val_f1_score: 0.8967 - lr: 2.5000e-04
# Epoch 27/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9716 - f1_score: 0.9711
# Epoch 27: val_f1_score improved from 0.89672 to 0.90177, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 75s 714ms/step - loss: 0.0886 - accuracy: 0.9716 - f1_score: 0.9711 - val_loss: 0.3198 - val_accuracy: 0.9066 - val_f1_score: 0.9018 - lr: 2.5000e-04
# Epoch 28/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9763 - f1_score: 0.9767
# Epoch 28: val_f1_score improved from 0.90177 to 0.90549, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 90s 864ms/step - loss: 0.0758 - accuracy: 0.9763 - f1_score: 0.9767 - val_loss: 0.3135 - val_accuracy: 0.9027 - val_f1_score: 0.9055 - lr: 2.5000e-04
# Epoch 29/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9777 - f1_score: 0.9774
# Epoch 29: val_f1_score did not improve from 0.90549
# 104/104 [==============================] - 87s 839ms/step - loss: 0.0724 - accuracy: 0.9777 - f1_score: 0.9774 - val_loss: 0.3607 - val_accuracy: 0.8935 - val_f1_score: 0.8940 - lr: 2.5000e-04
# Epoch 30/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9790 - f1_score: 0.9777
# Epoch 30: val_f1_score did not improve from 0.90549
# 104/104 [==============================] - 70s 670ms/step - loss: 0.0672 - accuracy: 0.9790 - f1_score: 0.9777 - val_loss: 0.3910 - val_accuracy: 0.8973 - val_f1_score: 0.8941 - lr: 2.5000e-04
# Epoch 31/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9790 - f1_score: 0.9780
# Epoch 31: val_f1_score did not improve from 0.90549
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 71s 679ms/step - loss: 0.0667 - accuracy: 0.9790 - f1_score: 0.9780 - val_loss: 0.3749 - val_accuracy: 0.8896 - val_f1_score: 0.8867 - lr: 2.5000e-04
# Epoch 32/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9830 - f1_score: 0.9827
# Epoch 32: val_f1_score improved from 0.90549 to 0.92369, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 75s 717ms/step - loss: 0.0594 - accuracy: 0.9830 - f1_score: 0.9827 - val_loss: 0.2583 - val_accuracy: 0.9274 - val_f1_score: 0.9237 - lr: 1.2500e-04
# Epoch 33/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9861 - f1_score: 0.9862
# Epoch 33: val_f1_score did not improve from 0.92369
# 104/104 [==============================] - 65s 624ms/step - loss: 0.0495 - accuracy: 0.9861 - f1_score: 0.9862 - val_loss: 0.3097 - val_accuracy: 0.9186 - val_f1_score: 0.9149 - lr: 1.2500e-04
# Epoch 34/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9860 - f1_score: 0.9860
# Epoch 34: val_f1_score did not improve from 0.92369
# 104/104 [==============================] - 63s 606ms/step - loss: 0.0455 - accuracy: 0.9860 - f1_score: 0.9860 - val_loss: 0.2710 - val_accuracy: 0.9240 - val_f1_score: 0.9210 - lr: 1.2500e-04
# Epoch 35/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9865 - f1_score: 0.9851
# Epoch 35: val_f1_score improved from 0.92369 to 0.92786, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 63s 609ms/step - loss: 0.0442 - accuracy: 0.9865 - f1_score: 0.9851 - val_loss: 0.2561 - val_accuracy: 0.9298 - val_f1_score: 0.9279 - lr: 1.2500e-04
# Epoch 36/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9859 - f1_score: 0.9854
# Epoch 36: val_f1_score improved from 0.92786 to 0.93168, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 63s 602ms/step - loss: 0.0448 - accuracy: 0.9859 - f1_score: 0.9854 - val_loss: 0.2706 - val_accuracy: 0.9290 - val_f1_score: 0.9317 - lr: 1.2500e-04
# Epoch 37/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9882 - f1_score: 0.9872
# Epoch 37: val_f1_score did not improve from 0.93168
# 104/104 [==============================] - 62s 592ms/step - loss: 0.0413 - accuracy: 0.9882 - f1_score: 0.9872 - val_loss: 0.2680 - val_accuracy: 0.9294 - val_f1_score: 0.9259 - lr: 1.2500e-04
# Epoch 38/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9864 - f1_score: 0.9861
# Epoch 38: val_f1_score improved from 0.93168 to 0.93326, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 62s 598ms/step - loss: 0.0429 - accuracy: 0.9864 - f1_score: 0.9861 - val_loss: 0.2417 - val_accuracy: 0.9340 - val_f1_score: 0.9333 - lr: 1.2500e-04
# Epoch 39/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9884 - f1_score: 0.9887
# Epoch 39: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 62s 595ms/step - loss: 0.0405 - accuracy: 0.9884 - f1_score: 0.9887 - val_loss: 0.2338 - val_accuracy: 0.9363 - val_f1_score: 0.9324 - lr: 1.2500e-04
# Epoch 40/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9857 - f1_score: 0.9851
# Epoch 40: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 63s 603ms/step - loss: 0.0434 - accuracy: 0.9857 - f1_score: 0.9851 - val_loss: 0.2585 - val_accuracy: 0.9244 - val_f1_score: 0.9201 - lr: 1.2500e-04
# Epoch 41/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9886 - f1_score: 0.9883
# Epoch 41: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 64s 609ms/step - loss: 0.0394 - accuracy: 0.9886 - f1_score: 0.9883 - val_loss: 0.2438 - val_accuracy: 0.9290 - val_f1_score: 0.9231 - lr: 1.2500e-04
# Epoch 42/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9886 - f1_score: 0.9886
# Epoch 42: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 65s 626ms/step - loss: 0.0378 - accuracy: 0.9886 - f1_score: 0.9886 - val_loss: 0.2646 - val_accuracy: 0.9282 - val_f1_score: 0.9236 - lr: 1.2500e-04
# Epoch 43/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9891 - f1_score: 0.9888
# Epoch 43: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 67s 640ms/step - loss: 0.0357 - accuracy: 0.9891 - f1_score: 0.9888 - val_loss: 0.2335 - val_accuracy: 0.9355 - val_f1_score: 0.9318 - lr: 1.2500e-04
# Epoch 44/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9882 - f1_score: 0.9880
# Epoch 44: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 77s 740ms/step - loss: 0.0382 - accuracy: 0.9882 - f1_score: 0.9880 - val_loss: 0.2775 - val_accuracy: 0.9286 - val_f1_score: 0.9257 - lr: 1.2500e-04
# Epoch 45/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9880 - f1_score: 0.9882
# Epoch 45: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 77s 742ms/step - loss: 0.0363 - accuracy: 0.9880 - f1_score: 0.9882 - val_loss: 0.2871 - val_accuracy: 0.9244 - val_f1_score: 0.9212 - lr: 1.2500e-04
# Epoch 46/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9886 - f1_score: 0.9884
# Epoch 46: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 80s 765ms/step - loss: 0.0370 - accuracy: 0.9886 - f1_score: 0.9884 - val_loss: 0.2540 - val_accuracy: 0.9271 - val_f1_score: 0.9227 - lr: 1.2500e-04
# Epoch 47/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9884 - f1_score: 0.9883
# Epoch 47: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 70s 669ms/step - loss: 0.0380 - accuracy: 0.9884 - f1_score: 0.9883 - val_loss: 0.2792 - val_accuracy: 0.9294 - val_f1_score: 0.9261 - lr: 1.2500e-04
# Epoch 48/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9882 - f1_score: 0.9878
# Epoch 48: val_f1_score did not improve from 0.93326
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 72s 687ms/step - loss: 0.0374 - accuracy: 0.9882 - f1_score: 0.9878 - val_loss: 0.2547 - val_accuracy: 0.9278 - val_f1_score: 0.9246 - lr: 1.2500e-04
# Epoch 49/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9914 - f1_score: 0.9910
# Epoch 49: val_f1_score did not improve from 0.93326
# 104/104 [==============================] - 79s 758ms/step - loss: 0.0281 - accuracy: 0.9914 - f1_score: 0.9910 - val_loss: 0.2710 - val_accuracy: 0.9282 - val_f1_score: 0.9236 - lr: 6.2500e-05
# Epoch 50/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9931 - f1_score: 0.9926
# Epoch 50: val_f1_score improved from 0.93326 to 0.93570, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 78s 754ms/step - loss: 0.0253 - accuracy: 0.9931 - f1_score: 0.9926 - val_loss: 0.2485 - val_accuracy: 0.9375 - val_f1_score: 0.9357 - lr: 6.2500e-05
# Epoch 51/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9918 - f1_score: 0.9914
# Epoch 51: val_f1_score did not improve from 0.93570
# 104/104 [==============================] - 78s 745ms/step - loss: 0.0251 - accuracy: 0.9918 - f1_score: 0.9914 - val_loss: 0.2398 - val_accuracy: 0.9363 - val_f1_score: 0.9344 - lr: 6.2500e-05
# Epoch 52/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9914 - f1_score: 0.9907
# Epoch 52: val_f1_score improved from 0.93570 to 0.93714, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 82s 784ms/step - loss: 0.0256 - accuracy: 0.9914 - f1_score: 0.9907 - val_loss: 0.2414 - val_accuracy: 0.9386 - val_f1_score: 0.9371 - lr: 6.2500e-05
# Epoch 53/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9927 - f1_score: 0.9922
# Epoch 53: val_f1_score did not improve from 0.93714
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 79s 756ms/step - loss: 0.0239 - accuracy: 0.9927 - f1_score: 0.9922 - val_loss: 0.2412 - val_accuracy: 0.9390 - val_f1_score: 0.9347 - lr: 6.2500e-05
# Epoch 54/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9936 - f1_score: 0.9938
# Epoch 54: val_f1_score improved from 0.93714 to 0.94389, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 76s 734ms/step - loss: 0.0210 - accuracy: 0.9936 - f1_score: 0.9938 - val_loss: 0.2258 - val_accuracy: 0.9460 - val_f1_score: 0.9439 - lr: 3.1250e-05
# Epoch 55/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9936 - f1_score: 0.9935
# Epoch 55: val_f1_score did not improve from 0.94389
# 104/104 [==============================] - 74s 712ms/step - loss: 0.0199 - accuracy: 0.9936 - f1_score: 0.9935 - val_loss: 0.2269 - val_accuracy: 0.9390 - val_f1_score: 0.9364 - lr: 3.1250e-05
# Epoch 56/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9939 - f1_score: 0.9934
# Epoch 56: val_f1_score improved from 0.94389 to 0.94666, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 81s 779ms/step - loss: 0.0206 - accuracy: 0.9939 - f1_score: 0.9934 - val_loss: 0.2173 - val_accuracy: 0.9483 - val_f1_score: 0.9467 - lr: 3.1250e-05
# Epoch 57/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9936 - f1_score: 0.9933
# Epoch 57: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 82s 791ms/step - loss: 0.0199 - accuracy: 0.9936 - f1_score: 0.9933 - val_loss: 0.2199 - val_accuracy: 0.9429 - val_f1_score: 0.9407 - lr: 3.1250e-05
# Epoch 58/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9948 - f1_score: 0.9943
# Epoch 58: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 81s 780ms/step - loss: 0.0181 - accuracy: 0.9948 - f1_score: 0.9943 - val_loss: 0.2246 - val_accuracy: 0.9406 - val_f1_score: 0.9391 - lr: 3.1250e-05
# Epoch 59/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9954 - f1_score: 0.9956
# Epoch 59: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 81s 781ms/step - loss: 0.0169 - accuracy: 0.9954 - f1_score: 0.9956 - val_loss: 0.2262 - val_accuracy: 0.9406 - val_f1_score: 0.9364 - lr: 3.1250e-05
# Epoch 60/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9942 - f1_score: 0.9943
# Epoch 60: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 73s 694ms/step - loss: 0.0174 - accuracy: 0.9942 - f1_score: 0.9943 - val_loss: 0.2135 - val_accuracy: 0.9433 - val_f1_score: 0.9411 - lr: 3.1250e-05
# Epoch 61/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9945 - f1_score: 0.9942
# Epoch 61: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 75s 725ms/step - loss: 0.0177 - accuracy: 0.9945 - f1_score: 0.9942 - val_loss: 0.2171 - val_accuracy: 0.9444 - val_f1_score: 0.9427 - lr: 3.1250e-05
# Epoch 62/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9939 - f1_score: 0.9937
# Epoch 62: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 68s 649ms/step - loss: 0.0191 - accuracy: 0.9939 - f1_score: 0.9937 - val_loss: 0.2119 - val_accuracy: 0.9413 - val_f1_score: 0.9359 - lr: 3.1250e-05
# Epoch 63/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9947 - f1_score: 0.9945
# Epoch 63: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 75s 717ms/step - loss: 0.0170 - accuracy: 0.9947 - f1_score: 0.9945 - val_loss: 0.2412 - val_accuracy: 0.9398 - val_f1_score: 0.9387 - lr: 3.1250e-05
# Epoch 64/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9945 - f1_score: 0.9942
# Epoch 64: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 83s 803ms/step - loss: 0.0171 - accuracy: 0.9945 - f1_score: 0.9942 - val_loss: 0.2388 - val_accuracy: 0.9425 - val_f1_score: 0.9408 - lr: 3.1250e-05
# Epoch 65/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9939 - f1_score: 0.9938
# Epoch 65: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 97s 931ms/step - loss: 0.0194 - accuracy: 0.9939 - f1_score: 0.9938 - val_loss: 0.2334 - val_accuracy: 0.9437 - val_f1_score: 0.9416 - lr: 3.1250e-05
# Epoch 66/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9951 - f1_score: 0.9947
# Epoch 66: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 77s 736ms/step - loss: 0.0168 - accuracy: 0.9951 - f1_score: 0.9947 - val_loss: 0.2444 - val_accuracy: 0.9406 - val_f1_score: 0.9376 - lr: 3.1250e-05
# Epoch 67/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9939 - f1_score: 0.9939
# Epoch 67: val_f1_score did not improve from 0.94666
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 76s 724ms/step - loss: 0.0165 - accuracy: 0.9939 - f1_score: 0.9939 - val_loss: 0.2356 - val_accuracy: 0.9425 - val_f1_score: 0.9408 - lr: 3.1250e-05
# Epoch 68/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9947 - f1_score: 0.9944
# Epoch 68: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 77s 743ms/step - loss: 0.0163 - accuracy: 0.9947 - f1_score: 0.9944 - val_loss: 0.2227 - val_accuracy: 0.9433 - val_f1_score: 0.9404 - lr: 1.5625e-05
# Epoch 69/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9945 - f1_score: 0.9940
# Epoch 69: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 69s 664ms/step - loss: 0.0178 - accuracy: 0.9945 - f1_score: 0.9940 - val_loss: 0.2209 - val_accuracy: 0.9460 - val_f1_score: 0.9433 - lr: 1.5625e-05
# Epoch 70/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9952 - f1_score: 0.9949
# Epoch 70: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 73s 697ms/step - loss: 0.0158 - accuracy: 0.9952 - f1_score: 0.9949 - val_loss: 0.2278 - val_accuracy: 0.9425 - val_f1_score: 0.9389 - lr: 1.5625e-05
# Epoch 71/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9947 - f1_score: 0.9944
# Epoch 71: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 72s 695ms/step - loss: 0.0150 - accuracy: 0.9947 - f1_score: 0.9944 - val_loss: 0.2146 - val_accuracy: 0.9437 - val_f1_score: 0.9406 - lr: 1.5625e-05
# Epoch 72/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9955 - f1_score: 0.9948
# Epoch 72: val_f1_score did not improve from 0.94666
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 103s 993ms/step - loss: 0.0157 - accuracy: 0.9955 - f1_score: 0.9948 - val_loss: 0.2293 - val_accuracy: 0.9452 - val_f1_score: 0.9462 - lr: 1.5625e-05
# Epoch 73/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9945 - f1_score: 0.9946
# Epoch 73: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 95s 912ms/step - loss: 0.0166 - accuracy: 0.9945 - f1_score: 0.9946 - val_loss: 0.2307 - val_accuracy: 0.9444 - val_f1_score: 0.9423 - lr: 7.8125e-06
# Epoch 74/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9954 - f1_score: 0.9950
# Epoch 74: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 80s 772ms/step - loss: 0.0149 - accuracy: 0.9954 - f1_score: 0.9950 - val_loss: 0.2076 - val_accuracy: 0.9471 - val_f1_score: 0.9464 - lr: 7.8125e-06
# Epoch 75/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9966 - f1_score: 0.9966
# Epoch 75: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 94s 906ms/step - loss: 0.0129 - accuracy: 0.9966 - f1_score: 0.9966 - val_loss: 0.2208 - val_accuracy: 0.9452 - val_f1_score: 0.9407 - lr: 7.8125e-06
# Epoch 76/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9951 - f1_score: 0.9947
# Epoch 76: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 91s 872ms/step - loss: 0.0147 - accuracy: 0.9951 - f1_score: 0.9947 - val_loss: 0.2071 - val_accuracy: 0.9460 - val_f1_score: 0.9427 - lr: 7.8125e-06
# Epoch 77/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9943 - f1_score: 0.9942
# Epoch 77: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 88s 844ms/step - loss: 0.0165 - accuracy: 0.9943 - f1_score: 0.9942 - val_loss: 0.2203 - val_accuracy: 0.9464 - val_f1_score: 0.9422 - lr: 7.8125e-06
# Epoch 78/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9958 - f1_score: 0.9957
# Epoch 78: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 86s 831ms/step - loss: 0.0136 - accuracy: 0.9958 - f1_score: 0.9957 - val_loss: 0.2276 - val_accuracy: 0.9413 - val_f1_score: 0.9368 - lr: 7.8125e-06
# Epoch 79/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9957 - f1_score: 0.9955
# Epoch 79: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 78s 747ms/step - loss: 0.0142 - accuracy: 0.9957 - f1_score: 0.9955 - val_loss: 0.2180 - val_accuracy: 0.9398 - val_f1_score: 0.9377 - lr: 7.8125e-06
# Epoch 80/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9954 - f1_score: 0.9948
# Epoch 80: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 65s 625ms/step - loss: 0.0138 - accuracy: 0.9954 - f1_score: 0.9948 - val_loss: 0.2226 - val_accuracy: 0.9437 - val_f1_score: 0.9407 - lr: 7.8125e-06
# Epoch 81/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9964 - f1_score: 0.9960
# Epoch 81: val_f1_score did not improve from 0.94666
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 104/104 [==============================] - 64s 616ms/step - loss: 0.0133 - accuracy: 0.9964 - f1_score: 0.9960 - val_loss: 0.2203 - val_accuracy: 0.9471 - val_f1_score: 0.9432 - lr: 7.8125e-06
# Epoch 82/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9962 - f1_score: 0.9964
# Epoch 82: val_f1_score did not improve from 0.94666
# 104/104 [==============================] - 64s 614ms/step - loss: 0.0133 - accuracy: 0.9962 - f1_score: 0.9964 - val_loss: 0.2181 - val_accuracy: 0.9440 - val_f1_score: 0.9377 - lr: 3.9063e-06
# Epoch 83/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9959 - f1_score: 0.9958
# Epoch 83: val_f1_score improved from 0.94666 to 0.95293, saving model to saved_outputs_basic_augment\MobileNet\saved_models\best_MobileNet.h5
# 104/104 [==============================] - 64s 617ms/step - loss: 0.0137 - accuracy: 0.9959 - f1_score: 0.9958 - val_loss: 0.1973 - val_accuracy: 0.9537 - val_f1_score: 0.9529 - lr: 3.9063e-06
# Epoch 84/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9955 - f1_score: 0.9953
# Epoch 84: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 62s 599ms/step - loss: 0.0151 - accuracy: 0.9955 - f1_score: 0.9953 - val_loss: 0.2177 - val_accuracy: 0.9479 - val_f1_score: 0.9434 - lr: 3.9063e-06
# Epoch 85/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9959 - f1_score: 0.9951
# Epoch 85: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 604ms/step - loss: 0.0134 - accuracy: 0.9959 - f1_score: 0.9951 - val_loss: 0.2175 - val_accuracy: 0.9483 - val_f1_score: 0.9455 - lr: 3.9063e-06
# Epoch 86/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9949 - f1_score: 0.9948
# Epoch 86: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 607ms/step - loss: 0.0145 - accuracy: 0.9949 - f1_score: 0.9948 - val_loss: 0.2284 - val_accuracy: 0.9444 - val_f1_score: 0.9427 - lr: 3.9063e-06
# Epoch 87/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9960 - f1_score: 0.9960
# Epoch 87: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 602ms/step - loss: 0.0128 - accuracy: 0.9960 - f1_score: 0.9960 - val_loss: 0.2141 - val_accuracy: 0.9464 - val_f1_score: 0.9436 - lr: 3.9063e-06
# Epoch 88/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9968 - f1_score: 0.9965
# Epoch 88: val_f1_score did not improve from 0.95293
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 104/104 [==============================] - 62s 598ms/step - loss: 0.0123 - accuracy: 0.9968 - f1_score: 0.9965 - val_loss: 0.2090 - val_accuracy: 0.9467 - val_f1_score: 0.9474 - lr: 3.9063e-06
# Epoch 89/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9961 - f1_score: 0.9955
# Epoch 89: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 603ms/step - loss: 0.0147 - accuracy: 0.9961 - f1_score: 0.9955 - val_loss: 0.2309 - val_accuracy: 0.9406 - val_f1_score: 0.9368 - lr: 1.9531e-06
# Epoch 90/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9961 - f1_score: 0.9962
# Epoch 90: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 64s 610ms/step - loss: 0.0129 - accuracy: 0.9961 - f1_score: 0.9962 - val_loss: 0.2184 - val_accuracy: 0.9460 - val_f1_score: 0.9433 - lr: 1.9531e-06
# Epoch 91/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9951 - f1_score: 0.9949
# Epoch 91: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 603ms/step - loss: 0.0140 - accuracy: 0.9951 - f1_score: 0.9949 - val_loss: 0.2175 - val_accuracy: 0.9425 - val_f1_score: 0.9401 - lr: 1.9531e-06
# Epoch 92/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9964 - f1_score: 0.9962
# Epoch 92: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 72s 692ms/step - loss: 0.0117 - accuracy: 0.9964 - f1_score: 0.9962 - val_loss: 0.2358 - val_accuracy: 0.9421 - val_f1_score: 0.9413 - lr: 1.9531e-06
# Epoch 93/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9949 - f1_score: 0.9949
# Epoch 93: val_f1_score did not improve from 0.95293
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 104/104 [==============================] - 77s 746ms/step - loss: 0.0146 - accuracy: 0.9949 - f1_score: 0.9949 - val_loss: 0.2374 - val_accuracy: 0.9398 - val_f1_score: 0.9365 - lr: 1.9531e-06
# Epoch 94/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9957 - f1_score: 0.9952
# Epoch 94: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 74s 716ms/step - loss: 0.0126 - accuracy: 0.9957 - f1_score: 0.9952 - val_loss: 0.2202 - val_accuracy: 0.9502 - val_f1_score: 0.9498 - lr: 9.7656e-07
# Epoch 95/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9962 - f1_score: 0.9963
# Epoch 95: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 76s 729ms/step - loss: 0.0127 - accuracy: 0.9962 - f1_score: 0.9963 - val_loss: 0.2131 - val_accuracy: 0.9479 - val_f1_score: 0.9421 - lr: 9.7656e-07
# Epoch 96/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9959 - f1_score: 0.9952
# Epoch 96: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 72s 688ms/step - loss: 0.0126 - accuracy: 0.9959 - f1_score: 0.9952 - val_loss: 0.2313 - val_accuracy: 0.9417 - val_f1_score: 0.9404 - lr: 9.7656e-07
# Epoch 97/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9956 - f1_score: 0.9955
# Epoch 97: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 81s 775ms/step - loss: 0.0130 - accuracy: 0.9956 - f1_score: 0.9955 - val_loss: 0.2257 - val_accuracy: 0.9433 - val_f1_score: 0.9378 - lr: 9.7656e-07
# Epoch 98/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9961 - f1_score: 0.9960
# Epoch 98: val_f1_score did not improve from 0.95293
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 104/104 [==============================] - 77s 740ms/step - loss: 0.0134 - accuracy: 0.9961 - f1_score: 0.9960 - val_loss: 0.2306 - val_accuracy: 0.9440 - val_f1_score: 0.9408 - lr: 9.7656e-07
# Epoch 99/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9966 - f1_score: 0.9965
# Epoch 99: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 66s 632ms/step - loss: 0.0110 - accuracy: 0.9966 - f1_score: 0.9965 - val_loss: 0.2133 - val_accuracy: 0.9456 - val_f1_score: 0.9406 - lr: 4.8828e-07
# Epoch 100/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9964 - f1_score: 0.9962
# Epoch 100: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 66s 632ms/step - loss: 0.0126 - accuracy: 0.9964 - f1_score: 0.9962 - val_loss: 0.2209 - val_accuracy: 0.9437 - val_f1_score: 0.9396 - lr: 4.8828e-07
# Epoch 101/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9968 - f1_score: 0.9965
# Epoch 101: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 607ms/step - loss: 0.0106 - accuracy: 0.9968 - f1_score: 0.9965 - val_loss: 0.2220 - val_accuracy: 0.9437 - val_f1_score: 0.9417 - lr: 4.8828e-07
# Epoch 102/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9957 - f1_score: 0.9953
# Epoch 102: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 62s 599ms/step - loss: 0.0136 - accuracy: 0.9957 - f1_score: 0.9953 - val_loss: 0.2302 - val_accuracy: 0.9406 - val_f1_score: 0.9380 - lr: 4.8828e-07
# Epoch 103/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9963 - f1_score: 0.9958
# Epoch 103: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 64s 617ms/step - loss: 0.0129 - accuracy: 0.9963 - f1_score: 0.9958 - val_loss: 0.1957 - val_accuracy: 0.9494 - val_f1_score: 0.9502 - lr: 4.8828e-07
# Epoch 104/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9962 - f1_score: 0.9962
# Epoch 104: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 64s 611ms/step - loss: 0.0130 - accuracy: 0.9962 - f1_score: 0.9962 - val_loss: 0.2149 - val_accuracy: 0.9433 - val_f1_score: 0.9421 - lr: 4.8828e-07
# Epoch 105/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9961 - f1_score: 0.9959
# Epoch 105: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 64s 611ms/step - loss: 0.0122 - accuracy: 0.9961 - f1_score: 0.9959 - val_loss: 0.2267 - val_accuracy: 0.9464 - val_f1_score: 0.9461 - lr: 4.8828e-07
# Epoch 106/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9966 - f1_score: 0.9964
# Epoch 106: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 63s 603ms/step - loss: 0.0121 - accuracy: 0.9966 - f1_score: 0.9964 - val_loss: 0.2246 - val_accuracy: 0.9448 - val_f1_score: 0.9409 - lr: 4.8828e-07
# Epoch 107/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9968 - f1_score: 0.9966
# Epoch 107: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 62s 597ms/step - loss: 0.0112 - accuracy: 0.9968 - f1_score: 0.9966 - val_loss: 0.2128 - val_accuracy: 0.9437 - val_f1_score: 0.9432 - lr: 4.8828e-07
# Epoch 108/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9965 - f1_score: 0.9965
# Epoch 108: val_f1_score did not improve from 0.95293
#
# Epoch 108: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 104/104 [==============================] - 66s 631ms/step - loss: 0.0116 - accuracy: 0.9965 - f1_score: 0.9965 - val_loss: 0.2384 - val_accuracy: 0.9425 - val_f1_score: 0.9399 - lr: 4.8828e-07
# Epoch 109/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9961 - f1_score: 0.9958
# Epoch 109: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 68s 648ms/step - loss: 0.0139 - accuracy: 0.9961 - f1_score: 0.9958 - val_loss: 0.2197 - val_accuracy: 0.9483 - val_f1_score: 0.9452 - lr: 2.4414e-07
# Epoch 110/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9967 - f1_score: 0.9968
# Epoch 110: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 75s 721ms/step - loss: 0.0123 - accuracy: 0.9967 - f1_score: 0.9968 - val_loss: 0.2038 - val_accuracy: 0.9471 - val_f1_score: 0.9433 - lr: 2.4414e-07
# Epoch 111/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9963 - f1_score: 0.9963
# Epoch 111: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 80s 769ms/step - loss: 0.0116 - accuracy: 0.9963 - f1_score: 0.9963 - val_loss: 0.2132 - val_accuracy: 0.9452 - val_f1_score: 0.9430 - lr: 2.4414e-07
# Epoch 112/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9968 - f1_score: 0.9968
# Epoch 112: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 73s 700ms/step - loss: 0.0121 - accuracy: 0.9968 - f1_score: 0.9968 - val_loss: 0.2084 - val_accuracy: 0.9448 - val_f1_score: 0.9434 - lr: 2.4414e-07
# Epoch 113/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9953 - f1_score: 0.9950
# Epoch 113: val_f1_score did not improve from 0.95293
#
# Epoch 113: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 104/104 [==============================] - 75s 717ms/step - loss: 0.0139 - accuracy: 0.9953 - f1_score: 0.9950 - val_loss: 0.2192 - val_accuracy: 0.9464 - val_f1_score: 0.9450 - lr: 2.4414e-07
# Epoch 114/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9959 - f1_score: 0.9956
# Epoch 114: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 68s 646ms/step - loss: 0.0126 - accuracy: 0.9959 - f1_score: 0.9956 - val_loss: 0.2228 - val_accuracy: 0.9471 - val_f1_score: 0.9456 - lr: 1.2207e-07
# Epoch 115/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9962 - f1_score: 0.9961
# Epoch 115: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0126 - accuracy: 0.9962 - f1_score: 0.9961 - val_loss: 0.2437 - val_accuracy: 0.9437 - val_f1_score: 0.9424 - lr: 1.2207e-07
# Epoch 116/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9963 - f1_score: 0.9958
# Epoch 116: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 75s 720ms/step - loss: 0.0135 - accuracy: 0.9963 - f1_score: 0.9958 - val_loss: 0.2209 - val_accuracy: 0.9460 - val_f1_score: 0.9436 - lr: 1.2207e-07
# Epoch 117/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9961 - f1_score: 0.9962
# Epoch 117: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 74s 712ms/step - loss: 0.0121 - accuracy: 0.9961 - f1_score: 0.9962 - val_loss: 0.2188 - val_accuracy: 0.9425 - val_f1_score: 0.9395 - lr: 1.2207e-07
# Epoch 118/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9965 - f1_score: 0.9963
# Epoch 118: val_f1_score did not improve from 0.95293
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 104/104 [==============================] - 63s 603ms/step - loss: 0.0126 - accuracy: 0.9965 - f1_score: 0.9963 - val_loss: 0.2229 - val_accuracy: 0.9409 - val_f1_score: 0.9375 - lr: 1.2207e-07
# Epoch 119/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9965 - f1_score: 0.9966
# Epoch 119: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 66s 631ms/step - loss: 0.0117 - accuracy: 0.9965 - f1_score: 0.9966 - val_loss: 0.2085 - val_accuracy: 0.9471 - val_f1_score: 0.9437 - lr: 6.1035e-08
# Epoch 120/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9976 - f1_score: 0.9974
# Epoch 120: val_f1_score did not improve from 0.95293
# 104/104 [==============================] - 73s 703ms/step - loss: 0.0115 - accuracy: 0.9976 - f1_score: 0.9974 - val_loss: 0.2289 - val_accuracy: 0.9437 - val_f1_score: 0.9411 - lr: 6.1035e-08

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 5s 118ms/step - loss: 0.4379 - accuracy: 0.8872 - f1_score: 0.8823
#   model_name  test_loss  test_accuracy  test_f1_score
# 0  MobileNet   0.437932       0.887211       0.882305

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 4s 118ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.792857  0.853846  0.822222   130.000000
# 1              0.926316  0.880000  0.902564   100.000000
# 2              0.912500  0.811111  0.858824    90.000000
# 3              0.965517  0.831683  0.893617   101.000000
# 4              0.880903  0.912766  0.896552   470.000000
# 5              0.857692  0.881423  0.869396   253.000000
# 6              0.912500  0.839080  0.874251   174.000000
# 7              0.912322  0.893271  0.902696   431.000000
# 8              0.809735  0.835616  0.822472   219.000000
# 9              0.889780  0.923077  0.906122   481.000000
# 10             0.857488  0.910256  0.883085   390.000000
# 11             0.948718  0.874016  0.909836   254.000000
# 12             0.964539  0.894737  0.928328   152.000000
# accuracy       0.887211  0.887211  0.887211     0.887211
# macro avg      0.894682  0.872376  0.882305  3245.000000
# weighted avg   0.889267  0.887211  0.887453  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#   Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  MobileNet  0.887211         0.894682      0.872376        0.882305
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.889267         0.887211           0.887453  0.437932

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.88721
# 1      Macro Precision  0.89468
# 2         Macro Recall  0.87238
# 3       Macro F1-Score  0.88230
# 4            Macro FPR  0.00970
# 5            Macro FNR  0.12762
# 6            Macro FDR  0.10532
# 7            Macro NPV  0.99042
# 8   Weighted Precision  0.88927
# 9      Weighted Recall  0.88721
# 10   Weighted F1-Score  0.88745
# 11        Weighted FPR  0.01330
# 12        Weighted FNR  0.11279
# 13        Weighted FDR  0.11073
# 14        Weighted NPV  0.98837
