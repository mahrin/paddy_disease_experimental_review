# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, Activation, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')
######################################################################################################
from keras_tuner import RandomSearch, HyperParameters
from tensorflow.keras.applications import Xception, DenseNet121
import keras_tuner as kt

# %%
model_name = 'Ensemble2_v2'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 
# FNAME_TUNER_REPORT = 'Report_tune_'+ model_name
################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_SAVE_RESULT, 'saved_tuner_model')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 150 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\Ensemble2_v2
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\Ensemble2_v2\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\Ensemble2_v2\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_13656\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':  
            print("Here in basic")
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set


                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Here in basic
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=15, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING
#
# Trial 15 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 9
# Score: 0.7056062817573547
#
# Trial 11 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 5
# Score: 0.705497920513153179205131531

# %%
# Function to build the model with an ensemble of feature extractors
def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
                      dropout= 0.1,
                      activation='relu',
                      units= 1024,
                      nr_classes=NUM_CLASSES,
                      loss = "categorical_crossentropy", 
                      retrain_backbone_network=False,
                      learning_rate = 0.001,
                      global_pooling = 'avg',
                      filters=7,
                      name='ensemble2'):


    inputs = Input(shape=input_shape)

    # Feature extraction from Xception
    Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    Xception_features = Xception_base(inputs)
    Xception_features = GlobalAveragePooling2D()(Xception_features)

    # Feature extraction from DenseNet121
    densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
    densenet_features = densenet_base(inputs)
    densenet_features = GlobalAveragePooling2D()(densenet_features)

    # Concatenate features
    concatenated_features = Concatenate()([Xception_features, densenet_features])

    if filters==3:
        filters = (3,3)
    elif filters==5:
        filters = (5,5)
    elif filters==7:
        filters = (7,7)
    elif filters==9:
        filters = (9,9)

    # # Add a tunable dropout layer
    # x = Dropout(dropout)(concatenated_features)

    # # A fully connected layer with a tunable number of units
    # x = Dense(units)(x)

    #     # Add a tunable dropout layer
    # x = Dropout(dropout)(x)

    # # A fully connected layer with a tunable number of units
    # x = Dense(units)(x)
        # Add a tunable dropout layer
    x = Dropout(dropout)(concatenated_features)

    # A fully connected layer with a tunable number of units
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)

    # Add a tunable dropout layer
    x = Dropout(dropout)(x)

    # A fully connected layer with a tunable number of units again
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)


    # Output layer
    predictions = Dense( nr_classes, activation='softmax')(x)

    # Create and compile the model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=loss,
        metrics=['accuracy', f1_score]
    )

    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN() 
model = get_ensemble2_model()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/150
# 104/104 [==============================] - ETA: 0s - loss: 1.9266 - accuracy: 0.4396 - f1_score: 0.3929
# Epoch 1: val_f1_score improved from -inf to 0.40490, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 97s 842ms/step - loss: 1.9266 - accuracy: 0.4396 - f1_score: 0.3929 - val_loss: 1.7261 - val_accuracy: 0.4701 - val_f1_score: 0.4049 - lr: 0.0010
# Epoch 2/150
# 104/104 [==============================] - ETA: 0s - loss: 1.3178 - accuracy: 0.5822 - f1_score: 0.5519
# Epoch 2: val_f1_score improved from 0.40490 to 0.56984, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 82s 783ms/step - loss: 1.3178 - accuracy: 0.5822 - f1_score: 0.5519 - val_loss: 1.2993 - val_accuracy: 0.5905 - val_f1_score: 0.5698 - lr: 0.0010
# Epoch 3/150
# 104/104 [==============================] - ETA: 0s - loss: 1.1281 - accuracy: 0.6410 - f1_score: 0.6183
# Epoch 3: val_f1_score improved from 0.56984 to 0.63423, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 81s 779ms/step - loss: 1.1281 - accuracy: 0.6410 - f1_score: 0.6183 - val_loss: 1.0852 - val_accuracy: 0.6727 - val_f1_score: 0.6342 - lr: 0.0010
# Epoch 4/150
# 104/104 [==============================] - ETA: 0s - loss: 1.0057 - accuracy: 0.6758 - f1_score: 0.6600
# Epoch 4: val_f1_score improved from 0.63423 to 0.67864, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 85s 821ms/step - loss: 1.0057 - accuracy: 0.6758 - f1_score: 0.6600 - val_loss: 0.9688 - val_accuracy: 0.6839 - val_f1_score: 0.6786 - lr: 0.0010
# Epoch 5/150
# 104/104 [==============================] - ETA: 0s - loss: 0.9298 - accuracy: 0.7029 - f1_score: 0.6867
# Epoch 5: val_f1_score improved from 0.67864 to 0.68267, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 80s 769ms/step - loss: 0.9298 - accuracy: 0.7029 - f1_score: 0.6867 - val_loss: 1.0376 - val_accuracy: 0.6816 - val_f1_score: 0.6827 - lr: 0.0010
# Epoch 6/150
# 104/104 [==============================] - ETA: 0s - loss: 0.8495 - accuracy: 0.7229 - f1_score: 0.7117
# Epoch 6: val_f1_score improved from 0.68267 to 0.69677, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 743ms/step - loss: 0.8495 - accuracy: 0.7229 - f1_score: 0.7117 - val_loss: 0.9121 - val_accuracy: 0.7117 - val_f1_score: 0.6968 - lr: 0.0010
# Epoch 7/150
# 104/104 [==============================] - ETA: 0s - loss: 0.8100 - accuracy: 0.7386 - f1_score: 0.7235
# Epoch 7: val_f1_score improved from 0.69677 to 0.72509, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 747ms/step - loss: 0.8100 - accuracy: 0.7386 - f1_score: 0.7235 - val_loss: 0.8154 - val_accuracy: 0.7395 - val_f1_score: 0.7251 - lr: 0.0010
# Epoch 8/150
# 104/104 [==============================] - ETA: 0s - loss: 0.7550 - accuracy: 0.7511 - f1_score: 0.7375
# Epoch 8: val_f1_score did not improve from 0.72509
# 104/104 [==============================] - 76s 728ms/step - loss: 0.7550 - accuracy: 0.7511 - f1_score: 0.7375 - val_loss: 0.8029 - val_accuracy: 0.7372 - val_f1_score: 0.7239 - lr: 0.0010
# Epoch 9/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.7733 - f1_score: 0.7622
# Epoch 9: val_f1_score improved from 0.72509 to 0.72703, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 77s 743ms/step - loss: 0.6939 - accuracy: 0.7733 - f1_score: 0.7622 - val_loss: 0.8124 - val_accuracy: 0.7395 - val_f1_score: 0.7270 - lr: 0.0010
# Epoch 10/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.7751 - f1_score: 0.7638
# Epoch 10: val_f1_score improved from 0.72703 to 0.74380, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 751ms/step - loss: 0.6888 - accuracy: 0.7751 - f1_score: 0.7638 - val_loss: 0.7808 - val_accuracy: 0.7557 - val_f1_score: 0.7438 - lr: 0.0010
# Epoch 11/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6562 - accuracy: 0.7876 - f1_score: 0.7804
# Epoch 11: val_f1_score improved from 0.74380 to 0.75658, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 75s 719ms/step - loss: 0.6562 - accuracy: 0.7876 - f1_score: 0.7804 - val_loss: 0.7804 - val_accuracy: 0.7545 - val_f1_score: 0.7566 - lr: 0.0010
# Epoch 12/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.7931 - f1_score: 0.7840
# Epoch 12: val_f1_score improved from 0.75658 to 0.76517, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 749ms/step - loss: 0.6236 - accuracy: 0.7931 - f1_score: 0.7840 - val_loss: 0.7005 - val_accuracy: 0.7769 - val_f1_score: 0.7652 - lr: 0.0010
# Epoch 13/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.8062 - f1_score: 0.7968
# Epoch 13: val_f1_score improved from 0.76517 to 0.76835, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 731ms/step - loss: 0.5979 - accuracy: 0.8062 - f1_score: 0.7968 - val_loss: 0.7616 - val_accuracy: 0.7680 - val_f1_score: 0.7684 - lr: 0.0010
# Epoch 14/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5758 - accuracy: 0.8101 - f1_score: 0.8027
# Epoch 14: val_f1_score improved from 0.76835 to 0.79036, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 82s 790ms/step - loss: 0.5758 - accuracy: 0.8101 - f1_score: 0.8027 - val_loss: 0.6840 - val_accuracy: 0.7939 - val_f1_score: 0.7904 - lr: 0.0010
# Epoch 15/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5487 - accuracy: 0.8162 - f1_score: 0.8108
# Epoch 15: val_f1_score improved from 0.79036 to 0.79605, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 745ms/step - loss: 0.5487 - accuracy: 0.8162 - f1_score: 0.8108 - val_loss: 0.6299 - val_accuracy: 0.7981 - val_f1_score: 0.7961 - lr: 0.0010
# Epoch 16/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.8304 - f1_score: 0.8258
# Epoch 16: val_f1_score improved from 0.79605 to 0.80492, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 80s 764ms/step - loss: 0.5228 - accuracy: 0.8304 - f1_score: 0.8258 - val_loss: 0.5910 - val_accuracy: 0.8086 - val_f1_score: 0.8049 - lr: 0.0010
# Epoch 17/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5006 - accuracy: 0.8338 - f1_score: 0.8264
# Epoch 17: val_f1_score did not improve from 0.80492
# 104/104 [==============================] - 74s 708ms/step - loss: 0.5006 - accuracy: 0.8338 - f1_score: 0.8264 - val_loss: 0.6279 - val_accuracy: 0.8055 - val_f1_score: 0.7976 - lr: 0.0010
# Epoch 18/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.8433 - f1_score: 0.8380
# Epoch 18: val_f1_score improved from 0.80492 to 0.81372, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 743ms/step - loss: 0.4897 - accuracy: 0.8433 - f1_score: 0.8380 - val_loss: 0.5914 - val_accuracy: 0.8151 - val_f1_score: 0.8137 - lr: 0.0010
# Epoch 19/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4865 - accuracy: 0.8399 - f1_score: 0.8336
# Epoch 19: val_f1_score did not improve from 0.81372
# 104/104 [==============================] - 71s 676ms/step - loss: 0.4865 - accuracy: 0.8399 - f1_score: 0.8336 - val_loss: 0.6056 - val_accuracy: 0.8066 - val_f1_score: 0.8012 - lr: 0.0010
# Epoch 20/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8401 - f1_score: 0.8354
# Epoch 20: val_f1_score did not improve from 0.81372
# 104/104 [==============================] - 93s 893ms/step - loss: 0.4803 - accuracy: 0.8401 - f1_score: 0.8354 - val_loss: 0.6207 - val_accuracy: 0.8093 - val_f1_score: 0.8059 - lr: 0.0010
# Epoch 21/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4770 - accuracy: 0.8426 - f1_score: 0.8371
# Epoch 21: val_f1_score improved from 0.81372 to 0.81915, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 80s 764ms/step - loss: 0.4770 - accuracy: 0.8426 - f1_score: 0.8371 - val_loss: 0.5531 - val_accuracy: 0.8267 - val_f1_score: 0.8192 - lr: 0.0010
# Epoch 22/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4424 - accuracy: 0.8576 - f1_score: 0.8533
# Epoch 22: val_f1_score did not improve from 0.81915
# 104/104 [==============================] - 73s 697ms/step - loss: 0.4424 - accuracy: 0.8576 - f1_score: 0.8533 - val_loss: 0.6217 - val_accuracy: 0.8136 - val_f1_score: 0.8058 - lr: 0.0010
# Epoch 23/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8599 - f1_score: 0.8577
# Epoch 23: val_f1_score did not improve from 0.81915
# 104/104 [==============================] - 73s 695ms/step - loss: 0.4284 - accuracy: 0.8599 - f1_score: 0.8577 - val_loss: 0.5528 - val_accuracy: 0.8267 - val_f1_score: 0.8171 - lr: 0.0010
# Epoch 24/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8551 - f1_score: 0.8491
# Epoch 24: val_f1_score improved from 0.81915 to 0.82418, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 75s 719ms/step - loss: 0.4360 - accuracy: 0.8551 - f1_score: 0.8491 - val_loss: 0.5627 - val_accuracy: 0.8279 - val_f1_score: 0.8242 - lr: 0.0010
# Epoch 25/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4227 - accuracy: 0.8584 - f1_score: 0.8530
# Epoch 25: val_f1_score improved from 0.82418 to 0.82657, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 79s 755ms/step - loss: 0.4227 - accuracy: 0.8584 - f1_score: 0.8530 - val_loss: 0.5436 - val_accuracy: 0.8337 - val_f1_score: 0.8266 - lr: 0.0010
# Epoch 26/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4117 - accuracy: 0.8640 - f1_score: 0.8602
# Epoch 26: val_f1_score improved from 0.82657 to 0.82787, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 81s 781ms/step - loss: 0.4117 - accuracy: 0.8640 - f1_score: 0.8602 - val_loss: 0.5305 - val_accuracy: 0.8255 - val_f1_score: 0.8279 - lr: 0.0010
# Epoch 27/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.8633 - f1_score: 0.8611
# Epoch 27: val_f1_score improved from 0.82787 to 0.83198, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 743ms/step - loss: 0.4052 - accuracy: 0.8633 - f1_score: 0.8611 - val_loss: 0.5127 - val_accuracy: 0.8429 - val_f1_score: 0.8320 - lr: 0.0010
# Epoch 28/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3875 - accuracy: 0.8706 - f1_score: 0.8655
# Epoch 28: val_f1_score improved from 0.83198 to 0.84211, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 728ms/step - loss: 0.3875 - accuracy: 0.8706 - f1_score: 0.8655 - val_loss: 0.5197 - val_accuracy: 0.8491 - val_f1_score: 0.8421 - lr: 0.0010
# Epoch 29/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8761 - f1_score: 0.8757
# Epoch 29: val_f1_score did not improve from 0.84211
# 104/104 [==============================] - 79s 761ms/step - loss: 0.3897 - accuracy: 0.8761 - f1_score: 0.8757 - val_loss: 0.5085 - val_accuracy: 0.8406 - val_f1_score: 0.8306 - lr: 0.0010
# Epoch 30/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3638 - accuracy: 0.8823 - f1_score: 0.8789
# Epoch 30: val_f1_score improved from 0.84211 to 0.85429, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 78s 749ms/step - loss: 0.3638 - accuracy: 0.8823 - f1_score: 0.8789 - val_loss: 0.4532 - val_accuracy: 0.8591 - val_f1_score: 0.8543 - lr: 0.0010
# Epoch 31/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.8777 - f1_score: 0.8737
# Epoch 31: val_f1_score did not improve from 0.85429
# 104/104 [==============================] - 70s 671ms/step - loss: 0.3654 - accuracy: 0.8777 - f1_score: 0.8737 - val_loss: 0.5083 - val_accuracy: 0.8418 - val_f1_score: 0.8351 - lr: 0.0010
# Epoch 32/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.8851 - f1_score: 0.8816
# Epoch 32: val_f1_score did not improve from 0.85429
# 104/104 [==============================] - 76s 725ms/step - loss: 0.3533 - accuracy: 0.8851 - f1_score: 0.8816 - val_loss: 0.4856 - val_accuracy: 0.8503 - val_f1_score: 0.8495 - lr: 0.0010
# Epoch 33/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8837 - f1_score: 0.8801
# Epoch 33: val_f1_score did not improve from 0.85429
# 104/104 [==============================] - 76s 725ms/step - loss: 0.3460 - accuracy: 0.8837 - f1_score: 0.8801 - val_loss: 0.5100 - val_accuracy: 0.8379 - val_f1_score: 0.8401 - lr: 0.0010
# Epoch 34/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8884 - f1_score: 0.8861
# Epoch 34: val_f1_score improved from 0.85429 to 0.87228, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 77s 736ms/step - loss: 0.3295 - accuracy: 0.8884 - f1_score: 0.8861 - val_loss: 0.4111 - val_accuracy: 0.8769 - val_f1_score: 0.8723 - lr: 0.0010
# Epoch 35/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8914 - f1_score: 0.8875
# Epoch 35: val_f1_score did not improve from 0.87228
# 104/104 [==============================] - 71s 678ms/step - loss: 0.3277 - accuracy: 0.8914 - f1_score: 0.8875 - val_loss: 0.4735 - val_accuracy: 0.8595 - val_f1_score: 0.8537 - lr: 0.0010
# Epoch 36/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3401 - accuracy: 0.8867 - f1_score: 0.8830
# Epoch 36: val_f1_score did not improve from 0.87228
# 104/104 [==============================] - 69s 663ms/step - loss: 0.3401 - accuracy: 0.8867 - f1_score: 0.8830 - val_loss: 0.4382 - val_accuracy: 0.8665 - val_f1_score: 0.8647 - lr: 0.0010
# Epoch 37/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8909 - f1_score: 0.8873
# Epoch 37: val_f1_score did not improve from 0.87228
# 104/104 [==============================] - 72s 687ms/step - loss: 0.3280 - accuracy: 0.8909 - f1_score: 0.8873 - val_loss: 0.4592 - val_accuracy: 0.8626 - val_f1_score: 0.8581 - lr: 0.0010
# Epoch 38/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.8890 - f1_score: 0.8850
# Epoch 38: val_f1_score did not improve from 0.87228
# 104/104 [==============================] - 73s 699ms/step - loss: 0.3322 - accuracy: 0.8890 - f1_score: 0.8850 - val_loss: 0.4848 - val_accuracy: 0.8514 - val_f1_score: 0.8454 - lr: 0.0010
# Epoch 39/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.8857 - f1_score: 0.8841
# Epoch 39: val_f1_score did not improve from 0.87228
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 74s 705ms/step - loss: 0.3379 - accuracy: 0.8857 - f1_score: 0.8841 - val_loss: 0.4436 - val_accuracy: 0.8680 - val_f1_score: 0.8668 - lr: 0.0010
# Epoch 40/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.9095 - f1_score: 0.9070
# Epoch 40: val_f1_score improved from 0.87228 to 0.87670, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 726ms/step - loss: 0.2730 - accuracy: 0.9095 - f1_score: 0.9070 - val_loss: 0.3823 - val_accuracy: 0.8823 - val_f1_score: 0.8767 - lr: 5.0000e-04
# Epoch 41/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9190 - f1_score: 0.9175
# Epoch 41: val_f1_score improved from 0.87670 to 0.89269, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 81s 780ms/step - loss: 0.2392 - accuracy: 0.9190 - f1_score: 0.9175 - val_loss: 0.3429 - val_accuracy: 0.8966 - val_f1_score: 0.8927 - lr: 5.0000e-04
# Epoch 42/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9216 - f1_score: 0.9198
# Epoch 42: val_f1_score improved from 0.89269 to 0.89346, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 74s 705ms/step - loss: 0.2356 - accuracy: 0.9216 - f1_score: 0.9198 - val_loss: 0.3649 - val_accuracy: 0.8927 - val_f1_score: 0.8935 - lr: 5.0000e-04
# Epoch 43/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9251 - f1_score: 0.9224
# Epoch 43: val_f1_score improved from 0.89346 to 0.89648, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 724ms/step - loss: 0.2273 - accuracy: 0.9251 - f1_score: 0.9224 - val_loss: 0.3362 - val_accuracy: 0.8993 - val_f1_score: 0.8965 - lr: 5.0000e-04
# Epoch 44/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9305 - f1_score: 0.9294
# Epoch 44: val_f1_score improved from 0.89648 to 0.89765, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 73s 701ms/step - loss: 0.2076 - accuracy: 0.9305 - f1_score: 0.9294 - val_loss: 0.3382 - val_accuracy: 0.8993 - val_f1_score: 0.8976 - lr: 5.0000e-04
# Epoch 45/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9325 - f1_score: 0.9313
# Epoch 45: val_f1_score did not improve from 0.89765
# 104/104 [==============================] - 66s 635ms/step - loss: 0.2098 - accuracy: 0.9325 - f1_score: 0.9313 - val_loss: 0.3325 - val_accuracy: 0.8958 - val_f1_score: 0.8931 - lr: 5.0000e-04
# Epoch 46/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.9305 - f1_score: 0.9297
# Epoch 46: val_f1_score improved from 0.89765 to 0.90730, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 74s 708ms/step - loss: 0.2046 - accuracy: 0.9305 - f1_score: 0.9297 - val_loss: 0.3215 - val_accuracy: 0.9066 - val_f1_score: 0.9073 - lr: 5.0000e-04
# Epoch 47/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9325 - f1_score: 0.9327
# Epoch 47: val_f1_score did not improve from 0.90730
# 104/104 [==============================] - 68s 654ms/step - loss: 0.2050 - accuracy: 0.9325 - f1_score: 0.9327 - val_loss: 0.3224 - val_accuracy: 0.8977 - val_f1_score: 0.8976 - lr: 5.0000e-04
# Epoch 48/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9330 - f1_score: 0.9306
# Epoch 48: val_f1_score did not improve from 0.90730
# 104/104 [==============================] - 72s 688ms/step - loss: 0.2074 - accuracy: 0.9330 - f1_score: 0.9306 - val_loss: 0.2986 - val_accuracy: 0.9093 - val_f1_score: 0.9066 - lr: 5.0000e-04
# Epoch 49/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9284 - f1_score: 0.9294
# Epoch 49: val_f1_score improved from 0.90730 to 0.90753, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 73s 704ms/step - loss: 0.2120 - accuracy: 0.9284 - f1_score: 0.9294 - val_loss: 0.2970 - val_accuracy: 0.9085 - val_f1_score: 0.9075 - lr: 5.0000e-04
# Epoch 50/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9326 - f1_score: 0.9328
# Epoch 50: val_f1_score improved from 0.90753 to 0.91445, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 77s 737ms/step - loss: 0.1997 - accuracy: 0.9326 - f1_score: 0.9328 - val_loss: 0.2894 - val_accuracy: 0.9135 - val_f1_score: 0.9144 - lr: 5.0000e-04
# Epoch 51/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9322 - f1_score: 0.9315
# Epoch 51: val_f1_score did not improve from 0.91445
# 104/104 [==============================] - 74s 713ms/step - loss: 0.2025 - accuracy: 0.9322 - f1_score: 0.9315 - val_loss: 0.2944 - val_accuracy: 0.9116 - val_f1_score: 0.9125 - lr: 5.0000e-04
# Epoch 52/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9350 - f1_score: 0.9342
# Epoch 52: val_f1_score did not improve from 0.91445
# 104/104 [==============================] - 70s 665ms/step - loss: 0.1952 - accuracy: 0.9350 - f1_score: 0.9342 - val_loss: 0.3197 - val_accuracy: 0.9062 - val_f1_score: 0.9015 - lr: 5.0000e-04
# Epoch 53/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9357 - f1_score: 0.9351
# Epoch 53: val_f1_score did not improve from 0.91445
# 104/104 [==============================] - 70s 670ms/step - loss: 0.2032 - accuracy: 0.9357 - f1_score: 0.9351 - val_loss: 0.3377 - val_accuracy: 0.8993 - val_f1_score: 0.9012 - lr: 5.0000e-04
# Epoch 54/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9330 - f1_score: 0.9316
# Epoch 54: val_f1_score did not improve from 0.91445
# 104/104 [==============================] - 73s 701ms/step - loss: 0.1940 - accuracy: 0.9330 - f1_score: 0.9316 - val_loss: 0.2928 - val_accuracy: 0.9101 - val_f1_score: 0.9120 - lr: 5.0000e-04
# Epoch 55/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9326 - f1_score: 0.9336
# Epoch 55: val_f1_score did not improve from 0.91445
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 73s 702ms/step - loss: 0.1982 - accuracy: 0.9326 - f1_score: 0.9336 - val_loss: 0.3086 - val_accuracy: 0.9043 - val_f1_score: 0.9020 - lr: 5.0000e-04
# Epoch 56/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9463 - f1_score: 0.9453
# Epoch 56: val_f1_score improved from 0.91445 to 0.92375, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 731ms/step - loss: 0.1670 - accuracy: 0.9463 - f1_score: 0.9453 - val_loss: 0.2722 - val_accuracy: 0.9236 - val_f1_score: 0.9238 - lr: 2.5000e-04
# Epoch 57/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9452 - f1_score: 0.9437
# Epoch 57: val_f1_score did not improve from 0.92375
# 104/104 [==============================] - 70s 670ms/step - loss: 0.1659 - accuracy: 0.9452 - f1_score: 0.9437 - val_loss: 0.2757 - val_accuracy: 0.9220 - val_f1_score: 0.9210 - lr: 2.5000e-04
# Epoch 58/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9460 - f1_score: 0.9453
# Epoch 58: val_f1_score improved from 0.92375 to 0.92502, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 74s 713ms/step - loss: 0.1591 - accuracy: 0.9460 - f1_score: 0.9453 - val_loss: 0.2595 - val_accuracy: 0.9236 - val_f1_score: 0.9250 - lr: 2.5000e-04
# Epoch 59/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9483 - f1_score: 0.9491
# Epoch 59: val_f1_score did not improve from 0.92502
# 104/104 [==============================] - 70s 671ms/step - loss: 0.1606 - accuracy: 0.9483 - f1_score: 0.9491 - val_loss: 0.2664 - val_accuracy: 0.9213 - val_f1_score: 0.9202 - lr: 2.5000e-04
# Epoch 60/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9498 - f1_score: 0.9505
# Epoch 60: val_f1_score did not improve from 0.92502
# 104/104 [==============================] - 70s 666ms/step - loss: 0.1580 - accuracy: 0.9498 - f1_score: 0.9505 - val_loss: 0.2754 - val_accuracy: 0.9213 - val_f1_score: 0.9218 - lr: 2.5000e-04
# Epoch 61/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9478 - f1_score: 0.9493
# Epoch 61: val_f1_score did not improve from 0.92502
# 104/104 [==============================] - 70s 672ms/step - loss: 0.1550 - accuracy: 0.9478 - f1_score: 0.9493 - val_loss: 0.2800 - val_accuracy: 0.9147 - val_f1_score: 0.9157 - lr: 2.5000e-04
# Epoch 62/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9511 - f1_score: 0.9506
# Epoch 62: val_f1_score did not improve from 0.92502
# 104/104 [==============================] - 70s 669ms/step - loss: 0.1471 - accuracy: 0.9511 - f1_score: 0.9506 - val_loss: 0.2647 - val_accuracy: 0.9240 - val_f1_score: 0.9242 - lr: 2.5000e-04
# Epoch 63/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9494 - f1_score: 0.9479
# Epoch 63: val_f1_score did not improve from 0.92502
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 69s 658ms/step - loss: 0.1504 - accuracy: 0.9494 - f1_score: 0.9479 - val_loss: 0.2703 - val_accuracy: 0.9220 - val_f1_score: 0.9220 - lr: 2.5000e-04
# Epoch 64/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9529 - f1_score: 0.9519
# Epoch 64: val_f1_score improved from 0.92502 to 0.92962, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 732ms/step - loss: 0.1445 - accuracy: 0.9529 - f1_score: 0.9519 - val_loss: 0.2538 - val_accuracy: 0.9325 - val_f1_score: 0.9296 - lr: 1.2500e-04
# Epoch 65/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9553 - f1_score: 0.9549
# Epoch 65: val_f1_score did not improve from 0.92962
# 104/104 [==============================] - 70s 667ms/step - loss: 0.1347 - accuracy: 0.9553 - f1_score: 0.9549 - val_loss: 0.2538 - val_accuracy: 0.9294 - val_f1_score: 0.9274 - lr: 1.2500e-04
# Epoch 66/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9529 - f1_score: 0.9526
# Epoch 66: val_f1_score improved from 0.92962 to 0.92994, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 729ms/step - loss: 0.1387 - accuracy: 0.9529 - f1_score: 0.9526 - val_loss: 0.2461 - val_accuracy: 0.9267 - val_f1_score: 0.9299 - lr: 1.2500e-04
# Epoch 67/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9556 - f1_score: 0.9561
# Epoch 67: val_f1_score did not improve from 0.92994
# 104/104 [==============================] - 70s 671ms/step - loss: 0.1350 - accuracy: 0.9556 - f1_score: 0.9561 - val_loss: 0.2471 - val_accuracy: 0.9271 - val_f1_score: 0.9289 - lr: 1.2500e-04
# Epoch 68/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9522 - f1_score: 0.9515
# Epoch 68: val_f1_score did not improve from 0.92994
# 104/104 [==============================] - 69s 656ms/step - loss: 0.1425 - accuracy: 0.9522 - f1_score: 0.9515 - val_loss: 0.2436 - val_accuracy: 0.9271 - val_f1_score: 0.9263 - lr: 1.2500e-04
# Epoch 69/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9562 - f1_score: 0.9570
# Epoch 69: val_f1_score did not improve from 0.92994
# 104/104 [==============================] - 69s 659ms/step - loss: 0.1334 - accuracy: 0.9562 - f1_score: 0.9570 - val_loss: 0.2500 - val_accuracy: 0.9263 - val_f1_score: 0.9256 - lr: 1.2500e-04
# Epoch 70/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9549 - f1_score: 0.9553
# Epoch 70: val_f1_score did not improve from 0.92994
# 104/104 [==============================] - 71s 678ms/step - loss: 0.1347 - accuracy: 0.9549 - f1_score: 0.9553 - val_loss: 0.2455 - val_accuracy: 0.9286 - val_f1_score: 0.9276 - lr: 1.2500e-04
# Epoch 71/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9573 - f1_score: 0.9558
# Epoch 71: val_f1_score improved from 0.92994 to 0.93385, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 74s 711ms/step - loss: 0.1293 - accuracy: 0.9573 - f1_score: 0.9558 - val_loss: 0.2436 - val_accuracy: 0.9309 - val_f1_score: 0.9338 - lr: 1.2500e-04
# Epoch 72/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9571 - f1_score: 0.9564
# Epoch 72: val_f1_score did not improve from 0.93385
# 104/104 [==============================] - 70s 669ms/step - loss: 0.1264 - accuracy: 0.9571 - f1_score: 0.9564 - val_loss: 0.2516 - val_accuracy: 0.9328 - val_f1_score: 0.9313 - lr: 1.2500e-04
# Epoch 73/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9603 - f1_score: 0.9622
# Epoch 73: val_f1_score improved from 0.93385 to 0.93605, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 74s 710ms/step - loss: 0.1255 - accuracy: 0.9603 - f1_score: 0.9622 - val_loss: 0.2401 - val_accuracy: 0.9328 - val_f1_score: 0.9361 - lr: 1.2500e-04
# Epoch 74/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9549 - f1_score: 0.9541
# Epoch 74: val_f1_score did not improve from 0.93605
# 104/104 [==============================] - 70s 673ms/step - loss: 0.1360 - accuracy: 0.9549 - f1_score: 0.9541 - val_loss: 0.2460 - val_accuracy: 0.9286 - val_f1_score: 0.9299 - lr: 1.2500e-04
# Epoch 75/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9560 - f1_score: 0.9565
# Epoch 75: val_f1_score did not improve from 0.93605
# 104/104 [==============================] - 72s 693ms/step - loss: 0.1289 - accuracy: 0.9560 - f1_score: 0.9565 - val_loss: 0.2368 - val_accuracy: 0.9294 - val_f1_score: 0.9299 - lr: 1.2500e-04
# Epoch 76/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9593 - f1_score: 0.9607
# Epoch 76: val_f1_score did not improve from 0.93605
# 104/104 [==============================] - 70s 670ms/step - loss: 0.1245 - accuracy: 0.9593 - f1_score: 0.9607 - val_loss: 0.2419 - val_accuracy: 0.9355 - val_f1_score: 0.9345 - lr: 1.2500e-04
# Epoch 77/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9602 - f1_score: 0.9593
# Epoch 77: val_f1_score did not improve from 0.93605
# 104/104 [==============================] - 72s 690ms/step - loss: 0.1228 - accuracy: 0.9602 - f1_score: 0.9593 - val_loss: 0.2303 - val_accuracy: 0.9367 - val_f1_score: 0.9338 - lr: 1.2500e-04
# Epoch 78/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9598 - f1_score: 0.9588
# Epoch 78: val_f1_score did not improve from 0.93605
# 104/104 [==============================] - 69s 662ms/step - loss: 0.1200 - accuracy: 0.9598 - f1_score: 0.9588 - val_loss: 0.2470 - val_accuracy: 0.9290 - val_f1_score: 0.9276 - lr: 1.2500e-04
# Epoch 79/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9587 - f1_score: 0.9579
# Epoch 79: val_f1_score improved from 0.93605 to 0.94068, saving model to saved_outputs_basic_augment\Ensemble2_v2\saved_models\best_Ensemble2_v2.h5
# 104/104 [==============================] - 76s 729ms/step - loss: 0.1243 - accuracy: 0.9587 - f1_score: 0.9579 - val_loss: 0.2176 - val_accuracy: 0.9390 - val_f1_score: 0.9407 - lr: 1.2500e-04
# Epoch 80/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9615 - f1_score: 0.9609
# Epoch 80: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 75s 720ms/step - loss: 0.1178 - accuracy: 0.9615 - f1_score: 0.9609 - val_loss: 0.2557 - val_accuracy: 0.9263 - val_f1_score: 0.9288 - lr: 1.2500e-04
# Epoch 81/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.9597 - f1_score: 0.9591
# Epoch 81: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 78s 741ms/step - loss: 0.1211 - accuracy: 0.9597 - f1_score: 0.9591 - val_loss: 0.2570 - val_accuracy: 0.9251 - val_f1_score: 0.9255 - lr: 1.2500e-04
# Epoch 82/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9635 - f1_score: 0.9637
# Epoch 82: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 74s 712ms/step - loss: 0.1137 - accuracy: 0.9635 - f1_score: 0.9637 - val_loss: 0.2339 - val_accuracy: 0.9305 - val_f1_score: 0.9294 - lr: 1.2500e-04
# Epoch 83/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9611 - f1_score: 0.9603
# Epoch 83: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 80s 770ms/step - loss: 0.1205 - accuracy: 0.9611 - f1_score: 0.9603 - val_loss: 0.2262 - val_accuracy: 0.9390 - val_f1_score: 0.9386 - lr: 1.2500e-04
# Epoch 84/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9595 - f1_score: 0.9595
# Epoch 84: val_f1_score did not improve from 0.94068
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 76s 729ms/step - loss: 0.1246 - accuracy: 0.9595 - f1_score: 0.9595 - val_loss: 0.2524 - val_accuracy: 0.9259 - val_f1_score: 0.9272 - lr: 1.2500e-04
# Epoch 85/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9610 - f1_score: 0.9614
# Epoch 85: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 74s 710ms/step - loss: 0.1198 - accuracy: 0.9610 - f1_score: 0.9614 - val_loss: 0.2241 - val_accuracy: 0.9313 - val_f1_score: 0.9302 - lr: 6.2500e-05
# Epoch 86/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9603 - f1_score: 0.9604
# Epoch 86: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 87s 835ms/step - loss: 0.1192 - accuracy: 0.9603 - f1_score: 0.9604 - val_loss: 0.2318 - val_accuracy: 0.9267 - val_f1_score: 0.9265 - lr: 6.2500e-05
# Epoch 87/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9598 - f1_score: 0.9591
# Epoch 87: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 77s 741ms/step - loss: 0.1206 - accuracy: 0.9598 - f1_score: 0.9591 - val_loss: 0.2329 - val_accuracy: 0.9317 - val_f1_score: 0.9311 - lr: 6.2500e-05
# Epoch 88/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9647 - f1_score: 0.9646
# Epoch 88: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 73s 703ms/step - loss: 0.1052 - accuracy: 0.9647 - f1_score: 0.9646 - val_loss: 0.2394 - val_accuracy: 0.9328 - val_f1_score: 0.9335 - lr: 6.2500e-05
# Epoch 89/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9632 - f1_score: 0.9623
# Epoch 89: val_f1_score did not improve from 0.94068
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 71s 682ms/step - loss: 0.1166 - accuracy: 0.9632 - f1_score: 0.9623 - val_loss: 0.2408 - val_accuracy: 0.9336 - val_f1_score: 0.9322 - lr: 6.2500e-05
# Epoch 90/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9619 - f1_score: 0.9625
# Epoch 90: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 72s 691ms/step - loss: 0.1130 - accuracy: 0.9619 - f1_score: 0.9625 - val_loss: 0.2252 - val_accuracy: 0.9325 - val_f1_score: 0.9329 - lr: 3.1250e-05
# Epoch 91/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9624 - f1_score: 0.9633
# Epoch 91: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 72s 693ms/step - loss: 0.1112 - accuracy: 0.9624 - f1_score: 0.9633 - val_loss: 0.2272 - val_accuracy: 0.9352 - val_f1_score: 0.9348 - lr: 3.1250e-05
# Epoch 92/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9651 - f1_score: 0.9657
# Epoch 92: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 76s 731ms/step - loss: 0.1087 - accuracy: 0.9651 - f1_score: 0.9657 - val_loss: 0.2256 - val_accuracy: 0.9325 - val_f1_score: 0.9316 - lr: 3.1250e-05
# Epoch 93/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9632 - f1_score: 0.9616
# Epoch 93: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 98s 942ms/step - loss: 0.1110 - accuracy: 0.9632 - f1_score: 0.9616 - val_loss: 0.2150 - val_accuracy: 0.9355 - val_f1_score: 0.9342 - lr: 3.1250e-05
# Epoch 94/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9622 - f1_score: 0.9619
# Epoch 94: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 76s 732ms/step - loss: 0.1145 - accuracy: 0.9622 - f1_score: 0.9619 - val_loss: 0.2194 - val_accuracy: 0.9382 - val_f1_score: 0.9369 - lr: 3.1250e-05
# Epoch 95/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9647 - f1_score: 0.9650
# Epoch 95: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 77s 742ms/step - loss: 0.1102 - accuracy: 0.9647 - f1_score: 0.9650 - val_loss: 0.2208 - val_accuracy: 0.9352 - val_f1_score: 0.9356 - lr: 3.1250e-05
# Epoch 96/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9650 - f1_score: 0.9647
# Epoch 96: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 84s 804ms/step - loss: 0.1089 - accuracy: 0.9650 - f1_score: 0.9647 - val_loss: 0.2357 - val_accuracy: 0.9309 - val_f1_score: 0.9291 - lr: 3.1250e-05
# Epoch 97/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9637 - f1_score: 0.9647
# Epoch 97: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 78s 749ms/step - loss: 0.1052 - accuracy: 0.9637 - f1_score: 0.9647 - val_loss: 0.2299 - val_accuracy: 0.9298 - val_f1_score: 0.9324 - lr: 3.1250e-05
# Epoch 98/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9635 - f1_score: 0.9624
# Epoch 98: val_f1_score did not improve from 0.94068
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 73s 696ms/step - loss: 0.1089 - accuracy: 0.9635 - f1_score: 0.9624 - val_loss: 0.2342 - val_accuracy: 0.9332 - val_f1_score: 0.9323 - lr: 3.1250e-05
# Epoch 99/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9659 - f1_score: 0.9666
# Epoch 99: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 78s 747ms/step - loss: 0.1047 - accuracy: 0.9659 - f1_score: 0.9666 - val_loss: 0.2385 - val_accuracy: 0.9321 - val_f1_score: 0.9327 - lr: 1.5625e-05
# Epoch 100/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9633 - f1_score: 0.9637
# Epoch 100: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 77s 739ms/step - loss: 0.1117 - accuracy: 0.9633 - f1_score: 0.9637 - val_loss: 0.2353 - val_accuracy: 0.9309 - val_f1_score: 0.9306 - lr: 1.5625e-05
# Epoch 101/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9662 - f1_score: 0.9663
# Epoch 101: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 77s 741ms/step - loss: 0.1057 - accuracy: 0.9662 - f1_score: 0.9663 - val_loss: 0.2429 - val_accuracy: 0.9313 - val_f1_score: 0.9299 - lr: 1.5625e-05
# Epoch 102/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9649 - f1_score: 0.9656
# Epoch 102: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 75s 716ms/step - loss: 0.1055 - accuracy: 0.9649 - f1_score: 0.9656 - val_loss: 0.2246 - val_accuracy: 0.9386 - val_f1_score: 0.9387 - lr: 1.5625e-05
# Epoch 103/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 0.9628 - f1_score: 0.9619
# Epoch 103: val_f1_score did not improve from 0.94068
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 77s 741ms/step - loss: 0.1108 - accuracy: 0.9628 - f1_score: 0.9619 - val_loss: 0.2175 - val_accuracy: 0.9402 - val_f1_score: 0.9404 - lr: 1.5625e-05
# Epoch 104/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 0.9665 - f1_score: 0.9663
# Epoch 104: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 79s 756ms/step - loss: 0.1051 - accuracy: 0.9665 - f1_score: 0.9663 - val_loss: 0.2143 - val_accuracy: 0.9390 - val_f1_score: 0.9389 - lr: 7.8125e-06
# Epoch 105/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9666 - f1_score: 0.9664
# Epoch 105: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 78s 749ms/step - loss: 0.1042 - accuracy: 0.9666 - f1_score: 0.9664 - val_loss: 0.2294 - val_accuracy: 0.9390 - val_f1_score: 0.9381 - lr: 7.8125e-06
# Epoch 106/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9671 - f1_score: 0.9672
# Epoch 106: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 79s 756ms/step - loss: 0.0998 - accuracy: 0.9671 - f1_score: 0.9672 - val_loss: 0.2437 - val_accuracy: 0.9305 - val_f1_score: 0.9315 - lr: 7.8125e-06
# Epoch 107/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9609 - f1_score: 0.9612
# Epoch 107: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 83s 796ms/step - loss: 0.1083 - accuracy: 0.9609 - f1_score: 0.9612 - val_loss: 0.2222 - val_accuracy: 0.9344 - val_f1_score: 0.9332 - lr: 7.8125e-06
# Epoch 108/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9653 - f1_score: 0.9648
# Epoch 108: val_f1_score did not improve from 0.94068
# 104/104 [==============================] - 78s 752ms/step - loss: 0.1066 - accuracy: 0.9653 - f1_score: 0.9648 - val_loss: 0.2274 - val_accuracy: 0.9313 - val_f1_score: 0.9291 - lr: 7.8125e-06

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 15s 450ms/step - loss: 0.2262 - accuracy: 0.9331 - f1_score: 0.9313
#      model_name  test_loss  test_accuracy  test_f1_score
# 0  Ensemble2_v2   0.226161       0.933128       0.931253

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 18s 444ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.888060  0.915385  0.901515   130.000000
# 1              0.940594  0.950000  0.945274   100.000000
# 2              0.977273  0.955556  0.966292    90.000000
# 3              0.947917  0.900990  0.923858   101.000000
# 4              0.934874  0.946809  0.940803   470.000000
# 5              0.902985  0.956522  0.928983   253.000000
# 6              0.870968  0.931034  0.900000   174.000000
# 7              0.926714  0.909513  0.918033   431.000000
# 8              0.910798  0.885845  0.898148   219.000000
# 9              0.952183  0.952183  0.952183   481.000000
# 10             0.955844  0.943590  0.949677   390.000000
# 11             0.958848  0.917323  0.937626   254.000000
# 12             0.947020  0.940789  0.943894   152.000000
# accuracy       0.933128  0.933128  0.933128     0.933128
# macro avg      0.931852  0.931195  0.931253  3245.000000
# weighted avg   0.933666  0.933128  0.933183  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#      Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  Ensemble2_v2  0.933128         0.931852      0.931195        0.931253
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.933666         0.933128           0.933183  0.226161

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.93313
# 1      Macro Precision  0.93185
# 2         Macro Recall  0.93120
# 3       Macro F1-Score  0.93125
# 4            Macro FPR  0.00570
# 5            Macro FNR  0.06880
# 6            Macro FDR  0.06815
# 7            Macro NPV  0.99429
# 8   Weighted Precision  0.93367
# 9      Weighted Recall  0.93313
# 10   Weighted F1-Score  0.93318
# 11        Weighted FPR  0.00725
# 12        Weighted FNR  0.06687
# 13        Weighted FDR  0.06633
# 14        Weighted NPV  0.99264
