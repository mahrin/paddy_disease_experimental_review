# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D, Activation
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')
######################################################################################################
from keras_tuner import RandomSearch, HyperParameters
from tensorflow.keras.applications import Xception, DenseNet121
import keras_tuner as kt

# %%
model_name = 'Ensemble2_filter7'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 
# FNAME_TUNER_REPORT = 'Report_tune_'+ model_name
################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_no_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_SAVE_RESULT, 'saved_tuner_model')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 250
EPOCHS = 120 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = False
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_no_augment\Ensemble2_filter7
# PATH_BEST_SAVE_WEIGHT saved_outputs_no_augment\Ensemble2_filter7\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_no_augment\Ensemble2_filter7\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_4724\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':  
            print("Here in basic")
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set


                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    ## Criteria for early stopping
#    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.0000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None, model_name="default_name", SAVE_RESULTS = False):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model, SAVE_RESULTS=False):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss, model_name="default_name", SAVE_RESULTS=False ):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING
#
# Trial 15 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 9
# Score: 0.7056062817573547
#
# Trial 11 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 5
# Score: 0.7054979205131531
#
# Trial 23 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 7
# Score: 0.7038310170173645
#
# Trial 03 summary
# Hyperparameters:
# dropout: 0.1
# units: 1024
# filters: 3
# Score: 0.7012895941734314979205131531979205131531

# %%
# Function to build the model with an ensemble of feature extractors
def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
                      dropout= 0.1,
                      activation='relu',
                      units= 1024,
                      nr_classes=NUM_CLASSES,
                      loss = "categorical_crossentropy", 
                      retrain_backbone_network=False,
                      learning_rate = 0.001,
                      global_pooling = 'avg',
                      filters=7,
                      name='ensemble2'):


    inputs = Input(shape=input_shape)

    # Feature extraction from Xception
    Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
    Xception_features = Xception_base(inputs)
    Xception_features = GlobalAveragePooling2D()(Xception_features)

    # Feature extraction from DenseNet121
    densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
    densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
    densenet_features = densenet_base(inputs)
    densenet_features = GlobalAveragePooling2D()(densenet_features)

    # Concatenate features
    concatenated_features = Concatenate()([Xception_features, densenet_features])

    if filters==3:
        filters = (3,3)
    elif filters==5:
        filters = (5,5)
    elif filters==7:
        filters = (7,7)
    elif filters==9:
        filters = (9,9)

    # # Add a tunable dropout layer
    # x = Dropout(dropout)(concatenated_features)

    # # A fully connected layer with a tunable number of units
    # x = Dense(units)(x)

    #     # Add a tunable dropout layer
    # x = Dropout(dropout)(x)

    # # A fully connected layer with a tunable number of units
    # x = Dense(units)(x)
        # Add a tunable dropout layer
    x = Dropout(dropout)(concatenated_features)

    # A fully connected layer with a tunable number of units
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)

    # Add a tunable dropout layer
    x = Dropout(dropout)(x)

    # A fully connected layer with a tunable number of units again
    x = Dense(units)(x)
    x = Activation(activation)(x)  # Add ReLU activation before batch normalization
    x = BatchNormalization()(x)


    # Output layer
    predictions = Dense( nr_classes, activation='softmax')(x)

    # Create and compile the model
    model = Model(inputs=inputs, outputs=predictions)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=loss,
        metrics=['accuracy', f1_score]
    )

    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN() 
model = get_ensemble2_model()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/120
# 42/42 [==============================] - ETA: 0s - loss: 1.5689 - accuracy: 0.5475 - f1_score: 0.5078
# Epoch 1: val_f1_score improved from -inf to 0.32978, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 70s 1s/step - loss: 1.5689 - accuracy: 0.5475 - f1_score: 0.5078 - val_loss: 1.8049 - val_accuracy: 0.3929 - val_f1_score: 0.3298 - lr: 0.0010
# Epoch 2/120
# 42/42 [==============================] - ETA: 0s - loss: 0.7291 - accuracy: 0.7683 - f1_score: 0.7596
# Epoch 2: val_f1_score improved from 0.32978 to 0.54734, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 61s 1s/step - loss: 0.7291 - accuracy: 0.7683 - f1_score: 0.7596 - val_loss: 1.2670 - val_accuracy: 0.5924 - val_f1_score: 0.5473 - lr: 0.0010
# Epoch 3/120
# 42/42 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.8404 - f1_score: 0.8345
# Epoch 3: val_f1_score improved from 0.54734 to 0.70623, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.5043 - accuracy: 0.8404 - f1_score: 0.8345 - val_loss: 0.9542 - val_accuracy: 0.7213 - val_f1_score: 0.7062 - lr: 0.0010
# Epoch 4/120
# 42/42 [==============================] - ETA: 0s - loss: 0.3769 - accuracy: 0.8778 - f1_score: 0.8716
# Epoch 4: val_f1_score improved from 0.70623 to 0.77600, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.3769 - accuracy: 0.8778 - f1_score: 0.8716 - val_loss: 0.7207 - val_accuracy: 0.7816 - val_f1_score: 0.7760 - lr: 0.0010
# Epoch 5/120
# 42/42 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.9060 - f1_score: 0.9043
# Epoch 5: val_f1_score did not improve from 0.77600
# 42/42 [==============================] - 62s 1s/step - loss: 0.2861 - accuracy: 0.9060 - f1_score: 0.9043 - val_loss: 0.6887 - val_accuracy: 0.7761 - val_f1_score: 0.7675 - lr: 0.0010
# Epoch 6/120
# 42/42 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9265 - f1_score: 0.9244
# Epoch 6: val_f1_score improved from 0.77600 to 0.77655, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 64s 2s/step - loss: 0.2235 - accuracy: 0.9265 - f1_score: 0.9244 - val_loss: 0.6830 - val_accuracy: 0.7908 - val_f1_score: 0.7765 - lr: 0.0010
# Epoch 7/120
# 42/42 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9421 - f1_score: 0.9402
# Epoch 7: val_f1_score improved from 0.77655 to 0.80395, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.1854 - accuracy: 0.9421 - f1_score: 0.9402 - val_loss: 0.5959 - val_accuracy: 0.8124 - val_f1_score: 0.8040 - lr: 0.0010
# Epoch 8/120
# 42/42 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9451 - f1_score: 0.9471
# Epoch 8: val_f1_score did not improve from 0.80395
# 42/42 [==============================] - 59s 1s/step - loss: 0.1681 - accuracy: 0.9451 - f1_score: 0.9471 - val_loss: 0.6584 - val_accuracy: 0.8113 - val_f1_score: 0.7937 - lr: 0.0010
# Epoch 9/120
# 42/42 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9523 - f1_score: 0.9507
# Epoch 9: val_f1_score improved from 0.80395 to 0.83001, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.1469 - accuracy: 0.9523 - f1_score: 0.9507 - val_loss: 0.5636 - val_accuracy: 0.8302 - val_f1_score: 0.8300 - lr: 0.0010
# Epoch 10/120
# 42/42 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9628 - f1_score: 0.9637
# Epoch 10: val_f1_score did not improve from 0.83001
# 42/42 [==============================] - 60s 1s/step - loss: 0.1233 - accuracy: 0.9628 - f1_score: 0.9637 - val_loss: 0.6288 - val_accuracy: 0.8190 - val_f1_score: 0.8198 - lr: 0.0010
# Epoch 11/120
# 42/42 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9666 - f1_score: 0.9663
# Epoch 11: val_f1_score did not improve from 0.83001
# 42/42 [==============================] - 61s 1s/step - loss: 0.1110 - accuracy: 0.9666 - f1_score: 0.9663 - val_loss: 0.5795 - val_accuracy: 0.8333 - val_f1_score: 0.8206 - lr: 0.0010
# Epoch 12/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9725 - f1_score: 0.9729
# Epoch 12: val_f1_score improved from 0.83001 to 0.83609, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.0939 - accuracy: 0.9725 - f1_score: 0.9729 - val_loss: 0.5542 - val_accuracy: 0.8379 - val_f1_score: 0.8361 - lr: 0.0010
# Epoch 13/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9742 - f1_score: 0.9741
# Epoch 13: val_f1_score did not improve from 0.83609
# 42/42 [==============================] - 62s 1s/step - loss: 0.0824 - accuracy: 0.9742 - f1_score: 0.9741 - val_loss: 0.5845 - val_accuracy: 0.8371 - val_f1_score: 0.8332 - lr: 0.0010
# Epoch 14/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9779 - f1_score: 0.9775
# Epoch 14: val_f1_score improved from 0.83609 to 0.84467, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 65s 2s/step - loss: 0.0781 - accuracy: 0.9779 - f1_score: 0.9775 - val_loss: 0.5154 - val_accuracy: 0.8560 - val_f1_score: 0.8447 - lr: 0.0010
# Epoch 15/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9778 - f1_score: 0.9768
# Epoch 15: val_f1_score improved from 0.84467 to 0.84505, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 62s 1s/step - loss: 0.0772 - accuracy: 0.9778 - f1_score: 0.9768 - val_loss: 0.5382 - val_accuracy: 0.8553 - val_f1_score: 0.8451 - lr: 0.0010
# Epoch 16/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9789 - f1_score: 0.9778
# Epoch 16: val_f1_score improved from 0.84505 to 0.85661, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.0652 - accuracy: 0.9789 - f1_score: 0.9778 - val_loss: 0.5369 - val_accuracy: 0.8622 - val_f1_score: 0.8566 - lr: 0.0010
# Epoch 17/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9832 - f1_score: 0.9830
# Epoch 17: val_f1_score did not improve from 0.85661
# 42/42 [==============================] - 62s 1s/step - loss: 0.0587 - accuracy: 0.9832 - f1_score: 0.9830 - val_loss: 0.5478 - val_accuracy: 0.8580 - val_f1_score: 0.8563 - lr: 0.0010
# Epoch 18/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9834 - f1_score: 0.9842
# Epoch 18: val_f1_score did not improve from 0.85661
# 42/42 [==============================] - 62s 1s/step - loss: 0.0584 - accuracy: 0.9834 - f1_score: 0.9842 - val_loss: 0.5698 - val_accuracy: 0.8545 - val_f1_score: 0.8452 - lr: 0.0010
# Epoch 19/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9838 - f1_score: 0.9842
# Epoch 19: val_f1_score did not improve from 0.85661
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 62s 1s/step - loss: 0.0536 - accuracy: 0.9838 - f1_score: 0.9842 - val_loss: 0.6078 - val_accuracy: 0.8391 - val_f1_score: 0.8364 - lr: 0.0010
# Epoch 20/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9892 - f1_score: 0.9898
# Epoch 20: val_f1_score improved from 0.85661 to 0.87376, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.0421 - accuracy: 0.9892 - f1_score: 0.9898 - val_loss: 0.4460 - val_accuracy: 0.8815 - val_f1_score: 0.8738 - lr: 5.0000e-04
# Epoch 21/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9947 - f1_score: 0.9947
# Epoch 21: val_f1_score improved from 0.87376 to 0.88883, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.0219 - accuracy: 0.9947 - f1_score: 0.9947 - val_loss: 0.3981 - val_accuracy: 0.8954 - val_f1_score: 0.8888 - lr: 5.0000e-04
# Epoch 22/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9953 - f1_score: 0.9954
# Epoch 22: val_f1_score improved from 0.88883 to 0.89721, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 66s 2s/step - loss: 0.0195 - accuracy: 0.9953 - f1_score: 0.9954 - val_loss: 0.3960 - val_accuracy: 0.9031 - val_f1_score: 0.8972 - lr: 5.0000e-04
# Epoch 23/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9962 - f1_score: 0.9958
# Epoch 23: val_f1_score did not improve from 0.89721
# 42/42 [==============================] - 64s 2s/step - loss: 0.0157 - accuracy: 0.9962 - f1_score: 0.9958 - val_loss: 0.3873 - val_accuracy: 0.8993 - val_f1_score: 0.8946 - lr: 5.0000e-04
# Epoch 24/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9970 - f1_score: 0.9965
# Epoch 24: val_f1_score improved from 0.89721 to 0.90018, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 68s 2s/step - loss: 0.0146 - accuracy: 0.9970 - f1_score: 0.9965 - val_loss: 0.3771 - val_accuracy: 0.9085 - val_f1_score: 0.9002 - lr: 5.0000e-04
# Epoch 25/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9961 - f1_score: 0.9959
# Epoch 25: val_f1_score did not improve from 0.90018
# 42/42 [==============================] - 66s 2s/step - loss: 0.0137 - accuracy: 0.9961 - f1_score: 0.9959 - val_loss: 0.4072 - val_accuracy: 0.9008 - val_f1_score: 0.8971 - lr: 5.0000e-04
# Epoch 26/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9975 - f1_score: 0.9975
# Epoch 26: val_f1_score improved from 0.90018 to 0.90435, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 75s 2s/step - loss: 0.0118 - accuracy: 0.9975 - f1_score: 0.9975 - val_loss: 0.3946 - val_accuracy: 0.9058 - val_f1_score: 0.9044 - lr: 5.0000e-04
# Epoch 27/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9973 - f1_score: 0.9974
# Epoch 27: val_f1_score improved from 0.90435 to 0.91028, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 81s 2s/step - loss: 0.0115 - accuracy: 0.9973 - f1_score: 0.9974 - val_loss: 0.3763 - val_accuracy: 0.9120 - val_f1_score: 0.9103 - lr: 5.0000e-04
# Epoch 28/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9975 - f1_score: 0.9979
# Epoch 28: val_f1_score did not improve from 0.91028
# 42/42 [==============================] - 78s 2s/step - loss: 0.0108 - accuracy: 0.9975 - f1_score: 0.9979 - val_loss: 0.3932 - val_accuracy: 0.9027 - val_f1_score: 0.9014 - lr: 5.0000e-04
# Epoch 29/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9966 - f1_score: 0.9969
# Epoch 29: val_f1_score did not improve from 0.91028
# 42/42 [==============================] - 77s 2s/step - loss: 0.0128 - accuracy: 0.9966 - f1_score: 0.9969 - val_loss: 0.3853 - val_accuracy: 0.9058 - val_f1_score: 0.9033 - lr: 5.0000e-04
# Epoch 30/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9976 - f1_score: 0.9975
# Epoch 30: val_f1_score did not improve from 0.91028
# 42/42 [==============================] - 72s 2s/step - loss: 0.0108 - accuracy: 0.9976 - f1_score: 0.9975 - val_loss: 0.3973 - val_accuracy: 0.9027 - val_f1_score: 0.8989 - lr: 5.0000e-04
# Epoch 31/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9977 - f1_score: 0.9979
# Epoch 31: val_f1_score did not improve from 0.91028
# 42/42 [==============================] - 78s 2s/step - loss: 0.0100 - accuracy: 0.9977 - f1_score: 0.9979 - val_loss: 0.3983 - val_accuracy: 0.9004 - val_f1_score: 0.8956 - lr: 5.0000e-04
# Epoch 32/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9977 - f1_score: 0.9978
# Epoch 32: val_f1_score did not improve from 0.91028
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 77s 2s/step - loss: 0.0086 - accuracy: 0.9977 - f1_score: 0.9978 - val_loss: 0.3874 - val_accuracy: 0.9062 - val_f1_score: 0.9005 - lr: 5.0000e-04
# Epoch 33/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9987 - f1_score: 0.9985
# Epoch 33: val_f1_score did not improve from 0.91028
# 42/42 [==============================] - 78s 2s/step - loss: 0.0080 - accuracy: 0.9987 - f1_score: 0.9985 - val_loss: 0.3557 - val_accuracy: 0.9116 - val_f1_score: 0.9097 - lr: 2.5000e-04
# Epoch 34/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9983 - f1_score: 0.9982
# Epoch 34: val_f1_score did not improve from 0.91028
# 42/42 [==============================] - 73s 2s/step - loss: 0.0070 - accuracy: 0.9983 - f1_score: 0.9982 - val_loss: 0.3518 - val_accuracy: 0.9112 - val_f1_score: 0.9096 - lr: 2.5000e-04
# Epoch 35/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9987 - f1_score: 0.9987
# Epoch 35: val_f1_score improved from 0.91028 to 0.91340, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 82s 2s/step - loss: 0.0059 - accuracy: 0.9987 - f1_score: 0.9987 - val_loss: 0.3500 - val_accuracy: 0.9147 - val_f1_score: 0.9134 - lr: 2.5000e-04
# Epoch 36/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9987 - f1_score: 0.9986
# Epoch 36: val_f1_score did not improve from 0.91340
# 42/42 [==============================] - 78s 2s/step - loss: 0.0054 - accuracy: 0.9987 - f1_score: 0.9986 - val_loss: 0.3488 - val_accuracy: 0.9139 - val_f1_score: 0.9133 - lr: 2.5000e-04
# Epoch 37/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9989 - f1_score: 0.9989
# Epoch 37: val_f1_score improved from 0.91340 to 0.91393, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 79s 2s/step - loss: 0.0059 - accuracy: 0.9989 - f1_score: 0.9989 - val_loss: 0.3550 - val_accuracy: 0.9155 - val_f1_score: 0.9139 - lr: 2.5000e-04
# Epoch 38/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9991 - f1_score: 0.9991
# Epoch 38: val_f1_score did not improve from 0.91393
# 42/42 [==============================] - 68s 2s/step - loss: 0.0046 - accuracy: 0.9991 - f1_score: 0.9991 - val_loss: 0.3598 - val_accuracy: 0.9151 - val_f1_score: 0.9126 - lr: 2.5000e-04
# Epoch 39/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9991 - f1_score: 0.9991
# Epoch 39: val_f1_score did not improve from 0.91393
# 42/42 [==============================] - 76s 2s/step - loss: 0.0044 - accuracy: 0.9991 - f1_score: 0.9991 - val_loss: 0.3671 - val_accuracy: 0.9139 - val_f1_score: 0.9099 - lr: 2.5000e-04
# Epoch 40/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9991 - f1_score: 0.9990
# Epoch 40: val_f1_score did not improve from 0.91393
# 42/42 [==============================] - 75s 2s/step - loss: 0.0047 - accuracy: 0.9991 - f1_score: 0.9990 - val_loss: 0.3611 - val_accuracy: 0.9151 - val_f1_score: 0.9122 - lr: 2.5000e-04
# Epoch 41/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9992 - f1_score: 0.9992
# Epoch 41: val_f1_score did not improve from 0.91393
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 76s 2s/step - loss: 0.0044 - accuracy: 0.9992 - f1_score: 0.9992 - val_loss: 0.3593 - val_accuracy: 0.9159 - val_f1_score: 0.9133 - lr: 2.5000e-04
# Epoch 42/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9995 - f1_score: 0.9996
# Epoch 42: val_f1_score did not improve from 0.91393
# 42/42 [==============================] - 72s 2s/step - loss: 0.0036 - accuracy: 0.9995 - f1_score: 0.9996 - val_loss: 0.3567 - val_accuracy: 0.9159 - val_f1_score: 0.9135 - lr: 1.2500e-04
# Epoch 43/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9990 - f1_score: 0.9988
# Epoch 43: val_f1_score did not improve from 0.91393
# 42/42 [==============================] - 76s 2s/step - loss: 0.0057 - accuracy: 0.9990 - f1_score: 0.9988 - val_loss: 0.3596 - val_accuracy: 0.9139 - val_f1_score: 0.9108 - lr: 1.2500e-04
# Epoch 44/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9991 - f1_score: 0.9993
# Epoch 44: val_f1_score did not improve from 0.91393
# 42/42 [==============================] - 76s 2s/step - loss: 0.0045 - accuracy: 0.9991 - f1_score: 0.9993 - val_loss: 0.3571 - val_accuracy: 0.9159 - val_f1_score: 0.9132 - lr: 1.2500e-04
# Epoch 45/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 45: val_f1_score improved from 0.91393 to 0.91471, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 82s 2s/step - loss: 0.0038 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3565 - val_accuracy: 0.9170 - val_f1_score: 0.9147 - lr: 1.2500e-04
# Epoch 46/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9996 - f1_score: 0.9995
# Epoch 46: val_f1_score did not improve from 0.91471
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 69s 2s/step - loss: 0.0034 - accuracy: 0.9996 - f1_score: 0.9995 - val_loss: 0.3493 - val_accuracy: 0.9151 - val_f1_score: 0.9131 - lr: 1.2500e-04
# Epoch 47/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9994 - f1_score: 0.9995
# Epoch 47: val_f1_score did not improve from 0.91471
# 42/42 [==============================] - 72s 2s/step - loss: 0.0032 - accuracy: 0.9994 - f1_score: 0.9995 - val_loss: 0.3495 - val_accuracy: 0.9159 - val_f1_score: 0.9129 - lr: 6.2500e-05
# Epoch 48/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 48: val_f1_score did not improve from 0.91471
# 42/42 [==============================] - 76s 2s/step - loss: 0.0029 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3509 - val_accuracy: 0.9166 - val_f1_score: 0.9143 - lr: 6.2500e-05
# Epoch 49/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9996 - f1_score: 0.9997
# Epoch 49: val_f1_score improved from 0.91471 to 0.91648, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 80s 2s/step - loss: 0.0033 - accuracy: 0.9996 - f1_score: 0.9997 - val_loss: 0.3495 - val_accuracy: 0.9182 - val_f1_score: 0.9165 - lr: 6.2500e-05
# Epoch 50/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9996 - f1_score: 0.9997
# Epoch 50: val_f1_score improved from 0.91648 to 0.91717, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 76s 2s/step - loss: 0.0031 - accuracy: 0.9996 - f1_score: 0.9997 - val_loss: 0.3471 - val_accuracy: 0.9186 - val_f1_score: 0.9172 - lr: 6.2500e-05
# Epoch 51/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 51: val_f1_score improved from 0.91717 to 0.91858, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 73s 2s/step - loss: 0.0033 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3463 - val_accuracy: 0.9205 - val_f1_score: 0.9186 - lr: 6.2500e-05
# Epoch 52/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995 - f1_score: 0.9996
# Epoch 52: val_f1_score improved from 0.91858 to 0.92014, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 82s 2s/step - loss: 0.0030 - accuracy: 0.9995 - f1_score: 0.9996 - val_loss: 0.3460 - val_accuracy: 0.9217 - val_f1_score: 0.9201 - lr: 6.2500e-05
# Epoch 53/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9991 - f1_score: 0.9992
# Epoch 53: val_f1_score did not improve from 0.92014
# 42/42 [==============================] - 76s 2s/step - loss: 0.0036 - accuracy: 0.9991 - f1_score: 0.9992 - val_loss: 0.3453 - val_accuracy: 0.9209 - val_f1_score: 0.9191 - lr: 6.2500e-05
# Epoch 54/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 54: val_f1_score did not improve from 0.92014
# 42/42 [==============================] - 73s 2s/step - loss: 0.0029 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3429 - val_accuracy: 0.9190 - val_f1_score: 0.9166 - lr: 6.2500e-05
# Epoch 55/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9993 - f1_score: 0.9992
# Epoch 55: val_f1_score did not improve from 0.92014
# 42/42 [==============================] - 67s 2s/step - loss: 0.0031 - accuracy: 0.9993 - f1_score: 0.9992 - val_loss: 0.3418 - val_accuracy: 0.9197 - val_f1_score: 0.9176 - lr: 6.2500e-05
# Epoch 56/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 56: val_f1_score did not improve from 0.92014
# 42/42 [==============================] - 77s 2s/step - loss: 0.0030 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3391 - val_accuracy: 0.9190 - val_f1_score: 0.9179 - lr: 6.2500e-05
# Epoch 57/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9995 - f1_score: 0.9996
# Epoch 57: val_f1_score did not improve from 0.92014
# 42/42 [==============================] - 76s 2s/step - loss: 0.0028 - accuracy: 0.9995 - f1_score: 0.9996 - val_loss: 0.3402 - val_accuracy: 0.9190 - val_f1_score: 0.9174 - lr: 6.2500e-05
# Epoch 58/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995 - f1_score: 0.9994
# Epoch 58: val_f1_score did not improve from 0.92014
# 42/42 [==============================] - 75s 2s/step - loss: 0.0031 - accuracy: 0.9995 - f1_score: 0.9994 - val_loss: 0.3386 - val_accuracy: 0.9209 - val_f1_score: 0.9194 - lr: 6.2500e-05
# Epoch 59/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996 - f1_score: 0.9997
# Epoch 59: val_f1_score improved from 0.92014 to 0.92091, saving model to saved_outputs_no_augment\Ensemble2_filter7\saved_models\best_Ensemble2_filter7.h5
# 42/42 [==============================] - 70s 2s/step - loss: 0.0025 - accuracy: 0.9996 - f1_score: 0.9997 - val_loss: 0.3359 - val_accuracy: 0.9228 - val_f1_score: 0.9209 - lr: 6.2500e-05
# Epoch 60/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 60: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 77s 2s/step - loss: 0.0030 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3384 - val_accuracy: 0.9201 - val_f1_score: 0.9186 - lr: 6.2500e-05
# Epoch 61/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9994 - f1_score: 0.9993
# Epoch 61: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 75s 2s/step - loss: 0.0028 - accuracy: 0.9994 - f1_score: 0.9993 - val_loss: 0.3408 - val_accuracy: 0.9205 - val_f1_score: 0.9189 - lr: 6.2500e-05
# Epoch 62/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992 - f1_score: 0.9993
# Epoch 62: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 78s 2s/step - loss: 0.0033 - accuracy: 0.9992 - f1_score: 0.9993 - val_loss: 0.3416 - val_accuracy: 0.9197 - val_f1_score: 0.9181 - lr: 6.2500e-05
# Epoch 63/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 63: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 66s 2s/step - loss: 0.0026 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3465 - val_accuracy: 0.9197 - val_f1_score: 0.9175 - lr: 6.2500e-05
# Epoch 64/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995 - f1_score: 0.9992
# Epoch 64: val_f1_score did not improve from 0.92091
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 42/42 [==============================] - 74s 2s/step - loss: 0.0031 - accuracy: 0.9995 - f1_score: 0.9992 - val_loss: 0.3449 - val_accuracy: 0.9205 - val_f1_score: 0.9183 - lr: 6.2500e-05
# Epoch 65/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9995 - f1_score: 0.9996
# Epoch 65: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 75s 2s/step - loss: 0.0029 - accuracy: 0.9995 - f1_score: 0.9996 - val_loss: 0.3432 - val_accuracy: 0.9209 - val_f1_score: 0.9188 - lr: 3.1250e-05
# Epoch 66/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 66: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 76s 2s/step - loss: 0.0025 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3436 - val_accuracy: 0.9209 - val_f1_score: 0.9191 - lr: 3.1250e-05
# Epoch 67/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996 - f1_score: 0.9997
# Epoch 67: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 69s 2s/step - loss: 0.0024 - accuracy: 0.9996 - f1_score: 0.9997 - val_loss: 0.3415 - val_accuracy: 0.9193 - val_f1_score: 0.9168 - lr: 3.1250e-05
# Epoch 68/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 68: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 66s 2s/step - loss: 0.0029 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3410 - val_accuracy: 0.9205 - val_f1_score: 0.9185 - lr: 3.1250e-05
# Epoch 69/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 69: val_f1_score did not improve from 0.92091
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 42/42 [==============================] - 77s 2s/step - loss: 0.0024 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3398 - val_accuracy: 0.9186 - val_f1_score: 0.9169 - lr: 3.1250e-05
# Epoch 70/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9999 - f1_score: 0.9999
# Epoch 70: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 75s 2s/step - loss: 0.0022 - accuracy: 0.9999 - f1_score: 0.9999 - val_loss: 0.3397 - val_accuracy: 0.9190 - val_f1_score: 0.9177 - lr: 1.5625e-05
# Epoch 71/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9993 - f1_score: 0.9994
# Epoch 71: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 74s 2s/step - loss: 0.0031 - accuracy: 0.9993 - f1_score: 0.9994 - val_loss: 0.3402 - val_accuracy: 0.9186 - val_f1_score: 0.9172 - lr: 1.5625e-05
# Epoch 72/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 72: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 69s 2s/step - loss: 0.0026 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3402 - val_accuracy: 0.9190 - val_f1_score: 0.9175 - lr: 1.5625e-05
# Epoch 73/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994 - f1_score: 0.9994
# Epoch 73: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 81s 2s/step - loss: 0.0030 - accuracy: 0.9994 - f1_score: 0.9994 - val_loss: 0.3405 - val_accuracy: 0.9190 - val_f1_score: 0.9173 - lr: 1.5625e-05
# Epoch 74/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 74: val_f1_score did not improve from 0.92091
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 42/42 [==============================] - 80s 2s/step - loss: 0.0021 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3410 - val_accuracy: 0.9193 - val_f1_score: 0.9177 - lr: 1.5625e-05
# Epoch 75/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 75: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 78s 2s/step - loss: 0.0025 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3413 - val_accuracy: 0.9197 - val_f1_score: 0.9183 - lr: 7.8125e-06
# Epoch 76/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995 - f1_score: 0.9997
# Epoch 76: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 73s 2s/step - loss: 0.0026 - accuracy: 0.9995 - f1_score: 0.9997 - val_loss: 0.3418 - val_accuracy: 0.9193 - val_f1_score: 0.9179 - lr: 7.8125e-06
# Epoch 77/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 77: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 71s 2s/step - loss: 0.0027 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3410 - val_accuracy: 0.9193 - val_f1_score: 0.9179 - lr: 7.8125e-06
# Epoch 78/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 78: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 75s 2s/step - loss: 0.0025 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3408 - val_accuracy: 0.9193 - val_f1_score: 0.9180 - lr: 7.8125e-06
# Epoch 79/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 79: val_f1_score did not improve from 0.92091
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 42/42 [==============================] - 77s 2s/step - loss: 0.0027 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3407 - val_accuracy: 0.9193 - val_f1_score: 0.9181 - lr: 7.8125e-06
# Epoch 80/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 80: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0028 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3409 - val_accuracy: 0.9197 - val_f1_score: 0.9182 - lr: 3.9063e-06
# Epoch 81/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 81: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 73s 2s/step - loss: 0.0029 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3412 - val_accuracy: 0.9201 - val_f1_score: 0.9187 - lr: 3.9063e-06
# Epoch 82/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 82: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0024 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3408 - val_accuracy: 0.9201 - val_f1_score: 0.9186 - lr: 3.9063e-06
# Epoch 83/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993 - f1_score: 0.9991
# Epoch 83: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0028 - accuracy: 0.9993 - f1_score: 0.9991 - val_loss: 0.3409 - val_accuracy: 0.9209 - val_f1_score: 0.9192 - lr: 3.9063e-06
# Epoch 84/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 84: val_f1_score did not improve from 0.92091
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 42/42 [==============================] - 78s 2s/step - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3412 - val_accuracy: 0.9201 - val_f1_score: 0.9187 - lr: 3.9063e-06
# Epoch 85/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994 - f1_score: 0.9996
# Epoch 85: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 76s 2s/step - loss: 0.0024 - accuracy: 0.9994 - f1_score: 0.9996 - val_loss: 0.3413 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 1.9531e-06
# Epoch 86/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 86: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 75s 2s/step - loss: 0.0032 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3414 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 1.9531e-06
# Epoch 87/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9999
# Epoch 87: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 80s 2s/step - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9999 - val_loss: 0.3413 - val_accuracy: 0.9217 - val_f1_score: 0.9199 - lr: 1.9531e-06
# Epoch 88/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9993 - f1_score: 0.9994
# Epoch 88: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0030 - accuracy: 0.9993 - f1_score: 0.9994 - val_loss: 0.3414 - val_accuracy: 0.9220 - val_f1_score: 0.9202 - lr: 1.9531e-06
# Epoch 89/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 89: val_f1_score did not improve from 0.92091
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 42/42 [==============================] - 80s 2s/step - loss: 0.0023 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3417 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 1.9531e-06
# Epoch 90/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 90: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 76s 2s/step - loss: 0.0020 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3418 - val_accuracy: 0.9217 - val_f1_score: 0.9199 - lr: 9.7656e-07
# Epoch 91/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 91: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 76s 2s/step - loss: 0.0025 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3418 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 9.7656e-07
# Epoch 92/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 92: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 80s 2s/step - loss: 0.0025 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3419 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 9.7656e-07
# Epoch 93/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 93: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 80s 2s/step - loss: 0.0023 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3417 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 9.7656e-07
# Epoch 94/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996 - f1_score: 0.9994
# Epoch 94: val_f1_score did not improve from 0.92091
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 42/42 [==============================] - 79s 2s/step - loss: 0.0024 - accuracy: 0.9996 - f1_score: 0.9994 - val_loss: 0.3417 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 9.7656e-07
# Epoch 95/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9997 - f1_score: 0.9996
# Epoch 95: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 74s 2s/step - loss: 0.0026 - accuracy: 0.9997 - f1_score: 0.9996 - val_loss: 0.3416 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 4.8828e-07
# Epoch 96/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9997 - f1_score: 0.9998
# Epoch 96: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 80s 2s/step - loss: 0.0019 - accuracy: 0.9997 - f1_score: 0.9998 - val_loss: 0.3415 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 4.8828e-07
# Epoch 97/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996 - f1_score: 0.9997
# Epoch 97: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0020 - accuracy: 0.9996 - f1_score: 0.9997 - val_loss: 0.3418 - val_accuracy: 0.9209 - val_f1_score: 0.9190 - lr: 4.8828e-07
# Epoch 98/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 98: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 81s 2s/step - loss: 0.0022 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3418 - val_accuracy: 0.9205 - val_f1_score: 0.9186 - lr: 4.8828e-07
# Epoch 99/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993 - f1_score: 0.9992
# Epoch 99: val_f1_score did not improve from 0.92091
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 42/42 [==============================] - 76s 2s/step - loss: 0.0027 - accuracy: 0.9993 - f1_score: 0.9992 - val_loss: 0.3419 - val_accuracy: 0.9209 - val_f1_score: 0.9190 - lr: 4.8828e-07
# Epoch 100/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 100: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 77s 2s/step - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3419 - val_accuracy: 0.9201 - val_f1_score: 0.9183 - lr: 2.4414e-07
# Epoch 101/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9999 - f1_score: 0.9999
# Epoch 101: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0023 - accuracy: 0.9999 - f1_score: 0.9999 - val_loss: 0.3417 - val_accuracy: 0.9209 - val_f1_score: 0.9190 - lr: 2.4414e-07
# Epoch 102/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 102: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0024 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3417 - val_accuracy: 0.9205 - val_f1_score: 0.9189 - lr: 2.4414e-07
# Epoch 103/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 103: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 80s 2s/step - loss: 0.0023 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3418 - val_accuracy: 0.9213 - val_f1_score: 0.9195 - lr: 2.4414e-07
# Epoch 104/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 104: val_f1_score did not improve from 0.92091
#
# Epoch 104: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 42/42 [==============================] - 73s 2s/step - loss: 0.0021 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3416 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 2.4414e-07
# Epoch 105/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 105: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0020 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3414 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 1.2207e-07
# Epoch 106/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 106: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 81s 2s/step - loss: 0.0024 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3412 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 1.2207e-07
# Epoch 107/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 107: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 79s 2s/step - loss: 0.0025 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3414 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 1.2207e-07
# Epoch 108/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996 - f1_score: 0.9997
# Epoch 108: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 77s 2s/step - loss: 0.0020 - accuracy: 0.9996 - f1_score: 0.9997 - val_loss: 0.3416 - val_accuracy: 0.9201 - val_f1_score: 0.9186 - lr: 1.2207e-07
# Epoch 109/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995 - f1_score: 0.9994
# Epoch 109: val_f1_score did not improve from 0.92091
#
# Epoch 109: ReduceLROnPlateau reducing learning rate to 1e-07.
# 42/42 [==============================] - 73s 2s/step - loss: 0.0024 - accuracy: 0.9995 - f1_score: 0.9994 - val_loss: 0.3417 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 1.2207e-07
# Epoch 110/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9995 - f1_score: 0.9993
# Epoch 110: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 77s 2s/step - loss: 0.0023 - accuracy: 0.9995 - f1_score: 0.9993 - val_loss: 0.3417 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 1.0000e-07
# Epoch 111/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996 - f1_score: 0.9996
# Epoch 111: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 76s 2s/step - loss: 0.0020 - accuracy: 0.9996 - f1_score: 0.9996 - val_loss: 0.3417 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 1.0000e-07
# Epoch 112/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9997 - f1_score: 0.9998
# Epoch 112: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 78s 2s/step - loss: 0.0023 - accuracy: 0.9997 - f1_score: 0.9998 - val_loss: 0.3416 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 1.0000e-07
# Epoch 113/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995 - f1_score: 0.9995
# Epoch 113: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 73s 2s/step - loss: 0.0027 - accuracy: 0.9995 - f1_score: 0.9995 - val_loss: 0.3416 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 1.0000e-07
# Epoch 114/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994 - f1_score: 0.9995
# Epoch 114: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 73s 2s/step - loss: 0.0026 - accuracy: 0.9994 - f1_score: 0.9995 - val_loss: 0.3416 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 1.0000e-07
# Epoch 115/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992 - f1_score: 0.9992
# Epoch 115: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 77s 2s/step - loss: 0.0036 - accuracy: 0.9992 - f1_score: 0.9992 - val_loss: 0.3417 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 1.0000e-07
# Epoch 116/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 116: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 75s 2s/step - loss: 0.0021 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3417 - val_accuracy: 0.9213 - val_f1_score: 0.9195 - lr: 1.0000e-07
# Epoch 117/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996 - f1_score: 0.9995
# Epoch 117: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 78s 2s/step - loss: 0.0024 - accuracy: 0.9996 - f1_score: 0.9995 - val_loss: 0.3416 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 1.0000e-07
# Epoch 118/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9998
# Epoch 118: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 72s 2s/step - loss: 0.0022 - accuracy: 0.9998 - f1_score: 0.9998 - val_loss: 0.3416 - val_accuracy: 0.9213 - val_f1_score: 0.9196 - lr: 1.0000e-07
# Epoch 119/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9997 - f1_score: 0.9997
# Epoch 119: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 70s 2s/step - loss: 0.0022 - accuracy: 0.9997 - f1_score: 0.9997 - val_loss: 0.3416 - val_accuracy: 0.9205 - val_f1_score: 0.9190 - lr: 1.0000e-07
# Epoch 120/120
# 42/42 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9993 - f1_score: 0.9994
# Epoch 120: val_f1_score did not improve from 0.92091
# 42/42 [==============================] - 77s 2s/step - loss: 0.0029 - accuracy: 0.9993 - f1_score: 0.9994 - val_loss: 0.3415 - val_accuracy: 0.9209 - val_f1_score: 0.9192 - lr: 1.0000e-07

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history, model_name = model_name, SAVE_RESULTS= SAVE_RESULTS)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 13/13 [==============================] - 23s 1s/step - loss: 0.3055 - accuracy: 0.9254 - f1_score: 0.9213
#           model_name  test_loss  test_accuracy  test_f1_score
# 0  Ensemble2_filter7   0.305485       0.925424       0.921318

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 13/13 [==============================] - 22s 1s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test , 
                                      model_name=model_name, 
                                      SAVE_RESULTS=SAVE_RESULTS)
# Out:
#               precision    recall  f1-score      support
# 0              0.871212  0.884615  0.877863   130.000000
# 1              0.912621  0.940000  0.926108   100.000000
# 2              0.929412  0.877778  0.902857    90.000000
# 3              0.967391  0.881188  0.922280   101.000000
# 4              0.923554  0.951064  0.937107   470.000000
# 5              0.940000  0.928854  0.934394   253.000000
# 6              0.902857  0.908046  0.905444   174.000000
# 7              0.909722  0.911833  0.910776   431.000000
# 8              0.907407  0.894977  0.901149   219.000000
# 9              0.938017  0.943867  0.940933   481.000000
# 10             0.939948  0.923077  0.931436   390.000000
# 11             0.922481  0.937008  0.929688   254.000000
# 12             0.960265  0.953947  0.957096   152.000000
# accuracy       0.925424  0.925424  0.925424     0.925424
# macro avg      0.924991  0.918173  0.921318  3245.000000
# weighted avg   0.925642  0.925424  0.925391  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test , 
                           model_name=model_name, 
                           SAVE_RESULTS=SAVE_RESULTS)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test, 
                                       model_name=model_name, 
                                       SAVE_RESULTS=SAVE_RESULTS, 
                                       test_loss=test_loss)
# Out:
#           Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  Ensemble2_filter7  0.925424         0.924991      0.918173        0.921318
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.925642         0.925424           0.925391  0.305485

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc, SHOW_RESULTS=True, SAVE_RESULTS=True)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.92542
# 1      Macro Precision  0.92499
# 2         Macro Recall  0.91817
# 3       Macro F1-Score  0.92132
# 4            Macro FPR  0.00639
# 5            Macro FNR  0.08183
# 6            Macro FDR  0.07501
# 7            Macro NPV  0.99365
# 8   Weighted Precision  0.92564
# 9      Weighted Recall  0.92542
# 10   Weighted F1-Score  0.92539
# 11        Weighted FPR  0.00849
# 12        Weighted FNR  0.07458
# 13        Weighted FDR  0.07436
# 14        Weighted NPV  0.99204
