# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files


import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report

import time
from tqdm import tqdm

import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'InceptionV3_v4'#'Xception'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment_3RD_RUN', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_all_augment_3RD_RUN\InceptionV3_v4
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_10708\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=12, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:      
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:        
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %% [markdown]
# #### Original models from keras

# %%
from tensorflow.keras.applications import InceptionV3
def get_InceptionV3(): 
 
    # model = Sequential()
    # base_model = InceptionV3(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)
    model = InceptionV3(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 2.0559 - accuracy: 0.3593 - f1_score: 0.2590
# Epoch 1: val_f1_score improved from -inf to 0.00778, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 113s 916ms/step - loss: 2.0559 - accuracy: 0.3593 - f1_score: 0.2590 - val_loss: 3.2178 - val_accuracy: 0.0533 - val_f1_score: 0.0078 - lr: 0.0010
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 1.4858 - accuracy: 0.5190 - f1_score: 0.4623
# Epoch 2: val_f1_score improved from 0.00778 to 0.00779, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 84s 806ms/step - loss: 1.4858 - accuracy: 0.5190 - f1_score: 0.4623 - val_loss: 4.1646 - val_accuracy: 0.0533 - val_f1_score: 0.0078 - lr: 0.0010
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 1.2382 - accuracy: 0.6010 - f1_score: 0.5649
# Epoch 3: val_f1_score improved from 0.00779 to 0.05039, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 85s 814ms/step - loss: 1.2382 - accuracy: 0.6010 - f1_score: 0.5649 - val_loss: 5.5407 - val_accuracy: 0.1517 - val_f1_score: 0.0504 - lr: 0.0010
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1828 - accuracy: 0.6235 - f1_score: 0.5888
# Epoch 4: val_f1_score did not improve from 0.05039
# 104/104 [==============================] - 78s 750ms/step - loss: 1.1828 - accuracy: 0.6235 - f1_score: 0.5888 - val_loss: 38.7468 - val_accuracy: 0.1115 - val_f1_score: 0.0193 - lr: 0.0010
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 1.0359 - accuracy: 0.6716 - f1_score: 0.6407
# Epoch 5: val_f1_score improved from 0.05039 to 0.13013, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 81s 781ms/step - loss: 1.0359 - accuracy: 0.6716 - f1_score: 0.6407 - val_loss: 3.6193 - val_accuracy: 0.2327 - val_f1_score: 0.1301 - lr: 0.0010
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8085 - accuracy: 0.7391 - f1_score: 0.7116
# Epoch 6: val_f1_score improved from 0.13013 to 0.54874, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 77s 733ms/step - loss: 0.8085 - accuracy: 0.7391 - f1_score: 0.7116 - val_loss: 1.7108 - val_accuracy: 0.5920 - val_f1_score: 0.5487 - lr: 0.0010
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 0.8301 - accuracy: 0.7374 - f1_score: 0.7108
# Epoch 7: val_f1_score did not improve from 0.54874
# 104/104 [==============================] - 79s 761ms/step - loss: 0.8301 - accuracy: 0.7374 - f1_score: 0.7108 - val_loss: 1.6644 - val_accuracy: 0.5658 - val_f1_score: 0.4902 - lr: 0.0010
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.7978 - f1_score: 0.7801
# Epoch 8: val_f1_score improved from 0.54874 to 0.58140, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 85s 814ms/step - loss: 0.6177 - accuracy: 0.7978 - f1_score: 0.7801 - val_loss: 1.3140 - val_accuracy: 0.6121 - val_f1_score: 0.5814 - lr: 0.0010
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6148 - accuracy: 0.8012 - f1_score: 0.7835
# Epoch 9: val_f1_score did not improve from 0.58140
# 104/104 [==============================] - 92s 882ms/step - loss: 0.6148 - accuracy: 0.8012 - f1_score: 0.7835 - val_loss: 1.9948 - val_accuracy: 0.5592 - val_f1_score: 0.4877 - lr: 0.0010
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5173 - accuracy: 0.8344 - f1_score: 0.8226
# Epoch 10: val_f1_score improved from 0.58140 to 0.67587, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 91s 867ms/step - loss: 0.5173 - accuracy: 0.8344 - f1_score: 0.8226 - val_loss: 0.9806 - val_accuracy: 0.6990 - val_f1_score: 0.6759 - lr: 0.0010
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.8461 - f1_score: 0.8347
# Epoch 11: val_f1_score did not improve from 0.67587
# 104/104 [==============================] - 85s 810ms/step - loss: 0.4729 - accuracy: 0.8461 - f1_score: 0.8347 - val_loss: 1.7711 - val_accuracy: 0.5372 - val_f1_score: 0.5054 - lr: 0.0010
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4691 - accuracy: 0.8465 - f1_score: 0.8355
# Epoch 12: val_f1_score improved from 0.67587 to 0.68503, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 88s 846ms/step - loss: 0.4691 - accuracy: 0.8465 - f1_score: 0.8355 - val_loss: 0.9798 - val_accuracy: 0.7125 - val_f1_score: 0.6850 - lr: 0.0010
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8724 - f1_score: 0.8614
# Epoch 13: val_f1_score improved from 0.68503 to 0.71430, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 86s 822ms/step - loss: 0.3931 - accuracy: 0.8724 - f1_score: 0.8614 - val_loss: 0.8538 - val_accuracy: 0.7399 - val_f1_score: 0.7143 - lr: 0.0010
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8894 - f1_score: 0.8836
# Epoch 14: val_f1_score did not improve from 0.71430
# 104/104 [==============================] - 83s 797ms/step - loss: 0.3392 - accuracy: 0.8894 - f1_score: 0.8836 - val_loss: 1.1603 - val_accuracy: 0.6646 - val_f1_score: 0.6488 - lr: 0.0010
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.8708 - f1_score: 0.8633
# Epoch 15: val_f1_score improved from 0.71430 to 0.74298, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 90s 857ms/step - loss: 0.4050 - accuracy: 0.8708 - f1_score: 0.8633 - val_loss: 0.8278 - val_accuracy: 0.7630 - val_f1_score: 0.7430 - lr: 0.0010
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.9024 - f1_score: 0.8957
# Epoch 16: val_f1_score improved from 0.74298 to 0.79004, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 88s 839ms/step - loss: 0.2982 - accuracy: 0.9024 - f1_score: 0.8957 - val_loss: 0.6266 - val_accuracy: 0.8159 - val_f1_score: 0.7900 - lr: 0.0010
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.9117 - f1_score: 0.9075
# Epoch 17: val_f1_score did not improve from 0.79004
# 104/104 [==============================] - 80s 771ms/step - loss: 0.2647 - accuracy: 0.9117 - f1_score: 0.9075 - val_loss: 2.8819 - val_accuracy: 0.4427 - val_f1_score: 0.4133 - lr: 0.0010
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9172 - f1_score: 0.9124
# Epoch 18: val_f1_score did not improve from 0.79004
# 104/104 [==============================] - 79s 760ms/step - loss: 0.2468 - accuracy: 0.9172 - f1_score: 0.9124 - val_loss: 2.1831 - val_accuracy: 0.5264 - val_f1_score: 0.4934 - lr: 0.0010
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9198 - f1_score: 0.9147
# Epoch 19: val_f1_score did not improve from 0.79004
# 104/104 [==============================] - 79s 759ms/step - loss: 0.2403 - accuracy: 0.9198 - f1_score: 0.9147 - val_loss: 1.3416 - val_accuracy: 0.6650 - val_f1_score: 0.6390 - lr: 0.0010
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9208 - f1_score: 0.9152
# Epoch 20: val_f1_score did not improve from 0.79004
# 104/104 [==============================] - 83s 793ms/step - loss: 0.2408 - accuracy: 0.9208 - f1_score: 0.9152 - val_loss: 0.7593 - val_accuracy: 0.7731 - val_f1_score: 0.7542 - lr: 0.0010
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9289 - f1_score: 0.9245
# Epoch 21: val_f1_score improved from 0.79004 to 0.86105, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 88s 848ms/step - loss: 0.2188 - accuracy: 0.9289 - f1_score: 0.9245 - val_loss: 0.4114 - val_accuracy: 0.8765 - val_f1_score: 0.8611 - lr: 0.0010
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9369 - f1_score: 0.9322
# Epoch 22: val_f1_score did not improve from 0.86105
# 104/104 [==============================] - 82s 782ms/step - loss: 0.1898 - accuracy: 0.9369 - f1_score: 0.9322 - val_loss: 0.5665 - val_accuracy: 0.8279 - val_f1_score: 0.8088 - lr: 0.0010
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9424 - f1_score: 0.9394
# Epoch 23: val_f1_score did not improve from 0.86105
# 104/104 [==============================] - 79s 760ms/step - loss: 0.1728 - accuracy: 0.9424 - f1_score: 0.9394 - val_loss: 0.8556 - val_accuracy: 0.7785 - val_f1_score: 0.7625 - lr: 0.0010
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9440 - f1_score: 0.9390
# Epoch 24: val_f1_score did not improve from 0.86105
# 104/104 [==============================] - 79s 754ms/step - loss: 0.1804 - accuracy: 0.9440 - f1_score: 0.9390 - val_loss: 0.5162 - val_accuracy: 0.8391 - val_f1_score: 0.8237 - lr: 0.0010
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9352 - f1_score: 0.9323
# Epoch 25: val_f1_score did not improve from 0.86105
# 104/104 [==============================] - 80s 761ms/step - loss: 0.1970 - accuracy: 0.9352 - f1_score: 0.9323 - val_loss: 1.5579 - val_accuracy: 0.6202 - val_f1_score: 0.5959 - lr: 0.0010
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9463 - f1_score: 0.9435
# Epoch 26: val_f1_score did not improve from 0.86105
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 79s 752ms/step - loss: 0.1704 - accuracy: 0.9463 - f1_score: 0.9435 - val_loss: 0.5301 - val_accuracy: 0.8495 - val_f1_score: 0.8362 - lr: 0.0010
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9709 - f1_score: 0.9694
# Epoch 27: val_f1_score improved from 0.86105 to 0.92090, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 83s 793ms/step - loss: 0.0850 - accuracy: 0.9709 - f1_score: 0.9694 - val_loss: 0.2774 - val_accuracy: 0.9205 - val_f1_score: 0.9209 - lr: 5.0000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9816 - f1_score: 0.9808
# Epoch 28: val_f1_score improved from 0.92090 to 0.92435, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 83s 796ms/step - loss: 0.0578 - accuracy: 0.9816 - f1_score: 0.9808 - val_loss: 0.2753 - val_accuracy: 0.9271 - val_f1_score: 0.9243 - lr: 5.0000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9813 - f1_score: 0.9812
# Epoch 29: val_f1_score improved from 0.92435 to 0.93702, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 84s 802ms/step - loss: 0.0543 - accuracy: 0.9813 - f1_score: 0.9812 - val_loss: 0.2025 - val_accuracy: 0.9398 - val_f1_score: 0.9370 - lr: 5.0000e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9807 - f1_score: 0.9805
# Epoch 30: val_f1_score did not improve from 0.93702
# 104/104 [==============================] - 76s 727ms/step - loss: 0.0585 - accuracy: 0.9807 - f1_score: 0.9805 - val_loss: 0.2610 - val_accuracy: 0.9267 - val_f1_score: 0.9158 - lr: 5.0000e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9807 - f1_score: 0.9787
# Epoch 31: val_f1_score did not improve from 0.93702
# 104/104 [==============================] - 75s 722ms/step - loss: 0.0568 - accuracy: 0.9807 - f1_score: 0.9787 - val_loss: 0.2485 - val_accuracy: 0.9286 - val_f1_score: 0.9224 - lr: 5.0000e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9831 - f1_score: 0.9819
# Epoch 32: val_f1_score improved from 0.93702 to 0.93754, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 81s 773ms/step - loss: 0.0521 - accuracy: 0.9831 - f1_score: 0.9819 - val_loss: 0.2174 - val_accuracy: 0.9425 - val_f1_score: 0.9375 - lr: 5.0000e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9777 - f1_score: 0.9758
# Epoch 33: val_f1_score did not improve from 0.93754
# 104/104 [==============================] - 82s 783ms/step - loss: 0.0695 - accuracy: 0.9777 - f1_score: 0.9758 - val_loss: 0.3926 - val_accuracy: 0.8946 - val_f1_score: 0.8950 - lr: 5.0000e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9796 - f1_score: 0.9795
# Epoch 34: val_f1_score did not improve from 0.93754
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 79s 759ms/step - loss: 0.0596 - accuracy: 0.9796 - f1_score: 0.9795 - val_loss: 0.3823 - val_accuracy: 0.8954 - val_f1_score: 0.8986 - lr: 5.0000e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9854 - f1_score: 0.9851
# Epoch 35: val_f1_score improved from 0.93754 to 0.94958, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 81s 775ms/step - loss: 0.0426 - accuracy: 0.9854 - f1_score: 0.9851 - val_loss: 0.1838 - val_accuracy: 0.9502 - val_f1_score: 0.9496 - lr: 2.5000e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9893 - f1_score: 0.9884
# Epoch 36: val_f1_score improved from 0.94958 to 0.95442, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 83s 802ms/step - loss: 0.0297 - accuracy: 0.9893 - f1_score: 0.9884 - val_loss: 0.1717 - val_accuracy: 0.9564 - val_f1_score: 0.9544 - lr: 2.5000e-04
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9897 - f1_score: 0.9893
# Epoch 37: val_f1_score did not improve from 0.95442
# 104/104 [==============================] - 80s 762ms/step - loss: 0.0294 - accuracy: 0.9897 - f1_score: 0.9893 - val_loss: 0.2113 - val_accuracy: 0.9464 - val_f1_score: 0.9436 - lr: 2.5000e-04
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9907 - f1_score: 0.9903
# Epoch 38: val_f1_score improved from 0.95442 to 0.95827, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 87s 833ms/step - loss: 0.0246 - accuracy: 0.9907 - f1_score: 0.9903 - val_loss: 0.1720 - val_accuracy: 0.9556 - val_f1_score: 0.9583 - lr: 2.5000e-04
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9895 - f1_score: 0.9890
# Epoch 39: val_f1_score improved from 0.95827 to 0.95898, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 89s 857ms/step - loss: 0.0308 - accuracy: 0.9895 - f1_score: 0.9890 - val_loss: 0.1638 - val_accuracy: 0.9587 - val_f1_score: 0.9590 - lr: 2.5000e-04
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9896 - f1_score: 0.9892
# Epoch 40: val_f1_score did not improve from 0.95898
# 104/104 [==============================] - 80s 767ms/step - loss: 0.0281 - accuracy: 0.9896 - f1_score: 0.9892 - val_loss: 0.2197 - val_accuracy: 0.9386 - val_f1_score: 0.9400 - lr: 2.5000e-04
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9898 - f1_score: 0.9899
# Epoch 41: val_f1_score did not improve from 0.95898
# 104/104 [==============================] - 81s 776ms/step - loss: 0.0269 - accuracy: 0.9898 - f1_score: 0.9899 - val_loss: 0.2348 - val_accuracy: 0.9402 - val_f1_score: 0.9380 - lr: 2.5000e-04
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9922 - f1_score: 0.9914
# Epoch 42: val_f1_score did not improve from 0.95898
# 104/104 [==============================] - 79s 752ms/step - loss: 0.0214 - accuracy: 0.9922 - f1_score: 0.9914 - val_loss: 0.1809 - val_accuracy: 0.9545 - val_f1_score: 0.9547 - lr: 2.5000e-04
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9892 - f1_score: 0.9883
# Epoch 43: val_f1_score did not improve from 0.95898
# 104/104 [==============================] - 79s 760ms/step - loss: 0.0304 - accuracy: 0.9892 - f1_score: 0.9883 - val_loss: 0.3077 - val_accuracy: 0.9209 - val_f1_score: 0.9193 - lr: 2.5000e-04
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9892 - f1_score: 0.9887
# Epoch 44: val_f1_score improved from 0.95898 to 0.95944, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 86s 819ms/step - loss: 0.0315 - accuracy: 0.9892 - f1_score: 0.9887 - val_loss: 0.1833 - val_accuracy: 0.9602 - val_f1_score: 0.9594 - lr: 2.5000e-04
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9922 - f1_score: 0.9920
# Epoch 45: val_f1_score did not improve from 0.95944
# 104/104 [==============================] - 94s 898ms/step - loss: 0.0204 - accuracy: 0.9922 - f1_score: 0.9920 - val_loss: 0.1794 - val_accuracy: 0.9514 - val_f1_score: 0.9511 - lr: 1.2500e-04
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9925 - f1_score: 0.9924
# Epoch 46: val_f1_score did not improve from 0.95944
# 104/104 [==============================] - 94s 893ms/step - loss: 0.0219 - accuracy: 0.9925 - f1_score: 0.9924 - val_loss: 0.1939 - val_accuracy: 0.9537 - val_f1_score: 0.9543 - lr: 1.2500e-04
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 47: val_f1_score improved from 0.95944 to 0.96588, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 100s 957ms/step - loss: 0.0178 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.1543 - val_accuracy: 0.9664 - val_f1_score: 0.9659 - lr: 1.2500e-04
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9931 - f1_score: 0.9924
# Epoch 48: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 93s 891ms/step - loss: 0.0175 - accuracy: 0.9931 - f1_score: 0.9924 - val_loss: 0.1760 - val_accuracy: 0.9591 - val_f1_score: 0.9589 - lr: 1.2500e-04
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9927 - f1_score: 0.9918
# Epoch 49: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 94s 904ms/step - loss: 0.0198 - accuracy: 0.9927 - f1_score: 0.9918 - val_loss: 0.1994 - val_accuracy: 0.9575 - val_f1_score: 0.9591 - lr: 1.2500e-04
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9931 - f1_score: 0.9929
# Epoch 50: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 92s 882ms/step - loss: 0.0172 - accuracy: 0.9931 - f1_score: 0.9929 - val_loss: 0.1792 - val_accuracy: 0.9587 - val_f1_score: 0.9593 - lr: 1.2500e-04
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9937 - f1_score: 0.9932
# Epoch 51: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 93s 893ms/step - loss: 0.0163 - accuracy: 0.9937 - f1_score: 0.9932 - val_loss: 0.1835 - val_accuracy: 0.9575 - val_f1_score: 0.9589 - lr: 1.2500e-04
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9938 - f1_score: 0.9930
# Epoch 52: val_f1_score did not improve from 0.96588
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 93s 897ms/step - loss: 0.0169 - accuracy: 0.9938 - f1_score: 0.9930 - val_loss: 0.1661 - val_accuracy: 0.9657 - val_f1_score: 0.9655 - lr: 1.2500e-04
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9942 - f1_score: 0.9935
# Epoch 53: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 94s 907ms/step - loss: 0.0149 - accuracy: 0.9942 - f1_score: 0.9935 - val_loss: 0.1671 - val_accuracy: 0.9641 - val_f1_score: 0.9645 - lr: 6.2500e-05
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9948 - f1_score: 0.9939
# Epoch 54: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 92s 882ms/step - loss: 0.0121 - accuracy: 0.9948 - f1_score: 0.9939 - val_loss: 0.1678 - val_accuracy: 0.9645 - val_f1_score: 0.9647 - lr: 6.2500e-05
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9948 - f1_score: 0.9939
# Epoch 55: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 90s 861ms/step - loss: 0.0115 - accuracy: 0.9948 - f1_score: 0.9939 - val_loss: 0.1693 - val_accuracy: 0.9622 - val_f1_score: 0.9608 - lr: 6.2500e-05
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9949 - f1_score: 0.9942
# Epoch 56: val_f1_score did not improve from 0.96588
# 104/104 [==============================] - 91s 877ms/step - loss: 0.0121 - accuracy: 0.9949 - f1_score: 0.9942 - val_loss: 0.1842 - val_accuracy: 0.9649 - val_f1_score: 0.9653 - lr: 6.2500e-05
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9949 - f1_score: 0.9947
# Epoch 57: val_f1_score did not improve from 0.96588
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 88s 842ms/step - loss: 0.0139 - accuracy: 0.9949 - f1_score: 0.9947 - val_loss: 0.1669 - val_accuracy: 0.9649 - val_f1_score: 0.9640 - lr: 6.2500e-05
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9959 - f1_score: 0.9955
# Epoch 58: val_f1_score improved from 0.96588 to 0.96751, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 97s 932ms/step - loss: 0.0116 - accuracy: 0.9959 - f1_score: 0.9955 - val_loss: 0.1648 - val_accuracy: 0.9657 - val_f1_score: 0.9675 - lr: 3.1250e-05
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9964 - f1_score: 0.9960
# Epoch 59: val_f1_score improved from 0.96751 to 0.96795, saving model to saved_outputs_all_augment_3RD_RUN\InceptionV3_v4\saved_models\best_InceptionV3_v4.h5
# 104/104 [==============================] - 99s 945ms/step - loss: 0.0099 - accuracy: 0.9964 - f1_score: 0.9960 - val_loss: 0.1676 - val_accuracy: 0.9660 - val_f1_score: 0.9679 - lr: 3.1250e-05

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 15s 381ms/step - loss: 0.2255 - accuracy: 0.9482 - f1_score: 0.9471
#        model_name  test_loss  test_accuracy  test_f1_score
# 0  InceptionV3_v4   0.225475       0.948228        0.94708

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 9s 207ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                            target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.931818  0.946154  0.938931   130.000000
# 1              0.958333  0.920000  0.938776   100.000000
# 2              0.988235  0.933333  0.960000    90.000000
# 3              0.979381  0.940594  0.959596   101.000000
# 4              0.930612  0.970213  0.950000   470.000000
# 5              0.951613  0.932806  0.942116   253.000000
# 6              0.924855  0.919540  0.922190   174.000000
# 7              0.958637  0.914153  0.935867   431.000000
# 8              0.902222  0.926941  0.914414   219.000000
# 9              0.957230  0.977131  0.967078   481.000000
# 10             0.963446  0.946154  0.954722   390.000000
# 11             0.946565  0.976378  0.961240   254.000000
# 12             0.967105  0.967105  0.967105   152.000000
# accuracy       0.948228  0.948228  0.948228     0.948228
# macro avg      0.950773  0.943885  0.947080  3245.000000
# weighted avg   0.948616  0.948228  0.948182  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#        Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  InceptionV3_v4  0.948228         0.950773      0.943885         0.94708
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.948616         0.948228           0.948182  0.225475

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.94823
# 1      Macro Precision  0.95077
# 2         Macro Recall  0.94388
# 3       Macro F1-Score  0.94708
# 4            Macro FPR  0.00444
# 5            Macro FNR  0.05612
# 6            Macro FDR  0.04923
# 7            Macro NPV  0.99560
# 8   Weighted Precision  0.94862
# 9      Weighted Recall  0.94823
# 10   Weighted F1-Score  0.94818
# 11        Weighted FPR  0.00595
# 12        Weighted FNR  0.05177
# 13        Weighted FDR  0.05138
# 14        Weighted NPV  0.99450
