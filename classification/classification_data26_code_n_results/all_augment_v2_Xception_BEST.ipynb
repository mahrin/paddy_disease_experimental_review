# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files


import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'Xception'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 150
EPOCHS = 150 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_all_augment\Xception
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment\Xception\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment\Xception\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_17280\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'_.h5'
    ## Criteria for early stopping
#    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    my_callbacks = [best_model_callback ]#, reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################
    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= 50, #epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    return saved_best_model_name, train_history

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    ##########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00001   # Lower bound on the learning rate.
    )

    my_callbacks = [ best_weight_callback]#, EarlyStop_callback]  , reduce_LRbest_model_callback,
    ##########################################################################################################
    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    return  PATH_BEST_WEIGHT_SAVE, train_history #model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None, model_name="default_name", SAVE_RESULTS = False):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model, SAVE_RESULTS=False):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss, model_name="default_name", SAVE_RESULTS=False ):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %% [markdown]
# #### Original models from keras

# %%
from tensorflow.keras.applications import Xception
def get_Xception(): 
 
    # model = Sequential()
    # base_model = Xception(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)
    model = Xception(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point # 0-150
best_model_name, train_history = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/150
# 70/70 [==============================] - ETA: 0s - loss: 2.1900 - accuracy: 0.2553 - f1_score: 0.1497
# Epoch 1: val_f1_score improved from -inf to 0.01803, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 337s 5s/step - loss: 2.1900 - accuracy: 0.2553 - f1_score: 0.1497 - val_loss: 2.5498 - val_accuracy: 0.1328 - val_f1_score: 0.0180
# Epoch 2/150
# 70/70 [==============================] - ETA: 0s - loss: 1.8398 - accuracy: 0.3814 - f1_score: 0.2739
# Epoch 2: val_f1_score did not improve from 0.01803
# 70/70 [==============================] - 314s 4s/step - loss: 1.8398 - accuracy: 0.3814 - f1_score: 0.2739 - val_loss: 2.5363 - val_accuracy: 0.1328 - val_f1_score: 0.0180
# Epoch 3/150
# 70/70 [==============================] - ETA: 0s - loss: 1.6434 - accuracy: 0.4420 - f1_score: 0.3673
# Epoch 3: val_f1_score improved from 0.01803 to 0.01950, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 313s 4s/step - loss: 1.6434 - accuracy: 0.4420 - f1_score: 0.3673 - val_loss: 2.5202 - val_accuracy: 0.1451 - val_f1_score: 0.0195
# Epoch 4/150
# 70/70 [==============================] - ETA: 0s - loss: 1.4611 - accuracy: 0.5075 - f1_score: 0.4518
# Epoch 4: val_f1_score did not improve from 0.01950
# 70/70 [==============================] - 144s 2s/step - loss: 1.4611 - accuracy: 0.5075 - f1_score: 0.4518 - val_loss: 2.5009 - val_accuracy: 0.1328 - val_f1_score: 0.0180
# Epoch 5/150
# 70/70 [==============================] - ETA: 0s - loss: 1.3064 - accuracy: 0.5588 - f1_score: 0.5158
# Epoch 5: val_f1_score did not improve from 0.01950
# 70/70 [==============================] - 129s 2s/step - loss: 1.3064 - accuracy: 0.5588 - f1_score: 0.5158 - val_loss: 2.4843 - val_accuracy: 0.1328 - val_f1_score: 0.0180
# Epoch 6/150
# 70/70 [==============================] - ETA: 0s - loss: 1.1556 - accuracy: 0.6121 - f1_score: 0.5817
# Epoch 6: val_f1_score did not improve from 0.01950
# 70/70 [==============================] - 131s 2s/step - loss: 1.1556 - accuracy: 0.6121 - f1_score: 0.5817 - val_loss: 2.4762 - val_accuracy: 0.1328 - val_f1_score: 0.0180
# Epoch 7/150
# 70/70 [==============================] - ETA: 0s - loss: 1.0447 - accuracy: 0.6503 - f1_score: 0.6236
# Epoch 7: val_f1_score improved from 0.01950 to 0.02052, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 132s 2s/step - loss: 1.0447 - accuracy: 0.6503 - f1_score: 0.6236 - val_loss: 2.5101 - val_accuracy: 0.1486 - val_f1_score: 0.0205
# Epoch 8/150
# 70/70 [==============================] - ETA: 0s - loss: 0.9456 - accuracy: 0.6839 - f1_score: 0.6656
# Epoch 8: val_f1_score did not improve from 0.02052
# 70/70 [==============================] - 131s 2s/step - loss: 0.9456 - accuracy: 0.6839 - f1_score: 0.6656 - val_loss: 2.6848 - val_accuracy: 0.1482 - val_f1_score: 0.0199
# Epoch 9/150
# 70/70 [==============================] - ETA: 0s - loss: 0.8631 - accuracy: 0.7066 - f1_score: 0.6868
# Epoch 9: val_f1_score improved from 0.02052 to 0.03599, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 132s 2s/step - loss: 0.8631 - accuracy: 0.7066 - f1_score: 0.6868 - val_loss: 2.7555 - val_accuracy: 0.1633 - val_f1_score: 0.0360
# Epoch 10/150
# 70/70 [==============================] - ETA: 0s - loss: 0.8113 - accuracy: 0.7233 - f1_score: 0.7029
# Epoch 10: val_f1_score improved from 0.03599 to 0.16822, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 131s 2s/step - loss: 0.8113 - accuracy: 0.7233 - f1_score: 0.7029 - val_loss: 2.1911 - val_accuracy: 0.2883 - val_f1_score: 0.1682
# Epoch 11/150
# 70/70 [==============================] - ETA: 0s - loss: 0.7110 - accuracy: 0.7597 - f1_score: 0.7446
# Epoch 11: val_f1_score improved from 0.16822 to 0.61252, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 132s 2s/step - loss: 0.7110 - accuracy: 0.7597 - f1_score: 0.7446 - val_loss: 1.0533 - val_accuracy: 0.6515 - val_f1_score: 0.6125
# Epoch 12/150
# 70/70 [==============================] - ETA: 0s - loss: 0.6611 - accuracy: 0.7776 - f1_score: 0.7612
# Epoch 12: val_f1_score improved from 0.61252 to 0.67237, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 131s 2s/step - loss: 0.6611 - accuracy: 0.7776 - f1_score: 0.7612 - val_loss: 0.8820 - val_accuracy: 0.6943 - val_f1_score: 0.6724
# Epoch 13/150
# 70/70 [==============================] - ETA: 0s - loss: 0.6286 - accuracy: 0.7869 - f1_score: 0.7727
# Epoch 13: val_f1_score improved from 0.67237 to 0.72153, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 131s 2s/step - loss: 0.6286 - accuracy: 0.7869 - f1_score: 0.7727 - val_loss: 0.8048 - val_accuracy: 0.7441 - val_f1_score: 0.7215
# Epoch 14/150
# 70/70 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.8112 - f1_score: 0.8025
# Epoch 14: val_f1_score did not improve from 0.72153
# 70/70 [==============================] - 130s 2s/step - loss: 0.5633 - accuracy: 0.8112 - f1_score: 0.8025 - val_loss: 0.8319 - val_accuracy: 0.7321 - val_f1_score: 0.7014
# Epoch 15/150
# 70/70 [==============================] - ETA: 0s - loss: 0.5483 - accuracy: 0.8162 - f1_score: 0.8074
# Epoch 15: val_f1_score did not improve from 0.72153
# 70/70 [==============================] - 131s 2s/step - loss: 0.5483 - accuracy: 0.8162 - f1_score: 0.8074 - val_loss: 0.8292 - val_accuracy: 0.7337 - val_f1_score: 0.7184
# Epoch 16/150
# 70/70 [==============================] - ETA: 0s - loss: 0.5116 - accuracy: 0.8272 - f1_score: 0.8202
# Epoch 16: val_f1_score improved from 0.72153 to 0.76651, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 131s 2s/step - loss: 0.5116 - accuracy: 0.8272 - f1_score: 0.8202 - val_loss: 0.7030 - val_accuracy: 0.7769 - val_f1_score: 0.7665
# Epoch 17/150
# 70/70 [==============================] - ETA: 0s - loss: 0.4581 - accuracy: 0.8461 - f1_score: 0.8420
# Epoch 17: val_f1_score improved from 0.76651 to 0.78369, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 132s 2s/step - loss: 0.4581 - accuracy: 0.8461 - f1_score: 0.8420 - val_loss: 0.6270 - val_accuracy: 0.7981 - val_f1_score: 0.7837
# Epoch 18/150
# 70/70 [==============================] - ETA: 0s - loss: 0.4396 - accuracy: 0.8484 - f1_score: 0.8425
# Epoch 18: val_f1_score improved from 0.78369 to 0.81968, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 149s 2s/step - loss: 0.4396 - accuracy: 0.8484 - f1_score: 0.8425 - val_loss: 0.5359 - val_accuracy: 0.8321 - val_f1_score: 0.8197
# Epoch 19/150
# 70/70 [==============================] - ETA: 0s - loss: 0.4025 - accuracy: 0.8674 - f1_score: 0.8662
# Epoch 19: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 119s 2s/step - loss: 0.4025 - accuracy: 0.8674 - f1_score: 0.8662 - val_loss: 0.6851 - val_accuracy: 0.7754 - val_f1_score: 0.7586
# Epoch 20/150
# 70/70 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.8680 - f1_score: 0.8644
# Epoch 20: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 128s 2s/step - loss: 0.3916 - accuracy: 0.8680 - f1_score: 0.8644 - val_loss: 0.5946 - val_accuracy: 0.8066 - val_f1_score: 0.8006
# Epoch 21/150
# 70/70 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.8809 - f1_score: 0.8762
# Epoch 21: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 148s 2s/step - loss: 0.3566 - accuracy: 0.8809 - f1_score: 0.8762 - val_loss: 0.7758 - val_accuracy: 0.7673 - val_f1_score: 0.7556
# Epoch 22/150
# 70/70 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8895 - f1_score: 0.8864
# Epoch 22: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 145s 2s/step - loss: 0.3339 - accuracy: 0.8895 - f1_score: 0.8864 - val_loss: 0.6081 - val_accuracy: 0.8086 - val_f1_score: 0.7985
# Epoch 23/150
# 70/70 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8895 - f1_score: 0.8875
# Epoch 23: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 148s 2s/step - loss: 0.3358 - accuracy: 0.8895 - f1_score: 0.8875 - val_loss: 0.6699 - val_accuracy: 0.7962 - val_f1_score: 0.7805
# Epoch 24/150
# 70/70 [==============================] - ETA: 0s - loss: 0.3162 - accuracy: 0.8909 - f1_score: 0.8878
# Epoch 24: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 145s 2s/step - loss: 0.3162 - accuracy: 0.8909 - f1_score: 0.8878 - val_loss: 0.6028 - val_accuracy: 0.8036 - val_f1_score: 0.7909
# Epoch 25/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8993 - f1_score: 0.8990
# Epoch 25: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 149s 2s/step - loss: 0.2985 - accuracy: 0.8993 - f1_score: 0.8990 - val_loss: 0.6967 - val_accuracy: 0.7912 - val_f1_score: 0.7758
# Epoch 26/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.9043 - f1_score: 0.9005
# Epoch 26: val_f1_score did not improve from 0.81968
# 70/70 [==============================] - 147s 2s/step - loss: 0.2898 - accuracy: 0.9043 - f1_score: 0.9005 - val_loss: 0.5724 - val_accuracy: 0.8113 - val_f1_score: 0.7990
# Epoch 27/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9122 - f1_score: 0.9093
# Epoch 27: val_f1_score improved from 0.81968 to 0.85430, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 148s 2s/step - loss: 0.2580 - accuracy: 0.9122 - f1_score: 0.9093 - val_loss: 0.4244 - val_accuracy: 0.8607 - val_f1_score: 0.8543
# Epoch 28/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9165 - f1_score: 0.9156
# Epoch 28: val_f1_score did not improve from 0.85430
# 70/70 [==============================] - 147s 2s/step - loss: 0.2546 - accuracy: 0.9165 - f1_score: 0.9156 - val_loss: 0.4613 - val_accuracy: 0.8549 - val_f1_score: 0.8536
# Epoch 29/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9144 - f1_score: 0.9131
# Epoch 29: val_f1_score improved from 0.85430 to 0.86020, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 148s 2s/step - loss: 0.2492 - accuracy: 0.9144 - f1_score: 0.9131 - val_loss: 0.4319 - val_accuracy: 0.8672 - val_f1_score: 0.8602
# Epoch 30/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9157 - f1_score: 0.9152
# Epoch 30: val_f1_score did not improve from 0.86020
# 70/70 [==============================] - 146s 2s/step - loss: 0.2426 - accuracy: 0.9157 - f1_score: 0.9152 - val_loss: 0.5906 - val_accuracy: 0.8194 - val_f1_score: 0.8197
# Epoch 31/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9222 - f1_score: 0.9208
# Epoch 31: val_f1_score did not improve from 0.86020
# 70/70 [==============================] - 147s 2s/step - loss: 0.2354 - accuracy: 0.9222 - f1_score: 0.9208 - val_loss: 0.4635 - val_accuracy: 0.8626 - val_f1_score: 0.8574
# Epoch 32/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9288 - f1_score: 0.9259
# Epoch 32: val_f1_score did not improve from 0.86020
# 70/70 [==============================] - 146s 2s/step - loss: 0.2183 - accuracy: 0.9288 - f1_score: 0.9259 - val_loss: 0.4214 - val_accuracy: 0.8618 - val_f1_score: 0.8530
# Epoch 33/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 0.9338 - f1_score: 0.9322
# Epoch 33: val_f1_score did not improve from 0.86020
# 70/70 [==============================] - 149s 2s/step - loss: 0.2002 - accuracy: 0.9338 - f1_score: 0.9322 - val_loss: 0.4580 - val_accuracy: 0.8653 - val_f1_score: 0.8586
# Epoch 34/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2101 - accuracy: 0.9271 - f1_score: 0.9264
# Epoch 34: val_f1_score did not improve from 0.86020
# 70/70 [==============================] - 149s 2s/step - loss: 0.2101 - accuracy: 0.9271 - f1_score: 0.9264 - val_loss: 0.6275 - val_accuracy: 0.8093 - val_f1_score: 0.7946
# Epoch 35/150
# 70/70 [==============================] - ETA: 0s - loss: 0.2078 - accuracy: 0.9307 - f1_score: 0.9281
# Epoch 35: val_f1_score improved from 0.86020 to 0.88788, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 152s 2s/step - loss: 0.2078 - accuracy: 0.9307 - f1_score: 0.9281 - val_loss: 0.3601 - val_accuracy: 0.8927 - val_f1_score: 0.8879
# Epoch 36/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9390 - f1_score: 0.9403
# Epoch 36: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 149s 2s/step - loss: 0.1853 - accuracy: 0.9390 - f1_score: 0.9403 - val_loss: 0.3676 - val_accuracy: 0.8915 - val_f1_score: 0.8820
# Epoch 37/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1803 - accuracy: 0.9400 - f1_score: 0.9396
# Epoch 37: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 151s 2s/step - loss: 0.1803 - accuracy: 0.9400 - f1_score: 0.9396 - val_loss: 0.4020 - val_accuracy: 0.8765 - val_f1_score: 0.8706
# Epoch 38/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9409 - f1_score: 0.9398
# Epoch 38: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 150s 2s/step - loss: 0.1717 - accuracy: 0.9409 - f1_score: 0.9398 - val_loss: 0.4012 - val_accuracy: 0.8838 - val_f1_score: 0.8827
# Epoch 39/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.9365 - f1_score: 0.9366
# Epoch 39: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 148s 2s/step - loss: 0.1840 - accuracy: 0.9365 - f1_score: 0.9366 - val_loss: 0.4265 - val_accuracy: 0.8692 - val_f1_score: 0.8636
# Epoch 40/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9382 - f1_score: 0.9373
# Epoch 40: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 144s 2s/step - loss: 0.1799 - accuracy: 0.9382 - f1_score: 0.9373 - val_loss: 0.4425 - val_accuracy: 0.8684 - val_f1_score: 0.8570
# Epoch 41/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9428 - f1_score: 0.9430
# Epoch 41: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 147s 2s/step - loss: 0.1774 - accuracy: 0.9428 - f1_score: 0.9430 - val_loss: 0.4211 - val_accuracy: 0.8742 - val_f1_score: 0.8610
# Epoch 42/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9481 - f1_score: 0.9481
# Epoch 42: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 149s 2s/step - loss: 0.1464 - accuracy: 0.9481 - f1_score: 0.9481 - val_loss: 0.3818 - val_accuracy: 0.8881 - val_f1_score: 0.8842
# Epoch 43/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9470 - f1_score: 0.9431
# Epoch 43: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 142s 2s/step - loss: 0.1568 - accuracy: 0.9470 - f1_score: 0.9431 - val_loss: 0.3779 - val_accuracy: 0.8827 - val_f1_score: 0.8752
# Epoch 44/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9432 - f1_score: 0.9421
# Epoch 44: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 113s 2s/step - loss: 0.1695 - accuracy: 0.9432 - f1_score: 0.9421 - val_loss: 0.4196 - val_accuracy: 0.8730 - val_f1_score: 0.8695
# Epoch 45/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9523 - f1_score: 0.9521
# Epoch 45: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 145s 2s/step - loss: 0.1422 - accuracy: 0.9523 - f1_score: 0.9521 - val_loss: 0.3547 - val_accuracy: 0.8985 - val_f1_score: 0.8809
# Epoch 46/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9463 - f1_score: 0.9464
# Epoch 46: val_f1_score did not improve from 0.88788
# 70/70 [==============================] - 144s 2s/step - loss: 0.1582 - accuracy: 0.9463 - f1_score: 0.9464 - val_loss: 0.3901 - val_accuracy: 0.8915 - val_f1_score: 0.8846
# Epoch 47/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9475 - f1_score: 0.9483
# Epoch 47: val_f1_score improved from 0.88788 to 0.89129, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 146s 2s/step - loss: 0.1516 - accuracy: 0.9475 - f1_score: 0.9483 - val_loss: 0.3617 - val_accuracy: 0.8973 - val_f1_score: 0.8913
# Epoch 48/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9544 - f1_score: 0.9547
# Epoch 48: val_f1_score improved from 0.89129 to 0.90937, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 147s 2s/step - loss: 0.1324 - accuracy: 0.9544 - f1_score: 0.9547 - val_loss: 0.2993 - val_accuracy: 0.9132 - val_f1_score: 0.9094
# Epoch 49/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9589 - f1_score: 0.9584
# Epoch 49: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 145s 2s/step - loss: 0.1206 - accuracy: 0.9589 - f1_score: 0.9584 - val_loss: 0.3209 - val_accuracy: 0.8993 - val_f1_score: 0.8870
# Epoch 50/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9517 - f1_score: 0.9505
# Epoch 50: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 146s 2s/step - loss: 0.1490 - accuracy: 0.9517 - f1_score: 0.9505 - val_loss: 0.4347 - val_accuracy: 0.8676 - val_f1_score: 0.8452
# Epoch 51/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9518 - f1_score: 0.9496
# Epoch 51: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 145s 2s/step - loss: 0.1357 - accuracy: 0.9518 - f1_score: 0.9496 - val_loss: 0.5937 - val_accuracy: 0.8406 - val_f1_score: 0.8226
# Epoch 52/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9499 - f1_score: 0.9505
# Epoch 52: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 145s 2s/step - loss: 0.1479 - accuracy: 0.9499 - f1_score: 0.9505 - val_loss: 0.3538 - val_accuracy: 0.8896 - val_f1_score: 0.8922
# Epoch 53/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9567 - f1_score: 0.9553
# Epoch 53: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 144s 2s/step - loss: 0.1274 - accuracy: 0.9567 - f1_score: 0.9553 - val_loss: 0.3561 - val_accuracy: 0.8997 - val_f1_score: 0.8888
# Epoch 54/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9613 - f1_score: 0.9611
# Epoch 54: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 145s 2s/step - loss: 0.1158 - accuracy: 0.9613 - f1_score: 0.9611 - val_loss: 0.3213 - val_accuracy: 0.9047 - val_f1_score: 0.9024
# Epoch 55/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9620 - f1_score: 0.9624
# Epoch 55: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 144s 2s/step - loss: 0.1133 - accuracy: 0.9620 - f1_score: 0.9624 - val_loss: 0.3556 - val_accuracy: 0.8966 - val_f1_score: 0.8895
# Epoch 56/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9589 - f1_score: 0.9582
# Epoch 56: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 144s 2s/step - loss: 0.1217 - accuracy: 0.9589 - f1_score: 0.9582 - val_loss: 0.3919 - val_accuracy: 0.8869 - val_f1_score: 0.8867
# Epoch 57/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1196 - accuracy: 0.9598 - f1_score: 0.9586
# Epoch 57: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 143s 2s/step - loss: 0.1196 - accuracy: 0.9598 - f1_score: 0.9586 - val_loss: 0.3585 - val_accuracy: 0.8985 - val_f1_score: 0.8988
# Epoch 58/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9583 - f1_score: 0.9580
# Epoch 58: val_f1_score did not improve from 0.90937
# 70/70 [==============================] - 145s 2s/step - loss: 0.1212 - accuracy: 0.9583 - f1_score: 0.9580 - val_loss: 0.3674 - val_accuracy: 0.8896 - val_f1_score: 0.8800
# Epoch 59/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9616 - f1_score: 0.9613
# Epoch 59: val_f1_score improved from 0.90937 to 0.91534, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 147s 2s/step - loss: 0.1102 - accuracy: 0.9616 - f1_score: 0.9613 - val_loss: 0.3123 - val_accuracy: 0.9159 - val_f1_score: 0.9153
# Epoch 60/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9615 - f1_score: 0.9617
# Epoch 60: val_f1_score improved from 0.91534 to 0.91977, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 147s 2s/step - loss: 0.1107 - accuracy: 0.9615 - f1_score: 0.9617 - val_loss: 0.2958 - val_accuracy: 0.9193 - val_f1_score: 0.9198
# Epoch 61/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9560 - f1_score: 0.9552
# Epoch 61: val_f1_score did not improve from 0.91977
# 70/70 [==============================] - 145s 2s/step - loss: 0.1270 - accuracy: 0.9560 - f1_score: 0.9552 - val_loss: 0.3313 - val_accuracy: 0.9000 - val_f1_score: 0.8955
# Epoch 62/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9639 - f1_score: 0.9634
# Epoch 62: val_f1_score did not improve from 0.91977
# 70/70 [==============================] - 146s 2s/step - loss: 0.1059 - accuracy: 0.9639 - f1_score: 0.9634 - val_loss: 0.3104 - val_accuracy: 0.9147 - val_f1_score: 0.9133
# Epoch 63/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9619 - f1_score: 0.9603
# Epoch 63: val_f1_score did not improve from 0.91977
# 70/70 [==============================] - 145s 2s/step - loss: 0.1095 - accuracy: 0.9619 - f1_score: 0.9603 - val_loss: 0.5659 - val_accuracy: 0.8418 - val_f1_score: 0.8310
# Epoch 64/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9521 - f1_score: 0.9523
# Epoch 64: val_f1_score improved from 0.91977 to 0.92866, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 146s 2s/step - loss: 0.1419 - accuracy: 0.9521 - f1_score: 0.9523 - val_loss: 0.2653 - val_accuracy: 0.9294 - val_f1_score: 0.9287
# Epoch 65/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9627 - f1_score: 0.9616
# Epoch 65: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.1131 - accuracy: 0.9627 - f1_score: 0.9616 - val_loss: 0.2888 - val_accuracy: 0.9139 - val_f1_score: 0.9079
# Epoch 66/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9685 - f1_score: 0.9679
# Epoch 66: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0878 - accuracy: 0.9685 - f1_score: 0.9679 - val_loss: 0.2873 - val_accuracy: 0.9190 - val_f1_score: 0.9156
# Epoch 67/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9704 - f1_score: 0.9710
# Epoch 67: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0898 - accuracy: 0.9704 - f1_score: 0.9710 - val_loss: 0.2566 - val_accuracy: 0.9263 - val_f1_score: 0.9200
# Epoch 68/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9653 - f1_score: 0.9645
# Epoch 68: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 146s 2s/step - loss: 0.0947 - accuracy: 0.9653 - f1_score: 0.9645 - val_loss: 0.3489 - val_accuracy: 0.9024 - val_f1_score: 0.8999
# Epoch 69/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9699 - f1_score: 0.9696
# Epoch 69: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 144s 2s/step - loss: 0.0931 - accuracy: 0.9699 - f1_score: 0.9696 - val_loss: 0.3135 - val_accuracy: 0.9143 - val_f1_score: 0.9074
# Epoch 70/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9659 - f1_score: 0.9660
# Epoch 70: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0984 - accuracy: 0.9659 - f1_score: 0.9660 - val_loss: 0.3621 - val_accuracy: 0.8954 - val_f1_score: 0.8830
# Epoch 71/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9674 - f1_score: 0.9684
# Epoch 71: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 144s 2s/step - loss: 0.0918 - accuracy: 0.9674 - f1_score: 0.9684 - val_loss: 0.3234 - val_accuracy: 0.9085 - val_f1_score: 0.9069
# Epoch 72/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9673 - f1_score: 0.9675
# Epoch 72: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0908 - accuracy: 0.9673 - f1_score: 0.9675 - val_loss: 0.2662 - val_accuracy: 0.9228 - val_f1_score: 0.9153
# Epoch 73/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9721 - f1_score: 0.9710
# Epoch 73: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 144s 2s/step - loss: 0.0845 - accuracy: 0.9721 - f1_score: 0.9710 - val_loss: 0.4141 - val_accuracy: 0.8796 - val_f1_score: 0.8605
# Epoch 74/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9716 - f1_score: 0.9702
# Epoch 74: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 146s 2s/step - loss: 0.0832 - accuracy: 0.9716 - f1_score: 0.9702 - val_loss: 0.5469 - val_accuracy: 0.8514 - val_f1_score: 0.8373
# Epoch 75/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9698 - f1_score: 0.9692
# Epoch 75: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0917 - accuracy: 0.9698 - f1_score: 0.9692 - val_loss: 0.2889 - val_accuracy: 0.9220 - val_f1_score: 0.9177
# Epoch 76/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9708 - f1_score: 0.9700
# Epoch 76: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 147s 2s/step - loss: 0.0891 - accuracy: 0.9708 - f1_score: 0.9700 - val_loss: 0.3762 - val_accuracy: 0.8973 - val_f1_score: 0.8839
# Epoch 77/150
# 70/70 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9635 - f1_score: 0.9634
# Epoch 77: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 146s 2s/step - loss: 0.1036 - accuracy: 0.9635 - f1_score: 0.9634 - val_loss: 0.3676 - val_accuracy: 0.9078 - val_f1_score: 0.8876
# Epoch 78/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9689 - f1_score: 0.9682
# Epoch 78: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 146s 2s/step - loss: 0.0920 - accuracy: 0.9689 - f1_score: 0.9682 - val_loss: 0.2757 - val_accuracy: 0.9128 - val_f1_score: 0.9058
# Epoch 79/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9683 - f1_score: 0.9690
# Epoch 79: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0906 - accuracy: 0.9683 - f1_score: 0.9690 - val_loss: 0.3187 - val_accuracy: 0.9066 - val_f1_score: 0.8974
# Epoch 80/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9713 - f1_score: 0.9687
# Epoch 80: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0856 - accuracy: 0.9713 - f1_score: 0.9687 - val_loss: 0.3049 - val_accuracy: 0.9078 - val_f1_score: 0.9012
# Epoch 81/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9694 - f1_score: 0.9680
# Epoch 81: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 147s 2s/step - loss: 0.0852 - accuracy: 0.9694 - f1_score: 0.9680 - val_loss: 0.2720 - val_accuracy: 0.9267 - val_f1_score: 0.9188
# Epoch 82/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9726 - f1_score: 0.9731
# Epoch 82: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 147s 2s/step - loss: 0.0825 - accuracy: 0.9726 - f1_score: 0.9731 - val_loss: 0.2642 - val_accuracy: 0.9274 - val_f1_score: 0.9214
# Epoch 83/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9703 - f1_score: 0.9708
# Epoch 83: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 142s 2s/step - loss: 0.0857 - accuracy: 0.9703 - f1_score: 0.9708 - val_loss: 0.3125 - val_accuracy: 0.9155 - val_f1_score: 0.9139
# Epoch 84/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9736 - f1_score: 0.9728
# Epoch 84: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 145s 2s/step - loss: 0.0737 - accuracy: 0.9736 - f1_score: 0.9728 - val_loss: 0.3343 - val_accuracy: 0.9035 - val_f1_score: 0.9064
# Epoch 85/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9714 - f1_score: 0.9706
# Epoch 85: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 147s 2s/step - loss: 0.0823 - accuracy: 0.9714 - f1_score: 0.9706 - val_loss: 0.4436 - val_accuracy: 0.8850 - val_f1_score: 0.8793
# Epoch 86/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9708 - f1_score: 0.9706
# Epoch 86: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 146s 2s/step - loss: 0.0869 - accuracy: 0.9708 - f1_score: 0.9706 - val_loss: 0.3163 - val_accuracy: 0.9132 - val_f1_score: 0.9026
# Epoch 87/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9691 - f1_score: 0.9687
# Epoch 87: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 148s 2s/step - loss: 0.0916 - accuracy: 0.9691 - f1_score: 0.9687 - val_loss: 0.2720 - val_accuracy: 0.9209 - val_f1_score: 0.9161
# Epoch 88/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9742 - f1_score: 0.9730
# Epoch 88: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 150s 2s/step - loss: 0.0768 - accuracy: 0.9742 - f1_score: 0.9730 - val_loss: 0.3095 - val_accuracy: 0.9081 - val_f1_score: 0.8992
# Epoch 89/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9685 - f1_score: 0.9682
# Epoch 89: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 150s 2s/step - loss: 0.0912 - accuracy: 0.9685 - f1_score: 0.9682 - val_loss: 0.3638 - val_accuracy: 0.9016 - val_f1_score: 0.8952
# Epoch 90/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9738 - f1_score: 0.9743
# Epoch 90: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 149s 2s/step - loss: 0.0776 - accuracy: 0.9738 - f1_score: 0.9743 - val_loss: 0.2684 - val_accuracy: 0.9205 - val_f1_score: 0.9131
# Epoch 91/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9743 - f1_score: 0.9728
# Epoch 91: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 149s 2s/step - loss: 0.0783 - accuracy: 0.9743 - f1_score: 0.9728 - val_loss: 0.2958 - val_accuracy: 0.9078 - val_f1_score: 0.9052
# Epoch 92/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9751 - f1_score: 0.9747
# Epoch 92: val_f1_score did not improve from 0.92866
# 70/70 [==============================] - 152s 2s/step - loss: 0.0744 - accuracy: 0.9751 - f1_score: 0.9747 - val_loss: 0.3526 - val_accuracy: 0.9093 - val_f1_score: 0.9074
# Epoch 93/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9750 - f1_score: 0.9745
# Epoch 93: val_f1_score improved from 0.92866 to 0.93953, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 152s 2s/step - loss: 0.0769 - accuracy: 0.9750 - f1_score: 0.9745 - val_loss: 0.2256 - val_accuracy: 0.9394 - val_f1_score: 0.9395
# Epoch 94/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9761 - f1_score: 0.9756
# Epoch 94: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 149s 2s/step - loss: 0.0658 - accuracy: 0.9761 - f1_score: 0.9756 - val_loss: 0.2820 - val_accuracy: 0.9263 - val_f1_score: 0.9206
# Epoch 95/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9766 - f1_score: 0.9765
# Epoch 95: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 150s 2s/step - loss: 0.0676 - accuracy: 0.9766 - f1_score: 0.9765 - val_loss: 0.2484 - val_accuracy: 0.9344 - val_f1_score: 0.9317
# Epoch 96/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9738 - f1_score: 0.9722
# Epoch 96: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 151s 2s/step - loss: 0.0773 - accuracy: 0.9738 - f1_score: 0.9722 - val_loss: 0.8724 - val_accuracy: 0.8028 - val_f1_score: 0.7791
# Epoch 97/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9711 - f1_score: 0.9698
# Epoch 97: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 149s 2s/step - loss: 0.0836 - accuracy: 0.9711 - f1_score: 0.9698 - val_loss: 0.3901 - val_accuracy: 0.9020 - val_f1_score: 0.9041
# Epoch 98/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9722 - f1_score: 0.9707
# Epoch 98: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 151s 2s/step - loss: 0.0773 - accuracy: 0.9722 - f1_score: 0.9707 - val_loss: 0.3246 - val_accuracy: 0.9101 - val_f1_score: 0.9050
# Epoch 99/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9711 - f1_score: 0.9706
# Epoch 99: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 154s 2s/step - loss: 0.0787 - accuracy: 0.9711 - f1_score: 0.9706 - val_loss: 0.2886 - val_accuracy: 0.9193 - val_f1_score: 0.9117
# Epoch 100/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9712 - f1_score: 0.9698
# Epoch 100: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 153s 2s/step - loss: 0.0793 - accuracy: 0.9712 - f1_score: 0.9698 - val_loss: 0.2876 - val_accuracy: 0.9220 - val_f1_score: 0.9138
# Epoch 101/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9769 - f1_score: 0.9767
# Epoch 101: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 149s 2s/step - loss: 0.0648 - accuracy: 0.9769 - f1_score: 0.9767 - val_loss: 0.2510 - val_accuracy: 0.9298 - val_f1_score: 0.9249
# Epoch 102/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9760 - f1_score: 0.9756
# Epoch 102: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 151s 2s/step - loss: 0.0726 - accuracy: 0.9760 - f1_score: 0.9756 - val_loss: 0.2896 - val_accuracy: 0.9147 - val_f1_score: 0.9130
# Epoch 103/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9703 - f1_score: 0.9696
# Epoch 103: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 150s 2s/step - loss: 0.0871 - accuracy: 0.9703 - f1_score: 0.9696 - val_loss: 0.3057 - val_accuracy: 0.9174 - val_f1_score: 0.9167
# Epoch 104/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9761 - f1_score: 0.9752
# Epoch 104: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 151s 2s/step - loss: 0.0699 - accuracy: 0.9761 - f1_score: 0.9752 - val_loss: 0.2675 - val_accuracy: 0.9294 - val_f1_score: 0.9281
# Epoch 105/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9764 - f1_score: 0.9766
# Epoch 105: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 151s 2s/step - loss: 0.0665 - accuracy: 0.9764 - f1_score: 0.9766 - val_loss: 0.3168 - val_accuracy: 0.9151 - val_f1_score: 0.9127
# Epoch 106/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9767 - f1_score: 0.9768
# Epoch 106: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 153s 2s/step - loss: 0.0637 - accuracy: 0.9767 - f1_score: 0.9768 - val_loss: 0.2545 - val_accuracy: 0.9317 - val_f1_score: 0.9309
# Epoch 107/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9767 - f1_score: 0.9745
# Epoch 107: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 152s 2s/step - loss: 0.0706 - accuracy: 0.9767 - f1_score: 0.9745 - val_loss: 0.3593 - val_accuracy: 0.9031 - val_f1_score: 0.8962
# Epoch 108/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9794 - f1_score: 0.9790
# Epoch 108: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 148s 2s/step - loss: 0.0624 - accuracy: 0.9794 - f1_score: 0.9790 - val_loss: 0.2569 - val_accuracy: 0.9282 - val_f1_score: 0.9263
# Epoch 109/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9767 - f1_score: 0.9759
# Epoch 109: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 148s 2s/step - loss: 0.0659 - accuracy: 0.9767 - f1_score: 0.9759 - val_loss: 0.2472 - val_accuracy: 0.9340 - val_f1_score: 0.9282
# Epoch 110/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9773 - f1_score: 0.9775
# Epoch 110: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 150s 2s/step - loss: 0.0725 - accuracy: 0.9773 - f1_score: 0.9775 - val_loss: 0.2664 - val_accuracy: 0.9236 - val_f1_score: 0.9280
# Epoch 111/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9756 - f1_score: 0.9755
# Epoch 111: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 151s 2s/step - loss: 0.0685 - accuracy: 0.9756 - f1_score: 0.9755 - val_loss: 0.2341 - val_accuracy: 0.9317 - val_f1_score: 0.9296
# Epoch 112/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9756 - f1_score: 0.9739
# Epoch 112: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 121s 2s/step - loss: 0.0714 - accuracy: 0.9756 - f1_score: 0.9739 - val_loss: 0.2957 - val_accuracy: 0.9259 - val_f1_score: 0.9217
# Epoch 113/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9774 - f1_score: 0.9775
# Epoch 113: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 106s 2s/step - loss: 0.0661 - accuracy: 0.9774 - f1_score: 0.9775 - val_loss: 0.4268 - val_accuracy: 0.8865 - val_f1_score: 0.8877
# Epoch 114/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9758 - f1_score: 0.9730
# Epoch 114: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 108s 2s/step - loss: 0.0690 - accuracy: 0.9758 - f1_score: 0.9730 - val_loss: 0.2673 - val_accuracy: 0.9278 - val_f1_score: 0.9225
# Epoch 115/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9769 - f1_score: 0.9764
# Epoch 115: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 108s 2s/step - loss: 0.0631 - accuracy: 0.9769 - f1_score: 0.9764 - val_loss: 0.2767 - val_accuracy: 0.9267 - val_f1_score: 0.9170
# Epoch 116/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9814 - f1_score: 0.9799
# Epoch 116: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 116s 2s/step - loss: 0.0563 - accuracy: 0.9814 - f1_score: 0.9799 - val_loss: 0.2641 - val_accuracy: 0.9290 - val_f1_score: 0.9258
# Epoch 117/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9793 - f1_score: 0.9779
# Epoch 117: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 106s 2s/step - loss: 0.0609 - accuracy: 0.9793 - f1_score: 0.9779 - val_loss: 0.2657 - val_accuracy: 0.9278 - val_f1_score: 0.9226
# Epoch 118/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9781 - f1_score: 0.9773
# Epoch 118: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 107s 2s/step - loss: 0.0642 - accuracy: 0.9781 - f1_score: 0.9773 - val_loss: 0.2823 - val_accuracy: 0.9247 - val_f1_score: 0.9224
# Epoch 119/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9774 - f1_score: 0.9761
# Epoch 119: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 106s 1s/step - loss: 0.0653 - accuracy: 0.9774 - f1_score: 0.9761 - val_loss: 0.2292 - val_accuracy: 0.9325 - val_f1_score: 0.9284
# Epoch 120/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9764 - f1_score: 0.9774
# Epoch 120: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 107s 2s/step - loss: 0.0717 - accuracy: 0.9764 - f1_score: 0.9774 - val_loss: 0.2596 - val_accuracy: 0.9255 - val_f1_score: 0.9220
# Epoch 121/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9746 - f1_score: 0.9752
# Epoch 121: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 108s 2s/step - loss: 0.0783 - accuracy: 0.9746 - f1_score: 0.9752 - val_loss: 0.3683 - val_accuracy: 0.9020 - val_f1_score: 0.8963
# Epoch 122/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9743 - f1_score: 0.9743
# Epoch 122: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 107s 2s/step - loss: 0.0737 - accuracy: 0.9743 - f1_score: 0.9743 - val_loss: 0.2672 - val_accuracy: 0.9267 - val_f1_score: 0.9215
# Epoch 123/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9787 - f1_score: 0.9775
# Epoch 123: val_f1_score did not improve from 0.93953
# 70/70 [==============================] - 107s 2s/step - loss: 0.0610 - accuracy: 0.9787 - f1_score: 0.9775 - val_loss: 0.3428 - val_accuracy: 0.9112 - val_f1_score: 0.8998
# Epoch 124/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9814 - f1_score: 0.9807
# Epoch 124: val_f1_score improved from 0.93953 to 0.94605, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 108s 2s/step - loss: 0.0529 - accuracy: 0.9814 - f1_score: 0.9807 - val_loss: 0.1944 - val_accuracy: 0.9475 - val_f1_score: 0.9460
# Epoch 125/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9805 - f1_score: 0.9787
# Epoch 125: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 108s 2s/step - loss: 0.0577 - accuracy: 0.9805 - f1_score: 0.9787 - val_loss: 0.2567 - val_accuracy: 0.9340 - val_f1_score: 0.9253
# Epoch 126/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9834 - f1_score: 0.9830
# Epoch 126: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 132s 2s/step - loss: 0.0493 - accuracy: 0.9834 - f1_score: 0.9830 - val_loss: 0.2639 - val_accuracy: 0.9321 - val_f1_score: 0.9291
# Epoch 127/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9777 - f1_score: 0.9762
# Epoch 127: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 147s 2s/step - loss: 0.0607 - accuracy: 0.9777 - f1_score: 0.9762 - val_loss: 0.2405 - val_accuracy: 0.9274 - val_f1_score: 0.9219
# Epoch 128/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9777 - f1_score: 0.9779
# Epoch 128: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 147s 2s/step - loss: 0.0648 - accuracy: 0.9777 - f1_score: 0.9779 - val_loss: 0.2583 - val_accuracy: 0.9247 - val_f1_score: 0.9234
# Epoch 129/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9798 - f1_score: 0.9783
# Epoch 129: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 147s 2s/step - loss: 0.0560 - accuracy: 0.9798 - f1_score: 0.9783 - val_loss: 0.2595 - val_accuracy: 0.9294 - val_f1_score: 0.9296
# Epoch 130/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9815 - f1_score: 0.9813
# Epoch 130: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 147s 2s/step - loss: 0.0535 - accuracy: 0.9815 - f1_score: 0.9813 - val_loss: 0.2334 - val_accuracy: 0.9437 - val_f1_score: 0.9420
# Epoch 131/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9845 - f1_score: 0.9838
# Epoch 131: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 147s 2s/step - loss: 0.0441 - accuracy: 0.9845 - f1_score: 0.9838 - val_loss: 0.2295 - val_accuracy: 0.9328 - val_f1_score: 0.9353
# Epoch 132/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9773 - f1_score: 0.9763
# Epoch 132: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 177s 3s/step - loss: 0.0694 - accuracy: 0.9773 - f1_score: 0.9763 - val_loss: 0.5161 - val_accuracy: 0.8827 - val_f1_score: 0.8745
# Epoch 133/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9775 - f1_score: 0.9786
# Epoch 133: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 184s 3s/step - loss: 0.0667 - accuracy: 0.9775 - f1_score: 0.9786 - val_loss: 0.3226 - val_accuracy: 0.9143 - val_f1_score: 0.9127
# Epoch 134/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9792 - f1_score: 0.9790
# Epoch 134: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 181s 3s/step - loss: 0.0609 - accuracy: 0.9792 - f1_score: 0.9790 - val_loss: 0.3556 - val_accuracy: 0.9112 - val_f1_score: 0.8962
# Epoch 135/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9810 - f1_score: 0.9807
# Epoch 135: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 182s 3s/step - loss: 0.0570 - accuracy: 0.9810 - f1_score: 0.9807 - val_loss: 0.2176 - val_accuracy: 0.9437 - val_f1_score: 0.9421
# Epoch 136/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9814 - f1_score: 0.9805
# Epoch 136: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 184s 3s/step - loss: 0.0564 - accuracy: 0.9814 - f1_score: 0.9805 - val_loss: 0.2474 - val_accuracy: 0.9429 - val_f1_score: 0.9453
# Epoch 137/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9835 - f1_score: 0.9833
# Epoch 137: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 179s 3s/step - loss: 0.0458 - accuracy: 0.9835 - f1_score: 0.9833 - val_loss: 0.2424 - val_accuracy: 0.9375 - val_f1_score: 0.9363
# Epoch 138/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9766 - f1_score: 0.9754
# Epoch 138: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 182s 3s/step - loss: 0.0777 - accuracy: 0.9766 - f1_score: 0.9754 - val_loss: 0.2794 - val_accuracy: 0.9271 - val_f1_score: 0.9220
# Epoch 139/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9809 - f1_score: 0.9806
# Epoch 139: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 181s 3s/step - loss: 0.0537 - accuracy: 0.9809 - f1_score: 0.9806 - val_loss: 0.2517 - val_accuracy: 0.9332 - val_f1_score: 0.9298
# Epoch 140/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9818 - f1_score: 0.9820
# Epoch 140: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 181s 3s/step - loss: 0.0540 - accuracy: 0.9818 - f1_score: 0.9820 - val_loss: 0.2573 - val_accuracy: 0.9309 - val_f1_score: 0.9274
# Epoch 141/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9820 - f1_score: 0.9811
# Epoch 141: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 182s 3s/step - loss: 0.0523 - accuracy: 0.9820 - f1_score: 0.9811 - val_loss: 0.2718 - val_accuracy: 0.9263 - val_f1_score: 0.9211
# Epoch 142/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9826 - f1_score: 0.9822
# Epoch 142: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 180s 3s/step - loss: 0.0521 - accuracy: 0.9826 - f1_score: 0.9822 - val_loss: 0.3922 - val_accuracy: 0.9089 - val_f1_score: 0.9093
# Epoch 143/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9817 - f1_score: 0.9810
# Epoch 143: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 182s 3s/step - loss: 0.0539 - accuracy: 0.9817 - f1_score: 0.9810 - val_loss: 0.2285 - val_accuracy: 0.9359 - val_f1_score: 0.9359
# Epoch 144/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9771 - f1_score: 0.9771
# Epoch 144: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 182s 3s/step - loss: 0.0683 - accuracy: 0.9771 - f1_score: 0.9771 - val_loss: 0.2996 - val_accuracy: 0.9139 - val_f1_score: 0.9142
# Epoch 145/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9788 - f1_score: 0.9796
# Epoch 145: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 180s 3s/step - loss: 0.0628 - accuracy: 0.9788 - f1_score: 0.9796 - val_loss: 0.2692 - val_accuracy: 0.9352 - val_f1_score: 0.9332
# Epoch 146/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9812 - f1_score: 0.9816
# Epoch 146: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 181s 3s/step - loss: 0.0526 - accuracy: 0.9812 - f1_score: 0.9816 - val_loss: 0.2309 - val_accuracy: 0.9344 - val_f1_score: 0.9336
# Epoch 147/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9855 - f1_score: 0.9847
# Epoch 147: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 180s 3s/step - loss: 0.0424 - accuracy: 0.9855 - f1_score: 0.9847 - val_loss: 0.2034 - val_accuracy: 0.9440 - val_f1_score: 0.9433
# Epoch 148/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9854 - f1_score: 0.9850
# Epoch 148: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 179s 3s/step - loss: 0.0436 - accuracy: 0.9854 - f1_score: 0.9850 - val_loss: 0.2158 - val_accuracy: 0.9394 - val_f1_score: 0.9373
# Epoch 149/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9812 - f1_score: 0.9801
# Epoch 149: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 180s 3s/step - loss: 0.0567 - accuracy: 0.9812 - f1_score: 0.9801 - val_loss: 0.2405 - val_accuracy: 0.9309 - val_f1_score: 0.9190
# Epoch 150/150
# 70/70 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9800 - f1_score: 0.9785
# Epoch 150: val_f1_score did not improve from 0.94605
# 70/70 [==============================] - 178s 3s/step - loss: 0.0549 - accuracy: 0.9800 - f1_score: 0.9785 - val_loss: 0.2766 - val_accuracy: 0.9301 - val_f1_score: 0.9239

# %%
# training the model and saving the best model as a check point #151-200
best_model_name, train_history = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9822 - f1_score: 0.9808
# Epoch 1: val_f1_score improved from -inf to 0.90595, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 123s 2s/step - loss: 0.0540 - accuracy: 0.9822 - f1_score: 0.9808 - val_loss: 0.3718 - val_accuracy: 0.9105 - val_f1_score: 0.9060
# Epoch 2/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9808 - f1_score: 0.9804
# Epoch 2: val_f1_score improved from 0.90595 to 0.92286, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 124s 2s/step - loss: 0.0553 - accuracy: 0.9808 - f1_score: 0.9804 - val_loss: 0.2757 - val_accuracy: 0.9220 - val_f1_score: 0.9229
# Epoch 3/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9828 - f1_score: 0.9820
# Epoch 3: val_f1_score did not improve from 0.92286
# 70/70 [==============================] - 123s 2s/step - loss: 0.0502 - accuracy: 0.9828 - f1_score: 0.9820 - val_loss: 0.3841 - val_accuracy: 0.9027 - val_f1_score: 0.8978
# Epoch 4/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9801 - f1_score: 0.9795
# Epoch 4: val_f1_score improved from 0.92286 to 0.94981, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 124s 2s/step - loss: 0.0578 - accuracy: 0.9801 - f1_score: 0.9795 - val_loss: 0.2024 - val_accuracy: 0.9498 - val_f1_score: 0.9498
# Epoch 5/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9833 - f1_score: 0.9829
# Epoch 5: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 122s 2s/step - loss: 0.0454 - accuracy: 0.9833 - f1_score: 0.9829 - val_loss: 0.2288 - val_accuracy: 0.9386 - val_f1_score: 0.9375
# Epoch 6/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9864 - f1_score: 0.9866
# Epoch 6: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 123s 2s/step - loss: 0.0410 - accuracy: 0.9864 - f1_score: 0.9866 - val_loss: 0.2387 - val_accuracy: 0.9355 - val_f1_score: 0.9328
# Epoch 7/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9859 - f1_score: 0.9864
# Epoch 7: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 122s 2s/step - loss: 0.0405 - accuracy: 0.9859 - f1_score: 0.9864 - val_loss: 0.2352 - val_accuracy: 0.9425 - val_f1_score: 0.9415
# Epoch 8/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9838 - f1_score: 0.9838
# Epoch 8: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 121s 2s/step - loss: 0.0439 - accuracy: 0.9838 - f1_score: 0.9838 - val_loss: 0.3853 - val_accuracy: 0.8915 - val_f1_score: 0.8842
# Epoch 9/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9857 - f1_score: 0.9847
# Epoch 9: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 123s 2s/step - loss: 0.0414 - accuracy: 0.9857 - f1_score: 0.9847 - val_loss: 0.2263 - val_accuracy: 0.9444 - val_f1_score: 0.9420
# Epoch 10/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9874 - f1_score: 0.9873
# Epoch 10: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 123s 2s/step - loss: 0.0381 - accuracy: 0.9874 - f1_score: 0.9873 - val_loss: 0.2100 - val_accuracy: 0.9440 - val_f1_score: 0.9449
# Epoch 11/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9848 - f1_score: 0.9840
# Epoch 11: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 123s 2s/step - loss: 0.0419 - accuracy: 0.9848 - f1_score: 0.9840 - val_loss: 0.2599 - val_accuracy: 0.9348 - val_f1_score: 0.9318
# Epoch 12/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9860 - f1_score: 0.9854
# Epoch 12: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 124s 2s/step - loss: 0.0415 - accuracy: 0.9860 - f1_score: 0.9854 - val_loss: 0.2823 - val_accuracy: 0.9263 - val_f1_score: 0.9214
# Epoch 13/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9838 - f1_score: 0.9833
# Epoch 13: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 123s 2s/step - loss: 0.0484 - accuracy: 0.9838 - f1_score: 0.9833 - val_loss: 0.3091 - val_accuracy: 0.9313 - val_f1_score: 0.9267
# Epoch 14/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9833 - f1_score: 0.9829
# Epoch 14: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 121s 2s/step - loss: 0.0501 - accuracy: 0.9833 - f1_score: 0.9829 - val_loss: 0.3050 - val_accuracy: 0.9240 - val_f1_score: 0.9177
# Epoch 15/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9820 - f1_score: 0.9825
# Epoch 15: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 132s 2s/step - loss: 0.0520 - accuracy: 0.9820 - f1_score: 0.9825 - val_loss: 0.3368 - val_accuracy: 0.9108 - val_f1_score: 0.9084
# Epoch 16/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9826 - f1_score: 0.9815
# Epoch 16: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 138s 2s/step - loss: 0.0447 - accuracy: 0.9826 - f1_score: 0.9815 - val_loss: 0.2796 - val_accuracy: 0.9282 - val_f1_score: 0.9209
# Epoch 17/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9794 - f1_score: 0.9772
# Epoch 17: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 138s 2s/step - loss: 0.0563 - accuracy: 0.9794 - f1_score: 0.9772 - val_loss: 0.3817 - val_accuracy: 0.9027 - val_f1_score: 0.8926
# Epoch 18/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9778 - f1_score: 0.9769
# Epoch 18: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 123s 2s/step - loss: 0.0660 - accuracy: 0.9778 - f1_score: 0.9769 - val_loss: 0.3310 - val_accuracy: 0.9155 - val_f1_score: 0.9012
# Epoch 19/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9824 - f1_score: 0.9826
# Epoch 19: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 114s 2s/step - loss: 0.0513 - accuracy: 0.9824 - f1_score: 0.9826 - val_loss: 0.4370 - val_accuracy: 0.8989 - val_f1_score: 0.8925
# Epoch 20/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9798 - f1_score: 0.9798
# Epoch 20: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 147s 2s/step - loss: 0.0654 - accuracy: 0.9798 - f1_score: 0.9798 - val_loss: 0.2719 - val_accuracy: 0.9332 - val_f1_score: 0.9311
# Epoch 21/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9839 - f1_score: 0.9830
# Epoch 21: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 147s 2s/step - loss: 0.0447 - accuracy: 0.9839 - f1_score: 0.9830 - val_loss: 0.2435 - val_accuracy: 0.9286 - val_f1_score: 0.9230
# Epoch 22/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9816 - f1_score: 0.9802
# Epoch 22: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 143s 2s/step - loss: 0.0521 - accuracy: 0.9816 - f1_score: 0.9802 - val_loss: 0.3461 - val_accuracy: 0.9132 - val_f1_score: 0.9087
# Epoch 23/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9804 - f1_score: 0.9785
# Epoch 23: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 145s 2s/step - loss: 0.0591 - accuracy: 0.9804 - f1_score: 0.9785 - val_loss: 0.2793 - val_accuracy: 0.9255 - val_f1_score: 0.9196
# Epoch 24/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9854 - f1_score: 0.9843
# Epoch 24: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 145s 2s/step - loss: 0.0435 - accuracy: 0.9854 - f1_score: 0.9843 - val_loss: 0.3212 - val_accuracy: 0.9139 - val_f1_score: 0.9102
# Epoch 25/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9820 - f1_score: 0.9815
# Epoch 25: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 147s 2s/step - loss: 0.0468 - accuracy: 0.9820 - f1_score: 0.9815 - val_loss: 0.2289 - val_accuracy: 0.9429 - val_f1_score: 0.9387
# Epoch 26/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9867 - f1_score: 0.9860
# Epoch 26: val_f1_score did not improve from 0.94981
# 70/70 [==============================] - 147s 2s/step - loss: 0.0366 - accuracy: 0.9867 - f1_score: 0.9860 - val_loss: 0.2106 - val_accuracy: 0.9448 - val_f1_score: 0.9469
# Epoch 27/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9859 - f1_score: 0.9852
# Epoch 27: val_f1_score improved from 0.94981 to 0.95298, saving model to saved_outputs_all_augment\Xception\saved_models\best_Xception_.h5
# 70/70 [==============================] - 148s 2s/step - loss: 0.0423 - accuracy: 0.9859 - f1_score: 0.9852 - val_loss: 0.2007 - val_accuracy: 0.9510 - val_f1_score: 0.9530
# Epoch 28/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9833 - f1_score: 0.9823
# Epoch 28: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 146s 2s/step - loss: 0.0492 - accuracy: 0.9833 - f1_score: 0.9823 - val_loss: 0.2125 - val_accuracy: 0.9456 - val_f1_score: 0.9463
# Epoch 29/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9871 - f1_score: 0.9869
# Epoch 29: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 129s 2s/step - loss: 0.0348 - accuracy: 0.9871 - f1_score: 0.9869 - val_loss: 0.2419 - val_accuracy: 0.9367 - val_f1_score: 0.9363
# Epoch 30/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9874 - f1_score: 0.9866
# Epoch 30: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 130s 2s/step - loss: 0.0356 - accuracy: 0.9874 - f1_score: 0.9866 - val_loss: 0.2016 - val_accuracy: 0.9467 - val_f1_score: 0.9413
# Epoch 31/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9874 - f1_score: 0.9872
# Epoch 31: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 138s 2s/step - loss: 0.0338 - accuracy: 0.9874 - f1_score: 0.9872 - val_loss: 0.3056 - val_accuracy: 0.9228 - val_f1_score: 0.9221
# Epoch 32/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9879 - f1_score: 0.9869
# Epoch 32: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0334 - accuracy: 0.9879 - f1_score: 0.9869 - val_loss: 0.2251 - val_accuracy: 0.9483 - val_f1_score: 0.9457
# Epoch 33/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9847 - f1_score: 0.9846
# Epoch 33: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0437 - accuracy: 0.9847 - f1_score: 0.9846 - val_loss: 0.4673 - val_accuracy: 0.9008 - val_f1_score: 0.8885
# Epoch 34/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9824 - f1_score: 0.9812
# Epoch 34: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 133s 2s/step - loss: 0.0504 - accuracy: 0.9824 - f1_score: 0.9812 - val_loss: 0.2718 - val_accuracy: 0.9367 - val_f1_score: 0.9340
# Epoch 35/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9806 - f1_score: 0.9808
# Epoch 35: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 133s 2s/step - loss: 0.0568 - accuracy: 0.9806 - f1_score: 0.9808 - val_loss: 0.2828 - val_accuracy: 0.9305 - val_f1_score: 0.9273
# Epoch 36/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9817 - f1_score: 0.9795
# Epoch 36: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0560 - accuracy: 0.9817 - f1_score: 0.9795 - val_loss: 0.4085 - val_accuracy: 0.9097 - val_f1_score: 0.8954
# Epoch 37/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9867 - f1_score: 0.9869
# Epoch 37: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0398 - accuracy: 0.9867 - f1_score: 0.9869 - val_loss: 0.2345 - val_accuracy: 0.9444 - val_f1_score: 0.9409
# Epoch 38/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9868 - f1_score: 0.9866
# Epoch 38: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0363 - accuracy: 0.9868 - f1_score: 0.9866 - val_loss: 0.2327 - val_accuracy: 0.9433 - val_f1_score: 0.9444
# Epoch 39/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9873 - f1_score: 0.9866
# Epoch 39: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0363 - accuracy: 0.9873 - f1_score: 0.9866 - val_loss: 0.1915 - val_accuracy: 0.9506 - val_f1_score: 0.9491
# Epoch 40/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9881 - f1_score: 0.9882
# Epoch 40: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0333 - accuracy: 0.9881 - f1_score: 0.9882 - val_loss: 0.2597 - val_accuracy: 0.9379 - val_f1_score: 0.9364
# Epoch 41/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9860 - f1_score: 0.9863
# Epoch 41: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0435 - accuracy: 0.9860 - f1_score: 0.9863 - val_loss: 0.3038 - val_accuracy: 0.9209 - val_f1_score: 0.9216
# Epoch 42/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9875 - f1_score: 0.9869
# Epoch 42: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0334 - accuracy: 0.9875 - f1_score: 0.9869 - val_loss: 0.2284 - val_accuracy: 0.9433 - val_f1_score: 0.9412
# Epoch 43/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9855 - f1_score: 0.9847
# Epoch 43: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0462 - accuracy: 0.9855 - f1_score: 0.9847 - val_loss: 0.4251 - val_accuracy: 0.9058 - val_f1_score: 0.9039
# Epoch 44/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9837 - f1_score: 0.9833
# Epoch 44: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0495 - accuracy: 0.9837 - f1_score: 0.9833 - val_loss: 0.2250 - val_accuracy: 0.9456 - val_f1_score: 0.9425
# Epoch 45/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9869 - f1_score: 0.9867
# Epoch 45: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0391 - accuracy: 0.9869 - f1_score: 0.9867 - val_loss: 0.2835 - val_accuracy: 0.9379 - val_f1_score: 0.9345
# Epoch 46/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9863 - f1_score: 0.9854
# Epoch 46: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0406 - accuracy: 0.9863 - f1_score: 0.9854 - val_loss: 0.2340 - val_accuracy: 0.9406 - val_f1_score: 0.9397
# Epoch 47/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9864 - f1_score: 0.9861
# Epoch 47: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0407 - accuracy: 0.9864 - f1_score: 0.9861 - val_loss: 0.2219 - val_accuracy: 0.9456 - val_f1_score: 0.9439
# Epoch 48/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9873 - f1_score: 0.9866
# Epoch 48: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0373 - accuracy: 0.9873 - f1_score: 0.9866 - val_loss: 0.2692 - val_accuracy: 0.9313 - val_f1_score: 0.9287
# Epoch 49/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9879 - f1_score: 0.9879
# Epoch 49: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 131s 2s/step - loss: 0.0330 - accuracy: 0.9879 - f1_score: 0.9879 - val_loss: 0.2228 - val_accuracy: 0.9529 - val_f1_score: 0.9523
# Epoch 50/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9891 - f1_score: 0.9880
# Epoch 50: val_f1_score did not improve from 0.95298
# 70/70 [==============================] - 132s 2s/step - loss: 0.0313 - accuracy: 0.9891 - f1_score: 0.9880 - val_loss: 0.2183 - val_accuracy: 0.9440 - val_f1_score: 0.9411

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
## Reading the saved train history
# Load the training history from a CSV file
df_history = pd.read_csv("saved_outputs_all_augment\Xception/training_history_epoch0to200.csv")

# %%
# Define the list of metrics to plot (excluding 'val_' prefixed ones)
list_of_metrics = [key for key in df_history.columns if not key.startswith('val_')]

# Number of plots is determined by the number of metrics
nr_plots = len(list_of_metrics)

# Create a figure and an array of axes for plotting
fig, ax = plt.subplots(1, nr_plots, figsize=(5 * nr_plots, 4))

# Iterate over the metrics to plot each one
for i, metric in enumerate(list_of_metrics):
    # Plot training and validation metrics
    ax[i].plot(np.array(df_history[metric]), label='Training ' + metric)
    ax[i].plot(np.array(df_history['val_' + metric]), label='Validation ' + metric)
    ax[i].set_xlabel('Epoch')
    ax[i].set_title(metric.capitalize())
    ax[i].grid(True)
    ax[i].legend()

fig.tight_layout()

if SAVE_RESULTS:
    # Save the plot to a PDF
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 22/22 [==============================] - 6s 195ms/step - loss: 0.3112 - accuracy: 0.9260 - f1_score: 0.9174
#   model_name  test_loss  test_accuracy  test_f1_score
# 0   Xception   0.311216        0.92604       0.917358

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 22/22 [==============================] - 5s 183ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test , 
                                      model_name=model_name, 
                                      SAVE_RESULTS=SAVE_RESULTS)
# Out:
#               precision    recall  f1-score     support
# 0              0.883333  0.815385  0.848000   130.00000
# 1              0.822034  0.970000  0.889908   100.00000
# 2              0.953488  0.911111  0.931818    90.00000
# 3              0.929293  0.910891  0.920000   101.00000
# 4              0.924242  0.908511  0.916309   470.00000
# 5              0.901099  0.972332  0.935361   253.00000
# 6              0.922156  0.885057  0.903226   174.00000
# 7              0.951923  0.918794  0.935065   431.00000
# 8              0.869159  0.849315  0.859122   219.00000
# 9              0.946939  0.964657  0.955716   481.00000
# 10             0.968668  0.951282  0.959897   390.00000
# 11             0.925197  0.925197  0.925197   254.00000
# 12             0.914110  0.980263  0.946032   152.00000
# accuracy       0.926040  0.926040  0.926040     0.92604
# macro avg      0.916280  0.920215  0.917358  3245.00000
# weighted avg   0.926769  0.926040  0.925887  3245.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test , 
                           model_name=model_name, 
                           SAVE_RESULTS=SAVE_RESULTS)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test, 
                                       model_name=model_name, 
                                       SAVE_RESULTS=SAVE_RESULTS, 
                                       test_loss=test_loss)
# Out:
#   Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0   Xception   0.92604          0.91628      0.920215        0.917358
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.926769          0.92604           0.925887  0.311216

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc, SHOW_RESULTS=True, SAVE_RESULTS=True)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.92604
# 1      Macro Precision  0.91628
# 2         Macro Recall  0.92021
# 3       Macro F1-Score  0.91736
# 4            Macro FPR  0.00626
# 5            Macro FNR  0.07979
# 6            Macro FDR  0.08372
# 7            Macro NPV  0.99371
# 8   Weighted Precision  0.92677
# 9      Weighted Recall  0.92604
# 10   Weighted F1-Score  0.92589
# 11        Weighted FPR  0.00742
# 12        Weighted FNR  0.07396
# 13        Weighted FDR  0.07323
# 14        Weighted NPV  0.99210
