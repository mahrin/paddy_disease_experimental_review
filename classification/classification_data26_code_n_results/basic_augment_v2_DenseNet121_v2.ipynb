# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'DenseNet121'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 150
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic' #'all'## basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 


# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\DenseNet121
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\DenseNet121\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\DenseNet121\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_19656\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    ## Criteria for early stopping
#    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %%
from tensorflow.keras.applications import  DenseNet121
def get_DenseNet121(): # almost proper--10 has high dense
 
    # model = Sequential()
    # base_model = DenseNet121(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)
    model = DenseNet121(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
model= get_DenseNet121()
# # model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/150
# 104/104 [==============================] - ETA: 0s - loss: 1.8719 - accuracy: 0.3765 - f1_score: 0.2840
# Epoch 1: val_f1_score improved from -inf to 0.01986, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 87s 719ms/step - loss: 1.8719 - accuracy: 0.3765 - f1_score: 0.2840 - val_loss: 2.6711 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 1.0000e-04
# Epoch 2/150
# 104/104 [==============================] - ETA: 0s - loss: 1.3087 - accuracy: 0.5813 - f1_score: 0.5279
# Epoch 2: val_f1_score improved from 0.01986 to 0.01986, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 74s 712ms/step - loss: 1.3087 - accuracy: 0.5813 - f1_score: 0.5279 - val_loss: 3.1323 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 1.0000e-04
# Epoch 3/150
# 104/104 [==============================] - ETA: 0s - loss: 1.0095 - accuracy: 0.6790 - f1_score: 0.6424
# Epoch 3: val_f1_score did not improve from 0.01986
# 104/104 [==============================] - 72s 693ms/step - loss: 1.0095 - accuracy: 0.6790 - f1_score: 0.6424 - val_loss: 7.3087 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 1.0000e-04
# Epoch 4/150
# 104/104 [==============================] - ETA: 0s - loss: 0.7845 - accuracy: 0.7561 - f1_score: 0.7340
# Epoch 4: val_f1_score improved from 0.01986 to 0.06024, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 77s 742ms/step - loss: 0.7845 - accuracy: 0.7561 - f1_score: 0.7340 - val_loss: 4.7359 - val_accuracy: 0.1660 - val_f1_score: 0.0602 - lr: 1.0000e-04
# Epoch 5/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6108 - accuracy: 0.8117 - f1_score: 0.7930
# Epoch 5: val_f1_score did not improve from 0.06024
# 104/104 [==============================] - 70s 674ms/step - loss: 0.6108 - accuracy: 0.8117 - f1_score: 0.7930 - val_loss: 5.1265 - val_accuracy: 0.1594 - val_f1_score: 0.0495 - lr: 1.0000e-04
# Epoch 6/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.8467 - f1_score: 0.8341
# Epoch 6: val_f1_score improved from 0.06024 to 0.27989, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 74s 705ms/step - loss: 0.4913 - accuracy: 0.8467 - f1_score: 0.8341 - val_loss: 2.2570 - val_accuracy: 0.3860 - val_f1_score: 0.2799 - lr: 1.0000e-04
# Epoch 7/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4169 - accuracy: 0.8725 - f1_score: 0.8663
# Epoch 7: val_f1_score improved from 0.27989 to 0.58460, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 84s 807ms/step - loss: 0.4169 - accuracy: 0.8725 - f1_score: 0.8663 - val_loss: 1.1177 - val_accuracy: 0.6341 - val_f1_score: 0.5846 - lr: 1.0000e-04
# Epoch 8/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8958 - f1_score: 0.8914
# Epoch 8: val_f1_score did not improve from 0.58460
# 104/104 [==============================] - 74s 706ms/step - loss: 0.3437 - accuracy: 0.8958 - f1_score: 0.8914 - val_loss: 1.1307 - val_accuracy: 0.6569 - val_f1_score: 0.5782 - lr: 1.0000e-04
# Epoch 9/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9148 - f1_score: 0.9097
# Epoch 9: val_f1_score improved from 0.58460 to 0.66378, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 90s 864ms/step - loss: 0.2844 - accuracy: 0.9148 - f1_score: 0.9097 - val_loss: 1.0053 - val_accuracy: 0.6854 - val_f1_score: 0.6638 - lr: 1.0000e-04
# Epoch 10/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9275 - f1_score: 0.9238
# Epoch 10: val_f1_score improved from 0.66378 to 0.82559, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 84s 808ms/step - loss: 0.2430 - accuracy: 0.9275 - f1_score: 0.9238 - val_loss: 0.5569 - val_accuracy: 0.8205 - val_f1_score: 0.8256 - lr: 1.0000e-04
# Epoch 11/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9386 - f1_score: 0.9353
# Epoch 11: val_f1_score did not improve from 0.82559
# 104/104 [==============================] - 77s 735ms/step - loss: 0.2111 - accuracy: 0.9386 - f1_score: 0.9353 - val_loss: 0.7641 - val_accuracy: 0.7507 - val_f1_score: 0.7186 - lr: 1.0000e-04
# Epoch 12/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9390 - f1_score: 0.9348
# Epoch 12: val_f1_score did not improve from 0.82559
# 104/104 [==============================] - 74s 705ms/step - loss: 0.1909 - accuracy: 0.9390 - f1_score: 0.9348 - val_loss: 0.5788 - val_accuracy: 0.8124 - val_f1_score: 0.8111 - lr: 1.0000e-04
# Epoch 13/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9512 - f1_score: 0.9497
# Epoch 13: val_f1_score did not improve from 0.82559
# 104/104 [==============================] - 73s 699ms/step - loss: 0.1686 - accuracy: 0.9512 - f1_score: 0.9497 - val_loss: 0.5685 - val_accuracy: 0.8290 - val_f1_score: 0.8078 - lr: 1.0000e-04
# Epoch 14/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9553 - f1_score: 0.9541
# Epoch 14: val_f1_score did not improve from 0.82559
# 104/104 [==============================] - 74s 711ms/step - loss: 0.1561 - accuracy: 0.9553 - f1_score: 0.9541 - val_loss: 0.8304 - val_accuracy: 0.7457 - val_f1_score: 0.7503 - lr: 1.0000e-04
# Epoch 15/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9541 - f1_score: 0.9521
# Epoch 15: val_f1_score did not improve from 0.82559
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 104/104 [==============================] - 74s 711ms/step - loss: 0.1479 - accuracy: 0.9541 - f1_score: 0.9521 - val_loss: 0.5754 - val_accuracy: 0.8078 - val_f1_score: 0.8112 - lr: 1.0000e-04
# Epoch 16/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9730 - f1_score: 0.9723
# Epoch 16: val_f1_score improved from 0.82559 to 0.92475, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 75s 717ms/step - loss: 0.0927 - accuracy: 0.9730 - f1_score: 0.9723 - val_loss: 0.2397 - val_accuracy: 0.9271 - val_f1_score: 0.9247 - lr: 5.0000e-05
# Epoch 17/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9803 - f1_score: 0.9793
# Epoch 17: val_f1_score improved from 0.92475 to 0.93188, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 73s 699ms/step - loss: 0.0733 - accuracy: 0.9803 - f1_score: 0.9793 - val_loss: 0.2174 - val_accuracy: 0.9352 - val_f1_score: 0.9319 - lr: 5.0000e-05
# Epoch 18/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9819 - f1_score: 0.9813
# Epoch 18: val_f1_score improved from 0.93188 to 0.93680, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 72s 693ms/step - loss: 0.0654 - accuracy: 0.9819 - f1_score: 0.9813 - val_loss: 0.2058 - val_accuracy: 0.9386 - val_f1_score: 0.9368 - lr: 5.0000e-05
# Epoch 19/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9816 - f1_score: 0.9808
# Epoch 19: val_f1_score did not improve from 0.93680
# 104/104 [==============================] - 75s 715ms/step - loss: 0.0639 - accuracy: 0.9816 - f1_score: 0.9808 - val_loss: 0.2099 - val_accuracy: 0.9336 - val_f1_score: 0.9322 - lr: 5.0000e-05
# Epoch 20/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9843 - f1_score: 0.9830
# Epoch 20: val_f1_score did not improve from 0.93680
# 104/104 [==============================] - 74s 705ms/step - loss: 0.0582 - accuracy: 0.9843 - f1_score: 0.9830 - val_loss: 0.2169 - val_accuracy: 0.9359 - val_f1_score: 0.9268 - lr: 5.0000e-05
# Epoch 21/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9860 - f1_score: 0.9854
# Epoch 21: val_f1_score did not improve from 0.93680
# 104/104 [==============================] - 76s 729ms/step - loss: 0.0506 - accuracy: 0.9860 - f1_score: 0.9854 - val_loss: 0.2308 - val_accuracy: 0.9298 - val_f1_score: 0.9270 - lr: 5.0000e-05
# Epoch 22/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9858 - f1_score: 0.9851
# Epoch 22: val_f1_score improved from 0.93680 to 0.94371, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 77s 743ms/step - loss: 0.0516 - accuracy: 0.9858 - f1_score: 0.9851 - val_loss: 0.2000 - val_accuracy: 0.9433 - val_f1_score: 0.9437 - lr: 5.0000e-05
# Epoch 23/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9841 - f1_score: 0.9842
# Epoch 23: val_f1_score did not improve from 0.94371
# 104/104 [==============================] - 83s 797ms/step - loss: 0.0581 - accuracy: 0.9841 - f1_score: 0.9842 - val_loss: 0.2235 - val_accuracy: 0.9359 - val_f1_score: 0.9328 - lr: 5.0000e-05
# Epoch 24/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9831 - f1_score: 0.9836
# Epoch 24: val_f1_score did not improve from 0.94371
# 104/104 [==============================] - 100s 960ms/step - loss: 0.0561 - accuracy: 0.9831 - f1_score: 0.9836 - val_loss: 0.2296 - val_accuracy: 0.9344 - val_f1_score: 0.9352 - lr: 5.0000e-05
# Epoch 25/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9864 - f1_score: 0.9860
# Epoch 25: val_f1_score did not improve from 0.94371
# 104/104 [==============================] - 76s 725ms/step - loss: 0.0490 - accuracy: 0.9864 - f1_score: 0.9860 - val_loss: 0.2827 - val_accuracy: 0.9190 - val_f1_score: 0.9213 - lr: 5.0000e-05
# Epoch 26/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9838 - f1_score: 0.9831
# Epoch 26: val_f1_score did not improve from 0.94371
# 104/104 [==============================] - 74s 710ms/step - loss: 0.0511 - accuracy: 0.9838 - f1_score: 0.9831 - val_loss: 0.2127 - val_accuracy: 0.9375 - val_f1_score: 0.9347 - lr: 5.0000e-05
# Epoch 27/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9843 - f1_score: 0.9835
# Epoch 27: val_f1_score did not improve from 0.94371
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 104/104 [==============================] - 78s 746ms/step - loss: 0.0548 - accuracy: 0.9843 - f1_score: 0.9835 - val_loss: 0.3872 - val_accuracy: 0.8861 - val_f1_score: 0.8834 - lr: 5.0000e-05
# Epoch 28/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9904 - f1_score: 0.9902
# Epoch 28: val_f1_score improved from 0.94371 to 0.94801, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 76s 726ms/step - loss: 0.0360 - accuracy: 0.9904 - f1_score: 0.9902 - val_loss: 0.1643 - val_accuracy: 0.9498 - val_f1_score: 0.9480 - lr: 2.5000e-05
# Epoch 29/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9931 - f1_score: 0.9929
# Epoch 29: val_f1_score improved from 0.94801 to 0.95132, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 74s 706ms/step - loss: 0.0290 - accuracy: 0.9931 - f1_score: 0.9929 - val_loss: 0.1673 - val_accuracy: 0.9529 - val_f1_score: 0.9513 - lr: 2.5000e-05
# Epoch 30/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9921 - f1_score: 0.9918
# Epoch 30: val_f1_score improved from 0.95132 to 0.95135, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 72s 688ms/step - loss: 0.0278 - accuracy: 0.9921 - f1_score: 0.9918 - val_loss: 0.1670 - val_accuracy: 0.9545 - val_f1_score: 0.9514 - lr: 2.5000e-05
# Epoch 31/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9938 - f1_score: 0.9934
# Epoch 31: val_f1_score improved from 0.95135 to 0.95302, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 72s 686ms/step - loss: 0.0227 - accuracy: 0.9938 - f1_score: 0.9934 - val_loss: 0.1737 - val_accuracy: 0.9533 - val_f1_score: 0.9530 - lr: 2.5000e-05
# Epoch 32/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9938 - f1_score: 0.9937
# Epoch 32: val_f1_score did not improve from 0.95302
# 104/104 [==============================] - 70s 669ms/step - loss: 0.0249 - accuracy: 0.9938 - f1_score: 0.9937 - val_loss: 0.1612 - val_accuracy: 0.9510 - val_f1_score: 0.9509 - lr: 2.5000e-05
# Epoch 33/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9921 - f1_score: 0.9917
# Epoch 33: val_f1_score did not improve from 0.95302
# 104/104 [==============================] - 71s 675ms/step - loss: 0.0268 - accuracy: 0.9921 - f1_score: 0.9917 - val_loss: 0.1753 - val_accuracy: 0.9518 - val_f1_score: 0.9506 - lr: 2.5000e-05
# Epoch 34/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9933 - f1_score: 0.9932
# Epoch 34: val_f1_score did not improve from 0.95302
# 104/104 [==============================] - 71s 674ms/step - loss: 0.0242 - accuracy: 0.9933 - f1_score: 0.9932 - val_loss: 0.1737 - val_accuracy: 0.9502 - val_f1_score: 0.9495 - lr: 2.5000e-05
# Epoch 35/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9939 - f1_score: 0.9937
# Epoch 35: val_f1_score improved from 0.95302 to 0.95635, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 73s 701ms/step - loss: 0.0224 - accuracy: 0.9939 - f1_score: 0.9937 - val_loss: 0.1612 - val_accuracy: 0.9591 - val_f1_score: 0.9563 - lr: 2.5000e-05
# Epoch 36/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9937 - f1_score: 0.9928
# Epoch 36: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 75s 716ms/step - loss: 0.0236 - accuracy: 0.9937 - f1_score: 0.9928 - val_loss: 0.1773 - val_accuracy: 0.9518 - val_f1_score: 0.9498 - lr: 2.5000e-05
# Epoch 37/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9937 - f1_score: 0.9926
# Epoch 37: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 71s 681ms/step - loss: 0.0235 - accuracy: 0.9937 - f1_score: 0.9926 - val_loss: 0.1539 - val_accuracy: 0.9545 - val_f1_score: 0.9547 - lr: 2.5000e-05
# Epoch 38/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9917 - f1_score: 0.9921
# Epoch 38: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 83s 791ms/step - loss: 0.0277 - accuracy: 0.9917 - f1_score: 0.9921 - val_loss: 0.1733 - val_accuracy: 0.9556 - val_f1_score: 0.9546 - lr: 2.5000e-05
# Epoch 39/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9946 - f1_score: 0.9944
# Epoch 39: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 85s 808ms/step - loss: 0.0228 - accuracy: 0.9946 - f1_score: 0.9944 - val_loss: 0.1745 - val_accuracy: 0.9494 - val_f1_score: 0.9469 - lr: 2.5000e-05
# Epoch 40/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9926 - f1_score: 0.9929
# Epoch 40: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 79s 753ms/step - loss: 0.0252 - accuracy: 0.9926 - f1_score: 0.9929 - val_loss: 0.2271 - val_accuracy: 0.9344 - val_f1_score: 0.9321 - lr: 2.5000e-05
# Epoch 41/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9939 - f1_score: 0.9936
# Epoch 41: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 74s 711ms/step - loss: 0.0235 - accuracy: 0.9939 - f1_score: 0.9936 - val_loss: 0.1637 - val_accuracy: 0.9560 - val_f1_score: 0.9533 - lr: 2.5000e-05
# Epoch 42/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9941 - f1_score: 0.9935
# Epoch 42: val_f1_score did not improve from 0.95635
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 104/104 [==============================] - 79s 753ms/step - loss: 0.0217 - accuracy: 0.9941 - f1_score: 0.9935 - val_loss: 0.1671 - val_accuracy: 0.9537 - val_f1_score: 0.9491 - lr: 2.5000e-05
# Epoch 43/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9944 - f1_score: 0.9938
# Epoch 43: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 85s 814ms/step - loss: 0.0197 - accuracy: 0.9944 - f1_score: 0.9938 - val_loss: 0.1536 - val_accuracy: 0.9575 - val_f1_score: 0.9546 - lr: 1.2500e-05
# Epoch 44/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9956 - f1_score: 0.9954
# Epoch 44: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 83s 796ms/step - loss: 0.0165 - accuracy: 0.9956 - f1_score: 0.9954 - val_loss: 0.1542 - val_accuracy: 0.9575 - val_f1_score: 0.9547 - lr: 1.2500e-05
# Epoch 45/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9955 - f1_score: 0.9952
# Epoch 45: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 83s 789ms/step - loss: 0.0166 - accuracy: 0.9955 - f1_score: 0.9952 - val_loss: 0.1593 - val_accuracy: 0.9548 - val_f1_score: 0.9529 - lr: 1.2500e-05
# Epoch 46/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9962 - f1_score: 0.9962
# Epoch 46: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 83s 790ms/step - loss: 0.0140 - accuracy: 0.9962 - f1_score: 0.9962 - val_loss: 0.1588 - val_accuracy: 0.9579 - val_f1_score: 0.9563 - lr: 1.2500e-05
# Epoch 47/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9961 - f1_score: 0.9959
# Epoch 47: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 76s 730ms/step - loss: 0.0148 - accuracy: 0.9961 - f1_score: 0.9959 - val_loss: 0.1497 - val_accuracy: 0.9579 - val_f1_score: 0.9557 - lr: 1.2500e-05
# Epoch 48/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9949 - f1_score: 0.9944
# Epoch 48: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 81s 782ms/step - loss: 0.0166 - accuracy: 0.9949 - f1_score: 0.9944 - val_loss: 0.1679 - val_accuracy: 0.9552 - val_f1_score: 0.9548 - lr: 1.2500e-05
# Epoch 49/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9955 - f1_score: 0.9951
# Epoch 49: val_f1_score did not improve from 0.95635
# 104/104 [==============================] - 84s 806ms/step - loss: 0.0157 - accuracy: 0.9955 - f1_score: 0.9951 - val_loss: 0.1554 - val_accuracy: 0.9583 - val_f1_score: 0.9558 - lr: 1.2500e-05
# Epoch 50/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9941 - f1_score: 0.9938
# Epoch 50: val_f1_score improved from 0.95635 to 0.95753, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 84s 808ms/step - loss: 0.0171 - accuracy: 0.9941 - f1_score: 0.9938 - val_loss: 0.1529 - val_accuracy: 0.9579 - val_f1_score: 0.9575 - lr: 1.2500e-05
# Epoch 51/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9960 - f1_score: 0.9962
# Epoch 51: val_f1_score improved from 0.95753 to 0.95984, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 85s 816ms/step - loss: 0.0135 - accuracy: 0.9960 - f1_score: 0.9962 - val_loss: 0.1612 - val_accuracy: 0.9602 - val_f1_score: 0.9598 - lr: 1.2500e-05
# Epoch 52/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9956 - f1_score: 0.9955
# Epoch 52: val_f1_score did not improve from 0.95984
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 104/104 [==============================] - 83s 793ms/step - loss: 0.0158 - accuracy: 0.9956 - f1_score: 0.9955 - val_loss: 0.1531 - val_accuracy: 0.9606 - val_f1_score: 0.9596 - lr: 1.2500e-05
# Epoch 53/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9963 - f1_score: 0.9960
# Epoch 53: val_f1_score improved from 0.95984 to 0.96282, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 77s 740ms/step - loss: 0.0132 - accuracy: 0.9963 - f1_score: 0.9960 - val_loss: 0.1420 - val_accuracy: 0.9633 - val_f1_score: 0.9628 - lr: 6.2500e-06
# Epoch 54/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9963 - f1_score: 0.9957
# Epoch 54: val_f1_score did not improve from 0.96282
# 104/104 [==============================] - 78s 750ms/step - loss: 0.0133 - accuracy: 0.9963 - f1_score: 0.9957 - val_loss: 0.1574 - val_accuracy: 0.9579 - val_f1_score: 0.9559 - lr: 6.2500e-06
# Epoch 55/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9962 - f1_score: 0.9958
# Epoch 55: val_f1_score did not improve from 0.96282
# 104/104 [==============================] - 74s 707ms/step - loss: 0.0135 - accuracy: 0.9962 - f1_score: 0.9958 - val_loss: 0.1516 - val_accuracy: 0.9610 - val_f1_score: 0.9607 - lr: 6.2500e-06
# Epoch 56/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9980 - f1_score: 0.9977
# Epoch 56: val_f1_score did not improve from 0.96282
# 104/104 [==============================] - 82s 788ms/step - loss: 0.0107 - accuracy: 0.9980 - f1_score: 0.9977 - val_loss: 0.1444 - val_accuracy: 0.9622 - val_f1_score: 0.9613 - lr: 6.2500e-06
# Epoch 57/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9967 - f1_score: 0.9965
# Epoch 57: val_f1_score did not improve from 0.96282
# 104/104 [==============================] - 90s 861ms/step - loss: 0.0117 - accuracy: 0.9967 - f1_score: 0.9965 - val_loss: 0.1415 - val_accuracy: 0.9579 - val_f1_score: 0.9571 - lr: 6.2500e-06
# Epoch 58/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9976 - f1_score: 0.9974
# Epoch 58: val_f1_score did not improve from 0.96282
# 104/104 [==============================] - 96s 925ms/step - loss: 0.0116 - accuracy: 0.9976 - f1_score: 0.9974 - val_loss: 0.1504 - val_accuracy: 0.9633 - val_f1_score: 0.9616 - lr: 6.2500e-06
# Epoch 59/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9978 - f1_score: 0.9979
# Epoch 59: val_f1_score improved from 0.96282 to 0.96286, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 81s 772ms/step - loss: 0.0108 - accuracy: 0.9978 - f1_score: 0.9979 - val_loss: 0.1467 - val_accuracy: 0.9641 - val_f1_score: 0.9629 - lr: 6.2500e-06
# Epoch 60/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9965 - f1_score: 0.9964
# Epoch 60: val_f1_score did not improve from 0.96286
# 104/104 [==============================] - 79s 755ms/step - loss: 0.0116 - accuracy: 0.9965 - f1_score: 0.9964 - val_loss: 0.1574 - val_accuracy: 0.9587 - val_f1_score: 0.9578 - lr: 6.2500e-06
# Epoch 61/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9970 - f1_score: 0.9969
# Epoch 61: val_f1_score did not improve from 0.96286
# 104/104 [==============================] - 79s 754ms/step - loss: 0.0113 - accuracy: 0.9970 - f1_score: 0.9969 - val_loss: 0.1526 - val_accuracy: 0.9583 - val_f1_score: 0.9583 - lr: 6.2500e-06
# Epoch 62/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9965 - f1_score: 0.9962
# Epoch 62: val_f1_score improved from 0.96286 to 0.96395, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 104/104 [==============================] - 73s 701ms/step - loss: 0.0113 - accuracy: 0.9965 - f1_score: 0.9962 - val_loss: 0.1478 - val_accuracy: 0.9641 - val_f1_score: 0.9640 - lr: 6.2500e-06
# Epoch 63/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9967 - f1_score: 0.9967
# Epoch 63: val_f1_score improved from 0.96395 to 0.96414, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 75s 720ms/step - loss: 0.0109 - accuracy: 0.9967 - f1_score: 0.9967 - val_loss: 0.1413 - val_accuracy: 0.9633 - val_f1_score: 0.9641 - lr: 3.1250e-06
# Epoch 64/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9980 - f1_score: 0.9979
# Epoch 64: val_f1_score did not improve from 0.96414
# 104/104 [==============================] - 99s 955ms/step - loss: 0.0089 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.1523 - val_accuracy: 0.9599 - val_f1_score: 0.9583 - lr: 3.1250e-06
# Epoch 65/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9976 - f1_score: 0.9976
# Epoch 65: val_f1_score did not improve from 0.96414
# 104/104 [==============================] - 98s 942ms/step - loss: 0.0102 - accuracy: 0.9976 - f1_score: 0.9976 - val_loss: 0.1430 - val_accuracy: 0.9614 - val_f1_score: 0.9610 - lr: 3.1250e-06
# Epoch 66/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9971 - f1_score: 0.9966
# Epoch 66: val_f1_score did not improve from 0.96414
# 104/104 [==============================] - 80s 769ms/step - loss: 0.0103 - accuracy: 0.9971 - f1_score: 0.9966 - val_loss: 0.1511 - val_accuracy: 0.9579 - val_f1_score: 0.9563 - lr: 3.1250e-06
# Epoch 67/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9982 - f1_score: 0.9980
# Epoch 67: val_f1_score did not improve from 0.96414
# 104/104 [==============================] - 104s 995ms/step - loss: 0.0094 - accuracy: 0.9982 - f1_score: 0.9980 - val_loss: 0.1539 - val_accuracy: 0.9599 - val_f1_score: 0.9586 - lr: 3.1250e-06
# Epoch 68/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9974 - f1_score: 0.9973
# Epoch 68: val_f1_score did not improve from 0.96414
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 104/104 [==============================] - 90s 857ms/step - loss: 0.0090 - accuracy: 0.9974 - f1_score: 0.9973 - val_loss: 0.1482 - val_accuracy: 0.9599 - val_f1_score: 0.9602 - lr: 3.1250e-06
# Epoch 69/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9974 - f1_score: 0.9970
# Epoch 69: val_f1_score improved from 0.96414 to 0.96557, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 94s 903ms/step - loss: 0.0094 - accuracy: 0.9974 - f1_score: 0.9970 - val_loss: 0.1371 - val_accuracy: 0.9672 - val_f1_score: 0.9656 - lr: 1.5625e-06
# Epoch 70/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9970 - f1_score: 0.9967
# Epoch 70: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 90s 867ms/step - loss: 0.0097 - accuracy: 0.9970 - f1_score: 0.9967 - val_loss: 0.1460 - val_accuracy: 0.9610 - val_f1_score: 0.9590 - lr: 1.5625e-06
# Epoch 71/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9973 - f1_score: 0.9971
# Epoch 71: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 82s 780ms/step - loss: 0.0096 - accuracy: 0.9973 - f1_score: 0.9971 - val_loss: 0.1488 - val_accuracy: 0.9591 - val_f1_score: 0.9555 - lr: 1.5625e-06
# Epoch 72/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9973 - f1_score: 0.9970
# Epoch 72: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 76s 724ms/step - loss: 0.0090 - accuracy: 0.9973 - f1_score: 0.9970 - val_loss: 0.1411 - val_accuracy: 0.9629 - val_f1_score: 0.9608 - lr: 1.5625e-06
# Epoch 73/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9975 - f1_score: 0.9973
# Epoch 73: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 695ms/step - loss: 0.0090 - accuracy: 0.9975 - f1_score: 0.9973 - val_loss: 0.1479 - val_accuracy: 0.9602 - val_f1_score: 0.9590 - lr: 1.5625e-06
# Epoch 74/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9974 - f1_score: 0.9969
# Epoch 74: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 692ms/step - loss: 0.0093 - accuracy: 0.9974 - f1_score: 0.9969 - val_loss: 0.1362 - val_accuracy: 0.9591 - val_f1_score: 0.9578 - lr: 1.5625e-06
# Epoch 75/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9973 - f1_score: 0.9971
# Epoch 75: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 70s 673ms/step - loss: 0.0095 - accuracy: 0.9973 - f1_score: 0.9971 - val_loss: 0.1415 - val_accuracy: 0.9633 - val_f1_score: 0.9616 - lr: 1.5625e-06
# Epoch 76/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9976 - f1_score: 0.9974
# Epoch 76: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 687ms/step - loss: 0.0088 - accuracy: 0.9976 - f1_score: 0.9974 - val_loss: 0.1438 - val_accuracy: 0.9614 - val_f1_score: 0.9602 - lr: 1.5625e-06
# Epoch 77/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9975 - f1_score: 0.9978
# Epoch 77: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 70s 674ms/step - loss: 0.0088 - accuracy: 0.9975 - f1_score: 0.9978 - val_loss: 0.1435 - val_accuracy: 0.9618 - val_f1_score: 0.9608 - lr: 1.5625e-06
# Epoch 78/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9971 - f1_score: 0.9967
# Epoch 78: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 70s 673ms/step - loss: 0.0100 - accuracy: 0.9971 - f1_score: 0.9967 - val_loss: 0.1435 - val_accuracy: 0.9641 - val_f1_score: 0.9629 - lr: 1.5625e-06
# Epoch 79/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9982 - f1_score: 0.9980
# Epoch 79: val_f1_score did not improve from 0.96557
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 104/104 [==============================] - 71s 677ms/step - loss: 0.0096 - accuracy: 0.9982 - f1_score: 0.9980 - val_loss: 0.1463 - val_accuracy: 0.9633 - val_f1_score: 0.9630 - lr: 1.5625e-06
# Epoch 80/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9974 - f1_score: 0.9971
# Epoch 80: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 676ms/step - loss: 0.0095 - accuracy: 0.9974 - f1_score: 0.9971 - val_loss: 0.1489 - val_accuracy: 0.9606 - val_f1_score: 0.9589 - lr: 7.8125e-07
# Epoch 81/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9982 - f1_score: 0.9982
# Epoch 81: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 677ms/step - loss: 0.0083 - accuracy: 0.9982 - f1_score: 0.9982 - val_loss: 0.1455 - val_accuracy: 0.9626 - val_f1_score: 0.9602 - lr: 7.8125e-07
# Epoch 82/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9979 - f1_score: 0.9978
# Epoch 82: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 687ms/step - loss: 0.0086 - accuracy: 0.9979 - f1_score: 0.9978 - val_loss: 0.1401 - val_accuracy: 0.9633 - val_f1_score: 0.9618 - lr: 7.8125e-07
# Epoch 83/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9976 - f1_score: 0.9975
# Epoch 83: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 77s 735ms/step - loss: 0.0085 - accuracy: 0.9976 - f1_score: 0.9975 - val_loss: 0.1341 - val_accuracy: 0.9664 - val_f1_score: 0.9647 - lr: 7.8125e-07
# Epoch 84/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9983 - f1_score: 0.9981
# Epoch 84: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 83s 790ms/step - loss: 0.0080 - accuracy: 0.9983 - f1_score: 0.9981 - val_loss: 0.1419 - val_accuracy: 0.9649 - val_f1_score: 0.9640 - lr: 7.8125e-07
# Epoch 85/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9979 - f1_score: 0.9974
# Epoch 85: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 78s 751ms/step - loss: 0.0088 - accuracy: 0.9979 - f1_score: 0.9974 - val_loss: 0.1480 - val_accuracy: 0.9626 - val_f1_score: 0.9614 - lr: 7.8125e-07
# Epoch 86/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9974 - f1_score: 0.9972
# Epoch 86: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 82s 788ms/step - loss: 0.0085 - accuracy: 0.9974 - f1_score: 0.9972 - val_loss: 0.1521 - val_accuracy: 0.9610 - val_f1_score: 0.9588 - lr: 7.8125e-07
# Epoch 87/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9977 - f1_score: 0.9972
# Epoch 87: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 79s 759ms/step - loss: 0.0087 - accuracy: 0.9977 - f1_score: 0.9972 - val_loss: 0.1453 - val_accuracy: 0.9629 - val_f1_score: 0.9597 - lr: 7.8125e-07
# Epoch 88/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9974 - f1_score: 0.9971
# Epoch 88: val_f1_score did not improve from 0.96557
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 104/104 [==============================] - 79s 755ms/step - loss: 0.0080 - accuracy: 0.9974 - f1_score: 0.9971 - val_loss: 0.1491 - val_accuracy: 0.9641 - val_f1_score: 0.9619 - lr: 7.8125e-07
# Epoch 89/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9977 - f1_score: 0.9976
# Epoch 89: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 81s 776ms/step - loss: 0.0088 - accuracy: 0.9977 - f1_score: 0.9976 - val_loss: 0.1431 - val_accuracy: 0.9649 - val_f1_score: 0.9625 - lr: 3.9062e-07
# Epoch 90/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9979 - f1_score: 0.9977
# Epoch 90: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 692ms/step - loss: 0.0077 - accuracy: 0.9979 - f1_score: 0.9977 - val_loss: 0.1463 - val_accuracy: 0.9610 - val_f1_score: 0.9596 - lr: 3.9062e-07
# Epoch 91/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9975 - f1_score: 0.9974
# Epoch 91: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 70s 672ms/step - loss: 0.0091 - accuracy: 0.9975 - f1_score: 0.9974 - val_loss: 0.1401 - val_accuracy: 0.9660 - val_f1_score: 0.9617 - lr: 3.9062e-07
# Epoch 92/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9981 - f1_score: 0.9979
# Epoch 92: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 675ms/step - loss: 0.0083 - accuracy: 0.9981 - f1_score: 0.9979 - val_loss: 0.1538 - val_accuracy: 0.9614 - val_f1_score: 0.9608 - lr: 3.9062e-07
# Epoch 93/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9980 - f1_score: 0.9981
# Epoch 93: val_f1_score did not improve from 0.96557
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 104/104 [==============================] - 71s 682ms/step - loss: 0.0084 - accuracy: 0.9980 - f1_score: 0.9981 - val_loss: 0.1388 - val_accuracy: 0.9629 - val_f1_score: 0.9607 - lr: 3.9062e-07
# Epoch 94/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9985 - f1_score: 0.9986
# Epoch 94: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 689ms/step - loss: 0.0072 - accuracy: 0.9985 - f1_score: 0.9986 - val_loss: 0.1436 - val_accuracy: 0.9649 - val_f1_score: 0.9640 - lr: 1.9531e-07
# Epoch 95/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9980 - f1_score: 0.9979
# Epoch 95: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 680ms/step - loss: 0.0085 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.1426 - val_accuracy: 0.9622 - val_f1_score: 0.9603 - lr: 1.9531e-07
# Epoch 96/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9986 - f1_score: 0.9984
# Epoch 96: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 678ms/step - loss: 0.0071 - accuracy: 0.9986 - f1_score: 0.9984 - val_loss: 0.1622 - val_accuracy: 0.9572 - val_f1_score: 0.9578 - lr: 1.9531e-07
# Epoch 97/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 97: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 76s 725ms/step - loss: 0.0077 - accuracy: 0.9979 - f1_score: 0.9979 - val_loss: 0.1525 - val_accuracy: 0.9610 - val_f1_score: 0.9585 - lr: 1.9531e-07
# Epoch 98/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9979 - f1_score: 0.9978
# Epoch 98: val_f1_score did not improve from 0.96557
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# 104/104 [==============================] - 71s 680ms/step - loss: 0.0091 - accuracy: 0.9979 - f1_score: 0.9978 - val_loss: 0.1478 - val_accuracy: 0.9633 - val_f1_score: 0.9618 - lr: 1.9531e-07
# Epoch 99/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9981 - f1_score: 0.9979
# Epoch 99: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 76s 723ms/step - loss: 0.0076 - accuracy: 0.9981 - f1_score: 0.9979 - val_loss: 0.1429 - val_accuracy: 0.9618 - val_f1_score: 0.9591 - lr: 9.7656e-08
# Epoch 100/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9979 - f1_score: 0.9976
# Epoch 100: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 88s 849ms/step - loss: 0.0086 - accuracy: 0.9979 - f1_score: 0.9976 - val_loss: 0.1461 - val_accuracy: 0.9606 - val_f1_score: 0.9598 - lr: 9.7656e-08
# Epoch 101/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9983 - f1_score: 0.9980
# Epoch 101: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 76s 726ms/step - loss: 0.0072 - accuracy: 0.9983 - f1_score: 0.9980 - val_loss: 0.1425 - val_accuracy: 0.9633 - val_f1_score: 0.9614 - lr: 9.7656e-08
# Epoch 102/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9978 - f1_score: 0.9977
# Epoch 102: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 80s 764ms/step - loss: 0.0085 - accuracy: 0.9978 - f1_score: 0.9977 - val_loss: 0.1521 - val_accuracy: 0.9614 - val_f1_score: 0.9611 - lr: 9.7656e-08
# Epoch 103/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9980 - f1_score: 0.9978
# Epoch 103: val_f1_score did not improve from 0.96557
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# 104/104 [==============================] - 76s 729ms/step - loss: 0.0077 - accuracy: 0.9980 - f1_score: 0.9978 - val_loss: 0.1416 - val_accuracy: 0.9649 - val_f1_score: 0.9637 - lr: 9.7656e-08
# Epoch 104/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9982 - f1_score: 0.9980
# Epoch 104: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 78s 746ms/step - loss: 0.0073 - accuracy: 0.9982 - f1_score: 0.9980 - val_loss: 0.1472 - val_accuracy: 0.9610 - val_f1_score: 0.9604 - lr: 4.8828e-08
# Epoch 105/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9973 - f1_score: 0.9969
# Epoch 105: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 77s 738ms/step - loss: 0.0086 - accuracy: 0.9973 - f1_score: 0.9969 - val_loss: 0.1431 - val_accuracy: 0.9637 - val_f1_score: 0.9637 - lr: 4.8828e-08
# Epoch 106/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9979 - f1_score: 0.9976
# Epoch 106: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 81s 773ms/step - loss: 0.0080 - accuracy: 0.9979 - f1_score: 0.9976 - val_loss: 0.1471 - val_accuracy: 0.9622 - val_f1_score: 0.9616 - lr: 4.8828e-08
# Epoch 107/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9976 - f1_score: 0.9972
# Epoch 107: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 73s 697ms/step - loss: 0.0078 - accuracy: 0.9976 - f1_score: 0.9972 - val_loss: 0.1334 - val_accuracy: 0.9645 - val_f1_score: 0.9612 - lr: 4.8828e-08
# Epoch 108/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9981 - f1_score: 0.9978
# Epoch 108: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 73s 703ms/step - loss: 0.0075 - accuracy: 0.9981 - f1_score: 0.9978 - val_loss: 0.1475 - val_accuracy: 0.9610 - val_f1_score: 0.9591 - lr: 4.8828e-08
# Epoch 109/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9980 - f1_score: 0.9981
# Epoch 109: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 80s 769ms/step - loss: 0.0085 - accuracy: 0.9980 - f1_score: 0.9981 - val_loss: 0.1492 - val_accuracy: 0.9637 - val_f1_score: 0.9623 - lr: 4.8828e-08
# Epoch 110/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9976 - f1_score: 0.9971
# Epoch 110: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 692ms/step - loss: 0.0084 - accuracy: 0.9976 - f1_score: 0.9971 - val_loss: 0.1463 - val_accuracy: 0.9633 - val_f1_score: 0.9608 - lr: 4.8828e-08
# Epoch 111/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9977 - f1_score: 0.9973
# Epoch 111: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 678ms/step - loss: 0.0083 - accuracy: 0.9977 - f1_score: 0.9973 - val_loss: 0.1479 - val_accuracy: 0.9637 - val_f1_score: 0.9615 - lr: 4.8828e-08
# Epoch 112/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9982 - f1_score: 0.9983
# Epoch 112: val_f1_score did not improve from 0.96557
#
# Epoch 112: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# 104/104 [==============================] - 73s 697ms/step - loss: 0.0078 - accuracy: 0.9982 - f1_score: 0.9983 - val_loss: 0.1496 - val_accuracy: 0.9637 - val_f1_score: 0.9633 - lr: 4.8828e-08
# Epoch 113/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9980 - f1_score: 0.9977
# Epoch 113: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 687ms/step - loss: 0.0078 - accuracy: 0.9980 - f1_score: 0.9977 - val_loss: 0.1576 - val_accuracy: 0.9575 - val_f1_score: 0.9546 - lr: 2.4414e-08
# Epoch 114/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9987 - f1_score: 0.9984
# Epoch 114: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 72s 683ms/step - loss: 0.0083 - accuracy: 0.9987 - f1_score: 0.9984 - val_loss: 0.1505 - val_accuracy: 0.9618 - val_f1_score: 0.9594 - lr: 2.4414e-08
# Epoch 115/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9979 - f1_score: 0.9976
# Epoch 115: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 71s 676ms/step - loss: 0.0080 - accuracy: 0.9979 - f1_score: 0.9976 - val_loss: 0.1487 - val_accuracy: 0.9629 - val_f1_score: 0.9615 - lr: 2.4414e-08
# Epoch 116/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9977 - f1_score: 0.9977
# Epoch 116: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 73s 703ms/step - loss: 0.0085 - accuracy: 0.9977 - f1_score: 0.9977 - val_loss: 0.1386 - val_accuracy: 0.9649 - val_f1_score: 0.9640 - lr: 2.4414e-08
# Epoch 117/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9977 - f1_score: 0.9976
# Epoch 117: val_f1_score did not improve from 0.96557
#
# Epoch 117: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# 104/104 [==============================] - 74s 712ms/step - loss: 0.0078 - accuracy: 0.9977 - f1_score: 0.9976 - val_loss: 0.1426 - val_accuracy: 0.9645 - val_f1_score: 0.9640 - lr: 2.4414e-08
# Epoch 118/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9979 - f1_score: 0.9977
# Epoch 118: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 73s 704ms/step - loss: 0.0083 - accuracy: 0.9979 - f1_score: 0.9977 - val_loss: 0.1252 - val_accuracy: 0.9664 - val_f1_score: 0.9645 - lr: 1.2207e-08
# Epoch 119/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9978 - f1_score: 0.9977
# Epoch 119: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 190s 2s/step - loss: 0.0081 - accuracy: 0.9978 - f1_score: 0.9977 - val_loss: 0.1410 - val_accuracy: 0.9622 - val_f1_score: 0.9601 - lr: 1.2207e-08
# Epoch 120/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9983 - f1_score: 0.9984
# Epoch 120: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 252s 2s/step - loss: 0.0077 - accuracy: 0.9983 - f1_score: 0.9984 - val_loss: 0.1403 - val_accuracy: 0.9622 - val_f1_score: 0.9607 - lr: 1.2207e-08
# Epoch 121/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9982 - f1_score: 0.9978
# Epoch 121: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 251s 2s/step - loss: 0.0078 - accuracy: 0.9982 - f1_score: 0.9978 - val_loss: 0.1489 - val_accuracy: 0.9649 - val_f1_score: 0.9632 - lr: 1.2207e-08
# Epoch 122/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9981 - f1_score: 0.9979
# Epoch 122: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 260s 2s/step - loss: 0.0085 - accuracy: 0.9981 - f1_score: 0.9979 - val_loss: 0.1451 - val_accuracy: 0.9633 - val_f1_score: 0.9617 - lr: 1.2207e-08
# Epoch 123/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9982 - f1_score: 0.9980
# Epoch 123: val_f1_score did not improve from 0.96557
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 1e-08.
# 104/104 [==============================] - 255s 2s/step - loss: 0.0076 - accuracy: 0.9982 - f1_score: 0.9980 - val_loss: 0.1456 - val_accuracy: 0.9587 - val_f1_score: 0.9574 - lr: 1.2207e-08
# Epoch 124/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9980 - f1_score: 0.9977
# Epoch 124: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 262s 3s/step - loss: 0.0091 - accuracy: 0.9980 - f1_score: 0.9977 - val_loss: 0.1355 - val_accuracy: 0.9649 - val_f1_score: 0.9634 - lr: 1.0000e-08
# Epoch 125/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9978 - f1_score: 0.9975
# Epoch 125: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 243s 2s/step - loss: 0.0083 - accuracy: 0.9978 - f1_score: 0.9975 - val_loss: 0.1492 - val_accuracy: 0.9610 - val_f1_score: 0.9589 - lr: 1.0000e-08
# Epoch 126/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9980 - f1_score: 0.9979
# Epoch 126: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 245s 2s/step - loss: 0.0087 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.1559 - val_accuracy: 0.9626 - val_f1_score: 0.9614 - lr: 1.0000e-08
# Epoch 127/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9982 - f1_score: 0.9981
# Epoch 127: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 255s 2s/step - loss: 0.0079 - accuracy: 0.9982 - f1_score: 0.9981 - val_loss: 0.1458 - val_accuracy: 0.9668 - val_f1_score: 0.9653 - lr: 1.0000e-08
# Epoch 128/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9978 - f1_score: 0.9972
# Epoch 128: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 252s 2s/step - loss: 0.0081 - accuracy: 0.9978 - f1_score: 0.9972 - val_loss: 0.1431 - val_accuracy: 0.9629 - val_f1_score: 0.9617 - lr: 1.0000e-08
# Epoch 129/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9978 - f1_score: 0.9977
# Epoch 129: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 271s 3s/step - loss: 0.0084 - accuracy: 0.9978 - f1_score: 0.9977 - val_loss: 0.1492 - val_accuracy: 0.9641 - val_f1_score: 0.9612 - lr: 1.0000e-08
# Epoch 130/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9985 - f1_score: 0.9984
# Epoch 130: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 270s 3s/step - loss: 0.0073 - accuracy: 0.9985 - f1_score: 0.9984 - val_loss: 0.1361 - val_accuracy: 0.9649 - val_f1_score: 0.9633 - lr: 1.0000e-08
# Epoch 131/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9983 - f1_score: 0.9978
# Epoch 131: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 261s 3s/step - loss: 0.0080 - accuracy: 0.9983 - f1_score: 0.9978 - val_loss: 0.1564 - val_accuracy: 0.9629 - val_f1_score: 0.9630 - lr: 1.0000e-08
# Epoch 132/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9986 - f1_score: 0.9984
# Epoch 132: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 262s 3s/step - loss: 0.0071 - accuracy: 0.9986 - f1_score: 0.9984 - val_loss: 0.1459 - val_accuracy: 0.9606 - val_f1_score: 0.9589 - lr: 1.0000e-08
# Epoch 133/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9983 - f1_score: 0.9979
# Epoch 133: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 262s 3s/step - loss: 0.0076 - accuracy: 0.9983 - f1_score: 0.9979 - val_loss: 0.1524 - val_accuracy: 0.9610 - val_f1_score: 0.9566 - lr: 1.0000e-08
# Epoch 134/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9981 - f1_score: 0.9977
# Epoch 134: val_f1_score did not improve from 0.96557
# 104/104 [==============================] - 256s 2s/step - loss: 0.0072 - accuracy: 0.9981 - f1_score: 0.9977 - val_loss: 0.1540 - val_accuracy: 0.9602 - val_f1_score: 0.9591 - lr: 1.0000e-08
# Epoch 135/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9980 - f1_score: 0.9976
# Epoch 135: val_f1_score improved from 0.96557 to 0.96606, saving model to saved_outputs_basic_augment\DenseNet121\saved_models\best_DenseNet121.h5
# 104/104 [==============================] - 264s 3s/step - loss: 0.0083 - accuracy: 0.9980 - f1_score: 0.9976 - val_loss: 0.1344 - val_accuracy: 0.9660 - val_f1_score: 0.9661 - lr: 1.0000e-08
# Epoch 136/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9982 - f1_score: 0.9979
# Epoch 136: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 249s 2s/step - loss: 0.0075 - accuracy: 0.9982 - f1_score: 0.9979 - val_loss: 0.1411 - val_accuracy: 0.9629 - val_f1_score: 0.9619 - lr: 1.0000e-08
# Epoch 137/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9982 - f1_score: 0.9982
# Epoch 137: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 263s 3s/step - loss: 0.0076 - accuracy: 0.9982 - f1_score: 0.9982 - val_loss: 0.1581 - val_accuracy: 0.9622 - val_f1_score: 0.9608 - lr: 1.0000e-08
# Epoch 138/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9983 - f1_score: 0.9983
# Epoch 138: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 277s 3s/step - loss: 0.0076 - accuracy: 0.9983 - f1_score: 0.9983 - val_loss: 0.1478 - val_accuracy: 0.9626 - val_f1_score: 0.9622 - lr: 1.0000e-08
# Epoch 139/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9980 - f1_score: 0.9980
# Epoch 139: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 266s 3s/step - loss: 0.0091 - accuracy: 0.9980 - f1_score: 0.9980 - val_loss: 0.1497 - val_accuracy: 0.9606 - val_f1_score: 0.9590 - lr: 1.0000e-08
# Epoch 140/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9977 - f1_score: 0.9972
# Epoch 140: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 246s 2s/step - loss: 0.0078 - accuracy: 0.9977 - f1_score: 0.9972 - val_loss: 0.1496 - val_accuracy: 0.9626 - val_f1_score: 0.9609 - lr: 1.0000e-08
# Epoch 141/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9982 - f1_score: 0.9980
# Epoch 141: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 273s 3s/step - loss: 0.0080 - accuracy: 0.9982 - f1_score: 0.9980 - val_loss: 0.1439 - val_accuracy: 0.9626 - val_f1_score: 0.9629 - lr: 1.0000e-08
# Epoch 142/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9974 - f1_score: 0.9974
# Epoch 142: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 277s 3s/step - loss: 0.0090 - accuracy: 0.9974 - f1_score: 0.9974 - val_loss: 0.1527 - val_accuracy: 0.9618 - val_f1_score: 0.9598 - lr: 1.0000e-08
# Epoch 143/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9981 - f1_score: 0.9978
# Epoch 143: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 275s 3s/step - loss: 0.0085 - accuracy: 0.9981 - f1_score: 0.9978 - val_loss: 0.1406 - val_accuracy: 0.9629 - val_f1_score: 0.9614 - lr: 1.0000e-08
# Epoch 144/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9984 - f1_score: 0.9983
# Epoch 144: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 272s 3s/step - loss: 0.0074 - accuracy: 0.9984 - f1_score: 0.9983 - val_loss: 0.1406 - val_accuracy: 0.9633 - val_f1_score: 0.9621 - lr: 1.0000e-08
# Epoch 145/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9980 - f1_score: 0.9979
# Epoch 145: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 275s 3s/step - loss: 0.0082 - accuracy: 0.9980 - f1_score: 0.9979 - val_loss: 0.1514 - val_accuracy: 0.9602 - val_f1_score: 0.9590 - lr: 1.0000e-08
# Epoch 146/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9978 - f1_score: 0.9976
# Epoch 146: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 277s 3s/step - loss: 0.0090 - accuracy: 0.9978 - f1_score: 0.9976 - val_loss: 0.1412 - val_accuracy: 0.9649 - val_f1_score: 0.9637 - lr: 1.0000e-08
# Epoch 147/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9976 - f1_score: 0.9972
# Epoch 147: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 277s 3s/step - loss: 0.0077 - accuracy: 0.9976 - f1_score: 0.9972 - val_loss: 0.1563 - val_accuracy: 0.9595 - val_f1_score: 0.9574 - lr: 1.0000e-08
# Epoch 148/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9976 - f1_score: 0.9977
# Epoch 148: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 264s 3s/step - loss: 0.0084 - accuracy: 0.9976 - f1_score: 0.9977 - val_loss: 0.1527 - val_accuracy: 0.9622 - val_f1_score: 0.9611 - lr: 1.0000e-08
# Epoch 149/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9984 - f1_score: 0.9980
# Epoch 149: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 263s 3s/step - loss: 0.0077 - accuracy: 0.9984 - f1_score: 0.9980 - val_loss: 0.1470 - val_accuracy: 0.9645 - val_f1_score: 0.9645 - lr: 1.0000e-08
# Epoch 150/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9980 - f1_score: 0.9978
# Epoch 150: val_f1_score did not improve from 0.96606
# 104/104 [==============================] - 263s 3s/step - loss: 0.0082 - accuracy: 0.9980 - f1_score: 0.9978 - val_loss: 0.1483 - val_accuracy: 0.9629 - val_f1_score: 0.9622 - lr: 1.0000e-08

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 16s 488ms/step - loss: 0.3166 - accuracy: 0.9039 - f1_score: 0.9040
#     model_name  test_loss  test_accuracy  test_f1_score
# 0  DenseNet121   0.316642       0.903852       0.904045

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 26s 743ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.896825  0.869231  0.882812   130.000000
# 1              0.831858  0.940000  0.882629   100.000000
# 2              0.975309  0.877778  0.923977    90.000000
# 3              0.938144  0.900990  0.919192   101.000000
# 4              0.897436  0.893617  0.895522   470.000000
# 5              0.882591  0.861660  0.872000   253.000000
# 6              0.885714  0.890805  0.888252   174.000000
# 7              0.929268  0.883991  0.906064   431.000000
# 8              0.907317  0.849315  0.877358   219.000000
# 9              0.862963  0.968815  0.912831   481.000000
# 10             0.911688  0.900000  0.905806   390.000000
# 11             0.959184  0.925197  0.941884   254.000000
# 12             0.941176  0.947368  0.944262   152.000000
# accuracy       0.903852  0.903852  0.903852     0.903852
# macro avg      0.909190  0.900674  0.904045  3245.000000
# weighted avg   0.905412  0.903852  0.903806  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#     Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  DenseNet121  0.903852          0.90919      0.900674        0.904045
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.905412         0.903852           0.903806  0.316642

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.90385
# 1      Macro Precision  0.90919
# 2         Macro Recall  0.90067
# 3       Macro F1-Score  0.90405
# 4            Macro FPR  0.00829
# 5            Macro FNR  0.09933
# 6            Macro FDR  0.09081
# 7            Macro NPV  0.99181
# 8   Weighted Precision  0.90541
# 9      Weighted Recall  0.90385
# 10   Weighted F1-Score  0.90381
# 11        Weighted FPR  0.01163
# 12        Weighted FNR  0.09615
# 13        Weighted FDR  0.09459
# 14        Weighted NPV  0.98952
