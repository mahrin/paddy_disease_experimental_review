# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
# from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'InceptionV3'#'Xception'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 150 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\InceptionV3
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\InceptionV3\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\InceptionV3\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'_.h5'
    ## Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=10, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)
    # # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=4,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.0000001   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %%
from tensorflow.keras.applications import InceptionV3
def get_InceptionV3(): 
 
    # model = Sequential()
    # base_model = InceptionV3(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)
    model = InceptionV3(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time  = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/150
# 104/104 [==============================] - ETA: 0s - loss: 2.0982 - accuracy: 0.3009 - f1_score: 0.2180
# Epoch 1: val_f1_score improved from -inf to 0.01653, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 88s 760ms/step - loss: 2.0982 - accuracy: 0.3009 - f1_score: 0.2180 - val_loss: 2.5567 - val_accuracy: 0.1204 - val_f1_score: 0.0165 - lr: 1.0000e-04
# Epoch 2/150
# 104/104 [==============================] - ETA: 0s - loss: 1.7640 - accuracy: 0.4143 - f1_score: 0.3382
# Epoch 2: val_f1_score improved from 0.01653 to 0.01994, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 83s 798ms/step - loss: 1.7640 - accuracy: 0.4143 - f1_score: 0.3382 - val_loss: 2.9944 - val_accuracy: 0.1200 - val_f1_score: 0.0199 - lr: 1.0000e-04
# Epoch 3/150
# 104/104 [==============================] - ETA: 0s - loss: 1.5399 - accuracy: 0.4922 - f1_score: 0.4392
# Epoch 3: val_f1_score improved from 0.01994 to 0.04391, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 89s 855ms/step - loss: 1.5399 - accuracy: 0.4922 - f1_score: 0.4392 - val_loss: 3.5690 - val_accuracy: 0.1729 - val_f1_score: 0.0439 - lr: 1.0000e-04
# Epoch 4/150
# 104/104 [==============================] - ETA: 0s - loss: 1.3528 - accuracy: 0.5531 - f1_score: 0.5105
# Epoch 4: val_f1_score did not improve from 0.04391
# 104/104 [==============================] - 81s 774ms/step - loss: 1.3528 - accuracy: 0.5531 - f1_score: 0.5105 - val_loss: 4.2077 - val_accuracy: 0.1382 - val_f1_score: 0.0339 - lr: 1.0000e-04
# Epoch 5/150
# 104/104 [==============================] - ETA: 0s - loss: 1.1954 - accuracy: 0.6097 - f1_score: 0.5789
# Epoch 5: val_f1_score improved from 0.04391 to 0.11865, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 104/104 [==============================] - 84s 804ms/step - loss: 1.1954 - accuracy: 0.6097 - f1_score: 0.5789 - val_loss: 3.3332 - val_accuracy: 0.2076 - val_f1_score: 0.1186 - lr: 1.0000e-04
# Epoch 6/150
# 104/104 [==============================] - ETA: 0s - loss: 1.0138 - accuracy: 0.6648 - f1_score: 0.6414
# Epoch 6: val_f1_score improved from 0.11865 to 0.37819, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 85s 818ms/step - loss: 1.0138 - accuracy: 0.6648 - f1_score: 0.6414 - val_loss: 1.8147 - val_accuracy: 0.4284 - val_f1_score: 0.3782 - lr: 5.0000e-05
# Epoch 7/150
# 104/104 [==============================] - ETA: 0s - loss: 0.9100 - accuracy: 0.7015 - f1_score: 0.6808
# Epoch 7: val_f1_score improved from 0.37819 to 0.58331, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 86s 829ms/step - loss: 0.9100 - accuracy: 0.7015 - f1_score: 0.6808 - val_loss: 1.1540 - val_accuracy: 0.6168 - val_f1_score: 0.5833 - lr: 5.0000e-05
# Epoch 8/150
# 104/104 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.7274 - f1_score: 0.7074
# Epoch 8: val_f1_score improved from 0.58331 to 0.69315, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 79s 754ms/step - loss: 0.8409 - accuracy: 0.7274 - f1_score: 0.7074 - val_loss: 0.9149 - val_accuracy: 0.7024 - val_f1_score: 0.6932 - lr: 5.0000e-05
# Epoch 9/150
# 104/104 [==============================] - ETA: 0s - loss: 0.7599 - accuracy: 0.7476 - f1_score: 0.7299
# Epoch 9: val_f1_score did not improve from 0.69315
# 104/104 [==============================] - 82s 788ms/step - loss: 0.7599 - accuracy: 0.7476 - f1_score: 0.7299 - val_loss: 0.8711 - val_accuracy: 0.7156 - val_f1_score: 0.6899 - lr: 5.0000e-05
# Epoch 10/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6998 - accuracy: 0.7712 - f1_score: 0.7568
# Epoch 10: val_f1_score did not improve from 0.69315
# 104/104 [==============================] - 79s 753ms/step - loss: 0.6998 - accuracy: 0.7712 - f1_score: 0.7568 - val_loss: 0.8963 - val_accuracy: 0.7082 - val_f1_score: 0.6789 - lr: 5.0000e-05
# Epoch 11/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6306 - accuracy: 0.7932 - f1_score: 0.7795
# Epoch 11: val_f1_score did not improve from 0.69315
# 104/104 [==============================] - 72s 686ms/step - loss: 0.6306 - accuracy: 0.7932 - f1_score: 0.7795 - val_loss: 0.8964 - val_accuracy: 0.7140 - val_f1_score: 0.6898 - lr: 5.0000e-05
# Epoch 12/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5960 - accuracy: 0.8032 - f1_score: 0.7889
# Epoch 12: val_f1_score improved from 0.69315 to 0.72720, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 90s 860ms/step - loss: 0.5960 - accuracy: 0.8032 - f1_score: 0.7889 - val_loss: 0.7850 - val_accuracy: 0.7530 - val_f1_score: 0.7272 - lr: 5.0000e-05
# Epoch 13/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5472 - accuracy: 0.8167 - f1_score: 0.8029
# Epoch 13: val_f1_score improved from 0.72720 to 0.75062, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 76s 732ms/step - loss: 0.5472 - accuracy: 0.8167 - f1_score: 0.8029 - val_loss: 0.7309 - val_accuracy: 0.7646 - val_f1_score: 0.7506 - lr: 5.0000e-05
# Epoch 14/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.8317 - f1_score: 0.8214
# Epoch 14: val_f1_score improved from 0.75062 to 0.78060, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 82s 785ms/step - loss: 0.5089 - accuracy: 0.8317 - f1_score: 0.8214 - val_loss: 0.6357 - val_accuracy: 0.7962 - val_f1_score: 0.7806 - lr: 5.0000e-05
# Epoch 15/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4568 - accuracy: 0.8505 - f1_score: 0.8427
# Epoch 15: val_f1_score improved from 0.78060 to 0.79318, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 86s 820ms/step - loss: 0.4568 - accuracy: 0.8505 - f1_score: 0.8427 - val_loss: 0.6382 - val_accuracy: 0.8078 - val_f1_score: 0.7932 - lr: 5.0000e-05
# Epoch 16/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4075 - accuracy: 0.8680 - f1_score: 0.8608
# Epoch 16: val_f1_score improved from 0.79318 to 0.79467, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 80s 764ms/step - loss: 0.4075 - accuracy: 0.8680 - f1_score: 0.8608 - val_loss: 0.6040 - val_accuracy: 0.8070 - val_f1_score: 0.7947 - lr: 5.0000e-05
# Epoch 17/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.8727 - f1_score: 0.8640
# Epoch 17: val_f1_score improved from 0.79467 to 0.81709, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 76s 732ms/step - loss: 0.3894 - accuracy: 0.8727 - f1_score: 0.8640 - val_loss: 0.5776 - val_accuracy: 0.8263 - val_f1_score: 0.8171 - lr: 5.0000e-05
# Epoch 18/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8843 - f1_score: 0.8789
# Epoch 18: val_f1_score did not improve from 0.81709
# 104/104 [==============================] - 81s 778ms/step - loss: 0.3550 - accuracy: 0.8843 - f1_score: 0.8789 - val_loss: 0.5842 - val_accuracy: 0.8171 - val_f1_score: 0.8069 - lr: 5.0000e-05
# Epoch 19/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.8909 - f1_score: 0.8859
# Epoch 19: val_f1_score improved from 0.81709 to 0.82353, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 82s 790ms/step - loss: 0.3285 - accuracy: 0.8909 - f1_score: 0.8859 - val_loss: 0.5466 - val_accuracy: 0.8337 - val_f1_score: 0.8235 - lr: 5.0000e-05
# Epoch 20/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3170 - accuracy: 0.8963 - f1_score: 0.8950
# Epoch 20: val_f1_score improved from 0.82353 to 0.84703, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 98s 931ms/step - loss: 0.3170 - accuracy: 0.8963 - f1_score: 0.8950 - val_loss: 0.5084 - val_accuracy: 0.8518 - val_f1_score: 0.8470 - lr: 5.0000e-05
# Epoch 21/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.9065 - f1_score: 0.9047
# Epoch 21: val_f1_score did not improve from 0.84703
# 104/104 [==============================] - 90s 861ms/step - loss: 0.2859 - accuracy: 0.9065 - f1_score: 0.9047 - val_loss: 0.5097 - val_accuracy: 0.8456 - val_f1_score: 0.8383 - lr: 5.0000e-05
# Epoch 22/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9118 - f1_score: 0.9083
# Epoch 22: val_f1_score improved from 0.84703 to 0.85064, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 91s 870ms/step - loss: 0.2611 - accuracy: 0.9118 - f1_score: 0.9083 - val_loss: 0.4321 - val_accuracy: 0.8630 - val_f1_score: 0.8506 - lr: 5.0000e-05
# Epoch 23/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.9203 - f1_score: 0.9181
# Epoch 23: val_f1_score did not improve from 0.85064
# 104/104 [==============================] - 85s 811ms/step - loss: 0.2486 - accuracy: 0.9203 - f1_score: 0.9181 - val_loss: 0.4929 - val_accuracy: 0.8499 - val_f1_score: 0.8433 - lr: 5.0000e-05
# Epoch 24/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2300 - accuracy: 0.9237 - f1_score: 0.9217
# Epoch 24: val_f1_score improved from 0.85064 to 0.86999, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 79s 760ms/step - loss: 0.2300 - accuracy: 0.9237 - f1_score: 0.9217 - val_loss: 0.4242 - val_accuracy: 0.8715 - val_f1_score: 0.8700 - lr: 5.0000e-05
# Epoch 25/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2184 - accuracy: 0.9262 - f1_score: 0.9259
# Epoch 25: val_f1_score did not improve from 0.86999
# 104/104 [==============================] - 88s 844ms/step - loss: 0.2184 - accuracy: 0.9262 - f1_score: 0.9259 - val_loss: 0.4302 - val_accuracy: 0.8699 - val_f1_score: 0.8581 - lr: 5.0000e-05
# Epoch 26/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9320 - f1_score: 0.9301
# Epoch 26: val_f1_score did not improve from 0.86999
# 104/104 [==============================] - 84s 806ms/step - loss: 0.2081 - accuracy: 0.9320 - f1_score: 0.9301 - val_loss: 0.4443 - val_accuracy: 0.8626 - val_f1_score: 0.8585 - lr: 5.0000e-05
# Epoch 27/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9363 - f1_score: 0.9345
# Epoch 27: val_f1_score improved from 0.86999 to 0.87806, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 84s 797ms/step - loss: 0.1901 - accuracy: 0.9363 - f1_score: 0.9345 - val_loss: 0.4019 - val_accuracy: 0.8834 - val_f1_score: 0.8781 - lr: 5.0000e-05
# Epoch 28/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9360 - f1_score: 0.9352
# Epoch 28: val_f1_score did not improve from 0.87806
# 104/104 [==============================] - 82s 781ms/step - loss: 0.1879 - accuracy: 0.9360 - f1_score: 0.9352 - val_loss: 0.4293 - val_accuracy: 0.8680 - val_f1_score: 0.8576 - lr: 5.0000e-05
# Epoch 29/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9445 - f1_score: 0.9423
# Epoch 29: val_f1_score did not improve from 0.87806
# 104/104 [==============================] - 86s 821ms/step - loss: 0.1744 - accuracy: 0.9445 - f1_score: 0.9423 - val_loss: 0.4464 - val_accuracy: 0.8688 - val_f1_score: 0.8574 - lr: 5.0000e-05
# Epoch 30/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9444 - f1_score: 0.9434
# Epoch 30: val_f1_score did not improve from 0.87806
# 104/104 [==============================] - 75s 721ms/step - loss: 0.1681 - accuracy: 0.9444 - f1_score: 0.9434 - val_loss: 0.3965 - val_accuracy: 0.8800 - val_f1_score: 0.8763 - lr: 5.0000e-05
# Epoch 31/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1652 - accuracy: 0.9465 - f1_score: 0.9457
# Epoch 31: val_f1_score improved from 0.87806 to 0.88508, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 75s 714ms/step - loss: 0.1652 - accuracy: 0.9465 - f1_score: 0.9457 - val_loss: 0.3747 - val_accuracy: 0.8942 - val_f1_score: 0.8851 - lr: 5.0000e-05
# Epoch 32/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9537 - f1_score: 0.9515
# Epoch 32: val_f1_score improved from 0.88508 to 0.88782, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 70s 673ms/step - loss: 0.1426 - accuracy: 0.9537 - f1_score: 0.9515 - val_loss: 0.3616 - val_accuracy: 0.8904 - val_f1_score: 0.8878 - lr: 5.0000e-05
# Epoch 33/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9536 - f1_score: 0.9516
# Epoch 33: val_f1_score improved from 0.88782 to 0.89292, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 82s 783ms/step - loss: 0.1410 - accuracy: 0.9536 - f1_score: 0.9516 - val_loss: 0.3643 - val_accuracy: 0.8958 - val_f1_score: 0.8929 - lr: 5.0000e-05
# Epoch 34/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9560 - f1_score: 0.9559
# Epoch 34: val_f1_score improved from 0.89292 to 0.89720, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 74s 713ms/step - loss: 0.1332 - accuracy: 0.9560 - f1_score: 0.9559 - val_loss: 0.3848 - val_accuracy: 0.9031 - val_f1_score: 0.8972 - lr: 5.0000e-05
# Epoch 35/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9620 - f1_score: 0.9609
# Epoch 35: val_f1_score did not improve from 0.89720
# 104/104 [==============================] - 70s 665ms/step - loss: 0.1198 - accuracy: 0.9620 - f1_score: 0.9609 - val_loss: 0.3546 - val_accuracy: 0.9008 - val_f1_score: 0.8955 - lr: 5.0000e-05
# Epoch 36/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9537 - f1_score: 0.9538
# Epoch 36: val_f1_score improved from 0.89720 to 0.89765, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 78s 743ms/step - loss: 0.1361 - accuracy: 0.9537 - f1_score: 0.9538 - val_loss: 0.3784 - val_accuracy: 0.9008 - val_f1_score: 0.8976 - lr: 5.0000e-05
# Epoch 37/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9553 - f1_score: 0.9549
# Epoch 37: val_f1_score improved from 0.89765 to 0.89939, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 72s 691ms/step - loss: 0.1318 - accuracy: 0.9553 - f1_score: 0.9549 - val_loss: 0.3500 - val_accuracy: 0.9054 - val_f1_score: 0.8994 - lr: 5.0000e-05
# Epoch 38/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9612 - f1_score: 0.9610
# Epoch 38: val_f1_score improved from 0.89939 to 0.89952, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 79s 759ms/step - loss: 0.1194 - accuracy: 0.9612 - f1_score: 0.9610 - val_loss: 0.3481 - val_accuracy: 0.9051 - val_f1_score: 0.8995 - lr: 5.0000e-05
# Epoch 39/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9605 - f1_score: 0.9609
# Epoch 39: val_f1_score did not improve from 0.89952
# 104/104 [==============================] - 71s 683ms/step - loss: 0.1177 - accuracy: 0.9605 - f1_score: 0.9609 - val_loss: 0.4200 - val_accuracy: 0.8865 - val_f1_score: 0.8785 - lr: 5.0000e-05
# Epoch 40/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9608 - f1_score: 0.9614
# Epoch 40: val_f1_score improved from 0.89952 to 0.90397, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 77s 733ms/step - loss: 0.1188 - accuracy: 0.9608 - f1_score: 0.9614 - val_loss: 0.3312 - val_accuracy: 0.9070 - val_f1_score: 0.9040 - lr: 5.0000e-05
# Epoch 41/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9595 - f1_score: 0.9588
# Epoch 41: val_f1_score did not improve from 0.90397
# 104/104 [==============================] - 80s 764ms/step - loss: 0.1163 - accuracy: 0.9595 - f1_score: 0.9588 - val_loss: 0.3833 - val_accuracy: 0.8861 - val_f1_score: 0.8814 - lr: 5.0000e-05
# Epoch 42/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9619 - f1_score: 0.9609
# Epoch 42: val_f1_score did not improve from 0.90397
# 104/104 [==============================] - 77s 737ms/step - loss: 0.1159 - accuracy: 0.9619 - f1_score: 0.9609 - val_loss: 0.4111 - val_accuracy: 0.8854 - val_f1_score: 0.8760 - lr: 5.0000e-05
# Epoch 43/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9626 - f1_score: 0.9604
# Epoch 43: val_f1_score improved from 0.90397 to 0.90575, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 78s 745ms/step - loss: 0.1134 - accuracy: 0.9626 - f1_score: 0.9604 - val_loss: 0.3218 - val_accuracy: 0.9062 - val_f1_score: 0.9057 - lr: 5.0000e-05
# Epoch 44/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9656 - f1_score: 0.9653
# Epoch 44: val_f1_score did not improve from 0.90575
# 104/104 [==============================] - 73s 697ms/step - loss: 0.1003 - accuracy: 0.9656 - f1_score: 0.9653 - val_loss: 0.3454 - val_accuracy: 0.9058 - val_f1_score: 0.9045 - lr: 5.0000e-05
# Epoch 45/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9662 - f1_score: 0.9659
# Epoch 45: val_f1_score did not improve from 0.90575
# 104/104 [==============================] - 73s 693ms/step - loss: 0.1065 - accuracy: 0.9662 - f1_score: 0.9659 - val_loss: 0.3726 - val_accuracy: 0.8946 - val_f1_score: 0.8902 - lr: 5.0000e-05
# Epoch 46/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9680 - f1_score: 0.9677
# Epoch 46: val_f1_score improved from 0.90575 to 0.91015, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 82s 782ms/step - loss: 0.0927 - accuracy: 0.9680 - f1_score: 0.9677 - val_loss: 0.3002 - val_accuracy: 0.9159 - val_f1_score: 0.9101 - lr: 5.0000e-05
# Epoch 47/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9640 - f1_score: 0.9632
# Epoch 47: val_f1_score did not improve from 0.91015
# 104/104 [==============================] - 74s 706ms/step - loss: 0.1044 - accuracy: 0.9640 - f1_score: 0.9632 - val_loss: 0.3392 - val_accuracy: 0.8989 - val_f1_score: 0.8915 - lr: 5.0000e-05
# Epoch 48/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9675 - f1_score: 0.9665
# Epoch 48: val_f1_score did not improve from 0.91015
# 104/104 [==============================] - 73s 700ms/step - loss: 0.0949 - accuracy: 0.9675 - f1_score: 0.9665 - val_loss: 0.3695 - val_accuracy: 0.8985 - val_f1_score: 0.8928 - lr: 5.0000e-05
# Epoch 49/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9695 - f1_score: 0.9692
# Epoch 49: val_f1_score improved from 0.91015 to 0.91655, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 76s 725ms/step - loss: 0.0917 - accuracy: 0.9695 - f1_score: 0.9692 - val_loss: 0.3023 - val_accuracy: 0.9190 - val_f1_score: 0.9165 - lr: 5.0000e-05
# Epoch 50/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9716 - f1_score: 0.9709
# Epoch 50: val_f1_score did not improve from 0.91655
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 104/104 [==============================] - 80s 770ms/step - loss: 0.0831 - accuracy: 0.9716 - f1_score: 0.9709 - val_loss: 0.3164 - val_accuracy: 0.9186 - val_f1_score: 0.9147 - lr: 5.0000e-05
# Epoch 51/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9785 - f1_score: 0.9782
# Epoch 51: val_f1_score improved from 0.91655 to 0.92730, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 80s 765ms/step - loss: 0.0609 - accuracy: 0.9785 - f1_score: 0.9782 - val_loss: 0.2665 - val_accuracy: 0.9290 - val_f1_score: 0.9273 - lr: 2.5000e-05
# Epoch 52/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9848 - f1_score: 0.9845
# Epoch 52: val_f1_score improved from 0.92730 to 0.93672, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 79s 753ms/step - loss: 0.0463 - accuracy: 0.9848 - f1_score: 0.9845 - val_loss: 0.2458 - val_accuracy: 0.9386 - val_f1_score: 0.9367 - lr: 2.5000e-05
# Epoch 53/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9855 - f1_score: 0.9849
# Epoch 53: val_f1_score did not improve from 0.93672
# 104/104 [==============================] - 72s 687ms/step - loss: 0.0447 - accuracy: 0.9855 - f1_score: 0.9849 - val_loss: 0.2423 - val_accuracy: 0.9367 - val_f1_score: 0.9339 - lr: 2.5000e-05
# Epoch 54/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9866 - f1_score: 0.9863
# Epoch 54: val_f1_score did not improve from 0.93672
# 104/104 [==============================] - 78s 744ms/step - loss: 0.0427 - accuracy: 0.9866 - f1_score: 0.9863 - val_loss: 0.2499 - val_accuracy: 0.9325 - val_f1_score: 0.9294 - lr: 2.5000e-05
# Epoch 55/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9874 - f1_score: 0.9870
# Epoch 55: val_f1_score improved from 0.93672 to 0.93754, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 102s 981ms/step - loss: 0.0414 - accuracy: 0.9874 - f1_score: 0.9870 - val_loss: 0.2440 - val_accuracy: 0.9386 - val_f1_score: 0.9375 - lr: 2.5000e-05
# Epoch 56/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9869 - f1_score: 0.9866
# Epoch 56: val_f1_score did not improve from 0.93754
# 104/104 [==============================] - 69s 661ms/step - loss: 0.0392 - accuracy: 0.9869 - f1_score: 0.9866 - val_loss: 0.2435 - val_accuracy: 0.9382 - val_f1_score: 0.9373 - lr: 2.5000e-05
# Epoch 57/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9860 - f1_score: 0.9853
# Epoch 57: val_f1_score improved from 0.93754 to 0.93854, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 74s 712ms/step - loss: 0.0394 - accuracy: 0.9860 - f1_score: 0.9853 - val_loss: 0.2349 - val_accuracy: 0.9394 - val_f1_score: 0.9385 - lr: 2.5000e-05
# Epoch 58/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9880 - f1_score: 0.9876
# Epoch 58: val_f1_score did not improve from 0.93854
# 104/104 [==============================] - 70s 669ms/step - loss: 0.0370 - accuracy: 0.9880 - f1_score: 0.9876 - val_loss: 0.2460 - val_accuracy: 0.9355 - val_f1_score: 0.9366 - lr: 2.5000e-05
# Epoch 59/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9867 - f1_score: 0.9864
# Epoch 59: val_f1_score did not improve from 0.93854
# 104/104 [==============================] - 71s 678ms/step - loss: 0.0394 - accuracy: 0.9867 - f1_score: 0.9864 - val_loss: 0.2721 - val_accuracy: 0.9367 - val_f1_score: 0.9347 - lr: 2.5000e-05
# Epoch 60/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9884 - f1_score: 0.9885
# Epoch 60: val_f1_score improved from 0.93854 to 0.94611, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 73s 703ms/step - loss: 0.0341 - accuracy: 0.9884 - f1_score: 0.9885 - val_loss: 0.2338 - val_accuracy: 0.9456 - val_f1_score: 0.9461 - lr: 2.5000e-05
# Epoch 61/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9885 - f1_score: 0.9882
# Epoch 61: val_f1_score did not improve from 0.94611
# 104/104 [==============================] - 67s 642ms/step - loss: 0.0342 - accuracy: 0.9885 - f1_score: 0.9882 - val_loss: 0.2521 - val_accuracy: 0.9375 - val_f1_score: 0.9385 - lr: 2.5000e-05
# Epoch 62/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9882 - f1_score: 0.9877
# Epoch 62: val_f1_score did not improve from 0.94611
# 104/104 [==============================] - 69s 660ms/step - loss: 0.0361 - accuracy: 0.9882 - f1_score: 0.9877 - val_loss: 0.2626 - val_accuracy: 0.9286 - val_f1_score: 0.9251 - lr: 2.5000e-05
# Epoch 63/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9885 - f1_score: 0.9891
# Epoch 63: val_f1_score did not improve from 0.94611
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0369 - accuracy: 0.9885 - f1_score: 0.9891 - val_loss: 0.2423 - val_accuracy: 0.9371 - val_f1_score: 0.9367 - lr: 2.5000e-05
# Epoch 64/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9894 - f1_score: 0.9885
# Epoch 64: val_f1_score did not improve from 0.94611
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0311 - accuracy: 0.9894 - f1_score: 0.9885 - val_loss: 0.2557 - val_accuracy: 0.9352 - val_f1_score: 0.9349 - lr: 2.5000e-05
# Epoch 65/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9908 - f1_score: 0.9906
# Epoch 65: val_f1_score improved from 0.94611 to 0.94628, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 71s 680ms/step - loss: 0.0281 - accuracy: 0.9908 - f1_score: 0.9906 - val_loss: 0.2121 - val_accuracy: 0.9456 - val_f1_score: 0.9463 - lr: 1.2500e-05
# Epoch 66/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9910 - f1_score: 0.9910
# Epoch 66: val_f1_score did not improve from 0.94628
# 104/104 [==============================] - 67s 644ms/step - loss: 0.0252 - accuracy: 0.9910 - f1_score: 0.9910 - val_loss: 0.2379 - val_accuracy: 0.9429 - val_f1_score: 0.9413 - lr: 1.2500e-05
# Epoch 67/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9928 - f1_score: 0.9925
# Epoch 67: val_f1_score did not improve from 0.94628
# 104/104 [==============================] - 71s 675ms/step - loss: 0.0225 - accuracy: 0.9928 - f1_score: 0.9925 - val_loss: 0.2157 - val_accuracy: 0.9464 - val_f1_score: 0.9451 - lr: 1.2500e-05
# Epoch 68/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9933 - f1_score: 0.9933
# Epoch 68: val_f1_score did not improve from 0.94628
# 104/104 [==============================] - 72s 691ms/step - loss: 0.0226 - accuracy: 0.9933 - f1_score: 0.9933 - val_loss: 0.2311 - val_accuracy: 0.9471 - val_f1_score: 0.9460 - lr: 1.2500e-05
# Epoch 69/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9924 - f1_score: 0.9918
# Epoch 69: val_f1_score did not improve from 0.94628
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 104/104 [==============================] - 84s 805ms/step - loss: 0.0240 - accuracy: 0.9924 - f1_score: 0.9918 - val_loss: 0.2317 - val_accuracy: 0.9452 - val_f1_score: 0.9445 - lr: 1.2500e-05
# Epoch 70/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9928 - f1_score: 0.9927
# Epoch 70: val_f1_score did not improve from 0.94628
# 104/104 [==============================] - 93s 890ms/step - loss: 0.0209 - accuracy: 0.9928 - f1_score: 0.9927 - val_loss: 0.2274 - val_accuracy: 0.9452 - val_f1_score: 0.9449 - lr: 6.2500e-06
# Epoch 71/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9941 - f1_score: 0.9940
# Epoch 71: val_f1_score improved from 0.94628 to 0.94673, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 79s 756ms/step - loss: 0.0191 - accuracy: 0.9941 - f1_score: 0.9940 - val_loss: 0.2262 - val_accuracy: 0.9494 - val_f1_score: 0.9467 - lr: 6.2500e-06
# Epoch 72/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9936 - f1_score: 0.9929
# Epoch 72: val_f1_score did not improve from 0.94673
# 104/104 [==============================] - 75s 720ms/step - loss: 0.0186 - accuracy: 0.9936 - f1_score: 0.9929 - val_loss: 0.2170 - val_accuracy: 0.9460 - val_f1_score: 0.9447 - lr: 6.2500e-06
# Epoch 73/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9946 - f1_score: 0.9944
# Epoch 73: val_f1_score did not improve from 0.94673
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 104/104 [==============================] - 68s 650ms/step - loss: 0.0159 - accuracy: 0.9946 - f1_score: 0.9944 - val_loss: 0.2245 - val_accuracy: 0.9444 - val_f1_score: 0.9427 - lr: 6.2500e-06
# Epoch 74/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9943 - f1_score: 0.9942
# Epoch 74: val_f1_score improved from 0.94673 to 0.94951, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 72s 693ms/step - loss: 0.0163 - accuracy: 0.9943 - f1_score: 0.9942 - val_loss: 0.2226 - val_accuracy: 0.9518 - val_f1_score: 0.9495 - lr: 3.1250e-06
# Epoch 75/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9950 - f1_score: 0.9950
# Epoch 75: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 66s 636ms/step - loss: 0.0151 - accuracy: 0.9950 - f1_score: 0.9950 - val_loss: 0.2234 - val_accuracy: 0.9471 - val_f1_score: 0.9459 - lr: 3.1250e-06
# Epoch 76/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9951 - f1_score: 0.9952
# Epoch 76: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 68s 650ms/step - loss: 0.0172 - accuracy: 0.9951 - f1_score: 0.9952 - val_loss: 0.2169 - val_accuracy: 0.9471 - val_f1_score: 0.9459 - lr: 3.1250e-06
# Epoch 77/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9940 - f1_score: 0.9940
# Epoch 77: val_f1_score did not improve from 0.94951
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 104/104 [==============================] - 68s 656ms/step - loss: 0.0175 - accuracy: 0.9940 - f1_score: 0.9940 - val_loss: 0.2188 - val_accuracy: 0.9483 - val_f1_score: 0.9480 - lr: 3.1250e-06
# Epoch 78/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9959 - f1_score: 0.9957
# Epoch 78: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 69s 662ms/step - loss: 0.0136 - accuracy: 0.9959 - f1_score: 0.9957 - val_loss: 0.2128 - val_accuracy: 0.9467 - val_f1_score: 0.9458 - lr: 1.5625e-06
# Epoch 79/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9961 - f1_score: 0.9960
# Epoch 79: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 67s 641ms/step - loss: 0.0144 - accuracy: 0.9961 - f1_score: 0.9960 - val_loss: 0.2128 - val_accuracy: 0.9479 - val_f1_score: 0.9458 - lr: 1.5625e-06
# Epoch 80/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9959 - f1_score: 0.9955
# Epoch 80: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 68s 650ms/step - loss: 0.0138 - accuracy: 0.9959 - f1_score: 0.9955 - val_loss: 0.2169 - val_accuracy: 0.9479 - val_f1_score: 0.9474 - lr: 1.5625e-06
# Epoch 81/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9954 - f1_score: 0.9954
# Epoch 81: val_f1_score did not improve from 0.94951
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 104/104 [==============================] - 68s 655ms/step - loss: 0.0147 - accuracy: 0.9954 - f1_score: 0.9954 - val_loss: 0.2180 - val_accuracy: 0.9475 - val_f1_score: 0.9466 - lr: 1.5625e-06
# Epoch 82/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9955 - f1_score: 0.9950
# Epoch 82: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 69s 659ms/step - loss: 0.0138 - accuracy: 0.9955 - f1_score: 0.9950 - val_loss: 0.2127 - val_accuracy: 0.9456 - val_f1_score: 0.9397 - lr: 7.8125e-07
# Epoch 83/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9949 - f1_score: 0.9947
# Epoch 83: val_f1_score did not improve from 0.94951
# 104/104 [==============================] - 68s 651ms/step - loss: 0.0150 - accuracy: 0.9949 - f1_score: 0.9947 - val_loss: 0.2285 - val_accuracy: 0.9467 - val_f1_score: 0.9435 - lr: 7.8125e-07
# Epoch 84/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9951 - f1_score: 0.9949
# Epoch 84: val_f1_score improved from 0.94951 to 0.95173, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 71s 678ms/step - loss: 0.0139 - accuracy: 0.9951 - f1_score: 0.9949 - val_loss: 0.2063 - val_accuracy: 0.9537 - val_f1_score: 0.9517 - lr: 7.8125e-07
# Epoch 85/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9952 - f1_score: 0.9948
# Epoch 85: val_f1_score improved from 0.95173 to 0.95214, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 71s 685ms/step - loss: 0.0135 - accuracy: 0.9952 - f1_score: 0.9948 - val_loss: 0.2184 - val_accuracy: 0.9506 - val_f1_score: 0.9521 - lr: 7.8125e-07
# Epoch 86/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9960 - f1_score: 0.9961
# Epoch 86: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 69s 657ms/step - loss: 0.0134 - accuracy: 0.9960 - f1_score: 0.9961 - val_loss: 0.2084 - val_accuracy: 0.9483 - val_f1_score: 0.9456 - lr: 7.8125e-07
# Epoch 87/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9965 - f1_score: 0.9963
# Epoch 87: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 67s 644ms/step - loss: 0.0118 - accuracy: 0.9965 - f1_score: 0.9963 - val_loss: 0.2117 - val_accuracy: 0.9494 - val_f1_score: 0.9466 - lr: 7.8125e-07
# Epoch 88/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9954 - f1_score: 0.9950
# Epoch 88: val_f1_score did not improve from 0.95214
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 104/104 [==============================] - 68s 648ms/step - loss: 0.0141 - accuracy: 0.9954 - f1_score: 0.9950 - val_loss: 0.2166 - val_accuracy: 0.9475 - val_f1_score: 0.9425 - lr: 7.8125e-07
# Epoch 89/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9951 - f1_score: 0.9945
# Epoch 89: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 69s 656ms/step - loss: 0.0131 - accuracy: 0.9951 - f1_score: 0.9945 - val_loss: 0.2252 - val_accuracy: 0.9514 - val_f1_score: 0.9488 - lr: 3.9062e-07
# Epoch 90/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9952 - f1_score: 0.9953
# Epoch 90: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 68s 652ms/step - loss: 0.0140 - accuracy: 0.9952 - f1_score: 0.9953 - val_loss: 0.2197 - val_accuracy: 0.9498 - val_f1_score: 0.9491 - lr: 3.9062e-07
# Epoch 91/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9959 - f1_score: 0.9959
# Epoch 91: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 66s 636ms/step - loss: 0.0130 - accuracy: 0.9959 - f1_score: 0.9959 - val_loss: 0.2044 - val_accuracy: 0.9471 - val_f1_score: 0.9456 - lr: 3.9062e-07
# Epoch 92/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9952 - f1_score: 0.9949
# Epoch 92: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0130 - accuracy: 0.9952 - f1_score: 0.9949 - val_loss: 0.2268 - val_accuracy: 0.9471 - val_f1_score: 0.9463 - lr: 3.9062e-07
# Epoch 93/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9950 - f1_score: 0.9953
# Epoch 93: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 67s 645ms/step - loss: 0.0149 - accuracy: 0.9950 - f1_score: 0.9953 - val_loss: 0.2018 - val_accuracy: 0.9525 - val_f1_score: 0.9519 - lr: 3.9062e-07
# Epoch 94/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9960 - f1_score: 0.9960
# Epoch 94: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 69s 661ms/step - loss: 0.0116 - accuracy: 0.9960 - f1_score: 0.9960 - val_loss: 0.2198 - val_accuracy: 0.9471 - val_f1_score: 0.9448 - lr: 3.9062e-07
# Epoch 95/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9961 - f1_score: 0.9956
# Epoch 95: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 67s 643ms/step - loss: 0.0119 - accuracy: 0.9961 - f1_score: 0.9956 - val_loss: 0.2147 - val_accuracy: 0.9502 - val_f1_score: 0.9474 - lr: 3.9062e-07
# Epoch 96/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9957 - f1_score: 0.9956
# Epoch 96: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 67s 646ms/step - loss: 0.0141 - accuracy: 0.9957 - f1_score: 0.9956 - val_loss: 0.2208 - val_accuracy: 0.9452 - val_f1_score: 0.9440 - lr: 3.9062e-07
# Epoch 97/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9959 - f1_score: 0.9953
# Epoch 97: val_f1_score did not improve from 0.95214
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 104/104 [==============================] - 67s 645ms/step - loss: 0.0127 - accuracy: 0.9959 - f1_score: 0.9953 - val_loss: 0.2060 - val_accuracy: 0.9498 - val_f1_score: 0.9486 - lr: 3.9062e-07
# Epoch 98/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9960 - f1_score: 0.9955
# Epoch 98: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 68s 653ms/step - loss: 0.0135 - accuracy: 0.9960 - f1_score: 0.9955 - val_loss: 0.2174 - val_accuracy: 0.9433 - val_f1_score: 0.9416 - lr: 1.9531e-07
# Epoch 99/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9957 - f1_score: 0.9954
# Epoch 99: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 88s 840ms/step - loss: 0.0128 - accuracy: 0.9957 - f1_score: 0.9954 - val_loss: 0.2159 - val_accuracy: 0.9483 - val_f1_score: 0.9480 - lr: 1.9531e-07
# Epoch 100/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9959 - f1_score: 0.9957
# Epoch 100: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 89s 851ms/step - loss: 0.0135 - accuracy: 0.9959 - f1_score: 0.9957 - val_loss: 0.2171 - val_accuracy: 0.9452 - val_f1_score: 0.9455 - lr: 1.9531e-07
# Epoch 101/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9967 - f1_score: 0.9962
# Epoch 101: val_f1_score did not improve from 0.95214
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 1e-07.
# 104/104 [==============================] - 89s 857ms/step - loss: 0.0114 - accuracy: 0.9967 - f1_score: 0.9962 - val_loss: 0.2110 - val_accuracy: 0.9471 - val_f1_score: 0.9458 - lr: 1.9531e-07
# Epoch 102/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9961 - f1_score: 0.9961
# Epoch 102: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 86s 829ms/step - loss: 0.0131 - accuracy: 0.9961 - f1_score: 0.9961 - val_loss: 0.2091 - val_accuracy: 0.9525 - val_f1_score: 0.9518 - lr: 1.0000e-07
# Epoch 103/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9952 - f1_score: 0.9948
# Epoch 103: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 91s 870ms/step - loss: 0.0133 - accuracy: 0.9952 - f1_score: 0.9948 - val_loss: 0.2268 - val_accuracy: 0.9483 - val_f1_score: 0.9480 - lr: 1.0000e-07
# Epoch 104/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9963 - f1_score: 0.9960
# Epoch 104: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 89s 849ms/step - loss: 0.0110 - accuracy: 0.9963 - f1_score: 0.9960 - val_loss: 0.2156 - val_accuracy: 0.9460 - val_f1_score: 0.9453 - lr: 1.0000e-07
# Epoch 105/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9962 - f1_score: 0.9956
# Epoch 105: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 86s 823ms/step - loss: 0.0137 - accuracy: 0.9962 - f1_score: 0.9956 - val_loss: 0.2251 - val_accuracy: 0.9464 - val_f1_score: 0.9466 - lr: 1.0000e-07
# Epoch 106/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9967 - f1_score: 0.9967
# Epoch 106: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 90s 859ms/step - loss: 0.0117 - accuracy: 0.9967 - f1_score: 0.9967 - val_loss: 0.2147 - val_accuracy: 0.9471 - val_f1_score: 0.9458 - lr: 1.0000e-07
# Epoch 107/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9964 - f1_score: 0.9961
# Epoch 107: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 88s 844ms/step - loss: 0.0122 - accuracy: 0.9964 - f1_score: 0.9961 - val_loss: 0.2322 - val_accuracy: 0.9437 - val_f1_score: 0.9417 - lr: 1.0000e-07
# Epoch 108/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9971 - f1_score: 0.9971
# Epoch 108: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 87s 830ms/step - loss: 0.0110 - accuracy: 0.9971 - f1_score: 0.9971 - val_loss: 0.2215 - val_accuracy: 0.9479 - val_f1_score: 0.9479 - lr: 1.0000e-07
# Epoch 109/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9961 - f1_score: 0.9960
# Epoch 109: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 95s 909ms/step - loss: 0.0132 - accuracy: 0.9961 - f1_score: 0.9960 - val_loss: 0.2157 - val_accuracy: 0.9460 - val_f1_score: 0.9458 - lr: 1.0000e-07
# Epoch 110/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9962 - f1_score: 0.9960
# Epoch 110: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 96s 921ms/step - loss: 0.0115 - accuracy: 0.9962 - f1_score: 0.9960 - val_loss: 0.2034 - val_accuracy: 0.9487 - val_f1_score: 0.9440 - lr: 1.0000e-07
# Epoch 111/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9960 - f1_score: 0.9958
# Epoch 111: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 96s 921ms/step - loss: 0.0125 - accuracy: 0.9960 - f1_score: 0.9958 - val_loss: 0.2222 - val_accuracy: 0.9479 - val_f1_score: 0.9465 - lr: 1.0000e-07
# Epoch 112/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9957 - f1_score: 0.9951
# Epoch 112: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 94s 903ms/step - loss: 0.0126 - accuracy: 0.9957 - f1_score: 0.9951 - val_loss: 0.2207 - val_accuracy: 0.9506 - val_f1_score: 0.9500 - lr: 1.0000e-07
# Epoch 113/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9952 - f1_score: 0.9948
# Epoch 113: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 96s 922ms/step - loss: 0.0130 - accuracy: 0.9952 - f1_score: 0.9948 - val_loss: 0.2302 - val_accuracy: 0.9452 - val_f1_score: 0.9446 - lr: 1.0000e-07
# Epoch 114/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9964 - f1_score: 0.9958
# Epoch 114: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 93s 887ms/step - loss: 0.0118 - accuracy: 0.9964 - f1_score: 0.9958 - val_loss: 0.1992 - val_accuracy: 0.9518 - val_f1_score: 0.9504 - lr: 1.0000e-07
# Epoch 115/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9970 - f1_score: 0.9972
# Epoch 115: val_f1_score did not improve from 0.95214
# 104/104 [==============================] - 95s 909ms/step - loss: 0.0115 - accuracy: 0.9970 - f1_score: 0.9972 - val_loss: 0.2254 - val_accuracy: 0.9437 - val_f1_score: 0.9451 - lr: 1.0000e-07
# Epoch 116/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9965 - f1_score: 0.9966
# Epoch 116: val_f1_score improved from 0.95214 to 0.95260, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 97s 930ms/step - loss: 0.0119 - accuracy: 0.9965 - f1_score: 0.9966 - val_loss: 0.1982 - val_accuracy: 0.9525 - val_f1_score: 0.9526 - lr: 1.0000e-07
# Epoch 117/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9963 - f1_score: 0.9958
# Epoch 117: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 93s 889ms/step - loss: 0.0113 - accuracy: 0.9963 - f1_score: 0.9958 - val_loss: 0.2043 - val_accuracy: 0.9483 - val_f1_score: 0.9484 - lr: 1.0000e-07
# Epoch 118/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9958 - f1_score: 0.9959
# Epoch 118: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 94s 902ms/step - loss: 0.0137 - accuracy: 0.9958 - f1_score: 0.9959 - val_loss: 0.2227 - val_accuracy: 0.9491 - val_f1_score: 0.9460 - lr: 1.0000e-07
# Epoch 119/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9959 - f1_score: 0.9962
# Epoch 119: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 94s 902ms/step - loss: 0.0134 - accuracy: 0.9959 - f1_score: 0.9962 - val_loss: 0.2082 - val_accuracy: 0.9521 - val_f1_score: 0.9503 - lr: 1.0000e-07
# Epoch 120/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9965 - f1_score: 0.9965
# Epoch 120: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 96s 925ms/step - loss: 0.0123 - accuracy: 0.9965 - f1_score: 0.9965 - val_loss: 0.2154 - val_accuracy: 0.9460 - val_f1_score: 0.9453 - lr: 1.0000e-07
# Epoch 121/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9961 - f1_score: 0.9961
# Epoch 121: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 79s 754ms/step - loss: 0.0133 - accuracy: 0.9961 - f1_score: 0.9961 - val_loss: 0.2180 - val_accuracy: 0.9491 - val_f1_score: 0.9473 - lr: 1.0000e-07
# Epoch 122/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9958 - f1_score: 0.9954
# Epoch 122: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 71s 683ms/step - loss: 0.0131 - accuracy: 0.9958 - f1_score: 0.9954 - val_loss: 0.2245 - val_accuracy: 0.9475 - val_f1_score: 0.9461 - lr: 1.0000e-07
# Epoch 123/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9964 - f1_score: 0.9964
# Epoch 123: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 72s 685ms/step - loss: 0.0118 - accuracy: 0.9964 - f1_score: 0.9964 - val_loss: 0.2292 - val_accuracy: 0.9494 - val_f1_score: 0.9490 - lr: 1.0000e-07
# Epoch 124/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9962 - f1_score: 0.9964
# Epoch 124: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 73s 702ms/step - loss: 0.0121 - accuracy: 0.9962 - f1_score: 0.9964 - val_loss: 0.2202 - val_accuracy: 0.9494 - val_f1_score: 0.9457 - lr: 1.0000e-07
# Epoch 125/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9955 - f1_score: 0.9953
# Epoch 125: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 74s 712ms/step - loss: 0.0135 - accuracy: 0.9955 - f1_score: 0.9953 - val_loss: 0.2199 - val_accuracy: 0.9502 - val_f1_score: 0.9498 - lr: 1.0000e-07
# Epoch 126/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9954 - f1_score: 0.9952
# Epoch 126: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 74s 706ms/step - loss: 0.0134 - accuracy: 0.9954 - f1_score: 0.9952 - val_loss: 0.2255 - val_accuracy: 0.9429 - val_f1_score: 0.9427 - lr: 1.0000e-07
# Epoch 127/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9961 - f1_score: 0.9961
# Epoch 127: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 73s 696ms/step - loss: 0.0124 - accuracy: 0.9961 - f1_score: 0.9961 - val_loss: 0.2045 - val_accuracy: 0.9491 - val_f1_score: 0.9471 - lr: 1.0000e-07
# Epoch 128/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9949 - f1_score: 0.9947
# Epoch 128: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 81s 783ms/step - loss: 0.0139 - accuracy: 0.9949 - f1_score: 0.9947 - val_loss: 0.2225 - val_accuracy: 0.9471 - val_f1_score: 0.9448 - lr: 1.0000e-07
# Epoch 129/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9962 - f1_score: 0.9962
# Epoch 129: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 75s 719ms/step - loss: 0.0121 - accuracy: 0.9962 - f1_score: 0.9962 - val_loss: 0.2097 - val_accuracy: 0.9494 - val_f1_score: 0.9472 - lr: 1.0000e-07
# Epoch 130/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9953 - f1_score: 0.9947
# Epoch 130: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 75s 717ms/step - loss: 0.0135 - accuracy: 0.9953 - f1_score: 0.9947 - val_loss: 0.1860 - val_accuracy: 0.9494 - val_f1_score: 0.9479 - lr: 1.0000e-07
# Epoch 131/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9962 - f1_score: 0.9959
# Epoch 131: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 77s 736ms/step - loss: 0.0114 - accuracy: 0.9962 - f1_score: 0.9959 - val_loss: 0.2145 - val_accuracy: 0.9502 - val_f1_score: 0.9506 - lr: 1.0000e-07
# Epoch 132/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9955 - f1_score: 0.9950
# Epoch 132: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 75s 718ms/step - loss: 0.0116 - accuracy: 0.9955 - f1_score: 0.9950 - val_loss: 0.2172 - val_accuracy: 0.9475 - val_f1_score: 0.9467 - lr: 1.0000e-07
# Epoch 133/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9955 - f1_score: 0.9950
# Epoch 133: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 74s 705ms/step - loss: 0.0138 - accuracy: 0.9955 - f1_score: 0.9950 - val_loss: 0.2107 - val_accuracy: 0.9460 - val_f1_score: 0.9432 - lr: 1.0000e-07
# Epoch 134/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9952 - f1_score: 0.9945
# Epoch 134: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 75s 722ms/step - loss: 0.0128 - accuracy: 0.9952 - f1_score: 0.9945 - val_loss: 0.2139 - val_accuracy: 0.9475 - val_f1_score: 0.9456 - lr: 1.0000e-07
# Epoch 135/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9957 - f1_score: 0.9953
# Epoch 135: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 80s 768ms/step - loss: 0.0136 - accuracy: 0.9957 - f1_score: 0.9953 - val_loss: 0.2197 - val_accuracy: 0.9498 - val_f1_score: 0.9477 - lr: 1.0000e-07
# Epoch 136/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9951 - f1_score: 0.9952
# Epoch 136: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 76s 729ms/step - loss: 0.0125 - accuracy: 0.9951 - f1_score: 0.9952 - val_loss: 0.2194 - val_accuracy: 0.9467 - val_f1_score: 0.9450 - lr: 1.0000e-07
# Epoch 137/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9972 - f1_score: 0.9970
# Epoch 137: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 76s 728ms/step - loss: 0.0108 - accuracy: 0.9972 - f1_score: 0.9970 - val_loss: 0.2186 - val_accuracy: 0.9409 - val_f1_score: 0.9397 - lr: 1.0000e-07
# Epoch 138/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9971 - f1_score: 0.9969
# Epoch 138: val_f1_score did not improve from 0.95260
# 104/104 [==============================] - 76s 726ms/step - loss: 0.0115 - accuracy: 0.9971 - f1_score: 0.9969 - val_loss: 0.2212 - val_accuracy: 0.9491 - val_f1_score: 0.9484 - lr: 1.0000e-07
# Epoch 139/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9965 - f1_score: 0.9961
# Epoch 139: val_f1_score improved from 0.95260 to 0.95463, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3_.h5
# 104/104 [==============================] - 79s 763ms/step - loss: 0.0115 - accuracy: 0.9965 - f1_score: 0.9961 - val_loss: 0.2115 - val_accuracy: 0.9537 - val_f1_score: 0.9546 - lr: 1.0000e-07
# Epoch 140/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9961 - f1_score: 0.9960
# Epoch 140: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 81s 781ms/step - loss: 0.0125 - accuracy: 0.9961 - f1_score: 0.9960 - val_loss: 0.1929 - val_accuracy: 0.9533 - val_f1_score: 0.9539 - lr: 1.0000e-07
# Epoch 141/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9972 - f1_score: 0.9971
# Epoch 141: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 75s 724ms/step - loss: 0.0123 - accuracy: 0.9972 - f1_score: 0.9971 - val_loss: 0.2123 - val_accuracy: 0.9483 - val_f1_score: 0.9468 - lr: 1.0000e-07
# Epoch 142/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9954 - f1_score: 0.9953
# Epoch 142: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 73s 701ms/step - loss: 0.0126 - accuracy: 0.9954 - f1_score: 0.9953 - val_loss: 0.2136 - val_accuracy: 0.9487 - val_f1_score: 0.9474 - lr: 1.0000e-07
# Epoch 143/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9961 - f1_score: 0.9960
# Epoch 143: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 75s 715ms/step - loss: 0.0124 - accuracy: 0.9961 - f1_score: 0.9960 - val_loss: 0.2347 - val_accuracy: 0.9444 - val_f1_score: 0.9443 - lr: 1.0000e-07
# Epoch 144/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9963 - f1_score: 0.9963
# Epoch 144: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 80s 766ms/step - loss: 0.0112 - accuracy: 0.9963 - f1_score: 0.9963 - val_loss: 0.2052 - val_accuracy: 0.9514 - val_f1_score: 0.9491 - lr: 1.0000e-07
# Epoch 145/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9963 - f1_score: 0.9962
# Epoch 145: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 75s 718ms/step - loss: 0.0112 - accuracy: 0.9963 - f1_score: 0.9962 - val_loss: 0.2252 - val_accuracy: 0.9487 - val_f1_score: 0.9477 - lr: 1.0000e-07
# Epoch 146/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9964 - f1_score: 0.9960
# Epoch 146: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 75s 718ms/step - loss: 0.0119 - accuracy: 0.9964 - f1_score: 0.9960 - val_loss: 0.2074 - val_accuracy: 0.9514 - val_f1_score: 0.9495 - lr: 1.0000e-07
# Epoch 147/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9965 - f1_score: 0.9962
# Epoch 147: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 76s 731ms/step - loss: 0.0112 - accuracy: 0.9965 - f1_score: 0.9962 - val_loss: 0.2335 - val_accuracy: 0.9502 - val_f1_score: 0.9474 - lr: 1.0000e-07
# Epoch 148/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9957 - f1_score: 0.9958
# Epoch 148: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 78s 749ms/step - loss: 0.0123 - accuracy: 0.9957 - f1_score: 0.9958 - val_loss: 0.2336 - val_accuracy: 0.9444 - val_f1_score: 0.9428 - lr: 1.0000e-07
# Epoch 149/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9958 - f1_score: 0.9957
# Epoch 149: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 80s 764ms/step - loss: 0.0130 - accuracy: 0.9958 - f1_score: 0.9957 - val_loss: 0.2135 - val_accuracy: 0.9487 - val_f1_score: 0.9510 - lr: 1.0000e-07
# Epoch 150/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9960 - f1_score: 0.9959
# Epoch 150: val_f1_score did not improve from 0.95463
# 104/104 [==============================] - 75s 717ms/step - loss: 0.0129 - accuracy: 0.9960 - f1_score: 0.9959 - val_loss: 0.2244 - val_accuracy: 0.9460 - val_f1_score: 0.9451 - lr: 1.0000e-07

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 8s 185ms/step - loss: 0.6120 - accuracy: 0.8379 - f1_score: 0.8303
#     model_name  test_loss  test_accuracy  test_f1_score
# 0  InceptionV3   0.611982       0.837904       0.830269

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 7s 167ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.675497  0.784615  0.725979   130.000000
# 1              0.776786  0.870000  0.820755   100.000000
# 2              1.000000  0.755556  0.860759    90.000000
# 3              0.873563  0.752475  0.808511   101.000000
# 4              0.820717  0.876596  0.847737   470.000000
# 5              0.820717  0.814229  0.817460   253.000000
# 6              0.849398  0.810345  0.829412   174.000000
# 7              0.861042  0.805104  0.832134   431.000000
# 8              0.760766  0.726027  0.742991   219.000000
# 9              0.861057  0.914761  0.887097   481.000000
# 10             0.828645  0.830769  0.829706   390.000000
# 11             0.904959  0.862205  0.883065   254.000000
# 12             0.907895  0.907895  0.907895   152.000000
# accuracy       0.837904  0.837904  0.837904     0.837904
# macro avg      0.841618  0.823891  0.830269  3245.000000
# weighted avg   0.840620  0.837904  0.837933  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test, 
                                       test_loss=test_loss)
# Out:
#     Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  InceptionV3  0.837904         0.841618      0.823891        0.830269
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0             0.84062         0.837904           0.837933  0.611982

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.83790
# 1      Macro Precision  0.84162
# 2         Macro Recall  0.82389
# 3       Macro F1-Score  0.83027
# 4            Macro FPR  0.01389
# 5            Macro FNR  0.17611
# 6            Macro FDR  0.15838
# 7            Macro NPV  0.98621
# 8   Weighted Precision  0.84062
# 9      Weighted Recall  0.83790
# 10   Weighted F1-Score  0.83793
# 11        Weighted FPR  0.01849
# 12        Weighted FNR  0.16210
# 13        Weighted FDR  0.15938
# 14        Weighted NPV  0.98282
