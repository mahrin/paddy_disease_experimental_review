# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'parallelViT'#'T2TViT'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, 'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 150 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE ='basic' #'all' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
# PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\parallelViT
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\parallelViT\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\parallelViT\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_19340\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'_.h5'
    ## Criteria for early stopping
#    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1) 

    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00001   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################
    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    return saved_best_model_name, train_history

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    #########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00001   # Lower bound on the learning rate.
    )

    my_callbacks = [ best_weight_callback, reduce_LR]#, EarlyStop_callback]  , reduce_LRbest_model_callback,
    ##########################################################################################################
    start_time = time.time()    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return  PATH_BEST_WEIGHT_SAVE, train_history , total_time#model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None, model_name="default_name", SAVE_RESULTS = False):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model, SAVE_RESULTS=False):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss, model_name="default_name", SAVE_RESULTS=False ):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %%
from parallel_vit import ViT as parallelViT
from tensorflow.keras.losses import CategoricalCrossentropy

def get_parallel_vit(): 
    model = parallelViT( #v4 --Improving gradually with each epoch val_loss: 2.2053 - val_accuracy: 0.2600 - val_f1_score: 0.1379
        image_size = max(MODEL_INPUT_SIZE[0], MODEL_INPUT_SIZE[1]),
        patch_size = 16, # original 16
        num_classes = NUM_CLASSES,
        dim = 512,#original 512
        depth = 6,
        heads = 20, # original 8
        mlp_dim = 1024,#original 1024
        num_parallel_branches = 2,  # in paper, they claimed 2 was optimal
        dropout = 0.2,
        emb_dropout = 0.2
    )

    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss=CategoricalCrossentropy(from_logits=True), 
                  run_eagerly=True,
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)

    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
model = get_parallel_vit()
# model = get_T2TViT()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point
PATH_BEST_WEIGHT_SAVE, train_history, total_time  = fit_and_save_best_model_vit(model_name, model)
# Out:
# Epoch 1/150
# 104/104 [==============================] - ETA: 0s - loss: 2.6325 - accuracy: 0.1388 - f1_score: 0.0713
# Epoch 1: val_f1_score improved from -inf to 0.05319, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 269s 3s/step - loss: 2.6325 - accuracy: 0.1388 - f1_score: 0.0713 - val_loss: 2.3408 - val_accuracy: 0.1741 - val_f1_score: 0.0532 - lr: 1.0000e-04
# Epoch 2/150
# 104/104 [==============================] - ETA: 0s - loss: 2.3888 - accuracy: 0.1670 - f1_score: 0.0964
# Epoch 2: val_f1_score improved from 0.05319 to 0.08563, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 258s 2s/step - loss: 2.3888 - accuracy: 0.1670 - f1_score: 0.0964 - val_loss: 2.2846 - val_accuracy: 0.2293 - val_f1_score: 0.0856 - lr: 1.0000e-04
# Epoch 3/150
# 104/104 [==============================] - ETA: 0s - loss: 2.2963 - accuracy: 0.2229 - f1_score: 0.1305
# Epoch 3: val_f1_score improved from 0.08563 to 0.12796, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 258s 2s/step - loss: 2.2963 - accuracy: 0.2229 - f1_score: 0.1305 - val_loss: 2.2398 - val_accuracy: 0.2682 - val_f1_score: 0.1280 - lr: 1.0000e-04
# Epoch 4/150
# 104/104 [==============================] - ETA: 0s - loss: 2.1972 - accuracy: 0.2613 - f1_score: 0.1559
# Epoch 4: val_f1_score improved from 0.12796 to 0.18177, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 258s 2s/step - loss: 2.1972 - accuracy: 0.2613 - f1_score: 0.1559 - val_loss: 2.0859 - val_accuracy: 0.2999 - val_f1_score: 0.1818 - lr: 1.0000e-04
# Epoch 5/150
# 104/104 [==============================] - ETA: 0s - loss: 2.1592 - accuracy: 0.2766 - f1_score: 0.1696
# Epoch 5: val_f1_score did not improve from 0.18177
# 104/104 [==============================] - 258s 2s/step - loss: 2.1592 - accuracy: 0.2766 - f1_score: 0.1696 - val_loss: 2.3852 - val_accuracy: 0.2486 - val_f1_score: 0.1389 - lr: 1.0000e-04
# Epoch 6/150
# 104/104 [==============================] - ETA: 0s - loss: 2.0374 - accuracy: 0.3175 - f1_score: 0.2177
# Epoch 6: val_f1_score improved from 0.18177 to 0.24608, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 259s 2s/step - loss: 2.0374 - accuracy: 0.3175 - f1_score: 0.2177 - val_loss: 2.0340 - val_accuracy: 0.3365 - val_f1_score: 0.2461 - lr: 1.0000e-04
# Epoch 7/150
# 104/104 [==============================] - ETA: 0s - loss: 1.9478 - accuracy: 0.3406 - f1_score: 0.2564
# Epoch 7: val_f1_score improved from 0.24608 to 0.25504, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 263s 3s/step - loss: 1.9478 - accuracy: 0.3406 - f1_score: 0.2564 - val_loss: 1.8845 - val_accuracy: 0.3717 - val_f1_score: 0.2550 - lr: 1.0000e-04
# Epoch 8/150
# 104/104 [==============================] - ETA: 0s - loss: 1.8568 - accuracy: 0.3739 - f1_score: 0.2981
# Epoch 8: val_f1_score improved from 0.25504 to 0.32301, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 262s 3s/step - loss: 1.8568 - accuracy: 0.3739 - f1_score: 0.2981 - val_loss: 1.7877 - val_accuracy: 0.4083 - val_f1_score: 0.3230 - lr: 1.0000e-04
# Epoch 9/150
# 104/104 [==============================] - ETA: 0s - loss: 1.7763 - accuracy: 0.4018 - f1_score: 0.3461
# Epoch 9: val_f1_score improved from 0.32301 to 0.36168, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 287s 3s/step - loss: 1.7763 - accuracy: 0.4018 - f1_score: 0.3461 - val_loss: 1.8497 - val_accuracy: 0.4226 - val_f1_score: 0.3617 - lr: 1.0000e-04
# Epoch 10/150
# 104/104 [==============================] - ETA: 0s - loss: 1.7037 - accuracy: 0.4312 - f1_score: 0.3835
# Epoch 10: val_f1_score improved from 0.36168 to 0.38390, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 281s 3s/step - loss: 1.7037 - accuracy: 0.4312 - f1_score: 0.3835 - val_loss: 1.7098 - val_accuracy: 0.4454 - val_f1_score: 0.3839 - lr: 1.0000e-04
# Epoch 11/150
# 104/104 [==============================] - ETA: 0s - loss: 1.6142 - accuracy: 0.4608 - f1_score: 0.4189
# Epoch 11: val_f1_score improved from 0.38390 to 0.41392, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 282s 3s/step - loss: 1.6142 - accuracy: 0.4608 - f1_score: 0.4189 - val_loss: 1.6268 - val_accuracy: 0.4786 - val_f1_score: 0.4139 - lr: 1.0000e-04
# Epoch 12/150
# 104/104 [==============================] - ETA: 0s - loss: 1.5468 - accuracy: 0.4852 - f1_score: 0.4454
# Epoch 12: val_f1_score improved from 0.41392 to 0.47732, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 283s 3s/step - loss: 1.5468 - accuracy: 0.4852 - f1_score: 0.4454 - val_loss: 1.5370 - val_accuracy: 0.5095 - val_f1_score: 0.4773 - lr: 1.0000e-04
# Epoch 13/150
# 104/104 [==============================] - ETA: 0s - loss: 1.4550 - accuracy: 0.5188 - f1_score: 0.4847
# Epoch 13: val_f1_score improved from 0.47732 to 0.50103, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 299s 3s/step - loss: 1.4550 - accuracy: 0.5188 - f1_score: 0.4847 - val_loss: 1.4490 - val_accuracy: 0.5369 - val_f1_score: 0.5010 - lr: 1.0000e-04
# Epoch 14/150
# 104/104 [==============================] - ETA: 0s - loss: 1.3733 - accuracy: 0.5497 - f1_score: 0.5170
# Epoch 14: val_f1_score improved from 0.50103 to 0.51312, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 318s 3s/step - loss: 1.3733 - accuracy: 0.5497 - f1_score: 0.5170 - val_loss: 1.3942 - val_accuracy: 0.5415 - val_f1_score: 0.5131 - lr: 1.0000e-04
# Epoch 15/150
# 104/104 [==============================] - ETA: 0s - loss: 1.2824 - accuracy: 0.5825 - f1_score: 0.5545
# Epoch 15: val_f1_score improved from 0.51312 to 0.54251, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 315s 3s/step - loss: 1.2824 - accuracy: 0.5825 - f1_score: 0.5545 - val_loss: 1.3429 - val_accuracy: 0.5631 - val_f1_score: 0.5425 - lr: 1.0000e-04
# Epoch 16/150
# 104/104 [==============================] - ETA: 0s - loss: 1.2410 - accuracy: 0.5944 - f1_score: 0.5673
# Epoch 16: val_f1_score improved from 0.54251 to 0.56643, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 317s 3s/step - loss: 1.2410 - accuracy: 0.5944 - f1_score: 0.5673 - val_loss: 1.2729 - val_accuracy: 0.5967 - val_f1_score: 0.5664 - lr: 1.0000e-04
# Epoch 17/150
# 104/104 [==============================] - ETA: 0s - loss: 1.1582 - accuracy: 0.6162 - f1_score: 0.5943
# Epoch 17: val_f1_score improved from 0.56643 to 0.61289, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 315s 3s/step - loss: 1.1582 - accuracy: 0.6162 - f1_score: 0.5943 - val_loss: 1.1411 - val_accuracy: 0.6345 - val_f1_score: 0.6129 - lr: 1.0000e-04
# Epoch 18/150
# 104/104 [==============================] - ETA: 0s - loss: 1.1136 - accuracy: 0.6361 - f1_score: 0.6165
# Epoch 18: val_f1_score improved from 0.61289 to 0.63016, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 313s 3s/step - loss: 1.1136 - accuracy: 0.6361 - f1_score: 0.6165 - val_loss: 1.0911 - val_accuracy: 0.6461 - val_f1_score: 0.6302 - lr: 1.0000e-04
# Epoch 19/150
# 104/104 [==============================] - ETA: 0s - loss: 1.0362 - accuracy: 0.6548 - f1_score: 0.6377
# Epoch 19: val_f1_score did not improve from 0.63016
# 104/104 [==============================] - 314s 3s/step - loss: 1.0362 - accuracy: 0.6548 - f1_score: 0.6377 - val_loss: 1.1065 - val_accuracy: 0.6426 - val_f1_score: 0.6170 - lr: 1.0000e-04
# Epoch 20/150
# 104/104 [==============================] - ETA: 0s - loss: 0.9782 - accuracy: 0.6786 - f1_score: 0.6687
# Epoch 20: val_f1_score improved from 0.63016 to 0.65892, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 316s 3s/step - loss: 0.9782 - accuracy: 0.6786 - f1_score: 0.6687 - val_loss: 1.1290 - val_accuracy: 0.6650 - val_f1_score: 0.6589 - lr: 1.0000e-04
# Epoch 21/150
# 104/104 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.6958 - f1_score: 0.6821
# Epoch 21: val_f1_score did not improve from 0.65892
# 104/104 [==============================] - 319s 3s/step - loss: 0.9244 - accuracy: 0.6958 - f1_score: 0.6821 - val_loss: 1.0338 - val_accuracy: 0.6727 - val_f1_score: 0.6581 - lr: 1.0000e-04
# Epoch 22/150
# 104/104 [==============================] - ETA: 0s - loss: 0.8620 - accuracy: 0.7149 - f1_score: 0.7039
# Epoch 22: val_f1_score improved from 0.65892 to 0.68620, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 287s 3s/step - loss: 0.8620 - accuracy: 0.7149 - f1_score: 0.7039 - val_loss: 1.0118 - val_accuracy: 0.6820 - val_f1_score: 0.6862 - lr: 1.0000e-04
# Epoch 23/150
# 104/104 [==============================] - ETA: 0s - loss: 0.8154 - accuracy: 0.7303 - f1_score: 0.7199
# Epoch 23: val_f1_score improved from 0.68620 to 0.70747, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 313s 3s/step - loss: 0.8154 - accuracy: 0.7303 - f1_score: 0.7199 - val_loss: 0.9314 - val_accuracy: 0.7059 - val_f1_score: 0.7075 - lr: 1.0000e-04
# Epoch 24/150
# 104/104 [==============================] - ETA: 0s - loss: 0.7890 - accuracy: 0.7368 - f1_score: 0.7332
# Epoch 24: val_f1_score improved from 0.70747 to 0.73182, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 314s 3s/step - loss: 0.7890 - accuracy: 0.7368 - f1_score: 0.7332 - val_loss: 0.8238 - val_accuracy: 0.7399 - val_f1_score: 0.7318 - lr: 1.0000e-04
# Epoch 25/150
# 104/104 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.7552 - f1_score: 0.7498
# Epoch 25: val_f1_score did not improve from 0.73182
# 104/104 [==============================] - 316s 3s/step - loss: 0.7374 - accuracy: 0.7552 - f1_score: 0.7498 - val_loss: 0.9112 - val_accuracy: 0.7105 - val_f1_score: 0.7088 - lr: 1.0000e-04
# Epoch 26/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6785 - accuracy: 0.7730 - f1_score: 0.7659
# Epoch 26: val_f1_score improved from 0.73182 to 0.73396, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 331s 3s/step - loss: 0.6785 - accuracy: 0.7730 - f1_score: 0.7659 - val_loss: 0.8451 - val_accuracy: 0.7403 - val_f1_score: 0.7340 - lr: 1.0000e-04
# Epoch 27/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6561 - accuracy: 0.7830 - f1_score: 0.7800
# Epoch 27: val_f1_score improved from 0.73396 to 0.75739, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 338s 3s/step - loss: 0.6561 - accuracy: 0.7830 - f1_score: 0.7800 - val_loss: 0.8031 - val_accuracy: 0.7603 - val_f1_score: 0.7574 - lr: 1.0000e-04
# Epoch 28/150
# 104/104 [==============================] - ETA: 0s - loss: 0.6053 - accuracy: 0.7959 - f1_score: 0.7915
# Epoch 28: val_f1_score improved from 0.75739 to 0.76094, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 337s 3s/step - loss: 0.6053 - accuracy: 0.7959 - f1_score: 0.7915 - val_loss: 0.7786 - val_accuracy: 0.7642 - val_f1_score: 0.7609 - lr: 1.0000e-04
# Epoch 29/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.8145 - f1_score: 0.8114
# Epoch 29: val_f1_score improved from 0.76094 to 0.79608, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 346s 3s/step - loss: 0.5734 - accuracy: 0.8145 - f1_score: 0.8114 - val_loss: 0.6923 - val_accuracy: 0.7978 - val_f1_score: 0.7961 - lr: 1.0000e-04
# Epoch 30/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.8198 - f1_score: 0.8217
# Epoch 30: val_f1_score did not improve from 0.79608
# 104/104 [==============================] - 337s 3s/step - loss: 0.5337 - accuracy: 0.8198 - f1_score: 0.8217 - val_loss: 0.7955 - val_accuracy: 0.7615 - val_f1_score: 0.7611 - lr: 1.0000e-04
# Epoch 31/150
# 104/104 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.8296 - f1_score: 0.8253
# Epoch 31: val_f1_score did not improve from 0.79608
# 104/104 [==============================] - 344s 3s/step - loss: 0.5135 - accuracy: 0.8296 - f1_score: 0.8253 - val_loss: 0.6790 - val_accuracy: 0.7862 - val_f1_score: 0.7846 - lr: 1.0000e-04
# Epoch 32/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.8422 - f1_score: 0.8440
# Epoch 32: val_f1_score improved from 0.79608 to 0.81364, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 360s 3s/step - loss: 0.4790 - accuracy: 0.8422 - f1_score: 0.8440 - val_loss: 0.5892 - val_accuracy: 0.8151 - val_f1_score: 0.8136 - lr: 1.0000e-04
# Epoch 33/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4658 - accuracy: 0.8425 - f1_score: 0.8414
# Epoch 33: val_f1_score improved from 0.81364 to 0.81546, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 340s 3s/step - loss: 0.4658 - accuracy: 0.8425 - f1_score: 0.8414 - val_loss: 0.6367 - val_accuracy: 0.8155 - val_f1_score: 0.8155 - lr: 1.0000e-04
# Epoch 34/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.8532 - f1_score: 0.8521
# Epoch 34: val_f1_score improved from 0.81546 to 0.84187, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 349s 3s/step - loss: 0.4492 - accuracy: 0.8532 - f1_score: 0.8521 - val_loss: 0.5313 - val_accuracy: 0.8418 - val_f1_score: 0.8419 - lr: 1.0000e-04
# Epoch 35/150
# 104/104 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.8643 - f1_score: 0.8623
# Epoch 35: val_f1_score did not improve from 0.84187
# 104/104 [==============================] - 362s 3s/step - loss: 0.4081 - accuracy: 0.8643 - f1_score: 0.8623 - val_loss: 0.5451 - val_accuracy: 0.8340 - val_f1_score: 0.8324 - lr: 1.0000e-04
# Epoch 36/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3938 - accuracy: 0.8668 - f1_score: 0.8666
# Epoch 36: val_f1_score did not improve from 0.84187
# 104/104 [==============================] - 364s 3s/step - loss: 0.3938 - accuracy: 0.8668 - f1_score: 0.8666 - val_loss: 0.6563 - val_accuracy: 0.8120 - val_f1_score: 0.8168 - lr: 1.0000e-04
# Epoch 37/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3683 - accuracy: 0.8759 - f1_score: 0.8754
# Epoch 37: val_f1_score did not improve from 0.84187
# 104/104 [==============================] - 376s 4s/step - loss: 0.3683 - accuracy: 0.8759 - f1_score: 0.8754 - val_loss: 0.5853 - val_accuracy: 0.8379 - val_f1_score: 0.8331 - lr: 1.0000e-04
# Epoch 38/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8795 - f1_score: 0.8804
# Epoch 38: val_f1_score improved from 0.84187 to 0.85516, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 384s 4s/step - loss: 0.3700 - accuracy: 0.8795 - f1_score: 0.8804 - val_loss: 0.5264 - val_accuracy: 0.8549 - val_f1_score: 0.8552 - lr: 1.0000e-04
# Epoch 39/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8909 - f1_score: 0.8930
# Epoch 39: val_f1_score did not improve from 0.85516
# 104/104 [==============================] - 297s 3s/step - loss: 0.3269 - accuracy: 0.8909 - f1_score: 0.8930 - val_loss: 0.5124 - val_accuracy: 0.8564 - val_f1_score: 0.8516 - lr: 1.0000e-04
# Epoch 40/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3301 - accuracy: 0.8883 - f1_score: 0.8889
# Epoch 40: val_f1_score did not improve from 0.85516
# 104/104 [==============================] - 309s 3s/step - loss: 0.3301 - accuracy: 0.8883 - f1_score: 0.8889 - val_loss: 0.5536 - val_accuracy: 0.8452 - val_f1_score: 0.8465 - lr: 1.0000e-04
# Epoch 41/150
# 104/104 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8993 - f1_score: 0.9006
# Epoch 41: val_f1_score did not improve from 0.85516
# 104/104 [==============================] - 306s 3s/step - loss: 0.3059 - accuracy: 0.8993 - f1_score: 0.9006 - val_loss: 0.5432 - val_accuracy: 0.8460 - val_f1_score: 0.8441 - lr: 1.0000e-04
# Epoch 42/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9021 - f1_score: 0.9015
# Epoch 42: val_f1_score did not improve from 0.85516
# 104/104 [==============================] - 326s 3s/step - loss: 0.2914 - accuracy: 0.9021 - f1_score: 0.9015 - val_loss: 0.5600 - val_accuracy: 0.8510 - val_f1_score: 0.8522 - lr: 1.0000e-04
# Epoch 43/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.9087 - f1_score: 0.9092
# Epoch 43: val_f1_score improved from 0.85516 to 0.85957, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 334s 3s/step - loss: 0.2727 - accuracy: 0.9087 - f1_score: 0.9092 - val_loss: 0.4919 - val_accuracy: 0.8649 - val_f1_score: 0.8596 - lr: 1.0000e-04
# Epoch 44/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9114 - f1_score: 0.9127
# Epoch 44: val_f1_score did not improve from 0.85957
# 104/104 [==============================] - 389s 4s/step - loss: 0.2520 - accuracy: 0.9114 - f1_score: 0.9127 - val_loss: 0.5195 - val_accuracy: 0.8595 - val_f1_score: 0.8564 - lr: 1.0000e-04
# Epoch 45/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9157 - f1_score: 0.9144
# Epoch 45: val_f1_score improved from 0.85957 to 0.87703, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 471s 4s/step - loss: 0.2531 - accuracy: 0.9157 - f1_score: 0.9144 - val_loss: 0.4705 - val_accuracy: 0.8738 - val_f1_score: 0.8770 - lr: 1.0000e-04
# Epoch 46/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.9194 - f1_score: 0.9222
# Epoch 46: val_f1_score improved from 0.87703 to 0.87867, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 487s 5s/step - loss: 0.2457 - accuracy: 0.9194 - f1_score: 0.9222 - val_loss: 0.4286 - val_accuracy: 0.8815 - val_f1_score: 0.8787 - lr: 1.0000e-04
# Epoch 47/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2298 - accuracy: 0.9236 - f1_score: 0.9237
# Epoch 47: val_f1_score did not improve from 0.87867
# 104/104 [==============================] - 522s 5s/step - loss: 0.2298 - accuracy: 0.9236 - f1_score: 0.9237 - val_loss: 0.4663 - val_accuracy: 0.8780 - val_f1_score: 0.8737 - lr: 1.0000e-04
# Epoch 48/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9243 - f1_score: 0.9240
# Epoch 48: val_f1_score did not improve from 0.87867
# 104/104 [==============================] - 523s 5s/step - loss: 0.2236 - accuracy: 0.9243 - f1_score: 0.9240 - val_loss: 0.4453 - val_accuracy: 0.8773 - val_f1_score: 0.8759 - lr: 1.0000e-04
# Epoch 49/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.9264 - f1_score: 0.9268
# Epoch 49: val_f1_score did not improve from 0.87867
# 104/104 [==============================] - 531s 5s/step - loss: 0.2115 - accuracy: 0.9264 - f1_score: 0.9268 - val_loss: 0.4792 - val_accuracy: 0.8773 - val_f1_score: 0.8752 - lr: 1.0000e-04
# Epoch 50/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9297 - f1_score: 0.9306
# Epoch 50: val_f1_score improved from 0.87867 to 0.88540, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 552s 5s/step - loss: 0.2038 - accuracy: 0.9297 - f1_score: 0.9306 - val_loss: 0.4464 - val_accuracy: 0.8811 - val_f1_score: 0.8854 - lr: 1.0000e-04
# Epoch 51/150
# 104/104 [==============================] - ETA: 0s - loss: 0.2026 - accuracy: 0.9327 - f1_score: 0.9311
# Epoch 51: val_f1_score did not improve from 0.88540
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 104/104 [==============================] - 587s 6s/step - loss: 0.2026 - accuracy: 0.9327 - f1_score: 0.9311 - val_loss: 0.4476 - val_accuracy: 0.8861 - val_f1_score: 0.8825 - lr: 1.0000e-04
# Epoch 52/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9501 - f1_score: 0.9512
# Epoch 52: val_f1_score improved from 0.88540 to 0.89918, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 603s 6s/step - loss: 0.1541 - accuracy: 0.9501 - f1_score: 0.9512 - val_loss: 0.4073 - val_accuracy: 0.9027 - val_f1_score: 0.8992 - lr: 5.0000e-05
# Epoch 53/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9555 - f1_score: 0.9566
# Epoch 53: val_f1_score improved from 0.89918 to 0.90874, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 612s 6s/step - loss: 0.1341 - accuracy: 0.9555 - f1_score: 0.9566 - val_loss: 0.3602 - val_accuracy: 0.9101 - val_f1_score: 0.9087 - lr: 5.0000e-05
# Epoch 54/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9592 - f1_score: 0.9604
# Epoch 54: val_f1_score did not improve from 0.90874
# 104/104 [==============================] - 640s 6s/step - loss: 0.1206 - accuracy: 0.9592 - f1_score: 0.9604 - val_loss: 0.4346 - val_accuracy: 0.8908 - val_f1_score: 0.8940 - lr: 5.0000e-05
# Epoch 55/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9643 - f1_score: 0.9650
# Epoch 55: val_f1_score improved from 0.90874 to 0.91291, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 465s 4s/step - loss: 0.1064 - accuracy: 0.9643 - f1_score: 0.9650 - val_loss: 0.3659 - val_accuracy: 0.9139 - val_f1_score: 0.9129 - lr: 5.0000e-05
# Epoch 56/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9642 - f1_score: 0.9648
# Epoch 56: val_f1_score did not improve from 0.91291
# 104/104 [==============================] - 457s 4s/step - loss: 0.1017 - accuracy: 0.9642 - f1_score: 0.9648 - val_loss: 0.3946 - val_accuracy: 0.9043 - val_f1_score: 0.9031 - lr: 5.0000e-05
# Epoch 57/150
# 104/104 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9631 - f1_score: 0.9644
# Epoch 57: val_f1_score did not improve from 0.91291
# 104/104 [==============================] - 472s 5s/step - loss: 0.1093 - accuracy: 0.9631 - f1_score: 0.9644 - val_loss: 0.3922 - val_accuracy: 0.9039 - val_f1_score: 0.8994 - lr: 5.0000e-05
# Epoch 58/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9679 - f1_score: 0.9683
# Epoch 58: val_f1_score improved from 0.91291 to 0.91385, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 104/104 [==============================] - 534s 5s/step - loss: 0.0988 - accuracy: 0.9679 - f1_score: 0.9683 - val_loss: 0.3617 - val_accuracy: 0.9151 - val_f1_score: 0.9138 - lr: 5.0000e-05
# Epoch 59/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9722 - f1_score: 0.9719
# Epoch 59: val_f1_score did not improve from 0.91385
# 104/104 [==============================] - 724s 7s/step - loss: 0.0892 - accuracy: 0.9722 - f1_score: 0.9719 - val_loss: 0.3681 - val_accuracy: 0.9135 - val_f1_score: 0.9112 - lr: 2.5000e-05
# Epoch 60/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9734 - f1_score: 0.9740
# Epoch 60: val_f1_score improved from 0.91385 to 0.91469, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 765s 7s/step - loss: 0.0782 - accuracy: 0.9734 - f1_score: 0.9740 - val_loss: 0.3584 - val_accuracy: 0.9178 - val_f1_score: 0.9147 - lr: 2.5000e-05
# Epoch 61/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9757 - f1_score: 0.9753
# Epoch 61: val_f1_score improved from 0.91469 to 0.91556, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 771s 7s/step - loss: 0.0715 - accuracy: 0.9757 - f1_score: 0.9753 - val_loss: 0.3529 - val_accuracy: 0.9155 - val_f1_score: 0.9156 - lr: 2.5000e-05
# Epoch 62/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9754 - f1_score: 0.9760
# Epoch 62: val_f1_score improved from 0.91556 to 0.93190, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 803s 8s/step - loss: 0.0725 - accuracy: 0.9754 - f1_score: 0.9760 - val_loss: 0.3214 - val_accuracy: 0.9301 - val_f1_score: 0.9319 - lr: 2.5000e-05
# Epoch 63/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9748 - f1_score: 0.9752
# Epoch 63: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 829s 8s/step - loss: 0.0753 - accuracy: 0.9748 - f1_score: 0.9752 - val_loss: 0.3330 - val_accuracy: 0.9197 - val_f1_score: 0.9227 - lr: 2.5000e-05
# Epoch 64/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9748 - f1_score: 0.9752
# Epoch 64: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 862s 8s/step - loss: 0.0712 - accuracy: 0.9748 - f1_score: 0.9752 - val_loss: 0.3628 - val_accuracy: 0.9166 - val_f1_score: 0.9156 - lr: 2.5000e-05
# Epoch 65/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9765 - f1_score: 0.9757
# Epoch 65: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 892s 9s/step - loss: 0.0697 - accuracy: 0.9765 - f1_score: 0.9757 - val_loss: 0.3800 - val_accuracy: 0.9139 - val_f1_score: 0.9120 - lr: 2.5000e-05
# Epoch 66/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9787 - f1_score: 0.9781
# Epoch 66: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 902s 9s/step - loss: 0.0669 - accuracy: 0.9787 - f1_score: 0.9781 - val_loss: 0.3712 - val_accuracy: 0.9236 - val_f1_score: 0.9256 - lr: 2.5000e-05
# Epoch 67/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9766 - f1_score: 0.9766
# Epoch 67: val_f1_score did not improve from 0.93190
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 104/104 [==============================] - 914s 9s/step - loss: 0.0674 - accuracy: 0.9766 - f1_score: 0.9766 - val_loss: 0.3387 - val_accuracy: 0.9244 - val_f1_score: 0.9179 - lr: 2.5000e-05
# Epoch 68/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9816 - f1_score: 0.9824
# Epoch 68: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 922s 9s/step - loss: 0.0544 - accuracy: 0.9816 - f1_score: 0.9824 - val_loss: 0.3305 - val_accuracy: 0.9244 - val_f1_score: 0.9260 - lr: 1.2500e-05
# Epoch 69/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9799 - f1_score: 0.9801
# Epoch 69: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 963s 9s/step - loss: 0.0577 - accuracy: 0.9799 - f1_score: 0.9801 - val_loss: 0.3308 - val_accuracy: 0.9224 - val_f1_score: 0.9200 - lr: 1.2500e-05
# Epoch 70/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9822 - f1_score: 0.9824
# Epoch 70: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1033s 10s/step - loss: 0.0520 - accuracy: 0.9822 - f1_score: 0.9824 - val_loss: 0.3502 - val_accuracy: 0.9228 - val_f1_score: 0.9233 - lr: 1.2500e-05
# Epoch 71/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9832 - f1_score: 0.9827
# Epoch 71: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1012s 10s/step - loss: 0.0546 - accuracy: 0.9832 - f1_score: 0.9827 - val_loss: 0.3417 - val_accuracy: 0.9247 - val_f1_score: 0.9216 - lr: 1.2500e-05
# Epoch 72/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9809 - f1_score: 0.9806
# Epoch 72: val_f1_score did not improve from 0.93190
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1e-05.
# 104/104 [==============================] - 1059s 10s/step - loss: 0.0541 - accuracy: 0.9809 - f1_score: 0.9806 - val_loss: 0.3504 - val_accuracy: 0.9205 - val_f1_score: 0.9165 - lr: 1.2500e-05
# Epoch 73/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9838 - f1_score: 0.9845
# Epoch 73: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1034s 10s/step - loss: 0.0509 - accuracy: 0.9838 - f1_score: 0.9845 - val_loss: 0.3409 - val_accuracy: 0.9201 - val_f1_score: 0.9164 - lr: 1.0000e-05
# Epoch 74/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9831 - f1_score: 0.9837
# Epoch 74: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1053s 10s/step - loss: 0.0501 - accuracy: 0.9831 - f1_score: 0.9837 - val_loss: 0.3254 - val_accuracy: 0.9240 - val_f1_score: 0.9251 - lr: 1.0000e-05
# Epoch 75/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9845 - f1_score: 0.9856
# Epoch 75: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1101s 11s/step - loss: 0.0473 - accuracy: 0.9845 - f1_score: 0.9856 - val_loss: 0.3448 - val_accuracy: 0.9236 - val_f1_score: 0.9210 - lr: 1.0000e-05
# Epoch 76/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9832 - f1_score: 0.9837
# Epoch 76: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1147s 11s/step - loss: 0.0511 - accuracy: 0.9832 - f1_score: 0.9837 - val_loss: 0.3296 - val_accuracy: 0.9263 - val_f1_score: 0.9268 - lr: 1.0000e-05
# Epoch 77/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9833 - f1_score: 0.9830
# Epoch 77: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1130s 11s/step - loss: 0.0455 - accuracy: 0.9833 - f1_score: 0.9830 - val_loss: 0.3498 - val_accuracy: 0.9255 - val_f1_score: 0.9263 - lr: 1.0000e-05
# Epoch 78/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9860 - f1_score: 0.9859
# Epoch 78: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1157s 11s/step - loss: 0.0450 - accuracy: 0.9860 - f1_score: 0.9859 - val_loss: 0.3358 - val_accuracy: 0.9263 - val_f1_score: 0.9236 - lr: 1.0000e-05
# Epoch 79/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9841 - f1_score: 0.9843
# Epoch 79: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1197s 11s/step - loss: 0.0478 - accuracy: 0.9841 - f1_score: 0.9843 - val_loss: 0.3446 - val_accuracy: 0.9298 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 80/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9851 - f1_score: 0.9859
# Epoch 80: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1210s 12s/step - loss: 0.0469 - accuracy: 0.9851 - f1_score: 0.9859 - val_loss: 0.3447 - val_accuracy: 0.9201 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 81/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9869 - f1_score: 0.9869
# Epoch 81: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1250s 12s/step - loss: 0.0417 - accuracy: 0.9869 - f1_score: 0.9869 - val_loss: 0.3208 - val_accuracy: 0.9251 - val_f1_score: 0.9251 - lr: 1.0000e-05
# Epoch 82/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9839 - f1_score: 0.9827
# Epoch 82: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1307s 13s/step - loss: 0.0489 - accuracy: 0.9839 - f1_score: 0.9827 - val_loss: 0.3281 - val_accuracy: 0.9271 - val_f1_score: 0.9266 - lr: 1.0000e-05
# Epoch 83/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9853 - f1_score: 0.9853
# Epoch 83: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1245s 12s/step - loss: 0.0448 - accuracy: 0.9853 - f1_score: 0.9853 - val_loss: 0.3332 - val_accuracy: 0.9278 - val_f1_score: 0.9261 - lr: 1.0000e-05
# Epoch 84/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9855 - f1_score: 0.9852
# Epoch 84: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 854s 8s/step - loss: 0.0453 - accuracy: 0.9855 - f1_score: 0.9852 - val_loss: 0.3358 - val_accuracy: 0.9274 - val_f1_score: 0.9271 - lr: 1.0000e-05
# Epoch 85/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9846 - f1_score: 0.9845
# Epoch 85: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 833s 8s/step - loss: 0.0434 - accuracy: 0.9846 - f1_score: 0.9845 - val_loss: 0.3513 - val_accuracy: 0.9278 - val_f1_score: 0.9258 - lr: 1.0000e-05
# Epoch 86/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9845 - f1_score: 0.9849
# Epoch 86: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1126s 11s/step - loss: 0.0448 - accuracy: 0.9845 - f1_score: 0.9849 - val_loss: 0.3238 - val_accuracy: 0.9286 - val_f1_score: 0.9262 - lr: 1.0000e-05
# Epoch 87/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9839 - f1_score: 0.9847
# Epoch 87: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 866s 8s/step - loss: 0.0455 - accuracy: 0.9839 - f1_score: 0.9847 - val_loss: 0.3577 - val_accuracy: 0.9224 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 88/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9842 - f1_score: 0.9839
# Epoch 88: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 908s 9s/step - loss: 0.0459 - accuracy: 0.9842 - f1_score: 0.9839 - val_loss: 0.3538 - val_accuracy: 0.9255 - val_f1_score: 0.9261 - lr: 1.0000e-05
# Epoch 89/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9849 - f1_score: 0.9850
# Epoch 89: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1345s 13s/step - loss: 0.0414 - accuracy: 0.9849 - f1_score: 0.9850 - val_loss: 0.3349 - val_accuracy: 0.9259 - val_f1_score: 0.9233 - lr: 1.0000e-05
# Epoch 90/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9866 - f1_score: 0.9873
# Epoch 90: val_f1_score did not improve from 0.93190
# 104/104 [==============================] - 1370s 13s/step - loss: 0.0426 - accuracy: 0.9866 - f1_score: 0.9873 - val_loss: 0.3290 - val_accuracy: 0.9271 - val_f1_score: 0.9235 - lr: 1.0000e-05
# Epoch 91/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9858 - f1_score: 0.9867
# Epoch 91: val_f1_score improved from 0.93190 to 0.93279, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 1460s 14s/step - loss: 0.0474 - accuracy: 0.9858 - f1_score: 0.9867 - val_loss: 0.3279 - val_accuracy: 0.9325 - val_f1_score: 0.9328 - lr: 1.0000e-05
# Epoch 92/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9868 - f1_score: 0.9869
# Epoch 92: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1430s 14s/step - loss: 0.0400 - accuracy: 0.9868 - f1_score: 0.9869 - val_loss: 0.3367 - val_accuracy: 0.9259 - val_f1_score: 0.9235 - lr: 1.0000e-05
# Epoch 93/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9857 - f1_score: 0.9854
# Epoch 93: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1529s 15s/step - loss: 0.0400 - accuracy: 0.9857 - f1_score: 0.9854 - val_loss: 0.3366 - val_accuracy: 0.9282 - val_f1_score: 0.9279 - lr: 1.0000e-05
# Epoch 94/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9857 - f1_score: 0.9862
# Epoch 94: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1474s 14s/step - loss: 0.0433 - accuracy: 0.9857 - f1_score: 0.9862 - val_loss: 0.3254 - val_accuracy: 0.9263 - val_f1_score: 0.9206 - lr: 1.0000e-05
# Epoch 95/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9862 - f1_score: 0.9860
# Epoch 95: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1537s 15s/step - loss: 0.0412 - accuracy: 0.9862 - f1_score: 0.9860 - val_loss: 0.3429 - val_accuracy: 0.9309 - val_f1_score: 0.9255 - lr: 1.0000e-05
# Epoch 96/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9865 - f1_score: 0.9861
# Epoch 96: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1317s 13s/step - loss: 0.0418 - accuracy: 0.9865 - f1_score: 0.9861 - val_loss: 0.3597 - val_accuracy: 0.9236 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 97/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9873 - f1_score: 0.9863
# Epoch 97: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1006s 10s/step - loss: 0.0394 - accuracy: 0.9873 - f1_score: 0.9863 - val_loss: 0.3292 - val_accuracy: 0.9282 - val_f1_score: 0.9259 - lr: 1.0000e-05
# Epoch 98/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9874 - f1_score: 0.9870
# Epoch 98: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1302s 13s/step - loss: 0.0372 - accuracy: 0.9874 - f1_score: 0.9870 - val_loss: 0.3671 - val_accuracy: 0.9236 - val_f1_score: 0.9222 - lr: 1.0000e-05
# Epoch 99/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9880 - f1_score: 0.9879
# Epoch 99: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1487s 14s/step - loss: 0.0389 - accuracy: 0.9880 - f1_score: 0.9879 - val_loss: 0.3447 - val_accuracy: 0.9305 - val_f1_score: 0.9288 - lr: 1.0000e-05
# Epoch 100/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9859 - f1_score: 0.9860
# Epoch 100: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1003s 10s/step - loss: 0.0409 - accuracy: 0.9859 - f1_score: 0.9860 - val_loss: 0.3402 - val_accuracy: 0.9271 - val_f1_score: 0.9234 - lr: 1.0000e-05
# Epoch 101/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9872 - f1_score: 0.9871
# Epoch 101: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1280s 12s/step - loss: 0.0381 - accuracy: 0.9872 - f1_score: 0.9871 - val_loss: 0.3368 - val_accuracy: 0.9286 - val_f1_score: 0.9282 - lr: 1.0000e-05
# Epoch 102/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9872 - f1_score: 0.9876
# Epoch 102: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1613s 15s/step - loss: 0.0405 - accuracy: 0.9872 - f1_score: 0.9876 - val_loss: 0.3368 - val_accuracy: 0.9309 - val_f1_score: 0.9305 - lr: 1.0000e-05
# Epoch 103/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9873 - f1_score: 0.9871
# Epoch 103: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1641s 16s/step - loss: 0.0390 - accuracy: 0.9873 - f1_score: 0.9871 - val_loss: 0.3497 - val_accuracy: 0.9255 - val_f1_score: 0.9242 - lr: 1.0000e-05
# Epoch 104/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9865 - f1_score: 0.9863
# Epoch 104: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1692s 16s/step - loss: 0.0399 - accuracy: 0.9865 - f1_score: 0.9863 - val_loss: 0.3702 - val_accuracy: 0.9259 - val_f1_score: 0.9245 - lr: 1.0000e-05
# Epoch 105/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9879 - f1_score: 0.9884
# Epoch 105: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1726s 17s/step - loss: 0.0374 - accuracy: 0.9879 - f1_score: 0.9884 - val_loss: 0.3443 - val_accuracy: 0.9232 - val_f1_score: 0.9195 - lr: 1.0000e-05
# Epoch 106/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9876 - f1_score: 0.9874
# Epoch 106: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1707s 16s/step - loss: 0.0355 - accuracy: 0.9876 - f1_score: 0.9874 - val_loss: 0.3553 - val_accuracy: 0.9259 - val_f1_score: 0.9242 - lr: 1.0000e-05
# Epoch 107/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9876 - f1_score: 0.9879
# Epoch 107: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1824s 18s/step - loss: 0.0368 - accuracy: 0.9876 - f1_score: 0.9879 - val_loss: 0.3529 - val_accuracy: 0.9286 - val_f1_score: 0.9285 - lr: 1.0000e-05
# Epoch 108/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9844 - f1_score: 0.9852
# Epoch 108: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1820s 17s/step - loss: 0.0423 - accuracy: 0.9844 - f1_score: 0.9852 - val_loss: 0.3556 - val_accuracy: 0.9244 - val_f1_score: 0.9252 - lr: 1.0000e-05
# Epoch 109/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9867 - f1_score: 0.9872
# Epoch 109: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1871s 18s/step - loss: 0.0389 - accuracy: 0.9867 - f1_score: 0.9872 - val_loss: 0.3550 - val_accuracy: 0.9259 - val_f1_score: 0.9269 - lr: 1.0000e-05
# Epoch 110/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9874 - f1_score: 0.9871
# Epoch 110: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1834s 18s/step - loss: 0.0357 - accuracy: 0.9874 - f1_score: 0.9871 - val_loss: 0.3864 - val_accuracy: 0.9201 - val_f1_score: 0.9184 - lr: 1.0000e-05
# Epoch 111/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9863 - f1_score: 0.9863
# Epoch 111: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1945s 19s/step - loss: 0.0394 - accuracy: 0.9863 - f1_score: 0.9863 - val_loss: 0.3509 - val_accuracy: 0.9278 - val_f1_score: 0.9256 - lr: 1.0000e-05
# Epoch 112/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9876 - f1_score: 0.9881
# Epoch 112: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1950s 19s/step - loss: 0.0387 - accuracy: 0.9876 - f1_score: 0.9881 - val_loss: 0.3630 - val_accuracy: 0.9236 - val_f1_score: 0.9214 - lr: 1.0000e-05
# Epoch 113/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9879 - f1_score: 0.9880
# Epoch 113: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1931s 19s/step - loss: 0.0348 - accuracy: 0.9879 - f1_score: 0.9880 - val_loss: 0.3563 - val_accuracy: 0.9271 - val_f1_score: 0.9268 - lr: 1.0000e-05
# Epoch 114/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9898 - f1_score: 0.9887
# Epoch 114: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1986s 19s/step - loss: 0.0320 - accuracy: 0.9898 - f1_score: 0.9887 - val_loss: 0.3293 - val_accuracy: 0.9290 - val_f1_score: 0.9258 - lr: 1.0000e-05
# Epoch 115/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9879 - f1_score: 0.9874
# Epoch 115: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2062s 20s/step - loss: 0.0367 - accuracy: 0.9879 - f1_score: 0.9874 - val_loss: 0.3539 - val_accuracy: 0.9309 - val_f1_score: 0.9277 - lr: 1.0000e-05
# Epoch 116/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9867 - f1_score: 0.9865
# Epoch 116: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 1991s 19s/step - loss: 0.0391 - accuracy: 0.9867 - f1_score: 0.9865 - val_loss: 0.3562 - val_accuracy: 0.9259 - val_f1_score: 0.9242 - lr: 1.0000e-05
# Epoch 117/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9873 - f1_score: 0.9870
# Epoch 117: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2042s 20s/step - loss: 0.0376 - accuracy: 0.9873 - f1_score: 0.9870 - val_loss: 0.3554 - val_accuracy: 0.9263 - val_f1_score: 0.9233 - lr: 1.0000e-05
# Epoch 118/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9873 - f1_score: 0.9877
# Epoch 118: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2088s 20s/step - loss: 0.0369 - accuracy: 0.9873 - f1_score: 0.9877 - val_loss: 0.3367 - val_accuracy: 0.9298 - val_f1_score: 0.9249 - lr: 1.0000e-05
# Epoch 119/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9875 - f1_score: 0.9877
# Epoch 119: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2098s 20s/step - loss: 0.0363 - accuracy: 0.9875 - f1_score: 0.9877 - val_loss: 0.3424 - val_accuracy: 0.9290 - val_f1_score: 0.9265 - lr: 1.0000e-05
# Epoch 120/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9864 - f1_score: 0.9869
# Epoch 120: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2083s 20s/step - loss: 0.0378 - accuracy: 0.9864 - f1_score: 0.9869 - val_loss: 0.3476 - val_accuracy: 0.9298 - val_f1_score: 0.9308 - lr: 1.0000e-05
# Epoch 121/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9870 - f1_score: 0.9866
# Epoch 121: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2271s 22s/step - loss: 0.0357 - accuracy: 0.9870 - f1_score: 0.9866 - val_loss: 0.3580 - val_accuracy: 0.9313 - val_f1_score: 0.9269 - lr: 1.0000e-05
# Epoch 122/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9882 - f1_score: 0.9878
# Epoch 122: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2556s 25s/step - loss: 0.0344 - accuracy: 0.9882 - f1_score: 0.9878 - val_loss: 0.3614 - val_accuracy: 0.9255 - val_f1_score: 0.9272 - lr: 1.0000e-05
# Epoch 123/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9882 - f1_score: 0.9881
# Epoch 123: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 3821s 37s/step - loss: 0.0338 - accuracy: 0.9882 - f1_score: 0.9881 - val_loss: 0.3570 - val_accuracy: 0.9286 - val_f1_score: 0.9256 - lr: 1.0000e-05
# Epoch 124/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9895 - f1_score: 0.9892
# Epoch 124: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2607s 25s/step - loss: 0.0300 - accuracy: 0.9895 - f1_score: 0.9892 - val_loss: 0.3532 - val_accuracy: 0.9267 - val_f1_score: 0.9227 - lr: 1.0000e-05
# Epoch 125/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9869 - f1_score: 0.9869
# Epoch 125: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 3498s 34s/step - loss: 0.0358 - accuracy: 0.9869 - f1_score: 0.9869 - val_loss: 0.3404 - val_accuracy: 0.9317 - val_f1_score: 0.9294 - lr: 1.0000e-05
# Epoch 126/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9902 - f1_score: 0.9902
# Epoch 126: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2751s 26s/step - loss: 0.0307 - accuracy: 0.9902 - f1_score: 0.9902 - val_loss: 0.3694 - val_accuracy: 0.9290 - val_f1_score: 0.9251 - lr: 1.0000e-05
# Epoch 127/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9890 - f1_score: 0.9883
# Epoch 127: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 4074s 39s/step - loss: 0.0344 - accuracy: 0.9890 - f1_score: 0.9883 - val_loss: 0.3466 - val_accuracy: 0.9294 - val_f1_score: 0.9272 - lr: 1.0000e-05
# Epoch 128/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9898 - f1_score: 0.9894
# Epoch 128: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 3474s 33s/step - loss: 0.0286 - accuracy: 0.9898 - f1_score: 0.9894 - val_loss: 0.3277 - val_accuracy: 0.9332 - val_f1_score: 0.9326 - lr: 1.0000e-05
# Epoch 129/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9879 - f1_score: 0.9877
# Epoch 129: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 3093s 30s/step - loss: 0.0367 - accuracy: 0.9879 - f1_score: 0.9877 - val_loss: 0.3556 - val_accuracy: 0.9321 - val_f1_score: 0.9304 - lr: 1.0000e-05
# Epoch 130/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9898 - f1_score: 0.9903
# Epoch 130: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 4065s 39s/step - loss: 0.0309 - accuracy: 0.9898 - f1_score: 0.9903 - val_loss: 0.3800 - val_accuracy: 0.9255 - val_f1_score: 0.9248 - lr: 1.0000e-05
# Epoch 131/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9884 - f1_score: 0.9887
# Epoch 131: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 4143s 40s/step - loss: 0.0328 - accuracy: 0.9884 - f1_score: 0.9887 - val_loss: 0.3459 - val_accuracy: 0.9313 - val_f1_score: 0.9294 - lr: 1.0000e-05
# Epoch 132/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9885 - f1_score: 0.9892
# Epoch 132: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2363s 23s/step - loss: 0.0349 - accuracy: 0.9885 - f1_score: 0.9892 - val_loss: 0.3596 - val_accuracy: 0.9240 - val_f1_score: 0.9210 - lr: 1.0000e-05
# Epoch 133/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9899 - f1_score: 0.9895
# Epoch 133: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 2784s 27s/step - loss: 0.0303 - accuracy: 0.9899 - f1_score: 0.9895 - val_loss: 0.3443 - val_accuracy: 0.9309 - val_f1_score: 0.9270 - lr: 1.0000e-05
# Epoch 134/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9884 - f1_score: 0.9886
# Epoch 134: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 3087s 30s/step - loss: 0.0333 - accuracy: 0.9884 - f1_score: 0.9886 - val_loss: 0.3556 - val_accuracy: 0.9271 - val_f1_score: 0.9255 - lr: 1.0000e-05
# Epoch 135/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9882 - f1_score: 0.9877
# Epoch 135: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 3235s 31s/step - loss: 0.0348 - accuracy: 0.9882 - f1_score: 0.9877 - val_loss: 0.3617 - val_accuracy: 0.9336 - val_f1_score: 0.9304 - lr: 1.0000e-05
# Epoch 136/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9883 - f1_score: 0.9883
# Epoch 136: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 4362s 42s/step - loss: 0.0346 - accuracy: 0.9883 - f1_score: 0.9883 - val_loss: 0.3519 - val_accuracy: 0.9294 - val_f1_score: 0.9254 - lr: 1.0000e-05
# Epoch 137/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9889 - f1_score: 0.9889
# Epoch 137: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 4356s 42s/step - loss: 0.0304 - accuracy: 0.9889 - f1_score: 0.9889 - val_loss: 0.3571 - val_accuracy: 0.9286 - val_f1_score: 0.9270 - lr: 1.0000e-05
# Epoch 138/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9900 - f1_score: 0.9900
# Epoch 138: val_f1_score did not improve from 0.93279
# 104/104 [==============================] - 4684s 45s/step - loss: 0.0286 - accuracy: 0.9900 - f1_score: 0.9900 - val_loss: 0.3650 - val_accuracy: 0.9278 - val_f1_score: 0.9264 - lr: 1.0000e-05
# Epoch 139/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9906 - f1_score: 0.9911
# Epoch 139: val_f1_score improved from 0.93279 to 0.93528, saving model to saved_outputs_basic_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 4681s 45s/step - loss: 0.0282 - accuracy: 0.9906 - f1_score: 0.9911 - val_loss: 0.3424 - val_accuracy: 0.9379 - val_f1_score: 0.9353 - lr: 1.0000e-05
# Epoch 140/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9907 - f1_score: 0.9908
# Epoch 140: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 4595s 44s/step - loss: 0.0273 - accuracy: 0.9907 - f1_score: 0.9908 - val_loss: 0.3788 - val_accuracy: 0.9224 - val_f1_score: 0.9215 - lr: 1.0000e-05
# Epoch 141/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9894 - f1_score: 0.9887
# Epoch 141: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 4284s 41s/step - loss: 0.0291 - accuracy: 0.9894 - f1_score: 0.9887 - val_loss: 0.3694 - val_accuracy: 0.9313 - val_f1_score: 0.9263 - lr: 1.0000e-05
# Epoch 142/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9891 - f1_score: 0.9894
# Epoch 142: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 4614s 44s/step - loss: 0.0297 - accuracy: 0.9891 - f1_score: 0.9894 - val_loss: 0.3592 - val_accuracy: 0.9290 - val_f1_score: 0.9291 - lr: 1.0000e-05
# Epoch 143/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9893 - f1_score: 0.9899
# Epoch 143: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 4726s 45s/step - loss: 0.0320 - accuracy: 0.9893 - f1_score: 0.9899 - val_loss: 0.3519 - val_accuracy: 0.9286 - val_f1_score: 0.9252 - lr: 1.0000e-05
# Epoch 144/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.9890
# Epoch 144: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 3212s 31s/step - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.9890 - val_loss: 0.3776 - val_accuracy: 0.9294 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 145/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9880 - f1_score: 0.9876
# Epoch 145: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 3981s 38s/step - loss: 0.0337 - accuracy: 0.9880 - f1_score: 0.9876 - val_loss: 0.3521 - val_accuracy: 0.9305 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 146/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9895 - f1_score: 0.9902
# Epoch 146: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 4203s 41s/step - loss: 0.0289 - accuracy: 0.9895 - f1_score: 0.9902 - val_loss: 0.3469 - val_accuracy: 0.9305 - val_f1_score: 0.9282 - lr: 1.0000e-05
# Epoch 147/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9905 - f1_score: 0.9898
# Epoch 147: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 4986s 48s/step - loss: 0.0275 - accuracy: 0.9905 - f1_score: 0.9898 - val_loss: 0.3392 - val_accuracy: 0.9332 - val_f1_score: 0.9318 - lr: 1.0000e-05
# Epoch 148/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9902 - f1_score: 0.9909
# Epoch 148: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 3595s 34s/step - loss: 0.0275 - accuracy: 0.9902 - f1_score: 0.9909 - val_loss: 0.3627 - val_accuracy: 0.9286 - val_f1_score: 0.9277 - lr: 1.0000e-05
# Epoch 149/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9898 - f1_score: 0.9895
# Epoch 149: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 3112s 30s/step - loss: 0.0299 - accuracy: 0.9898 - f1_score: 0.9895 - val_loss: 0.3614 - val_accuracy: 0.9325 - val_f1_score: 0.9283 - lr: 1.0000e-05
# Epoch 150/150
# 104/104 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9909 - f1_score: 0.9904
# Epoch 150: val_f1_score did not improve from 0.93528
# 104/104 [==============================] - 2865s 28s/step - loss: 0.0267 - accuracy: 0.9909 - f1_score: 0.9904 - val_loss: 0.3471 - val_accuracy: 0.9309 - val_f1_score: 0.9307 - lr: 1.0000e-05

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
total_time=198720

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
## Reading the saved train history
# Load the training history from a CSV file
df_history = pd.read_csv("saved_outputs_basic_augment\\parallelViT/training_history.csv")
df_history
# Out:
#          loss  accuracy  f1_score  val_loss  val_accuracy  val_f1_score  \
# 0    2.632499  0.138801  0.071309  2.340756      0.174064      0.053195
# 1    2.388817  0.167004  0.096419  2.284569      0.229255      0.085633
# 2    2.296340  0.222928  0.130547  2.239793      0.268236      0.127956
# 3    2.197215  0.261334  0.155867  2.085908      0.299884      0.181765
# 4    2.159180  0.276639  0.169571  2.385194      0.248553      0.138867
# ..        ...       ...       ...       ...           ...           ...
# 145  0.028869  0.989508  0.990157  0.346922      0.930529      0.928202
# 146  0.027483  0.990471  0.989807  0.339174      0.933230      0.931803
# 147  0.027464  0.990182  0.990932  0.362684      0.928599      0.927734
# 148  0.029893  0.989797  0.989505  0.361355      0.932459      0.928312
# 149  0.026654  0.990856  0.990430  0.347126      0.930915      0.930736
#
#           lr
# 0    0.00010
# 1    0.00010
# 2    0.00010
# 3    0.00010
# 4    0.00010
# ..       ...
# 145  0.00001
# 146  0.00001
# 147  0.00001
# 148  0.00001
# 149  0.00001
#
# [150 rows x 7 columns]

# %%
df_history = df_history.drop(columns=['lr'])
df_history
# Out:
#          loss  accuracy  f1_score  val_loss  val_accuracy  val_f1_score
# 0    2.632499  0.138801  0.071309  2.340756      0.174064      0.053195
# 1    2.388817  0.167004  0.096419  2.284569      0.229255      0.085633
# 2    2.296340  0.222928  0.130547  2.239793      0.268236      0.127956
# 3    2.197215  0.261334  0.155867  2.085908      0.299884      0.181765
# 4    2.159180  0.276639  0.169571  2.385194      0.248553      0.138867
# ..        ...       ...       ...       ...           ...           ...
# 145  0.028869  0.989508  0.990157  0.346922      0.930529      0.928202
# 146  0.027483  0.990471  0.989807  0.339174      0.933230      0.931803
# 147  0.027464  0.990182  0.990932  0.362684      0.928599      0.927734
# 148  0.029893  0.989797  0.989505  0.361355      0.932459      0.928312
# 149  0.026654  0.990856  0.990430  0.347126      0.930915      0.930736
#
# [150 rows x 6 columns]

# %%
# Define the list of metrics to plot (excluding 'val_' prefixed ones)
list_of_metrics = [key for key in df_history.columns if not key.startswith('val_')]

# Number of plots is determined by the number of metrics
nr_plots = len(list_of_metrics)

# Create a figure and an array of axes for plotting
fig, ax = plt.subplots(1, nr_plots, figsize=(5 * nr_plots, 4))

# Iterate over the metrics to plot each one
for i, metric in enumerate(list_of_metrics):
    # Plot training and validation metrics
    ax[i].plot(np.array(df_history[metric]), label='Training ' + metric)
    ax[i].plot(np.array(df_history['val_' + metric]), label='Validation ' + metric)
    ax[i].set_xlabel('Epoch')
    ax[i].set_title(metric.capitalize())
    ax[i].grid(True)
    ax[i].legend()

fig.tight_layout()

if SAVE_RESULTS:
    # Save the plot to a PDF
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
# plotting train history
plot_training_history(train_history, model_name = model_name, SAVE_RESULTS= SAVE_RESULTS)

# %%
best_model = get_parallel_vit()

# %%
best_model.load_weights("saved_outputs_basic_augment\\parallelViT\\saved_weights\\best_parallelViT_weights")
    
# best_model.fit(
#     train_generator,
#     epochs= 1,
#     batch_size=BATCH_SIZE,
#     validation_data=valid_generator,
# )

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 12s 337ms/step - loss: 0.2955 - accuracy: 0.9399 - f1_score: 0.9405
#     model_name  test_loss  test_accuracy  test_f1_score
# 0  parallelViT   0.295472       0.939908       0.940486

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 10s 309ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test , 
                                      model_name=model_name, 
                                      SAVE_RESULTS=SAVE_RESULTS)
# Out:
#               precision    recall  f1-score      support
# 0              0.958333  0.884615  0.920000   130.000000
# 1              0.914286  0.960000  0.936585   100.000000
# 2              0.956044  0.966667  0.961326    90.000000
# 3              0.960000  0.950495  0.955224   101.000000
# 4              0.943038  0.951064  0.947034   470.000000
# 5              0.934156  0.897233  0.915323   253.000000
# 6              0.941860  0.931034  0.936416   174.000000
# 7              0.907240  0.930394  0.918671   431.000000
# 8              0.913636  0.917808  0.915718   219.000000
# 9              0.936992  0.958420  0.947585   481.000000
# 10             0.966057  0.948718  0.957309   390.000000
# 11             0.967611  0.940945  0.954092   254.000000
# 12             0.948718  0.973684  0.961039   152.000000
# accuracy       0.939908  0.939908  0.939908     0.939908
# macro avg      0.942152  0.939314  0.940486  3245.000000
# weighted avg   0.940219  0.939908  0.939883  3245.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test , 
                           model_name=model_name, 
                           SAVE_RESULTS=SAVE_RESULTS)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test, 
                                       model_name=model_name, 
                                       SAVE_RESULTS=SAVE_RESULTS, 
                                       test_loss=test_loss)
# Out:
#     Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  parallelViT  0.939908         0.942152      0.939314        0.940486
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.940219         0.939908           0.939883  0.295472

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc, SHOW_RESULTS=True, SAVE_RESULTS=True)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.93991
# 1      Macro Precision  0.94215
# 2         Macro Recall  0.93931
# 3       Macro F1-Score  0.94049
# 4            Macro FPR  0.00517
# 5            Macro FNR  0.06069
# 6            Macro FDR  0.05785
# 7            Macro NPV  0.99487
# 8   Weighted Precision  0.94022
# 9      Weighted Recall  0.93991
# 10   Weighted F1-Score  0.93988
# 11        Weighted FPR  0.00713
# 12        Weighted FNR  0.06009
# 13        Weighted FDR  0.05978
# 14        Weighted NPV  0.99341
