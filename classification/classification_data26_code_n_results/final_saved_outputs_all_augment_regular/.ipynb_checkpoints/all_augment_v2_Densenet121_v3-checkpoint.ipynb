# %% [markdown]
# - imbalance data: https://www.linkedin.com/pulse/some-tricks-handling-imbalanced-dataset-image-m-farhan-tandia
# - base model: https://www.youtube.com/watch?v=t8eSPbvl0vU
# - https://www.kaggle.com/code/hongjae6/simple-baseline-using-keras-resnet50

# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files


import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report

import time
from tqdm import tqdm

import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'Densenet121_v4'#'Xception'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment_3RD_RUN', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'training_time.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 250 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic'#'all'#'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_all_augment_3RD_RUN\Densenet121_v4
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_7656\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'
    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=15, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00000001    # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR, EarlyStop_callback]#, EarlyStop_callback]
    ##########################################################################################################

    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )

    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:      
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:        
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %% [markdown]
# #### Original models from keras

# %%
# def get_basic_CNN():
#     model = Sequential()
    
#     # Convolutional and pooling layers
#     model.add(Conv2D(32, (3, 3), activation='relu', input_shape=MODEL_INPUT_SIZE))
#     model.add(MaxPooling2D((2, 2)))
#     model.add(Conv2D(64, (3, 3), activation='relu'))
#     model.add(MaxPooling2D((2, 2)))
#     model.add(Conv2D(128, (3, 3), activation='relu'))
#     model.add(MaxPooling2D((2, 2)))
    
#     # Flatten the output for fully connected layers
#     model.add(Flatten())
    
#     # Fully connected layers
#     model.add(Dense(128, activation='relu'))
#     # model.add(Dense(64, activation='relu'))
#     model.add(Dense(NUM_CLASSES, activation='softmax'))  # Adjust the output size based on your problem


#     optimizer = Adam(learning_rate=0.001)
#     model.compile(loss="categorical_crossentropy", 
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %%
# from tensorflow.keras.applications import InceptionV3
# def get_InceptionV3(): 
 
#     # model = Sequential()
#     # base_model = InceptionV3(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
#     # # Global average pooling and additional dense layers
#     # x = Flatten()(base_model.output)
#     # # x = Dense(512, activation='relu')(x)
#     # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
#     # # Build the functional model
#     # model = Model(inputs=base_model.input, outputs=predictions)
#     model = InceptionV3(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR)
#     model.compile(loss="categorical_crossentropy", 
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %%
# from tensorflow.keras.applications import MobileNet#### WORKING
# def get_MobileNet_original(): 
 
#     # model = Sequential()
#     # base_model = MobileNet(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
#     # # Global average pooling and additional dense layers
#     # x = Flatten()(base_model.output)
#     # # x = Dense(512, activation='relu')(x)
#     # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
#     # # Build the functional model
#     # model = Model(inputs=base_model.input, outputs=predictions)

#     model = MobileNet(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR)
#     model.compile(loss="categorical_crossentropy", 
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %%
# from tensorflow.keras.applications import Xception
# def get_Xception(): 
 
#     # model = Sequential()
#     # base_model = Xception(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
#     # # Global average pooling and additional dense layers
#     # x = Flatten()(base_model.output)
#     # # x = Dense(512, activation='relu')(x)
#     # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
#     # # Build the functional model
#     # model = Model(inputs=base_model.input, outputs=predictions)
#     model = Xception(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR)
#     model.compile(loss="categorical_crossentropy", 
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %%
from tensorflow.keras.applications import  DenseNet121
def get_DenseNet121(): # almost proper--10 has high dense
 
    # model = Sequential()
    # base_model = DenseNet121(input_shape=MODEL_INPUT_SIZE, include_top=False, weights=None)
    
    # # Global average pooling and additional dense layers
    # x = Flatten()(base_model.output)
    # # x = Dense(512, activation='relu')(x)
    # predictions = Dense(NUM_CLASSES, activation='softmax')(x)
    
    # # Build the functional model
    # model = Model(inputs=base_model.input, outputs=predictions)
    model = DenseNet121(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=0.001)
    model.compile(loss="categorical_crossentropy", 
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %%
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.1,
#                       activation='relu',
#                       units= 1024,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy", 
#                       retrain_backbone_network=False,
#                       filters=7,
#                       name='ensemble2'):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Concatenate features
#     concatenated_features = Concatenate()([Xception_features, densenet_features])

#     if filters==3:
#         filters = (3,3)
#     elif filters==5:
#         filters = (5,5)
#     elif filters==7:
#         filters = (7,7)
#     elif filters==9:
#         filters = (9,9)

#     # # Add a tunable dropout layer
#     # x = Dropout(dropout)(concatenated_features)

#     # # A fully connected layer with a tunable number of units
#     # x = Dense(units)(x)

#     #     # Add a tunable dropout layer
#     # x = Dropout(dropout)(x)

#     # # A fully connected layer with a tunable number of units
#     # x = Dense(units)(x)
#         # Add a tunable dropout layer
#     x = Dropout(dropout)(concatenated_features)

#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Add a tunable dropout layer
#     x = Dropout(dropout)(x)

#     # A fully connected layer with a tunable number of units again
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)


#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create and compile the model
#     model = Model(inputs=inputs, outputs=predictions)
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(INITIAL_LR),
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %%
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble3_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.2,
#                       activation='relu',
#                       units= 512,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy", 
#                       retrain_backbone_network=False,
#                       filters=7,
#                       name='ensemble2'):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)


#         # Feature extraction from Xception
#     InceptionResNetV2_base = InceptionResNetV2(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     InceptionResNetV2_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     InceptionResNetV2_features = InceptionResNetV2_base(inputs)
#     InceptionResNetV2_features = GlobalAveragePooling2D()(InceptionResNetV2_features)
    

#     # Concatenate the features
#     concatenated_features = Concatenate()([densenet_features, Xception_features, InceptionResNetV2_features])

#     x = Dropout(dropout)(concatenated_features)
#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create the final ensemble model
#     model = Model(inputs=inputs, outputs=predictions)
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(INITIAL_LR),
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %% [markdown]
# # Train and Results
# - DOES NOT WORK---EfficientNetV2, Nasnet, Resnet, VGG16,
# - DOES NOT WORK--InceptionV3--ERROR: No matching distribution found for tensorflow-directml (checked with colab)
# - DOES NOT WORK--InceptionResNetV2--slighly works
# - original models selected: DenseNet121, -mobilenet X-ception, ,-Inception
# - My models selected: 'ensemble2' (70), Basic CNN v1(91), Basic CNN v2 (92), transfer_mobilenet (85), ensembleXception
# - tuned vit models:  T2TViT(47)",---Cait (26), 16

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point---0-120
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/250
# 104/104 [==============================] - ETA: 0s - loss: 1.7152 - accuracy: 0.4373 - f1_score: 0.3735
# Epoch 1: val_f1_score improved from -inf to 0.01986, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 197s 2s/step - loss: 1.7152 - accuracy: 0.4373 - f1_score: 0.3735 - val_loss: 6.0415 - val_accuracy: 0.1482 - val_f1_score: 0.0199 - lr: 0.0010
# Epoch 2/250
# 104/104 [==============================] - ETA: 0s - loss: 1.1695 - accuracy: 0.6148 - f1_score: 0.5753
# Epoch 2: val_f1_score did not improve from 0.01986
# 104/104 [==============================] - 168s 2s/step - loss: 1.1695 - accuracy: 0.6148 - f1_score: 0.5753 - val_loss: 4.5257 - val_accuracy: 0.1285 - val_f1_score: 0.0188 - lr: 0.0010
# Epoch 3/250
# 104/104 [==============================] - ETA: 0s - loss: 0.9255 - accuracy: 0.6899 - f1_score: 0.6652
# Epoch 3: val_f1_score improved from 0.01986 to 0.03365, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 165s 2s/step - loss: 0.9255 - accuracy: 0.6899 - f1_score: 0.6652 - val_loss: 4.5785 - val_accuracy: 0.1428 - val_f1_score: 0.0336 - lr: 0.0010
# Epoch 4/250
# 104/104 [==============================] - ETA: 0s - loss: 0.7365 - accuracy: 0.7605 - f1_score: 0.7414
# Epoch 4: val_f1_score improved from 0.03365 to 0.04875, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 170s 2s/step - loss: 0.7365 - accuracy: 0.7605 - f1_score: 0.7414 - val_loss: 4.5222 - val_accuracy: 0.1285 - val_f1_score: 0.0487 - lr: 0.0010
# Epoch 5/250
# 104/104 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.7936 - f1_score: 0.7764
# Epoch 5: val_f1_score improved from 0.04875 to 0.20604, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 175s 2s/step - loss: 0.6291 - accuracy: 0.7936 - f1_score: 0.7764 - val_loss: 2.9549 - val_accuracy: 0.3211 - val_f1_score: 0.2060 - lr: 0.0010
# Epoch 6/250
# 104/104 [==============================] - ETA: 0s - loss: 0.5296 - accuracy: 0.8264 - f1_score: 0.8152
# Epoch 6: val_f1_score improved from 0.20604 to 0.54547, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 186s 2s/step - loss: 0.5296 - accuracy: 0.8264 - f1_score: 0.8152 - val_loss: 1.4503 - val_accuracy: 0.5951 - val_f1_score: 0.5455 - lr: 0.0010
# Epoch 7/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.8479 - f1_score: 0.8386
# Epoch 7: val_f1_score improved from 0.54547 to 0.63675, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 198s 2s/step - loss: 0.4653 - accuracy: 0.8479 - f1_score: 0.8386 - val_loss: 1.0926 - val_accuracy: 0.6615 - val_f1_score: 0.6368 - lr: 0.0010
# Epoch 8/250
# 104/104 [==============================] - ETA: 0s - loss: 0.4177 - accuracy: 0.8609 - f1_score: 0.8533
# Epoch 8: val_f1_score did not improve from 0.63675
# 104/104 [==============================] - 198s 2s/step - loss: 0.4177 - accuracy: 0.8609 - f1_score: 0.8533 - val_loss: 1.1846 - val_accuracy: 0.6256 - val_f1_score: 0.6159 - lr: 0.0010
# Epoch 9/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3669 - accuracy: 0.8766 - f1_score: 0.8728
# Epoch 9: val_f1_score did not improve from 0.63675
# 104/104 [==============================] - 207s 2s/step - loss: 0.3669 - accuracy: 0.8766 - f1_score: 0.8728 - val_loss: 3.3420 - val_accuracy: 0.3721 - val_f1_score: 0.2796 - lr: 0.0010
# Epoch 10/250
# 104/104 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8914 - f1_score: 0.8872
# Epoch 10: val_f1_score did not improve from 0.63675
# 104/104 [==============================] - 201s 2s/step - loss: 0.3381 - accuracy: 0.8914 - f1_score: 0.8872 - val_loss: 2.7009 - val_accuracy: 0.4257 - val_f1_score: 0.3955 - lr: 0.0010
# Epoch 11/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.9077 - f1_score: 0.9038
# Epoch 11: val_f1_score did not improve from 0.63675
# 104/104 [==============================] - 199s 2s/step - loss: 0.2847 - accuracy: 0.9077 - f1_score: 0.9038 - val_loss: 1.6898 - val_accuracy: 0.5797 - val_f1_score: 0.5861 - lr: 0.0010
# Epoch 12/250
# 104/104 [==============================] - ETA: 0s - loss: 0.2917 - accuracy: 0.9043 - f1_score: 0.8984
# Epoch 12: val_f1_score did not improve from 0.63675
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 [==============================] - 199s 2s/step - loss: 0.2917 - accuracy: 0.9043 - f1_score: 0.8984 - val_loss: 1.3946 - val_accuracy: 0.6287 - val_f1_score: 0.5768 - lr: 0.0010
# Epoch 13/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9524 - f1_score: 0.9504
# Epoch 13: val_f1_score improved from 0.63675 to 0.85157, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 205s 2s/step - loss: 0.1513 - accuracy: 0.9524 - f1_score: 0.9504 - val_loss: 0.4459 - val_accuracy: 0.8626 - val_f1_score: 0.8516 - lr: 5.0000e-04
# Epoch 14/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9660 - f1_score: 0.9649
# Epoch 14: val_f1_score improved from 0.85157 to 0.89433, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 202s 2s/step - loss: 0.1081 - accuracy: 0.9660 - f1_score: 0.9649 - val_loss: 0.3082 - val_accuracy: 0.8993 - val_f1_score: 0.8943 - lr: 5.0000e-04
# Epoch 15/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9660 - f1_score: 0.9666
# Epoch 15: val_f1_score did not improve from 0.89433
# 104/104 [==============================] - 201s 2s/step - loss: 0.1072 - accuracy: 0.9660 - f1_score: 0.9666 - val_loss: 0.9181 - val_accuracy: 0.7561 - val_f1_score: 0.7522 - lr: 5.0000e-04
# Epoch 16/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9662 - f1_score: 0.9657
# Epoch 16: val_f1_score did not improve from 0.89433
# 104/104 [==============================] - 198s 2s/step - loss: 0.1030 - accuracy: 0.9662 - f1_score: 0.9657 - val_loss: 0.6009 - val_accuracy: 0.8298 - val_f1_score: 0.8224 - lr: 5.0000e-04
# Epoch 17/250
# 104/104 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9651 - f1_score: 0.9640
# Epoch 17: val_f1_score did not improve from 0.89433
# 104/104 [==============================] - 199s 2s/step - loss: 0.1010 - accuracy: 0.9651 - f1_score: 0.9640 - val_loss: 0.8722 - val_accuracy: 0.7399 - val_f1_score: 0.7431 - lr: 5.0000e-04
# Epoch 18/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9722 - f1_score: 0.9713
# Epoch 18: val_f1_score did not improve from 0.89433
# 104/104 [==============================] - 199s 2s/step - loss: 0.0879 - accuracy: 0.9722 - f1_score: 0.9713 - val_loss: 0.4527 - val_accuracy: 0.8630 - val_f1_score: 0.8597 - lr: 5.0000e-04
# Epoch 19/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9723 - f1_score: 0.9719
# Epoch 19: val_f1_score did not improve from 0.89433
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 104/104 [==============================] - 206s 2s/step - loss: 0.0853 - accuracy: 0.9723 - f1_score: 0.9719 - val_loss: 0.7810 - val_accuracy: 0.7677 - val_f1_score: 0.7706 - lr: 5.0000e-04
# Epoch 20/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9842 - f1_score: 0.9835
# Epoch 20: val_f1_score improved from 0.89433 to 0.95002, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 222s 2s/step - loss: 0.0565 - accuracy: 0.9842 - f1_score: 0.9835 - val_loss: 0.1711 - val_accuracy: 0.9510 - val_f1_score: 0.9500 - lr: 2.5000e-04
# Epoch 21/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9882 - f1_score: 0.9875
# Epoch 21: val_f1_score did not improve from 0.95002
# 104/104 [==============================] - 218s 2s/step - loss: 0.0393 - accuracy: 0.9882 - f1_score: 0.9875 - val_loss: 0.2274 - val_accuracy: 0.9344 - val_f1_score: 0.9329 - lr: 2.5000e-04
# Epoch 22/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9880 - f1_score: 0.9873
# Epoch 22: val_f1_score improved from 0.95002 to 0.95411, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 228s 2s/step - loss: 0.0419 - accuracy: 0.9880 - f1_score: 0.9873 - val_loss: 0.1612 - val_accuracy: 0.9494 - val_f1_score: 0.9541 - lr: 2.5000e-04
# Epoch 23/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9886 - f1_score: 0.9885
# Epoch 23: val_f1_score did not improve from 0.95411
# 104/104 [==============================] - 238s 2s/step - loss: 0.0371 - accuracy: 0.9886 - f1_score: 0.9885 - val_loss: 0.1581 - val_accuracy: 0.9533 - val_f1_score: 0.9515 - lr: 2.5000e-04
# Epoch 24/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9864 - f1_score: 0.9857
# Epoch 24: val_f1_score did not improve from 0.95411
# 104/104 [==============================] - 231s 2s/step - loss: 0.0378 - accuracy: 0.9864 - f1_score: 0.9857 - val_loss: 0.2919 - val_accuracy: 0.9093 - val_f1_score: 0.9082 - lr: 2.5000e-04
# Epoch 25/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9874 - f1_score: 0.9877
# Epoch 25: val_f1_score did not improve from 0.95411
# 104/104 [==============================] - 230s 2s/step - loss: 0.0362 - accuracy: 0.9874 - f1_score: 0.9877 - val_loss: 0.2420 - val_accuracy: 0.9301 - val_f1_score: 0.9307 - lr: 2.5000e-04
# Epoch 26/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9904 - f1_score: 0.9897
# Epoch 26: val_f1_score did not improve from 0.95411
# 104/104 [==============================] - 230s 2s/step - loss: 0.0325 - accuracy: 0.9904 - f1_score: 0.9897 - val_loss: 0.2941 - val_accuracy: 0.9162 - val_f1_score: 0.9153 - lr: 2.5000e-04
# Epoch 27/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9885 - f1_score: 0.9877
# Epoch 27: val_f1_score improved from 0.95411 to 0.95438, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 233s 2s/step - loss: 0.0353 - accuracy: 0.9885 - f1_score: 0.9877 - val_loss: 0.1730 - val_accuracy: 0.9556 - val_f1_score: 0.9544 - lr: 2.5000e-04
# Epoch 28/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9894 - f1_score: 0.9886
# Epoch 28: val_f1_score did not improve from 0.95438
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 104/104 [==============================] - 230s 2s/step - loss: 0.0311 - accuracy: 0.9894 - f1_score: 0.9886 - val_loss: 0.1790 - val_accuracy: 0.9518 - val_f1_score: 0.9507 - lr: 2.5000e-04
# Epoch 29/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9933 - f1_score: 0.9928
# Epoch 29: val_f1_score improved from 0.95438 to 0.96226, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 228s 2s/step - loss: 0.0222 - accuracy: 0.9933 - f1_score: 0.9928 - val_loss: 0.1401 - val_accuracy: 0.9622 - val_f1_score: 0.9623 - lr: 1.2500e-04
# Epoch 30/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9928 - f1_score: 0.9924
# Epoch 30: val_f1_score improved from 0.96226 to 0.96384, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 225s 2s/step - loss: 0.0218 - accuracy: 0.9928 - f1_score: 0.9924 - val_loss: 0.1335 - val_accuracy: 0.9645 - val_f1_score: 0.9638 - lr: 1.2500e-04
# Epoch 31/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9934 - f1_score: 0.9932
# Epoch 31: val_f1_score did not improve from 0.96384
# 104/104 [==============================] - 220s 2s/step - loss: 0.0193 - accuracy: 0.9934 - f1_score: 0.9932 - val_loss: 0.1770 - val_accuracy: 0.9506 - val_f1_score: 0.9483 - lr: 1.2500e-04
# Epoch 32/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9936 - f1_score: 0.9937
# Epoch 32: val_f1_score did not improve from 0.96384
# 104/104 [==============================] - 215s 2s/step - loss: 0.0206 - accuracy: 0.9936 - f1_score: 0.9937 - val_loss: 0.1565 - val_accuracy: 0.9564 - val_f1_score: 0.9550 - lr: 1.2500e-04
# Epoch 33/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9944 - f1_score: 0.9946
# Epoch 33: val_f1_score did not improve from 0.96384
# 104/104 [==============================] - 223s 2s/step - loss: 0.0200 - accuracy: 0.9944 - f1_score: 0.9946 - val_loss: 0.1380 - val_accuracy: 0.9626 - val_f1_score: 0.9608 - lr: 1.2500e-04
# Epoch 34/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9941 - f1_score: 0.9937
# Epoch 34: val_f1_score did not improve from 0.96384
# 104/104 [==============================] - 219s 2s/step - loss: 0.0176 - accuracy: 0.9941 - f1_score: 0.9937 - val_loss: 0.1413 - val_accuracy: 0.9637 - val_f1_score: 0.9636 - lr: 1.2500e-04
# Epoch 35/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9937 - f1_score: 0.9937
# Epoch 35: val_f1_score did not improve from 0.96384
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 104/104 [==============================] - 212s 2s/step - loss: 0.0183 - accuracy: 0.9937 - f1_score: 0.9937 - val_loss: 0.1482 - val_accuracy: 0.9548 - val_f1_score: 0.9528 - lr: 1.2500e-04
# Epoch 36/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9957 - f1_score: 0.9956
# Epoch 36: val_f1_score did not improve from 0.96384
# 104/104 [==============================] - 217s 2s/step - loss: 0.0146 - accuracy: 0.9957 - f1_score: 0.9956 - val_loss: 0.1433 - val_accuracy: 0.9641 - val_f1_score: 0.9624 - lr: 6.2500e-05
# Epoch 37/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9951 - f1_score: 0.9947
# Epoch 37: val_f1_score improved from 0.96384 to 0.96405, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 220s 2s/step - loss: 0.0149 - accuracy: 0.9951 - f1_score: 0.9947 - val_loss: 0.1300 - val_accuracy: 0.9645 - val_f1_score: 0.9640 - lr: 6.2500e-05
# Epoch 38/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9960 - f1_score: 0.9958
# Epoch 38: val_f1_score did not improve from 0.96405
# 104/104 [==============================] - 211s 2s/step - loss: 0.0127 - accuracy: 0.9960 - f1_score: 0.9958 - val_loss: 0.1379 - val_accuracy: 0.9626 - val_f1_score: 0.9608 - lr: 6.2500e-05
# Epoch 39/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9952 - f1_score: 0.9945
# Epoch 39: val_f1_score improved from 0.96405 to 0.96415, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 217s 2s/step - loss: 0.0131 - accuracy: 0.9952 - f1_score: 0.9945 - val_loss: 0.1302 - val_accuracy: 0.9637 - val_f1_score: 0.9641 - lr: 6.2500e-05
# Epoch 40/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9956 - f1_score: 0.9951
# Epoch 40: val_f1_score improved from 0.96415 to 0.96661, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 209s 2s/step - loss: 0.0132 - accuracy: 0.9956 - f1_score: 0.9951 - val_loss: 0.1331 - val_accuracy: 0.9676 - val_f1_score: 0.9666 - lr: 6.2500e-05
# Epoch 41/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9952 - f1_score: 0.9946
# Epoch 41: val_f1_score did not improve from 0.96661
# 104/104 [==============================] - 203s 2s/step - loss: 0.0135 - accuracy: 0.9952 - f1_score: 0.9946 - val_loss: 0.1405 - val_accuracy: 0.9649 - val_f1_score: 0.9649 - lr: 6.2500e-05
# Epoch 42/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9955 - f1_score: 0.9953
# Epoch 42: val_f1_score did not improve from 0.96661
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 104/104 [==============================] - 198s 2s/step - loss: 0.0126 - accuracy: 0.9955 - f1_score: 0.9953 - val_loss: 0.1302 - val_accuracy: 0.9657 - val_f1_score: 0.9638 - lr: 6.2500e-05
# Epoch 43/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9957 - f1_score: 0.9947
# Epoch 43: val_f1_score did not improve from 0.96661
# 104/104 [==============================] - 193s 2s/step - loss: 0.0117 - accuracy: 0.9957 - f1_score: 0.9947 - val_loss: 0.1263 - val_accuracy: 0.9610 - val_f1_score: 0.9598 - lr: 3.1250e-05
# Epoch 44/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9958 - f1_score: 0.9954
# Epoch 44: val_f1_score did not improve from 0.96661
# 104/104 [==============================] - 198s 2s/step - loss: 0.0114 - accuracy: 0.9958 - f1_score: 0.9954 - val_loss: 0.1312 - val_accuracy: 0.9653 - val_f1_score: 0.9635 - lr: 3.1250e-05
# Epoch 45/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9962 - f1_score: 0.9957
# Epoch 45: val_f1_score improved from 0.96661 to 0.96681, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 200s 2s/step - loss: 0.0106 - accuracy: 0.9962 - f1_score: 0.9957 - val_loss: 0.1293 - val_accuracy: 0.9684 - val_f1_score: 0.9668 - lr: 3.1250e-05
# Epoch 46/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9959 - f1_score: 0.9952
# Epoch 46: val_f1_score did not improve from 0.96681
# 104/104 [==============================] - 191s 2s/step - loss: 0.0111 - accuracy: 0.9959 - f1_score: 0.9952 - val_loss: 0.1281 - val_accuracy: 0.9653 - val_f1_score: 0.9662 - lr: 3.1250e-05
# Epoch 47/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9965 - f1_score: 0.9960
# Epoch 47: val_f1_score did not improve from 0.96681
# 104/104 [==============================] - 191s 2s/step - loss: 0.0104 - accuracy: 0.9965 - f1_score: 0.9960 - val_loss: 0.1314 - val_accuracy: 0.9641 - val_f1_score: 0.9642 - lr: 3.1250e-05
# Epoch 48/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9974 - f1_score: 0.9967
# Epoch 48: val_f1_score did not improve from 0.96681
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 104/104 [==============================] - 190s 2s/step - loss: 0.0100 - accuracy: 0.9974 - f1_score: 0.9967 - val_loss: 0.1313 - val_accuracy: 0.9641 - val_f1_score: 0.9635 - lr: 3.1250e-05
# Epoch 49/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9965 - f1_score: 0.9961
# Epoch 49: val_f1_score did not improve from 0.96681
# 104/104 [==============================] - 191s 2s/step - loss: 0.0106 - accuracy: 0.9965 - f1_score: 0.9961 - val_loss: 0.1292 - val_accuracy: 0.9660 - val_f1_score: 0.9650 - lr: 1.5625e-05
# Epoch 50/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9976 - f1_score: 0.9974
# Epoch 50: val_f1_score improved from 0.96681 to 0.96921, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 197s 2s/step - loss: 0.0088 - accuracy: 0.9976 - f1_score: 0.9974 - val_loss: 0.1251 - val_accuracy: 0.9695 - val_f1_score: 0.9692 - lr: 1.5625e-05
# Epoch 51/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9976 - f1_score: 0.9971
# Epoch 51: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 200s 2s/step - loss: 0.0088 - accuracy: 0.9976 - f1_score: 0.9971 - val_loss: 0.1310 - val_accuracy: 0.9664 - val_f1_score: 0.9647 - lr: 1.5625e-05
# Epoch 52/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9976 - f1_score: 0.9974
# Epoch 52: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 195s 2s/step - loss: 0.0083 - accuracy: 0.9976 - f1_score: 0.9974 - val_loss: 0.1293 - val_accuracy: 0.9672 - val_f1_score: 0.9661 - lr: 1.5625e-05
# Epoch 53/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9967 - f1_score: 0.9960
# Epoch 53: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 201s 2s/step - loss: 0.0088 - accuracy: 0.9967 - f1_score: 0.9960 - val_loss: 0.1239 - val_accuracy: 0.9680 - val_f1_score: 0.9664 - lr: 1.5625e-05
# Epoch 54/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9970 - f1_score: 0.9963
# Epoch 54: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 210s 2s/step - loss: 0.0093 - accuracy: 0.9970 - f1_score: 0.9963 - val_loss: 0.1368 - val_accuracy: 0.9664 - val_f1_score: 0.9646 - lr: 1.5625e-05
# Epoch 55/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9970 - f1_score: 0.9967
# Epoch 55: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 200s 2s/step - loss: 0.0086 - accuracy: 0.9970 - f1_score: 0.9967 - val_loss: 0.1199 - val_accuracy: 0.9668 - val_f1_score: 0.9647 - lr: 1.5625e-05
# Epoch 56/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9971 - f1_score: 0.9963
# Epoch 56: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 201s 2s/step - loss: 0.0088 - accuracy: 0.9971 - f1_score: 0.9963 - val_loss: 0.1299 - val_accuracy: 0.9676 - val_f1_score: 0.9666 - lr: 1.5625e-05
# Epoch 57/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9971 - f1_score: 0.9967
# Epoch 57: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 198s 2s/step - loss: 0.0094 - accuracy: 0.9971 - f1_score: 0.9967 - val_loss: 0.1256 - val_accuracy: 0.9684 - val_f1_score: 0.9671 - lr: 1.5625e-05
# Epoch 58/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9979 - f1_score: 0.9975
# Epoch 58: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 202s 2s/step - loss: 0.0082 - accuracy: 0.9979 - f1_score: 0.9975 - val_loss: 0.1337 - val_accuracy: 0.9641 - val_f1_score: 0.9626 - lr: 1.5625e-05
# Epoch 59/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9970 - f1_score: 0.9966
# Epoch 59: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 208s 2s/step - loss: 0.0078 - accuracy: 0.9970 - f1_score: 0.9966 - val_loss: 0.1285 - val_accuracy: 0.9645 - val_f1_score: 0.9643 - lr: 1.5625e-05
# Epoch 60/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9977 - f1_score: 0.9974
# Epoch 60: val_f1_score did not improve from 0.96921
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 104/104 [==============================] - 205s 2s/step - loss: 0.0080 - accuracy: 0.9977 - f1_score: 0.9974 - val_loss: 0.1318 - val_accuracy: 0.9653 - val_f1_score: 0.9642 - lr: 1.5625e-05
# Epoch 61/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9968 - f1_score: 0.9961
# Epoch 61: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 207s 2s/step - loss: 0.0085 - accuracy: 0.9968 - f1_score: 0.9961 - val_loss: 0.1346 - val_accuracy: 0.9641 - val_f1_score: 0.9630 - lr: 7.8125e-06
# Epoch 62/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9974 - f1_score: 0.9970
# Epoch 62: val_f1_score did not improve from 0.96921
# 104/104 [==============================] - 205s 2s/step - loss: 0.0079 - accuracy: 0.9974 - f1_score: 0.9970 - val_loss: 0.1387 - val_accuracy: 0.9649 - val_f1_score: 0.9633 - lr: 7.8125e-06
# Epoch 63/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9972 - f1_score: 0.9967
# Epoch 63: val_f1_score improved from 0.96921 to 0.97226, saving model to saved_outputs_all_augment_3RD_RUN\Densenet121_v4\saved_models\best_Densenet121_v4.h5
# 104/104 [==============================] - 209s 2s/step - loss: 0.0073 - accuracy: 0.9972 - f1_score: 0.9967 - val_loss: 0.1139 - val_accuracy: 0.9718 - val_f1_score: 0.9723 - lr: 7.8125e-06
# Epoch 64/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9983 - f1_score: 0.9979
# Epoch 64: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 205s 2s/step - loss: 0.0069 - accuracy: 0.9983 - f1_score: 0.9979 - val_loss: 0.1293 - val_accuracy: 0.9660 - val_f1_score: 0.9665 - lr: 7.8125e-06
# Epoch 65/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9978 - f1_score: 0.9978
# Epoch 65: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 203s 2s/step - loss: 0.0075 - accuracy: 0.9978 - f1_score: 0.9978 - val_loss: 0.1232 - val_accuracy: 0.9695 - val_f1_score: 0.9680 - lr: 7.8125e-06
# Epoch 66/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9978 - f1_score: 0.9977
# Epoch 66: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 205s 2s/step - loss: 0.0081 - accuracy: 0.9978 - f1_score: 0.9977 - val_loss: 0.1289 - val_accuracy: 0.9680 - val_f1_score: 0.9679 - lr: 7.8125e-06
# Epoch 67/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9975 - f1_score: 0.9973
# Epoch 67: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 205s 2s/step - loss: 0.0083 - accuracy: 0.9975 - f1_score: 0.9973 - val_loss: 0.1212 - val_accuracy: 0.9699 - val_f1_score: 0.9701 - lr: 7.8125e-06
# Epoch 68/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9973 - f1_score: 0.9967
# Epoch 68: val_f1_score did not improve from 0.97226
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 104/104 [==============================] - 204s 2s/step - loss: 0.0081 - accuracy: 0.9973 - f1_score: 0.9967 - val_loss: 0.1303 - val_accuracy: 0.9664 - val_f1_score: 0.9667 - lr: 7.8125e-06
# Epoch 69/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9978 - f1_score: 0.9976
# Epoch 69: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 209s 2s/step - loss: 0.0074 - accuracy: 0.9978 - f1_score: 0.9976 - val_loss: 0.1346 - val_accuracy: 0.9680 - val_f1_score: 0.9680 - lr: 3.9063e-06
# Epoch 70/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9972 - f1_score: 0.9967
# Epoch 70: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 204s 2s/step - loss: 0.0079 - accuracy: 0.9972 - f1_score: 0.9967 - val_loss: 0.1247 - val_accuracy: 0.9653 - val_f1_score: 0.9649 - lr: 3.9063e-06
# Epoch 71/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9976 - f1_score: 0.9973
# Epoch 71: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 207s 2s/step - loss: 0.0073 - accuracy: 0.9976 - f1_score: 0.9973 - val_loss: 0.1225 - val_accuracy: 0.9664 - val_f1_score: 0.9660 - lr: 3.9063e-06
# Epoch 72/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9974 - f1_score: 0.9971
# Epoch 72: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 207s 2s/step - loss: 0.0078 - accuracy: 0.9974 - f1_score: 0.9971 - val_loss: 0.1254 - val_accuracy: 0.9699 - val_f1_score: 0.9696 - lr: 3.9063e-06
# Epoch 73/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9978 - f1_score: 0.9973
# Epoch 73: val_f1_score did not improve from 0.97226
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 104/104 [==============================] - 204s 2s/step - loss: 0.0072 - accuracy: 0.9978 - f1_score: 0.9973 - val_loss: 0.1217 - val_accuracy: 0.9695 - val_f1_score: 0.9711 - lr: 3.9063e-06
# Epoch 74/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9976 - f1_score: 0.9975
# Epoch 74: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 208s 2s/step - loss: 0.0073 - accuracy: 0.9976 - f1_score: 0.9975 - val_loss: 0.1316 - val_accuracy: 0.9687 - val_f1_score: 0.9693 - lr: 1.9531e-06
# Epoch 75/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9985 - f1_score: 0.9983
# Epoch 75: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 206s 2s/step - loss: 0.0070 - accuracy: 0.9985 - f1_score: 0.9983 - val_loss: 0.1302 - val_accuracy: 0.9699 - val_f1_score: 0.9680 - lr: 1.9531e-06
# Epoch 76/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9971 - f1_score: 0.9970
# Epoch 76: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 202s 2s/step - loss: 0.0083 - accuracy: 0.9971 - f1_score: 0.9970 - val_loss: 0.1295 - val_accuracy: 0.9664 - val_f1_score: 0.9658 - lr: 1.9531e-06
# Epoch 77/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9978 - f1_score: 0.9974
# Epoch 77: val_f1_score did not improve from 0.97226
# 104/104 [==============================] - 202s 2s/step - loss: 0.0073 - accuracy: 0.9978 - f1_score: 0.9974 - val_loss: 0.1373 - val_accuracy: 0.9657 - val_f1_score: 0.9633 - lr: 1.9531e-06
# Epoch 78/250
# 104/104 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9971 - f1_score: 0.9964
# Epoch 78: val_f1_score did not improve from 0.97226
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 104/104 [==============================] - 196s 2s/step - loss: 0.0075 - accuracy: 0.9971 - f1_score: 0.9964 - val_loss: 0.1253 - val_accuracy: 0.9672 - val_f1_score: 0.9671 - lr: 1.9531e-06

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 16s 388ms/step - loss: 0.1661 - accuracy: 0.9596 - f1_score: 0.9560
#        model_name  test_loss  test_accuracy  test_f1_score
# 0  Densenet121_v4   0.166118        0.95963       0.955952

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 14s 338ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                            target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score     support
# 0              0.939394  0.953846  0.946565   130.00000
# 1              0.950000  0.950000  0.950000   100.00000
# 2              0.988235  0.933333  0.960000    90.00000
# 3              0.978723  0.910891  0.943590   101.00000
# 4              0.978402  0.963830  0.971061   470.00000
# 5              0.920152  0.956522  0.937984   253.00000
# 6              0.917127  0.954023  0.935211   174.00000
# 7              0.968825  0.937355  0.952830   431.00000
# 8              0.928571  0.949772  0.939052   219.00000
# 9              0.961303  0.981289  0.971193   481.00000
# 10             0.976804  0.971795  0.974293   390.00000
# 11             0.976000  0.960630  0.968254   254.00000
# 12             0.961783  0.993421  0.977346   152.00000
# accuracy       0.959630  0.959630  0.959630     0.95963
# macro avg      0.957332  0.955131  0.955952  3245.00000
# weighted avg   0.960092  0.959630  0.959669  3245.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#        Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  Densenet121_v4   0.95963         0.957332      0.955131        0.955952
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.960092          0.95963           0.959669  0.166118

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.95963
# 1      Macro Precision  0.95733
# 2         Macro Recall  0.95513
# 3       Macro F1-Score  0.95595
# 4            Macro FPR  0.00342
# 5            Macro FNR  0.04487
# 6            Macro FDR  0.04267
# 7            Macro NPV  0.99657
# 8   Weighted Precision  0.96009
# 9      Weighted Recall  0.95963
# 10   Weighted F1-Score  0.95967
# 11        Weighted FPR  0.00413
# 12        Weighted FNR  0.04037
# 13        Weighted FDR  0.03991
# 14        Weighted NPV  0.99568
