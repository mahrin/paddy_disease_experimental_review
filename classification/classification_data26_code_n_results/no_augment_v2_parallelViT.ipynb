# %% [markdown]
# ## Imports

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files


import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random
# from PIL import Image

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf
# from tensorflow.keras.applications import xception, MobileNet, MobileNetV2, Xception, Xception, EfficientNetV2M, InceptionV3
# from tensorflow.keras.applications import EfficientNetB2

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D
from keras.initializers import RandomNormal# weights will be initialized according to a Gaussian distribution 

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=13, average='macro')

# %%
model_name = 'parallelViT'#'T2TViT'#    'InceptionV3'##'T2TViT', , 'MobileNet', 'Xception', 

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)
DATASET_PATH = '../paddy-doctor-diseases-small-split/'
# DATASET_PATH =  '../paddy-doctor-diseases-small-400-split/'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_no_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, 'training_history.csv')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################


IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 13 #len(target_labels) # 13

BATCH_SIZE = 100
EPOCHS = 120 #120
# EXTRA_RUN_AFTER_BEST_EPOCH = 10

################################################################################################
AUGMENT = False
AUGMENT_TYPE = 'basic' # basic, advanced,
################################################################################################

# METRICS_TO_RECORD = 'short'#'full' #'short'  # "full" or 'short'
SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it. 
PATIENCE_EARLY_STOP = 10

# # Checkpoint parameters
# REDUCTION_FACTOR = 0.8            # Factor which lr will be reduced with at plateau
# EPOCH_PATIENCE   = 5              # For how many epochs must the score plateau before reducing lr
# COOLDOWN_EPOCHS  = 5              # How many epochs to wait after learning rate reduction before it can be reduced again

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH ../paddy-doctor-diseases-small-split/
# DATASET_PATH_TRAIN ../paddy-doctor-diseases-small-split/train
# DATASET_PATH_TEST ../paddy-doctor-diseases-small-split/test
# PATH_TO_SAVE_RESULT saved_outputs_no_augment\parallelViT
# PATH_BEST_SAVE_WEIGHT saved_outputs_no_augment\parallelViT\saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_no_augment\parallelViT\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_10704\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation Options in Keras `ImageDataGenerator`
#
# The Keras `ImageDataGenerator` offers various options for image augmentation, enhancing training dataset diversity and improving model robustness. Below is a list of common augmentations available:
#
# 1. **`rotation_range`**: Degrees range (0-180) for random rotations.
#
# 2. **`width_shift_range` & `height_shift_range`**: Fraction of total width or height, or an integer number of pixels, for horizontal or vertical image shift.
#
# 3. **`brightness_range`**: Tuple specifying a range for random brightness adjustment. Values < 1 darken the image, > 1 brighten it.
#
# 4. **`shear_range`**: Shear Intensity (angle in counter-clockwise direction as radians) for shear transformations.
#
# 5. **`zoom_range`**: Range for random zoom. If a float, `[lower, upper] = [1-zoom_range, 1+zoom_range]`.
#
# 6. **`channel_shift_range`**: Range for random channel (color) shifts.
#
# 7. **`fill_mode`**: Mode for filling points outside boundaries ('constant', 'nearest', 'reflect', 'wrap') after transformations.
#
# 8. **`cval`**: Value for filling points outside boundaries when `fill_mode` is 'constant'.
#
# 9. **`horizontal_flip` & `vertical_flip`**: Boolean. Randomly flip images horizontally or vertically.
#
# 10. **`rescale`**: Rescaling factor, often 1/255 to scale pixel values to [0, 1].
#
# 11. **`preprocessing_function`**: Function to be applied to each input after resizing and augmenting.
#
# 12. **`validation_split`**: Fraction of images reserved for validation (between 0 and 1).
#
# 13. **`dtype`**: Dtype to use for generated arrays.
#
# Note: The appropriateness of these augmentations depends on the specific data and use case. Some, like flipping, may not suit certain types of images (e.g., text).

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([  
    iaa.ElasticTransformation(alpha=50, sigma=10)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
# images are alreagy rescaled--so no rescaling is needed
def create_generators(dataset_path_train=DATASET_PATH_TRAIN, 
                      dataset_path_test=DATASET_PATH_TEST, 
                      valid_ratio=VALIDATION_SPLIT, 
                      augment= False, 
                      augment_type='all'):
   
    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.3,  # fraction of total height
                shear_range=0.4,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.25,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                vertical_flip=True,  # randomly flip images vertically
                
                # Pixel-Level Transformations
                brightness_range=[0.6, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.3,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=40,  # degrees
                horizontal_flip=True,  # randomly flip images horizontally
            )
        elif augment_type == 'advanced':     
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
            
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )
    
    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )
    
    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        shuffle = True,        
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )
    
    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements        
        seed = SEED,
        shuffle = False,        
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)
    
    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 10389 images belonging to 13 classes.
# Found 2591 images belonging to 13 classes.
# Found 3245 images belonging to 13 classes.

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'_.h5'
    ## Criteria for early stopping
#    EarlyStop_callback = EarlyStopping(min_delta=0.001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1)

    my_callbacks = [best_model_callback ]#, reduce_LR]#, EarlyStop_callback]
    ##########################################################################################################
    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    return saved_best_model_name, train_history

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    ##########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR, 
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE, 
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=0.5,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=0.00001   # Lower bound on the learning rate.
    )

    my_callbacks = [ best_weight_callback]#, EarlyStop_callback]  , reduce_LRbest_model_callback,
    ##########################################################################################################
    
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    return  PATH_BEST_WEIGHT_SAVE, train_history #model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None, model_name="default_name", SAVE_RESULTS = False):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################
    
    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()


    # if not os.path.exists(PATH_TO_SAVE_RESULT):
    #     # If it does not exist, create it
    #     os.makedirs(PATH_TO_SAVE_RESULT)
    
    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    cm = confusion_matrix(target_labels, predicted_labels)
    
    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        #  # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)
    
    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)
        
        # Calculate support for each class
        support = TP + FN
        
        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []
    
    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)
 
    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)
    
    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)
    
    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)
    
    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)
    
    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels, model_name="default_name", SAVE_RESULTS=False):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)
                
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model, SAVE_RESULTS=False):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator) 
    
    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")
    
    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)
    
    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss, model_name="default_name", SAVE_RESULTS=False ):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')    
    
    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,        
        'Loss': test_loss
    }
    
        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])
    
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        
    del report_df, test_results

# %% [markdown]
# ## MODEL CREATING

# %%
from parallel_vit import ViT as parallelViT
from tensorflow.keras.losses import CategoricalCrossentropy

def get_parallel_vit(): 
    model = parallelViT( #v4 --Improving gradually with each epoch val_loss: 2.2053 - val_accuracy: 0.2600 - val_f1_score: 0.1379
        image_size = max(MODEL_INPUT_SIZE[0], MODEL_INPUT_SIZE[1]),
        patch_size = 16, # original 16
        num_classes = NUM_CLASSES,
        dim = 512,#original 512
        depth = 6,
        heads = 20, # original 8
        mlp_dim = 1024,#original 1024
        num_parallel_branches = 2,  # in paper, they claimed 2 was optimal
        dropout = 0.2,
        emb_dropout = 0.2
    )

    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss=CategoricalCrossentropy(from_logits=True), 
                  run_eagerly=True,
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)

    return model

# %% [markdown]
# # Train and Results 16

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
model = get_parallel_vit()
# model = get_T2TViT()
# # ## Getting the model
# model = get_basic_CNN()

# %%
# training the model and saving the best model as a check point
PATH_BEST_WEIGHT_SAVE, train_history = fit_and_save_best_model_vit(model_name, model)
# Out:
# Epoch 1/120
# 104/104 [==============================] - ETA: 0s - loss: 2.6730 - accuracy: 0.1350 - f1_score: 0.0717
# Epoch 1: val_f1_score improved from -inf to 0.06153, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 430s 4s/step - loss: 2.6730 - accuracy: 0.1350 - f1_score: 0.0717 - val_loss: 2.3886 - val_accuracy: 0.1783 - val_f1_score: 0.0615
# Epoch 2/120
# 104/104 [==============================] - ETA: 0s - loss: 2.4113 - accuracy: 0.1642 - f1_score: 0.0918
# Epoch 2: val_f1_score improved from 0.06153 to 0.07161, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 415s 4s/step - loss: 2.4113 - accuracy: 0.1642 - f1_score: 0.0918 - val_loss: 2.3908 - val_accuracy: 0.1741 - val_f1_score: 0.0716
# Epoch 3/120
# 104/104 [==============================] - ETA: 0s - loss: 2.3001 - accuracy: 0.2163 - f1_score: 0.1260
# Epoch 3: val_f1_score improved from 0.07161 to 0.14266, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 411s 4s/step - loss: 2.3001 - accuracy: 0.2163 - f1_score: 0.1260 - val_loss: 2.2061 - val_accuracy: 0.2740 - val_f1_score: 0.1427
# Epoch 4/120
# 104/104 [==============================] - ETA: 0s - loss: 2.1679 - accuracy: 0.2840 - f1_score: 0.1697
# Epoch 4: val_f1_score improved from 0.14266 to 0.18078, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 416s 4s/step - loss: 2.1679 - accuracy: 0.2840 - f1_score: 0.1697 - val_loss: 2.2152 - val_accuracy: 0.3018 - val_f1_score: 0.1808
# Epoch 5/120
# 104/104 [==============================] - ETA: 0s - loss: 2.0308 - accuracy: 0.3277 - f1_score: 0.2243
# Epoch 5: val_f1_score improved from 0.18078 to 0.29135, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 412s 4s/step - loss: 2.0308 - accuracy: 0.3277 - f1_score: 0.2243 - val_loss: 1.9277 - val_accuracy: 0.3840 - val_f1_score: 0.2914
# Epoch 6/120
# 104/104 [==============================] - ETA: 0s - loss: 1.8843 - accuracy: 0.3769 - f1_score: 0.2859
# Epoch 6: val_f1_score improved from 0.29135 to 0.29977, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 417s 4s/step - loss: 1.8843 - accuracy: 0.3769 - f1_score: 0.2859 - val_loss: 1.8359 - val_accuracy: 0.4199 - val_f1_score: 0.2998
# Epoch 7/120
# 104/104 [==============================] - ETA: 0s - loss: 1.7254 - accuracy: 0.4357 - f1_score: 0.3706
# Epoch 7: val_f1_score improved from 0.29977 to 0.40449, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 418s 4s/step - loss: 1.7254 - accuracy: 0.4357 - f1_score: 0.3706 - val_loss: 1.6821 - val_accuracy: 0.4755 - val_f1_score: 0.4045
# Epoch 8/120
# 104/104 [==============================] - ETA: 0s - loss: 1.5834 - accuracy: 0.4842 - f1_score: 0.4340
# Epoch 8: val_f1_score improved from 0.40449 to 0.49161, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 435s 4s/step - loss: 1.5834 - accuracy: 0.4842 - f1_score: 0.4340 - val_loss: 1.4690 - val_accuracy: 0.5392 - val_f1_score: 0.4916
# Epoch 9/120
# 104/104 [==============================] - ETA: 0s - loss: 1.4460 - accuracy: 0.5265 - f1_score: 0.4949
# Epoch 9: val_f1_score improved from 0.49161 to 0.51977, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 489s 5s/step - loss: 1.4460 - accuracy: 0.5265 - f1_score: 0.4949 - val_loss: 1.5431 - val_accuracy: 0.5469 - val_f1_score: 0.5198
# Epoch 10/120
# 104/104 [==============================] - ETA: 0s - loss: 1.2758 - accuracy: 0.5858 - f1_score: 0.5598
# Epoch 10: val_f1_score improved from 0.51977 to 0.56668, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 467s 4s/step - loss: 1.2758 - accuracy: 0.5858 - f1_score: 0.5598 - val_loss: 1.3105 - val_accuracy: 0.5955 - val_f1_score: 0.5667
# Epoch 11/120
# 104/104 [==============================] - ETA: 0s - loss: 1.1158 - accuracy: 0.6409 - f1_score: 0.6234
# Epoch 11: val_f1_score improved from 0.56668 to 0.62797, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 472s 5s/step - loss: 1.1158 - accuracy: 0.6409 - f1_score: 0.6234 - val_loss: 1.1551 - val_accuracy: 0.6418 - val_f1_score: 0.6280
# Epoch 12/120
# 104/104 [==============================] - ETA: 0s - loss: 1.0067 - accuracy: 0.6708 - f1_score: 0.6603
# Epoch 12: val_f1_score improved from 0.62797 to 0.66056, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 481s 5s/step - loss: 1.0067 - accuracy: 0.6708 - f1_score: 0.6603 - val_loss: 1.0281 - val_accuracy: 0.6804 - val_f1_score: 0.6606
# Epoch 13/120
# 104/104 [==============================] - ETA: 0s - loss: 0.8770 - accuracy: 0.7161 - f1_score: 0.7042
# Epoch 13: val_f1_score improved from 0.66056 to 0.69473, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 511s 5s/step - loss: 0.8770 - accuracy: 0.7161 - f1_score: 0.7042 - val_loss: 1.0187 - val_accuracy: 0.7067 - val_f1_score: 0.6947
# Epoch 14/120
# 104/104 [==============================] - ETA: 0s - loss: 0.7922 - accuracy: 0.7424 - f1_score: 0.7384
# Epoch 14: val_f1_score improved from 0.69473 to 0.73306, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 545s 5s/step - loss: 0.7922 - accuracy: 0.7424 - f1_score: 0.7384 - val_loss: 0.8648 - val_accuracy: 0.7441 - val_f1_score: 0.7331
# Epoch 15/120
# 104/104 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.7878 - f1_score: 0.7874
# Epoch 15: val_f1_score did not improve from 0.73306
# 104/104 [==============================] - 507s 5s/step - loss: 0.6389 - accuracy: 0.7878 - f1_score: 0.7874 - val_loss: 0.8834 - val_accuracy: 0.7433 - val_f1_score: 0.7318
# Epoch 16/120
# 104/104 [==============================] - ETA: 0s - loss: 0.5681 - accuracy: 0.8133 - f1_score: 0.8079
# Epoch 16: val_f1_score improved from 0.73306 to 0.73559, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 533s 5s/step - loss: 0.5681 - accuracy: 0.8133 - f1_score: 0.8079 - val_loss: 0.8840 - val_accuracy: 0.7584 - val_f1_score: 0.7356
# Epoch 17/120
# 104/104 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.8394 - f1_score: 0.8379
# Epoch 17: val_f1_score improved from 0.73559 to 0.79082, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 573s 6s/step - loss: 0.4854 - accuracy: 0.8394 - f1_score: 0.8379 - val_loss: 0.7578 - val_accuracy: 0.7989 - val_f1_score: 0.7908
# Epoch 18/120
# 104/104 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.8566 - f1_score: 0.8525
# Epoch 18: val_f1_score improved from 0.79082 to 0.81418, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 577s 6s/step - loss: 0.4252 - accuracy: 0.8566 - f1_score: 0.8525 - val_loss: 0.6738 - val_accuracy: 0.8209 - val_f1_score: 0.8142
# Epoch 19/120
# 104/104 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8786 - f1_score: 0.8756
# Epoch 19: val_f1_score improved from 0.81418 to 0.81869, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 559s 5s/step - loss: 0.3687 - accuracy: 0.8786 - f1_score: 0.8756 - val_loss: 0.6635 - val_accuracy: 0.8275 - val_f1_score: 0.8187
# Epoch 20/120
# 104/104 [==============================] - ETA: 0s - loss: 0.3248 - accuracy: 0.8892 - f1_score: 0.8890
# Epoch 20: val_f1_score improved from 0.81869 to 0.82516, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 538s 5s/step - loss: 0.3248 - accuracy: 0.8892 - f1_score: 0.8890 - val_loss: 0.6740 - val_accuracy: 0.8283 - val_f1_score: 0.8252
# Epoch 21/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.9058 - f1_score: 0.9061
# Epoch 21: val_f1_score improved from 0.82516 to 0.83716, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 513s 5s/step - loss: 0.2771 - accuracy: 0.9058 - f1_score: 0.9061 - val_loss: 0.6389 - val_accuracy: 0.8429 - val_f1_score: 0.8372
# Epoch 22/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.9107 - f1_score: 0.9109
# Epoch 22: val_f1_score improved from 0.83716 to 0.84564, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 497s 5s/step - loss: 0.2607 - accuracy: 0.9107 - f1_score: 0.9109 - val_loss: 0.6205 - val_accuracy: 0.8526 - val_f1_score: 0.8456
# Epoch 23/120
# 104/104 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9313 - f1_score: 0.9323
# Epoch 23: val_f1_score improved from 0.84564 to 0.85180, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 506s 5s/step - loss: 0.2116 - accuracy: 0.9313 - f1_score: 0.9323 - val_loss: 0.6207 - val_accuracy: 0.8549 - val_f1_score: 0.8518
# Epoch 24/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9372 - f1_score: 0.9363
# Epoch 24: val_f1_score improved from 0.85180 to 0.86083, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 501s 5s/step - loss: 0.1806 - accuracy: 0.9372 - f1_score: 0.9363 - val_loss: 0.5881 - val_accuracy: 0.8680 - val_f1_score: 0.8608
# Epoch 25/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9480 - f1_score: 0.9472
# Epoch 25: val_f1_score did not improve from 0.86083
# 104/104 [==============================] - 545s 5s/step - loss: 0.1557 - accuracy: 0.9480 - f1_score: 0.9472 - val_loss: 0.6506 - val_accuracy: 0.8468 - val_f1_score: 0.8440
# Epoch 26/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9439 - f1_score: 0.9439
# Epoch 26: val_f1_score did not improve from 0.86083
# 104/104 [==============================] - 504s 5s/step - loss: 0.1595 - accuracy: 0.9439 - f1_score: 0.9439 - val_loss: 0.6391 - val_accuracy: 0.8622 - val_f1_score: 0.8554
# Epoch 27/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9586 - f1_score: 0.9592
# Epoch 27: val_f1_score improved from 0.86083 to 0.86666, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 504s 5s/step - loss: 0.1283 - accuracy: 0.9586 - f1_score: 0.9592 - val_loss: 0.6191 - val_accuracy: 0.8707 - val_f1_score: 0.8667
# Epoch 28/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9601 - f1_score: 0.9596
# Epoch 28: val_f1_score did not improve from 0.86666
# 104/104 [==============================] - 498s 5s/step - loss: 0.1215 - accuracy: 0.9601 - f1_score: 0.9596 - val_loss: 0.6165 - val_accuracy: 0.8661 - val_f1_score: 0.8584
# Epoch 29/120
# 104/104 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9625 - f1_score: 0.9615
# Epoch 29: val_f1_score did not improve from 0.86666
# 104/104 [==============================] - 493s 5s/step - loss: 0.1122 - accuracy: 0.9625 - f1_score: 0.9615 - val_loss: 0.6130 - val_accuracy: 0.8699 - val_f1_score: 0.8599
# Epoch 30/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9673 - f1_score: 0.9661
# Epoch 30: val_f1_score improved from 0.86666 to 0.86941, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 505s 5s/step - loss: 0.0984 - accuracy: 0.9673 - f1_score: 0.9661 - val_loss: 0.6323 - val_accuracy: 0.8738 - val_f1_score: 0.8694
# Epoch 31/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9671 - f1_score: 0.9670
# Epoch 31: val_f1_score did not improve from 0.86941
# 104/104 [==============================] - 503s 5s/step - loss: 0.0974 - accuracy: 0.9671 - f1_score: 0.9670 - val_loss: 0.6061 - val_accuracy: 0.8769 - val_f1_score: 0.8693
# Epoch 32/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9689 - f1_score: 0.9696
# Epoch 32: val_f1_score did not improve from 0.86941
# 104/104 [==============================] - 502s 5s/step - loss: 0.0932 - accuracy: 0.9689 - f1_score: 0.9696 - val_loss: 0.6136 - val_accuracy: 0.8742 - val_f1_score: 0.8635
# Epoch 33/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9682 - f1_score: 0.9672
# Epoch 33: val_f1_score improved from 0.86941 to 0.87236, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 523s 5s/step - loss: 0.0909 - accuracy: 0.9682 - f1_score: 0.9672 - val_loss: 0.6329 - val_accuracy: 0.8765 - val_f1_score: 0.8724
# Epoch 34/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9687 - f1_score: 0.9679
# Epoch 34: val_f1_score did not improve from 0.87236
# 104/104 [==============================] - 518s 5s/step - loss: 0.0891 - accuracy: 0.9687 - f1_score: 0.9679 - val_loss: 0.6782 - val_accuracy: 0.8560 - val_f1_score: 0.8535
# Epoch 35/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9733 - f1_score: 0.9737
# Epoch 35: val_f1_score did not improve from 0.87236
# 104/104 [==============================] - 520s 5s/step - loss: 0.0790 - accuracy: 0.9733 - f1_score: 0.9737 - val_loss: 0.6165 - val_accuracy: 0.8773 - val_f1_score: 0.8661
# Epoch 36/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9700 - f1_score: 0.9694
# Epoch 36: val_f1_score improved from 0.87236 to 0.87386, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 527s 5s/step - loss: 0.0938 - accuracy: 0.9700 - f1_score: 0.9694 - val_loss: 0.6356 - val_accuracy: 0.8773 - val_f1_score: 0.8739
# Epoch 37/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9740 - f1_score: 0.9733
# Epoch 37: val_f1_score did not improve from 0.87386
# 104/104 [==============================] - 692s 7s/step - loss: 0.0779 - accuracy: 0.9740 - f1_score: 0.9733 - val_loss: 0.5679 - val_accuracy: 0.8800 - val_f1_score: 0.8726
# Epoch 38/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9781 - f1_score: 0.9750
# Epoch 38: val_f1_score did not improve from 0.87386
# 104/104 [==============================] - 792s 8s/step - loss: 0.0641 - accuracy: 0.9781 - f1_score: 0.9750 - val_loss: 0.6125 - val_accuracy: 0.8780 - val_f1_score: 0.8706
# Epoch 39/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9756 - f1_score: 0.9748
# Epoch 39: val_f1_score improved from 0.87386 to 0.88567, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 779s 7s/step - loss: 0.0705 - accuracy: 0.9756 - f1_score: 0.9748 - val_loss: 0.5598 - val_accuracy: 0.8881 - val_f1_score: 0.8857
# Epoch 40/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9807 - f1_score: 0.9807
# Epoch 40: val_f1_score did not improve from 0.88567
# 104/104 [==============================] - 804s 8s/step - loss: 0.0634 - accuracy: 0.9807 - f1_score: 0.9807 - val_loss: 0.5583 - val_accuracy: 0.8900 - val_f1_score: 0.8834
# Epoch 41/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9778 - f1_score: 0.9774
# Epoch 41: val_f1_score did not improve from 0.88567
# 104/104 [==============================] - 643s 6s/step - loss: 0.0701 - accuracy: 0.9778 - f1_score: 0.9774 - val_loss: 0.6614 - val_accuracy: 0.8742 - val_f1_score: 0.8645
# Epoch 42/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9729 - f1_score: 0.9725
# Epoch 42: val_f1_score did not improve from 0.88567
# 104/104 [==============================] - 556s 5s/step - loss: 0.0802 - accuracy: 0.9729 - f1_score: 0.9725 - val_loss: 0.5872 - val_accuracy: 0.8811 - val_f1_score: 0.8767
# Epoch 43/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9824 - f1_score: 0.9826
# Epoch 43: val_f1_score improved from 0.88567 to 0.89998, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 561s 5s/step - loss: 0.0573 - accuracy: 0.9824 - f1_score: 0.9826 - val_loss: 0.5383 - val_accuracy: 0.9020 - val_f1_score: 0.9000
# Epoch 44/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9848 - f1_score: 0.9841
# Epoch 44: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 577s 6s/step - loss: 0.0473 - accuracy: 0.9848 - f1_score: 0.9841 - val_loss: 0.5755 - val_accuracy: 0.8923 - val_f1_score: 0.8867
# Epoch 45/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9825 - f1_score: 0.9826
# Epoch 45: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 572s 5s/step - loss: 0.0546 - accuracy: 0.9825 - f1_score: 0.9826 - val_loss: 0.5796 - val_accuracy: 0.8850 - val_f1_score: 0.8807
# Epoch 46/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9754 - f1_score: 0.9755
# Epoch 46: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 570s 5s/step - loss: 0.0697 - accuracy: 0.9754 - f1_score: 0.9755 - val_loss: 0.6092 - val_accuracy: 0.8861 - val_f1_score: 0.8783
# Epoch 47/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9759 - f1_score: 0.9746
# Epoch 47: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 600s 6s/step - loss: 0.0705 - accuracy: 0.9759 - f1_score: 0.9746 - val_loss: 0.5920 - val_accuracy: 0.8904 - val_f1_score: 0.8874
# Epoch 48/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9822 - f1_score: 0.9818
# Epoch 48: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 608s 6s/step - loss: 0.0501 - accuracy: 0.9822 - f1_score: 0.9818 - val_loss: 0.5636 - val_accuracy: 0.8931 - val_f1_score: 0.8895
# Epoch 49/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9855 - f1_score: 0.9852
# Epoch 49: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 594s 6s/step - loss: 0.0425 - accuracy: 0.9855 - f1_score: 0.9852 - val_loss: 0.5958 - val_accuracy: 0.8892 - val_f1_score: 0.8877
# Epoch 50/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9830 - f1_score: 0.9828
# Epoch 50: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 597s 6s/step - loss: 0.0532 - accuracy: 0.9830 - f1_score: 0.9828 - val_loss: 0.5583 - val_accuracy: 0.8993 - val_f1_score: 0.8969
# Epoch 51/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9781 - f1_score: 0.9768
# Epoch 51: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 622s 6s/step - loss: 0.0643 - accuracy: 0.9781 - f1_score: 0.9768 - val_loss: 0.5825 - val_accuracy: 0.8919 - val_f1_score: 0.8888
# Epoch 52/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9843 - f1_score: 0.9849
# Epoch 52: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 631s 6s/step - loss: 0.0470 - accuracy: 0.9843 - f1_score: 0.9849 - val_loss: 0.6513 - val_accuracy: 0.8769 - val_f1_score: 0.8715
# Epoch 53/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9799 - f1_score: 0.9800
# Epoch 53: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 644s 6s/step - loss: 0.0593 - accuracy: 0.9799 - f1_score: 0.9800 - val_loss: 0.6396 - val_accuracy: 0.8838 - val_f1_score: 0.8777
# Epoch 54/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9808 - f1_score: 0.9792
# Epoch 54: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 624s 6s/step - loss: 0.0602 - accuracy: 0.9808 - f1_score: 0.9792 - val_loss: 0.6130 - val_accuracy: 0.8877 - val_f1_score: 0.8797
# Epoch 55/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9859 - f1_score: 0.9849
# Epoch 55: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 622s 6s/step - loss: 0.0442 - accuracy: 0.9859 - f1_score: 0.9849 - val_loss: 0.5809 - val_accuracy: 0.9004 - val_f1_score: 0.8942
# Epoch 56/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9876 - f1_score: 0.9881
# Epoch 56: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 647s 6s/step - loss: 0.0390 - accuracy: 0.9876 - f1_score: 0.9881 - val_loss: 0.6147 - val_accuracy: 0.8834 - val_f1_score: 0.8792
# Epoch 57/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9834 - f1_score: 0.9838
# Epoch 57: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 670s 6s/step - loss: 0.0462 - accuracy: 0.9834 - f1_score: 0.9838 - val_loss: 0.5911 - val_accuracy: 0.8904 - val_f1_score: 0.8785
# Epoch 58/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9859 - f1_score: 0.9859
# Epoch 58: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 718s 7s/step - loss: 0.0410 - accuracy: 0.9859 - f1_score: 0.9859 - val_loss: 0.5771 - val_accuracy: 0.8962 - val_f1_score: 0.8896
# Epoch 59/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9839 - f1_score: 0.9834
# Epoch 59: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 726s 7s/step - loss: 0.0462 - accuracy: 0.9839 - f1_score: 0.9834 - val_loss: 0.6593 - val_accuracy: 0.8788 - val_f1_score: 0.8744
# Epoch 60/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9858 - f1_score: 0.9857
# Epoch 60: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 730s 7s/step - loss: 0.0418 - accuracy: 0.9858 - f1_score: 0.9857 - val_loss: 0.5976 - val_accuracy: 0.8923 - val_f1_score: 0.8878
# Epoch 61/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9887 - f1_score: 0.9878
# Epoch 61: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 798s 8s/step - loss: 0.0317 - accuracy: 0.9887 - f1_score: 0.9878 - val_loss: 0.6550 - val_accuracy: 0.8858 - val_f1_score: 0.8812
# Epoch 62/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9866 - f1_score: 0.9856
# Epoch 62: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 799s 8s/step - loss: 0.0384 - accuracy: 0.9866 - f1_score: 0.9856 - val_loss: 0.5835 - val_accuracy: 0.8912 - val_f1_score: 0.8896
# Epoch 63/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9898 - f1_score: 0.9894
# Epoch 63: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 775s 7s/step - loss: 0.0364 - accuracy: 0.9898 - f1_score: 0.9894 - val_loss: 0.6142 - val_accuracy: 0.8946 - val_f1_score: 0.8908
# Epoch 64/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9883 - f1_score: 0.9887
# Epoch 64: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 700s 7s/step - loss: 0.0370 - accuracy: 0.9883 - f1_score: 0.9887 - val_loss: 0.6137 - val_accuracy: 0.8954 - val_f1_score: 0.8929
# Epoch 65/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9867 - f1_score: 0.9853
# Epoch 65: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 734s 7s/step - loss: 0.0385 - accuracy: 0.9867 - f1_score: 0.9853 - val_loss: 0.6489 - val_accuracy: 0.8842 - val_f1_score: 0.8713
# Epoch 66/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9839 - f1_score: 0.9830
# Epoch 66: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 831s 8s/step - loss: 0.0483 - accuracy: 0.9839 - f1_score: 0.9830 - val_loss: 0.6368 - val_accuracy: 0.8935 - val_f1_score: 0.8856
# Epoch 67/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9877 - f1_score: 0.9864
# Epoch 67: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 754s 7s/step - loss: 0.0351 - accuracy: 0.9877 - f1_score: 0.9864 - val_loss: 0.6830 - val_accuracy: 0.8842 - val_f1_score: 0.8780
# Epoch 68/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9859 - f1_score: 0.9843
# Epoch 68: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 709s 7s/step - loss: 0.0435 - accuracy: 0.9859 - f1_score: 0.9843 - val_loss: 0.7241 - val_accuracy: 0.8838 - val_f1_score: 0.8764
# Epoch 69/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9863 - f1_score: 0.9859
# Epoch 69: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 773s 7s/step - loss: 0.0422 - accuracy: 0.9863 - f1_score: 0.9859 - val_loss: 0.6511 - val_accuracy: 0.8877 - val_f1_score: 0.8882
# Epoch 70/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9886 - f1_score: 0.9889
# Epoch 70: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 782s 7s/step - loss: 0.0335 - accuracy: 0.9886 - f1_score: 0.9889 - val_loss: 0.6383 - val_accuracy: 0.8888 - val_f1_score: 0.8864
# Epoch 71/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9885 - f1_score: 0.9875
# Epoch 71: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 799s 8s/step - loss: 0.0324 - accuracy: 0.9885 - f1_score: 0.9875 - val_loss: 0.5645 - val_accuracy: 0.8946 - val_f1_score: 0.8879
# Epoch 72/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9930 - f1_score: 0.9923
# Epoch 72: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 750s 7s/step - loss: 0.0216 - accuracy: 0.9930 - f1_score: 0.9923 - val_loss: 0.5871 - val_accuracy: 0.9054 - val_f1_score: 0.8984
# Epoch 73/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9898 - f1_score: 0.9893
# Epoch 73: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 771s 7s/step - loss: 0.0296 - accuracy: 0.9898 - f1_score: 0.9893 - val_loss: 0.6295 - val_accuracy: 0.8958 - val_f1_score: 0.8958
# Epoch 74/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9892 - f1_score: 0.9898
# Epoch 74: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 785s 8s/step - loss: 0.0323 - accuracy: 0.9892 - f1_score: 0.9898 - val_loss: 0.6462 - val_accuracy: 0.8869 - val_f1_score: 0.8819
# Epoch 75/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9869 - f1_score: 0.9859
# Epoch 75: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 798s 8s/step - loss: 0.0372 - accuracy: 0.9869 - f1_score: 0.9859 - val_loss: 0.6029 - val_accuracy: 0.8997 - val_f1_score: 0.8967
# Epoch 76/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9895 - f1_score: 0.9887
# Epoch 76: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 748s 7s/step - loss: 0.0341 - accuracy: 0.9895 - f1_score: 0.9887 - val_loss: 0.5986 - val_accuracy: 0.8981 - val_f1_score: 0.8936
# Epoch 77/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9867 - f1_score: 0.9864
# Epoch 77: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 770s 7s/step - loss: 0.0374 - accuracy: 0.9867 - f1_score: 0.9864 - val_loss: 0.6520 - val_accuracy: 0.8850 - val_f1_score: 0.8796
# Epoch 78/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9792 - f1_score: 0.9780
# Epoch 78: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 964s 9s/step - loss: 0.0620 - accuracy: 0.9792 - f1_score: 0.9780 - val_loss: 0.6252 - val_accuracy: 0.8958 - val_f1_score: 0.8873
# Epoch 79/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9866 - f1_score: 0.9867
# Epoch 79: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1350s 13s/step - loss: 0.0394 - accuracy: 0.9866 - f1_score: 0.9867 - val_loss: 0.5766 - val_accuracy: 0.8923 - val_f1_score: 0.8852
# Epoch 80/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9893 - f1_score: 0.9897
# Epoch 80: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1312s 13s/step - loss: 0.0306 - accuracy: 0.9893 - f1_score: 0.9897 - val_loss: 0.5692 - val_accuracy: 0.9024 - val_f1_score: 0.8941
# Epoch 81/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9894 - f1_score: 0.9899
# Epoch 81: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1356s 13s/step - loss: 0.0300 - accuracy: 0.9894 - f1_score: 0.9899 - val_loss: 0.6496 - val_accuracy: 0.8958 - val_f1_score: 0.8882
# Epoch 82/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9886 - f1_score: 0.9891
# Epoch 82: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1411s 14s/step - loss: 0.0360 - accuracy: 0.9886 - f1_score: 0.9891 - val_loss: 0.6074 - val_accuracy: 0.8954 - val_f1_score: 0.8914
# Epoch 83/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9903 - f1_score: 0.9901
# Epoch 83: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1418s 14s/step - loss: 0.0304 - accuracy: 0.9903 - f1_score: 0.9901 - val_loss: 0.5800 - val_accuracy: 0.8966 - val_f1_score: 0.8911
# Epoch 84/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9933 - f1_score: 0.9931
# Epoch 84: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1480s 14s/step - loss: 0.0232 - accuracy: 0.9933 - f1_score: 0.9931 - val_loss: 0.6212 - val_accuracy: 0.8962 - val_f1_score: 0.8942
# Epoch 85/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9925 - f1_score: 0.9927
# Epoch 85: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1518s 15s/step - loss: 0.0234 - accuracy: 0.9925 - f1_score: 0.9927 - val_loss: 0.5907 - val_accuracy: 0.8970 - val_f1_score: 0.8951
# Epoch 86/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9937 - f1_score: 0.9935
# Epoch 86: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1506s 14s/step - loss: 0.0200 - accuracy: 0.9937 - f1_score: 0.9935 - val_loss: 0.6005 - val_accuracy: 0.8954 - val_f1_score: 0.8852
# Epoch 87/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9898 - f1_score: 0.9898
# Epoch 87: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1564s 15s/step - loss: 0.0298 - accuracy: 0.9898 - f1_score: 0.9898 - val_loss: 0.6125 - val_accuracy: 0.8888 - val_f1_score: 0.8850
# Epoch 88/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9911 - f1_score: 0.9911
# Epoch 88: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1705s 16s/step - loss: 0.0257 - accuracy: 0.9911 - f1_score: 0.9911 - val_loss: 0.5909 - val_accuracy: 0.9016 - val_f1_score: 0.8956
# Epoch 89/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9917 - f1_score: 0.9909
# Epoch 89: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1568s 15s/step - loss: 0.0261 - accuracy: 0.9917 - f1_score: 0.9909 - val_loss: 0.6596 - val_accuracy: 0.8935 - val_f1_score: 0.8904
# Epoch 90/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9876 - f1_score: 0.9855
# Epoch 90: val_f1_score did not improve from 0.89998
# 104/104 [==============================] - 1727s 17s/step - loss: 0.0374 - accuracy: 0.9876 - f1_score: 0.9855 - val_loss: 0.6262 - val_accuracy: 0.8827 - val_f1_score: 0.8731
# Epoch 91/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9911 - f1_score: 0.9901
# Epoch 91: val_f1_score improved from 0.89998 to 0.90478, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 1719s 16s/step - loss: 0.0267 - accuracy: 0.9911 - f1_score: 0.9901 - val_loss: 0.5431 - val_accuracy: 0.9101 - val_f1_score: 0.9048
# Epoch 92/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9910 - f1_score: 0.9906
# Epoch 92: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 1703s 16s/step - loss: 0.0273 - accuracy: 0.9910 - f1_score: 0.9906 - val_loss: 0.6193 - val_accuracy: 0.8919 - val_f1_score: 0.8845
# Epoch 93/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9882 - f1_score: 0.9870
# Epoch 93: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 1839s 18s/step - loss: 0.0349 - accuracy: 0.9882 - f1_score: 0.9870 - val_loss: 0.6140 - val_accuracy: 0.8885 - val_f1_score: 0.8831
# Epoch 94/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9880 - f1_score: 0.9863
# Epoch 94: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 999s 9s/step - loss: 0.0367 - accuracy: 0.9880 - f1_score: 0.9863 - val_loss: 0.5963 - val_accuracy: 0.9035 - val_f1_score: 0.8969
# Epoch 95/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9898 - f1_score: 0.9890
# Epoch 95: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 978s 9s/step - loss: 0.0298 - accuracy: 0.9898 - f1_score: 0.9890 - val_loss: 0.6184 - val_accuracy: 0.8950 - val_f1_score: 0.8912
# Epoch 96/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9917 - f1_score: 0.9908
# Epoch 96: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 1171s 11s/step - loss: 0.0261 - accuracy: 0.9917 - f1_score: 0.9908 - val_loss: 0.6273 - val_accuracy: 0.9027 - val_f1_score: 0.9005
# Epoch 97/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9918 - f1_score: 0.9911
# Epoch 97: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 1603s 15s/step - loss: 0.0262 - accuracy: 0.9918 - f1_score: 0.9911 - val_loss: 0.6274 - val_accuracy: 0.8923 - val_f1_score: 0.8830
# Epoch 98/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9930 - f1_score: 0.9930
# Epoch 98: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 880s 8s/step - loss: 0.0214 - accuracy: 0.9930 - f1_score: 0.9930 - val_loss: 0.6493 - val_accuracy: 0.8962 - val_f1_score: 0.8966
# Epoch 99/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9886 - f1_score: 0.9897
# Epoch 99: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 898s 9s/step - loss: 0.0350 - accuracy: 0.9886 - f1_score: 0.9897 - val_loss: 0.6326 - val_accuracy: 0.8900 - val_f1_score: 0.8884
# Epoch 100/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9936 - f1_score: 0.9933
# Epoch 100: val_f1_score did not improve from 0.90478
# 104/104 [==============================] - 873s 8s/step - loss: 0.0229 - accuracy: 0.9936 - f1_score: 0.9933 - val_loss: 0.5468 - val_accuracy: 0.9062 - val_f1_score: 0.9016
# Epoch 101/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9921 - f1_score: 0.9916
# Epoch 101: val_f1_score improved from 0.90478 to 0.90527, saving model to saved_outputs_no_augment\parallelViT\saved_weights\best_parallelViT_weights
# 104/104 [==============================] - 961s 9s/step - loss: 0.0233 - accuracy: 0.9921 - f1_score: 0.9916 - val_loss: 0.5486 - val_accuracy: 0.9105 - val_f1_score: 0.9053
# Epoch 102/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9926 - f1_score: 0.9914
# Epoch 102: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 991s 9s/step - loss: 0.0264 - accuracy: 0.9926 - f1_score: 0.9914 - val_loss: 0.6518 - val_accuracy: 0.8973 - val_f1_score: 0.8958
# Epoch 103/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9908 - f1_score: 0.9895
# Epoch 103: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1031s 10s/step - loss: 0.0321 - accuracy: 0.9908 - f1_score: 0.9895 - val_loss: 0.6500 - val_accuracy: 0.8970 - val_f1_score: 0.8911
# Epoch 104/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9915 - f1_score: 0.9911
# Epoch 104: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 994s 10s/step - loss: 0.0287 - accuracy: 0.9915 - f1_score: 0.9911 - val_loss: 0.6499 - val_accuracy: 0.9016 - val_f1_score: 0.8954
# Epoch 105/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9910 - f1_score: 0.9915
# Epoch 105: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1100s 11s/step - loss: 0.0253 - accuracy: 0.9910 - f1_score: 0.9915 - val_loss: 0.6294 - val_accuracy: 0.9000 - val_f1_score: 0.8933
# Epoch 106/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9920 - f1_score: 0.9914
# Epoch 106: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1183s 11s/step - loss: 0.0227 - accuracy: 0.9920 - f1_score: 0.9914 - val_loss: 0.6931 - val_accuracy: 0.8912 - val_f1_score: 0.8831
# Epoch 107/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9892 - f1_score: 0.9895
# Epoch 107: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1175s 11s/step - loss: 0.0337 - accuracy: 0.9892 - f1_score: 0.9895 - val_loss: 0.6408 - val_accuracy: 0.8892 - val_f1_score: 0.8848
# Epoch 108/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9902 - f1_score: 0.9902
# Epoch 108: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1143s 11s/step - loss: 0.0312 - accuracy: 0.9902 - f1_score: 0.9902 - val_loss: 0.6191 - val_accuracy: 0.8939 - val_f1_score: 0.8908
# Epoch 109/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9932 - f1_score: 0.9927
# Epoch 109: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1258s 12s/step - loss: 0.0233 - accuracy: 0.9932 - f1_score: 0.9927 - val_loss: 0.6016 - val_accuracy: 0.9027 - val_f1_score: 0.8985
# Epoch 110/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9938 - f1_score: 0.9945
# Epoch 110: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1309s 13s/step - loss: 0.0185 - accuracy: 0.9938 - f1_score: 0.9945 - val_loss: 0.6213 - val_accuracy: 0.9043 - val_f1_score: 0.9023
# Epoch 111/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9924 - f1_score: 0.9925
# Epoch 111: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1188s 11s/step - loss: 0.0244 - accuracy: 0.9924 - f1_score: 0.9925 - val_loss: 0.5862 - val_accuracy: 0.9058 - val_f1_score: 0.9019
# Epoch 112/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9925 - f1_score: 0.9920
# Epoch 112: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1188s 11s/step - loss: 0.0214 - accuracy: 0.9925 - f1_score: 0.9920 - val_loss: 0.6028 - val_accuracy: 0.9004 - val_f1_score: 0.8961
# Epoch 113/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9937 - f1_score: 0.9934
# Epoch 113: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1156s 11s/step - loss: 0.0207 - accuracy: 0.9937 - f1_score: 0.9934 - val_loss: 0.5891 - val_accuracy: 0.8989 - val_f1_score: 0.8936
# Epoch 114/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9914 - f1_score: 0.9914
# Epoch 114: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1145s 11s/step - loss: 0.0269 - accuracy: 0.9914 - f1_score: 0.9914 - val_loss: 0.5807 - val_accuracy: 0.9070 - val_f1_score: 0.9014
# Epoch 115/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9907 - f1_score: 0.9910
# Epoch 115: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1164s 11s/step - loss: 0.0274 - accuracy: 0.9907 - f1_score: 0.9910 - val_loss: 0.5967 - val_accuracy: 0.9016 - val_f1_score: 0.8988
# Epoch 116/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9911 - f1_score: 0.9917
# Epoch 116: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1311s 13s/step - loss: 0.0254 - accuracy: 0.9911 - f1_score: 0.9917 - val_loss: 0.6023 - val_accuracy: 0.9074 - val_f1_score: 0.9024
# Epoch 117/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9939 - f1_score: 0.9942
# Epoch 117: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1174s 11s/step - loss: 0.0176 - accuracy: 0.9939 - f1_score: 0.9942 - val_loss: 0.5802 - val_accuracy: 0.9085 - val_f1_score: 0.9018
# Epoch 118/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9915 - f1_score: 0.9910
# Epoch 118: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1157s 11s/step - loss: 0.0229 - accuracy: 0.9915 - f1_score: 0.9910 - val_loss: 0.6278 - val_accuracy: 0.9047 - val_f1_score: 0.8974
# Epoch 119/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9910 - f1_score: 0.9894
# Epoch 119: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1289s 12s/step - loss: 0.0247 - accuracy: 0.9910 - f1_score: 0.9894 - val_loss: 0.5868 - val_accuracy: 0.8981 - val_f1_score: 0.8956
# Epoch 120/120
# 104/104 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9957 - f1_score: 0.9946
# Epoch 120: val_f1_score did not improve from 0.90527
# 104/104 [==============================] - 1210s 12s/step - loss: 0.0157 - accuracy: 0.9957 - f1_score: 0.9946 - val_loss: 0.5778 - val_accuracy: 0.9004 - val_f1_score: 0.8976

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history, model_name = model_name, SAVE_RESULTS= SAVE_RESULTS)

# %%
best_model = get_parallel_vit()

best_model.load_weights(PATH_BEST_WEIGHT_SAVE)
    
# best_model.fit(
#     train_generator,
#     epochs= 1,
#     batch_size=BATCH_SIZE,
#     validation_data=valid_generator,
# )

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 33/33 [==============================] - 224s 7s/step - loss: 0.5696 - accuracy: 0.9042 - f1_score: 0.8971
#     model_name  test_loss  test_accuracy  test_f1_score
# 0  parallelViT    0.56959        0.90416       0.897147

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test  
############################################################################################################]
# Out:
# 33/33 [==============================] - 220s 7s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, 
                                      target_labels=true_labels_y_test , 
                                      model_name=model_name, 
                                      SAVE_RESULTS=SAVE_RESULTS)
# Out:
#               precision    recall  f1-score     support
# 0              0.896825  0.869231  0.882812   130.00000
# 1              0.957447  0.900000  0.927835   100.00000
# 2              0.768519  0.922222  0.838384    90.00000
# 3              0.936842  0.881188  0.908163   101.00000
# 4              0.919037  0.893617  0.906149   470.00000
# 5              0.809028  0.920949  0.861368   253.00000
# 6              0.824742  0.919540  0.869565   174.00000
# 7              0.912240  0.916473  0.914352   431.00000
# 8              0.908654  0.863014  0.885246   219.00000
# 9              0.952278  0.912682  0.932059   481.00000
# 10             0.938303  0.935897  0.937099   390.00000
# 11             0.926724  0.846457  0.884774   254.00000
# 12             0.893750  0.940789  0.916667   152.00000
# accuracy       0.904160  0.904160  0.904160     0.90416
# macro avg      0.895722  0.901697  0.897267  3245.00000
# weighted avg   0.907134  0.904160  0.904671  3245.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, 
                           target_labels=true_labels_y_test , 
                           model_name=model_name, 
                           SAVE_RESULTS=SAVE_RESULTS)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels, 
                                       target_labels=true_labels_y_test, 
                                       model_name=model_name, 
                                       SAVE_RESULTS=SAVE_RESULTS, 
                                       test_loss=test_loss)
# Out:
#     Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  parallelViT   0.90416         0.895722      0.901697        0.897267
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score     Loss
# 0            0.907134          0.90416           0.904671  0.56959

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc, SHOW_RESULTS=True, SAVE_RESULTS=True)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.90416
# 1      Macro Precision  0.89572
# 2         Macro Recall  0.90170
# 3       Macro F1-Score  0.89727
# 4            Macro FPR  0.00811
# 5            Macro FNR  0.09830
# 6            Macro FDR  0.10428
# 7            Macro NPV  0.99182
# 8   Weighted Precision  0.90713
# 9      Weighted Recall  0.90416
# 10   Weighted F1-Score  0.90467
# 11        Weighted FPR  0.00955
# 12        Weighted FNR  0.09584
# 13        Weighted FDR  0.09287
# 14        Weighted NPV  0.98933
