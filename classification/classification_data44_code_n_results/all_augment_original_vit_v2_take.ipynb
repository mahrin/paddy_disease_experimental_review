# %% [markdown]
# ## Imports

# %%
# !pip install tensorflow-addons

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=4, average='macro')

# %% [markdown]
# ## Setting the paths

# %%
model_name = 'original_vit_v2'#'Xception'#'DenseNet121'#    'InceptionV3'##  'MobileNet', 'Xception', ensemble2, ensemble3, 'parallel_vit'

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
# PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/classification'
sys.path.append(PATH_TO_CODE)
# DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/classification/data44_resized_splited'
DATASET_PATH = r'data44_resized_splited'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_all_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')


if not os.path.exists(PATH_TO_SAVE_RESULT):
    # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################


IMG_HEIGHT = 200
IMG_WIDTH = 200
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.3
NUM_CLASSES = 4

BATCH_SIZE = 64
EPOCHS = 150

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'all' #'all'## basic, advanced,
################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.



PATIENCE_EARLY_STOP = 12 # With no improvement in Loss, will stop training

# # Checkpoint parameters
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
PATIENCE_LR_REDUCE=3      # Number of epochs with no improvement after which learning rate will be reduced
COOLDOWN_EPOCHS  = 2              # How many epochs to wait after learning rate reduction before it can be reduced again
MIN_LR = 1e-9
INITIAL_LR =  0.0001 # with 0.001 got 99 percent

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_SAVE_TIME ", PATH_SAVE_TIME )
print("PATH_SAVE_HISTORY", PATH_SAVE_HISTORY)
print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH data44_resized_splited
# DATASET_PATH_TRAIN data44_resized_splited\train
# DATASET_PATH_TEST data44_resized_splited\test
# PATH_SAVE_TIME  saved_outputs_all_augment\original_vit_v2\original_vit_v2_training_time.csv
# PATH_SAVE_HISTORY saved_outputs_all_augment\original_vit_v2\original_vit_v2_training_history.csv
# PATH_TO_SAVE_RESULT saved_outputs_all_augment\original_vit_v2
# PATH_BEST_SAVE_WEIGHT saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_all_augment\original_vit_v2\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_15792\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([
    iaa.ElasticTransformation(alpha=10, sigma=5)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
def create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                      dataset_path_test=DATASET_PATH_TEST,
                      valid_ratio=VALIDATION_SPLIT,
                      augment= False,
                      augment_type='basic'):

    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=10,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.2,  # fraction of total height
                shear_range=0.2,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically

                # Pixel-Level Transformations
                brightness_range=[0.8, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.2,  # range for random channel shifts

                # # Advanced functions
                # preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                # rotation_range=10,  # degrees
                zoom_range=0.2,  # zoom range for random zoom
                # vertical_flip=True,  # randomly flip images vertically
                horizontal_flip=True,  # randomly flip images horizontally
            )
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )

    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )

    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )

    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        seed = SEED,
        shuffle = False,
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)

    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 3324 images belonging to 4 classes.
# Found 1421 images belonging to 4 classes.
# Found 1187 images belonging to 4 classes.

# %% [markdown]
# ## Visualization

# %%
def plot_images(images, labels, classes=None):
    plt.figure(figsize=(8, 8))
    for i in range(15):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)

        # If class labels are provided, add them to the subplot
        if classes is not None:
            label = classes[np.argmax(labels[i])]
            plt.xlabel(label)
    plt.show()


train_images, train_labels = next(train_generator)  # Fetch a batch of images and labels


plot_images(train_images, train_labels)

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    ##########################################################################################################

    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)
    ##########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR,   # Lower bound on the learning rate.
        cooldown = COOLDOWN_EPOCHS
    )

    my_callbacks = [best_weight_callback , reduce_LR , EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return  PATH_BEST_WEIGHT_SAVE, train_history , total_time#model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)

    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)

    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)

        # Calculate support for each class
        support = TP + FN

        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []

    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)

    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)

    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)

    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator)

    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")

    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)


    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Loss': test_loss
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

    del report_df, test_results

# %% [markdown]
# # MODEL CREATING

# %%
from vit import ViT
from tensorflow.keras.losses import CategoricalCrossentropy

def get_original_vit():
    model = ViT( # v1 val_accuracy: 0.3172 - val_f1_score: 0.1981
    image_size = 128,
    patch_size = 16,
    num_classes = NUM_CLASSES,
    dim = 512,
    depth = 6,
    heads = 16,
    mlp_dim = 1024,
    dropout = 0.1,
    emb_dropout = 0.1
    )

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss=CategoricalCrossentropy(from_logits=True),
                  run_eagerly=True,
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)

    return model

# %% [markdown]
# # Train and Results

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()
# model = get_ensemble2_model()
model = get_original_vit()

# %%
# training the model and saving the best model as a check point
PATH_BEST_WEIGHT_SAVE, train_history , total_time = fit_and_save_best_model_vit(model_name, model)
# Out:
# Epoch 1/150
# 52/52 [==============================] - ETA: 0s - loss: 1.7545 - accuracy: 0.3192 - f1_score: 0.3177
# Epoch 1: val_f1_score improved from -inf to 0.41898, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 81s 2s/step - loss: 1.7545 - accuracy: 0.3192 - f1_score: 0.3177 - val_loss: 1.2382 - val_accuracy: 0.4433 - val_f1_score: 0.4190 - lr: 1.0000e-04
# Epoch 2/150
# 52/52 [==============================] - ETA: 0s - loss: 1.2003 - accuracy: 0.4714 - f1_score: 0.4681
# Epoch 2: val_f1_score improved from 0.41898 to 0.53633, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 81s 2s/step - loss: 1.2003 - accuracy: 0.4714 - f1_score: 0.4681 - val_loss: 1.1262 - val_accuracy: 0.5524 - val_f1_score: 0.5363 - lr: 1.0000e-04
# Epoch 3/150
# 52/52 [==============================] - ETA: 0s - loss: 1.0123 - accuracy: 0.5972 - f1_score: 0.5955
# Epoch 3: val_f1_score improved from 0.53633 to 0.69026, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 80s 2s/step - loss: 1.0123 - accuracy: 0.5972 - f1_score: 0.5955 - val_loss: 0.8704 - val_accuracy: 0.6946 - val_f1_score: 0.6903 - lr: 1.0000e-04
# Epoch 4/150
# 52/52 [==============================] - ETA: 0s - loss: 0.8840 - accuracy: 0.6619 - f1_score: 0.6606
# Epoch 4: val_f1_score improved from 0.69026 to 0.69912, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 93s 2s/step - loss: 0.8840 - accuracy: 0.6619 - f1_score: 0.6606 - val_loss: 0.8372 - val_accuracy: 0.6988 - val_f1_score: 0.6991 - lr: 1.0000e-04
# Epoch 5/150
# 52/52 [==============================] - ETA: 0s - loss: 0.8091 - accuracy: 0.6859 - f1_score: 0.6863
# Epoch 5: val_f1_score improved from 0.69912 to 0.71258, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 89s 2s/step - loss: 0.8091 - accuracy: 0.6859 - f1_score: 0.6863 - val_loss: 0.7660 - val_accuracy: 0.7143 - val_f1_score: 0.7126 - lr: 1.0000e-04
# Epoch 6/150
# 52/52 [==============================] - ETA: 0s - loss: 0.7609 - accuracy: 0.7052 - f1_score: 0.7056
# Epoch 6: val_f1_score did not improve from 0.71258
# 52/52 [==============================] - 96s 2s/step - loss: 0.7609 - accuracy: 0.7052 - f1_score: 0.7056 - val_loss: 0.9466 - val_accuracy: 0.6242 - val_f1_score: 0.6172 - lr: 1.0000e-04
# Epoch 7/150
# 52/52 [==============================] - ETA: 0s - loss: 0.7391 - accuracy: 0.7151 - f1_score: 0.7152
# Epoch 7: val_f1_score did not improve from 0.71258
# 52/52 [==============================] - 108s 2s/step - loss: 0.7391 - accuracy: 0.7151 - f1_score: 0.7152 - val_loss: 0.7847 - val_accuracy: 0.6995 - val_f1_score: 0.6982 - lr: 1.0000e-04
# Epoch 8/150
# 52/52 [==============================] - ETA: 0s - loss: 0.7031 - accuracy: 0.7250 - f1_score: 0.7257
# Epoch 8: val_f1_score did not improve from 0.71258
# 52/52 [==============================] - 113s 2s/step - loss: 0.7031 - accuracy: 0.7250 - f1_score: 0.7257 - val_loss: 0.6893 - val_accuracy: 0.7136 - val_f1_score: 0.7081 - lr: 1.0000e-04
# Epoch 9/150
# 52/52 [==============================] - ETA: 0s - loss: 0.6483 - accuracy: 0.7458 - f1_score: 0.7467
# Epoch 9: val_f1_score improved from 0.71258 to 0.73432, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 116s 2s/step - loss: 0.6483 - accuracy: 0.7458 - f1_score: 0.7467 - val_loss: 0.6683 - val_accuracy: 0.7403 - val_f1_score: 0.7343 - lr: 1.0000e-04
# Epoch 10/150
# 52/52 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.7662 - f1_score: 0.7675
# Epoch 10: val_f1_score improved from 0.73432 to 0.76619, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 121s 2s/step - loss: 0.5836 - accuracy: 0.7662 - f1_score: 0.7675 - val_loss: 0.6237 - val_accuracy: 0.7692 - val_f1_score: 0.7662 - lr: 1.0000e-04
# Epoch 11/150
# 52/52 [==============================] - ETA: 0s - loss: 0.5728 - accuracy: 0.7690 - f1_score: 0.7700
# Epoch 11: val_f1_score improved from 0.76619 to 0.79267, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 118s 2s/step - loss: 0.5728 - accuracy: 0.7690 - f1_score: 0.7700 - val_loss: 0.5292 - val_accuracy: 0.7910 - val_f1_score: 0.7927 - lr: 1.0000e-04
# Epoch 12/150
# 52/52 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.8075 - f1_score: 0.8092
# Epoch 12: val_f1_score improved from 0.79267 to 0.82978, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 81s 2s/step - loss: 0.4826 - accuracy: 0.8075 - f1_score: 0.8092 - val_loss: 0.4696 - val_accuracy: 0.8297 - val_f1_score: 0.8298 - lr: 1.0000e-04
# Epoch 13/150
# 52/52 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.7966 - f1_score: 0.7978
# Epoch 13: val_f1_score did not improve from 0.82978
# 52/52 [==============================] - 42s 811ms/step - loss: 0.5235 - accuracy: 0.7966 - f1_score: 0.7978 - val_loss: 0.4950 - val_accuracy: 0.8100 - val_f1_score: 0.8106 - lr: 1.0000e-04
# Epoch 14/150
# 52/52 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.8228 - f1_score: 0.8239
# Epoch 14: val_f1_score did not improve from 0.82978
# 52/52 [==============================] - 89s 2s/step - loss: 0.4615 - accuracy: 0.8228 - f1_score: 0.8239 - val_loss: 0.5350 - val_accuracy: 0.7868 - val_f1_score: 0.7904 - lr: 1.0000e-04
# Epoch 15/150
# 52/52 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8288 - f1_score: 0.8295
# Epoch 15: val_f1_score improved from 0.82978 to 0.83288, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 93s 2s/step - loss: 0.4275 - accuracy: 0.8288 - f1_score: 0.8295 - val_loss: 0.4592 - val_accuracy: 0.8318 - val_f1_score: 0.8329 - lr: 1.0000e-04
# Epoch 16/150
# 52/52 [==============================] - ETA: 0s - loss: 0.4029 - accuracy: 0.8469 - f1_score: 0.8478
# Epoch 16: val_f1_score improved from 0.83288 to 0.85018, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 83s 2s/step - loss: 0.4029 - accuracy: 0.8469 - f1_score: 0.8478 - val_loss: 0.3886 - val_accuracy: 0.8501 - val_f1_score: 0.8502 - lr: 1.0000e-04
# Epoch 17/150
# 52/52 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.8580 - f1_score: 0.8583
# Epoch 17: val_f1_score did not improve from 0.85018
# 52/52 [==============================] - 91s 2s/step - loss: 0.3665 - accuracy: 0.8580 - f1_score: 0.8583 - val_loss: 0.4812 - val_accuracy: 0.8241 - val_f1_score: 0.8198 - lr: 1.0000e-04
# Epoch 18/150
# 52/52 [==============================] - ETA: 0s - loss: 0.3663 - accuracy: 0.8589 - f1_score: 0.8595
# Epoch 18: val_f1_score improved from 0.85018 to 0.87798, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 101s 2s/step - loss: 0.3663 - accuracy: 0.8589 - f1_score: 0.8595 - val_loss: 0.3290 - val_accuracy: 0.8797 - val_f1_score: 0.8780 - lr: 1.0000e-04
# Epoch 19/150
# 52/52 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8724 - f1_score: 0.8731
# Epoch 19: val_f1_score did not improve from 0.87798
# 52/52 [==============================] - 117s 2s/step - loss: 0.3338 - accuracy: 0.8724 - f1_score: 0.8731 - val_loss: 0.4860 - val_accuracy: 0.8290 - val_f1_score: 0.8294 - lr: 1.0000e-04
# Epoch 20/150
# 52/52 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.8806 - f1_score: 0.8812
# Epoch 20: val_f1_score improved from 0.87798 to 0.90925, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 151s 3s/step - loss: 0.3129 - accuracy: 0.8806 - f1_score: 0.8812 - val_loss: 0.2434 - val_accuracy: 0.9085 - val_f1_score: 0.9093 - lr: 1.0000e-04
# Epoch 21/150
# 52/52 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.8992 - f1_score: 0.9008
# Epoch 21: val_f1_score did not improve from 0.90925
# 52/52 [==============================] - 136s 3s/step - loss: 0.2732 - accuracy: 0.8992 - f1_score: 0.9008 - val_loss: 0.3340 - val_accuracy: 0.8635 - val_f1_score: 0.8627 - lr: 1.0000e-04
# Epoch 22/150
# 52/52 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.8860 - f1_score: 0.8873
# Epoch 22: val_f1_score did not improve from 0.90925
# 52/52 [==============================] - 146s 3s/step - loss: 0.3019 - accuracy: 0.8860 - f1_score: 0.8873 - val_loss: 0.2500 - val_accuracy: 0.9001 - val_f1_score: 0.9016 - lr: 1.0000e-04
# Epoch 23/150
# 52/52 [==============================] - ETA: 0s - loss: 0.2431 - accuracy: 0.9088 - f1_score: 0.9094
# Epoch 23: val_f1_score improved from 0.90925 to 0.92104, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 152s 3s/step - loss: 0.2431 - accuracy: 0.9088 - f1_score: 0.9094 - val_loss: 0.2169 - val_accuracy: 0.9205 - val_f1_score: 0.9210 - lr: 1.0000e-04
# Epoch 24/150
# 52/52 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.9197 - f1_score: 0.9205
# Epoch 24: val_f1_score improved from 0.92104 to 0.92467, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 128s 2s/step - loss: 0.2148 - accuracy: 0.9197 - f1_score: 0.9205 - val_loss: 0.1942 - val_accuracy: 0.9226 - val_f1_score: 0.9247 - lr: 1.0000e-04
# Epoch 25/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9350 - f1_score: 0.9357
# Epoch 25: val_f1_score improved from 0.92467 to 0.96263, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 138s 3s/step - loss: 0.1823 - accuracy: 0.9350 - f1_score: 0.9357 - val_loss: 0.1163 - val_accuracy: 0.9620 - val_f1_score: 0.9626 - lr: 1.0000e-04
# Epoch 26/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1844 - accuracy: 0.9317 - f1_score: 0.9326
# Epoch 26: val_f1_score did not improve from 0.96263
# 52/52 [==============================] - 149s 3s/step - loss: 0.1844 - accuracy: 0.9317 - f1_score: 0.9326 - val_loss: 0.1715 - val_accuracy: 0.9374 - val_f1_score: 0.9375 - lr: 1.0000e-04
# Epoch 27/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.9284 - f1_score: 0.9292
# Epoch 27: val_f1_score did not improve from 0.96263
# 52/52 [==============================] - 153s 3s/step - loss: 0.1791 - accuracy: 0.9284 - f1_score: 0.9292 - val_loss: 0.1409 - val_accuracy: 0.9493 - val_f1_score: 0.9506 - lr: 1.0000e-04
# Epoch 28/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9492 - f1_score: 0.9496
# Epoch 28: val_f1_score improved from 0.96263 to 0.96292, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 167s 3s/step - loss: 0.1390 - accuracy: 0.9492 - f1_score: 0.9496 - val_loss: 0.0988 - val_accuracy: 0.9627 - val_f1_score: 0.9629 - lr: 1.0000e-04
# Epoch 29/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.9455 - f1_score: 0.9459
# Epoch 29: val_f1_score did not improve from 0.96292
# 52/52 [==============================] - 159s 3s/step - loss: 0.1430 - accuracy: 0.9455 - f1_score: 0.9459 - val_loss: 0.2052 - val_accuracy: 0.9120 - val_f1_score: 0.9137 - lr: 1.0000e-04
# Epoch 30/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9329 - f1_score: 0.9338
# Epoch 30: val_f1_score did not improve from 0.96292
# 52/52 [==============================] - 185s 4s/step - loss: 0.1900 - accuracy: 0.9329 - f1_score: 0.9338 - val_loss: 0.1243 - val_accuracy: 0.9536 - val_f1_score: 0.9542 - lr: 1.0000e-04
# Epoch 31/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9480 - f1_score: 0.9486
# Epoch 31: val_f1_score improved from 0.96292 to 0.96419, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 52/52 [==============================] - 187s 4s/step - loss: 0.1319 - accuracy: 0.9480 - f1_score: 0.9486 - val_loss: 0.1023 - val_accuracy: 0.9634 - val_f1_score: 0.9642 - lr: 1.0000e-04
# Epoch 32/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9675 - f1_score: 0.9680
# Epoch 32: val_f1_score improved from 0.96419 to 0.97467, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 180s 3s/step - loss: 0.0883 - accuracy: 0.9675 - f1_score: 0.9680 - val_loss: 0.0754 - val_accuracy: 0.9747 - val_f1_score: 0.9747 - lr: 5.0000e-05
# Epoch 33/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9813 - f1_score: 0.9816
# Epoch 33: val_f1_score improved from 0.97467 to 0.97745, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 181s 3s/step - loss: 0.0590 - accuracy: 0.9813 - f1_score: 0.9816 - val_loss: 0.0628 - val_accuracy: 0.9768 - val_f1_score: 0.9774 - lr: 5.0000e-05
# Epoch 34/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9789 - f1_score: 0.9793
# Epoch 34: val_f1_score improved from 0.97745 to 0.98959, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 175s 3s/step - loss: 0.0683 - accuracy: 0.9789 - f1_score: 0.9793 - val_loss: 0.0367 - val_accuracy: 0.9894 - val_f1_score: 0.9896 - lr: 5.0000e-05
# Epoch 35/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9789 - f1_score: 0.9793
# Epoch 35: val_f1_score did not improve from 0.98959
# 52/52 [==============================] - 182s 3s/step - loss: 0.0583 - accuracy: 0.9789 - f1_score: 0.9793 - val_loss: 0.0392 - val_accuracy: 0.9859 - val_f1_score: 0.9861 - lr: 5.0000e-05
# Epoch 36/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9795 - f1_score: 0.9798
# Epoch 36: val_f1_score did not improve from 0.98959
# 52/52 [==============================] - 176s 3s/step - loss: 0.0664 - accuracy: 0.9795 - f1_score: 0.9798 - val_loss: 0.0731 - val_accuracy: 0.9740 - val_f1_score: 0.9743 - lr: 5.0000e-05
# Epoch 37/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9789 - f1_score: 0.9792
# Epoch 37: val_f1_score did not improve from 0.98959
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 52/52 [==============================] - 185s 4s/step - loss: 0.0602 - accuracy: 0.9789 - f1_score: 0.9792 - val_loss: 0.0464 - val_accuracy: 0.9838 - val_f1_score: 0.9843 - lr: 5.0000e-05
# Epoch 38/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9810 - f1_score: 0.9813
# Epoch 38: val_f1_score improved from 0.98959 to 0.99231, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 196s 4s/step - loss: 0.0500 - accuracy: 0.9810 - f1_score: 0.9813 - val_loss: 0.0271 - val_accuracy: 0.9923 - val_f1_score: 0.9923 - lr: 2.5000e-05
# Epoch 39/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9907 - f1_score: 0.9908
# Epoch 39: val_f1_score improved from 0.99231 to 0.99377, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 196s 4s/step - loss: 0.0287 - accuracy: 0.9907 - f1_score: 0.9908 - val_loss: 0.0146 - val_accuracy: 0.9937 - val_f1_score: 0.9938 - lr: 2.5000e-05
# Epoch 40/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9835 - f1_score: 0.9836
# Epoch 40: val_f1_score did not improve from 0.99377
# 52/52 [==============================] - 260s 5s/step - loss: 0.0448 - accuracy: 0.9835 - f1_score: 0.9836 - val_loss: 0.0338 - val_accuracy: 0.9838 - val_f1_score: 0.9841 - lr: 2.5000e-05
# Epoch 41/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9853 - f1_score: 0.9855
# Epoch 41: val_f1_score did not improve from 0.99377
# 52/52 [==============================] - 244s 5s/step - loss: 0.0453 - accuracy: 0.9853 - f1_score: 0.9855 - val_loss: 0.0309 - val_accuracy: 0.9930 - val_f1_score: 0.9932 - lr: 2.5000e-05
# Epoch 42/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9823 - f1_score: 0.9826
# Epoch 42: val_f1_score did not improve from 0.99377
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 52/52 [==============================] - 259s 5s/step - loss: 0.0399 - accuracy: 0.9823 - f1_score: 0.9826 - val_loss: 0.0208 - val_accuracy: 0.9923 - val_f1_score: 0.9923 - lr: 2.5000e-05
# Epoch 43/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9910 - f1_score: 0.9911
# Epoch 43: val_f1_score did not improve from 0.99377
# 52/52 [==============================] - 278s 5s/step - loss: 0.0261 - accuracy: 0.9910 - f1_score: 0.9911 - val_loss: 0.0235 - val_accuracy: 0.9916 - val_f1_score: 0.9917 - lr: 1.2500e-05
# Epoch 44/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9919 - f1_score: 0.9919
# Epoch 44: val_f1_score did not improve from 0.99377
# 52/52 [==============================] - 298s 6s/step - loss: 0.0287 - accuracy: 0.9919 - f1_score: 0.9919 - val_loss: 0.0181 - val_accuracy: 0.9923 - val_f1_score: 0.9925 - lr: 1.2500e-05
# Epoch 45/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9922 - f1_score: 0.9923
# Epoch 45: val_f1_score improved from 0.99377 to 0.99444, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 300s 6s/step - loss: 0.0304 - accuracy: 0.9922 - f1_score: 0.9923 - val_loss: 0.0162 - val_accuracy: 0.9944 - val_f1_score: 0.9944 - lr: 1.2500e-05
# Epoch 46/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9925 - f1_score: 0.9926
# Epoch 46: val_f1_score did not improve from 0.99444
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 52/52 [==============================] - 290s 6s/step - loss: 0.0250 - accuracy: 0.9925 - f1_score: 0.9926 - val_loss: 0.0214 - val_accuracy: 0.9930 - val_f1_score: 0.9931 - lr: 1.2500e-05
# Epoch 47/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9916 - f1_score: 0.9918
# Epoch 47: val_f1_score improved from 0.99444 to 0.99795, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 273s 5s/step - loss: 0.0278 - accuracy: 0.9916 - f1_score: 0.9918 - val_loss: 0.0108 - val_accuracy: 0.9979 - val_f1_score: 0.9980 - lr: 6.2500e-06
# Epoch 48/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9922 - f1_score: 0.9923
# Epoch 48: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 365s 7s/step - loss: 0.0205 - accuracy: 0.9922 - f1_score: 0.9923 - val_loss: 0.0216 - val_accuracy: 0.9944 - val_f1_score: 0.9944 - lr: 6.2500e-06
# Epoch 49/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9937 - f1_score: 0.9938
# Epoch 49: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 415s 8s/step - loss: 0.0240 - accuracy: 0.9937 - f1_score: 0.9938 - val_loss: 0.0112 - val_accuracy: 0.9958 - val_f1_score: 0.9959 - lr: 6.2500e-06
# Epoch 50/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9892 - f1_score: 0.9893
# Epoch 50: val_f1_score did not improve from 0.99795
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 52/52 [==============================] - 331s 6s/step - loss: 0.0300 - accuracy: 0.9892 - f1_score: 0.9893 - val_loss: 0.0157 - val_accuracy: 0.9958 - val_f1_score: 0.9958 - lr: 6.2500e-06
# Epoch 51/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 51: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 343s 7s/step - loss: 0.0228 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.0151 - val_accuracy: 0.9951 - val_f1_score: 0.9951 - lr: 3.1250e-06
# Epoch 52/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9919 - f1_score: 0.9920
# Epoch 52: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 365s 7s/step - loss: 0.0236 - accuracy: 0.9919 - f1_score: 0.9920 - val_loss: 0.0202 - val_accuracy: 0.9944 - val_f1_score: 0.9944 - lr: 3.1250e-06
# Epoch 53/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9946 - f1_score: 0.9946
# Epoch 53: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 343s 7s/step - loss: 0.0203 - accuracy: 0.9946 - f1_score: 0.9946 - val_loss: 0.0216 - val_accuracy: 0.9916 - val_f1_score: 0.9916 - lr: 3.1250e-06
# Epoch 54/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9925 - f1_score: 0.9926
# Epoch 54: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 351s 7s/step - loss: 0.0209 - accuracy: 0.9925 - f1_score: 0.9926 - val_loss: 0.0097 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 3.1250e-06
# Epoch 55/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9946 - f1_score: 0.9947
# Epoch 55: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 506s 10s/step - loss: 0.0178 - accuracy: 0.9946 - f1_score: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9923 - val_f1_score: 0.9924 - lr: 3.1250e-06
# Epoch 56/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9898 - f1_score: 0.9899
# Epoch 56: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 555s 11s/step - loss: 0.0289 - accuracy: 0.9898 - f1_score: 0.9899 - val_loss: 0.0093 - val_accuracy: 0.9951 - val_f1_score: 0.9950 - lr: 3.1250e-06
# Epoch 57/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9910 - f1_score: 0.9910
# Epoch 57: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 563s 11s/step - loss: 0.0256 - accuracy: 0.9910 - f1_score: 0.9910 - val_loss: 0.0190 - val_accuracy: 0.9937 - val_f1_score: 0.9937 - lr: 3.1250e-06
# Epoch 58/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9907 - f1_score: 0.9908
# Epoch 58: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 360s 7s/step - loss: 0.0248 - accuracy: 0.9907 - f1_score: 0.9908 - val_loss: 0.0167 - val_accuracy: 0.9930 - val_f1_score: 0.9931 - lr: 3.1250e-06
# Epoch 59/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9946 - f1_score: 0.9946
# Epoch 59: val_f1_score did not improve from 0.99795
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 52/52 [==============================] - 178s 3s/step - loss: 0.0174 - accuracy: 0.9946 - f1_score: 0.9946 - val_loss: 0.0178 - val_accuracy: 0.9951 - val_f1_score: 0.9952 - lr: 3.1250e-06
# Epoch 60/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9946 - f1_score: 0.9947
# Epoch 60: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 370s 7s/step - loss: 0.0170 - accuracy: 0.9946 - f1_score: 0.9947 - val_loss: 0.0099 - val_accuracy: 0.9958 - val_f1_score: 0.9958 - lr: 1.5625e-06
# Epoch 61/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9931 - f1_score: 0.9931
# Epoch 61: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 350s 7s/step - loss: 0.0220 - accuracy: 0.9931 - f1_score: 0.9931 - val_loss: 0.0094 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 1.5625e-06
# Epoch 62/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 62: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 358s 7s/step - loss: 0.0223 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.0128 - val_accuracy: 0.9951 - val_f1_score: 0.9952 - lr: 1.5625e-06
# Epoch 63/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9919 - f1_score: 0.9921
# Epoch 63: val_f1_score did not improve from 0.99795
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 52/52 [==============================] - 374s 7s/step - loss: 0.0246 - accuracy: 0.9919 - f1_score: 0.9921 - val_loss: 0.0163 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 1.5625e-06
# Epoch 64/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9934 - f1_score: 0.9935
# Epoch 64: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 395s 8s/step - loss: 0.0207 - accuracy: 0.9934 - f1_score: 0.9935 - val_loss: 0.0113 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 7.8125e-07
# Epoch 65/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9946 - f1_score: 0.9946
# Epoch 65: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 361s 7s/step - loss: 0.0194 - accuracy: 0.9946 - f1_score: 0.9946 - val_loss: 0.0234 - val_accuracy: 0.9930 - val_f1_score: 0.9930 - lr: 7.8125e-07
# Epoch 66/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9943 - f1_score: 0.9944
# Epoch 66: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 396s 8s/step - loss: 0.0192 - accuracy: 0.9943 - f1_score: 0.9944 - val_loss: 0.0208 - val_accuracy: 0.9923 - val_f1_score: 0.9924 - lr: 7.8125e-07
# Epoch 67/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9931 - f1_score: 0.9931
# Epoch 67: val_f1_score did not improve from 0.99795
# 52/52 [==============================] - 401s 8s/step - loss: 0.0222 - accuracy: 0.9931 - f1_score: 0.9931 - val_loss: 0.0084 - val_accuracy: 0.9972 - val_f1_score: 0.9973 - lr: 7.8125e-07
# Epoch 68/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9928 - f1_score: 0.9929
# Epoch 68: val_f1_score improved from 0.99795 to 0.99931, saving model to saved_outputs_all_augment\original_vit_v2\original_vit_v2_saved_weights\best_original_vit_v2_weights
# 52/52 [==============================] - 406s 8s/step - loss: 0.0250 - accuracy: 0.9928 - f1_score: 0.9929 - val_loss: 0.0053 - val_accuracy: 0.9993 - val_f1_score: 0.9993 - lr: 7.8125e-07
# Epoch 69/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9931 - f1_score: 0.9933
# Epoch 69: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 434s 8s/step - loss: 0.0211 - accuracy: 0.9931 - f1_score: 0.9933 - val_loss: 0.0092 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 7.8125e-07
# Epoch 70/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9955 - f1_score: 0.9956
# Epoch 70: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 432s 8s/step - loss: 0.0168 - accuracy: 0.9955 - f1_score: 0.9956 - val_loss: 0.0121 - val_accuracy: 0.9958 - val_f1_score: 0.9959 - lr: 7.8125e-07
# Epoch 71/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 71: val_f1_score did not improve from 0.99931
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 52/52 [==============================] - 449s 9s/step - loss: 0.0210 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.0131 - val_accuracy: 0.9958 - val_f1_score: 0.9958 - lr: 7.8125e-07
# Epoch 72/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9937 - f1_score: 0.9938
# Epoch 72: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 419s 8s/step - loss: 0.0207 - accuracy: 0.9937 - f1_score: 0.9938 - val_loss: 0.0120 - val_accuracy: 0.9958 - val_f1_score: 0.9958 - lr: 3.9062e-07
# Epoch 73/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9934 - f1_score: 0.9936
# Epoch 73: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 451s 9s/step - loss: 0.0217 - accuracy: 0.9934 - f1_score: 0.9936 - val_loss: 0.0147 - val_accuracy: 0.9944 - val_f1_score: 0.9945 - lr: 3.9062e-07
# Epoch 74/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 74: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 489s 9s/step - loss: 0.0167 - accuracy: 0.9955 - f1_score: 0.9955 - val_loss: 0.0150 - val_accuracy: 0.9944 - val_f1_score: 0.9944 - lr: 3.9062e-07
# Epoch 75/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9949 - f1_score: 0.9950
# Epoch 75: val_f1_score did not improve from 0.99931
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 52/52 [==============================] - 524s 10s/step - loss: 0.0193 - accuracy: 0.9949 - f1_score: 0.9950 - val_loss: 0.0110 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 3.9062e-07
# Epoch 76/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9949 - f1_score: 0.9950
# Epoch 76: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 514s 10s/step - loss: 0.0193 - accuracy: 0.9949 - f1_score: 0.9950 - val_loss: 0.0125 - val_accuracy: 0.9951 - val_f1_score: 0.9951 - lr: 1.9531e-07
# Epoch 77/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9931 - f1_score: 0.9933
# Epoch 77: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 555s 11s/step - loss: 0.0188 - accuracy: 0.9931 - f1_score: 0.9933 - val_loss: 0.0164 - val_accuracy: 0.9951 - val_f1_score: 0.9950 - lr: 1.9531e-07
# Epoch 78/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9961 - f1_score: 0.9962
# Epoch 78: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 581s 11s/step - loss: 0.0158 - accuracy: 0.9961 - f1_score: 0.9962 - val_loss: 0.0092 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 1.9531e-07
# Epoch 79/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9958 - f1_score: 0.9959
# Epoch 79: val_f1_score did not improve from 0.99931
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# 52/52 [==============================] - 582s 11s/step - loss: 0.0168 - accuracy: 0.9958 - f1_score: 0.9959 - val_loss: 0.0113 - val_accuracy: 0.9972 - val_f1_score: 0.9973 - lr: 1.9531e-07
# Epoch 80/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9943 - f1_score: 0.9943
# Epoch 80: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 635s 12s/step - loss: 0.0183 - accuracy: 0.9943 - f1_score: 0.9943 - val_loss: 0.0238 - val_accuracy: 0.9916 - val_f1_score: 0.9917 - lr: 9.7656e-08

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
best_model = get_original_vit()

best_model.load_weights(PATH_BEST_WEIGHT_SAVE)

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 19/19 [==============================] - 73s 4s/step - loss: 0.0101 - accuracy: 0.9933 - f1_score: 0.9923
#         model_name  test_loss  test_accuracy  test_f1_score
# 0  original_vit_v2   0.010119        0.99326        0.99229

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test
############################################################################################################]
# Out:
# 19/19 [==============================] - 70s 4s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score     support
# 0              1.000000  0.976540  0.988131   341.00000
# 1              1.000000  1.000000  1.000000   268.00000
# 2              1.000000  1.000000  1.000000   317.00000
# 3              0.970260  1.000000  0.984906   261.00000
# accuracy       0.993260  0.993260  0.993260     0.99326
# macro avg      0.992565  0.994135  0.993259  1187.00000
# weighted avg   0.993461  0.993260  0.993271  1187.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels,
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#         Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  original_vit_v2   0.99326         0.992565      0.994135        0.993259
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.993461          0.99326           0.993271  0.010119

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.99326
# 1      Macro Precision  0.99257
# 2         Macro Recall  0.99413
# 3       Macro F1-Score  0.99326
# 4            Macro FPR  0.00216
# 5            Macro FNR  0.00587
# 6            Macro FDR  0.00743
# 7            Macro NPV  0.99766
# 8   Weighted Precision  0.99346
# 9      Weighted Recall  0.99326
# 10   Weighted F1-Score  0.99327
# 11        Weighted FPR  0.00190
# 12        Weighted FNR  0.00674
# 13        Weighted FDR  0.00654
# 14        Weighted NPV  0.99731
