# %% [markdown]
# ## Imports

# %%
# !pip install tensorflow-addons

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=4, average='macro')

# %% [markdown]
# ## Setting the paths

# %%
model_name = 'InceptionV3'#'Xception'#'MobileNet'
#'DenseNet121'#'InceptionV3'#'Xception'#'DenseNet121'#    'InceptionV3'##  'MobileNet', 'Xception', ensemble2, ensemble3, 'parallel_vit'

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
# PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/classification'
sys.path.append(PATH_TO_CODE)
# DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/classification/data44_resized_splited'
DATASET_PATH = r'data44_resized_splited'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')


if not os.path.exists(PATH_TO_SAVE_RESULT):
    # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################


IMG_HEIGHT = 200
IMG_WIDTH = 200
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.3
NUM_CLASSES = 4

BATCH_SIZE = 64
EPOCHS = 150

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic' #'all'## basic, advanced,
################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.



PATIENCE_EARLY_STOP = 12 # With no improvement in Loss, will stop training

# # Checkpoint parameters
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
PATIENCE_LR_REDUCE=3      # Number of epochs with no improvement after which learning rate will be reduced
COOLDOWN_EPOCHS  = 2              # How many epochs to wait after learning rate reduction before it can be reduced again
MIN_LR = 1e-9
INITIAL_LR = 0.0001 # with 0.001 got 99 percent

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_SAVE_TIME ", PATH_SAVE_TIME )
print("PATH_SAVE_HISTORY", PATH_SAVE_HISTORY)
print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH data44_resized_splited
# DATASET_PATH_TRAIN data44_resized_splited\train
# DATASET_PATH_TEST data44_resized_splited\test
# PATH_SAVE_TIME  saved_outputs_basic_augment\InceptionV3\InceptionV3_training_time.csv
# PATH_SAVE_HISTORY saved_outputs_basic_augment\InceptionV3\InceptionV3_training_history.csv
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\InceptionV3
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\InceptionV3\InceptionV3_saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\InceptionV3\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_10968\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([
    iaa.ElasticTransformation(alpha=10, sigma=5)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
def create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                      dataset_path_test=DATASET_PATH_TEST,
                      valid_ratio=VALIDATION_SPLIT,
                      augment= False,
                      augment_type='basic'):

    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=10,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.2,  # fraction of total height
                shear_range=0.2,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically

                # Pixel-Level Transformations
                brightness_range=[0.8, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.2,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                # rotation_range=10,  # degrees
                zoom_range=0.2,  # zoom range for random zoom
                # vertical_flip=True,  # randomly flip images vertically
                horizontal_flip=True,  # randomly flip images horizontally
            )
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )

    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )

    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )

    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        seed = SEED,
        shuffle = False,
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)

    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 3324 images belonging to 4 classes.
# Found 1421 images belonging to 4 classes.
# Found 1187 images belonging to 4 classes.

# %% [markdown]
# ## Visualization

# %%
def plot_images(images, labels, classes=None):
    fig = plt.figure(figsize=(10, 10))
    for i in range(15):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)

        # If class labels are provided, add them to the subplot
        if classes is not None:
            label = classes[np.argmax(labels[i])]
            plt.xlabel(label)
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_visualization.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()


train_images, train_labels = next(train_generator)  # Fetch a batch of images and labels
plot_images(train_images, train_labels)

# %% [markdown]
# ## Essential functions (training)

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)

    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR,   # Lower bound on the learning rate.
        cooldown = COOLDOWN_EPOCHS
    )

    my_callbacks = [best_model_callback , reduce_LR , EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return saved_best_model_name, train_history, total_time

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)

    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)

    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)

        # Calculate support for each class
        support = TP + FN

        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []

    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)

    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)

    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)

    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator)

    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")

    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)


    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Loss': test_loss
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

    del report_df, test_results

# %% [markdown]
# # MODEL CREATING

# %% [markdown]
# ### Inception-V3

# %%
from tensorflow.keras.applications import InceptionV3
def get_InceptionV3():

    model = InceptionV3(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

    optimizer = Adam(learning_rate=INITIAL_LR )
    model.compile(loss="categorical_crossentropy",
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)
    return model

# %% [markdown]
# # Train and Results

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()
# model = get_ensemble2_model()

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/150
# 52/52 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.7332 - f1_score: 0.7340
# Epoch 1: val_f1_score improved from -inf to 0.09049, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 55s 753ms/step - loss: 0.6849 - accuracy: 0.7332 - f1_score: 0.7340 - val_loss: 1.4752 - val_accuracy: 0.2210 - val_f1_score: 0.0905 - lr: 1.0000e-04
# Epoch 2/150
# 52/52 [==============================] - ETA: 0s - loss: 0.3611 - accuracy: 0.8736 - f1_score: 0.8755
# Epoch 2: val_f1_score did not improve from 0.09049
# 52/52 [==============================] - 29s 550ms/step - loss: 0.3611 - accuracy: 0.8736 - f1_score: 0.8755 - val_loss: 1.9353 - val_accuracy: 0.2210 - val_f1_score: 0.0905 - lr: 1.0000e-04
# Epoch 3/150
# 52/52 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.8971 - f1_score: 0.8984
# Epoch 3: val_f1_score did not improve from 0.09049
# 52/52 [==============================] - 29s 553ms/step - loss: 0.2710 - accuracy: 0.8971 - f1_score: 0.8984 - val_loss: 2.2193 - val_accuracy: 0.2210 - val_f1_score: 0.0905 - lr: 1.0000e-04
# Epoch 4/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9326 - f1_score: 0.9333
# Epoch 4: val_f1_score improved from 0.09049 to 0.10637, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 52/52 [==============================] - 34s 661ms/step - loss: 0.1936 - accuracy: 0.9326 - f1_score: 0.9333 - val_loss: 2.7653 - val_accuracy: 0.2702 - val_f1_score: 0.1064 - lr: 1.0000e-04
# Epoch 5/150
# 52/52 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9555 - f1_score: 0.9562
# Epoch 5: val_f1_score improved from 0.10637 to 0.10937, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 33s 632ms/step - loss: 0.1335 - accuracy: 0.9555 - f1_score: 0.9562 - val_loss: 4.3043 - val_accuracy: 0.2716 - val_f1_score: 0.1094 - lr: 5.0000e-05
# Epoch 6/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9660 - f1_score: 0.9664
# Epoch 6: val_f1_score did not improve from 0.10937
# 52/52 [==============================] - 28s 535ms/step - loss: 0.0961 - accuracy: 0.9660 - f1_score: 0.9664 - val_loss: 6.0427 - val_accuracy: 0.2709 - val_f1_score: 0.1079 - lr: 5.0000e-05
# Epoch 7/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9666 - f1_score: 0.9670
# Epoch 7: val_f1_score improved from 0.10937 to 0.17351, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 34s 646ms/step - loss: 0.0911 - accuracy: 0.9666 - f1_score: 0.9670 - val_loss: 4.1493 - val_accuracy: 0.2920 - val_f1_score: 0.1735 - lr: 5.0000e-05
# Epoch 8/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9726 - f1_score: 0.9730
# Epoch 8: val_f1_score improved from 0.17351 to 0.28613, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 52/52 [==============================] - 33s 627ms/step - loss: 0.0824 - accuracy: 0.9726 - f1_score: 0.9730 - val_loss: 3.1357 - val_accuracy: 0.3681 - val_f1_score: 0.2861 - lr: 5.0000e-05
# Epoch 9/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9741 - f1_score: 0.9744
# Epoch 9: val_f1_score improved from 0.28613 to 0.51408, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 33s 635ms/step - loss: 0.0666 - accuracy: 0.9741 - f1_score: 0.9744 - val_loss: 1.8728 - val_accuracy: 0.5292 - val_f1_score: 0.5141 - lr: 2.5000e-05
# Epoch 10/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9826 - f1_score: 0.9825
# Epoch 10: val_f1_score improved from 0.51408 to 0.66731, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 34s 657ms/step - loss: 0.0542 - accuracy: 0.9826 - f1_score: 0.9825 - val_loss: 1.3031 - val_accuracy: 0.6714 - val_f1_score: 0.6673 - lr: 2.5000e-05
# Epoch 11/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9853 - f1_score: 0.9853
# Epoch 11: val_f1_score improved from 0.66731 to 0.79770, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 34s 664ms/step - loss: 0.0486 - accuracy: 0.9853 - f1_score: 0.9853 - val_loss: 0.7218 - val_accuracy: 0.7959 - val_f1_score: 0.7977 - lr: 2.5000e-05
# Epoch 12/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9792 - f1_score: 0.9794
# Epoch 12: val_f1_score improved from 0.79770 to 0.90222, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 33s 636ms/step - loss: 0.0508 - accuracy: 0.9792 - f1_score: 0.9794 - val_loss: 0.2710 - val_accuracy: 0.9008 - val_f1_score: 0.9022 - lr: 2.5000e-05
# Epoch 13/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9883 - f1_score: 0.9884
# Epoch 13: val_f1_score improved from 0.90222 to 0.97020, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 35s 672ms/step - loss: 0.0388 - accuracy: 0.9883 - f1_score: 0.9884 - val_loss: 0.0907 - val_accuracy: 0.9697 - val_f1_score: 0.9702 - lr: 2.5000e-05
# Epoch 14/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9865 - f1_score: 0.9866
# Epoch 14: val_f1_score improved from 0.97020 to 0.98533, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 35s 667ms/step - loss: 0.0387 - accuracy: 0.9865 - f1_score: 0.9866 - val_loss: 0.0630 - val_accuracy: 0.9852 - val_f1_score: 0.9853 - lr: 2.5000e-05
# Epoch 15/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9868 - f1_score: 0.9867
# Epoch 15: val_f1_score did not improve from 0.98533
# 52/52 [==============================] - 31s 597ms/step - loss: 0.0407 - accuracy: 0.9868 - f1_score: 0.9867 - val_loss: 0.0409 - val_accuracy: 0.9838 - val_f1_score: 0.9839 - lr: 2.5000e-05
# Epoch 16/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9865 - f1_score: 0.9867
# Epoch 16: val_f1_score did not improve from 0.98533
# 52/52 [==============================] - 29s 565ms/step - loss: 0.0418 - accuracy: 0.9865 - f1_score: 0.9867 - val_loss: 0.0736 - val_accuracy: 0.9810 - val_f1_score: 0.9814 - lr: 2.5000e-05
# Epoch 17/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9877 - f1_score: 0.9877
# Epoch 17: val_f1_score did not improve from 0.98533
# 52/52 [==============================] - 29s 553ms/step - loss: 0.0353 - accuracy: 0.9877 - f1_score: 0.9877 - val_loss: 0.0509 - val_accuracy: 0.9803 - val_f1_score: 0.9807 - lr: 2.5000e-05
# Epoch 18/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9862 - f1_score: 0.9864
# Epoch 18: val_f1_score improved from 0.98533 to 0.99240, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 34s 655ms/step - loss: 0.0415 - accuracy: 0.9862 - f1_score: 0.9864 - val_loss: 0.0236 - val_accuracy: 0.9923 - val_f1_score: 0.9924 - lr: 2.5000e-05
# Epoch 19/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9916 - f1_score: 0.9917
# Epoch 19: val_f1_score improved from 0.99240 to 0.99571, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 35s 679ms/step - loss: 0.0264 - accuracy: 0.9916 - f1_score: 0.9917 - val_loss: 0.0162 - val_accuracy: 0.9958 - val_f1_score: 0.9957 - lr: 2.5000e-05
# Epoch 20/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9883 - f1_score: 0.9885
# Epoch 20: val_f1_score improved from 0.99571 to 0.99780, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 35s 677ms/step - loss: 0.0374 - accuracy: 0.9883 - f1_score: 0.9885 - val_loss: 0.0126 - val_accuracy: 0.9979 - val_f1_score: 0.9978 - lr: 2.5000e-05
# Epoch 21/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9931 - f1_score: 0.9932
# Epoch 21: val_f1_score did not improve from 0.99780
# 52/52 [==============================] - 32s 620ms/step - loss: 0.0190 - accuracy: 0.9931 - f1_score: 0.9932 - val_loss: 0.0093 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 2.5000e-05
# Epoch 22/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9877 - f1_score: 0.9878
# Epoch 22: val_f1_score did not improve from 0.99780
# 52/52 [==============================] - 29s 564ms/step - loss: 0.0351 - accuracy: 0.9877 - f1_score: 0.9878 - val_loss: 0.0713 - val_accuracy: 0.9852 - val_f1_score: 0.9855 - lr: 2.5000e-05
# Epoch 23/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9940 - f1_score: 0.9941
# Epoch 23: val_f1_score did not improve from 0.99780
# 52/52 [==============================] - 28s 536ms/step - loss: 0.0202 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.0181 - val_accuracy: 0.9937 - val_f1_score: 0.9938 - lr: 2.5000e-05
# Epoch 24/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9949 - f1_score: 0.9949
# Epoch 24: val_f1_score did not improve from 0.99780
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 52/52 [==============================] - 29s 560ms/step - loss: 0.0180 - accuracy: 0.9949 - f1_score: 0.9949 - val_loss: 0.0135 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 2.5000e-05
# Epoch 25/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9940 - f1_score: 0.9940
# Epoch 25: val_f1_score improved from 0.99780 to 0.99784, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 35s 678ms/step - loss: 0.0174 - accuracy: 0.9940 - f1_score: 0.9940 - val_loss: 0.0063 - val_accuracy: 0.9979 - val_f1_score: 0.9978 - lr: 1.2500e-05
# Epoch 26/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9943 - f1_score: 0.9943
# Epoch 26: val_f1_score improved from 0.99784 to 0.99931, saving model to saved_outputs_basic_augment\InceptionV3\saved_models\best_InceptionV3.h5
# 52/52 [==============================] - 34s 650ms/step - loss: 0.0156 - accuracy: 0.9943 - f1_score: 0.9943 - val_loss: 0.0070 - val_accuracy: 0.9993 - val_f1_score: 0.9993 - lr: 1.2500e-05
# Epoch 27/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9955 - f1_score: 0.9956
# Epoch 27: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 29s 553ms/step - loss: 0.0157 - accuracy: 0.9955 - f1_score: 0.9956 - val_loss: 0.0073 - val_accuracy: 0.9979 - val_f1_score: 0.9978 - lr: 1.2500e-05
# Epoch 28/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9955 - f1_score: 0.9955
# Epoch 28: val_f1_score did not improve from 0.99931
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 52/52 [==============================] - 29s 557ms/step - loss: 0.0167 - accuracy: 0.9955 - f1_score: 0.9955 - val_loss: 0.0105 - val_accuracy: 0.9972 - val_f1_score: 0.9973 - lr: 1.2500e-05
# Epoch 29/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9961 - f1_score: 0.9961
# Epoch 29: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 28s 537ms/step - loss: 0.0154 - accuracy: 0.9961 - f1_score: 0.9961 - val_loss: 0.0134 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 6.2500e-06
# Epoch 30/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9979 - f1_score: 0.9979
# Epoch 30: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 29s 553ms/step - loss: 0.0094 - accuracy: 0.9979 - f1_score: 0.9979 - val_loss: 0.0080 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 6.2500e-06
# Epoch 31/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9949 - f1_score: 0.9949
# Epoch 31: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 29s 561ms/step - loss: 0.0136 - accuracy: 0.9949 - f1_score: 0.9949 - val_loss: 0.0071 - val_accuracy: 0.9972 - val_f1_score: 0.9971 - lr: 6.2500e-06
# Epoch 32/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9961 - f1_score: 0.9962
# Epoch 32: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 31s 593ms/step - loss: 0.0125 - accuracy: 0.9961 - f1_score: 0.9962 - val_loss: 0.0032 - val_accuracy: 0.9993 - val_f1_score: 0.9992 - lr: 6.2500e-06
# Epoch 33/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9952 - f1_score: 0.9953
# Epoch 33: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 30s 570ms/step - loss: 0.0119 - accuracy: 0.9952 - f1_score: 0.9953 - val_loss: 0.0062 - val_accuracy: 0.9979 - val_f1_score: 0.9979 - lr: 6.2500e-06
# Epoch 34/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9934 - f1_score: 0.9935
# Epoch 34: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 29s 558ms/step - loss: 0.0164 - accuracy: 0.9934 - f1_score: 0.9935 - val_loss: 0.0044 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 6.2500e-06
# Epoch 35/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9970 - f1_score: 0.9971
# Epoch 35: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 30s 580ms/step - loss: 0.0118 - accuracy: 0.9970 - f1_score: 0.9971 - val_loss: 0.0030 - val_accuracy: 0.9993 - val_f1_score: 0.9992 - lr: 6.2500e-06
# Epoch 36/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9976 - f1_score: 0.9976
# Epoch 36: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 28s 539ms/step - loss: 0.0102 - accuracy: 0.9976 - f1_score: 0.9976 - val_loss: 0.0034 - val_accuracy: 0.9993 - val_f1_score: 0.9993 - lr: 6.2500e-06
# Epoch 37/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9961 - f1_score: 0.9961
# Epoch 37: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 28s 543ms/step - loss: 0.0111 - accuracy: 0.9961 - f1_score: 0.9961 - val_loss: 0.0095 - val_accuracy: 0.9972 - val_f1_score: 0.9971 - lr: 6.2500e-06
# Epoch 38/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9946 - f1_score: 0.9946
# Epoch 38: val_f1_score did not improve from 0.99931
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 52/52 [==============================] - 26s 493ms/step - loss: 0.0171 - accuracy: 0.9946 - f1_score: 0.9946 - val_loss: 0.0046 - val_accuracy: 0.9993 - val_f1_score: 0.9993 - lr: 6.2500e-06
# Epoch 39/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9964 - f1_score: 0.9964
# Epoch 39: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 26s 497ms/step - loss: 0.0130 - accuracy: 0.9964 - f1_score: 0.9964 - val_loss: 0.0033 - val_accuracy: 0.9993 - val_f1_score: 0.9992 - lr: 3.1250e-06
# Epoch 40/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9964 - f1_score: 0.9964
# Epoch 40: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 25s 483ms/step - loss: 0.0109 - accuracy: 0.9964 - f1_score: 0.9964 - val_loss: 0.0108 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 3.1250e-06
# Epoch 41/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9940 - f1_score: 0.9941
# Epoch 41: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 25s 487ms/step - loss: 0.0158 - accuracy: 0.9940 - f1_score: 0.9941 - val_loss: 0.0072 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 3.1250e-06
# Epoch 42/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9964 - f1_score: 0.9965
# Epoch 42: val_f1_score did not improve from 0.99931
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 52/52 [==============================] - 26s 506ms/step - loss: 0.0094 - accuracy: 0.9964 - f1_score: 0.9965 - val_loss: 0.0044 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 3.1250e-06
# Epoch 43/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9973 - f1_score: 0.9973
# Epoch 43: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 28s 525ms/step - loss: 0.0126 - accuracy: 0.9973 - f1_score: 0.9973 - val_loss: 0.0073 - val_accuracy: 0.9972 - val_f1_score: 0.9972 - lr: 1.5625e-06
# Epoch 44/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9949 - f1_score: 0.9950
# Epoch 44: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 27s 509ms/step - loss: 0.0163 - accuracy: 0.9949 - f1_score: 0.9950 - val_loss: 0.0034 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 1.5625e-06
# Epoch 45/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9970 - f1_score: 0.9970
# Epoch 45: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 28s 540ms/step - loss: 0.0121 - accuracy: 0.9970 - f1_score: 0.9970 - val_loss: 0.0080 - val_accuracy: 0.9965 - val_f1_score: 0.9965 - lr: 1.5625e-06
# Epoch 46/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9973 - f1_score: 0.9973
# Epoch 46: val_f1_score did not improve from 0.99931
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 52/52 [==============================] - 28s 541ms/step - loss: 0.0084 - accuracy: 0.9973 - f1_score: 0.9973 - val_loss: 0.0058 - val_accuracy: 0.9986 - val_f1_score: 0.9986 - lr: 1.5625e-06
# Epoch 47/150
# 52/52 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9964 - f1_score: 0.9964
# Epoch 47: val_f1_score did not improve from 0.99931
# 52/52 [==============================] - 29s 551ms/step - loss: 0.0093 - accuracy: 0.9964 - f1_score: 0.9964 - val_loss: 0.0056 - val_accuracy: 0.9986 - val_f1_score: 0.9985 - lr: 7.8125e-07

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
# Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name), custom_objects={'F1Score': F1Score})

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 19/19 [==============================] - 4s 99ms/step - loss: 0.0206 - accuracy: 0.9933 - f1_score: 0.9932
#     model_name  test_loss  test_accuracy  test_f1_score
# 0  InceptionV3   0.020647        0.99326       0.993203

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test
############################################################################################################]
# Out:
# 19/19 [==============================] - 3s 87ms/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score     support
# 0              0.979885  1.000000  0.989840   341.00000
# 1              0.996198  0.977612  0.986817   268.00000
# 2              1.000000  1.000000  1.000000   317.00000
# 3              1.000000  0.992337  0.996154   261.00000
# accuracy       0.993260  0.993260  0.993260     0.99326
# macro avg      0.994021  0.992487  0.993203  1187.00000
# weighted avg   0.993363  0.993260  0.993259  1187.00000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels,
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#     Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  InceptionV3   0.99326         0.994021      0.992487        0.993203
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.993363          0.99326           0.993259  0.020647

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.99326
# 1      Macro Precision  0.99402
# 2         Macro Recall  0.99249
# 3       Macro F1-Score  0.99320
# 4            Macro FPR  0.00234
# 5            Macro FNR  0.00751
# 6            Macro FDR  0.00598
# 7            Macro NPV  0.99784
# 8   Weighted Precision  0.99336
# 9      Weighted Recall  0.99326
# 10   Weighted F1-Score  0.99326
# 11        Weighted FPR  0.00262
# 12        Weighted FNR  0.00674
# 13        Weighted FDR  0.00664
# 14        Weighted NPV  0.99806
