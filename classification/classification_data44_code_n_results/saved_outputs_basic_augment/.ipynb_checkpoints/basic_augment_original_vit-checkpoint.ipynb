# %% [markdown]
# - imbalance data: https://www.linkedin.com/pulse/some-tricks-handling-imbalanced-dataset-image-m-farhan-tandia
# - base model: https://www.youtube.com/watch?v=t8eSPbvl0vU
# - https://www.kaggle.com/code/hongjae6/simple-baseline-using-keras-resnet50

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Imports

# %%
# !pip install tensorflow-addons

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # read and manipulate local files

import time
from tqdm import tqdm

import matplotlib.pyplot as plt
import cv2
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score as f1_score_report


import random

from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow.keras as ks
import tensorflow as tf


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from imgaug import augmenters as iaa # elastic_deformation

from tensorflow.keras import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dense, BatchNormalization, Concatenate, GlobalAveragePooling2D

# hide wornings
import warnings
warnings.filterwarnings('ignore')

################################################################################################
# SETTING F1 SCORE
from tensorflow_addons.metrics import F1Score
f1_score = F1Score(num_classes=4, average='macro')

# %% [markdown]
# ## Setting the paths

# %%
model_name = 'original_vit'#'Xception'#'DenseNet121'#    'InceptionV3'##  'MobileNet', 'Xception', ensemble2, ensemble3, 'parallel_vit'

################################################################################################

## SEETING THE PATHS
PATH_TO_CODE =''
# PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/classification'
sys.path.append(PATH_TO_CODE)
# DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/classification/data44_resized_splited'
DATASET_PATH = r'data44_resized_splited'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_basic_augment', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT,model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')


if not os.path.exists(PATH_TO_SAVE_RESULT):
    # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################


IMG_HEIGHT = 200
IMG_WIDTH = 200
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = (128, 128)
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.3
NUM_CLASSES = 4

BATCH_SIZE = 64
EPOCHS = 120

################################################################################################
AUGMENT = True
AUGMENT_TYPE = 'basic' #'all'## basic, advanced,
################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters
SCORE_TO_MONITOR = 'val_f1_score' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.



PATIENCE_EARLY_STOP = 12 # With no improvement in Loss, will stop training

# # Checkpoint parameters
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
PATIENCE_LR_REDUCE=3      # Number of epochs with no improvement after which learning rate will be reduced
COOLDOWN_EPOCHS  = 2              # How many epochs to wait after learning rate reduction before it can be reduced again
MIN_LR = 1e-9
INITIAL_LR = 0.001 # with 0.001 got 99 percent

# %%
print("DATASET_PATH", DATASET_PATH)
print("DATASET_PATH_TRAIN", DATASET_PATH_TRAIN)
print("DATASET_PATH_TEST", DATASET_PATH_TEST)

print("PATH_SAVE_TIME ", PATH_SAVE_TIME )
print("PATH_SAVE_HISTORY", PATH_SAVE_HISTORY)
print("PATH_TO_SAVE_RESULT",PATH_TO_SAVE_RESULT)
print("PATH_BEST_SAVE_WEIGHT", PATH_BEST_SAVE_WEIGHT)
print("PATH_TO_SAVE_MODEL", PATH_TO_SAVE_MODEL)
# Out:
# DATASET_PATH data44_resized_splited
# DATASET_PATH_TRAIN data44_resized_splited\train
# DATASET_PATH_TEST data44_resized_splited\test
# PATH_SAVE_TIME  saved_outputs_basic_augment\original_vit\original_vit_training_time.csv
# PATH_SAVE_HISTORY saved_outputs_basic_augment\original_vit\original_vit_training_history.csv
# PATH_TO_SAVE_RESULT saved_outputs_basic_augment\original_vit
# PATH_BEST_SAVE_WEIGHT saved_outputs_basic_augment\original_vit\original_vit_saved_weights
# PATH_TO_SAVE_MODEL saved_outputs_basic_augment\original_vit\saved_models

# %% [markdown]
# ## Using GPU

# %%
# Check if GPU is available
print("GPU Available: ", tf.test.is_gpu_available())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# WARNING:tensorflow:From C:\Users\mahri\AppData\Local\Temp\ipykernel_6264\984659479.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Num GPUs Available:  2

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# ### ElasticTransformation

# %%
# Define an augmentation pipeline
# Alpha parameter controls the intensity of the deformation
# Sigma controls the smoothness of the deformation field.
aug = iaa.Sequential([
    iaa.ElasticTransformation(alpha=10, sigma=5)  # Apply elastic transformations , sigma=1
])

def elastic_deformation(image):
    image_aug = aug(image=image)
    return image_aug

# %%
# Defining a function for creating the generators with given augmentation type
def create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                      dataset_path_test=DATASET_PATH_TEST,
                      valid_ratio=VALIDATION_SPLIT,
                      augment= False,
                      augment_type='basic'):

    # If augmentation is True, apply data augmentation. Otherwise, only rescale.
    if augment:
        if augment_type == 'all':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                rotation_range=10,  # degrees
                width_shift_range=0.2,  # fraction of total width
                height_shift_range=0.2,  # fraction of total height
                shear_range=0.2,  # shear angle in counter-clockwise direction as radians
                zoom_range=0.2,  # zoom range for random zoom
                horizontal_flip=True,  # randomly flip images horizontally
                # vertical_flip=True,  # randomly flip images vertically

                # Pixel-Level Transformations
                brightness_range=[0.8, 1.1],  # range for picking a brightness shift value
                channel_shift_range=0.2,  # range for random channel shifts

                # Advanced functions
                preprocessing_function=elastic_deformation
            )
        elif augment_type == 'basic':
            datagen = ImageDataGenerator(
                rescale=1./255, # Normalize images
                validation_split=valid_ratio,  # Split ratio for validation set

                # Geometric Transformations
                # rotation_range=10,  # degrees
                zoom_range=0.2,  # zoom range for random zoom
                # vertical_flip=True,  # randomly flip images vertically
                horizontal_flip=True,  # randomly flip images horizontally
            )
    else:
        # No augmentation
        datagen = ImageDataGenerator(
            validation_split=valid_ratio,  # Split ratio for validation set
            rescale=1./255, # Normalize images
        )

    # Create training generator
    train_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='training'  # Specify subset as 'training'
    )

    # Create validation generator
    valid_generator = datagen.flow_from_directory(
        dataset_path_train,
        batch_size=BATCH_SIZE,
        seed = SEED,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        shuffle = True,
        color_mode = 'rgb',
        subset='validation'  # Specify subset as 'validation'
    )

    # For the test set, assuming no augmentation, just rescaling
    test_datagen = ImageDataGenerator(
                rescale=1./255# Normalize images
    )
    test_generator = test_datagen.flow_from_directory(
        dataset_path_test,
        class_mode="categorical",  # Use "categorical" for multi-class classification
        target_size=RESIZE_SHAPE,  # Adjust target size based on your model requirements
        seed = SEED,
        shuffle = False,
        color_mode = 'rgb',
        batch_size=BATCH_SIZE)

    return train_generator, valid_generator, test_generator

# %%
# Creating the generators using functions
train_generator, valid_generator, test_generator = create_generators(dataset_path_train=DATASET_PATH_TRAIN,
                                                                     dataset_path_test = DATASET_PATH_TEST,
                                                                     augment=AUGMENT,
                                                                     augment_type = AUGMENT_TYPE,
                                                                     valid_ratio = VALIDATION_SPLIT)
# Out:
# Found 3324 images belonging to 4 classes.
# Found 1421 images belonging to 4 classes.
# Found 1187 images belonging to 4 classes.

# %% [markdown]
# ## Visualization

# %%
def plot_images(images, labels, classes=None):
    plt.figure(figsize=(8, 8))
    for i in range(15):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)

        # If class labels are provided, add them to the subplot
        if classes is not None:
            label = classes[np.argmax(labels[i])]
            plt.xlabel(label)
    plt.show()


train_images, train_labels = next(train_generator)  # Fetch a batch of images and labels


plot_images(train_images, train_labels)

# %% [markdown]
# ## Essential functions (training)

# %%
# def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
#     ##########################################################################################################
#     saved_best_model_name = 'best_'+model_name+'.h5'

#     model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)

#     # Criteria for early stopping
#     EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)

#     # Set up a model checkpoint to save the best model during training
#     best_model_callback= ModelCheckpoint(model_saving_path,
#                                           monitor=SCORE_TO_MONITOR,
#                                           save_best_only=True,
#                                           mode=SCORE_OBJECTIVE,
#                                           verbose=1)

#     # learning_rate_monitor_callback = ks.callbacks.ReduceLROnPlateau(
#     # monitor  = SCORE_TO_MONITOR,
#     # factor   = REDUCTION_FACTOR,
#     # patience = EPOCH_PATIENCE,
#     # mode     = SCORE_OBJECTIVE,
#     # cooldown = COOLDOWN_EPOCHS
#     # )

#     # # Setup the ReduceLROnPlateau callback
#     reduce_LR = ReduceLROnPlateau(
#         factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
#         patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
#         verbose=1,       # int. 0: quiet, 1: update messages.
#         min_lr=MIN_LR,   # Lower bound on the learning rate.
#         cooldown = COOLDOWN_EPOCHS
#     )

#     my_callbacks = [best_model_callback , reduce_LR , EarlyStop_callback]
#     ##########################################################################################################
#     start_time = time.time()
#     # Fitting the model
#     train_history = model.fit(
#         train_generator,
#         epochs= epochs,
#         batch_size=BATCH_SIZE,
#         validation_data=valid_generator,
#         callbacks=my_callbacks,
#     )
#     total_time = time.time() -start_time
#     return saved_best_model_name, train_history, total_time

# %%
def fit_and_save_best_model_vit(model_name, model, epochs=EPOCHS):
    ##########################################################################################################

    # Criteria for early stopping
    EarlyStop_callback = EarlyStopping(min_delta=0.0001, patience=PATIENCE_EARLY_STOP, restore_best_weights=True)
    ##########################################################################################################

    saved_best_weights = 'best_'+model_name+'_weights'
    PATH_BEST_WEIGHT_SAVE = os.path.join(PATH_BEST_SAVE_WEIGHT, saved_best_weights)
    # Set up a model checkpoint to save the best model during training
    best_weight_callback= ModelCheckpoint(filepath=PATH_BEST_WEIGHT_SAVE,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1,
                                          save_weights_only=True )

    ##########################################################################################################
    # # Setup the ReduceLROnPlateau callback
    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE,      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR,   # Lower bound on the learning rate.
        cooldown = COOLDOWN_EPOCHS
    )

    my_callbacks = [best_weight_callback , reduce_LR , EarlyStop_callback]
    ##########################################################################################################
    start_time = time.time()
    # Fitting the model
    train_history = model.fit(
        train_generator,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_data=valid_generator,
        callbacks=my_callbacks,
    )
    total_time = time.time() -start_time
    return  PATH_BEST_WEIGHT_SAVE, train_history , total_time#model_saving_path,

# %% [markdown]
# ## Essential functions (saving result)

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################ADDDED NEW################################################
    # Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(5*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout
    # plt.show()

    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def show_save_confusion_matrix(predicted_labels, target_labels):
    cm = confusion_matrix(target_labels, predicted_labels)

    plt.figure(figsize=(8, 7))
    sns.heatmap(cm, annot=True, fmt='g',  cmap='Greens')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    # plt.show()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
def calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels):
    # Calculate confusion matrix
    cm = confusion_matrix(true_labels_y_test, predicted_labels)

    class_to_performance_data = {}
    # Calculate TP, FP, TN, FN for each class
    num_classes = cm.shape[0]
    for cls in range(num_classes):
        TP = cm[cls, cls]
        FP = cm[:, cls].sum() - TP
        FN = cm[cls, :].sum() - TP
        TN = cm.sum() - (FP + FN + TP)

        # Calculate support for each class
        support = TP + FN

        class_to_performance_data[cls] = {'TP': TP, 'FP': FP, 'TN': TN, 'FN': FN, 'Support': support}
    return class_to_performance_data


def calculate_metrics(class_to_performance_data, accuracy, SHOW_RESULTS=True, SAVE_RESULTS=True):
    metrics_summary = {
        'overall':{},
        'Macro': {},
        'Weighted': {}
    }

    metrics_summary[ 'overall']= {'accuracy': accuracy}

    # Lists to store metric values for macro averaging
    precision_list, recall_list, f1_score_list = [], [], []
    fpr_list, fnr_list, fdr_list, npv_list = [], [], [], []

    # Variables for weighted sum of metrics
    weighted_precision, weighted_recall, weighted_f1 = 0, 0, 0
    weighted_fpr, weighted_fnr, weighted_fdr, weighted_npv = 0, 0, 0, 0
    total_support = 0

    # Calculate metrics for each class
    for class_id, metrics in class_to_performance_data.items():
        tp = metrics['TP']
        fp = metrics['FP']
        tn = metrics['TN']
        fn = metrics['FN']
        support = metrics['Support']

        # Basic evaluation metrics
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Additional evaluation metrics
        fpr = fp / (fp + tn) if (fp + tn) > 0 else 0
        fnr = fn / (tp + fn) if (tp + fn) > 0 else 0
        fdr = fp / (fp + tp) if (fp + tp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        # Append to lists for macro averaging
        precision_list.append(precision)
        recall_list.append(recall)
        f1_score_list.append(f1_score)
        fpr_list.append(fpr)
        fnr_list.append(fnr)
        fdr_list.append(fdr)
        npv_list.append(npv)

        # Weighted sum of metrics
        weighted_precision += precision * support
        weighted_recall += recall * support
        weighted_f1 += f1_score * support
        weighted_fpr += fpr * support
        weighted_fnr += fnr * support
        weighted_fdr += fdr * support
        weighted_npv += npv * support
        total_support += support

    # Calculate macro averages and round to 5 decimal places
    metrics_summary['Macro']['Precision'] = round(sum(precision_list) / len(precision_list), 5)
    metrics_summary['Macro']['Recall'] = round(sum(recall_list) / len(recall_list), 5)
    metrics_summary['Macro']['F1-Score'] = round(sum(f1_score_list) / len(f1_score_list), 5)
    metrics_summary['Macro']['FPR'] = round(sum(fpr_list) / len(fpr_list), 5)
    metrics_summary['Macro']['FNR'] = round(sum(fnr_list) / len(fnr_list), 5)
    metrics_summary['Macro']['FDR'] = round(sum(fdr_list) / len(fdr_list), 5)
    metrics_summary['Macro']['NPV'] = round(sum(npv_list) / len(npv_list), 5)

    # Calculate weighted averages and round to 5 decimal places
    if total_support > 0:
        metrics_summary['Weighted']['Precision'] = round(weighted_precision / total_support, 5)
        metrics_summary['Weighted']['Recall'] = round(weighted_recall / total_support, 5)
        metrics_summary['Weighted']['F1-Score'] = round(weighted_f1 / total_support, 5)
        metrics_summary['Weighted']['FPR'] = round(weighted_fpr / total_support, 5)
        metrics_summary['Weighted']['FNR'] = round(weighted_fnr / total_support, 5)
        metrics_summary['Weighted']['FDR'] = round(weighted_fdr / total_support, 5)
        metrics_summary['Weighted']['NPV'] = round(weighted_npv / total_support, 5)

    # Convert the nested dictionary into a DataFrame
    report_df = pd.DataFrame.from_dict({(i+" "+j): metrics_summary[i][j]  for i in metrics_summary.keys()  for j in metrics_summary[i].keys()}, orient='index').reset_index()
    # Rename columns for clarity
    report_df.columns = ['Metric Type', 'Value']
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        # if not os.path.exists(PATH_TO_SAVE_RESULT):
        # # If it does not exist, create it
        #     os.makedirs(PATH_TO_SAVE_RESULT)

        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_all_performance_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

    # return metrics_summary

def calculate_accuracy(true_labels_y_test, predicted_labels):
    # Ensure the inputs are NumPy arrays for element-wise comparison
    true_labels_y_test = np.array(true_labels_y_test)
    predicted_labels = np.array(predicted_labels)

    # Calculate the number of correct predictions
    correct_predictions = np.sum(true_labels_y_test == predicted_labels)

    # Calculate the total number of predictions
    total_predictions = len(true_labels_y_test)

    # Calculate accuracy
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Round accuracy to 5 decimal places
    accuracy = round(accuracy, 5)

    return accuracy

# %%
def store_classification_report(predicted_labels, target_labels):
    report_dict = classification_report(target_labels, predicted_labels, output_dict=True)
    report_df = pd.DataFrame(report_dict).transpose()
    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        prediction_report_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_classification_report.csv" )
        # Save the DataFrame to a CSV file
        report_df.to_csv(prediction_report_filename, index=True)

# %%
def show_save_test_results(test_generator, best_model):
    # Evaluate the model on test data
    test_loss, test_accuracy, test_f1_score = best_model.evaluate(test_generator)

    # print(f"Test Loss: {test_loss}")
    # print(f"Test Accuracy: {test_accuracy}")
    # print(f"Test F1 Score: {test_f1_score}")

    test_results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_f1_score': test_f1_score
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)


    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)
        del report_df, test_results
    return  test_loss

# %%
def calculate_test_performance_metrics_all(predicted_labels, target_labels, test_loss):
    # Calculate metrics
    accuracy = accuracy_score(target_labels, predicted_labels)
    precision_macro = precision_score(target_labels, predicted_labels, average='macro')
    recall_macro = recall_score(target_labels, predicted_labels, average='macro')
    f1_macro = f1_score_report(target_labels, predicted_labels, average='macro')

    precision_weighted = precision_score(target_labels, predicted_labels, average='weighted')
    recall_weighted = recall_score(target_labels, predicted_labels, average='weighted')
    f1_weighted = f1_score_report(target_labels, predicted_labels, average='weighted')

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Accuracy': accuracy,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Loss': test_loss
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

    del report_df, test_results

# %% [markdown]
# # MODEL CREATING

# %% [markdown]
# ## Original models from keras

# %% [markdown]
# ### Basic CNN

# %%
# def get_basic_CNN():
#     model = Sequential()

#     # Convolutional and pooling layers
#     model.add(Conv2D(32, (3, 3), activation='relu', input_shape=MODEL_INPUT_SIZE))
#     model.add(MaxPooling2D((2, 2)))
#     model.add(Conv2D(64, (3, 3), activation='relu'))
#     model.add(MaxPooling2D((2, 2)))
#     model.add(Conv2D(128, (3, 3), activation='relu'))
#     model.add(MaxPooling2D((2, 2)))

#     # Flatten the output for fully connected layers
#     model.add(Flatten())

#     # Fully connected layers
#     model.add(Dense(128, activation='relu'))
#     # model.add(Dense(64, activation='relu'))
#     model.add(Dense(NUM_CLASSES, activation='softmax'))  # Adjust the output size based on your problem


#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(loss="categorical_crossentropy",
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %% [markdown]
# ### Inception-V3

# %%
# from tensorflow.keras.applications import InceptionV3
# def get_InceptionV3():

#     model = InceptionV3(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(loss="categorical_crossentropy",
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %% [markdown]
# ### Original mobilenet

# %%
# from tensorflow.keras.applications import MobileNet#### WORKING
# def get_MobileNet_original():

#     model = MobileNet(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(loss="categorical_crossentropy",
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %% [markdown]
# ### Xception

# %%
# from tensorflow.keras.applications import Xception
# def get_Xception():

#     model = Xception(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(loss="categorical_crossentropy",
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %% [markdown]
# ### DenseNet121

# %%
# from tensorflow.keras.applications import  DenseNet121
# def get_DenseNet121():

#     # # Build the functional model
#     model = DenseNet121(input_shape=MODEL_INPUT_SIZE,  weights=None, classes=NUM_CLASSES)

#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(loss="categorical_crossentropy",
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)
#     return model

# %% [markdown]
# ### Ensemble models

# %% [markdown]
# ### ensemble2

# %%
# from tensorflow.keras.applications import Xception, DenseNet121
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble2_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.1,
#                       activation='relu',
#                       units= 1024,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy",
#                       retrain_backbone_network=False,
#                       global_pooling = 'avg',
#                       filters=7,
#                       name='ensemble2'):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Concatenate features
#     concatenated_features = Concatenate()([Xception_features, densenet_features])

#     if filters==3:
#         filters = (3,3)
#     elif filters==5:
#         filters = (5,5)
#     elif filters==7:
#         filters = (7,7)
#     elif filters==9:
#         filters = (9,9)

#     x = Dropout(dropout)(concatenated_features)

#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Add a tunable dropout layer
#     x = Dropout(dropout)(x)

#     # A fully connected layer with a tunable number of units again
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)


#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create and compile the model
#     model = Model(inputs=inputs, outputs=predictions)
#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(
#         optimizer=optimizer,
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %% [markdown]
# ### ensemble3

# %%
# from tensorflow.keras.applications import Xception, DenseNet121, InceptionResNetV2
# # Function to build the model with an ensemble of feature extractors
# def get_ensemble3_model(input_shape=MODEL_INPUT_SIZE,
#                       dropout= 0.2,
#                       activation='relu',
#                       units= 512,
#                       nr_classes=NUM_CLASSES,
#                       loss = "categorical_crossentropy",
#                       retrain_backbone_network=False,
#                       learning_rate = 0.001,
#                       filters=7,
#                       name='ensemble2'):


#     inputs = Input(shape=input_shape)

#     # Feature extraction from DenseNet121
#     densenet_base = DenseNet121(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     densenet_base.trainable = retrain_backbone_network  # Freeze the layers of DenseNet121
#     densenet_features = densenet_base(inputs)
#     densenet_features = GlobalAveragePooling2D()(densenet_features)

#     # Feature extraction from Xception
#     Xception_base = Xception(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     Xception_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     Xception_features = Xception_base(inputs)
#     Xception_features = GlobalAveragePooling2D()(Xception_features)


#         # Feature extraction from Xception
#     InceptionResNetV2_base = InceptionResNetV2(include_top=False, input_tensor=Input(shape=input_shape), weights='imagenet')
#     InceptionResNetV2_base.trainable = retrain_backbone_network # Freeze the layers of Xception
#     InceptionResNetV2_features = InceptionResNetV2_base(inputs)
#     InceptionResNetV2_features = GlobalAveragePooling2D()(InceptionResNetV2_features)


#     # Concatenate the features
#     concatenated_features = Concatenate()([densenet_features, Xception_features, InceptionResNetV2_features])

#     x = Dropout(dropout)(concatenated_features)
#     # A fully connected layer with a tunable number of units
#     x = Dense(units)(x)
#     x = Activation(activation)(x)  # Add ReLU activation before batch normalization
#     x = BatchNormalization()(x)

#     # Output layer
#     predictions = Dense( nr_classes, activation='softmax')(x)

#     # Create the final ensemble model
#     model = Model(inputs=inputs, outputs=predictions)
#     optimizer = Adam(learning_rate=INITIAL_LR )
#     model.compile(
#         optimizer=optimizer,
#         loss=loss,
#         metrics=['accuracy', f1_score]
#     )

#     return model

# %% [markdown]
# ### Original Vit models

# %%
# from parallel_vit import ViT as parallelViT
# from tensorflow.keras.losses import CategoricalCrossentropy

# def get_parallel_vit():
#     model = parallelViT( #v4 --Improving gradually with each epoch val_loss: 2.2053 - val_accuracy: 0.2600 - val_f1_score: 0.1379
#         image_size = max(MODEL_INPUT_SIZE[0], MODEL_INPUT_SIZE[1]),
#         patch_size = 16, # original 16
#         num_classes = NUM_CLASSES,
#         dim = 512,#original 512
#         depth = 6,
#         heads = 20, # original 8
#         mlp_dim = 1024,#original 1024
#         num_parallel_branches = 2,  # in paper, they claimed 2 was optimal
#         dropout = 0.2,
#         emb_dropout = 0.2
#     )

#     optimizer = Adam(learning_rate=INITIAL_LR)
#     model.compile(loss=CategoricalCrossentropy(from_logits=True),
#                   run_eagerly=True,
#                   metrics=['accuracy', f1_score],
#                   optimizer=optimizer)

#     return model

# %%
from vit import ViT
from tensorflow.keras.losses import CategoricalCrossentropy

def get_original_vit():
    model = ViT( # v1 val_accuracy: 0.3172 - val_f1_score: 0.1981
    image_size = 128,
    patch_size = 16,
    num_classes = NUM_CLASSES,
    dim = 512,
    depth = 6,
    heads = 16,
    mlp_dim = 1024,
    dropout = 0.1,
    emb_dropout = 0.1
    )

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss=CategoricalCrossentropy(from_logits=True),
                  run_eagerly=True,
                  metrics=['accuracy', f1_score],
                  optimizer=optimizer)

    return model

# %% [markdown]
# # Train and Results
# - DOES NOT WORK---EfficientNetV2, Nasnet, Resnet, VGG16,
# - DOES NOT WORK--InceptionV3--ERROR: No matching distribution found for tensorflow-directml (checked with colab)
# - DOES NOT WORK--InceptionResNetV2--slighly works
# - original models selected: DenseNet121, -mobilenet X-ception, ,-Inception
# - My models selected: 'ensemble2' (70), Basic CNN v1(91), Basic CNN v2 (92), transfer_mobilenet (85), ensembleXception
# - tuned vit models:  T2TViT(47)",---Cait (26), 16

# %% [markdown]
# ### MobileNet

# %%
# if model_name=='DenseNet121':
#     model= get_DenseNet121()
# elif model_name=='MobileNet':
#     model= get_MobileNet_original()
# elif model_name=='Xception':
#     model= get_Xception()
# elif model_name=='InceptionV3':
#     model= get_InceptionV3()

# ##Getting the model
# model= get_MobileNet_original()
# model= get_DenseNet121()
# model= get_Xception()
# model= get_InceptionV3()
# model = get_cait()
# # ## Getting the model
# model = get_basic_CNN()
# model = get_ensemble2_model()
model = get_original_vit()

# %%
# training the model and saving the best model as a check point
PATH_BEST_WEIGHT_SAVE, train_history , total_time = fit_and_save_best_model_vit(model_name, model)
# Out:
# Epoch 1/120
# 52/52 [==============================] - ETA: 0s - loss: 2.4093 - accuracy: 0.2506 - f1_score: 0.2463
# Epoch 1: val_f1_score improved from -inf to 0.11224, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 80s 2s/step - loss: 2.4093 - accuracy: 0.2506 - f1_score: 0.2463 - val_loss: 1.3780 - val_accuracy: 0.2730 - val_f1_score: 0.1122 - lr: 0.0010
# Epoch 2/120
# 52/52 [==============================] - ETA: 0s - loss: 1.3561 - accuracy: 0.3255 - f1_score: 0.3129
# Epoch 2: val_f1_score improved from 0.11224 to 0.23953, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 77s 1s/step - loss: 1.3561 - accuracy: 0.3255 - f1_score: 0.3129 - val_loss: 1.2678 - val_accuracy: 0.3434 - val_f1_score: 0.2395 - lr: 0.0010
# Epoch 3/120
# 52/52 [==============================] - ETA: 0s - loss: 1.2221 - accuracy: 0.4305 - f1_score: 0.4171
# Epoch 3: val_f1_score improved from 0.23953 to 0.48912, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 75s 1s/step - loss: 1.2221 - accuracy: 0.4305 - f1_score: 0.4171 - val_loss: 1.1299 - val_accuracy: 0.5271 - val_f1_score: 0.4891 - lr: 0.0010
# Epoch 4/120
# 52/52 [==============================] - ETA: 0s - loss: 1.0369 - accuracy: 0.5638 - f1_score: 0.5565
# Epoch 4: val_f1_score improved from 0.48912 to 0.62816, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 83s 2s/step - loss: 1.0369 - accuracy: 0.5638 - f1_score: 0.5565 - val_loss: 0.9637 - val_accuracy: 0.6312 - val_f1_score: 0.6282 - lr: 0.0010
# Epoch 5/120
# 52/52 [==============================] - ETA: 0s - loss: 0.9248 - accuracy: 0.6420 - f1_score: 0.6372
# Epoch 5: val_f1_score did not improve from 0.62816
# 52/52 [==============================] - 77s 1s/step - loss: 0.9248 - accuracy: 0.6420 - f1_score: 0.6372 - val_loss: 0.9586 - val_accuracy: 0.6256 - val_f1_score: 0.6149 - lr: 0.0010
# Epoch 6/120
# 52/52 [==============================] - ETA: 0s - loss: 0.9325 - accuracy: 0.6414 - f1_score: 0.6381
# Epoch 6: val_f1_score improved from 0.62816 to 0.67255, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 76s 1s/step - loss: 0.9325 - accuracy: 0.6414 - f1_score: 0.6381 - val_loss: 0.8601 - val_accuracy: 0.6798 - val_f1_score: 0.6726 - lr: 0.0010
# Epoch 7/120
# 52/52 [==============================] - ETA: 0s - loss: 0.9645 - accuracy: 0.6303 - f1_score: 0.6216
# Epoch 7: val_f1_score did not improve from 0.67255
# 52/52 [==============================] - 83s 2s/step - loss: 0.9645 - accuracy: 0.6303 - f1_score: 0.6216 - val_loss: 0.9426 - val_accuracy: 0.6425 - val_f1_score: 0.6258 - lr: 0.0010
# Epoch 8/120
# 52/52 [==============================] - ETA: 0s - loss: 0.9340 - accuracy: 0.6456 - f1_score: 0.6422
# Epoch 8: val_f1_score did not improve from 0.67255
# 52/52 [==============================] - 87s 2s/step - loss: 0.9340 - accuracy: 0.6456 - f1_score: 0.6422 - val_loss: 0.9094 - val_accuracy: 0.6425 - val_f1_score: 0.6341 - lr: 0.0010
# Epoch 9/120
# 52/52 [==============================] - ETA: 0s - loss: 0.8397 - accuracy: 0.6796 - f1_score: 0.6765
# Epoch 9: val_f1_score improved from 0.67255 to 0.68113, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 87s 2s/step - loss: 0.8397 - accuracy: 0.6796 - f1_score: 0.6765 - val_loss: 0.8026 - val_accuracy: 0.6897 - val_f1_score: 0.6811 - lr: 0.0010
# Epoch 10/120
# 52/52 [==============================] - ETA: 0s - loss: 0.8082 - accuracy: 0.6847 - f1_score: 0.6825
# Epoch 10: val_f1_score improved from 0.68113 to 0.68599, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 109s 2s/step - loss: 0.8082 - accuracy: 0.6847 - f1_score: 0.6825 - val_loss: 0.7933 - val_accuracy: 0.6974 - val_f1_score: 0.6860 - lr: 0.0010
# Epoch 11/120
# 52/52 [==============================] - ETA: 0s - loss: 0.7616 - accuracy: 0.7073 - f1_score: 0.7066
# Epoch 11: val_f1_score did not improve from 0.68599
# 52/52 [==============================] - 125s 2s/step - loss: 0.7616 - accuracy: 0.7073 - f1_score: 0.7066 - val_loss: 0.8193 - val_accuracy: 0.6819 - val_f1_score: 0.6556 - lr: 0.0010
# Epoch 12/120
# 52/52 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.7292 - f1_score: 0.7290
# Epoch 12: val_f1_score improved from 0.68599 to 0.70309, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 129s 2s/step - loss: 0.6909 - accuracy: 0.7292 - f1_score: 0.7290 - val_loss: 0.7410 - val_accuracy: 0.7058 - val_f1_score: 0.7031 - lr: 0.0010
# Epoch 13/120
# 52/52 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.7301 - f1_score: 0.7292
# Epoch 13: val_f1_score improved from 0.70309 to 0.74335, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 135s 3s/step - loss: 0.7055 - accuracy: 0.7301 - f1_score: 0.7292 - val_loss: 0.6888 - val_accuracy: 0.7424 - val_f1_score: 0.7433 - lr: 0.0010
# Epoch 14/120
# 52/52 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.7326 - f1_score: 0.7328
# Epoch 14: val_f1_score did not improve from 0.74335
# 52/52 [==============================] - 137s 3s/step - loss: 0.6913 - accuracy: 0.7326 - f1_score: 0.7328 - val_loss: 0.6850 - val_accuracy: 0.7312 - val_f1_score: 0.7212 - lr: 0.0010
# Epoch 15/120
# 52/52 [==============================] - ETA: 0s - loss: 0.6896 - accuracy: 0.7356 - f1_score: 0.7345
# Epoch 15: val_f1_score improved from 0.74335 to 0.75164, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 131s 3s/step - loss: 0.6896 - accuracy: 0.7356 - f1_score: 0.7345 - val_loss: 0.6181 - val_accuracy: 0.7523 - val_f1_score: 0.7516 - lr: 0.0010
# Epoch 16/120
# 52/52 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.7506 - f1_score: 0.7510
# Epoch 16: val_f1_score improved from 0.75164 to 0.75968, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 101s 2s/step - loss: 0.6351 - accuracy: 0.7506 - f1_score: 0.7510 - val_loss: 0.6278 - val_accuracy: 0.7579 - val_f1_score: 0.7597 - lr: 0.0010
# Epoch 17/120
# 52/52 [==============================] - ETA: 0s - loss: 0.7153 - accuracy: 0.7169 - f1_score: 0.7159
# Epoch 17: val_f1_score did not improve from 0.75968
# 52/52 [==============================] - 101s 2s/step - loss: 0.7153 - accuracy: 0.7169 - f1_score: 0.7159 - val_loss: 0.6706 - val_accuracy: 0.7220 - val_f1_score: 0.7221 - lr: 0.0010
# Epoch 18/120
# 52/52 [==============================] - ETA: 0s - loss: 0.6363 - accuracy: 0.7506 - f1_score: 0.7514
# Epoch 18: val_f1_score did not improve from 0.75968
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 52/52 [==============================] - 102s 2s/step - loss: 0.6363 - accuracy: 0.7506 - f1_score: 0.7514 - val_loss: 0.6648 - val_accuracy: 0.7481 - val_f1_score: 0.7436 - lr: 0.0010
# Epoch 19/120
# 52/52 [==============================] - ETA: 0s - loss: 0.5627 - accuracy: 0.7813 - f1_score: 0.7815
# Epoch 19: val_f1_score did not improve from 0.75968
# 52/52 [==============================] - 103s 2s/step - loss: 0.5627 - accuracy: 0.7813 - f1_score: 0.7815 - val_loss: 0.6201 - val_accuracy: 0.7600 - val_f1_score: 0.7594 - lr: 5.0000e-04
# Epoch 20/120
# 52/52 [==============================] - ETA: 0s - loss: 0.5315 - accuracy: 0.7825 - f1_score: 0.7829
# Epoch 20: val_f1_score improved from 0.75968 to 0.77999, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 113s 2s/step - loss: 0.5315 - accuracy: 0.7825 - f1_score: 0.7829 - val_loss: 0.5146 - val_accuracy: 0.7875 - val_f1_score: 0.7800 - lr: 5.0000e-04
# Epoch 21/120
# 52/52 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.7885 - f1_score: 0.7892
# Epoch 21: val_f1_score improved from 0.77999 to 0.78285, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 118s 2s/step - loss: 0.5302 - accuracy: 0.7885 - f1_score: 0.7892 - val_loss: 0.5393 - val_accuracy: 0.7797 - val_f1_score: 0.7829 - lr: 5.0000e-04
# Epoch 22/120
# 52/52 [==============================] - ETA: 0s - loss: 0.5175 - accuracy: 0.7942 - f1_score: 0.7957
# Epoch 22: val_f1_score improved from 0.78285 to 0.80490, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 113s 2s/step - loss: 0.5175 - accuracy: 0.7942 - f1_score: 0.7957 - val_loss: 0.4675 - val_accuracy: 0.8072 - val_f1_score: 0.8049 - lr: 5.0000e-04
# Epoch 23/120
# 52/52 [==============================] - ETA: 0s - loss: 0.4889 - accuracy: 0.8060 - f1_score: 0.8075
# Epoch 23: val_f1_score improved from 0.80490 to 0.81863, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 102s 2s/step - loss: 0.4889 - accuracy: 0.8060 - f1_score: 0.8075 - val_loss: 0.4387 - val_accuracy: 0.8213 - val_f1_score: 0.8186 - lr: 5.0000e-04
# Epoch 24/120
# 52/52 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.8171 - f1_score: 0.8189
# Epoch 24: val_f1_score improved from 0.81863 to 0.84089, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 97s 2s/step - loss: 0.4661 - accuracy: 0.8171 - f1_score: 0.8189 - val_loss: 0.4291 - val_accuracy: 0.8381 - val_f1_score: 0.8409 - lr: 5.0000e-04
# Epoch 25/120
# 52/52 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.8156 - f1_score: 0.8174
# Epoch 25: val_f1_score did not improve from 0.84089
# 52/52 [==============================] - 103s 2s/step - loss: 0.4653 - accuracy: 0.8156 - f1_score: 0.8174 - val_loss: 0.4983 - val_accuracy: 0.7952 - val_f1_score: 0.7925 - lr: 5.0000e-04
# Epoch 26/120
# 52/52 [==============================] - ETA: 0s - loss: 0.4811 - accuracy: 0.8132 - f1_score: 0.8146
# Epoch 26: val_f1_score did not improve from 0.84089
# 52/52 [==============================] - 124s 2s/step - loss: 0.4811 - accuracy: 0.8132 - f1_score: 0.8146 - val_loss: 0.4687 - val_accuracy: 0.8149 - val_f1_score: 0.8199 - lr: 5.0000e-04
# Epoch 27/120
# 52/52 [==============================] - ETA: 0s - loss: 0.5005 - accuracy: 0.8005 - f1_score: 0.8022
# Epoch 27: val_f1_score did not improve from 0.84089
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 52/52 [==============================] - 132s 3s/step - loss: 0.5005 - accuracy: 0.8005 - f1_score: 0.8022 - val_loss: 0.5114 - val_accuracy: 0.8037 - val_f1_score: 0.8043 - lr: 5.0000e-04
# Epoch 28/120
# 52/52 [==============================] - ETA: 0s - loss: 0.4009 - accuracy: 0.8436 - f1_score: 0.8454
# Epoch 28: val_f1_score improved from 0.84089 to 0.84290, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 110s 2s/step - loss: 0.4009 - accuracy: 0.8436 - f1_score: 0.8454 - val_loss: 0.3914 - val_accuracy: 0.8424 - val_f1_score: 0.8429 - lr: 2.5000e-04
# Epoch 29/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8430 - f1_score: 0.8450
# Epoch 29: val_f1_score did not improve from 0.84290
# 52/52 [==============================] - 107s 2s/step - loss: 0.3878 - accuracy: 0.8430 - f1_score: 0.8450 - val_loss: 0.3847 - val_accuracy: 0.8395 - val_f1_score: 0.8383 - lr: 2.5000e-04
# Epoch 30/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8502 - f1_score: 0.8522
# Epoch 30: val_f1_score did not improve from 0.84290
# 52/52 [==============================] - 115s 2s/step - loss: 0.3801 - accuracy: 0.8502 - f1_score: 0.8522 - val_loss: 0.4090 - val_accuracy: 0.8360 - val_f1_score: 0.8357 - lr: 2.5000e-04
# Epoch 31/120
# 52/52 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.8406 - f1_score: 0.8417
# Epoch 31: val_f1_score improved from 0.84290 to 0.84309, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 122s 2s/step - loss: 0.4074 - accuracy: 0.8406 - f1_score: 0.8417 - val_loss: 0.3802 - val_accuracy: 0.8431 - val_f1_score: 0.8431 - lr: 2.5000e-04
# Epoch 32/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3745 - accuracy: 0.8547 - f1_score: 0.8571
# Epoch 32: val_f1_score improved from 0.84309 to 0.87035, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 123s 2s/step - loss: 0.3745 - accuracy: 0.8547 - f1_score: 0.8571 - val_loss: 0.3464 - val_accuracy: 0.8684 - val_f1_score: 0.8704 - lr: 2.5000e-04
# Epoch 33/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3597 - accuracy: 0.8559 - f1_score: 0.8580
# Epoch 33: val_f1_score did not improve from 0.87035
# 52/52 [==============================] - 123s 2s/step - loss: 0.3597 - accuracy: 0.8559 - f1_score: 0.8580 - val_loss: 0.4039 - val_accuracy: 0.8501 - val_f1_score: 0.8496 - lr: 2.5000e-04
# Epoch 34/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8577 - f1_score: 0.8590
# Epoch 34: val_f1_score improved from 0.87035 to 0.88117, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 130s 3s/step - loss: 0.3607 - accuracy: 0.8577 - f1_score: 0.8590 - val_loss: 0.3202 - val_accuracy: 0.8811 - val_f1_score: 0.8812 - lr: 2.5000e-04
# Epoch 35/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.8634 - f1_score: 0.8650
# Epoch 35: val_f1_score did not improve from 0.88117
# 52/52 [==============================] - 129s 2s/step - loss: 0.3484 - accuracy: 0.8634 - f1_score: 0.8650 - val_loss: 0.3399 - val_accuracy: 0.8712 - val_f1_score: 0.8720 - lr: 2.5000e-04
# Epoch 36/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.8661 - f1_score: 0.8682
# Epoch 36: val_f1_score did not improve from 0.88117
# 52/52 [==============================] - 149s 3s/step - loss: 0.3459 - accuracy: 0.8661 - f1_score: 0.8682 - val_loss: 0.3519 - val_accuracy: 0.8494 - val_f1_score: 0.8503 - lr: 2.5000e-04
# Epoch 37/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8785 - f1_score: 0.8801
# Epoch 37: val_f1_score improved from 0.88117 to 0.88395, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 136s 3s/step - loss: 0.3199 - accuracy: 0.8785 - f1_score: 0.8801 - val_loss: 0.3153 - val_accuracy: 0.8832 - val_f1_score: 0.8839 - lr: 2.5000e-04
# Epoch 38/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8755 - f1_score: 0.8773
# Epoch 38: val_f1_score did not improve from 0.88395
# 52/52 [==============================] - 162s 3s/step - loss: 0.3222 - accuracy: 0.8755 - f1_score: 0.8773 - val_loss: 0.3129 - val_accuracy: 0.8825 - val_f1_score: 0.8822 - lr: 2.5000e-04
# Epoch 39/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.8791 - f1_score: 0.8806
# Epoch 39: val_f1_score improved from 0.88395 to 0.88931, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 176s 3s/step - loss: 0.3088 - accuracy: 0.8791 - f1_score: 0.8806 - val_loss: 0.3083 - val_accuracy: 0.8888 - val_f1_score: 0.8893 - lr: 2.5000e-04
# Epoch 40/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8742 - f1_score: 0.8759
# Epoch 40: val_f1_score did not improve from 0.88931
# 52/52 [==============================] - 179s 3s/step - loss: 0.3232 - accuracy: 0.8742 - f1_score: 0.8759 - val_loss: 0.3328 - val_accuracy: 0.8642 - val_f1_score: 0.8632 - lr: 2.5000e-04
# Epoch 41/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8767 - f1_score: 0.8783
# Epoch 41: val_f1_score did not improve from 0.88931
# 52/52 [==============================] - 232s 4s/step - loss: 0.3159 - accuracy: 0.8767 - f1_score: 0.8783 - val_loss: 0.3515 - val_accuracy: 0.8670 - val_f1_score: 0.8652 - lr: 2.5000e-04
# Epoch 42/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.8962 - f1_score: 0.8975
# Epoch 42: val_f1_score did not improve from 0.88931
# 52/52 [==============================] - 229s 4s/step - loss: 0.2669 - accuracy: 0.8962 - f1_score: 0.8975 - val_loss: 0.2917 - val_accuracy: 0.8825 - val_f1_score: 0.8840 - lr: 2.5000e-04
# Epoch 43/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.8935 - f1_score: 0.8953
# Epoch 43: val_f1_score improved from 0.88931 to 0.90192, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 240s 5s/step - loss: 0.2790 - accuracy: 0.8935 - f1_score: 0.8953 - val_loss: 0.2692 - val_accuracy: 0.9015 - val_f1_score: 0.9019 - lr: 2.5000e-04
# Epoch 44/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8917 - f1_score: 0.8936
# Epoch 44: val_f1_score improved from 0.90192 to 0.90943, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 240s 5s/step - loss: 0.2817 - accuracy: 0.8917 - f1_score: 0.8936 - val_loss: 0.2616 - val_accuracy: 0.9085 - val_f1_score: 0.9094 - lr: 2.5000e-04
# Epoch 45/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.8950 - f1_score: 0.8964
# Epoch 45: val_f1_score did not improve from 0.90943
# 52/52 [==============================] - 236s 5s/step - loss: 0.2717 - accuracy: 0.8950 - f1_score: 0.8964 - val_loss: 0.2773 - val_accuracy: 0.8980 - val_f1_score: 0.9000 - lr: 2.5000e-04
# Epoch 46/120
# 52/52 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8878 - f1_score: 0.8890
# Epoch 46: val_f1_score did not improve from 0.90943
# 52/52 [==============================] - 250s 5s/step - loss: 0.3033 - accuracy: 0.8878 - f1_score: 0.8890 - val_loss: 0.3870 - val_accuracy: 0.8487 - val_f1_score: 0.8489 - lr: 2.5000e-04
# Epoch 47/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.8890 - f1_score: 0.8900
# Epoch 47: val_f1_score did not improve from 0.90943
# 52/52 [==============================] - 250s 5s/step - loss: 0.2948 - accuracy: 0.8890 - f1_score: 0.8900 - val_loss: 0.2594 - val_accuracy: 0.9078 - val_f1_score: 0.9090 - lr: 2.5000e-04
# Epoch 48/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8959 - f1_score: 0.8976
# Epoch 48: val_f1_score did not improve from 0.90943
# 52/52 [==============================] - 237s 5s/step - loss: 0.2754 - accuracy: 0.8959 - f1_score: 0.8976 - val_loss: 0.2487 - val_accuracy: 0.8987 - val_f1_score: 0.8980 - lr: 2.5000e-04
# Epoch 49/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2518 - accuracy: 0.9055 - f1_score: 0.9071
# Epoch 49: val_f1_score did not improve from 0.90943
# 52/52 [==============================] - 246s 5s/step - loss: 0.2518 - accuracy: 0.9055 - f1_score: 0.9071 - val_loss: 0.2429 - val_accuracy: 0.9022 - val_f1_score: 0.9029 - lr: 2.5000e-04
# Epoch 50/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9100 - f1_score: 0.9110
# Epoch 50: val_f1_score did not improve from 0.90943
# 52/52 [==============================] - 246s 5s/step - loss: 0.2338 - accuracy: 0.9100 - f1_score: 0.9110 - val_loss: 0.2490 - val_accuracy: 0.9008 - val_f1_score: 0.9024 - lr: 2.5000e-04
# Epoch 51/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9113 - f1_score: 0.9123
# Epoch 51: val_f1_score improved from 0.90943 to 0.91848, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 242s 5s/step - loss: 0.2303 - accuracy: 0.9113 - f1_score: 0.9123 - val_loss: 0.2225 - val_accuracy: 0.9177 - val_f1_score: 0.9185 - lr: 2.5000e-04
# Epoch 52/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9122 - f1_score: 0.9134
# Epoch 52: val_f1_score did not improve from 0.91848
# 52/52 [==============================] - 244s 5s/step - loss: 0.2485 - accuracy: 0.9122 - f1_score: 0.9134 - val_loss: 0.2615 - val_accuracy: 0.8923 - val_f1_score: 0.8911 - lr: 2.5000e-04
# Epoch 53/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8989 - f1_score: 0.8999
# Epoch 53: val_f1_score did not improve from 0.91848
# 52/52 [==============================] - 240s 5s/step - loss: 0.2657 - accuracy: 0.8989 - f1_score: 0.8999 - val_loss: 0.2403 - val_accuracy: 0.9029 - val_f1_score: 0.9034 - lr: 2.5000e-04
# Epoch 54/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9037 - f1_score: 0.9049
# Epoch 54: val_f1_score did not improve from 0.91848
# 52/52 [==============================] - 250s 5s/step - loss: 0.2565 - accuracy: 0.9037 - f1_score: 0.9049 - val_loss: 0.2123 - val_accuracy: 0.9148 - val_f1_score: 0.9152 - lr: 2.5000e-04
# Epoch 55/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2332 - accuracy: 0.9097 - f1_score: 0.9107
# Epoch 55: val_f1_score did not improve from 0.91848
# 52/52 [==============================] - 243s 5s/step - loss: 0.2332 - accuracy: 0.9097 - f1_score: 0.9107 - val_loss: 0.2437 - val_accuracy: 0.9078 - val_f1_score: 0.9082 - lr: 2.5000e-04
# Epoch 56/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9085 - f1_score: 0.9096
# Epoch 56: val_f1_score improved from 0.91848 to 0.93377, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 250s 5s/step - loss: 0.2383 - accuracy: 0.9085 - f1_score: 0.9096 - val_loss: 0.1947 - val_accuracy: 0.9324 - val_f1_score: 0.9338 - lr: 2.5000e-04
# Epoch 57/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9125 - f1_score: 0.9135
# Epoch 57: val_f1_score did not improve from 0.93377
# 52/52 [==============================] - 256s 5s/step - loss: 0.2228 - accuracy: 0.9125 - f1_score: 0.9135 - val_loss: 0.2287 - val_accuracy: 0.9184 - val_f1_score: 0.9200 - lr: 2.5000e-04
# Epoch 58/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9164 - f1_score: 0.9177
# Epoch 58: val_f1_score did not improve from 0.93377
# 52/52 [==============================] - 303s 6s/step - loss: 0.2197 - accuracy: 0.9164 - f1_score: 0.9177 - val_loss: 0.1870 - val_accuracy: 0.9289 - val_f1_score: 0.9291 - lr: 2.5000e-04
# Epoch 59/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9194 - f1_score: 0.9204
# Epoch 59: val_f1_score did not improve from 0.93377
# 52/52 [==============================] - 303s 6s/step - loss: 0.2208 - accuracy: 0.9194 - f1_score: 0.9204 - val_loss: 0.2038 - val_accuracy: 0.9317 - val_f1_score: 0.9323 - lr: 2.5000e-04
# Epoch 60/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9197 - f1_score: 0.9205
# Epoch 60: val_f1_score did not improve from 0.93377
# 52/52 [==============================] - 305s 6s/step - loss: 0.2054 - accuracy: 0.9197 - f1_score: 0.9205 - val_loss: 0.1811 - val_accuracy: 0.9324 - val_f1_score: 0.9335 - lr: 2.5000e-04
# Epoch 61/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8872 - f1_score: 0.8887
# Epoch 61: val_f1_score did not improve from 0.93377
# 52/52 [==============================] - 313s 6s/step - loss: 0.2810 - accuracy: 0.8872 - f1_score: 0.8887 - val_loss: 0.2192 - val_accuracy: 0.9106 - val_f1_score: 0.9116 - lr: 2.5000e-04
# Epoch 62/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2007 - accuracy: 0.9212 - f1_score: 0.9224
# Epoch 62: val_f1_score did not improve from 0.93377
# 52/52 [==============================] - 322s 6s/step - loss: 0.2007 - accuracy: 0.9212 - f1_score: 0.9224 - val_loss: 0.1862 - val_accuracy: 0.9317 - val_f1_score: 0.9325 - lr: 2.5000e-04
# Epoch 63/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9326 - f1_score: 0.9336
# Epoch 63: val_f1_score improved from 0.93377 to 0.93748, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 333s 6s/step - loss: 0.1771 - accuracy: 0.9326 - f1_score: 0.9336 - val_loss: 0.1659 - val_accuracy: 0.9367 - val_f1_score: 0.9375 - lr: 2.5000e-04
# Epoch 64/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1844 - accuracy: 0.9305 - f1_score: 0.9312
# Epoch 64: val_f1_score did not improve from 0.93748
# 52/52 [==============================] - 337s 6s/step - loss: 0.1844 - accuracy: 0.9305 - f1_score: 0.9312 - val_loss: 0.2167 - val_accuracy: 0.9219 - val_f1_score: 0.9218 - lr: 2.5000e-04
# Epoch 65/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9284 - f1_score: 0.9293
# Epoch 65: val_f1_score did not improve from 0.93748
# 52/52 [==============================] - 345s 7s/step - loss: 0.2059 - accuracy: 0.9284 - f1_score: 0.9293 - val_loss: 0.1915 - val_accuracy: 0.9289 - val_f1_score: 0.9285 - lr: 2.5000e-04
# Epoch 66/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9287 - f1_score: 0.9297
# Epoch 66: val_f1_score improved from 0.93748 to 0.94680, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 356s 7s/step - loss: 0.1817 - accuracy: 0.9287 - f1_score: 0.9297 - val_loss: 0.1489 - val_accuracy: 0.9458 - val_f1_score: 0.9468 - lr: 2.5000e-04
# Epoch 67/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9311 - f1_score: 0.9322
# Epoch 67: val_f1_score did not improve from 0.94680
# 52/52 [==============================] - 370s 7s/step - loss: 0.2000 - accuracy: 0.9311 - f1_score: 0.9322 - val_loss: 0.2050 - val_accuracy: 0.9275 - val_f1_score: 0.9285 - lr: 2.5000e-04
# Epoch 68/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9185 - f1_score: 0.9195
# Epoch 68: val_f1_score did not improve from 0.94680
# 52/52 [==============================] - 320s 6s/step - loss: 0.2238 - accuracy: 0.9185 - f1_score: 0.9195 - val_loss: 0.2425 - val_accuracy: 0.9099 - val_f1_score: 0.9104 - lr: 2.5000e-04
# Epoch 69/120
# 52/52 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9131 - f1_score: 0.9142
# Epoch 69: val_f1_score did not improve from 0.94680
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 52/52 [==============================] - 373s 7s/step - loss: 0.2093 - accuracy: 0.9131 - f1_score: 0.9142 - val_loss: 0.2041 - val_accuracy: 0.9254 - val_f1_score: 0.9262 - lr: 2.5000e-04
# Epoch 70/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9350 - f1_score: 0.9359
# Epoch 70: val_f1_score did not improve from 0.94680
# 52/52 [==============================] - 334s 6s/step - loss: 0.1692 - accuracy: 0.9350 - f1_score: 0.9359 - val_loss: 0.1589 - val_accuracy: 0.9409 - val_f1_score: 0.9413 - lr: 1.2500e-04
# Epoch 71/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9422 - f1_score: 0.9429
# Epoch 71: val_f1_score improved from 0.94680 to 0.94862, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 317s 6s/step - loss: 0.1486 - accuracy: 0.9422 - f1_score: 0.9429 - val_loss: 0.1420 - val_accuracy: 0.9479 - val_f1_score: 0.9486 - lr: 1.2500e-04
# Epoch 72/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9471 - f1_score: 0.9481
# Epoch 72: val_f1_score did not improve from 0.94862
# 52/52 [==============================] - 323s 6s/step - loss: 0.1447 - accuracy: 0.9471 - f1_score: 0.9481 - val_loss: 0.1562 - val_accuracy: 0.9430 - val_f1_score: 0.9436 - lr: 1.2500e-04
# Epoch 73/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9465 - f1_score: 0.9473
# Epoch 73: val_f1_score improved from 0.94862 to 0.94978, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 312s 6s/step - loss: 0.1422 - accuracy: 0.9465 - f1_score: 0.9473 - val_loss: 0.1338 - val_accuracy: 0.9493 - val_f1_score: 0.9498 - lr: 1.2500e-04
# Epoch 74/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9377 - f1_score: 0.9386
# Epoch 74: val_f1_score did not improve from 0.94978
# 52/52 [==============================] - 320s 6s/step - loss: 0.1595 - accuracy: 0.9377 - f1_score: 0.9386 - val_loss: 0.1693 - val_accuracy: 0.9388 - val_f1_score: 0.9390 - lr: 1.2500e-04
# Epoch 75/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9386 - f1_score: 0.9395
# Epoch 75: val_f1_score improved from 0.94978 to 0.95309, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 330s 6s/step - loss: 0.1651 - accuracy: 0.9386 - f1_score: 0.9395 - val_loss: 0.1366 - val_accuracy: 0.9521 - val_f1_score: 0.9531 - lr: 1.2500e-04
# Epoch 76/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9422 - f1_score: 0.9433
# Epoch 76: val_f1_score did not improve from 0.95309
# 52/52 [==============================] - 383s 7s/step - loss: 0.1521 - accuracy: 0.9422 - f1_score: 0.9433 - val_loss: 0.1332 - val_accuracy: 0.9507 - val_f1_score: 0.9513 - lr: 1.2500e-04
# Epoch 77/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9504 - f1_score: 0.9510
# Epoch 77: val_f1_score improved from 0.95309 to 0.95766, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 357s 7s/step - loss: 0.1361 - accuracy: 0.9504 - f1_score: 0.9510 - val_loss: 0.1199 - val_accuracy: 0.9571 - val_f1_score: 0.9577 - lr: 1.2500e-04
# Epoch 78/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9480 - f1_score: 0.9485
# Epoch 78: val_f1_score did not improve from 0.95766
# 52/52 [==============================] - 349s 7s/step - loss: 0.1342 - accuracy: 0.9480 - f1_score: 0.9485 - val_loss: 0.1380 - val_accuracy: 0.9500 - val_f1_score: 0.9498 - lr: 1.2500e-04
# Epoch 79/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9549 - f1_score: 0.9555
# Epoch 79: val_f1_score did not improve from 0.95766
# 52/52 [==============================] - 345s 7s/step - loss: 0.1255 - accuracy: 0.9549 - f1_score: 0.9555 - val_loss: 0.1159 - val_accuracy: 0.9543 - val_f1_score: 0.9552 - lr: 1.2500e-04
# Epoch 80/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9477 - f1_score: 0.9487
# Epoch 80: val_f1_score did not improve from 0.95766
# 52/52 [==============================] - 366s 7s/step - loss: 0.1445 - accuracy: 0.9477 - f1_score: 0.9487 - val_loss: 0.1031 - val_accuracy: 0.9557 - val_f1_score: 0.9564 - lr: 1.2500e-04
# Epoch 81/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9531 - f1_score: 0.9539
# Epoch 81: val_f1_score improved from 0.95766 to 0.96439, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 367s 7s/step - loss: 0.1240 - accuracy: 0.9531 - f1_score: 0.9539 - val_loss: 0.1053 - val_accuracy: 0.9641 - val_f1_score: 0.9644 - lr: 1.2500e-04
# Epoch 82/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9603 - f1_score: 0.9610
# Epoch 82: val_f1_score improved from 0.96439 to 0.96545, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 386s 7s/step - loss: 0.1154 - accuracy: 0.9603 - f1_score: 0.9610 - val_loss: 0.1061 - val_accuracy: 0.9648 - val_f1_score: 0.9655 - lr: 1.2500e-04
# Epoch 83/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9522 - f1_score: 0.9530
# Epoch 83: val_f1_score improved from 0.96545 to 0.97041, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 388s 7s/step - loss: 0.1186 - accuracy: 0.9522 - f1_score: 0.9530 - val_loss: 0.0886 - val_accuracy: 0.9697 - val_f1_score: 0.9704 - lr: 1.2500e-04
# Epoch 84/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1213 - accuracy: 0.9522 - f1_score: 0.9528
# Epoch 84: val_f1_score improved from 0.97041 to 0.97380, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 384s 7s/step - loss: 0.1213 - accuracy: 0.9522 - f1_score: 0.9528 - val_loss: 0.0725 - val_accuracy: 0.9733 - val_f1_score: 0.9738 - lr: 1.2500e-04
# Epoch 85/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9633 - f1_score: 0.9640
# Epoch 85: val_f1_score did not improve from 0.97380
# 52/52 [==============================] - 393s 8s/step - loss: 0.1046 - accuracy: 0.9633 - f1_score: 0.9640 - val_loss: 0.1177 - val_accuracy: 0.9571 - val_f1_score: 0.9572 - lr: 1.2500e-04
# Epoch 86/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9639 - f1_score: 0.9642
# Epoch 86: val_f1_score did not improve from 0.97380
# 52/52 [==============================] - 390s 7s/step - loss: 0.0957 - accuracy: 0.9639 - f1_score: 0.9642 - val_loss: 0.1047 - val_accuracy: 0.9613 - val_f1_score: 0.9615 - lr: 1.2500e-04
# Epoch 87/120
# 52/52 [==============================] - ETA: 0s - loss: 0.1020 - accuracy: 0.9585 - f1_score: 0.9593
# Epoch 87: val_f1_score did not improve from 0.97380
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 52/52 [==============================] - 496s 10s/step - loss: 0.1020 - accuracy: 0.9585 - f1_score: 0.9593 - val_loss: 0.0968 - val_accuracy: 0.9676 - val_f1_score: 0.9681 - lr: 1.2500e-04
# Epoch 88/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9699 - f1_score: 0.9706
# Epoch 88: val_f1_score improved from 0.97380 to 0.97566, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 509s 10s/step - loss: 0.0861 - accuracy: 0.9699 - f1_score: 0.9706 - val_loss: 0.0831 - val_accuracy: 0.9754 - val_f1_score: 0.9757 - lr: 6.2500e-05
# Epoch 89/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9690 - f1_score: 0.9696
# Epoch 89: val_f1_score improved from 0.97566 to 0.97851, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 521s 10s/step - loss: 0.0824 - accuracy: 0.9690 - f1_score: 0.9696 - val_loss: 0.0660 - val_accuracy: 0.9782 - val_f1_score: 0.9785 - lr: 6.2500e-05
# Epoch 90/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9690 - f1_score: 0.9696
# Epoch 90: val_f1_score did not improve from 0.97851
# 52/52 [==============================] - 509s 10s/step - loss: 0.0831 - accuracy: 0.9690 - f1_score: 0.9696 - val_loss: 0.0713 - val_accuracy: 0.9768 - val_f1_score: 0.9770 - lr: 6.2500e-05
# Epoch 91/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9693 - f1_score: 0.9698
# Epoch 91: val_f1_score did not improve from 0.97851
# 52/52 [==============================] - 482s 9s/step - loss: 0.0917 - accuracy: 0.9693 - f1_score: 0.9698 - val_loss: 0.0776 - val_accuracy: 0.9768 - val_f1_score: 0.9773 - lr: 6.2500e-05
# Epoch 92/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9756 - f1_score: 0.9761
# Epoch 92: val_f1_score improved from 0.97851 to 0.98054, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 441s 8s/step - loss: 0.0741 - accuracy: 0.9756 - f1_score: 0.9761 - val_loss: 0.0636 - val_accuracy: 0.9803 - val_f1_score: 0.9805 - lr: 6.2500e-05
# Epoch 93/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9726 - f1_score: 0.9729
# Epoch 93: val_f1_score did not improve from 0.98054
# 52/52 [==============================] - 427s 8s/step - loss: 0.0749 - accuracy: 0.9726 - f1_score: 0.9729 - val_loss: 0.0753 - val_accuracy: 0.9683 - val_f1_score: 0.9689 - lr: 6.2500e-05
# Epoch 94/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9708 - f1_score: 0.9713
# Epoch 94: val_f1_score did not improve from 0.98054
# 52/52 [==============================] - 460s 9s/step - loss: 0.0835 - accuracy: 0.9708 - f1_score: 0.9713 - val_loss: 0.0789 - val_accuracy: 0.9704 - val_f1_score: 0.9705 - lr: 6.2500e-05
# Epoch 95/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9699 - f1_score: 0.9705
# Epoch 95: val_f1_score did not improve from 0.98054
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 52/52 [==============================] - 477s 9s/step - loss: 0.0803 - accuracy: 0.9699 - f1_score: 0.9705 - val_loss: 0.0758 - val_accuracy: 0.9704 - val_f1_score: 0.9708 - lr: 6.2500e-05
# Epoch 96/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9702 - f1_score: 0.9707
# Epoch 96: val_f1_score did not improve from 0.98054
# 52/52 [==============================] - 446s 9s/step - loss: 0.0765 - accuracy: 0.9702 - f1_score: 0.9707 - val_loss: 0.0730 - val_accuracy: 0.9697 - val_f1_score: 0.9704 - lr: 3.1250e-05
# Epoch 97/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9723 - f1_score: 0.9727
# Epoch 97: val_f1_score improved from 0.98054 to 0.98067, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 457s 9s/step - loss: 0.0771 - accuracy: 0.9723 - f1_score: 0.9727 - val_loss: 0.0560 - val_accuracy: 0.9803 - val_f1_score: 0.9807 - lr: 3.1250e-05
# Epoch 98/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9669 - f1_score: 0.9674
# Epoch 98: val_f1_score did not improve from 0.98067
# 52/52 [==============================] - 472s 9s/step - loss: 0.0846 - accuracy: 0.9669 - f1_score: 0.9674 - val_loss: 0.0518 - val_accuracy: 0.9768 - val_f1_score: 0.9770 - lr: 3.1250e-05
# Epoch 99/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9720 - f1_score: 0.9725
# Epoch 99: val_f1_score did not improve from 0.98067
# 52/52 [==============================] - 470s 9s/step - loss: 0.0784 - accuracy: 0.9720 - f1_score: 0.9725 - val_loss: 0.0586 - val_accuracy: 0.9796 - val_f1_score: 0.9795 - lr: 3.1250e-05
# Epoch 100/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9759 - f1_score: 0.9764
# Epoch 100: val_f1_score improved from 0.98067 to 0.98404, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 489s 9s/step - loss: 0.0692 - accuracy: 0.9759 - f1_score: 0.9764 - val_loss: 0.0453 - val_accuracy: 0.9838 - val_f1_score: 0.9840 - lr: 3.1250e-05
# Epoch 101/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9747 - f1_score: 0.9752
# Epoch 101: val_f1_score did not improve from 0.98404
# 52/52 [==============================] - 487s 9s/step - loss: 0.0751 - accuracy: 0.9747 - f1_score: 0.9752 - val_loss: 0.0698 - val_accuracy: 0.9775 - val_f1_score: 0.9776 - lr: 3.1250e-05
# Epoch 102/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9759 - f1_score: 0.9764
# Epoch 102: val_f1_score did not improve from 0.98404
# 52/52 [==============================] - 516s 10s/step - loss: 0.0652 - accuracy: 0.9759 - f1_score: 0.9764 - val_loss: 0.0619 - val_accuracy: 0.9810 - val_f1_score: 0.9814 - lr: 3.1250e-05
# Epoch 103/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9750 - f1_score: 0.9754
# Epoch 103: val_f1_score improved from 0.98404 to 0.98484, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
#
# Epoch 103: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 52/52 [==============================] - 523s 10s/step - loss: 0.0668 - accuracy: 0.9750 - f1_score: 0.9754 - val_loss: 0.0503 - val_accuracy: 0.9845 - val_f1_score: 0.9848 - lr: 3.1250e-05
# Epoch 104/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9714 - f1_score: 0.9721
# Epoch 104: val_f1_score did not improve from 0.98484
# 52/52 [==============================] - 505s 10s/step - loss: 0.0733 - accuracy: 0.9714 - f1_score: 0.9721 - val_loss: 0.0599 - val_accuracy: 0.9803 - val_f1_score: 0.9805 - lr: 1.5625e-05
# Epoch 105/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9768 - f1_score: 0.9773
# Epoch 105: val_f1_score did not improve from 0.98484
# 52/52 [==============================] - 498s 10s/step - loss: 0.0643 - accuracy: 0.9768 - f1_score: 0.9773 - val_loss: 0.0584 - val_accuracy: 0.9768 - val_f1_score: 0.9771 - lr: 1.5625e-05
# Epoch 106/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9768 - f1_score: 0.9772
# Epoch 106: val_f1_score did not improve from 0.98484
# 52/52 [==============================] - 489s 9s/step - loss: 0.0603 - accuracy: 0.9768 - f1_score: 0.9772 - val_loss: 0.0567 - val_accuracy: 0.9768 - val_f1_score: 0.9771 - lr: 1.5625e-05
# Epoch 107/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9771 - f1_score: 0.9775
# Epoch 107: val_f1_score did not improve from 0.98484
#
# Epoch 107: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 52/52 [==============================] - 502s 10s/step - loss: 0.0663 - accuracy: 0.9771 - f1_score: 0.9775 - val_loss: 0.0543 - val_accuracy: 0.9789 - val_f1_score: 0.9792 - lr: 1.5625e-05
# Epoch 108/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9792 - f1_score: 0.9798
# Epoch 108: val_f1_score improved from 0.98484 to 0.98605, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 497s 10s/step - loss: 0.0567 - accuracy: 0.9792 - f1_score: 0.9798 - val_loss: 0.0447 - val_accuracy: 0.9859 - val_f1_score: 0.9861 - lr: 7.8125e-06
# Epoch 109/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9798 - f1_score: 0.9802
# Epoch 109: val_f1_score improved from 0.98605 to 0.98827, saving model to saved_outputs_basic_augment\original_vit\original_vit_saved_weights\best_original_vit_weights
# 52/52 [==============================] - 512s 10s/step - loss: 0.0592 - accuracy: 0.9798 - f1_score: 0.9802 - val_loss: 0.0431 - val_accuracy: 0.9880 - val_f1_score: 0.9883 - lr: 7.8125e-06
# Epoch 110/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9810 - f1_score: 0.9813
# Epoch 110: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 517s 10s/step - loss: 0.0555 - accuracy: 0.9810 - f1_score: 0.9813 - val_loss: 0.0550 - val_accuracy: 0.9845 - val_f1_score: 0.9846 - lr: 7.8125e-06
# Epoch 111/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9762 - f1_score: 0.9766
# Epoch 111: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 589s 11s/step - loss: 0.0619 - accuracy: 0.9762 - f1_score: 0.9766 - val_loss: 0.0547 - val_accuracy: 0.9761 - val_f1_score: 0.9766 - lr: 7.8125e-06
# Epoch 112/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9723 - f1_score: 0.9728
# Epoch 112: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 549s 11s/step - loss: 0.0749 - accuracy: 0.9723 - f1_score: 0.9728 - val_loss: 0.0392 - val_accuracy: 0.9873 - val_f1_score: 0.9876 - lr: 7.8125e-06
# Epoch 113/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9819 - f1_score: 0.9821
# Epoch 113: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 561s 11s/step - loss: 0.0525 - accuracy: 0.9819 - f1_score: 0.9821 - val_loss: 0.0571 - val_accuracy: 0.9817 - val_f1_score: 0.9818 - lr: 7.8125e-06
# Epoch 114/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9780 - f1_score: 0.9783
# Epoch 114: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 572s 11s/step - loss: 0.0651 - accuracy: 0.9780 - f1_score: 0.9783 - val_loss: 0.0490 - val_accuracy: 0.9810 - val_f1_score: 0.9812 - lr: 7.8125e-06
# Epoch 115/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9792 - f1_score: 0.9796
# Epoch 115: val_f1_score did not improve from 0.98827
#
# Epoch 115: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 52/52 [==============================] - 585s 11s/step - loss: 0.0581 - accuracy: 0.9792 - f1_score: 0.9796 - val_loss: 0.0467 - val_accuracy: 0.9824 - val_f1_score: 0.9828 - lr: 7.8125e-06
# Epoch 116/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9777 - f1_score: 0.9781
# Epoch 116: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 588s 11s/step - loss: 0.0613 - accuracy: 0.9777 - f1_score: 0.9781 - val_loss: 0.0530 - val_accuracy: 0.9845 - val_f1_score: 0.9848 - lr: 3.9063e-06
# Epoch 117/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9804 - f1_score: 0.9808
# Epoch 117: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 567s 11s/step - loss: 0.0562 - accuracy: 0.9804 - f1_score: 0.9808 - val_loss: 0.0662 - val_accuracy: 0.9747 - val_f1_score: 0.9750 - lr: 3.9063e-06
# Epoch 118/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9801 - f1_score: 0.9805
# Epoch 118: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 587s 11s/step - loss: 0.0550 - accuracy: 0.9801 - f1_score: 0.9805 - val_loss: 0.0390 - val_accuracy: 0.9824 - val_f1_score: 0.9823 - lr: 3.9063e-06
# Epoch 119/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9804 - f1_score: 0.9806
# Epoch 119: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 618s 12s/step - loss: 0.0652 - accuracy: 0.9804 - f1_score: 0.9806 - val_loss: 0.0473 - val_accuracy: 0.9838 - val_f1_score: 0.9840 - lr: 3.9063e-06
# Epoch 120/120
# 52/52 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9765 - f1_score: 0.9769
# Epoch 120: val_f1_score did not improve from 0.98827
# 52/52 [==============================] - 766s 15s/step - loss: 0.0562 - accuracy: 0.9765 - f1_score: 0.9769 - val_loss: 0.0521 - val_accuracy: 0.9817 - val_f1_score: 0.9822 - lr: 3.9063e-06

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %%
best_model = get_original_vit()

best_model.load_weights(PATH_BEST_WEIGHT_SAVE)

# %%
# Use the best model for Test results: loss, accuracy, f1_score
test_loss = show_save_test_results(test_generator, best_model)
# Out:
# 19/19 [==============================] - 127s 7s/step - loss: 0.0394 - accuracy: 0.9890 - f1_score: 0.9853
#      model_name  test_loss  test_accuracy  test_f1_score
# 0  original_vit   0.039388       0.989048       0.985292

# %%
# Get predictions from the model
predictions = best_model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

true_labels_y_test =  np.array(test_generator.classes) # y_test
############################################################################################################]
# Out:
# 19/19 [==============================] - 118s 6s/step

# %%
# # Classification report
store_classification_report(predicted_labels=predicted_labels, target_labels=true_labels_y_test)
# Out:
#               precision    recall  f1-score      support
# 0              0.991176  0.988270  0.989721   341.000000
# 1              0.977528  0.973881  0.975701   268.000000
# 2              0.987500  0.996845  0.992151   317.000000
# 3              1.000000  0.996169  0.998081   261.000000
# accuracy       0.989048  0.989048  0.989048     0.989048
# macro avg      0.989051  0.988791  0.988913  1187.000000
# weighted avg   0.989053  0.989048  0.989043  1187.000000

# %%
# For saving confusion matrix
show_save_confusion_matrix(predicted_labels=predicted_labels, target_labels=true_labels_y_test)

# %%
# # Calculate all
calculate_test_performance_metrics_all(predicted_labels=predicted_labels,
                                       target_labels=true_labels_y_test,
                                       test_loss=test_loss)
# Out:
#      Model Name  Accuracy  Macro Precision  Macro Recall  Macro F1-Score  \
# 0  original_vit  0.989048         0.989051      0.988791        0.988913
#
#    Weighted Precision  Weighted Recall  Weighted F1-Score      Loss
# 0            0.989053         0.989048           0.989043  0.039388

# %%
data = calculate_TF_TP_FP_FN(true_labels_y_test, predicted_labels)
acc = calculate_accuracy(true_labels_y_test, predicted_labels)
calculate_metrics(class_to_performance_data=data, accuracy=acc)
# Out:
#            Metric Type    Value
# 0     overall accuracy  0.98905
# 1      Macro Precision  0.98905
# 2         Macro Recall  0.98879
# 3       Macro F1-Score  0.98891
# 4            Macro FPR  0.00367
# 5            Macro FNR  0.01121
# 6            Macro FDR  0.01095
# 7            Macro NPV  0.99636
# 8   Weighted Precision  0.98905
# 9      Weighted Recall  0.98905
# 10   Weighted F1-Score  0.98904
# 11        Weighted FPR  0.00372
# 12        Weighted FNR  0.01095
# 13        Weighted FDR  0.01095
# 14        Weighted NPV  0.99638
