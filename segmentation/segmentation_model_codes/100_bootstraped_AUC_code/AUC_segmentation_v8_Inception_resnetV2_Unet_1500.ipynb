# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip uninstall -y numpy pandas
# !pip install numpy==1.26.4 pandas==2.2.2

# imgaug (compatible with older NumPy)
# !pip install -q imgaug==0.4.0

# Downgrade NumPy to avoid issues with imgaug (NumPy ≥ 2.0 breaks imgaug)
# !pip install -q numpy==1.26.4

# !pip install tensorflow==2.15.0
# Out:
# Requirement already satisfied: tensorflow==2.15.0 in /usr/local/lib/python3.11/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (1.72.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# from keras import ops# For deeplab3

# import keras_cv # basnet

from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Inception_resnetV2_Unet_1500' #Basic_Unet'#'Vgg16_unet'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation_AUC', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 52

TOTAL_DATA = 1500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 5
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)

# Expand mask dimensions to (batch, 256, 256, 1)
y_train = np.expand_dims(y_train, axis=-1)
y_test = np.expand_dims(y_test, axis=-1)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 1500 original images into x_train
# Loaded 1500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time, model

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### InceptionResNetV2---Works--checked with batch size10

# %%
from tensorflow.keras.applications import  InceptionResNetV2
# def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
#     """Function to add 2 convolutional layers with the parameters passed to it"""
#     # first layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)

#     # second layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(x)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)

#     return x

# def get_unet_InceptionResNetV2(n_filters=16, batchnorm=True, dropout=0.1):
#     InceptionResNetV2_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=MODEL_INPUT_SIZE)

#     # Encoder
#     encoder = InceptionResNetV2_base.get_layer('activation_89').output

#     # Bottleneck
#     bottleneck = Conv2D(512, (3, 3), activation='relu', padding='same')(encoder)

#     # Resizing for skip connections
#     resized_skip1 = tf.image.resize(InceptionResNetV2_base.get_layer('activation_89').output, [28, 28])
#     resized_skip2 = tf.image.resize(InceptionResNetV2_base.get_layer('max_pooling2d').output, [56, 56])
#     resized_skip3 = tf.image.resize(InceptionResNetV2_base.get_layer('conv2d_1').output, [112, 112])

#     # Decoder
#     u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(bottleneck)
#     u6 = Concatenate(axis=-1)([u6, resized_skip1])
#     u6 = Dropout(dropout)(u6)
#     c6 = conv2d_block(u6, n_filters * 8, kernel_size=3, batchnorm=batchnorm)

#     u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
#     u7 = Concatenate(axis=-1)([u7, resized_skip2])
#     u7 = Dropout(dropout)(u7)
#     c7 = conv2d_block(u7, n_filters * 4, kernel_size=3, batchnorm=batchnorm)

#     u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)

#     u8 = Dropout(dropout)(u8)
#     c8 = conv2d_block(u8, n_filters * 2, kernel_size=3, batchnorm=batchnorm)

#     # Final upsampling to match the original input size
#     u9 = Conv2DTranspose(n_filters, (3, 3), strides=(2, 2), padding='same')(c8)
#     u9 = Dropout(dropout)(u9)
#     c9 = conv2d_block(u9, n_filters, kernel_size=3, batchnorm=batchnorm)

#     # Additional resizing layer to ensure output is 256x256
#     final_output = Resizing(256, 256, interpolation='bilinear')(c9)

#     outputs = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(final_output)
#     model = Model(inputs=InceptionResNetV2_base.input, outputs=[outputs])
#     optimizer = Adam(learning_rate=INITIAL_LR)
#     model.compile(loss='binary_crossentropy',
#                   metrics=['accuracy', f1_score, iou_score_binary],
#                   optimizer=optimizer)

#     return model

# def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
#     """Function to add 2 convolutional layers with the parameters passed to it"""
#     # first layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)

#     # second layer
#     x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
#               kernel_initializer = 'he_normal', padding = 'same')(x)
#     if batchnorm:
#         x = BatchNormalization()(x)
#     x = Activation('relu')(x)

#     return x

# def get_unet_InceptionResNetV2(n_filters=16, batchnorm=True, dropout=0.1):
#     InceptionResNetV2_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=MODEL_INPUT_SIZE)

#     # Encoder
#     encoder = InceptionResNetV2_base.get_layer('activation_89').output

#     # Bottleneck
#     bottleneck = Conv2D(512, (3, 3), activation='relu', padding='same')(encoder)

#     # Resizing for skip connections using Keras Resizing layer
#     # Use a Resizing layer for each skip connection to correctly handle KerasTensors
#     resized_skip1 = Resizing(28, 28, interpolation='bilinear')(InceptionResNetV2_base.get_layer('activation_89').output)
#     resized_skip2 = Resizing(56, 56, interpolation='bilinear')(InceptionResNetV2_base.get_layer('max_pooling2d').output)
#     resized_skip3 = Resizing(112, 112, interpolation='bilinear')(InceptionResNetV2_base.get_layer('conv2d_1').output)


#     # Decoder
#     u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(bottleneck)
#     # Check the shape of u6 before concatenating to ensure it matches the resized_skip1 shape
#     # print(f"Shape of u6 before concatenation with resized_skip1: {u6.shape}")
#     # print(f"Shape of resized_skip1: {resized_skip1.shape}")
#     u6 = Concatenate(axis=-1)([u6, resized_skip1])
#     u6 = Dropout(dropout)(u6)
#     c6 = conv2d_block(u6, n_filters * 8, kernel_size=3, batchnorm=batchnorm)

#     u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
#     # Check the shape of u7 before concatenating to ensure it matches the resized_skip2 shape
#     # print(f"Shape of u7 before concatenation with resized_skip2: {u7.shape}")
#     # print(f"Shape of resized_skip2: {resized_skip2.shape}")
#     u7 = Concatenate(axis=-1)([u7, resized_skip2])
#     u7 = Dropout(dropout)(u7)
#     c7 = conv2d_block(u7, n_filters * 4, kernel_size=3, batchnorm=batchnorm)

#     u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
#     # There is no concatenation with resized_skip3 here. If resized_skip3 was intended for u8,
#     # you would concatenate it here. Based on the original code structure, it seems
#     # resized_skip3 might have been a leftover or intended for a different part of the decoder.
#     # If you intended to use it, uncomment and adapt the following line:
#     # u8 = Concatenate(axis=-1)([u8, resized_skip3])

#     u8 = Dropout(dropout)(u8)
#     c8 = conv2d_block(u8, n_filters * 2, kernel_size=3, batchnorm=batchnorm)

#     # Final upsampling to match the original input size
#     u9 = Conv2DTranspose(n_filters, (3, 3), strides=(2, 2), padding='same')(c8)
#     u9 = Dropout(dropout)(u9)
#     c9 = conv2d_block(u9, n_filters, kernel_size=3, batchnorm=batchnorm)

#     # Additional resizing layer to ensure output is 256x256
#     # This resizing layer seems redundant if the upsampling layers are already
#     # designed to reach the target size. Double check the expected output size after u9/c9.
#     # If the previous layers correctly bring the size to 256x256, you can remove this layer.
#     # If not, keep it to ensure the final output shape.
#     final_output = Resizing(256, 256, interpolation='bilinear')(c9)

#     outputs = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(final_output)
#     model = Model(inputs=InceptionResNetV2_base.input, outputs=[outputs])
#     optimizer = Adam(learning_rate=INITIAL_LR)
#     model.compile(loss='binary_crossentropy',
#                   metrics=['accuracy', f1_score, iou_score_binary],
#                   optimizer=optimizer)

#     return model

# Conv block function
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size),
               kernel_initializer='he_normal', padding='same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size),
               kernel_initializer='he_normal', padding='same')(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

# Model function
def get_unet_InceptionResNetV2(n_filters=16, batchnorm=True, dropout=0.1):
    InceptionResNetV2_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=MODEL_INPUT_SIZE)

    # Encoder
    encoder = InceptionResNetV2_base.get_layer('activation_89').output

    # Bottleneck
    bottleneck = Conv2D(512, (3, 3), activation='relu', padding='same')(encoder)

    # Resizing skip connections with Lambda
    resized_skip1 = Lambda(lambda x: tf.image.resize(x, [28, 28]))(
        InceptionResNetV2_base.get_layer('activation_89').output)
    resized_skip2 = Lambda(lambda x: tf.image.resize(x, [56, 56]))(
        InceptionResNetV2_base.get_layer('max_pooling2d').output)
    resized_skip3 = Lambda(lambda x: tf.image.resize(x, [112, 112]))(
        InceptionResNetV2_base.get_layer('conv2d_1').output)

    # Decoder
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(bottleneck)
    u6 = Concatenate(axis=-1)([u6, resized_skip1])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = Concatenate(axis=-1)([u7, resized_skip2])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters, kernel_size=3, batchnorm=batchnorm)

    # Resize to match final output size
    final_output = Resizing(256, 256, interpolation='bilinear')(c9)

    outputs = Conv2D(NUM_CLASSES - 1, (1, 1), activation='sigmoid')(final_output)

    model = Model(inputs=InceptionResNetV2_base.input, outputs=[outputs])
    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 127, 127, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 127, 127, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 127, 127, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 125, 125, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 125, 125, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 125, 125, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 125, 125, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 125, 125, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 62, 62, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 62, 62, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 62, 62, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 62, 62, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 60, 60, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 60, 60, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 29, 29, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 29, 29, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 29, 29, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 29, 29, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 29, 29, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 29, 29, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 29, 29, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 29, 29, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 29, 29, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 29, 29, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 29, 29, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 29, 29, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 29, 29, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 29, 29, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 29, 29, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 29, 29, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 29, 29, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 29, 29, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 29, 29, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 29, 29, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 29, 29, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 29, 29, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 29, 29, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 29, 29, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 29, 29, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 29, 29, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 29, 29, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 29, 29, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 29, 29, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 29, 29, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 29, 29, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 29, 29, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 29, 29, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 29, 29, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 29, 29, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 29, 29, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 29, 29, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 29, 29, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 29, 29, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 29, 29, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 29, 29, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 29, 29, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 29, 29, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 29, 29, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 29, 29, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 29, 29, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 29, 29, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 29, 29, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 29, 29, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 29, 29, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 29, 29, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 29, 29, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 29, 29, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 29, 29, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 29, 29, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 29, 29, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 29, 29, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 29, 29, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 29, 29, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 29, 29, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 29, 29, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 29, 29, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 29, 29, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 29, 29, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 29, 29, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 29, 29, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 29, 29, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 29, 29, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 29, 29, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 29, 29, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
# ...
#
#  custom_scale_layer_11 (Cus  (None, 14, 14, 1088)         0         ['block17_1_ac[0][0]',
#  tomScaleLayer)                                                      'block17_2_conv[0][0]']
#
#  block17_2_ac (Activation)   (None, 14, 14, 1088)         0         ['custom_scale_layer_11[0][0]'
#                                                                     ]
#
#  conv2d_85 (Conv2D)          (None, 14, 14, 128)          139264    ['block17_2_ac[0][0]']
#
#  batch_normalization_85 (Ba  (None, 14, 14, 128)          384       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 14, 14, 160)          143360    ['activation_85[0][0]']
#
#  batch_normalization_86 (Ba  (None, 14, 14, 160)          480       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 14, 14, 160)          0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 14, 14, 192)          208896    ['block17_2_ac[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 14, 14, 192)          215040    ['activation_86[0][0]']
#
#  batch_normalization_84 (Ba  (None, 14, 14, 192)          576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  batch_normalization_87 (Ba  (None, 14, 14, 192)          576       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 14, 14, 192)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  activation_87 (Activation)  (None, 14, 14, 192)          0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  block17_3_mixed (Concatena  (None, 14, 14, 384)          0         ['activation_84[0][0]',
#  te)                                                                 'activation_87[0][0]']
#
#  block17_3_conv (Conv2D)     (None, 14, 14, 1088)         418880    ['block17_3_mixed[0][0]']
#
#  custom_scale_layer_12 (Cus  (None, 14, 14, 1088)         0         ['block17_2_ac[0][0]',
#  tomScaleLayer)                                                      'block17_3_conv[0][0]']
#
#  block17_3_ac (Activation)   (None, 14, 14, 1088)         0         ['custom_scale_layer_12[0][0]'
#                                                                     ]
#
#  conv2d_89 (Conv2D)          (None, 14, 14, 128)          139264    ['block17_3_ac[0][0]']
#
#  batch_normalization_89 (Ba  (None, 14, 14, 128)          384       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_203 (Conv2D)         (None, 14, 14, 512)          590336    ['activation_89[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 28, 28, 128)          589952    ['conv2d_203[0][0]']
#  anspose)
#
#  lambda (Lambda)             (None, 28, 28, 128)          0         ['activation_89[0][0]']
#
#  concatenate (Concatenate)   (None, 28, 28, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'lambda[0][0]']
#
#  dropout (Dropout)           (None, 28, 28, 256)          0         ['concatenate[0][0]']
#
#  conv2d_204 (Conv2D)         (None, 28, 28, 128)          295040    ['dropout[0][0]']
#
#  batch_normalization_203 (B  (None, 28, 28, 128)          512       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_205 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_203[0][0]']
#
#  batch_normalization_204 (B  (None, 28, 28, 128)          512       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  activation_204 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  conv2d_transpose_1 (Conv2D  (None, 56, 56, 64)           73792     ['activation_204[0][0]']
#  Transpose)
#
#  lambda_1 (Lambda)           (None, 56, 56, 64)           0         ['max_pooling2d[0][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'lambda_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 56, 56, 128)          0         ['concatenate_1[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 56, 56, 64)           73792     ['dropout_1[0][0]']
#
#  batch_normalization_205 (B  (None, 56, 56, 64)           256       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_205 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  conv2d_207 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_205[0][0]']
#
#  batch_normalization_206 (B  (None, 56, 56, 64)           256       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  activation_206 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  conv2d_transpose_2 (Conv2D  (None, 112, 112, 32)         18464     ['activation_206[0][0]']
#  Transpose)
#
#  dropout_2 (Dropout)         (None, 112, 112, 32)         0         ['conv2d_transpose_2[0][0]']
#
#  conv2d_208 (Conv2D)         (None, 112, 112, 32)         9248      ['dropout_2[0][0]']
#
#  batch_normalization_207 (B  (None, 112, 112, 32)         128       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 112, 112, 32)         0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  conv2d_209 (Conv2D)         (None, 112, 112, 32)         9248      ['activation_207[0][0]']
#
#  batch_normalization_208 (B  (None, 112, 112, 32)         128       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (None, 112, 112, 32)         0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  conv2d_transpose_3 (Conv2D  (None, 224, 224, 16)         4624      ['activation_208[0][0]']
#  Transpose)
#
#  dropout_3 (Dropout)         (None, 224, 224, 16)         0         ['conv2d_transpose_3[0][0]']
#
#  conv2d_210 (Conv2D)         (None, 224, 224, 16)         2320      ['dropout_3[0][0]']
#
#  batch_normalization_209 (B  (None, 224, 224, 16)         64        ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_209 (Activation  (None, 224, 224, 16)         0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  conv2d_211 (Conv2D)         (None, 224, 224, 16)         2320      ['activation_209[0][0]']
#
#  batch_normalization_210 (B  (None, 224, 224, 16)         64        ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 224, 224, 16)         0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  resizing (Resizing)         (None, 256, 256, 16)         0         ['activation_210[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 256, 256, 1)          17        ['resizing[0][0]']
#
# ==================================================================================================
# Total params: 9719841 (37.08 MB)
# Trainable params: 9705377 (37.02 MB)
# Non-trainable params: 14464 (56.50 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time, best_model = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/52
# 120/120 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9682 - f1_score: 0.6220 - binary_io_u: 0.7028
# Epoch 1: val_binary_io_u improved from -inf to 0.59316, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 139s 970ms/step - loss: 0.2231 - accuracy: 0.9682 - f1_score: 0.6220 - binary_io_u: 0.7028 - val_loss: 0.1469 - val_accuracy: 0.9726 - val_f1_score: 0.2813 - val_binary_io_u: 0.5932 - lr: 0.0010
# Epoch 2/52
# 120/120 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9779 - f1_score: 0.6924 - binary_io_u: 0.7595
# Epoch 2: val_binary_io_u improved from 0.59316 to 0.72341, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 111s 922ms/step - loss: 0.1107 - accuracy: 0.9779 - f1_score: 0.6924 - binary_io_u: 0.7595 - val_loss: 0.0782 - val_accuracy: 0.9799 - val_f1_score: 0.5708 - val_binary_io_u: 0.7234 - lr: 0.0010
# Epoch 3/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9796 - f1_score: 0.7171 - binary_io_u: 0.7770
# Epoch 3: val_binary_io_u improved from 0.72341 to 0.72585, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 111s 926ms/step - loss: 0.0790 - accuracy: 0.9796 - f1_score: 0.7171 - binary_io_u: 0.7770 - val_loss: 0.0640 - val_accuracy: 0.9807 - val_f1_score: 0.5622 - val_binary_io_u: 0.7259 - lr: 0.0010
# Epoch 4/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9802 - f1_score: 0.7270 - binary_io_u: 0.7834
# Epoch 4: val_binary_io_u did not improve from 0.72585
# 120/120 [==============================] - 108s 902ms/step - loss: 0.0672 - accuracy: 0.9802 - f1_score: 0.7270 - binary_io_u: 0.7834 - val_loss: 0.0651 - val_accuracy: 0.9785 - val_f1_score: 0.4861 - val_binary_io_u: 0.6855 - lr: 0.0010
# Epoch 5/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9815 - f1_score: 0.7456 - binary_io_u: 0.7961
# Epoch 5: val_binary_io_u improved from 0.72585 to 0.75406, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 921ms/step - loss: 0.0592 - accuracy: 0.9815 - f1_score: 0.7456 - binary_io_u: 0.7961 - val_loss: 0.0662 - val_accuracy: 0.9781 - val_f1_score: 0.6421 - val_binary_io_u: 0.7541 - lr: 0.0010
# Epoch 6/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9818 - f1_score: 0.7534 - binary_io_u: 0.8003
# Epoch 6: val_binary_io_u did not improve from 0.75406
# 120/120 [==============================] - 108s 903ms/step - loss: 0.0557 - accuracy: 0.9818 - f1_score: 0.7534 - binary_io_u: 0.8003 - val_loss: 0.0536 - val_accuracy: 0.9822 - val_f1_score: 0.6188 - val_binary_io_u: 0.7506 - lr: 0.0010
# Epoch 7/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9827 - f1_score: 0.7612 - binary_io_u: 0.8087
# Epoch 7: val_binary_io_u did not improve from 0.75406
# 120/120 [==============================] - 109s 907ms/step - loss: 0.0522 - accuracy: 0.9827 - f1_score: 0.7612 - binary_io_u: 0.8087 - val_loss: 0.0546 - val_accuracy: 0.9817 - val_f1_score: 0.5759 - val_binary_io_u: 0.7323 - lr: 0.0010
# Epoch 8/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9828 - f1_score: 0.7697 - binary_io_u: 0.8095
# Epoch 8: val_binary_io_u improved from 0.75406 to 0.77201, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 919ms/step - loss: 0.0509 - accuracy: 0.9828 - f1_score: 0.7697 - binary_io_u: 0.8095 - val_loss: 0.0492 - val_accuracy: 0.9832 - val_f1_score: 0.6512 - val_binary_io_u: 0.7720 - lr: 0.0010
# Epoch 9/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9842 - f1_score: 0.7861 - binary_io_u: 0.8237
# Epoch 9: val_binary_io_u improved from 0.77201 to 0.77942, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 111s 926ms/step - loss: 0.0462 - accuracy: 0.9842 - f1_score: 0.7861 - binary_io_u: 0.8237 - val_loss: 0.0466 - val_accuracy: 0.9843 - val_f1_score: 0.6666 - val_binary_io_u: 0.7794 - lr: 0.0010
# Epoch 10/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9845 - f1_score: 0.7917 - binary_io_u: 0.8267
# Epoch 10: val_binary_io_u did not improve from 0.77942
# 120/120 [==============================] - 108s 903ms/step - loss: 0.0448 - accuracy: 0.9845 - f1_score: 0.7917 - binary_io_u: 0.8267 - val_loss: 0.0477 - val_accuracy: 0.9841 - val_f1_score: 0.6447 - val_binary_io_u: 0.7718 - lr: 0.0010
# Epoch 11/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9851 - f1_score: 0.7990 - binary_io_u: 0.8339
# Epoch 11: val_binary_io_u improved from 0.77942 to 0.79607, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 920ms/step - loss: 0.0425 - accuracy: 0.9851 - f1_score: 0.7990 - binary_io_u: 0.8339 - val_loss: 0.0430 - val_accuracy: 0.9852 - val_f1_score: 0.7020 - val_binary_io_u: 0.7961 - lr: 0.0010
# Epoch 12/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9853 - f1_score: 0.7987 - binary_io_u: 0.8360
# Epoch 12: val_binary_io_u did not improve from 0.79607
# 120/120 [==============================] - 108s 902ms/step - loss: 0.0413 - accuracy: 0.9853 - f1_score: 0.7987 - binary_io_u: 0.8360 - val_loss: 0.0429 - val_accuracy: 0.9851 - val_f1_score: 0.6906 - val_binary_io_u: 0.7912 - lr: 0.0010
# Epoch 13/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9857 - f1_score: 0.8045 - binary_io_u: 0.8397
# Epoch 13: val_binary_io_u improved from 0.79607 to 0.80684, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 918ms/step - loss: 0.0400 - accuracy: 0.9857 - f1_score: 0.8045 - binary_io_u: 0.8397 - val_loss: 0.0405 - val_accuracy: 0.9859 - val_f1_score: 0.7177 - val_binary_io_u: 0.8068 - lr: 0.0010
# Epoch 14/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9861 - f1_score: 0.8157 - binary_io_u: 0.8443
# Epoch 14: val_binary_io_u improved from 0.80684 to 0.81440, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 921ms/step - loss: 0.0381 - accuracy: 0.9861 - f1_score: 0.8157 - binary_io_u: 0.8443 - val_loss: 0.0407 - val_accuracy: 0.9858 - val_f1_score: 0.7302 - val_binary_io_u: 0.8144 - lr: 0.0010
# Epoch 15/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9867 - f1_score: 0.8208 - binary_io_u: 0.8504
# Epoch 15: val_binary_io_u did not improve from 0.81440
# 120/120 [==============================] - 108s 902ms/step - loss: 0.0362 - accuracy: 0.9867 - f1_score: 0.8208 - binary_io_u: 0.8504 - val_loss: 0.0392 - val_accuracy: 0.9862 - val_f1_score: 0.7195 - val_binary_io_u: 0.8083 - lr: 0.0010
# Epoch 16/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9872 - f1_score: 0.8300 - binary_io_u: 0.8562
# Epoch 16: val_binary_io_u improved from 0.81440 to 0.81930, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 921ms/step - loss: 0.0342 - accuracy: 0.9872 - f1_score: 0.8300 - binary_io_u: 0.8562 - val_loss: 0.0379 - val_accuracy: 0.9866 - val_f1_score: 0.7420 - val_binary_io_u: 0.8193 - lr: 0.0010
# Epoch 17/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9875 - f1_score: 0.8317 - binary_io_u: 0.8589
# Epoch 17: val_binary_io_u did not improve from 0.81930
# 120/120 [==============================] - 108s 902ms/step - loss: 0.0333 - accuracy: 0.9875 - f1_score: 0.8317 - binary_io_u: 0.8589 - val_loss: 0.0388 - val_accuracy: 0.9867 - val_f1_score: 0.7266 - val_binary_io_u: 0.8146 - lr: 0.0010
# Epoch 18/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9876 - f1_score: 0.8341 - binary_io_u: 0.8600
# Epoch 18: val_binary_io_u did not improve from 0.81930
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0330 - accuracy: 0.9876 - f1_score: 0.8341 - binary_io_u: 0.8600 - val_loss: 0.0388 - val_accuracy: 0.9857 - val_f1_score: 0.7395 - val_binary_io_u: 0.8178 - lr: 0.0010
# Epoch 19/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9881 - f1_score: 0.8440 - binary_io_u: 0.8654
# Epoch 19: val_binary_io_u improved from 0.81930 to 0.82240, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 916ms/step - loss: 0.0314 - accuracy: 0.9881 - f1_score: 0.8440 - binary_io_u: 0.8654 - val_loss: 0.0392 - val_accuracy: 0.9867 - val_f1_score: 0.7411 - val_binary_io_u: 0.8224 - lr: 0.0010
# Epoch 20/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9880 - f1_score: 0.8407 - binary_io_u: 0.8650
# Epoch 20: val_binary_io_u improved from 0.82240 to 0.82595, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 920ms/step - loss: 0.0313 - accuracy: 0.9880 - f1_score: 0.8407 - binary_io_u: 0.8650 - val_loss: 0.0380 - val_accuracy: 0.9869 - val_f1_score: 0.7535 - val_binary_io_u: 0.8259 - lr: 0.0010
# Epoch 21/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9885 - f1_score: 0.8485 - binary_io_u: 0.8704
# Epoch 21: val_binary_io_u did not improve from 0.82595
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 120/120 [==============================] - 108s 901ms/step - loss: 0.0298 - accuracy: 0.9885 - f1_score: 0.8485 - binary_io_u: 0.8704 - val_loss: 0.0396 - val_accuracy: 0.9865 - val_f1_score: 0.7118 - val_binary_io_u: 0.8088 - lr: 0.0010
# Epoch 22/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9894 - f1_score: 0.8612 - binary_io_u: 0.8797
# Epoch 22: val_binary_io_u did not improve from 0.82595
# 120/120 [==============================] - 107s 890ms/step - loss: 0.0273 - accuracy: 0.9894 - f1_score: 0.8612 - binary_io_u: 0.8797 - val_loss: 0.0366 - val_accuracy: 0.9875 - val_f1_score: 0.7477 - val_binary_io_u: 0.8257 - lr: 5.0000e-04
# Epoch 23/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9900 - f1_score: 0.8668 - binary_io_u: 0.8862
# Epoch 23: val_binary_io_u improved from 0.82595 to 0.82808, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 916ms/step - loss: 0.0258 - accuracy: 0.9900 - f1_score: 0.8668 - binary_io_u: 0.8862 - val_loss: 0.0356 - val_accuracy: 0.9875 - val_f1_score: 0.7524 - val_binary_io_u: 0.8281 - lr: 5.0000e-04
# Epoch 24/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9902 - f1_score: 0.8742 - binary_io_u: 0.8890
# Epoch 24: val_binary_io_u improved from 0.82808 to 0.83275, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 915ms/step - loss: 0.0249 - accuracy: 0.9902 - f1_score: 0.8742 - binary_io_u: 0.8890 - val_loss: 0.0357 - val_accuracy: 0.9876 - val_f1_score: 0.7642 - val_binary_io_u: 0.8327 - lr: 5.0000e-04
# Epoch 25/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9904 - f1_score: 0.8755 - binary_io_u: 0.8906
# Epoch 25: val_binary_io_u did not improve from 0.83275
# 120/120 [==============================] - 107s 895ms/step - loss: 0.0244 - accuracy: 0.9904 - f1_score: 0.8755 - binary_io_u: 0.8906 - val_loss: 0.0364 - val_accuracy: 0.9875 - val_f1_score: 0.7637 - val_binary_io_u: 0.8327 - lr: 5.0000e-04
# Epoch 26/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9906 - f1_score: 0.8752 - binary_io_u: 0.8926
# Epoch 26: val_binary_io_u improved from 0.83275 to 0.83472, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 110s 916ms/step - loss: 0.0239 - accuracy: 0.9906 - f1_score: 0.8752 - binary_io_u: 0.8926 - val_loss: 0.0368 - val_accuracy: 0.9875 - val_f1_score: 0.7668 - val_binary_io_u: 0.8347 - lr: 5.0000e-04
# Epoch 27/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9907 - f1_score: 0.8768 - binary_io_u: 0.8939
# Epoch 27: val_binary_io_u did not improve from 0.83472
# 120/120 [==============================] - 107s 895ms/step - loss: 0.0234 - accuracy: 0.9907 - f1_score: 0.8768 - binary_io_u: 0.8939 - val_loss: 0.0371 - val_accuracy: 0.9877 - val_f1_score: 0.7625 - val_binary_io_u: 0.8326 - lr: 5.0000e-04
# Epoch 28/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9907 - f1_score: 0.8800 - binary_io_u: 0.8944
# Epoch 28: val_binary_io_u did not improve from 0.83472
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 120/120 [==============================] - 107s 893ms/step - loss: 0.0232 - accuracy: 0.9907 - f1_score: 0.8800 - binary_io_u: 0.8944 - val_loss: 0.0379 - val_accuracy: 0.9874 - val_f1_score: 0.7578 - val_binary_io_u: 0.8306 - lr: 5.0000e-04
# Epoch 29/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9910 - f1_score: 0.8825 - binary_io_u: 0.8976
# Epoch 29: val_binary_io_u improved from 0.83472 to 0.83784, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation_AUC/Inception_resnetV2_Unet_1500/saved_models/best_Inception_resnetV2_Unet_1500.h5
# 120/120 [==============================] - 111s 922ms/step - loss: 0.0225 - accuracy: 0.9910 - f1_score: 0.8825 - binary_io_u: 0.8976 - val_loss: 0.0366 - val_accuracy: 0.9878 - val_f1_score: 0.7717 - val_binary_io_u: 0.8378 - lr: 2.5000e-04
# Epoch 30/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9914 - f1_score: 0.8906 - binary_io_u: 0.9020
# Epoch 30: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 108s 900ms/step - loss: 0.0214 - accuracy: 0.9914 - f1_score: 0.8906 - binary_io_u: 0.9020 - val_loss: 0.0369 - val_accuracy: 0.9879 - val_f1_score: 0.7679 - val_binary_io_u: 0.8356 - lr: 2.5000e-04
# Epoch 31/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9915 - f1_score: 0.8893 - binary_io_u: 0.9031
# Epoch 31: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0211 - accuracy: 0.9915 - f1_score: 0.8893 - binary_io_u: 0.9031 - val_loss: 0.0368 - val_accuracy: 0.9879 - val_f1_score: 0.7693 - val_binary_io_u: 0.8370 - lr: 2.5000e-04
# Epoch 32/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9917 - f1_score: 0.8922 - binary_io_u: 0.9052
# Epoch 32: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0206 - accuracy: 0.9917 - f1_score: 0.8922 - binary_io_u: 0.9052 - val_loss: 0.0363 - val_accuracy: 0.9878 - val_f1_score: 0.7650 - val_binary_io_u: 0.8345 - lr: 2.5000e-04
# Epoch 33/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9918 - f1_score: 0.8928 - binary_io_u: 0.9057
# Epoch 33: val_binary_io_u did not improve from 0.83784
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 120/120 [==============================] - 106s 887ms/step - loss: 0.0204 - accuracy: 0.9918 - f1_score: 0.8928 - binary_io_u: 0.9057 - val_loss: 0.0366 - val_accuracy: 0.9878 - val_f1_score: 0.7638 - val_binary_io_u: 0.8320 - lr: 2.5000e-04
# Epoch 34/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8958 - binary_io_u: 0.9080
# Epoch 34: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 891ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8958 - binary_io_u: 0.9080 - val_loss: 0.0372 - val_accuracy: 0.9879 - val_f1_score: 0.7655 - val_binary_io_u: 0.8340 - lr: 1.2500e-04
# Epoch 35/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9921 - f1_score: 0.8982 - binary_io_u: 0.9097
# Epoch 35: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0196 - accuracy: 0.9921 - f1_score: 0.8982 - binary_io_u: 0.9097 - val_loss: 0.0378 - val_accuracy: 0.9878 - val_f1_score: 0.7667 - val_binary_io_u: 0.8344 - lr: 1.2500e-04
# Epoch 36/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9922 - f1_score: 0.8996 - binary_io_u: 0.9105
# Epoch 36: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0193 - accuracy: 0.9922 - f1_score: 0.8996 - binary_io_u: 0.9105 - val_loss: 0.0371 - val_accuracy: 0.9879 - val_f1_score: 0.7671 - val_binary_io_u: 0.8353 - lr: 1.2500e-04
# Epoch 37/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9923 - f1_score: 0.8991 - binary_io_u: 0.9115
# Epoch 37: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 891ms/step - loss: 0.0191 - accuracy: 0.9923 - f1_score: 0.8991 - binary_io_u: 0.9115 - val_loss: 0.0377 - val_accuracy: 0.9879 - val_f1_score: 0.7662 - val_binary_io_u: 0.8351 - lr: 1.2500e-04
# Epoch 38/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9924 - f1_score: 0.9018 - binary_io_u: 0.9121
# Epoch 38: val_binary_io_u did not improve from 0.83784
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 120/120 [==============================] - 107s 889ms/step - loss: 0.0189 - accuracy: 0.9924 - f1_score: 0.9018 - binary_io_u: 0.9121 - val_loss: 0.0377 - val_accuracy: 0.9877 - val_f1_score: 0.7699 - val_binary_io_u: 0.8358 - lr: 1.2500e-04
# Epoch 39/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9925 - f1_score: 0.9013 - binary_io_u: 0.9132
# Epoch 39: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 895ms/step - loss: 0.0187 - accuracy: 0.9925 - f1_score: 0.9013 - binary_io_u: 0.9132 - val_loss: 0.0376 - val_accuracy: 0.9878 - val_f1_score: 0.7691 - val_binary_io_u: 0.8355 - lr: 6.2500e-05
# Epoch 40/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9925 - f1_score: 0.9036 - binary_io_u: 0.9138
# Epoch 40: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 108s 897ms/step - loss: 0.0185 - accuracy: 0.9925 - f1_score: 0.9036 - binary_io_u: 0.9138 - val_loss: 0.0379 - val_accuracy: 0.9878 - val_f1_score: 0.7700 - val_binary_io_u: 0.8355 - lr: 6.2500e-05
# Epoch 41/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9926 - f1_score: 0.9043 - binary_io_u: 0.9146
# Epoch 41: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 895ms/step - loss: 0.0184 - accuracy: 0.9926 - f1_score: 0.9043 - binary_io_u: 0.9146 - val_loss: 0.0380 - val_accuracy: 0.9878 - val_f1_score: 0.7682 - val_binary_io_u: 0.8348 - lr: 6.2500e-05
# Epoch 42/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9926 - f1_score: 0.9032 - binary_io_u: 0.9146
# Epoch 42: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0184 - accuracy: 0.9926 - f1_score: 0.9032 - binary_io_u: 0.9146 - val_loss: 0.0380 - val_accuracy: 0.9877 - val_f1_score: 0.7684 - val_binary_io_u: 0.8349 - lr: 6.2500e-05
# Epoch 43/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9926 - f1_score: 0.9059 - binary_io_u: 0.9149
# Epoch 43: val_binary_io_u did not improve from 0.83784
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 120/120 [==============================] - 107s 890ms/step - loss: 0.0183 - accuracy: 0.9926 - f1_score: 0.9059 - binary_io_u: 0.9149 - val_loss: 0.0381 - val_accuracy: 0.9877 - val_f1_score: 0.7699 - val_binary_io_u: 0.8358 - lr: 6.2500e-05
# Epoch 44/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9927 - f1_score: 0.9037 - binary_io_u: 0.9154
# Epoch 44: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 893ms/step - loss: 0.0182 - accuracy: 0.9927 - f1_score: 0.9037 - binary_io_u: 0.9154 - val_loss: 0.0383 - val_accuracy: 0.9877 - val_f1_score: 0.7679 - val_binary_io_u: 0.8347 - lr: 3.1250e-05
# Epoch 45/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9927 - f1_score: 0.9072 - binary_io_u: 0.9163
# Epoch 45: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 108s 897ms/step - loss: 0.0180 - accuracy: 0.9927 - f1_score: 0.9072 - binary_io_u: 0.9163 - val_loss: 0.0383 - val_accuracy: 0.9877 - val_f1_score: 0.7686 - val_binary_io_u: 0.8346 - lr: 3.1250e-05
# Epoch 46/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9927 - f1_score: 0.9055 - binary_io_u: 0.9159
# Epoch 46: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 108s 897ms/step - loss: 0.0181 - accuracy: 0.9927 - f1_score: 0.9055 - binary_io_u: 0.9159 - val_loss: 0.0382 - val_accuracy: 0.9877 - val_f1_score: 0.7684 - val_binary_io_u: 0.8348 - lr: 3.1250e-05
# Epoch 47/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9928 - f1_score: 0.9070 - binary_io_u: 0.9167
# Epoch 47: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0179 - accuracy: 0.9928 - f1_score: 0.9070 - binary_io_u: 0.9167 - val_loss: 0.0384 - val_accuracy: 0.9877 - val_f1_score: 0.7690 - val_binary_io_u: 0.8346 - lr: 3.1250e-05
# Epoch 48/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9075 - binary_io_u: 0.9172
# Epoch 48: val_binary_io_u did not improve from 0.83784
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 120/120 [==============================] - 106s 887ms/step - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9075 - binary_io_u: 0.9172 - val_loss: 0.0388 - val_accuracy: 0.9877 - val_f1_score: 0.7669 - val_binary_io_u: 0.8339 - lr: 3.1250e-05
# Epoch 49/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9065 - binary_io_u: 0.9173
# Epoch 49: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 891ms/step - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9065 - binary_io_u: 0.9173 - val_loss: 0.0386 - val_accuracy: 0.9876 - val_f1_score: 0.7679 - val_binary_io_u: 0.8343 - lr: 1.5625e-05
# Epoch 50/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9067 - binary_io_u: 0.9174
# Epoch 50: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 896ms/step - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9067 - binary_io_u: 0.9174 - val_loss: 0.0387 - val_accuracy: 0.9877 - val_f1_score: 0.7674 - val_binary_io_u: 0.8342 - lr: 1.5625e-05
# Epoch 51/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9060 - binary_io_u: 0.9173
# Epoch 51: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 108s 899ms/step - loss: 0.0178 - accuracy: 0.9928 - f1_score: 0.9060 - binary_io_u: 0.9173 - val_loss: 0.0386 - val_accuracy: 0.9876 - val_f1_score: 0.7686 - val_binary_io_u: 0.8345 - lr: 1.5625e-05
# Epoch 52/52
# 120/120 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9929 - f1_score: 0.9097 - binary_io_u: 0.9178
# Epoch 52: val_binary_io_u did not improve from 0.83784
# 120/120 [==============================] - 107s 894ms/step - loss: 0.0176 - accuracy: 0.9929 - f1_score: 0.9097 - binary_io_u: 0.9178 - val_loss: 0.0387 - val_accuracy: 0.9876 - val_f1_score: 0.7687 - val_binary_io_u: 0.8346 - lr: 1.5625e-05

# %% [markdown]
# ## Loading the best model

# %%
# ##Now, load the best model
# best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
#                                   custom_objects={'f1_score': f1_score,
#                                                   'binary_io_u':iou_score_binary})

# # best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# # AUC

# %%
from sklearn.metrics import roc_auc_score

# Flatten masks for AUC computation
y_true_flat = y_test.flatten()
y_score_flat = predictions.flatten()  # Predicted probabilities

# %%
# Bootstrapping AUC
n_iterations = 100
rng = np.random.default_rng(SEED)
bootstrap_aucs = []

for _ in range(n_iterations):
    indices = rng.integers(0, len(y_true_flat), len(y_true_flat))
    y_true_sample = y_true_flat[indices]
    y_score_sample = y_score_flat[indices]

    # Ensure both classes are present in the sample
    if len(np.unique(y_true_sample)) < 2:
        continue

    auc = roc_auc_score(y_true_sample, y_score_sample)
    bootstrap_aucs.append(auc)

# %%
# Calculate statistics
mean_auc = np.mean(bootstrap_aucs)
std_auc = np.std(bootstrap_aucs)
lower_ci = np.percentile(bootstrap_aucs, 2.5)
upper_ci = np.percentile(bootstrap_aucs, 97.5)

# Print AUC statistics
print(f"Bootstrapped AUC: Mean={mean_auc:.4f}, Std={std_auc:.4f}, 95% CI=({lower_ci:.4f}, {upper_ci:.4f})")

# Optional saving
if SAVE_RESULTS:
    auc_df = pd.DataFrame({'AUC Scores': bootstrap_aucs})
    auc_df.to_csv(os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_bootstrapped_auc.csv"), index=False)
# Out:
# Bootstrapped AUC: Mean=0.9776, Std=0.0004, 95% CI=(0.9769, 0.9783)
