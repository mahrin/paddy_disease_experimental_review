# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# from keras import ops# For deeplab3

# import keras_cv # basnet

from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Attention_UNet'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 80#80#100

TOTAL_DATA = 1500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 3
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
# COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 18588.37it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 1500 original images into x_train
# Loaded 1500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### UNet_with_attention--works--Ran with batch size10 (memory issues)
# ---Works properly after 10 epochs--within 5 epoch--sometimes does not show anything

# %%
def conv_block(x, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def attention_gate(g, s, num_filters):
    Wg = Conv2D(num_filters, 1, padding="same")(g)
    Wg = BatchNormalization()(Wg)

    Ws = Conv2D(num_filters, 1, padding="same")(s)
    Ws = BatchNormalization()(Ws)

    out = Activation("relu")(Wg + Ws)
    out = Conv2D(num_filters, 1, padding="same")(out)
    out = Activation("sigmoid")(out)

    return out * s

def decoder_block(x, s, num_filters):
    x = UpSampling2D(interpolation="bilinear")(x)
    s = attention_gate(x, s, num_filters)
    x = Concatenate()([x, s])
    x = conv_block(x, num_filters)
    return x

def UNet_with_attention():
    """ Inputs """

    ### Source: https://github.com/nikhilroxtomar/Semantic-Segmentation-Architecture/blob/main/TensorFlow/attention-unet.py
    inputs = Input(MODEL_INPUT_SIZE)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)

    b1 = conv_block(p3, 512)

    """ Decoder """
    d1 = decoder_block(b1, s3, 256)
    d2 = decoder_block(d1, s2, 128)
    d3 = decoder_block(d2, s1, 64)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d3)

    """ Model """
    model = Model(inputs, outputs, name="Attention-UNET")
    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Model: "Attention-UNET"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 128)        512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)        147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 128)        512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)          590080    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 512)          2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  up_sampling2d (UpSampling2  (None, 64, 64, 512)          0         ['activation_7[0][0]']
#  D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 256)          131328    ['up_sampling2d[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 256)          65792     ['activation_5[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 256)          1024      ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 64, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  tf.__operators__.add (TFOp  (None, 64, 64, 256)          0         ['batch_normalization_8[0][0]'
#  Lambda)                                                            , 'batch_normalization_9[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 64, 64, 256)          0         ['tf.__operators__.add[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 256)          65792     ['activation_8[0][0]']
#
#  activation_9 (Activation)   (None, 64, 64, 256)          0         ['conv2d_10[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 64, 64, 256)          0         ['activation_9[0][0]',
#  da)                                                                 'activation_5[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 768)          0         ['up_sampling2d[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 256)          1769728   ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 64, 64, 256)          1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 64, 64, 256)          1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_1 (UpSamplin  (None, 128, 128, 256)        0         ['activation_11[0][0]']
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 128)        32896     ['up_sampling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 128)        16512     ['activation_3[0][0]']
#
#  batch_normalization_12 (Ba  (None, 128, 128, 128)        512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 128, 128, 128)        512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_1 (TF  (None, 128, 128, 128)        0         ['batch_normalization_12[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 128, 128, 128)        0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 128)        16512     ['activation_12[0][0]']
#
#  activation_13 (Activation)  (None, 128, 128, 128)        0         ['conv2d_15[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 128, 128, 128)        0         ['activation_13[0][0]',
#  mbda)                                                               'activation_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_1[0][0]',
#  )                                                                   'tf.math.multiply_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 128)        442496    ['concatenate_1[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128, 128, 128)        512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 128)        512       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, 256, 256, 128)        0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 64)         8256      ['up_sampling2d_2[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 64)         4160      ['activation_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 256, 256, 64)         256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 256, 256, 64)         256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_2 (TF  (None, 256, 256, 64)         0         ['batch_normalization_16[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 256, 256, 64)         0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 64)         4160      ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 256, 256, 64)         0         ['conv2d_20[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 256, 256, 64)         0         ['activation_17[0][0]',
#  mbda)                                                               'activation_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'tf.math.multiply_2[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 256, 256, 64)         110656    ['concatenate_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 256, 256, 64)         256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 256, 256, 64)         256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 256, 256, 1)          65        ['activation_19[0][0]']
#
# ==================================================================================================
# Total params: 8143169 (31.06 MB)
# Trainable params: 8135745 (31.04 MB)
# Non-trainable params: 7424 (29.00 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9501 - f1_score: 0.5278 - binary_io_u: 0.6197
# Epoch 1: val_binary_io_u improved from -inf to 0.48256, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 132s 755ms/step - loss: 0.1876 - accuracy: 0.9501 - f1_score: 0.5278 - binary_io_u: 0.6197 - val_loss: 0.2625 - val_accuracy: 0.9651 - val_f1_score: 0.0000e+00 - val_binary_io_u: 0.4826 - lr: 0.0010
# Epoch 2/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9782 - f1_score: 0.6975 - binary_io_u: 0.7661
# Epoch 2: val_binary_io_u improved from 0.48256 to 0.48663, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 91s 759ms/step - loss: 0.0806 - accuracy: 0.9782 - f1_score: 0.6975 - binary_io_u: 0.7661 - val_loss: 0.1374 - val_accuracy: 0.9654 - val_f1_score: 0.0121 - val_binary_io_u: 0.4866 - lr: 0.0010
# Epoch 3/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9804 - f1_score: 0.7298 - binary_io_u: 0.7856
# Epoch 3: val_binary_io_u improved from 0.48663 to 0.56950, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 91s 760ms/step - loss: 0.0643 - accuracy: 0.9804 - f1_score: 0.7298 - binary_io_u: 0.7856 - val_loss: 0.0902 - val_accuracy: 0.9701 - val_f1_score: 0.2596 - val_binary_io_u: 0.5695 - lr: 0.0010
# Epoch 4/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9814 - f1_score: 0.7494 - binary_io_u: 0.7966
# Epoch 4: val_binary_io_u improved from 0.56950 to 0.62640, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 91s 760ms/step - loss: 0.0583 - accuracy: 0.9814 - f1_score: 0.7494 - binary_io_u: 0.7966 - val_loss: 0.0843 - val_accuracy: 0.9740 - val_f1_score: 0.3975 - val_binary_io_u: 0.6264 - lr: 0.0010
# Epoch 5/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9817 - f1_score: 0.7499 - binary_io_u: 0.7982
# Epoch 5: val_binary_io_u improved from 0.62640 to 0.78767, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 91s 761ms/step - loss: 0.0555 - accuracy: 0.9817 - f1_score: 0.7499 - binary_io_u: 0.7982 - val_loss: 0.0520 - val_accuracy: 0.9835 - val_f1_score: 0.6965 - val_binary_io_u: 0.7877 - lr: 0.0010
# Epoch 6/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9818 - f1_score: 0.7557 - binary_io_u: 0.8000
# Epoch 6: val_binary_io_u did not improve from 0.78767
# 120/120 [==============================] - 90s 749ms/step - loss: 0.0547 - accuracy: 0.9818 - f1_score: 0.7557 - binary_io_u: 0.8000 - val_loss: 0.0517 - val_accuracy: 0.9833 - val_f1_score: 0.6814 - val_binary_io_u: 0.7845 - lr: 0.0010
# Epoch 7/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9820 - f1_score: 0.7535 - binary_io_u: 0.8016
# Epoch 7: val_binary_io_u did not improve from 0.78767
# 120/120 [==============================] - 90s 747ms/step - loss: 0.0539 - accuracy: 0.9820 - f1_score: 0.7535 - binary_io_u: 0.8016 - val_loss: 0.0567 - val_accuracy: 0.9814 - val_f1_score: 0.6190 - val_binary_io_u: 0.7398 - lr: 0.0010
# Epoch 8/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9824 - f1_score: 0.7652 - binary_io_u: 0.8051
# Epoch 8: val_binary_io_u did not improve from 0.78767
# 120/120 [==============================] - 90s 748ms/step - loss: 0.0530 - accuracy: 0.9824 - f1_score: 0.7652 - binary_io_u: 0.8051 - val_loss: 0.0522 - val_accuracy: 0.9823 - val_f1_score: 0.6996 - val_binary_io_u: 0.7871 - lr: 0.0010
# Epoch 9/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9828 - f1_score: 0.7688 - binary_io_u: 0.8099
# Epoch 9: val_binary_io_u did not improve from 0.78767
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 120/120 [==============================] - 90s 750ms/step - loss: 0.0512 - accuracy: 0.9828 - f1_score: 0.7688 - binary_io_u: 0.8099 - val_loss: 0.0618 - val_accuracy: 0.9793 - val_f1_score: 0.6462 - val_binary_io_u: 0.7601 - lr: 0.0010
# Epoch 10/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9835 - f1_score: 0.7812 - binary_io_u: 0.8165
# Epoch 10: val_binary_io_u improved from 0.78767 to 0.80234, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 91s 760ms/step - loss: 0.0491 - accuracy: 0.9835 - f1_score: 0.7812 - binary_io_u: 0.8165 - val_loss: 0.0464 - val_accuracy: 0.9846 - val_f1_score: 0.7163 - val_binary_io_u: 0.8023 - lr: 5.0000e-04
# Epoch 11/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9841 - f1_score: 0.7854 - binary_io_u: 0.8217
# Epoch 11: val_binary_io_u did not improve from 0.80234
# 120/120 [==============================] - 90s 748ms/step - loss: 0.0475 - accuracy: 0.9841 - f1_score: 0.7854 - binary_io_u: 0.8217 - val_loss: 0.0451 - val_accuracy: 0.9851 - val_f1_score: 0.7062 - val_binary_io_u: 0.8004 - lr: 5.0000e-04
# Epoch 12/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9841 - f1_score: 0.7826 - binary_io_u: 0.8229
# Epoch 12: val_binary_io_u did not improve from 0.80234
# 120/120 [==============================] - 90s 747ms/step - loss: 0.0468 - accuracy: 0.9841 - f1_score: 0.7826 - binary_io_u: 0.8229 - val_loss: 0.0453 - val_accuracy: 0.9848 - val_f1_score: 0.7160 - val_binary_io_u: 0.8023 - lr: 5.0000e-04
# Epoch 13/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9844 - f1_score: 0.7856 - binary_io_u: 0.8253
# Epoch 13: val_binary_io_u did not improve from 0.80234
# 120/120 [==============================] - 90s 747ms/step - loss: 0.0463 - accuracy: 0.9844 - f1_score: 0.7856 - binary_io_u: 0.8253 - val_loss: 0.0801 - val_accuracy: 0.9680 - val_f1_score: 0.5693 - val_binary_io_u: 0.7024 - lr: 5.0000e-04
# Epoch 14/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9850 - f1_score: 0.7987 - binary_io_u: 0.8317
# Epoch 14: val_binary_io_u improved from 0.80234 to 0.80777, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 764ms/step - loss: 0.0445 - accuracy: 0.9850 - f1_score: 0.7987 - binary_io_u: 0.8317 - val_loss: 0.0441 - val_accuracy: 0.9852 - val_f1_score: 0.7170 - val_binary_io_u: 0.8078 - lr: 5.0000e-04
# Epoch 15/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9850 - f1_score: 0.7975 - binary_io_u: 0.8317
# Epoch 15: val_binary_io_u did not improve from 0.80777
# 120/120 [==============================] - 90s 750ms/step - loss: 0.0446 - accuracy: 0.9850 - f1_score: 0.7975 - binary_io_u: 0.8317 - val_loss: 0.0473 - val_accuracy: 0.9850 - val_f1_score: 0.7078 - val_binary_io_u: 0.7998 - lr: 5.0000e-04
# Epoch 16/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9849 - f1_score: 0.7960 - binary_io_u: 0.8308
# Epoch 16: val_binary_io_u improved from 0.80777 to 0.81502, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 91s 763ms/step - loss: 0.0443 - accuracy: 0.9849 - f1_score: 0.7960 - binary_io_u: 0.8308 - val_loss: 0.0439 - val_accuracy: 0.9853 - val_f1_score: 0.7402 - val_binary_io_u: 0.8150 - lr: 5.0000e-04
# Epoch 17/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9851 - f1_score: 0.7987 - binary_io_u: 0.8331
# Epoch 17: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 90s 749ms/step - loss: 0.0438 - accuracy: 0.9851 - f1_score: 0.7987 - binary_io_u: 0.8331 - val_loss: 0.0423 - val_accuracy: 0.9860 - val_f1_score: 0.7291 - val_binary_io_u: 0.8147 - lr: 5.0000e-04
# Epoch 18/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9855 - f1_score: 0.8012 - binary_io_u: 0.8366
# Epoch 18: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 90s 748ms/step - loss: 0.0429 - accuracy: 0.9855 - f1_score: 0.8012 - binary_io_u: 0.8366 - val_loss: 0.0486 - val_accuracy: 0.9835 - val_f1_score: 0.7156 - val_binary_io_u: 0.8025 - lr: 5.0000e-04
# Epoch 19/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9856 - f1_score: 0.8072 - binary_io_u: 0.8378
# Epoch 19: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 90s 749ms/step - loss: 0.0422 - accuracy: 0.9856 - f1_score: 0.8072 - binary_io_u: 0.8378 - val_loss: 0.0502 - val_accuracy: 0.9840 - val_f1_score: 0.6639 - val_binary_io_u: 0.7763 - lr: 5.0000e-04
# Epoch 20/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9854 - f1_score: 0.8039 - binary_io_u: 0.8359
# Epoch 20: val_binary_io_u did not improve from 0.81502
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 120/120 [==============================] - 90s 748ms/step - loss: 0.0430 - accuracy: 0.9854 - f1_score: 0.8039 - binary_io_u: 0.8359 - val_loss: 0.0448 - val_accuracy: 0.9857 - val_f1_score: 0.7134 - val_binary_io_u: 0.8052 - lr: 5.0000e-04
# Epoch 21/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9864 - f1_score: 0.8174 - binary_io_u: 0.8467
# Epoch 21: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0397 - accuracy: 0.9864 - f1_score: 0.8174 - binary_io_u: 0.8467 - val_loss: 0.0423 - val_accuracy: 0.9861 - val_f1_score: 0.7107 - val_binary_io_u: 0.8078 - lr: 2.5000e-04
# Epoch 22/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9868 - f1_score: 0.8207 - binary_io_u: 0.8500
# Epoch 22: val_binary_io_u improved from 0.81502 to 0.81944, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 765ms/step - loss: 0.0385 - accuracy: 0.9868 - f1_score: 0.8207 - binary_io_u: 0.8500 - val_loss: 0.0393 - val_accuracy: 0.9867 - val_f1_score: 0.7312 - val_binary_io_u: 0.8194 - lr: 2.5000e-04
# Epoch 23/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9867 - f1_score: 0.8194 - binary_io_u: 0.8491
# Epoch 23: val_binary_io_u improved from 0.81944 to 0.82281, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 767ms/step - loss: 0.0387 - accuracy: 0.9867 - f1_score: 0.8194 - binary_io_u: 0.8491 - val_loss: 0.0395 - val_accuracy: 0.9869 - val_f1_score: 0.7414 - val_binary_io_u: 0.8228 - lr: 2.5000e-04
# Epoch 24/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0381 - accuracy: 0.9870 - f1_score: 0.8259 - binary_io_u: 0.8521
# Epoch 24: val_binary_io_u did not improve from 0.82281
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0381 - accuracy: 0.9870 - f1_score: 0.8259 - binary_io_u: 0.8521 - val_loss: 0.0423 - val_accuracy: 0.9858 - val_f1_score: 0.7349 - val_binary_io_u: 0.8174 - lr: 2.5000e-04
# Epoch 25/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9869 - f1_score: 0.8253 - binary_io_u: 0.8518
# Epoch 25: val_binary_io_u improved from 0.82281 to 0.82585, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 120/120 [==============================] - 92s 764ms/step - loss: 0.0382 - accuracy: 0.9869 - f1_score: 0.8253 - binary_io_u: 0.8518 - val_loss: 0.0396 - val_accuracy: 0.9866 - val_f1_score: 0.7428 - val_binary_io_u: 0.8259 - lr: 2.5000e-04
# Epoch 26/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9874 - f1_score: 0.8252 - binary_io_u: 0.8560
# Epoch 26: val_binary_io_u improved from 0.82585 to 0.83159, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 766ms/step - loss: 0.0365 - accuracy: 0.9874 - f1_score: 0.8252 - binary_io_u: 0.8560 - val_loss: 0.0379 - val_accuracy: 0.9873 - val_f1_score: 0.7536 - val_binary_io_u: 0.8316 - lr: 1.2500e-04
# Epoch 27/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9877 - f1_score: 0.8291 - binary_io_u: 0.8599
# Epoch 27: val_binary_io_u did not improve from 0.83159
# 120/120 [==============================] - 90s 750ms/step - loss: 0.0357 - accuracy: 0.9877 - f1_score: 0.8291 - binary_io_u: 0.8599 - val_loss: 0.0380 - val_accuracy: 0.9873 - val_f1_score: 0.7352 - val_binary_io_u: 0.8244 - lr: 1.2500e-04
# Epoch 28/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9878 - f1_score: 0.8357 - binary_io_u: 0.8605
# Epoch 28: val_binary_io_u did not improve from 0.83159
# 120/120 [==============================] - 90s 751ms/step - loss: 0.0353 - accuracy: 0.9878 - f1_score: 0.8357 - binary_io_u: 0.8605 - val_loss: 0.0371 - val_accuracy: 0.9873 - val_f1_score: 0.7418 - val_binary_io_u: 0.8283 - lr: 1.2500e-04
# Epoch 29/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9878 - f1_score: 0.8332 - binary_io_u: 0.8606
# Epoch 29: val_binary_io_u improved from 0.83159 to 0.83445, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 765ms/step - loss: 0.0353 - accuracy: 0.9878 - f1_score: 0.8332 - binary_io_u: 0.8606 - val_loss: 0.0364 - val_accuracy: 0.9876 - val_f1_score: 0.7589 - val_binary_io_u: 0.8344 - lr: 1.2500e-04
# Epoch 30/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9880 - f1_score: 0.8393 - binary_io_u: 0.8625
# Epoch 30: val_binary_io_u did not improve from 0.83445
# 120/120 [==============================] - 90s 752ms/step - loss: 0.0349 - accuracy: 0.9880 - f1_score: 0.8393 - binary_io_u: 0.8625 - val_loss: 0.0373 - val_accuracy: 0.9874 - val_f1_score: 0.7512 - val_binary_io_u: 0.8332 - lr: 1.2500e-04
# Epoch 31/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9880 - f1_score: 0.8350 - binary_io_u: 0.8625
# Epoch 31: val_binary_io_u did not improve from 0.83445
# 120/120 [==============================] - 90s 751ms/step - loss: 0.0347 - accuracy: 0.9880 - f1_score: 0.8350 - binary_io_u: 0.8625 - val_loss: 0.0372 - val_accuracy: 0.9876 - val_f1_score: 0.7505 - val_binary_io_u: 0.8321 - lr: 1.2500e-04
# Epoch 32/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9881 - f1_score: 0.8358 - binary_io_u: 0.8636
# Epoch 32: val_binary_io_u did not improve from 0.83445
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 120/120 [==============================] - 90s 752ms/step - loss: 0.0342 - accuracy: 0.9881 - f1_score: 0.8358 - binary_io_u: 0.8636 - val_loss: 0.0365 - val_accuracy: 0.9877 - val_f1_score: 0.7530 - val_binary_io_u: 0.8318 - lr: 1.2500e-04
# Epoch 33/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9884 - f1_score: 0.8427 - binary_io_u: 0.8675
# Epoch 33: val_binary_io_u improved from 0.83445 to 0.83503, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 765ms/step - loss: 0.0330 - accuracy: 0.9884 - f1_score: 0.8427 - binary_io_u: 0.8675 - val_loss: 0.0357 - val_accuracy: 0.9879 - val_f1_score: 0.7601 - val_binary_io_u: 0.8350 - lr: 6.2500e-05
# Epoch 34/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9886 - f1_score: 0.8457 - binary_io_u: 0.8694
# Epoch 34: val_binary_io_u improved from 0.83503 to 0.83702, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 767ms/step - loss: 0.0325 - accuracy: 0.9886 - f1_score: 0.8457 - binary_io_u: 0.8694 - val_loss: 0.0355 - val_accuracy: 0.9881 - val_f1_score: 0.7628 - val_binary_io_u: 0.8370 - lr: 6.2500e-05
# Epoch 35/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9886 - f1_score: 0.8458 - binary_io_u: 0.8692
# Epoch 35: val_binary_io_u did not improve from 0.83702
# 120/120 [==============================] - 90s 752ms/step - loss: 0.0326 - accuracy: 0.9886 - f1_score: 0.8458 - binary_io_u: 0.8692 - val_loss: 0.0352 - val_accuracy: 0.9880 - val_f1_score: 0.7583 - val_binary_io_u: 0.8365 - lr: 6.2500e-05
# Epoch 36/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9887 - f1_score: 0.8472 - binary_io_u: 0.8703
# Epoch 36: val_binary_io_u improved from 0.83702 to 0.84113, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 769ms/step - loss: 0.0322 - accuracy: 0.9887 - f1_score: 0.8472 - binary_io_u: 0.8703 - val_loss: 0.0353 - val_accuracy: 0.9882 - val_f1_score: 0.7668 - val_binary_io_u: 0.8411 - lr: 6.2500e-05
# Epoch 37/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9889 - f1_score: 0.8464 - binary_io_u: 0.8721
# Epoch 37: val_binary_io_u did not improve from 0.84113
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0315 - accuracy: 0.9889 - f1_score: 0.8464 - binary_io_u: 0.8721 - val_loss: 0.0358 - val_accuracy: 0.9880 - val_f1_score: 0.7606 - val_binary_io_u: 0.8362 - lr: 6.2500e-05
# Epoch 38/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9889 - f1_score: 0.8507 - binary_io_u: 0.8726
# Epoch 38: val_binary_io_u did not improve from 0.84113
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0312 - accuracy: 0.9889 - f1_score: 0.8507 - binary_io_u: 0.8726 - val_loss: 0.0349 - val_accuracy: 0.9883 - val_f1_score: 0.7638 - val_binary_io_u: 0.8404 - lr: 6.2500e-05
# Epoch 39/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9890 - f1_score: 0.8482 - binary_io_u: 0.8731
# Epoch 39: val_binary_io_u did not improve from 0.84113
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0310 - accuracy: 0.9890 - f1_score: 0.8482 - binary_io_u: 0.8731 - val_loss: 0.0357 - val_accuracy: 0.9879 - val_f1_score: 0.7652 - val_binary_io_u: 0.8381 - lr: 6.2500e-05
# Epoch 40/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9892 - f1_score: 0.8541 - binary_io_u: 0.8757
# Epoch 40: val_binary_io_u improved from 0.84113 to 0.84388, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 768ms/step - loss: 0.0306 - accuracy: 0.9892 - f1_score: 0.8541 - binary_io_u: 0.8757 - val_loss: 0.0346 - val_accuracy: 0.9883 - val_f1_score: 0.7729 - val_binary_io_u: 0.8439 - lr: 6.2500e-05
# Epoch 41/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9892 - f1_score: 0.8552 - binary_io_u: 0.8760
# Epoch 41: val_binary_io_u did not improve from 0.84388
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0305 - accuracy: 0.9892 - f1_score: 0.8552 - binary_io_u: 0.8760 - val_loss: 0.0349 - val_accuracy: 0.9882 - val_f1_score: 0.7620 - val_binary_io_u: 0.8402 - lr: 6.2500e-05
# Epoch 42/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9892 - f1_score: 0.8487 - binary_io_u: 0.8750
# Epoch 42: val_binary_io_u did not improve from 0.84388
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0307 - accuracy: 0.9892 - f1_score: 0.8487 - binary_io_u: 0.8750 - val_loss: 0.0348 - val_accuracy: 0.9883 - val_f1_score: 0.7623 - val_binary_io_u: 0.8393 - lr: 6.2500e-05
# Epoch 43/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9892 - f1_score: 0.8555 - binary_io_u: 0.8757
# Epoch 43: val_binary_io_u did not improve from 0.84388
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0306 - accuracy: 0.9892 - f1_score: 0.8555 - binary_io_u: 0.8757 - val_loss: 0.0348 - val_accuracy: 0.9884 - val_f1_score: 0.7703 - val_binary_io_u: 0.8423 - lr: 6.2500e-05
# Epoch 44/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9895 - f1_score: 0.8545 - binary_io_u: 0.8794
# Epoch 44: val_binary_io_u improved from 0.84388 to 0.84571, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 766ms/step - loss: 0.0295 - accuracy: 0.9895 - f1_score: 0.8545 - binary_io_u: 0.8794 - val_loss: 0.0333 - val_accuracy: 0.9886 - val_f1_score: 0.7740 - val_binary_io_u: 0.8457 - lr: 3.1250e-05
# Epoch 45/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9897 - f1_score: 0.8622 - binary_io_u: 0.8813
# Epoch 45: val_binary_io_u improved from 0.84571 to 0.84602, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 767ms/step - loss: 0.0287 - accuracy: 0.9897 - f1_score: 0.8622 - binary_io_u: 0.8813 - val_loss: 0.0337 - val_accuracy: 0.9886 - val_f1_score: 0.7742 - val_binary_io_u: 0.8460 - lr: 3.1250e-05
# Epoch 46/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9897 - f1_score: 0.8599 - binary_io_u: 0.8809
# Epoch 46: val_binary_io_u did not improve from 0.84602
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0289 - accuracy: 0.9897 - f1_score: 0.8599 - binary_io_u: 0.8809 - val_loss: 0.0336 - val_accuracy: 0.9887 - val_f1_score: 0.7707 - val_binary_io_u: 0.8452 - lr: 3.1250e-05
# Epoch 47/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9897 - f1_score: 0.8612 - binary_io_u: 0.8816
# Epoch 47: val_binary_io_u improved from 0.84602 to 0.84709, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 120/120 [==============================] - 92s 766ms/step - loss: 0.0286 - accuracy: 0.9897 - f1_score: 0.8612 - binary_io_u: 0.8816 - val_loss: 0.0333 - val_accuracy: 0.9887 - val_f1_score: 0.7789 - val_binary_io_u: 0.8471 - lr: 3.1250e-05
# Epoch 48/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9900 - f1_score: 0.8639 - binary_io_u: 0.8839
# Epoch 48: val_binary_io_u improved from 0.84709 to 0.84832, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 767ms/step - loss: 0.0278 - accuracy: 0.9900 - f1_score: 0.8639 - binary_io_u: 0.8839 - val_loss: 0.0328 - val_accuracy: 0.9888 - val_f1_score: 0.7795 - val_binary_io_u: 0.8483 - lr: 1.5625e-05
# Epoch 49/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9900 - f1_score: 0.8644 - binary_io_u: 0.8844
# Epoch 49: val_binary_io_u did not improve from 0.84832
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0277 - accuracy: 0.9900 - f1_score: 0.8644 - binary_io_u: 0.8844 - val_loss: 0.0332 - val_accuracy: 0.9887 - val_f1_score: 0.7729 - val_binary_io_u: 0.8459 - lr: 1.5625e-05
# Epoch 50/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9901 - f1_score: 0.8646 - binary_io_u: 0.8850
# Epoch 50: val_binary_io_u did not improve from 0.84832
# 120/120 [==============================] - 90s 752ms/step - loss: 0.0276 - accuracy: 0.9901 - f1_score: 0.8646 - binary_io_u: 0.8850 - val_loss: 0.0331 - val_accuracy: 0.9888 - val_f1_score: 0.7771 - val_binary_io_u: 0.8475 - lr: 1.5625e-05
# Epoch 51/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9901 - f1_score: 0.8645 - binary_io_u: 0.8858
# Epoch 51: val_binary_io_u did not improve from 0.84832
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 120/120 [==============================] - 90s 752ms/step - loss: 0.0273 - accuracy: 0.9901 - f1_score: 0.8645 - binary_io_u: 0.8858 - val_loss: 0.0330 - val_accuracy: 0.9888 - val_f1_score: 0.7752 - val_binary_io_u: 0.8473 - lr: 1.5625e-05
# Epoch 52/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9902 - f1_score: 0.8686 - binary_io_u: 0.8860
# Epoch 52: val_binary_io_u improved from 0.84832 to 0.84925, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 765ms/step - loss: 0.0273 - accuracy: 0.9902 - f1_score: 0.8686 - binary_io_u: 0.8860 - val_loss: 0.0327 - val_accuracy: 0.9889 - val_f1_score: 0.7800 - val_binary_io_u: 0.8492 - lr: 7.8125e-06
# Epoch 53/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9902 - f1_score: 0.8643 - binary_io_u: 0.8862
# Epoch 53: val_binary_io_u did not improve from 0.84925
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0272 - accuracy: 0.9902 - f1_score: 0.8643 - binary_io_u: 0.8862 - val_loss: 0.0327 - val_accuracy: 0.9889 - val_f1_score: 0.7798 - val_binary_io_u: 0.8487 - lr: 7.8125e-06
# Epoch 54/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9903 - f1_score: 0.8641 - binary_io_u: 0.8873
# Epoch 54: val_binary_io_u improved from 0.84925 to 0.85017, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 768ms/step - loss: 0.0268 - accuracy: 0.9903 - f1_score: 0.8641 - binary_io_u: 0.8873 - val_loss: 0.0326 - val_accuracy: 0.9889 - val_f1_score: 0.7832 - val_binary_io_u: 0.8502 - lr: 7.8125e-06
# Epoch 55/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9902 - f1_score: 0.8661 - binary_io_u: 0.8868
# Epoch 55: val_binary_io_u did not improve from 0.85017
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0270 - accuracy: 0.9902 - f1_score: 0.8661 - binary_io_u: 0.8868 - val_loss: 0.0327 - val_accuracy: 0.9889 - val_f1_score: 0.7819 - val_binary_io_u: 0.8495 - lr: 7.8125e-06
# Epoch 56/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9903 - f1_score: 0.8669 - binary_io_u: 0.8876
# Epoch 56: val_binary_io_u did not improve from 0.85017
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0266 - accuracy: 0.9903 - f1_score: 0.8669 - binary_io_u: 0.8876 - val_loss: 0.0327 - val_accuracy: 0.9889 - val_f1_score: 0.7806 - val_binary_io_u: 0.8495 - lr: 7.8125e-06
# Epoch 57/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9903 - f1_score: 0.8677 - binary_io_u: 0.8870
# Epoch 57: val_binary_io_u improved from 0.85017 to 0.85017, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 767ms/step - loss: 0.0270 - accuracy: 0.9903 - f1_score: 0.8677 - binary_io_u: 0.8870 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7826 - val_binary_io_u: 0.8502 - lr: 3.9063e-06
# Epoch 58/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9903 - f1_score: 0.8703 - binary_io_u: 0.8880
# Epoch 58: val_binary_io_u did not improve from 0.85017
# 120/120 [==============================] - 90s 755ms/step - loss: 0.0265 - accuracy: 0.9903 - f1_score: 0.8703 - binary_io_u: 0.8880 - val_loss: 0.0326 - val_accuracy: 0.9889 - val_f1_score: 0.7812 - val_binary_io_u: 0.8496 - lr: 3.9063e-06
# Epoch 59/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9903 - f1_score: 0.8704 - binary_io_u: 0.8871
# Epoch 59: val_binary_io_u improved from 0.85017 to 0.85031, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 768ms/step - loss: 0.0267 - accuracy: 0.9903 - f1_score: 0.8704 - binary_io_u: 0.8871 - val_loss: 0.0326 - val_accuracy: 0.9889 - val_f1_score: 0.7828 - val_binary_io_u: 0.8503 - lr: 3.9063e-06
# Epoch 60/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8694 - binary_io_u: 0.8880
# Epoch 60: val_binary_io_u improved from 0.85031 to 0.85046, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 120/120 [==============================] - 92s 765ms/step - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8694 - binary_io_u: 0.8880 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7835 - val_binary_io_u: 0.8505 - lr: 3.9063e-06
# Epoch 61/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8677 - binary_io_u: 0.8885
# Epoch 61: val_binary_io_u did not improve from 0.85046
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8677 - binary_io_u: 0.8885 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7823 - val_binary_io_u: 0.8502 - lr: 1.9531e-06
# Epoch 62/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8726 - binary_io_u: 0.8885
# Epoch 62: val_binary_io_u did not improve from 0.85046
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8726 - binary_io_u: 0.8885 - val_loss: 0.0326 - val_accuracy: 0.9889 - val_f1_score: 0.7822 - val_binary_io_u: 0.8501 - lr: 1.9531e-06
# Epoch 63/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9903 - f1_score: 0.8666 - binary_io_u: 0.8880
# Epoch 63: val_binary_io_u did not improve from 0.85046
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0267 - accuracy: 0.9903 - f1_score: 0.8666 - binary_io_u: 0.8880 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7820 - val_binary_io_u: 0.8500 - lr: 1.9531e-06
# Epoch 64/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8704 - binary_io_u: 0.8886
# Epoch 64: val_binary_io_u did not improve from 0.85046
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8704 - binary_io_u: 0.8886 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7829 - val_binary_io_u: 0.8504 - lr: 9.7656e-07
# Epoch 65/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8699 - binary_io_u: 0.8890
# Epoch 65: val_binary_io_u improved from 0.85046 to 0.85047, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
# 120/120 [==============================] - 92s 767ms/step - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8699 - binary_io_u: 0.8890 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7830 - val_binary_io_u: 0.8505 - lr: 9.7656e-07
# Epoch 66/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8708 - binary_io_u: 0.8885
# Epoch 66: val_binary_io_u improved from 0.85047 to 0.85066, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 120/120 [==============================] - 93s 774ms/step - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8708 - binary_io_u: 0.8885 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7836 - val_binary_io_u: 0.8507 - lr: 9.7656e-07
# Epoch 67/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9904 - f1_score: 0.8698 - binary_io_u: 0.8885
# Epoch 67: val_binary_io_u did not improve from 0.85066
# 120/120 [==============================] - 91s 755ms/step - loss: 0.0263 - accuracy: 0.9904 - f1_score: 0.8698 - binary_io_u: 0.8885 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7834 - val_binary_io_u: 0.8506 - lr: 4.8828e-07
# Epoch 68/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8709 - binary_io_u: 0.8891
# Epoch 68: val_binary_io_u did not improve from 0.85066
# 120/120 [==============================] - 90s 753ms/step - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8709 - binary_io_u: 0.8891 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7836 - val_binary_io_u: 0.8506 - lr: 4.8828e-07
# Epoch 69/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8708 - binary_io_u: 0.8890
# Epoch 69: val_binary_io_u improved from 0.85066 to 0.85072, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Attention_UNet/saved_models/best_Attention_UNet.h5
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 120/120 [==============================] - 92s 766ms/step - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8708 - binary_io_u: 0.8890 - val_loss: 0.0325 - val_accuracy: 0.9890 - val_f1_score: 0.7837 - val_binary_io_u: 0.8507 - lr: 4.8828e-07
# Epoch 70/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8735 - binary_io_u: 0.8884
# Epoch 70: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 755ms/step - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8735 - binary_io_u: 0.8884 - val_loss: 0.0325 - val_accuracy: 0.9890 - val_f1_score: 0.7835 - val_binary_io_u: 0.8506 - lr: 2.4414e-07
# Epoch 71/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9904 - f1_score: 0.8681 - binary_io_u: 0.8891
# Epoch 71: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0263 - accuracy: 0.9904 - f1_score: 0.8681 - binary_io_u: 0.8891 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7832 - val_binary_io_u: 0.8505 - lr: 2.4414e-07
# Epoch 72/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8710 - binary_io_u: 0.8889
# Epoch 72: val_binary_io_u did not improve from 0.85072
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0262 - accuracy: 0.9904 - f1_score: 0.8710 - binary_io_u: 0.8889 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7834 - val_binary_io_u: 0.8505 - lr: 2.4414e-07
# Epoch 73/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9905 - f1_score: 0.8670 - binary_io_u: 0.8892
# Epoch 73: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0263 - accuracy: 0.9905 - f1_score: 0.8670 - binary_io_u: 0.8892 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7835 - val_binary_io_u: 0.8506 - lr: 1.2207e-07
# Epoch 74/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8709 - binary_io_u: 0.8881
# Epoch 74: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8709 - binary_io_u: 0.8881 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7832 - val_binary_io_u: 0.8505 - lr: 1.2207e-07
# Epoch 75/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9904 - f1_score: 0.8712 - binary_io_u: 0.8889
# Epoch 75: val_binary_io_u did not improve from 0.85072
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0263 - accuracy: 0.9904 - f1_score: 0.8712 - binary_io_u: 0.8889 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7834 - val_binary_io_u: 0.8506 - lr: 1.2207e-07
# Epoch 76/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9903 - f1_score: 0.8673 - binary_io_u: 0.8880
# Epoch 76: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0265 - accuracy: 0.9903 - f1_score: 0.8673 - binary_io_u: 0.8880 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7836 - val_binary_io_u: 0.8506 - lr: 6.1035e-08
# Epoch 77/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8666 - binary_io_u: 0.8883
# Epoch 77: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 754ms/step - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8666 - binary_io_u: 0.8883 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7835 - val_binary_io_u: 0.8506 - lr: 6.1035e-08
# Epoch 78/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8693 - binary_io_u: 0.8884
# Epoch 78: val_binary_io_u did not improve from 0.85072
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 120/120 [==============================] - 91s 756ms/step - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8693 - binary_io_u: 0.8884 - val_loss: 0.0325 - val_accuracy: 0.9890 - val_f1_score: 0.7835 - val_binary_io_u: 0.8506 - lr: 6.1035e-08
# Epoch 79/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8688 - binary_io_u: 0.8886
# Epoch 79: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 90s 752ms/step - loss: 0.0264 - accuracy: 0.9904 - f1_score: 0.8688 - binary_io_u: 0.8886 - val_loss: 0.0325 - val_accuracy: 0.9889 - val_f1_score: 0.7834 - val_binary_io_u: 0.8506 - lr: 3.0518e-08
# Epoch 80/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8700 - binary_io_u: 0.8885
# Epoch 80: val_binary_io_u did not improve from 0.85072
# 120/120 [==============================] - 91s 755ms/step - loss: 0.0265 - accuracy: 0.9904 - f1_score: 0.8700 - binary_io_u: 0.8885 - val_loss: 0.0325 - val_accuracy: 0.9890 - val_f1_score: 0.7833 - val_binary_io_u: 0.8505 - lr: 3.0518e-08

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 19s 19s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 18]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#        Model Name      Loss  Accuracy  Precision    Recall  F1-Score       IoU
# 0  Attention_UNet  0.030487  0.990295   0.912345  0.818405  0.862826  0.852303

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
