# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# from keras import ops# For deeplab3

# import keras_cv # basnet

from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Inception_resnetV2_Unet_1500_v2'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 80

TOTAL_DATA = 1500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 5
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"


# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 18230.24it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 1500 original images into x_train
# Loaded 1500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"


# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### InceptionResNetV2---Works--checked with batch size10

# %%
from tensorflow.keras.applications import  InceptionResNetV2
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

def get_unet_InceptionResNetV2(n_filters=16, batchnorm=True, dropout=0.1):
    InceptionResNetV2_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=MODEL_INPUT_SIZE)

    # Encoder
    encoder = InceptionResNetV2_base.get_layer('activation_89').output

    # Bottleneck
    bottleneck = Conv2D(512, (3, 3), activation='relu', padding='same')(encoder)

    # Resizing for skip connections
    resized_skip1 = tf.image.resize(InceptionResNetV2_base.get_layer('activation_89').output, [28, 28])
    resized_skip2 = tf.image.resize(InceptionResNetV2_base.get_layer('max_pooling2d').output, [56, 56])
    resized_skip3 = tf.image.resize(InceptionResNetV2_base.get_layer('conv2d_1').output, [112, 112])

    # Decoder
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(bottleneck)
    u6 = Concatenate(axis=-1)([u6, resized_skip1])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = Concatenate(axis=-1)([u7, resized_skip2])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
    u8 = Concatenate(axis=-1)([u8, resized_skip3])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size=3, batchnorm=batchnorm)

    # Final upsampling to match the original input size
    u9 = Conv2DTranspose(n_filters, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters, kernel_size=3, batchnorm=batchnorm)

    # Additional resizing layer to ensure output is 256x256
    final_output = Resizing(256, 256, interpolation='bilinear')(c9)

    outputs = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(final_output)
    model = Model(inputs=InceptionResNetV2_base.input, outputs=[outputs])
    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 8s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 127, 127, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 127, 127, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 127, 127, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 125, 125, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 125, 125, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 125, 125, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 125, 125, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 125, 125, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 62, 62, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 62, 62, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 62, 62, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 62, 62, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 60, 60, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 60, 60, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 60, 60, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 29, 29, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 29, 29, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 29, 29, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 29, 29, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 29, 29, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 29, 29, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 29, 29, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 29, 29, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 29, 29, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 29, 29, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 29, 29, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 29, 29, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 29, 29, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 29, 29, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 29, 29, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 29, 29, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 29, 29, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 29, 29, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 29, 29, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 29, 29, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 29, 29, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 29, 29, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 29, 29, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 29, 29, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 29, 29, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 29, 29, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 29, 29, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 29, 29, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 29, 29, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 29, 29, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 29, 29, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 29, 29, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 29, 29, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 29, 29, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 29, 29, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 29, 29, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 29, 29, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 29, 29, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 29, 29, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 29, 29, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 29, 29, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 29, 29, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 29, 29, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 29, 29, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 29, 29, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 29, 29, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 29, 29, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 29, 29, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 29, 29, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 29, 29, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 29, 29, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 29, 29, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 29, 29, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 29, 29, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 29, 29, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 29, 29, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 29, 29, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 29, 29, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 29, 29, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 29, 29, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 29, 29, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 29, 29, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 29, 29, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 29, 29, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 29, 29, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 29, 29, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 29, 29, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 29, 29, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 29, 29, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 29, 29, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 29, 29, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 29, 29, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 29, 29, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 29, 29, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 29, 29, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 29, 29, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 29, 29, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 29, 29, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 29, 29, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
# ...
#
#  batch_normalization_85 (Ba  (None, 14, 14, 128)          384       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 14, 14, 160)          143360    ['activation_85[0][0]']
#
#  batch_normalization_86 (Ba  (None, 14, 14, 160)          480       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 14, 14, 160)          0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 14, 14, 192)          208896    ['block17_2_ac[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 14, 14, 192)          215040    ['activation_86[0][0]']
#
#  batch_normalization_84 (Ba  (None, 14, 14, 192)          576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  batch_normalization_87 (Ba  (None, 14, 14, 192)          576       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 14, 14, 192)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  activation_87 (Activation)  (None, 14, 14, 192)          0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  block17_3_mixed (Concatena  (None, 14, 14, 384)          0         ['activation_84[0][0]',
#  te)                                                                 'activation_87[0][0]']
#
#  block17_3_conv (Conv2D)     (None, 14, 14, 1088)         418880    ['block17_3_mixed[0][0]']
#
#  custom_scale_layer_12 (Cus  (None, 14, 14, 1088)         0         ['block17_2_ac[0][0]',
#  tomScaleLayer)                                                      'block17_3_conv[0][0]']
#
#  block17_3_ac (Activation)   (None, 14, 14, 1088)         0         ['custom_scale_layer_12[0][0]'
#                                                                     ]
#
#  conv2d_89 (Conv2D)          (None, 14, 14, 128)          139264    ['block17_3_ac[0][0]']
#
#  batch_normalization_89 (Ba  (None, 14, 14, 128)          384       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 14, 14, 128)          0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_203 (Conv2D)         (None, 14, 14, 512)          590336    ['activation_89[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 28, 28, 128)          589952    ['conv2d_203[0][0]']
#  anspose)
#
#  tf.image.resize (TFOpLambd  (None, 28, 28, 128)          0         ['activation_89[0][0]']
#  a)
#
#  concatenate (Concatenate)   (None, 28, 28, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'tf.image.resize[0][0]']
#
#  dropout (Dropout)           (None, 28, 28, 256)          0         ['concatenate[0][0]']
#
#  conv2d_204 (Conv2D)         (None, 28, 28, 128)          295040    ['dropout[0][0]']
#
#  batch_normalization_203 (B  (None, 28, 28, 128)          512       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_205 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_203[0][0]']
#
#  batch_normalization_204 (B  (None, 28, 28, 128)          512       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  activation_204 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  conv2d_transpose_1 (Conv2D  (None, 56, 56, 64)           73792     ['activation_204[0][0]']
#  Transpose)
#
#  tf.image.resize_1 (TFOpLam  (None, 56, 56, 64)           0         ['max_pooling2d[0][0]']
#  bda)
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'tf.image.resize_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 56, 56, 128)          0         ['concatenate_1[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 56, 56, 64)           73792     ['dropout_1[0][0]']
#
#  batch_normalization_205 (B  (None, 56, 56, 64)           256       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_205 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  conv2d_207 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_205[0][0]']
#
#  batch_normalization_206 (B  (None, 56, 56, 64)           256       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  activation_206 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  conv2d_transpose_2 (Conv2D  (None, 112, 112, 32)         18464     ['activation_206[0][0]']
#  Transpose)
#
#  tf.image.resize_2 (TFOpLam  (None, 112, 112, 32)         0         ['conv2d_1[0][0]']
#  bda)
#
#  concatenate_2 (Concatenate  (None, 112, 112, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'tf.image.resize_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 112, 112, 64)         0         ['concatenate_2[0][0]']
#
#  conv2d_208 (Conv2D)         (None, 112, 112, 32)         18464     ['dropout_2[0][0]']
#
#  batch_normalization_207 (B  (None, 112, 112, 32)         128       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 112, 112, 32)         0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  conv2d_209 (Conv2D)         (None, 112, 112, 32)         9248      ['activation_207[0][0]']
#
#  batch_normalization_208 (B  (None, 112, 112, 32)         128       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (None, 112, 112, 32)         0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  conv2d_transpose_3 (Conv2D  (None, 224, 224, 16)         4624      ['activation_208[0][0]']
#  Transpose)
#
#  dropout_3 (Dropout)         (None, 224, 224, 16)         0         ['conv2d_transpose_3[0][0]']
#
#  conv2d_210 (Conv2D)         (None, 224, 224, 16)         2320      ['dropout_3[0][0]']
#
#  batch_normalization_209 (B  (None, 224, 224, 16)         64        ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_209 (Activation  (None, 224, 224, 16)         0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  conv2d_211 (Conv2D)         (None, 224, 224, 16)         2320      ['activation_209[0][0]']
#
#  batch_normalization_210 (B  (None, 224, 224, 16)         64        ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 224, 224, 16)         0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  resizing (Resizing)         (None, 256, 256, 16)         0         ['activation_210[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 256, 256, 1)          17        ['resizing[0][0]']
#
# ==================================================================================================
# Total params: 9729057 (37.11 MB)
# Trainable params: 9714593 (37.06 MB)
# Non-trainable params: 14464 (56.50 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/80
# 120/120 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.8457 - f1_score: 0.0361 - binary_io_u: 0.4450
# Epoch 1: val_binary_io_u improved from -inf to 0.48316, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 75s 246ms/step - loss: 0.4543 - accuracy: 0.8457 - f1_score: 0.0361 - binary_io_u: 0.4450 - val_loss: 0.4089 - val_accuracy: 0.9630 - val_f1_score: 0.0067 - val_binary_io_u: 0.4832 - lr: 0.0010
# Epoch 2/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.9694 - f1_score: 0.4639 - binary_io_u: 0.6645
# Epoch 2: val_binary_io_u improved from 0.48316 to 0.64576, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 28s 234ms/step - loss: 0.2327 - accuracy: 0.9694 - f1_score: 0.4639 - binary_io_u: 0.6645 - val_loss: 0.2010 - val_accuracy: 0.9753 - val_f1_score: 0.4072 - val_binary_io_u: 0.6458 - lr: 0.0010
# Epoch 3/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9770 - f1_score: 0.6775 - binary_io_u: 0.7556
# Epoch 3: val_binary_io_u improved from 0.64576 to 0.66546, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 29s 240ms/step - loss: 0.1425 - accuracy: 0.9770 - f1_score: 0.6775 - binary_io_u: 0.7556 - val_loss: 0.1185 - val_accuracy: 0.9772 - val_f1_score: 0.4400 - val_binary_io_u: 0.6655 - lr: 0.0010
# Epoch 4/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9783 - f1_score: 0.7070 - binary_io_u: 0.7715
# Epoch 4: val_binary_io_u improved from 0.66546 to 0.73397, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 29s 242ms/step - loss: 0.0990 - accuracy: 0.9783 - f1_score: 0.7070 - binary_io_u: 0.7715 - val_loss: 0.0803 - val_accuracy: 0.9810 - val_f1_score: 0.5725 - val_binary_io_u: 0.7340 - lr: 0.0010
# Epoch 5/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9798 - f1_score: 0.7242 - binary_io_u: 0.7824
# Epoch 5: val_binary_io_u improved from 0.73397 to 0.76624, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 29s 241ms/step - loss: 0.0792 - accuracy: 0.9798 - f1_score: 0.7242 - binary_io_u: 0.7824 - val_loss: 0.0680 - val_accuracy: 0.9816 - val_f1_score: 0.6484 - val_binary_io_u: 0.7662 - lr: 0.0010
# Epoch 6/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9800 - f1_score: 0.7268 - binary_io_u: 0.7840
# Epoch 6: val_binary_io_u improved from 0.76624 to 0.77116, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 246ms/step - loss: 0.0707 - accuracy: 0.9800 - f1_score: 0.7268 - binary_io_u: 0.7840 - val_loss: 0.0670 - val_accuracy: 0.9811 - val_f1_score: 0.6625 - val_binary_io_u: 0.7712 - lr: 0.0010
# Epoch 7/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9806 - f1_score: 0.7340 - binary_io_u: 0.7899
# Epoch 7: val_binary_io_u did not improve from 0.77116
# 120/120 [==============================] - 27s 225ms/step - loss: 0.0644 - accuracy: 0.9806 - f1_score: 0.7340 - binary_io_u: 0.7899 - val_loss: 0.0593 - val_accuracy: 0.9822 - val_f1_score: 0.6046 - val_binary_io_u: 0.7483 - lr: 0.0010
# Epoch 8/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9810 - f1_score: 0.7435 - binary_io_u: 0.7928
# Epoch 8: val_binary_io_u improved from 0.77116 to 0.77824, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 250ms/step - loss: 0.0610 - accuracy: 0.9810 - f1_score: 0.7435 - binary_io_u: 0.7928 - val_loss: 0.0571 - val_accuracy: 0.9822 - val_f1_score: 0.6733 - val_binary_io_u: 0.7782 - lr: 0.0010
# Epoch 9/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9817 - f1_score: 0.7500 - binary_io_u: 0.7986
# Epoch 9: val_binary_io_u did not improve from 0.77824
# 120/120 [==============================] - 27s 227ms/step - loss: 0.0573 - accuracy: 0.9817 - f1_score: 0.7500 - binary_io_u: 0.7986 - val_loss: 0.0525 - val_accuracy: 0.9835 - val_f1_score: 0.6460 - val_binary_io_u: 0.7741 - lr: 0.0010
# Epoch 10/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9819 - f1_score: 0.7531 - binary_io_u: 0.8001
# Epoch 10: val_binary_io_u did not improve from 0.77824
# 120/120 [==============================] - 27s 226ms/step - loss: 0.0559 - accuracy: 0.9819 - f1_score: 0.7531 - binary_io_u: 0.8001 - val_loss: 0.0521 - val_accuracy: 0.9833 - val_f1_score: 0.6504 - val_binary_io_u: 0.7756 - lr: 0.0010
# Epoch 11/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9822 - f1_score: 0.7562 - binary_io_u: 0.8038
# Epoch 11: val_binary_io_u improved from 0.77824 to 0.78010, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 248ms/step - loss: 0.0540 - accuracy: 0.9822 - f1_score: 0.7562 - binary_io_u: 0.8038 - val_loss: 0.0511 - val_accuracy: 0.9837 - val_f1_score: 0.6623 - val_binary_io_u: 0.7801 - lr: 0.0010
# Epoch 12/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9827 - f1_score: 0.7575 - binary_io_u: 0.8080
# Epoch 12: val_binary_io_u improved from 0.78010 to 0.78928, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 247ms/step - loss: 0.0522 - accuracy: 0.9827 - f1_score: 0.7575 - binary_io_u: 0.8080 - val_loss: 0.0505 - val_accuracy: 0.9830 - val_f1_score: 0.6962 - val_binary_io_u: 0.7893 - lr: 0.0010
# Epoch 13/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9833 - f1_score: 0.7642 - binary_io_u: 0.8135
# Epoch 13: val_binary_io_u did not improve from 0.78928
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0503 - accuracy: 0.9833 - f1_score: 0.7642 - binary_io_u: 0.8135 - val_loss: 0.0526 - val_accuracy: 0.9828 - val_f1_score: 0.6030 - val_binary_io_u: 0.7499 - lr: 0.0010
# Epoch 14/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9837 - f1_score: 0.7773 - binary_io_u: 0.8181
# Epoch 14: val_binary_io_u did not improve from 0.78928
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0488 - accuracy: 0.9837 - f1_score: 0.7773 - binary_io_u: 0.8181 - val_loss: 0.0501 - val_accuracy: 0.9838 - val_f1_score: 0.6519 - val_binary_io_u: 0.7762 - lr: 0.0010
# Epoch 15/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9837 - f1_score: 0.7762 - binary_io_u: 0.8182
# Epoch 15: val_binary_io_u improved from 0.78928 to 0.79877, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 248ms/step - loss: 0.0482 - accuracy: 0.9837 - f1_score: 0.7762 - binary_io_u: 0.8182 - val_loss: 0.0454 - val_accuracy: 0.9846 - val_f1_score: 0.7010 - val_binary_io_u: 0.7988 - lr: 0.0010
# Epoch 16/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9842 - f1_score: 0.7842 - binary_io_u: 0.8229
# Epoch 16: val_binary_io_u did not improve from 0.79877
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0466 - accuracy: 0.9842 - f1_score: 0.7842 - binary_io_u: 0.8229 - val_loss: 0.0489 - val_accuracy: 0.9830 - val_f1_score: 0.7026 - val_binary_io_u: 0.7926 - lr: 0.0010
# Epoch 17/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9843 - f1_score: 0.7809 - binary_io_u: 0.8234
# Epoch 17: val_binary_io_u improved from 0.79877 to 0.79945, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 248ms/step - loss: 0.0462 - accuracy: 0.9843 - f1_score: 0.7809 - binary_io_u: 0.8234 - val_loss: 0.0449 - val_accuracy: 0.9852 - val_f1_score: 0.6997 - val_binary_io_u: 0.7994 - lr: 0.0010
# Epoch 18/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9845 - f1_score: 0.7879 - binary_io_u: 0.8270
# Epoch 18: val_binary_io_u did not improve from 0.79945
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0454 - accuracy: 0.9845 - f1_score: 0.7879 - binary_io_u: 0.8270 - val_loss: 0.0440 - val_accuracy: 0.9852 - val_f1_score: 0.6958 - val_binary_io_u: 0.7954 - lr: 0.0010
# Epoch 19/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9848 - f1_score: 0.7937 - binary_io_u: 0.8291
# Epoch 19: val_binary_io_u did not improve from 0.79945
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0443 - accuracy: 0.9848 - f1_score: 0.7937 - binary_io_u: 0.8291 - val_loss: 0.0506 - val_accuracy: 0.9842 - val_f1_score: 0.6534 - val_binary_io_u: 0.7779 - lr: 0.0010
# Epoch 20/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9848 - f1_score: 0.7903 - binary_io_u: 0.8284
# Epoch 20: val_binary_io_u did not improve from 0.79945
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0445 - accuracy: 0.9848 - f1_score: 0.7903 - binary_io_u: 0.8284 - val_loss: 0.0448 - val_accuracy: 0.9851 - val_f1_score: 0.6869 - val_binary_io_u: 0.7918 - lr: 0.0010
# Epoch 21/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9855 - f1_score: 0.8002 - binary_io_u: 0.8361
# Epoch 21: val_binary_io_u improved from 0.79945 to 0.80231, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 247ms/step - loss: 0.0421 - accuracy: 0.9855 - f1_score: 0.8002 - binary_io_u: 0.8361 - val_loss: 0.0434 - val_accuracy: 0.9853 - val_f1_score: 0.7049 - val_binary_io_u: 0.8023 - lr: 0.0010
# Epoch 22/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9854 - f1_score: 0.8006 - binary_io_u: 0.8348
# Epoch 22: val_binary_io_u improved from 0.80231 to 0.80488, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 253ms/step - loss: 0.0420 - accuracy: 0.9854 - f1_score: 0.8006 - binary_io_u: 0.8348 - val_loss: 0.0422 - val_accuracy: 0.9857 - val_f1_score: 0.7011 - val_binary_io_u: 0.8049 - lr: 0.0010
# Epoch 23/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9857 - f1_score: 0.8010 - binary_io_u: 0.8377
# Epoch 23: val_binary_io_u improved from 0.80488 to 0.81502, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 250ms/step - loss: 0.0409 - accuracy: 0.9857 - f1_score: 0.8010 - binary_io_u: 0.8377 - val_loss: 0.0400 - val_accuracy: 0.9863 - val_f1_score: 0.7195 - val_binary_io_u: 0.8150 - lr: 0.0010
# Epoch 24/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9860 - f1_score: 0.8113 - binary_io_u: 0.8415
# Epoch 24: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 27s 227ms/step - loss: 0.0401 - accuracy: 0.9860 - f1_score: 0.8113 - binary_io_u: 0.8415 - val_loss: 0.0408 - val_accuracy: 0.9860 - val_f1_score: 0.7091 - val_binary_io_u: 0.8067 - lr: 0.0010
# Epoch 25/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9862 - f1_score: 0.8123 - binary_io_u: 0.8435
# Epoch 25: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0390 - accuracy: 0.9862 - f1_score: 0.8123 - binary_io_u: 0.8435 - val_loss: 0.0414 - val_accuracy: 0.9854 - val_f1_score: 0.7253 - val_binary_io_u: 0.8120 - lr: 0.0010
# Epoch 26/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9860 - f1_score: 0.8052 - binary_io_u: 0.8417
# Epoch 26: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0389 - accuracy: 0.9860 - f1_score: 0.8052 - binary_io_u: 0.8417 - val_loss: 0.0403 - val_accuracy: 0.9859 - val_f1_score: 0.7215 - val_binary_io_u: 0.8132 - lr: 0.0010
# Epoch 27/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9865 - f1_score: 0.8123 - binary_io_u: 0.8466
# Epoch 27: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0380 - accuracy: 0.9865 - f1_score: 0.8123 - binary_io_u: 0.8466 - val_loss: 0.0381 - val_accuracy: 0.9866 - val_f1_score: 0.7105 - val_binary_io_u: 0.8125 - lr: 0.0010
# Epoch 28/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9868 - f1_score: 0.8212 - binary_io_u: 0.8497
# Epoch 28: val_binary_io_u did not improve from 0.81502
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0367 - accuracy: 0.9868 - f1_score: 0.8212 - binary_io_u: 0.8497 - val_loss: 0.0419 - val_accuracy: 0.9861 - val_f1_score: 0.7003 - val_binary_io_u: 0.8050 - lr: 0.0010
# Epoch 29/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9871 - f1_score: 0.8222 - binary_io_u: 0.8527
# Epoch 29: val_binary_io_u improved from 0.81502 to 0.82109, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 247ms/step - loss: 0.0358 - accuracy: 0.9871 - f1_score: 0.8222 - binary_io_u: 0.8527 - val_loss: 0.0395 - val_accuracy: 0.9864 - val_f1_score: 0.7422 - val_binary_io_u: 0.8211 - lr: 0.0010
# Epoch 30/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9873 - f1_score: 0.8313 - binary_io_u: 0.8556
# Epoch 30: val_binary_io_u did not improve from 0.82109
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0350 - accuracy: 0.9873 - f1_score: 0.8313 - binary_io_u: 0.8556 - val_loss: 0.0392 - val_accuracy: 0.9860 - val_f1_score: 0.7237 - val_binary_io_u: 0.8146 - lr: 0.0010
# Epoch 31/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9869 - f1_score: 0.8197 - binary_io_u: 0.8512
# Epoch 31: val_binary_io_u did not improve from 0.82109
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0356 - accuracy: 0.9869 - f1_score: 0.8197 - binary_io_u: 0.8512 - val_loss: 0.0381 - val_accuracy: 0.9866 - val_f1_score: 0.7233 - val_binary_io_u: 0.8177 - lr: 0.0010
# Epoch 32/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9873 - f1_score: 0.8244 - binary_io_u: 0.8547
# Epoch 32: val_binary_io_u improved from 0.82109 to 0.82552, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 247ms/step - loss: 0.0344 - accuracy: 0.9873 - f1_score: 0.8244 - binary_io_u: 0.8547 - val_loss: 0.0368 - val_accuracy: 0.9869 - val_f1_score: 0.7456 - val_binary_io_u: 0.8255 - lr: 0.0010
# Epoch 33/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9878 - f1_score: 0.8340 - binary_io_u: 0.8604
# Epoch 33: val_binary_io_u did not improve from 0.82552
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0331 - accuracy: 0.9878 - f1_score: 0.8340 - binary_io_u: 0.8604 - val_loss: 0.0403 - val_accuracy: 0.9859 - val_f1_score: 0.7469 - val_binary_io_u: 0.8231 - lr: 0.0010
# Epoch 34/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9882 - f1_score: 0.8401 - binary_io_u: 0.8645
# Epoch 34: val_binary_io_u did not improve from 0.82552
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0321 - accuracy: 0.9882 - f1_score: 0.8401 - binary_io_u: 0.8645 - val_loss: 0.0372 - val_accuracy: 0.9870 - val_f1_score: 0.7439 - val_binary_io_u: 0.8250 - lr: 0.0010
# Epoch 35/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9879 - f1_score: 0.8348 - binary_io_u: 0.8614
# Epoch 35: val_binary_io_u did not improve from 0.82552
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0325 - accuracy: 0.9879 - f1_score: 0.8348 - binary_io_u: 0.8614 - val_loss: 0.0375 - val_accuracy: 0.9872 - val_f1_score: 0.7353 - val_binary_io_u: 0.8212 - lr: 0.0010
# Epoch 36/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9882 - f1_score: 0.8411 - binary_io_u: 0.8650
# Epoch 36: val_binary_io_u did not improve from 0.82552
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0314 - accuracy: 0.9882 - f1_score: 0.8411 - binary_io_u: 0.8650 - val_loss: 0.0408 - val_accuracy: 0.9858 - val_f1_score: 0.6770 - val_binary_io_u: 0.7956 - lr: 0.0010
# Epoch 37/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9884 - f1_score: 0.8405 - binary_io_u: 0.8677
# Epoch 37: val_binary_io_u did not improve from 0.82552
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0305 - accuracy: 0.9884 - f1_score: 0.8405 - binary_io_u: 0.8677 - val_loss: 0.0395 - val_accuracy: 0.9869 - val_f1_score: 0.7452 - val_binary_io_u: 0.8244 - lr: 0.0010
# Epoch 38/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9891 - f1_score: 0.8542 - binary_io_u: 0.8745
# Epoch 38: val_binary_io_u improved from 0.82552 to 0.83511, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 247ms/step - loss: 0.0284 - accuracy: 0.9891 - f1_score: 0.8542 - binary_io_u: 0.8745 - val_loss: 0.0346 - val_accuracy: 0.9877 - val_f1_score: 0.7622 - val_binary_io_u: 0.8351 - lr: 5.0000e-04
# Epoch 39/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9894 - f1_score: 0.8554 - binary_io_u: 0.8780
# Epoch 39: val_binary_io_u did not improve from 0.83511
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0276 - accuracy: 0.9894 - f1_score: 0.8554 - binary_io_u: 0.8780 - val_loss: 0.0342 - val_accuracy: 0.9881 - val_f1_score: 0.7604 - val_binary_io_u: 0.8348 - lr: 5.0000e-04
# Epoch 40/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9896 - f1_score: 0.8616 - binary_io_u: 0.8805
# Epoch 40: val_binary_io_u improved from 0.83511 to 0.83562, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 249ms/step - loss: 0.0268 - accuracy: 0.9896 - f1_score: 0.8616 - binary_io_u: 0.8805 - val_loss: 0.0335 - val_accuracy: 0.9880 - val_f1_score: 0.7586 - val_binary_io_u: 0.8356 - lr: 5.0000e-04
# Epoch 41/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9897 - f1_score: 0.8618 - binary_io_u: 0.8818
# Epoch 41: val_binary_io_u did not improve from 0.83562
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0264 - accuracy: 0.9897 - f1_score: 0.8618 - binary_io_u: 0.8818 - val_loss: 0.0339 - val_accuracy: 0.9879 - val_f1_score: 0.7459 - val_binary_io_u: 0.8296 - lr: 5.0000e-04
# Epoch 42/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9900 - f1_score: 0.8624 - binary_io_u: 0.8842
# Epoch 42: val_binary_io_u did not improve from 0.83562
# 120/120 [==============================] - 27s 229ms/step - loss: 0.0259 - accuracy: 0.9900 - f1_score: 0.8624 - binary_io_u: 0.8842 - val_loss: 0.0356 - val_accuracy: 0.9879 - val_f1_score: 0.7507 - val_binary_io_u: 0.8294 - lr: 5.0000e-04
# Epoch 43/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9900 - f1_score: 0.8678 - binary_io_u: 0.8846
# Epoch 43: val_binary_io_u improved from 0.83562 to 0.83791, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 246ms/step - loss: 0.0257 - accuracy: 0.9900 - f1_score: 0.8678 - binary_io_u: 0.8846 - val_loss: 0.0333 - val_accuracy: 0.9883 - val_f1_score: 0.7661 - val_binary_io_u: 0.8379 - lr: 5.0000e-04
# Epoch 44/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9900 - f1_score: 0.8639 - binary_io_u: 0.8850
# Epoch 44: val_binary_io_u improved from 0.83791 to 0.83818, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 252ms/step - loss: 0.0256 - accuracy: 0.9900 - f1_score: 0.8639 - binary_io_u: 0.8850 - val_loss: 0.0347 - val_accuracy: 0.9883 - val_f1_score: 0.7681 - val_binary_io_u: 0.8382 - lr: 5.0000e-04
# Epoch 45/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9902 - f1_score: 0.8699 - binary_io_u: 0.8866
# Epoch 45: val_binary_io_u did not improve from 0.83818
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0250 - accuracy: 0.9902 - f1_score: 0.8699 - binary_io_u: 0.8866 - val_loss: 0.0341 - val_accuracy: 0.9882 - val_f1_score: 0.7541 - val_binary_io_u: 0.8328 - lr: 5.0000e-04
# Epoch 46/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9903 - f1_score: 0.8701 - binary_io_u: 0.8877
# Epoch 46: val_binary_io_u did not improve from 0.83818
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0247 - accuracy: 0.9903 - f1_score: 0.8701 - binary_io_u: 0.8877 - val_loss: 0.0357 - val_accuracy: 0.9880 - val_f1_score: 0.7567 - val_binary_io_u: 0.8323 - lr: 5.0000e-04
# Epoch 47/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9905 - f1_score: 0.8713 - binary_io_u: 0.8897
# Epoch 47: val_binary_io_u improved from 0.83818 to 0.84171, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 30s 247ms/step - loss: 0.0243 - accuracy: 0.9905 - f1_score: 0.8713 - binary_io_u: 0.8897 - val_loss: 0.0332 - val_accuracy: 0.9884 - val_f1_score: 0.7754 - val_binary_io_u: 0.8417 - lr: 5.0000e-04
# Epoch 48/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9905 - f1_score: 0.8737 - binary_io_u: 0.8903
# Epoch 48: val_binary_io_u did not improve from 0.84171
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0240 - accuracy: 0.9905 - f1_score: 0.8737 - binary_io_u: 0.8903 - val_loss: 0.0379 - val_accuracy: 0.9877 - val_f1_score: 0.7452 - val_binary_io_u: 0.8281 - lr: 5.0000e-04
# Epoch 49/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9908 - f1_score: 0.8761 - binary_io_u: 0.8939
# Epoch 49: val_binary_io_u did not improve from 0.84171
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0232 - accuracy: 0.9908 - f1_score: 0.8761 - binary_io_u: 0.8939 - val_loss: 0.0333 - val_accuracy: 0.9884 - val_f1_score: 0.7618 - val_binary_io_u: 0.8373 - lr: 2.5000e-04
# Epoch 50/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9910 - f1_score: 0.8807 - binary_io_u: 0.8960
# Epoch 50: val_binary_io_u did not improve from 0.84171
# 120/120 [==============================] - 27s 227ms/step - loss: 0.0226 - accuracy: 0.9910 - f1_score: 0.8807 - binary_io_u: 0.8960 - val_loss: 0.0336 - val_accuracy: 0.9885 - val_f1_score: 0.7667 - val_binary_io_u: 0.8393 - lr: 2.5000e-04
# Epoch 51/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9912 - f1_score: 0.8811 - binary_io_u: 0.8976
# Epoch 51: val_binary_io_u did not improve from 0.84171
# 120/120 [==============================] - 27s 227ms/step - loss: 0.0223 - accuracy: 0.9912 - f1_score: 0.8811 - binary_io_u: 0.8976 - val_loss: 0.0347 - val_accuracy: 0.9883 - val_f1_score: 0.7628 - val_binary_io_u: 0.8362 - lr: 2.5000e-04
# Epoch 52/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9911 - f1_score: 0.8833 - binary_io_u: 0.8972
# Epoch 52: val_binary_io_u improved from 0.84171 to 0.84301, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Inception_resnetV2_Unet_v2/saved_models/best_Inception_resnetV2_Unet_v2.h5
# 120/120 [==============================] - 29s 246ms/step - loss: 0.0223 - accuracy: 0.9911 - f1_score: 0.8833 - binary_io_u: 0.8972 - val_loss: 0.0333 - val_accuracy: 0.9885 - val_f1_score: 0.7747 - val_binary_io_u: 0.8430 - lr: 2.5000e-04
# Epoch 53/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9911 - f1_score: 0.8796 - binary_io_u: 0.8971
# Epoch 53: val_binary_io_u did not improve from 0.84301
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0223 - accuracy: 0.9911 - f1_score: 0.8796 - binary_io_u: 0.8971 - val_loss: 0.0340 - val_accuracy: 0.9884 - val_f1_score: 0.7651 - val_binary_io_u: 0.8389 - lr: 2.5000e-04
# Epoch 54/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9914 - f1_score: 0.8845 - binary_io_u: 0.9005
# Epoch 54: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0215 - accuracy: 0.9914 - f1_score: 0.8845 - binary_io_u: 0.9005 - val_loss: 0.0340 - val_accuracy: 0.9885 - val_f1_score: 0.7709 - val_binary_io_u: 0.8409 - lr: 1.2500e-04
# Epoch 55/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9915 - f1_score: 0.8847 - binary_io_u: 0.9010
# Epoch 55: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0213 - accuracy: 0.9915 - f1_score: 0.8847 - binary_io_u: 0.9010 - val_loss: 0.0339 - val_accuracy: 0.9885 - val_f1_score: 0.7764 - val_binary_io_u: 0.8429 - lr: 1.2500e-04
# Epoch 56/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9916 - f1_score: 0.8865 - binary_io_u: 0.9020
# Epoch 56: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 227ms/step - loss: 0.0211 - accuracy: 0.9916 - f1_score: 0.8865 - binary_io_u: 0.9020 - val_loss: 0.0334 - val_accuracy: 0.9885 - val_f1_score: 0.7713 - val_binary_io_u: 0.8412 - lr: 1.2500e-04
# Epoch 57/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9916 - f1_score: 0.8878 - binary_io_u: 0.9023
# Epoch 57: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0211 - accuracy: 0.9916 - f1_score: 0.8878 - binary_io_u: 0.9023 - val_loss: 0.0343 - val_accuracy: 0.9885 - val_f1_score: 0.7716 - val_binary_io_u: 0.8410 - lr: 1.2500e-04
# Epoch 58/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9916 - f1_score: 0.8892 - binary_io_u: 0.9021
# Epoch 58: val_binary_io_u did not improve from 0.84301
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0210 - accuracy: 0.9916 - f1_score: 0.8892 - binary_io_u: 0.9021 - val_loss: 0.0344 - val_accuracy: 0.9885 - val_f1_score: 0.7726 - val_binary_io_u: 0.8412 - lr: 1.2500e-04
# Epoch 59/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9917 - f1_score: 0.8916 - binary_io_u: 0.9033
# Epoch 59: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0208 - accuracy: 0.9917 - f1_score: 0.8916 - binary_io_u: 0.9033 - val_loss: 0.0335 - val_accuracy: 0.9885 - val_f1_score: 0.7756 - val_binary_io_u: 0.8426 - lr: 6.2500e-05
# Epoch 60/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9918 - f1_score: 0.8921 - binary_io_u: 0.9044
# Epoch 60: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0205 - accuracy: 0.9918 - f1_score: 0.8921 - binary_io_u: 0.9044 - val_loss: 0.0342 - val_accuracy: 0.9885 - val_f1_score: 0.7728 - val_binary_io_u: 0.8417 - lr: 6.2500e-05
# Epoch 61/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9918 - f1_score: 0.8898 - binary_io_u: 0.9049
# Epoch 61: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0204 - accuracy: 0.9918 - f1_score: 0.8898 - binary_io_u: 0.9049 - val_loss: 0.0341 - val_accuracy: 0.9885 - val_f1_score: 0.7724 - val_binary_io_u: 0.8412 - lr: 6.2500e-05
# Epoch 62/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9918 - f1_score: 0.8933 - binary_io_u: 0.9048
# Epoch 62: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0204 - accuracy: 0.9918 - f1_score: 0.8933 - binary_io_u: 0.9048 - val_loss: 0.0341 - val_accuracy: 0.9885 - val_f1_score: 0.7729 - val_binary_io_u: 0.8413 - lr: 6.2500e-05
# Epoch 63/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9918 - f1_score: 0.8896 - binary_io_u: 0.9045
# Epoch 63: val_binary_io_u did not improve from 0.84301
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0205 - accuracy: 0.9918 - f1_score: 0.8896 - binary_io_u: 0.9045 - val_loss: 0.0340 - val_accuracy: 0.9885 - val_f1_score: 0.7743 - val_binary_io_u: 0.8423 - lr: 6.2500e-05
# Epoch 64/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9919 - f1_score: 0.8926 - binary_io_u: 0.9052
# Epoch 64: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0203 - accuracy: 0.9919 - f1_score: 0.8926 - binary_io_u: 0.9052 - val_loss: 0.0342 - val_accuracy: 0.9885 - val_f1_score: 0.7757 - val_binary_io_u: 0.8428 - lr: 3.1250e-05
# Epoch 65/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9919 - f1_score: 0.8928 - binary_io_u: 0.9059
# Epoch 65: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0201 - accuracy: 0.9919 - f1_score: 0.8928 - binary_io_u: 0.9059 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7725 - val_binary_io_u: 0.8412 - lr: 3.1250e-05
# Epoch 66/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9919 - f1_score: 0.8931 - binary_io_u: 0.9054
# Epoch 66: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0202 - accuracy: 0.9919 - f1_score: 0.8931 - binary_io_u: 0.9054 - val_loss: 0.0341 - val_accuracy: 0.9885 - val_f1_score: 0.7735 - val_binary_io_u: 0.8420 - lr: 3.1250e-05
# Epoch 67/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9919 - f1_score: 0.8940 - binary_io_u: 0.9060
# Epoch 67: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0201 - accuracy: 0.9919 - f1_score: 0.8940 - binary_io_u: 0.9060 - val_loss: 0.0341 - val_accuracy: 0.9885 - val_f1_score: 0.7752 - val_binary_io_u: 0.8427 - lr: 3.1250e-05
# Epoch 68/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9920 - f1_score: 0.8934 - binary_io_u: 0.9064
# Epoch 68: val_binary_io_u did not improve from 0.84301
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0200 - accuracy: 0.9920 - f1_score: 0.8934 - binary_io_u: 0.9064 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7747 - val_binary_io_u: 0.8423 - lr: 3.1250e-05
# Epoch 69/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9920 - f1_score: 0.8941 - binary_io_u: 0.9066
# Epoch 69: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0200 - accuracy: 0.9920 - f1_score: 0.8941 - binary_io_u: 0.9066 - val_loss: 0.0346 - val_accuracy: 0.9885 - val_f1_score: 0.7726 - val_binary_io_u: 0.8414 - lr: 1.5625e-05
# Epoch 70/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8964 - binary_io_u: 0.9067
# Epoch 70: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8964 - binary_io_u: 0.9067 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7725 - val_binary_io_u: 0.8414 - lr: 1.5625e-05
# Epoch 71/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8932 - binary_io_u: 0.9066
# Epoch 71: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8932 - binary_io_u: 0.9066 - val_loss: 0.0346 - val_accuracy: 0.9885 - val_f1_score: 0.7736 - val_binary_io_u: 0.8418 - lr: 1.5625e-05
# Epoch 72/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8947 - binary_io_u: 0.9071
# Epoch 72: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8947 - binary_io_u: 0.9071 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7732 - val_binary_io_u: 0.8416 - lr: 1.5625e-05
# Epoch 73/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8916 - binary_io_u: 0.9069
# Epoch 73: val_binary_io_u did not improve from 0.84301
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8916 - binary_io_u: 0.9069 - val_loss: 0.0346 - val_accuracy: 0.9885 - val_f1_score: 0.7725 - val_binary_io_u: 0.8413 - lr: 1.5625e-05
# Epoch 74/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8956 - binary_io_u: 0.9068
# Epoch 74: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8956 - binary_io_u: 0.9068 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7736 - val_binary_io_u: 0.8418 - lr: 7.8125e-06
# Epoch 75/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9920 - f1_score: 0.8950 - binary_io_u: 0.9073
# Epoch 75: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0198 - accuracy: 0.9920 - f1_score: 0.8950 - binary_io_u: 0.9073 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7738 - val_binary_io_u: 0.8418 - lr: 7.8125e-06
# Epoch 76/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8944 - binary_io_u: 0.9071
# Epoch 76: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8944 - binary_io_u: 0.9071 - val_loss: 0.0346 - val_accuracy: 0.9885 - val_f1_score: 0.7731 - val_binary_io_u: 0.8416 - lr: 7.8125e-06
# Epoch 77/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8932 - binary_io_u: 0.9069
# Epoch 77: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 229ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8932 - binary_io_u: 0.9069 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7725 - val_binary_io_u: 0.8413 - lr: 7.8125e-06
# Epoch 78/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8938 - binary_io_u: 0.9068
# Epoch 78: val_binary_io_u did not improve from 0.84301
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 120/120 [==============================] - 27s 229ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8938 - binary_io_u: 0.9068 - val_loss: 0.0347 - val_accuracy: 0.9885 - val_f1_score: 0.7722 - val_binary_io_u: 0.8412 - lr: 7.8125e-06
# Epoch 79/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8932 - binary_io_u: 0.9068
# Epoch 79: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8932 - binary_io_u: 0.9068 - val_loss: 0.0346 - val_accuracy: 0.9885 - val_f1_score: 0.7729 - val_binary_io_u: 0.8416 - lr: 3.9063e-06
# Epoch 80/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8955 - binary_io_u: 0.9071
# Epoch 80: val_binary_io_u did not improve from 0.84301
# 120/120 [==============================] - 27s 228ms/step - loss: 0.0199 - accuracy: 0.9920 - f1_score: 0.8955 - binary_io_u: 0.9071 - val_loss: 0.0345 - val_accuracy: 0.9885 - val_f1_score: 0.7739 - val_binary_io_u: 0.8419 - lr: 3.9063e-06

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 6s 6s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 18]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.0350 - accuracy: 0.9895 - f1_score: 0.8538 - binary_io_u: 0.8670

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#                    Model Name      Loss  Accuracy  Precision    Recall  \
# 0  Inception_resnetV2_Unet_v2  0.035011  0.989472   0.885433  0.824364
#
#    F1-Score       IoU
# 0  0.853808  0.843856

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
