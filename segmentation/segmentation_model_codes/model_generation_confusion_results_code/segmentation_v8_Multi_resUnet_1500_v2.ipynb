# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')


from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Multi_resUnet_1500_v2'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
#PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
#DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 80#100

TOTAL_DATA = 1500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 5
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 19124.42it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 1500 original images into x_train
# Loaded 1500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### Multi-resUnet---works after 10 epochs...batch size was 10

# %%
def conv2d_bn(x, filters, num_row, num_col, padding='same', strides=(1, 1), activation='relu', name=None):
    '''
    2D Convolutional layers

    Arguments:
        x {keras layer} -- input layer
        filters {int} -- number of filters
        num_row {int} -- number of rows in filters
        num_col {int} -- number of columns in filters

    Keyword Arguments:
        padding {str} -- mode of padding (default: {'same'})
        strides {tuple} -- stride of convolution operation (default: {(1, 1)})
        activation {str} -- activation function (default: {'relu'})
        name {str} -- name of the layer (default: {None})

    Returns:
        [keras layer] -- [output layer]
    '''

    x = Conv2D(filters, (num_row, num_col), strides=strides, padding=padding, use_bias=False)(x)
    x = BatchNormalization(axis=3, scale=False)(x)

    if(activation == None):
        return x

    x = Activation(activation, name=name)(x)

    return x


def trans_conv2d_bn(x, filters, num_row, num_col, padding='same', strides=(2, 2), name=None):
    '''
    2D Transposed Convolutional layers

    Arguments:
        x {keras layer} -- input layer
        filters {int} -- number of filters
        num_row {int} -- number of rows in filters
        num_col {int} -- number of columns in filters

    Keyword Arguments:
        padding {str} -- mode of padding (default: {'same'})
        strides {tuple} -- stride of convolution operation (default: {(2, 2)})
        name {str} -- name of the layer (default: {None})

    Returns:
        [keras layer] -- [output layer]
    '''

    x = Conv2DTranspose(filters, (num_row, num_col), strides=strides, padding=padding)(x)
    x = BatchNormalization(axis=3, scale=False)(x)

    return x


def MultiResBlock(U, inp, alpha = 1.67):
    '''
    MultiRes Block

    Arguments:
        U {int} -- Number of filters in a corrsponding UNet stage
        inp {keras layer} -- input layer

    Returns:
        [keras layer] -- [output layer]
    '''

    W = alpha * U

    shortcut = inp

    shortcut = conv2d_bn(shortcut, int(W*0.167) + int(W*0.333) + int(W*0.5), 1, 1, activation=None, padding='same')

    conv3x3 = conv2d_bn(inp, int(W*0.167), 3, 3, activation='relu', padding='same')
    conv5x5 = conv2d_bn(conv3x3, int(W*0.333), 3, 3, activation='relu', padding='same')
    conv7x7 = conv2d_bn(conv5x5, int(W*0.5), 3, 3,  activation='relu', padding='same')

    out = Concatenate(axis=3)([conv3x3, conv5x5, conv7x7])
    out = BatchNormalization(axis=3)(out)

    out = add([shortcut, out])
    out = Activation('relu')(out)
    out = BatchNormalization(axis=3)(out)

    return out


def ResPath(filters, length, inp):
    '''
    ResPath

    Arguments:
        filters {int} -- [description]
        length {int} -- length of ResPath
        inp {keras layer} -- input layer

    Returns:
        [keras layer] -- [output layer]
    '''


    shortcut = inp
    shortcut = conv2d_bn(shortcut, filters, 1, 1, activation=None, padding='same')

    out = conv2d_bn(inp, filters, 3, 3, activation='relu', padding='same')

    out = add([shortcut, out])
    out = Activation('relu')(out)
    out = BatchNormalization(axis=3)(out)

    for i in range(length-1):

        shortcut = out
        shortcut = conv2d_bn(shortcut, filters, 1, 1,
                             activation=None, padding='same')

        out = conv2d_bn(out, filters, 3, 3, activation='relu', padding='same')

        out = add([shortcut, out])
        out = Activation('relu')(out)
        out = BatchNormalization(axis=3)(out)

    return out


def get_multires_unet():
    '''
    MultiResUNet

    Arguments:
        height {int} -- height of image
        width {int} -- width of image
        n_channels {int} -- number of channels in image

    Returns:
        [keras model] -- MultiResUNet model
    Source original author: https://github.com/nibtehaz/MultiResUNet/blob/master/tensorflow/MultiResUNet.py
    '''


    inputs = Input(MODEL_INPUT_SIZE)

    mresblock1 = MultiResBlock(32, inputs)
    pool1 = MaxPooling2D(pool_size=(2, 2))(mresblock1)
    mresblock1 = ResPath(32, 4, mresblock1)

    mresblock2 = MultiResBlock(32*2, pool1)
    pool2 = MaxPooling2D(pool_size=(2, 2))(mresblock2)
    mresblock2 = ResPath(32*2, 3, mresblock2)

    mresblock3 = MultiResBlock(32*4, pool2)
    pool3 = MaxPooling2D(pool_size=(2, 2))(mresblock3)
    mresblock3 = ResPath(32*4, 2, mresblock3)

    mresblock4 = MultiResBlock(32*8, pool3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(mresblock4)
    mresblock4 = ResPath(32*8, 1, mresblock4)

    mresblock5 = MultiResBlock(32*16, pool4)

    up6 = Concatenate(axis=3)([Conv2DTranspose(32*8, (2, 2), strides=(2, 2), padding='same')(mresblock5), mresblock4])
    mresblock6 = MultiResBlock(32*8, up6)

    up7 = Concatenate(axis=3)([Conv2DTranspose(32*4, (2, 2), strides=(2, 2), padding='same')(mresblock6), mresblock3])
    mresblock7 = MultiResBlock(32*4, up7)

    up8 = Concatenate(axis=3)([Conv2DTranspose(32*2, (2, 2), strides=(2, 2), padding='same')(mresblock7), mresblock2])
    mresblock8 = MultiResBlock(32*2, up8)

    up9 = Concatenate(axis=3)([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(mresblock8), mresblock1])
    mresblock9 = MultiResBlock(32, up9)

    conv10 = conv2d_bn(mresblock9, 1, 1, 1, activation='sigmoid')

    model = Model(inputs=[inputs], outputs=[conv10], name="multi-res-Unet")

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
model = get_multires_unet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Model: "multi-res-Unet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 8)          216       ['input_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 8)          24        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 256, 256, 8)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 17)         1224      ['activation[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 17)         51        ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 17)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 26)         3978      ['activation_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 256, 256, 26)         78        ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 256, 256, 26)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d (Conv2D)             (None, 256, 256, 51)         153       ['input_1[0][0]']
#
#  concatenate (Concatenate)   (None, 256, 256, 51)         0         ['activation[0][0]',
#                                                                      'activation_1[0][0]',
#                                                                      'activation_2[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 51)         153       ['conv2d[0][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 256, 256, 51)         204       ['concatenate[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 256, 256, 51)         0         ['batch_normalization[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 256, 256, 51)         0         ['add[0][0]']
#
#  batch_normalization_5 (Bat  (None, 256, 256, 51)         204       ['activation_3[0][0]']
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 51)         0         ['batch_normalization_5[0][0]'
#  D)                                                                 ]
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 17)         7803      ['max_pooling2d[0][0]']
#
#  batch_normalization_19 (Ba  (None, 128, 128, 17)         51        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 128, 128, 17)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 35)         5355      ['activation_12[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 128, 35)         105       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 128, 128, 35)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 53)         16695     ['activation_13[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 53)         159       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 128, 128, 53)         0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 128, 128, 105)        5355      ['max_pooling2d[0][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 128, 105)        0         ['activation_12[0][0]',
#  )                                                                   'activation_13[0][0]',
#                                                                      'activation_14[0][0]']
#
#  batch_normalization_18 (Ba  (None, 128, 128, 105)        315       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 128, 128, 105)        420       ['concatenate_1[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 128, 128, 105)        0         ['batch_normalization_18[0][0]
#                                                                     ',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_15 (Activation)  (None, 128, 128, 105)        0         ['add_5[0][0]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 105)        420       ['activation_15[0][0]']
#  tchNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 105)          0         ['batch_normalization_23[0][0]
#  g2D)                                                               ']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 35)           33075     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_34 (Ba  (None, 64, 64, 35)           105       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 64, 64, 35)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 71)           22365     ['activation_22[0][0]']
#
#  batch_normalization_35 (Ba  (None, 64, 64, 71)           213       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 71)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 106)          67734     ['activation_23[0][0]']
#
#  batch_normalization_36 (Ba  (None, 64, 64, 106)          318       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 64, 64, 106)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 212)          22260     ['max_pooling2d_1[0][0]']
#
#  concatenate_2 (Concatenate  (None, 64, 64, 212)          0         ['activation_22[0][0]',
#  )                                                                   'activation_23[0][0]',
#                                                                      'activation_24[0][0]']
#
#  batch_normalization_33 (Ba  (None, 64, 64, 212)          636       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 64, 64, 212)          848       ['concatenate_2[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 64, 64, 212)          0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 64, 64, 212)          0         ['add_9[0][0]']
#
#  batch_normalization_38 (Ba  (None, 64, 64, 212)          848       ['activation_25[0][0]']
#  tchNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 212)          0         ['batch_normalization_38[0][0]
#  g2D)                                                               ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 71)           135468    ['max_pooling2d_2[0][0]']
#
#  batch_normalization_46 (Ba  (None, 32, 32, 71)           213       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 32, 32, 71)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 142)          90738     ['activation_30[0][0]']
#
#  batch_normalization_47 (Ba  (None, 32, 32, 142)          426       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 32, 32, 142)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 213)          272214    ['activation_31[0][0]']
#
#  batch_normalization_48 (Ba  (None, 32, 32, 213)          639       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 213)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 426)          90312     ['max_pooling2d_2[0][0]']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 426)          0         ['activation_30[0][0]',
#  )                                                                   'activation_31[0][0]',
#                                                                      'activation_32[0][0]']
#
#  batch_normalization_45 (Ba  (None, 32, 32, 426)          1278      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 32, 32, 426)          1704      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 32, 32, 426)          0         ['batch_normalization_45[0][0]
#                                                                     ',
#                                                                      'batch_normalization_49[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 32, 32, 426)          0         ['add_12[0][0]']
#
#  batch_normalization_50 (Ba  (None, 32, 32, 426)          1704      ['activation_33[0][0]']
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 426)          0         ['batch_normalization_50[0][0]
#  g2D)                                                               ']
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 142)          544428    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_55 (Ba  (None, 16, 16, 142)          426       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 16, 16, 142)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 284)          362952    ['activation_36[0][0]']
#
#  batch_normalization_56 (Ba  (None, 16, 16, 284)          852       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 16, 16, 284)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 427)          1091412   ['activation_37[0][0]']
#
#  batch_normalization_57 (Ba  (None, 16, 16, 427)          1281      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 16, 16, 427)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 853)          363378    ['max_pooling2d_3[0][0]']
#
#  concatenate_4 (Concatenate  (None, 16, 16, 853)          0         ['activation_36[0][0]',
#  )                                                                   'activation_37[0][0]',
#                                                                      'activation_38[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 256)          981504    ['batch_normalization_50[0][0]
#                                                                     ']
#
#  batch_normalization_54 (Ba  (None, 16, 16, 853)          2559      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 16, 16, 853)          3412      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  conv2d_34 (Conv2D)          (None, 32, 32, 256)          109056    ['batch_normalization_50[0][0]
#                                                                     ']
#
#  batch_normalization_52 (Ba  (None, 32, 32, 256)          768       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 16, 16, 853)          0         ['batch_normalization_54[0][0]
#                                                                     ',
#                                                                      'batch_normalization_58[0][0]
#                                                                     ']
#
#  batch_normalization_51 (Ba  (None, 32, 32, 256)          768       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 16, 16, 853)          0         ['add_14[0][0]']
#
#  add_13 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_51[0][0]
#                                                                     ',
#                                                                      'activation_34[0][0]']
#
#  batch_normalization_59 (Ba  (None, 16, 16, 853)          3412      ['activation_39[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 32, 32, 256)          0         ['add_13[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          873728    ['batch_normalization_59[0][0]
#  anspose)                                                           ']
#
#  batch_normalization_53 (Ba  (None, 32, 32, 256)          1024      ['activation_35[0][0]']
#  tchNormalization)
#
#  concatenate_5 (Concatenate  (None, 32, 32, 512)          0         ['conv2d_transpose[0][0]',
#  )                                                                   'batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 71)           327168    ['concatenate_5[0][0]']
#
#  batch_normalization_61 (Ba  (None, 32, 32, 71)           213       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 32, 32, 71)           0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 142)          90738     ['activation_40[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 128)          244224    ['batch_normalization_38[0][0]
#                                                                     ']
#
#  batch_normalization_62 (Ba  (None, 32, 32, 142)          426       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 128)          27136     ['batch_normalization_38[0][0]
#                                                                     ']
#
#  batch_normalization_40 (Ba  (None, 64, 64, 128)          384       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 32, 32, 142)          0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  batch_normalization_39 (Ba  (None, 64, 64, 128)          384       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 213)          272214    ['activation_41[0][0]']
#
#  add_10 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_39[0][0]
#                                                                     ',
#                                                                      'activation_26[0][0]']
#
#  batch_normalization_63 (Ba  (None, 32, 32, 213)          639       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 64, 64, 128)          0         ['add_10[0][0]']
#
#  activation_42 (Activation)  (None, 32, 32, 213)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  batch_normalization_41 (Ba  (None, 64, 64, 128)          512       ['activation_27[0][0]']
#  tchNormalization)
#
#  conv2d_40 (Conv2D)          (None, 32, 32, 426)          218112    ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 426)          0         ['activation_40[0][0]',
#  )                                                                   'activation_41[0][0]',
#                                                                      'activation_42[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 128)          147456    ['batch_normalization_41[0][0]
#                                                                     ']
#
#  batch_normalization_60 (Ba  (None, 32, 32, 426)          1278      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_64 (Ba  (None, 32, 32, 426)          1704      ['concatenate_6[0][0]']
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 128)          16384     ['batch_normalization_41[0][0]
#                                                                     ']
#
#  batch_normalization_43 (Ba  (None, 64, 64, 128)          384       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 32, 32, 426)          0         ['batch_normalization_60[0][0]
#                                                                     ',
#                                                                      'batch_normalization_64[0][0]
#                                                                     ']
#
#  batch_normalization_42 (Ba  (None, 64, 64, 128)          384       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 32, 32, 426)          0         ['add_15[0][0]']
#
#  add_11 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_42[0][0]
#                                                                     ',
#                                                                      'activation_28[0][0]']
#
#  batch_normalization_65 (Ba  (None, 32, 32, 426)          1704      ['activation_43[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 64, 64, 128)          0         ['add_11[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 64)         60480     ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          218240    ['batch_normalization_65[0][0]
#  Transpose)                                                         ']
#
#  batch_normalization_44 (Ba  (None, 64, 64, 128)          512       ['activation_29[0][0]']
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)         6720      ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_25 (Ba  (None, 128, 128, 64)         192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  concatenate_7 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'batch_normalization_44[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 64)         192       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 64, 64, 35)           80640     ['concatenate_7[0][0]']
#
#  add_6 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'activation_16[0][0]']
#
#  batch_normalization_67 (Ba  (None, 64, 64, 35)           105       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 128, 128, 64)         0         ['add_6[0][0]']
#
#  activation_44 (Activation)  (None, 64, 64, 35)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  batch_normalization_26 (Ba  (None, 128, 128, 64)         256       ['activation_17[0][0]']
#  tchNormalization)
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 71)           22365     ['activation_44[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 64)         36864     ['batch_normalization_26[0][0]
#                                                                     ']
#
#  batch_normalization_68 (Ba  (None, 64, 64, 71)           213       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 64)         4096      ['batch_normalization_26[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 128, 128, 64)         192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 64, 64, 71)           0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  batch_normalization_27 (Ba  (None, 128, 128, 64)         192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 106)          67734     ['activation_45[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'activation_18[0][0]']
#
#  batch_normalization_69 (Ba  (None, 64, 64, 106)          318       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 128, 128, 64)         0         ['add_7[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 32)         14688     ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_46 (Activation)  (None, 64, 64, 106)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  batch_normalization_29 (Ba  (None, 128, 128, 64)         256       ['activation_19[0][0]']
#  tchNormalization)
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 32)         1632      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 256, 256, 32)         96        ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 212)          54272     ['concatenate_7[0][0]']
#
#  concatenate_8 (Concatenate  (None, 64, 64, 212)          0         ['activation_44[0][0]',
#  )                                                                   'activation_45[0][0]',
#                                                                      'activation_46[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 128, 128, 64)         36864     ['batch_normalization_29[0][0]
#                                                                     ']
#
#  batch_normalization_6 (Bat  (None, 256, 256, 32)         96        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_66 (Ba  (None, 64, 64, 212)          636       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_70 (Ba  (None, 64, 64, 212)          848       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 64)         4096      ['batch_normalization_29[0][0]
#                                                                     ']
#
#  batch_normalization_31 (Ba  (None, 128, 128, 64)         192       ['conv2d_21[0][0]']
# ...
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 256, 256, 32)         0         ['add_2[0][0]']
#
#  activation_48 (Activation)  (None, 128, 128, 17)         0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  batch_normalization_11 (Ba  (None, 256, 256, 32)         128       ['activation_7[0][0]']
#  tchNormalization)
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 35)         5355      ['activation_48[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)         9216      ['batch_normalization_11[0][0]
#                                                                     ']
#
#  batch_normalization_74 (Ba  (None, 128, 128, 35)         105       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)         1024      ['batch_normalization_11[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 256, 256, 32)         96        ['conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 128, 128, 35)         0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  batch_normalization_12 (Ba  (None, 256, 256, 32)         96        ['conv2d_8[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 53)         16695     ['activation_49[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'activation_8[0][0]']
#
#  batch_normalization_75 (Ba  (None, 128, 128, 53)         159       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 256, 256, 32)         0         ['add_3[0][0]']
#
#  activation_50 (Activation)  (None, 128, 128, 53)         0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  batch_normalization_14 (Ba  (None, 256, 256, 32)         128       ['activation_9[0][0]']
#  tchNormalization)
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 105)        13440     ['concatenate_9[0][0]']
#
#  concatenate_10 (Concatenat  (None, 128, 128, 105)        0         ['activation_48[0][0]',
#  e)                                                                  'activation_49[0][0]',
#                                                                      'activation_50[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 32)         9216      ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_72 (Ba  (None, 128, 128, 105)        315       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_76 (Ba  (None, 128, 128, 105)        420       ['concatenate_10[0][0]']
#  tchNormalization)
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 32)         1024      ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 256, 256, 32)         96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 128, 128, 105)        0         ['batch_normalization_72[0][0]
#                                                                     ',
#                                                                      'batch_normalization_76[0][0]
#                                                                     ']
#
#  batch_normalization_15 (Ba  (None, 256, 256, 32)         96        ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_51 (Activation)  (None, 128, 128, 105)        0         ['add_17[0][0]']
#
#  add_4 (Add)                 (None, 256, 256, 32)         0         ['batch_normalization_15[0][0]
#                                                                     ',
#                                                                      'activation_10[0][0]']
#
#  batch_normalization_77 (Ba  (None, 128, 128, 105)        420       ['activation_51[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 256, 256, 32)         0         ['add_4[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 32)         13472     ['batch_normalization_77[0][0]
#  Transpose)                                                         ']
#
#  batch_normalization_17 (Ba  (None, 256, 256, 32)         128       ['activation_11[0][0]']
#  tchNormalization)
#
#  concatenate_11 (Concatenat  (None, 256, 256, 64)         0         ['conv2d_transpose_3[0][0]',
#  e)                                                                  'batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 256, 256, 8)          4608      ['concatenate_11[0][0]']
#
#  batch_normalization_79 (Ba  (None, 256, 256, 8)          24        ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 256, 256, 8)          0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 17)         1224      ['activation_52[0][0]']
#
#  batch_normalization_80 (Ba  (None, 256, 256, 17)         51        ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 256, 256, 17)         0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 26)         3978      ['activation_53[0][0]']
#
#  batch_normalization_81 (Ba  (None, 256, 256, 26)         78        ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 256, 256, 26)         0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 256, 256, 51)         3264      ['concatenate_11[0][0]']
#
#  concatenate_12 (Concatenat  (None, 256, 256, 51)         0         ['activation_52[0][0]',
#  e)                                                                  'activation_53[0][0]',
#                                                                      'activation_54[0][0]']
#
#  batch_normalization_78 (Ba  (None, 256, 256, 51)         153       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 256, 256, 51)         204       ['concatenate_12[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 256, 256, 51)         0         ['batch_normalization_78[0][0]
#                                                                     ',
#                                                                      'batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_55 (Activation)  (None, 256, 256, 51)         0         ['add_18[0][0]']
#
#  batch_normalization_83 (Ba  (None, 256, 256, 51)         204       ['activation_55[0][0]']
#  tchNormalization)
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 1)          51        ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 256, 256, 1)          3         ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 256, 256, 1)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 7262750 (27.71 MB)
# Trainable params: 7238228 (27.61 MB)
# Non-trainable params: 24522 (95.79 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/80
# 120/120 [==============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.9238 - f1_score: 0.5330 - binary_io_u: 0.6197
# Epoch 1: val_binary_io_u improved from -inf to 0.48261, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 126s 612ms/step - loss: 0.5956 - accuracy: 0.9238 - f1_score: 0.5330 - binary_io_u: 0.6197 - val_loss: 0.5446 - val_accuracy: 0.9652 - val_f1_score: 0.0000e+00 - val_binary_io_u: 0.4826 - lr: 0.0010
# Epoch 2/80
# 120/120 [==============================] - ETA: 0s - loss: 0.5372 - accuracy: 0.9658 - f1_score: 0.6584 - binary_io_u: 0.7364
# Epoch 2: val_binary_io_u improved from 0.48261 to 0.48924, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.5372 - accuracy: 0.9658 - f1_score: 0.6584 - binary_io_u: 0.7364 - val_loss: 0.4521 - val_accuracy: 0.9657 - val_f1_score: 0.0202 - val_binary_io_u: 0.4892 - lr: 0.0010
# Epoch 3/80
# 120/120 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.9719 - f1_score: 0.6994 - binary_io_u: 0.7646
# Epoch 3: val_binary_io_u improved from 0.48924 to 0.69097, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 610ms/step - loss: 0.4919 - accuracy: 0.9719 - f1_score: 0.6994 - binary_io_u: 0.7646 - val_loss: 0.4815 - val_accuracy: 0.9678 - val_f1_score: 0.5515 - val_binary_io_u: 0.6910 - lr: 0.0010
# Epoch 4/80
# 120/120 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.9762 - f1_score: 0.7343 - binary_io_u: 0.7856
# Epoch 4: val_binary_io_u improved from 0.69097 to 0.71389, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 608ms/step - loss: 0.4513 - accuracy: 0.9762 - f1_score: 0.7343 - binary_io_u: 0.7856 - val_loss: 0.4310 - val_accuracy: 0.9789 - val_f1_score: 0.5651 - val_binary_io_u: 0.7139 - lr: 0.0010
# Epoch 5/80
# 120/120 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.9787 - f1_score: 0.7538 - binary_io_u: 0.7996
# Epoch 5: val_binary_io_u improved from 0.71389 to 0.78204, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 610ms/step - loss: 0.4154 - accuracy: 0.9787 - f1_score: 0.7538 - binary_io_u: 0.7996 - val_loss: 0.3990 - val_accuracy: 0.9818 - val_f1_score: 0.6817 - val_binary_io_u: 0.7820 - lr: 0.0010
# Epoch 6/80
# 120/120 [==============================] - ETA: 0s - loss: 0.3840 - accuracy: 0.9796 - f1_score: 0.7563 - binary_io_u: 0.8039
# Epoch 6: val_binary_io_u improved from 0.78204 to 0.79334, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 610ms/step - loss: 0.3840 - accuracy: 0.9796 - f1_score: 0.7563 - binary_io_u: 0.8039 - val_loss: 0.3642 - val_accuracy: 0.9846 - val_f1_score: 0.6886 - val_binary_io_u: 0.7933 - lr: 0.0010
# Epoch 7/80
# 120/120 [==============================] - ETA: 0s - loss: 0.3552 - accuracy: 0.9812 - f1_score: 0.7690 - binary_io_u: 0.8140
# Epoch 7: val_binary_io_u improved from 0.79334 to 0.80022, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.3552 - accuracy: 0.9812 - f1_score: 0.7690 - binary_io_u: 0.8140 - val_loss: 0.3386 - val_accuracy: 0.9843 - val_f1_score: 0.7139 - val_binary_io_u: 0.8002 - lr: 0.0010
# Epoch 8/80
# 120/120 [==============================] - ETA: 0s - loss: 0.3286 - accuracy: 0.9821 - f1_score: 0.7835 - binary_io_u: 0.8195
# Epoch 8: val_binary_io_u improved from 0.80022 to 0.80042, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 610ms/step - loss: 0.3286 - accuracy: 0.9821 - f1_score: 0.7835 - binary_io_u: 0.8195 - val_loss: 0.3125 - val_accuracy: 0.9841 - val_f1_score: 0.7142 - val_binary_io_u: 0.8004 - lr: 0.0010
# Epoch 9/80
# 120/120 [==============================] - ETA: 0s - loss: 0.3046 - accuracy: 0.9828 - f1_score: 0.7899 - binary_io_u: 0.8249
# Epoch 9: val_binary_io_u improved from 0.80042 to 0.81132, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.3046 - accuracy: 0.9828 - f1_score: 0.7899 - binary_io_u: 0.8249 - val_loss: 0.2904 - val_accuracy: 0.9846 - val_f1_score: 0.7278 - val_binary_io_u: 0.8113 - lr: 0.0010
# Epoch 10/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.9832 - f1_score: 0.7910 - binary_io_u: 0.8261
# Epoch 10: val_binary_io_u did not improve from 0.81132
# 120/120 [==============================] - 71s 595ms/step - loss: 0.2839 - accuracy: 0.9832 - f1_score: 0.7910 - binary_io_u: 0.8261 - val_loss: 0.2712 - val_accuracy: 0.9850 - val_f1_score: 0.6812 - val_binary_io_u: 0.7959 - lr: 0.0010
# Epoch 11/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.9840 - f1_score: 0.7975 - binary_io_u: 0.8324
# Epoch 11: val_binary_io_u did not improve from 0.81132
# 120/120 [==============================] - 71s 594ms/step - loss: 0.2644 - accuracy: 0.9840 - f1_score: 0.7975 - binary_io_u: 0.8324 - val_loss: 0.2732 - val_accuracy: 0.9788 - val_f1_score: 0.6782 - val_binary_io_u: 0.7753 - lr: 0.0010
# Epoch 12/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9841 - f1_score: 0.7926 - binary_io_u: 0.8320
# Epoch 12: val_binary_io_u improved from 0.81132 to 0.81578, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 610ms/step - loss: 0.2476 - accuracy: 0.9841 - f1_score: 0.7926 - binary_io_u: 0.8320 - val_loss: 0.2349 - val_accuracy: 0.9859 - val_f1_score: 0.7346 - val_binary_io_u: 0.8158 - lr: 0.0010
# Epoch 13/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9850 - f1_score: 0.8036 - binary_io_u: 0.8393
# Epoch 13: val_binary_io_u did not improve from 0.81578
# 120/120 [==============================] - 71s 596ms/step - loss: 0.2311 - accuracy: 0.9850 - f1_score: 0.8036 - binary_io_u: 0.8393 - val_loss: 0.2259 - val_accuracy: 0.9841 - val_f1_score: 0.7311 - val_binary_io_u: 0.8101 - lr: 0.0010
# Epoch 14/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9860 - f1_score: 0.8201 - binary_io_u: 0.8477
# Epoch 14: val_binary_io_u did not improve from 0.81578
# 120/120 [==============================] - 72s 596ms/step - loss: 0.2150 - accuracy: 0.9860 - f1_score: 0.8201 - binary_io_u: 0.8477 - val_loss: 0.2275 - val_accuracy: 0.9801 - val_f1_score: 0.6765 - val_binary_io_u: 0.7732 - lr: 0.0010
# Epoch 15/80
# 120/120 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9859 - f1_score: 0.8144 - binary_io_u: 0.8462
# Epoch 15: val_binary_io_u improved from 0.81578 to 0.82285, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 610ms/step - loss: 0.2028 - accuracy: 0.9859 - f1_score: 0.8144 - binary_io_u: 0.8462 - val_loss: 0.1969 - val_accuracy: 0.9863 - val_f1_score: 0.7449 - val_binary_io_u: 0.8229 - lr: 0.0010
# Epoch 16/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1908 - accuracy: 0.9859 - f1_score: 0.8162 - binary_io_u: 0.8451
# Epoch 16: val_binary_io_u did not improve from 0.82285
# 120/120 [==============================] - 72s 596ms/step - loss: 0.1908 - accuracy: 0.9859 - f1_score: 0.8162 - binary_io_u: 0.8451 - val_loss: 0.1900 - val_accuracy: 0.9830 - val_f1_score: 0.7110 - val_binary_io_u: 0.7978 - lr: 0.0010
# Epoch 17/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9861 - f1_score: 0.8165 - binary_io_u: 0.8471
# Epoch 17: val_binary_io_u improved from 0.82285 to 0.82813, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.1799 - accuracy: 0.9861 - f1_score: 0.8165 - binary_io_u: 0.8471 - val_loss: 0.1728 - val_accuracy: 0.9872 - val_f1_score: 0.7459 - val_binary_io_u: 0.8281 - lr: 0.0010
# Epoch 18/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1695 - accuracy: 0.9866 - f1_score: 0.8223 - binary_io_u: 0.8517
# Epoch 18: val_binary_io_u improved from 0.82813 to 0.83027, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 612ms/step - loss: 0.1695 - accuracy: 0.9866 - f1_score: 0.8223 - binary_io_u: 0.8517 - val_loss: 0.1657 - val_accuracy: 0.9868 - val_f1_score: 0.7561 - val_binary_io_u: 0.8303 - lr: 0.0010
# Epoch 19/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9875 - f1_score: 0.8362 - binary_io_u: 0.8599
# Epoch 19: val_binary_io_u did not improve from 0.83027
# 120/120 [==============================] - 72s 596ms/step - loss: 0.1587 - accuracy: 0.9875 - f1_score: 0.8362 - binary_io_u: 0.8599 - val_loss: 0.1544 - val_accuracy: 0.9871 - val_f1_score: 0.7389 - val_binary_io_u: 0.8241 - lr: 0.0010
# Epoch 20/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9867 - f1_score: 0.8234 - binary_io_u: 0.8515
# Epoch 20: val_binary_io_u did not improve from 0.83027
# 120/120 [==============================] - 72s 596ms/step - loss: 0.1521 - accuracy: 0.9867 - f1_score: 0.8234 - binary_io_u: 0.8515 - val_loss: 0.1467 - val_accuracy: 0.9872 - val_f1_score: 0.7502 - val_binary_io_u: 0.8288 - lr: 0.0010
# Epoch 21/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9877 - f1_score: 0.8360 - binary_io_u: 0.8613
# Epoch 21: val_binary_io_u improved from 0.83027 to 0.83399, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.1427 - accuracy: 0.9877 - f1_score: 0.8360 - binary_io_u: 0.8613 - val_loss: 0.1383 - val_accuracy: 0.9879 - val_f1_score: 0.7528 - val_binary_io_u: 0.8340 - lr: 0.0010
# Epoch 22/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9877 - f1_score: 0.8363 - binary_io_u: 0.8609
# Epoch 22: val_binary_io_u did not improve from 0.83399
# 120/120 [==============================] - 72s 597ms/step - loss: 0.1356 - accuracy: 0.9877 - f1_score: 0.8363 - binary_io_u: 0.8609 - val_loss: 0.1334 - val_accuracy: 0.9868 - val_f1_score: 0.7540 - val_binary_io_u: 0.8279 - lr: 0.0010
# Epoch 23/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9875 - f1_score: 0.8326 - binary_io_u: 0.8585
# Epoch 23: val_binary_io_u did not improve from 0.83399
# 120/120 [==============================] - 72s 596ms/step - loss: 0.1299 - accuracy: 0.9875 - f1_score: 0.8326 - binary_io_u: 0.8585 - val_loss: 0.1240 - val_accuracy: 0.9875 - val_f1_score: 0.7523 - val_binary_io_u: 0.8327 - lr: 0.0010
# Epoch 24/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9880 - f1_score: 0.8416 - binary_io_u: 0.8637
# Epoch 24: val_binary_io_u did not improve from 0.83399
# 120/120 [==============================] - 72s 597ms/step - loss: 0.1228 - accuracy: 0.9880 - f1_score: 0.8416 - binary_io_u: 0.8637 - val_loss: 0.1214 - val_accuracy: 0.9874 - val_f1_score: 0.7607 - val_binary_io_u: 0.8326 - lr: 0.0010
# Epoch 25/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9884 - f1_score: 0.8464 - binary_io_u: 0.8675
# Epoch 25: val_binary_io_u did not improve from 0.83399
# 120/120 [==============================] - 72s 597ms/step - loss: 0.1169 - accuracy: 0.9884 - f1_score: 0.8464 - binary_io_u: 0.8675 - val_loss: 0.1148 - val_accuracy: 0.9874 - val_f1_score: 0.7447 - val_binary_io_u: 0.8306 - lr: 0.0010
# Epoch 26/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9880 - f1_score: 0.8358 - binary_io_u: 0.8629
# Epoch 26: val_binary_io_u did not improve from 0.83399
# 120/120 [==============================] - 72s 597ms/step - loss: 0.1127 - accuracy: 0.9880 - f1_score: 0.8358 - binary_io_u: 0.8629 - val_loss: 0.1121 - val_accuracy: 0.9871 - val_f1_score: 0.7538 - val_binary_io_u: 0.8315 - lr: 0.0010
# Epoch 27/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9884 - f1_score: 0.8415 - binary_io_u: 0.8672
# Epoch 27: val_binary_io_u improved from 0.83399 to 0.84028, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 612ms/step - loss: 0.1070 - accuracy: 0.9884 - f1_score: 0.8415 - binary_io_u: 0.8672 - val_loss: 0.1065 - val_accuracy: 0.9877 - val_f1_score: 0.7721 - val_binary_io_u: 0.8403 - lr: 0.0010
# Epoch 28/80
# 120/120 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9889 - f1_score: 0.8525 - binary_io_u: 0.8719
# Epoch 28: val_binary_io_u did not improve from 0.84028
# 120/120 [==============================] - 72s 597ms/step - loss: 0.1019 - accuracy: 0.9889 - f1_score: 0.8525 - binary_io_u: 0.8719 - val_loss: 0.1045 - val_accuracy: 0.9879 - val_f1_score: 0.7568 - val_binary_io_u: 0.8343 - lr: 0.0010
# Epoch 29/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9888 - f1_score: 0.8475 - binary_io_u: 0.8710
# Epoch 29: val_binary_io_u did not improve from 0.84028
# 120/120 [==============================] - 72s 596ms/step - loss: 0.0983 - accuracy: 0.9888 - f1_score: 0.8475 - binary_io_u: 0.8710 - val_loss: 0.0972 - val_accuracy: 0.9881 - val_f1_score: 0.7673 - val_binary_io_u: 0.8383 - lr: 0.0010
# Epoch 30/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9892 - f1_score: 0.8556 - binary_io_u: 0.8746
# Epoch 30: val_binary_io_u did not improve from 0.84028
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0937 - accuracy: 0.9892 - f1_score: 0.8556 - binary_io_u: 0.8746 - val_loss: 0.0941 - val_accuracy: 0.9877 - val_f1_score: 0.7520 - val_binary_io_u: 0.8343 - lr: 0.0010
# Epoch 31/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9892 - f1_score: 0.8533 - binary_io_u: 0.8745
# Epoch 31: val_binary_io_u did not improve from 0.84028
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0905 - accuracy: 0.9892 - f1_score: 0.8533 - binary_io_u: 0.8745 - val_loss: 0.0887 - val_accuracy: 0.9880 - val_f1_score: 0.7395 - val_binary_io_u: 0.8329 - lr: 0.0010
# Epoch 32/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9894 - f1_score: 0.8557 - binary_io_u: 0.8768
# Epoch 32: val_binary_io_u improved from 0.84028 to 0.84880, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.0871 - accuracy: 0.9894 - f1_score: 0.8557 - binary_io_u: 0.8768 - val_loss: 0.0849 - val_accuracy: 0.9888 - val_f1_score: 0.7838 - val_binary_io_u: 0.8488 - lr: 0.0010
# Epoch 33/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9896 - f1_score: 0.8583 - binary_io_u: 0.8790
# Epoch 33: val_binary_io_u did not improve from 0.84880
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0836 - accuracy: 0.9896 - f1_score: 0.8583 - binary_io_u: 0.8790 - val_loss: 0.0819 - val_accuracy: 0.9886 - val_f1_score: 0.7795 - val_binary_io_u: 0.8481 - lr: 0.0010
# Epoch 34/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9895 - f1_score: 0.8592 - binary_io_u: 0.8779
# Epoch 34: val_binary_io_u did not improve from 0.84880
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0811 - accuracy: 0.9895 - f1_score: 0.8592 - binary_io_u: 0.8779 - val_loss: 0.0827 - val_accuracy: 0.9873 - val_f1_score: 0.7313 - val_binary_io_u: 0.8204 - lr: 0.0010
# Epoch 35/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9894 - f1_score: 0.8558 - binary_io_u: 0.8760
# Epoch 35: val_binary_io_u did not improve from 0.84880
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0788 - accuracy: 0.9894 - f1_score: 0.8558 - binary_io_u: 0.8760 - val_loss: 0.0780 - val_accuracy: 0.9882 - val_f1_score: 0.7619 - val_binary_io_u: 0.8384 - lr: 0.0010
# Epoch 36/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9899 - f1_score: 0.8640 - binary_io_u: 0.8815
# Epoch 36: val_binary_io_u did not improve from 0.84880
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0753 - accuracy: 0.9899 - f1_score: 0.8640 - binary_io_u: 0.8815 - val_loss: 0.0749 - val_accuracy: 0.9886 - val_f1_score: 0.7569 - val_binary_io_u: 0.8410 - lr: 0.0010
# Epoch 37/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9901 - f1_score: 0.8639 - binary_io_u: 0.8836
# Epoch 37: val_binary_io_u did not improve from 0.84880
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0734 - accuracy: 0.9901 - f1_score: 0.8639 - binary_io_u: 0.8836 - val_loss: 0.0729 - val_accuracy: 0.9886 - val_f1_score: 0.7693 - val_binary_io_u: 0.8440 - lr: 0.0010
# Epoch 38/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9899 - f1_score: 0.8640 - binary_io_u: 0.8817
# Epoch 38: val_binary_io_u improved from 0.84880 to 0.85082, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 612ms/step - loss: 0.0711 - accuracy: 0.9899 - f1_score: 0.8640 - binary_io_u: 0.8817 - val_loss: 0.0691 - val_accuracy: 0.9890 - val_f1_score: 0.7816 - val_binary_io_u: 0.8508 - lr: 0.0010
# Epoch 39/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9900 - f1_score: 0.8621 - binary_io_u: 0.8820
# Epoch 39: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0696 - accuracy: 0.9900 - f1_score: 0.8621 - binary_io_u: 0.8820 - val_loss: 0.0739 - val_accuracy: 0.9862 - val_f1_score: 0.7625 - val_binary_io_u: 0.8313 - lr: 0.0010
# Epoch 40/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9902 - f1_score: 0.8686 - binary_io_u: 0.8847
# Epoch 40: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 71s 595ms/step - loss: 0.0670 - accuracy: 0.9902 - f1_score: 0.8686 - binary_io_u: 0.8847 - val_loss: 0.0670 - val_accuracy: 0.9891 - val_f1_score: 0.7741 - val_binary_io_u: 0.8473 - lr: 0.0010
# Epoch 41/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9900 - f1_score: 0.8659 - binary_io_u: 0.8820
# Epoch 41: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0658 - accuracy: 0.9900 - f1_score: 0.8659 - binary_io_u: 0.8820 - val_loss: 0.0674 - val_accuracy: 0.9888 - val_f1_score: 0.7602 - val_binary_io_u: 0.8418 - lr: 0.0010
# Epoch 42/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9900 - f1_score: 0.8630 - binary_io_u: 0.8819
# Epoch 42: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0640 - accuracy: 0.9900 - f1_score: 0.8630 - binary_io_u: 0.8819 - val_loss: 0.0659 - val_accuracy: 0.9885 - val_f1_score: 0.7654 - val_binary_io_u: 0.8411 - lr: 0.0010
# Epoch 43/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9902 - f1_score: 0.8695 - binary_io_u: 0.8840
# Epoch 43: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0626 - accuracy: 0.9902 - f1_score: 0.8695 - binary_io_u: 0.8840 - val_loss: 0.0619 - val_accuracy: 0.9890 - val_f1_score: 0.7708 - val_binary_io_u: 0.8445 - lr: 0.0010
# Epoch 44/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9901 - f1_score: 0.8655 - binary_io_u: 0.8831
# Epoch 44: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0615 - accuracy: 0.9901 - f1_score: 0.8655 - binary_io_u: 0.8831 - val_loss: 0.0614 - val_accuracy: 0.9888 - val_f1_score: 0.7604 - val_binary_io_u: 0.8420 - lr: 0.0010
# Epoch 45/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9903 - f1_score: 0.8708 - binary_io_u: 0.8854
# Epoch 45: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0596 - accuracy: 0.9903 - f1_score: 0.8708 - binary_io_u: 0.8854 - val_loss: 0.0582 - val_accuracy: 0.9892 - val_f1_score: 0.7783 - val_binary_io_u: 0.8476 - lr: 0.0010
# Epoch 46/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9904 - f1_score: 0.8711 - binary_io_u: 0.8857
# Epoch 46: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0586 - accuracy: 0.9904 - f1_score: 0.8711 - binary_io_u: 0.8857 - val_loss: 0.0622 - val_accuracy: 0.9889 - val_f1_score: 0.7661 - val_binary_io_u: 0.8430 - lr: 0.0010
# Epoch 47/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9904 - f1_score: 0.8700 - binary_io_u: 0.8862
# Epoch 47: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0573 - accuracy: 0.9904 - f1_score: 0.8700 - binary_io_u: 0.8862 - val_loss: 0.0590 - val_accuracy: 0.9888 - val_f1_score: 0.7665 - val_binary_io_u: 0.8407 - lr: 0.0010
# Epoch 48/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9903 - f1_score: 0.8720 - binary_io_u: 0.8849
# Epoch 48: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0565 - accuracy: 0.9903 - f1_score: 0.8720 - binary_io_u: 0.8849 - val_loss: 0.0580 - val_accuracy: 0.9885 - val_f1_score: 0.7466 - val_binary_io_u: 0.8351 - lr: 0.0010
# Epoch 49/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9904 - f1_score: 0.8709 - binary_io_u: 0.8857
# Epoch 49: val_binary_io_u did not improve from 0.85082
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0557 - accuracy: 0.9904 - f1_score: 0.8709 - binary_io_u: 0.8857 - val_loss: 0.0544 - val_accuracy: 0.9891 - val_f1_score: 0.7721 - val_binary_io_u: 0.8473 - lr: 0.0010
# Epoch 50/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9902 - f1_score: 0.8695 - binary_io_u: 0.8832
# Epoch 50: val_binary_io_u improved from 0.85082 to 0.85764, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 611ms/step - loss: 0.0547 - accuracy: 0.9902 - f1_score: 0.8695 - binary_io_u: 0.8832 - val_loss: 0.0528 - val_accuracy: 0.9897 - val_f1_score: 0.7939 - val_binary_io_u: 0.8576 - lr: 0.0010
# Epoch 51/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9895 - f1_score: 0.8611 - binary_io_u: 0.8741
# Epoch 51: val_binary_io_u did not improve from 0.85764
# 120/120 [==============================] - 72s 596ms/step - loss: 0.0543 - accuracy: 0.9895 - f1_score: 0.8611 - binary_io_u: 0.8741 - val_loss: 0.0542 - val_accuracy: 0.9893 - val_f1_score: 0.7782 - val_binary_io_u: 0.8508 - lr: 0.0010
# Epoch 52/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9898 - f1_score: 0.8660 - binary_io_u: 0.8774
# Epoch 52: val_binary_io_u did not improve from 0.85764
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0527 - accuracy: 0.9898 - f1_score: 0.8660 - binary_io_u: 0.8774 - val_loss: 0.0552 - val_accuracy: 0.9888 - val_f1_score: 0.7619 - val_binary_io_u: 0.8397 - lr: 0.0010
# Epoch 53/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9881 - f1_score: 0.8458 - binary_io_u: 0.8575
# Epoch 53: val_binary_io_u improved from 0.85764 to 0.85960, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Multi_resUnet_1500_v2/saved_models/best_Multi_resUnet_1500_v2.h5
# 120/120 [==============================] - 73s 612ms/step - loss: 0.0535 - accuracy: 0.9881 - f1_score: 0.8458 - binary_io_u: 0.8575 - val_loss: 0.0504 - val_accuracy: 0.9899 - val_f1_score: 0.7973 - val_binary_io_u: 0.8596 - lr: 0.0010
# Epoch 54/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9887 - f1_score: 0.8492 - binary_io_u: 0.8642
# Epoch 54: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0523 - accuracy: 0.9887 - f1_score: 0.8492 - binary_io_u: 0.8642 - val_loss: 0.0514 - val_accuracy: 0.9893 - val_f1_score: 0.7823 - val_binary_io_u: 0.8481 - lr: 0.0010
# Epoch 55/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9892 - f1_score: 0.8572 - binary_io_u: 0.8705
# Epoch 55: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0518 - accuracy: 0.9892 - f1_score: 0.8572 - binary_io_u: 0.8705 - val_loss: 0.0532 - val_accuracy: 0.9891 - val_f1_score: 0.7693 - val_binary_io_u: 0.8439 - lr: 0.0010
# Epoch 56/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9876 - f1_score: 0.8408 - binary_io_u: 0.8513
# Epoch 56: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 595ms/step - loss: 0.0511 - accuracy: 0.9876 - f1_score: 0.8408 - binary_io_u: 0.8513 - val_loss: 0.0505 - val_accuracy: 0.9894 - val_f1_score: 0.7717 - val_binary_io_u: 0.8506 - lr: 0.0010
# Epoch 57/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9890 - f1_score: 0.8531 - binary_io_u: 0.8681
# Epoch 57: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0505 - accuracy: 0.9890 - f1_score: 0.8531 - binary_io_u: 0.8681 - val_loss: 0.0503 - val_accuracy: 0.9892 - val_f1_score: 0.7736 - val_binary_io_u: 0.8451 - lr: 0.0010
# Epoch 58/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9896 - f1_score: 0.8640 - binary_io_u: 0.8747
# Epoch 58: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0496 - accuracy: 0.9896 - f1_score: 0.8640 - binary_io_u: 0.8747 - val_loss: 0.0506 - val_accuracy: 0.9893 - val_f1_score: 0.7776 - val_binary_io_u: 0.8494 - lr: 0.0010
# Epoch 59/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9888 - f1_score: 0.8544 - binary_io_u: 0.8653
# Epoch 59: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0496 - accuracy: 0.9888 - f1_score: 0.8544 - binary_io_u: 0.8653 - val_loss: 0.0515 - val_accuracy: 0.9887 - val_f1_score: 0.7611 - val_binary_io_u: 0.8382 - lr: 0.0010
# Epoch 60/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9888 - f1_score: 0.8540 - binary_io_u: 0.8650
# Epoch 60: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0488 - accuracy: 0.9888 - f1_score: 0.8540 - binary_io_u: 0.8650 - val_loss: 0.0495 - val_accuracy: 0.9898 - val_f1_score: 0.7906 - val_binary_io_u: 0.8561 - lr: 0.0010
# Epoch 61/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9891 - f1_score: 0.8561 - binary_io_u: 0.8683
# Epoch 61: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0488 - accuracy: 0.9891 - f1_score: 0.8561 - binary_io_u: 0.8683 - val_loss: 0.0506 - val_accuracy: 0.9893 - val_f1_score: 0.7774 - val_binary_io_u: 0.8480 - lr: 0.0010
# Epoch 62/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9877 - f1_score: 0.8380 - binary_io_u: 0.8521
# Epoch 62: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 595ms/step - loss: 0.0496 - accuracy: 0.9877 - f1_score: 0.8380 - binary_io_u: 0.8521 - val_loss: 0.0485 - val_accuracy: 0.9895 - val_f1_score: 0.7872 - val_binary_io_u: 0.8533 - lr: 0.0010
# Epoch 63/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9880 - f1_score: 0.8420 - binary_io_u: 0.8554
# Epoch 63: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0492 - accuracy: 0.9880 - f1_score: 0.8420 - binary_io_u: 0.8554 - val_loss: 0.0515 - val_accuracy: 0.9886 - val_f1_score: 0.7602 - val_binary_io_u: 0.8366 - lr: 0.0010
# Epoch 64/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9875 - f1_score: 0.8358 - binary_io_u: 0.8491
# Epoch 64: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0479 - accuracy: 0.9875 - f1_score: 0.8358 - binary_io_u: 0.8491 - val_loss: 0.0488 - val_accuracy: 0.9895 - val_f1_score: 0.7805 - val_binary_io_u: 0.8507 - lr: 0.0010
# Epoch 65/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9882 - f1_score: 0.8404 - binary_io_u: 0.8571
# Epoch 65: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0474 - accuracy: 0.9882 - f1_score: 0.8404 - binary_io_u: 0.8571 - val_loss: 0.0480 - val_accuracy: 0.9891 - val_f1_score: 0.7728 - val_binary_io_u: 0.8442 - lr: 0.0010
# Epoch 66/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9859 - f1_score: 0.8074 - binary_io_u: 0.8291
# Epoch 66: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0475 - accuracy: 0.9859 - f1_score: 0.8074 - binary_io_u: 0.8291 - val_loss: 0.0492 - val_accuracy: 0.9894 - val_f1_score: 0.7830 - val_binary_io_u: 0.8489 - lr: 0.0010
# Epoch 67/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9873 - f1_score: 0.8357 - binary_io_u: 0.8467
# Epoch 67: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 598ms/step - loss: 0.0474 - accuracy: 0.9873 - f1_score: 0.8357 - binary_io_u: 0.8467 - val_loss: 0.0484 - val_accuracy: 0.9895 - val_f1_score: 0.7802 - val_binary_io_u: 0.8506 - lr: 0.0010
# Epoch 68/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9875 - f1_score: 0.8378 - binary_io_u: 0.8483
# Epoch 68: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0471 - accuracy: 0.9875 - f1_score: 0.8378 - binary_io_u: 0.8483 - val_loss: 0.0495 - val_accuracy: 0.9891 - val_f1_score: 0.7716 - val_binary_io_u: 0.8441 - lr: 0.0010
# Epoch 69/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9877 - f1_score: 0.8372 - binary_io_u: 0.8506
# Epoch 69: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0469 - accuracy: 0.9877 - f1_score: 0.8372 - binary_io_u: 0.8506 - val_loss: 0.0478 - val_accuracy: 0.9895 - val_f1_score: 0.7778 - val_binary_io_u: 0.8497 - lr: 0.0010
# Epoch 70/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9884 - f1_score: 0.8488 - binary_io_u: 0.8594
# Epoch 70: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0463 - accuracy: 0.9884 - f1_score: 0.8488 - binary_io_u: 0.8594 - val_loss: 0.0487 - val_accuracy: 0.9897 - val_f1_score: 0.7855 - val_binary_io_u: 0.8533 - lr: 0.0010
# Epoch 71/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9871 - f1_score: 0.8284 - binary_io_u: 0.8442
# Epoch 71: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0468 - accuracy: 0.9871 - f1_score: 0.8284 - binary_io_u: 0.8442 - val_loss: 0.0488 - val_accuracy: 0.9895 - val_f1_score: 0.7773 - val_binary_io_u: 0.8501 - lr: 0.0010
# Epoch 72/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9874 - f1_score: 0.8333 - binary_io_u: 0.8471
# Epoch 72: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0467 - accuracy: 0.9874 - f1_score: 0.8333 - binary_io_u: 0.8471 - val_loss: 0.0499 - val_accuracy: 0.9892 - val_f1_score: 0.7776 - val_binary_io_u: 0.8466 - lr: 0.0010
# Epoch 73/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9864 - f1_score: 0.8119 - binary_io_u: 0.8348
# Epoch 73: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 596ms/step - loss: 0.0464 - accuracy: 0.9864 - f1_score: 0.8119 - binary_io_u: 0.8348 - val_loss: 0.0493 - val_accuracy: 0.9890 - val_f1_score: 0.7720 - val_binary_io_u: 0.8418 - lr: 0.0010
# Epoch 74/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9864 - f1_score: 0.8145 - binary_io_u: 0.8351
# Epoch 74: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0462 - accuracy: 0.9864 - f1_score: 0.8145 - binary_io_u: 0.8351 - val_loss: 0.0470 - val_accuracy: 0.9896 - val_f1_score: 0.7950 - val_binary_io_u: 0.8531 - lr: 0.0010
# Epoch 75/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9870 - f1_score: 0.8252 - binary_io_u: 0.8421
# Epoch 75: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 71s 596ms/step - loss: 0.0456 - accuracy: 0.9870 - f1_score: 0.8252 - binary_io_u: 0.8421 - val_loss: 0.0477 - val_accuracy: 0.9896 - val_f1_score: 0.7857 - val_binary_io_u: 0.8528 - lr: 0.0010
# Epoch 76/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9877 - f1_score: 0.8334 - binary_io_u: 0.8505
# Epoch 76: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0452 - accuracy: 0.9877 - f1_score: 0.8334 - binary_io_u: 0.8505 - val_loss: 0.0488 - val_accuracy: 0.9894 - val_f1_score: 0.7803 - val_binary_io_u: 0.8484 - lr: 0.0010
# Epoch 77/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9865 - f1_score: 0.8138 - binary_io_u: 0.8364
# Epoch 77: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0456 - accuracy: 0.9865 - f1_score: 0.8138 - binary_io_u: 0.8364 - val_loss: 0.0479 - val_accuracy: 0.9900 - val_f1_score: 0.7957 - val_binary_io_u: 0.8589 - lr: 0.0010
# Epoch 78/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9866 - f1_score: 0.8189 - binary_io_u: 0.8367
# Epoch 78: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 596ms/step - loss: 0.0456 - accuracy: 0.9866 - f1_score: 0.8189 - binary_io_u: 0.8367 - val_loss: 0.0468 - val_accuracy: 0.9897 - val_f1_score: 0.7920 - val_binary_io_u: 0.8544 - lr: 0.0010
# Epoch 79/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9859 - f1_score: 0.8081 - binary_io_u: 0.8290
# Epoch 79: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 597ms/step - loss: 0.0459 - accuracy: 0.9859 - f1_score: 0.8081 - binary_io_u: 0.8290 - val_loss: 0.0501 - val_accuracy: 0.9889 - val_f1_score: 0.7699 - val_binary_io_u: 0.8406 - lr: 0.0010
# Epoch 80/80
# 120/120 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9866 - f1_score: 0.8190 - binary_io_u: 0.8371
# Epoch 80: val_binary_io_u did not improve from 0.85960
# 120/120 [==============================] - 72s 596ms/step - loss: 0.0451 - accuracy: 0.9866 - f1_score: 0.8190 - binary_io_u: 0.8371 - val_loss: 0.0477 - val_accuracy: 0.9898 - val_f1_score: 0.7904 - val_binary_io_u: 0.8540 - lr: 0.0010

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 15s 15s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 18]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.0502 - accuracy: 0.9903 - f1_score: 0.8638 - binary_io_u: 0.8751

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#               Model Name      Loss  Accuracy  Precision    Recall  F1-Score  \
# 0  Multi_resUnet_1500_v2  0.050236   0.99032   0.908748  0.823084  0.863797
#
#         IoU
# 0  0.855674

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
