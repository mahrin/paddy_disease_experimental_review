# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# from keras import ops# For deeplab3

# import keras_cv # basnet

from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Basic_Unet__without_drop_1500_without_norm'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 80

TOTAL_DATA = 1500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 5
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 19371.56it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 1500 original images into x_train
# Loaded 1500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### Basic basic_unet

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    x = Activation('relu')(x)

    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    x = Activation('relu')(x)

    return x

def get_basic_unet(n_filters = 16):
    """
    Version of U-Net with dropout and size preservation (padding= 'same')--from class note
    """
    input_img = Input(shape=MODEL_INPUT_SIZE)
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size=3)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = conv2d_block(p1, n_filters * 2, kernel_size=3)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = conv2d_block(p2, n_filters * 4, kernel_size=3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = conv2d_block(p3, n_filters * 8, kernel_size=3)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = conv2d_block(p4, n_filters * 16, kernel_size=3)

    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(c5)
    u6 = Concatenate()([u6, c4])
    c6 = conv2d_block(u6, n_filters * 8, kernel_size=3)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = Concatenate()([u7, c3])
    c7 = conv2d_block(u7, n_filters * 4, kernel_size=3)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
    u8 = Concatenate()([u8, c2])
    c8 = conv2d_block(u8, n_filters * 2, kernel_size=3)

    u9 = Conv2DTranspose(n_filters, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = Concatenate()([u9, c1])
    c9 = conv2d_block(u9, n_filters, kernel_size=3)

    outputs = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['activation[0][0]']
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['activation_2[0][0]']
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)   (None, 64, 64, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          147584    ['activation_6[0][0]']
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          590080    ['activation_8[0][0]']
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          295040    ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate[0][0]']
#
#  activation_10 (Activation)  (None, 32, 32, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 32, 32, 128)          0         ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           73792     ['activation_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_1[0][0]']
#
#  activation_12 (Activation)  (None, 64, 64, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_12[0][0]']
#
#  activation_13 (Activation)  (None, 64, 64, 64)           0         ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 32)         18464     ['activation_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_2[0][0]']
#
#  activation_14 (Activation)  (None, 128, 128, 32)         0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 32)         9248      ['activation_14[0][0]']
#
#  activation_15 (Activation)  (None, 128, 128, 32)         0         ['conv2d_15[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 16)         4624      ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_3[0][0]']
#
#  activation_16 (Activation)  (None, 256, 256, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 16)         2320      ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 256, 256, 16)         0         ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 1)          17        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 2158705 (8.23 MB)
# Trainable params: 2158705 (8.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9632 - f1_score: 0.2253 - binary_io_u: 0.5626
# Epoch 1: val_binary_io_u improved from -inf to 0.69973, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 21s 73ms/step - loss: 0.1339 - accuracy: 0.9633 - f1_score: 0.2275 - binary_io_u: 0.5633 - val_loss: 0.0762 - val_accuracy: 0.9745 - val_f1_score: 0.5495 - val_binary_io_u: 0.6997 - lr: 0.0010
# Epoch 2/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0734 - accuracy: 0.9759 - f1_score: 0.6399 - binary_io_u: 0.7384
# Epoch 2: val_binary_io_u improved from 0.69973 to 0.75649, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0735 - accuracy: 0.9759 - f1_score: 0.6393 - binary_io_u: 0.7380 - val_loss: 0.0577 - val_accuracy: 0.9814 - val_f1_score: 0.6471 - val_binary_io_u: 0.7565 - lr: 0.0010
# Epoch 3/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0646 - accuracy: 0.9788 - f1_score: 0.6967 - binary_io_u: 0.7699
# Epoch 3: val_binary_io_u improved from 0.75649 to 0.77648, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0644 - accuracy: 0.9789 - f1_score: 0.6976 - binary_io_u: 0.7702 - val_loss: 0.0544 - val_accuracy: 0.9823 - val_f1_score: 0.6816 - val_binary_io_u: 0.7765 - lr: 0.0010
# Epoch 4/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0580 - accuracy: 0.9807 - f1_score: 0.7311 - binary_io_u: 0.7897
# Epoch 4: val_binary_io_u did not improve from 0.77648
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0579 - accuracy: 0.9808 - f1_score: 0.7305 - binary_io_u: 0.7894 - val_loss: 0.0527 - val_accuracy: 0.9830 - val_f1_score: 0.6553 - val_binary_io_u: 0.7662 - lr: 0.0010
# Epoch 5/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0574 - accuracy: 0.9809 - f1_score: 0.7336 - binary_io_u: 0.7898
# Epoch 5: val_binary_io_u did not improve from 0.77648
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0575 - accuracy: 0.9808 - f1_score: 0.7343 - binary_io_u: 0.7903 - val_loss: 0.0592 - val_accuracy: 0.9800 - val_f1_score: 0.6554 - val_binary_io_u: 0.7599 - lr: 0.0010
# Epoch 6/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9819 - f1_score: 0.7541 - binary_io_u: 0.8013
# Epoch 6: val_binary_io_u improved from 0.77648 to 0.77763, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0545 - accuracy: 0.9819 - f1_score: 0.7527 - binary_io_u: 0.8009 - val_loss: 0.0503 - val_accuracy: 0.9836 - val_f1_score: 0.6752 - val_binary_io_u: 0.7776 - lr: 0.0010
# Epoch 7/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9820 - f1_score: 0.7428 - binary_io_u: 0.7993
# Epoch 7: val_binary_io_u did not improve from 0.77763
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0546 - accuracy: 0.9817 - f1_score: 0.7428 - binary_io_u: 0.7988 - val_loss: 0.0522 - val_accuracy: 0.9832 - val_f1_score: 0.6475 - val_binary_io_u: 0.7644 - lr: 0.0010
# Epoch 8/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9818 - f1_score: 0.7538 - binary_io_u: 0.8005
# Epoch 8: val_binary_io_u improved from 0.77763 to 0.78319, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0545 - accuracy: 0.9818 - f1_score: 0.7532 - binary_io_u: 0.8002 - val_loss: 0.0501 - val_accuracy: 0.9832 - val_f1_score: 0.6886 - val_binary_io_u: 0.7832 - lr: 0.0010
# Epoch 9/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9819 - f1_score: 0.7522 - binary_io_u: 0.8005
# Epoch 9: val_binary_io_u did not improve from 0.78319
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0537 - accuracy: 0.9819 - f1_score: 0.7526 - binary_io_u: 0.8008 - val_loss: 0.0577 - val_accuracy: 0.9827 - val_f1_score: 0.6343 - val_binary_io_u: 0.7556 - lr: 0.0010
# Epoch 10/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9818 - f1_score: 0.7483 - binary_io_u: 0.7976
# Epoch 10: val_binary_io_u improved from 0.78319 to 0.78751, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 36ms/step - loss: 0.0559 - accuracy: 0.9816 - f1_score: 0.7484 - binary_io_u: 0.7975 - val_loss: 0.0498 - val_accuracy: 0.9835 - val_f1_score: 0.6933 - val_binary_io_u: 0.7875 - lr: 0.0010
# Epoch 11/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9829 - f1_score: 0.7634 - binary_io_u: 0.8099
# Epoch 11: val_binary_io_u improved from 0.78751 to 0.79168, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0508 - accuracy: 0.9829 - f1_score: 0.7641 - binary_io_u: 0.8104 - val_loss: 0.0485 - val_accuracy: 0.9839 - val_f1_score: 0.7014 - val_binary_io_u: 0.7917 - lr: 0.0010
# Epoch 12/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0511 - accuracy: 0.9826 - f1_score: 0.7569 - binary_io_u: 0.8087
# Epoch 12: val_binary_io_u did not improve from 0.79168
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0512 - accuracy: 0.9826 - f1_score: 0.7562 - binary_io_u: 0.8083 - val_loss: 0.0550 - val_accuracy: 0.9824 - val_f1_score: 0.6171 - val_binary_io_u: 0.7462 - lr: 0.0010
# Epoch 13/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9829 - f1_score: 0.7621 - binary_io_u: 0.8105
# Epoch 13: val_binary_io_u did not improve from 0.79168
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0507 - accuracy: 0.9829 - f1_score: 0.7620 - binary_io_u: 0.8104 - val_loss: 0.0496 - val_accuracy: 0.9830 - val_f1_score: 0.7025 - val_binary_io_u: 0.7888 - lr: 0.0010
# Epoch 14/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9825 - f1_score: 0.7609 - binary_io_u: 0.8064
# Epoch 14: val_binary_io_u did not improve from 0.79168
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0514 - accuracy: 0.9825 - f1_score: 0.7614 - binary_io_u: 0.8067 - val_loss: 0.0492 - val_accuracy: 0.9842 - val_f1_score: 0.6855 - val_binary_io_u: 0.7855 - lr: 0.0010
# Epoch 15/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9831 - f1_score: 0.7674 - binary_io_u: 0.8122
# Epoch 15: val_binary_io_u improved from 0.79168 to 0.79612, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0499 - accuracy: 0.9830 - f1_score: 0.7672 - binary_io_u: 0.8119 - val_loss: 0.0475 - val_accuracy: 0.9840 - val_f1_score: 0.7091 - val_binary_io_u: 0.7961 - lr: 0.0010
# Epoch 16/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9836 - f1_score: 0.7765 - binary_io_u: 0.8173
# Epoch 16: val_binary_io_u improved from 0.79612 to 0.79790, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0482 - accuracy: 0.9836 - f1_score: 0.7769 - binary_io_u: 0.8176 - val_loss: 0.0473 - val_accuracy: 0.9841 - val_f1_score: 0.7173 - val_binary_io_u: 0.7979 - lr: 0.0010
# Epoch 17/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9838 - f1_score: 0.7759 - binary_io_u: 0.8197
# Epoch 17: val_binary_io_u did not improve from 0.79790
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0476 - accuracy: 0.9838 - f1_score: 0.7758 - binary_io_u: 0.8194 - val_loss: 0.0479 - val_accuracy: 0.9848 - val_f1_score: 0.6931 - val_binary_io_u: 0.7905 - lr: 0.0010
# Epoch 18/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9835 - f1_score: 0.7732 - binary_io_u: 0.8172
# Epoch 18: val_binary_io_u did not improve from 0.79790
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0484 - accuracy: 0.9834 - f1_score: 0.7721 - binary_io_u: 0.8164 - val_loss: 0.0508 - val_accuracy: 0.9842 - val_f1_score: 0.6794 - val_binary_io_u: 0.7853 - lr: 0.0010
# Epoch 19/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9832 - f1_score: 0.7699 - binary_io_u: 0.8128
# Epoch 19: val_binary_io_u did not improve from 0.79790
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0490 - accuracy: 0.9832 - f1_score: 0.7705 - binary_io_u: 0.8133 - val_loss: 0.0476 - val_accuracy: 0.9835 - val_f1_score: 0.7035 - val_binary_io_u: 0.7902 - lr: 0.0010
# Epoch 20/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9844 - f1_score: 0.7874 - binary_io_u: 0.8265
# Epoch 20: val_binary_io_u improved from 0.79790 to 0.80304, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0458 - accuracy: 0.9844 - f1_score: 0.7873 - binary_io_u: 0.8263 - val_loss: 0.0454 - val_accuracy: 0.9851 - val_f1_score: 0.7190 - val_binary_io_u: 0.8030 - lr: 0.0010
# Epoch 21/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9844 - f1_score: 0.7883 - binary_io_u: 0.8272
# Epoch 21: val_binary_io_u did not improve from 0.80304
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0456 - accuracy: 0.9845 - f1_score: 0.7883 - binary_io_u: 0.8272 - val_loss: 0.0472 - val_accuracy: 0.9846 - val_f1_score: 0.6974 - val_binary_io_u: 0.7941 - lr: 0.0010
# Epoch 22/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9843 - f1_score: 0.7874 - binary_io_u: 0.8255
# Epoch 22: val_binary_io_u did not improve from 0.80304
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0459 - accuracy: 0.9844 - f1_score: 0.7878 - binary_io_u: 0.8257 - val_loss: 0.0472 - val_accuracy: 0.9841 - val_f1_score: 0.6586 - val_binary_io_u: 0.7729 - lr: 0.0010
# Epoch 23/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9839 - f1_score: 0.7774 - binary_io_u: 0.8208
# Epoch 23: val_binary_io_u improved from 0.80304 to 0.80584, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0472 - accuracy: 0.9839 - f1_score: 0.7771 - binary_io_u: 0.8205 - val_loss: 0.0453 - val_accuracy: 0.9851 - val_f1_score: 0.7191 - val_binary_io_u: 0.8058 - lr: 0.0010
# Epoch 24/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9844 - f1_score: 0.7918 - binary_io_u: 0.8265
# Epoch 24: val_binary_io_u did not improve from 0.80584
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0457 - accuracy: 0.9844 - f1_score: 0.7917 - binary_io_u: 0.8264 - val_loss: 0.0466 - val_accuracy: 0.9842 - val_f1_score: 0.7273 - val_binary_io_u: 0.8051 - lr: 0.0010
# Epoch 25/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9850 - f1_score: 0.7965 - binary_io_u: 0.8320
# Epoch 25: val_binary_io_u improved from 0.80584 to 0.80659, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0441 - accuracy: 0.9849 - f1_score: 0.7960 - binary_io_u: 0.8317 - val_loss: 0.0437 - val_accuracy: 0.9854 - val_f1_score: 0.7182 - val_binary_io_u: 0.8066 - lr: 0.0010
# Epoch 26/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9853 - f1_score: 0.7954 - binary_io_u: 0.8358
# Epoch 26: val_binary_io_u improved from 0.80659 to 0.80846, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0429 - accuracy: 0.9854 - f1_score: 0.7951 - binary_io_u: 0.8356 - val_loss: 0.0439 - val_accuracy: 0.9852 - val_f1_score: 0.7274 - val_binary_io_u: 0.8085 - lr: 0.0010
# Epoch 27/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9849 - f1_score: 0.7907 - binary_io_u: 0.8313
# Epoch 27: val_binary_io_u did not improve from 0.80846
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0441 - accuracy: 0.9849 - f1_score: 0.7900 - binary_io_u: 0.8308 - val_loss: 0.0440 - val_accuracy: 0.9852 - val_f1_score: 0.7054 - val_binary_io_u: 0.7997 - lr: 0.0010
# Epoch 28/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0426 - accuracy: 0.9854 - f1_score: 0.8020 - binary_io_u: 0.8362
# Epoch 28: val_binary_io_u did not improve from 0.80846
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0426 - accuracy: 0.9854 - f1_score: 0.8024 - binary_io_u: 0.8365 - val_loss: 0.0437 - val_accuracy: 0.9855 - val_f1_score: 0.7204 - val_binary_io_u: 0.8084 - lr: 0.0010
# Epoch 29/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9859 - f1_score: 0.8035 - binary_io_u: 0.8410
# Epoch 29: val_binary_io_u improved from 0.80846 to 0.80924, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0414 - accuracy: 0.9859 - f1_score: 0.8038 - binary_io_u: 0.8411 - val_loss: 0.0446 - val_accuracy: 0.9851 - val_f1_score: 0.7290 - val_binary_io_u: 0.8092 - lr: 0.0010
# Epoch 30/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9860 - f1_score: 0.8103 - binary_io_u: 0.8419
# Epoch 30: val_binary_io_u improved from 0.80924 to 0.80943, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0409 - accuracy: 0.9860 - f1_score: 0.8108 - binary_io_u: 0.8422 - val_loss: 0.0427 - val_accuracy: 0.9858 - val_f1_score: 0.7201 - val_binary_io_u: 0.8094 - lr: 0.0010
# Epoch 31/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9864 - f1_score: 0.8114 - binary_io_u: 0.8461
# Epoch 31: val_binary_io_u improved from 0.80943 to 0.81642, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0397 - accuracy: 0.9864 - f1_score: 0.8116 - binary_io_u: 0.8462 - val_loss: 0.0419 - val_accuracy: 0.9862 - val_f1_score: 0.7311 - val_binary_io_u: 0.8164 - lr: 0.0010
# Epoch 32/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9863 - f1_score: 0.8113 - binary_io_u: 0.8457
# Epoch 32: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0399 - accuracy: 0.9863 - f1_score: 0.8112 - binary_io_u: 0.8455 - val_loss: 0.0436 - val_accuracy: 0.9859 - val_f1_score: 0.7127 - val_binary_io_u: 0.8033 - lr: 0.0010
# Epoch 33/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0417 - accuracy: 0.9857 - f1_score: 0.8046 - binary_io_u: 0.8386
# Epoch 33: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0416 - accuracy: 0.9857 - f1_score: 0.8051 - binary_io_u: 0.8389 - val_loss: 0.0419 - val_accuracy: 0.9863 - val_f1_score: 0.7130 - val_binary_io_u: 0.8074 - lr: 0.0010
# Epoch 34/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0401 - accuracy: 0.9862 - f1_score: 0.8087 - binary_io_u: 0.8439
# Epoch 34: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0400 - accuracy: 0.9862 - f1_score: 0.8088 - binary_io_u: 0.8439 - val_loss: 0.0424 - val_accuracy: 0.9859 - val_f1_score: 0.7312 - val_binary_io_u: 0.8118 - lr: 0.0010
# Epoch 35/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9858 - f1_score: 0.8046 - binary_io_u: 0.8397
# Epoch 35: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0412 - accuracy: 0.9857 - f1_score: 0.8047 - binary_io_u: 0.8396 - val_loss: 0.0419 - val_accuracy: 0.9860 - val_f1_score: 0.7231 - val_binary_io_u: 0.8115 - lr: 0.0010
# Epoch 36/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9867 - f1_score: 0.8189 - binary_io_u: 0.8494
# Epoch 36: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0390 - accuracy: 0.9867 - f1_score: 0.8189 - binary_io_u: 0.8494 - val_loss: 0.0412 - val_accuracy: 0.9862 - val_f1_score: 0.7228 - val_binary_io_u: 0.8133 - lr: 0.0010
# Epoch 37/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9870 - f1_score: 0.8195 - binary_io_u: 0.8524
# Epoch 37: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0378 - accuracy: 0.9870 - f1_score: 0.8187 - binary_io_u: 0.8519 - val_loss: 0.0407 - val_accuracy: 0.9866 - val_f1_score: 0.7253 - val_binary_io_u: 0.8157 - lr: 0.0010
# Epoch 38/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9876 - f1_score: 0.8314 - binary_io_u: 0.8582
# Epoch 38: val_binary_io_u did not improve from 0.81642
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0358 - accuracy: 0.9876 - f1_score: 0.8316 - binary_io_u: 0.8584 - val_loss: 0.0432 - val_accuracy: 0.9865 - val_f1_score: 0.7155 - val_binary_io_u: 0.8094 - lr: 0.0010
# Epoch 39/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9871 - f1_score: 0.8201 - binary_io_u: 0.8533
# Epoch 39: val_binary_io_u improved from 0.81642 to 0.81772, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0374 - accuracy: 0.9871 - f1_score: 0.8200 - binary_io_u: 0.8532 - val_loss: 0.0416 - val_accuracy: 0.9860 - val_f1_score: 0.7357 - val_binary_io_u: 0.8177 - lr: 0.0010
# Epoch 40/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9872 - f1_score: 0.8251 - binary_io_u: 0.8549
# Epoch 40: val_binary_io_u improved from 0.81772 to 0.81937, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0364 - accuracy: 0.9872 - f1_score: 0.8245 - binary_io_u: 0.8545 - val_loss: 0.0403 - val_accuracy: 0.9866 - val_f1_score: 0.7390 - val_binary_io_u: 0.8194 - lr: 0.0010
# Epoch 41/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9878 - f1_score: 0.8351 - binary_io_u: 0.8609
# Epoch 41: val_binary_io_u did not improve from 0.81937
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0352 - accuracy: 0.9878 - f1_score: 0.8345 - binary_io_u: 0.8607 - val_loss: 0.0407 - val_accuracy: 0.9863 - val_f1_score: 0.7285 - val_binary_io_u: 0.8150 - lr: 0.0010
# Epoch 42/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9877 - f1_score: 0.8263 - binary_io_u: 0.8595
# Epoch 42: val_binary_io_u improved from 0.81937 to 0.82301, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0348 - accuracy: 0.9878 - f1_score: 0.8272 - binary_io_u: 0.8602 - val_loss: 0.0414 - val_accuracy: 0.9864 - val_f1_score: 0.7457 - val_binary_io_u: 0.8230 - lr: 0.0010
# Epoch 43/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9878 - f1_score: 0.8356 - binary_io_u: 0.8604
# Epoch 43: val_binary_io_u did not improve from 0.82301
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0345 - accuracy: 0.9878 - f1_score: 0.8357 - binary_io_u: 0.8604 - val_loss: 0.0409 - val_accuracy: 0.9866 - val_f1_score: 0.7310 - val_binary_io_u: 0.8143 - lr: 0.0010
# Epoch 44/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0341 - accuracy: 0.9881 - f1_score: 0.8335 - binary_io_u: 0.8647
# Epoch 44: val_binary_io_u did not improve from 0.82301
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0340 - accuracy: 0.9882 - f1_score: 0.8333 - binary_io_u: 0.8646 - val_loss: 0.0413 - val_accuracy: 0.9867 - val_f1_score: 0.7216 - val_binary_io_u: 0.8136 - lr: 0.0010
# Epoch 45/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9881 - f1_score: 0.8389 - binary_io_u: 0.8644
# Epoch 45: val_binary_io_u did not improve from 0.82301
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0337 - accuracy: 0.9881 - f1_score: 0.8387 - binary_io_u: 0.8643 - val_loss: 0.0399 - val_accuracy: 0.9868 - val_f1_score: 0.7367 - val_binary_io_u: 0.8213 - lr: 0.0010
# Epoch 46/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9886 - f1_score: 0.8433 - binary_io_u: 0.8692
# Epoch 46: val_binary_io_u did not improve from 0.82301
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0319 - accuracy: 0.9886 - f1_score: 0.8435 - binary_io_u: 0.8693 - val_loss: 0.0416 - val_accuracy: 0.9868 - val_f1_score: 0.7400 - val_binary_io_u: 0.8220 - lr: 0.0010
# Epoch 47/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9887 - f1_score: 0.8454 - binary_io_u: 0.8699
# Epoch 47: val_binary_io_u improved from 0.82301 to 0.82345, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0322 - accuracy: 0.9887 - f1_score: 0.8453 - binary_io_u: 0.8698 - val_loss: 0.0396 - val_accuracy: 0.9870 - val_f1_score: 0.7447 - val_binary_io_u: 0.8234 - lr: 0.0010
# Epoch 48/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9889 - f1_score: 0.8491 - binary_io_u: 0.8728
# Epoch 48: val_binary_io_u improved from 0.82345 to 0.82566, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0310 - accuracy: 0.9890 - f1_score: 0.8492 - binary_io_u: 0.8728 - val_loss: 0.0396 - val_accuracy: 0.9870 - val_f1_score: 0.7465 - val_binary_io_u: 0.8257 - lr: 0.0010
# Epoch 49/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9889 - f1_score: 0.8486 - binary_io_u: 0.8727
# Epoch 49: val_binary_io_u did not improve from 0.82566
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0307 - accuracy: 0.9889 - f1_score: 0.8483 - binary_io_u: 0.8725 - val_loss: 0.0410 - val_accuracy: 0.9868 - val_f1_score: 0.7240 - val_binary_io_u: 0.8182 - lr: 0.0010
# Epoch 50/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9890 - f1_score: 0.8497 - binary_io_u: 0.8740
# Epoch 50: val_binary_io_u did not improve from 0.82566
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0306 - accuracy: 0.9890 - f1_score: 0.8497 - binary_io_u: 0.8739 - val_loss: 0.0398 - val_accuracy: 0.9871 - val_f1_score: 0.7395 - val_binary_io_u: 0.8227 - lr: 0.0010
# Epoch 51/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0291 - accuracy: 0.9895 - f1_score: 0.8543 - binary_io_u: 0.8783
# Epoch 51: val_binary_io_u did not improve from 0.82566
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0291 - accuracy: 0.9895 - f1_score: 0.8546 - binary_io_u: 0.8785 - val_loss: 0.0419 - val_accuracy: 0.9870 - val_f1_score: 0.7471 - val_binary_io_u: 0.8255 - lr: 0.0010
# Epoch 52/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9888 - f1_score: 0.8495 - binary_io_u: 0.8708
# Epoch 52: val_binary_io_u did not improve from 0.82566
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0316 - accuracy: 0.9888 - f1_score: 0.8498 - binary_io_u: 0.8711 - val_loss: 0.0409 - val_accuracy: 0.9868 - val_f1_score: 0.7265 - val_binary_io_u: 0.8161 - lr: 0.0010
# Epoch 53/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9899 - f1_score: 0.8600 - binary_io_u: 0.8835
# Epoch 53: val_binary_io_u improved from 0.82566 to 0.82942, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0277 - accuracy: 0.9899 - f1_score: 0.8598 - binary_io_u: 0.8832 - val_loss: 0.0389 - val_accuracy: 0.9876 - val_f1_score: 0.7503 - val_binary_io_u: 0.8294 - lr: 5.0000e-04
# Epoch 54/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9906 - f1_score: 0.8690 - binary_io_u: 0.8900
# Epoch 54: val_binary_io_u did not improve from 0.82942
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0256 - accuracy: 0.9905 - f1_score: 0.8692 - binary_io_u: 0.8901 - val_loss: 0.0405 - val_accuracy: 0.9875 - val_f1_score: 0.7519 - val_binary_io_u: 0.8289 - lr: 5.0000e-04
# Epoch 55/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9907 - f1_score: 0.8715 - binary_io_u: 0.8922
# Epoch 55: val_binary_io_u improved from 0.82942 to 0.83087, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0249 - accuracy: 0.9907 - f1_score: 0.8718 - binary_io_u: 0.8923 - val_loss: 0.0397 - val_accuracy: 0.9876 - val_f1_score: 0.7542 - val_binary_io_u: 0.8309 - lr: 5.0000e-04
# Epoch 56/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 0.9910 - f1_score: 0.8757 - binary_io_u: 0.8949
# Epoch 56: val_binary_io_u did not improve from 0.83087
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0241 - accuracy: 0.9910 - f1_score: 0.8760 - binary_io_u: 0.8950 - val_loss: 0.0405 - val_accuracy: 0.9876 - val_f1_score: 0.7475 - val_binary_io_u: 0.8286 - lr: 5.0000e-04
# Epoch 57/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0235 - accuracy: 0.9911 - f1_score: 0.8799 - binary_io_u: 0.8968
# Epoch 57: val_binary_io_u improved from 0.83087 to 0.83202, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_1500_without_norm/saved_models/best_Basic_Unet__without_drop_1500_without_norm.h5
# 120/120 [==============================] - 4s 35ms/step - loss: 0.0235 - accuracy: 0.9911 - f1_score: 0.8796 - binary_io_u: 0.8966 - val_loss: 0.0402 - val_accuracy: 0.9877 - val_f1_score: 0.7576 - val_binary_io_u: 0.8320 - lr: 5.0000e-04
# Epoch 58/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9913 - f1_score: 0.8849 - binary_io_u: 0.8993
# Epoch 58: val_binary_io_u did not improve from 0.83202
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0228 - accuracy: 0.9913 - f1_score: 0.8843 - binary_io_u: 0.8989 - val_loss: 0.0405 - val_accuracy: 0.9876 - val_f1_score: 0.7568 - val_binary_io_u: 0.8311 - lr: 5.0000e-04
# Epoch 59/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9916 - f1_score: 0.8891 - binary_io_u: 0.9026
# Epoch 59: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0217 - accuracy: 0.9917 - f1_score: 0.8896 - binary_io_u: 0.9029 - val_loss: 0.0423 - val_accuracy: 0.9876 - val_f1_score: 0.7528 - val_binary_io_u: 0.8300 - lr: 2.5000e-04
# Epoch 60/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9919 - f1_score: 0.8926 - binary_io_u: 0.9056
# Epoch 60: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0209 - accuracy: 0.9919 - f1_score: 0.8929 - binary_io_u: 0.9058 - val_loss: 0.0429 - val_accuracy: 0.9876 - val_f1_score: 0.7569 - val_binary_io_u: 0.8308 - lr: 2.5000e-04
# Epoch 61/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0205 - accuracy: 0.9921 - f1_score: 0.8924 - binary_io_u: 0.9074
# Epoch 61: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0205 - accuracy: 0.9920 - f1_score: 0.8918 - binary_io_u: 0.9070 - val_loss: 0.0427 - val_accuracy: 0.9876 - val_f1_score: 0.7543 - val_binary_io_u: 0.8302 - lr: 2.5000e-04
# Epoch 62/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9922 - f1_score: 0.8972 - binary_io_u: 0.9085
# Epoch 62: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0201 - accuracy: 0.9922 - f1_score: 0.8972 - binary_io_u: 0.9085 - val_loss: 0.0435 - val_accuracy: 0.9875 - val_f1_score: 0.7518 - val_binary_io_u: 0.8289 - lr: 2.5000e-04
# Epoch 63/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9923 - f1_score: 0.8962 - binary_io_u: 0.9104
# Epoch 63: val_binary_io_u did not improve from 0.83202
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0197 - accuracy: 0.9923 - f1_score: 0.8951 - binary_io_u: 0.9097 - val_loss: 0.0443 - val_accuracy: 0.9875 - val_f1_score: 0.7539 - val_binary_io_u: 0.8295 - lr: 2.5000e-04
# Epoch 64/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9925 - f1_score: 0.9000 - binary_io_u: 0.9121
# Epoch 64: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0191 - accuracy: 0.9925 - f1_score: 0.8998 - binary_io_u: 0.9120 - val_loss: 0.0452 - val_accuracy: 0.9875 - val_f1_score: 0.7532 - val_binary_io_u: 0.8294 - lr: 1.2500e-04
# Epoch 65/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0190 - accuracy: 0.9925 - f1_score: 0.8995 - binary_io_u: 0.9127
# Epoch 65: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0189 - accuracy: 0.9926 - f1_score: 0.8999 - binary_io_u: 0.9130 - val_loss: 0.0456 - val_accuracy: 0.9875 - val_f1_score: 0.7520 - val_binary_io_u: 0.8286 - lr: 1.2500e-04
# Epoch 66/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0185 - accuracy: 0.9927 - f1_score: 0.9030 - binary_io_u: 0.9142
# Epoch 66: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0186 - accuracy: 0.9927 - f1_score: 0.9030 - binary_io_u: 0.9142 - val_loss: 0.0454 - val_accuracy: 0.9875 - val_f1_score: 0.7550 - val_binary_io_u: 0.8298 - lr: 1.2500e-04
# Epoch 67/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0183 - accuracy: 0.9928 - f1_score: 0.9043 - binary_io_u: 0.9154
# Epoch 67: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0183 - accuracy: 0.9928 - f1_score: 0.9045 - binary_io_u: 0.9154 - val_loss: 0.0459 - val_accuracy: 0.9874 - val_f1_score: 0.7531 - val_binary_io_u: 0.8287 - lr: 1.2500e-04
# Epoch 68/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9928 - f1_score: 0.9051 - binary_io_u: 0.9164
# Epoch 68: val_binary_io_u did not improve from 0.83202
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0181 - accuracy: 0.9929 - f1_score: 0.9053 - binary_io_u: 0.9165 - val_loss: 0.0466 - val_accuracy: 0.9874 - val_f1_score: 0.7545 - val_binary_io_u: 0.8292 - lr: 1.2500e-04
# Epoch 69/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9930 - f1_score: 0.9088 - binary_io_u: 0.9183
# Epoch 69: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0178 - accuracy: 0.9930 - f1_score: 0.9080 - binary_io_u: 0.9179 - val_loss: 0.0471 - val_accuracy: 0.9874 - val_f1_score: 0.7529 - val_binary_io_u: 0.8284 - lr: 6.2500e-05
# Epoch 70/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9931 - f1_score: 0.9099 - binary_io_u: 0.9187
# Epoch 70: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0176 - accuracy: 0.9931 - f1_score: 0.9099 - binary_io_u: 0.9187 - val_loss: 0.0473 - val_accuracy: 0.9873 - val_f1_score: 0.7524 - val_binary_io_u: 0.8281 - lr: 6.2500e-05
# Epoch 71/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9931 - f1_score: 0.9082 - binary_io_u: 0.9190
# Epoch 71: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0175 - accuracy: 0.9931 - f1_score: 0.9086 - binary_io_u: 0.9192 - val_loss: 0.0482 - val_accuracy: 0.9873 - val_f1_score: 0.7508 - val_binary_io_u: 0.8274 - lr: 6.2500e-05
# Epoch 72/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9931 - f1_score: 0.9094 - binary_io_u: 0.9192
# Epoch 72: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0174 - accuracy: 0.9931 - f1_score: 0.9098 - binary_io_u: 0.9196 - val_loss: 0.0481 - val_accuracy: 0.9873 - val_f1_score: 0.7521 - val_binary_io_u: 0.8280 - lr: 6.2500e-05
# Epoch 73/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9932 - f1_score: 0.9074 - binary_io_u: 0.9198
# Epoch 73: val_binary_io_u did not improve from 0.83202
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0173 - accuracy: 0.9932 - f1_score: 0.9079 - binary_io_u: 0.9202 - val_loss: 0.0480 - val_accuracy: 0.9873 - val_f1_score: 0.7526 - val_binary_io_u: 0.8280 - lr: 6.2500e-05
# Epoch 74/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9933 - f1_score: 0.9116 - binary_io_u: 0.9209
# Epoch 74: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0171 - accuracy: 0.9933 - f1_score: 0.9118 - binary_io_u: 0.9210 - val_loss: 0.0486 - val_accuracy: 0.9873 - val_f1_score: 0.7517 - val_binary_io_u: 0.8276 - lr: 3.1250e-05
# Epoch 75/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9933 - f1_score: 0.9125 - binary_io_u: 0.9216
# Epoch 75: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0171 - accuracy: 0.9933 - f1_score: 0.9122 - binary_io_u: 0.9213 - val_loss: 0.0488 - val_accuracy: 0.9873 - val_f1_score: 0.7512 - val_binary_io_u: 0.8274 - lr: 3.1250e-05
# Epoch 76/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9933 - f1_score: 0.9112 - binary_io_u: 0.9209
# Epoch 76: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0170 - accuracy: 0.9933 - f1_score: 0.9116 - binary_io_u: 0.9216 - val_loss: 0.0491 - val_accuracy: 0.9873 - val_f1_score: 0.7504 - val_binary_io_u: 0.8269 - lr: 3.1250e-05
# Epoch 77/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9933 - f1_score: 0.9115 - binary_io_u: 0.9218
# Epoch 77: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0169 - accuracy: 0.9933 - f1_score: 0.9117 - binary_io_u: 0.9219 - val_loss: 0.0490 - val_accuracy: 0.9873 - val_f1_score: 0.7518 - val_binary_io_u: 0.8276 - lr: 3.1250e-05
# Epoch 78/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9934 - f1_score: 0.9126 - binary_io_u: 0.9220
# Epoch 78: val_binary_io_u did not improve from 0.83202
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 120/120 [==============================] - 4s 33ms/step - loss: 0.0169 - accuracy: 0.9934 - f1_score: 0.9128 - binary_io_u: 0.9222 - val_loss: 0.0494 - val_accuracy: 0.9873 - val_f1_score: 0.7512 - val_binary_io_u: 0.8273 - lr: 3.1250e-05
# Epoch 79/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0168 - accuracy: 0.9934 - f1_score: 0.9123 - binary_io_u: 0.9225
# Epoch 79: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0168 - accuracy: 0.9934 - f1_score: 0.9125 - binary_io_u: 0.9226 - val_loss: 0.0495 - val_accuracy: 0.9873 - val_f1_score: 0.7509 - val_binary_io_u: 0.8271 - lr: 1.5625e-05
# Epoch 80/80
# 119/120 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9934 - f1_score: 0.9142 - binary_io_u: 0.9227
# Epoch 80: val_binary_io_u did not improve from 0.83202
# 120/120 [==============================] - 4s 34ms/step - loss: 0.0168 - accuracy: 0.9934 - f1_score: 0.9142 - binary_io_u: 0.9227 - val_loss: 0.0496 - val_accuracy: 0.9873 - val_f1_score: 0.7511 - val_binary_io_u: 0.8271 - lr: 1.5625e-05

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 18]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 1s 508ms/step - loss: 0.0363 - accuracy: 0.9895 - f1_score: 0.8576 - binary_io_u: 0.8699

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#                                    Model Name      Loss  Accuracy  Precision  \
# 0  Basic_Unet__without_drop_1500_without_norm  0.036261  0.989532   0.870358
#
#      Recall  F1-Score       IoU
# 0  0.845214  0.857602  0.830453

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
