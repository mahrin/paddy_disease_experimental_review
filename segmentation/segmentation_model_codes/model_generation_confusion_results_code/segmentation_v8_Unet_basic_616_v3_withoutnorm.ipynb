# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# from keras import ops# For deeplab3

# import keras_cv # basnet

# from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Basic_Unet__without_drop_616_v3_without norm'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 70

TOTAL_DATA = 616
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 5
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 616/616 [00:00<00:00, 18365.21it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### Basic basic_unet

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    x = Activation('relu')(x)

    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    x = Activation('relu')(x)

    return x

def get_basic_unet(n_filters = 16):
    """
    Version of U-Net with dropout and size preservation (padding= 'same')--from class note
    """
    input_img = Input(shape=MODEL_INPUT_SIZE)
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size=3)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = conv2d_block(p1, n_filters * 2, kernel_size=3)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = conv2d_block(p2, n_filters * 4, kernel_size=3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = conv2d_block(p3, n_filters * 8, kernel_size=3)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = conv2d_block(p4, n_filters * 16, kernel_size=3)

    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides=(2, 2), padding='same')(c5)
    u6 = Concatenate()([u6, c4])
    c6 = conv2d_block(u6, n_filters * 8, kernel_size=3)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = Concatenate()([u7, c3])
    c7 = conv2d_block(u7, n_filters * 4, kernel_size=3)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides=(2, 2), padding='same')(c7)
    u8 = Concatenate()([u8, c2])
    c8 = conv2d_block(u8, n_filters * 2, kernel_size=3)

    u9 = Conv2DTranspose(n_filters, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = Concatenate()([u9, c1])
    c9 = conv2d_block(u9, n_filters, kernel_size=3)

    outputs = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['activation[0][0]']
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['activation_2[0][0]']
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)   (None, 64, 64, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          147584    ['activation_6[0][0]']
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          590080    ['activation_8[0][0]']
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          295040    ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate[0][0]']
#
#  activation_10 (Activation)  (None, 32, 32, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 32, 32, 128)          0         ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           73792     ['activation_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_1[0][0]']
#
#  activation_12 (Activation)  (None, 64, 64, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)           36928     ['activation_12[0][0]']
#
#  activation_13 (Activation)  (None, 64, 64, 64)           0         ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 32)         18464     ['activation_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_2[0][0]']
#
#  activation_14 (Activation)  (None, 128, 128, 32)         0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 32)         9248      ['activation_14[0][0]']
#
#  activation_15 (Activation)  (None, 128, 128, 32)         0         ['conv2d_15[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 16)         4624      ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_3[0][0]']
#
#  activation_16 (Activation)  (None, 256, 256, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 16)         2320      ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 256, 256, 16)         0         ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 1)          17        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 2158705 (8.23 MB)
# Trainable params: 2158705 (8.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/70
# 50/50 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.9294 - f1_score: 0.0047 - binary_io_u: 0.4734
# Epoch 1: val_binary_io_u improved from -inf to 0.47730, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 23s 160ms/step - loss: 0.2406 - accuracy: 0.9294 - f1_score: 0.0047 - binary_io_u: 0.4734 - val_loss: 0.1508 - val_accuracy: 0.9546 - val_f1_score: 0.0000e+00 - val_binary_io_u: 0.4773 - lr: 0.0010
# Epoch 2/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.1270 - accuracy: 0.9536 - f1_score: 0.0011 - binary_io_u: 0.4771
# Epoch 2: val_binary_io_u improved from 0.47730 to 0.48045, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 2s 48ms/step - loss: 0.1272 - accuracy: 0.9537 - f1_score: 0.0011 - binary_io_u: 0.4771 - val_loss: 0.1063 - val_accuracy: 0.9549 - val_f1_score: 0.0101 - val_binary_io_u: 0.4805 - lr: 0.0010
# Epoch 3/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.1001 - accuracy: 0.9626 - f1_score: 0.3284 - binary_io_u: 0.6034
# Epoch 3: val_binary_io_u improved from 0.48045 to 0.71672, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0999 - accuracy: 0.9627 - f1_score: 0.3219 - binary_io_u: 0.6034 - val_loss: 0.0842 - val_accuracy: 0.9740 - val_f1_score: 0.5665 - val_binary_io_u: 0.7167 - lr: 0.0010
# Epoch 4/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0872 - accuracy: 0.9718 - f1_score: 0.6072 - binary_io_u: 0.7187
# Epoch 4: val_binary_io_u did not improve from 0.71672
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0876 - accuracy: 0.9717 - f1_score: 0.6007 - binary_io_u: 0.7179 - val_loss: 0.0778 - val_accuracy: 0.9747 - val_f1_score: 0.5618 - val_binary_io_u: 0.7143 - lr: 0.0010
# Epoch 5/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9727 - f1_score: 0.6265 - binary_io_u: 0.7333
# Epoch 5: val_binary_io_u improved from 0.71672 to 0.79435, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0810 - accuracy: 0.9728 - f1_score: 0.6176 - binary_io_u: 0.7331 - val_loss: 0.0708 - val_accuracy: 0.9797 - val_f1_score: 0.6984 - val_binary_io_u: 0.7944 - lr: 0.0010
# Epoch 6/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9729 - f1_score: 0.6389 - binary_io_u: 0.7367
# Epoch 6: val_binary_io_u did not improve from 0.79435
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0829 - accuracy: 0.9729 - f1_score: 0.6311 - binary_io_u: 0.7365 - val_loss: 0.0823 - val_accuracy: 0.9748 - val_f1_score: 0.6726 - val_binary_io_u: 0.7716 - lr: 0.0010
# Epoch 7/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0692 - accuracy: 0.9773 - f1_score: 0.7107 - binary_io_u: 0.7748
# Epoch 7: val_binary_io_u did not improve from 0.79435
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0697 - accuracy: 0.9772 - f1_score: 0.7072 - binary_io_u: 0.7742 - val_loss: 0.0835 - val_accuracy: 0.9773 - val_f1_score: 0.7110 - val_binary_io_u: 0.7884 - lr: 0.0010
# Epoch 8/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9769 - f1_score: 0.6952 - binary_io_u: 0.7694
# Epoch 8: val_binary_io_u did not improve from 0.79435
# 50/50 [==============================] - 2s 43ms/step - loss: 0.0697 - accuracy: 0.9770 - f1_score: 0.6815 - binary_io_u: 0.7691 - val_loss: 0.0731 - val_accuracy: 0.9765 - val_f1_score: 0.7085 - val_binary_io_u: 0.7884 - lr: 0.0010
# Epoch 9/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0612 - accuracy: 0.9795 - f1_score: 0.7418 - binary_io_u: 0.7955
# Epoch 9: val_binary_io_u improved from 0.79435 to 0.80847, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 3s 62ms/step - loss: 0.0615 - accuracy: 0.9794 - f1_score: 0.7433 - binary_io_u: 0.7959 - val_loss: 0.0609 - val_accuracy: 0.9814 - val_f1_score: 0.7140 - val_binary_io_u: 0.8085 - lr: 0.0010
# Epoch 10/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9799 - f1_score: 0.7469 - binary_io_u: 0.8002
# Epoch 10: val_binary_io_u did not improve from 0.80847
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0610 - accuracy: 0.9799 - f1_score: 0.7433 - binary_io_u: 0.7999 - val_loss: 0.0638 - val_accuracy: 0.9799 - val_f1_score: 0.7247 - val_binary_io_u: 0.8037 - lr: 0.0010
# Epoch 11/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0632 - accuracy: 0.9789 - f1_score: 0.7296 - binary_io_u: 0.7899
# Epoch 11: val_binary_io_u did not improve from 0.80847
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0633 - accuracy: 0.9789 - f1_score: 0.7164 - binary_io_u: 0.7894 - val_loss: 0.0631 - val_accuracy: 0.9808 - val_f1_score: 0.7207 - val_binary_io_u: 0.8062 - lr: 0.0010
# Epoch 12/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9802 - f1_score: 0.7580 - binary_io_u: 0.8028
# Epoch 12: val_binary_io_u did not improve from 0.80847
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0585 - accuracy: 0.9803 - f1_score: 0.7610 - binary_io_u: 0.8033 - val_loss: 0.0620 - val_accuracy: 0.9808 - val_f1_score: 0.7221 - val_binary_io_u: 0.8049 - lr: 0.0010
# Epoch 13/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9794 - f1_score: 0.7404 - binary_io_u: 0.7960
# Epoch 13: val_binary_io_u did not improve from 0.80847
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0595 - accuracy: 0.9795 - f1_score: 0.7434 - binary_io_u: 0.7965 - val_loss: 0.0654 - val_accuracy: 0.9792 - val_f1_score: 0.7015 - val_binary_io_u: 0.7892 - lr: 0.0010
# Epoch 14/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0581 - accuracy: 0.9801 - f1_score: 0.7615 - binary_io_u: 0.8021
# Epoch 14: val_binary_io_u did not improve from 0.80847
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0584 - accuracy: 0.9801 - f1_score: 0.7524 - binary_io_u: 0.8014 - val_loss: 0.0649 - val_accuracy: 0.9785 - val_f1_score: 0.7272 - val_binary_io_u: 0.7990 - lr: 0.0010
# Epoch 15/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0541 - accuracy: 0.9814 - f1_score: 0.7665 - binary_io_u: 0.8147
# Epoch 15: val_binary_io_u did not improve from 0.80847
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0540 - accuracy: 0.9814 - f1_score: 0.7691 - binary_io_u: 0.8148 - val_loss: 0.0636 - val_accuracy: 0.9808 - val_f1_score: 0.7103 - val_binary_io_u: 0.8012 - lr: 5.0000e-04
# Epoch 16/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9812 - f1_score: 0.7725 - binary_io_u: 0.8127
# Epoch 16: val_binary_io_u improved from 0.80847 to 0.81024, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 3s 60ms/step - loss: 0.0542 - accuracy: 0.9812 - f1_score: 0.7693 - binary_io_u: 0.8126 - val_loss: 0.0621 - val_accuracy: 0.9816 - val_f1_score: 0.7261 - val_binary_io_u: 0.8102 - lr: 5.0000e-04
# Epoch 17/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9818 - f1_score: 0.7739 - binary_io_u: 0.8172
# Epoch 17: val_binary_io_u improved from 0.81024 to 0.81410, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Basic_Unet__without_drop_616_v3_without norm/saved_models/best_Basic_Unet__without_drop_616_v3_without norm.h5
# 50/50 [==============================] - 2s 48ms/step - loss: 0.0535 - accuracy: 0.9817 - f1_score: 0.7757 - binary_io_u: 0.8178 - val_loss: 0.0607 - val_accuracy: 0.9816 - val_f1_score: 0.7337 - val_binary_io_u: 0.8141 - lr: 5.0000e-04
# Epoch 18/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9817 - f1_score: 0.7729 - binary_io_u: 0.8164
# Epoch 18: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0524 - accuracy: 0.9818 - f1_score: 0.7611 - binary_io_u: 0.8164 - val_loss: 0.0652 - val_accuracy: 0.9810 - val_f1_score: 0.7227 - val_binary_io_u: 0.8065 - lr: 5.0000e-04
# Epoch 19/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9827 - f1_score: 0.7962 - binary_io_u: 0.8265
# Epoch 19: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0502 - accuracy: 0.9828 - f1_score: 0.7942 - binary_io_u: 0.8265 - val_loss: 0.0628 - val_accuracy: 0.9809 - val_f1_score: 0.7319 - val_binary_io_u: 0.8091 - lr: 5.0000e-04
# Epoch 20/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0489 - accuracy: 0.9830 - f1_score: 0.7828 - binary_io_u: 0.8280
# Epoch 20: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0493 - accuracy: 0.9829 - f1_score: 0.7774 - binary_io_u: 0.8269 - val_loss: 0.0678 - val_accuracy: 0.9801 - val_f1_score: 0.6987 - val_binary_io_u: 0.7911 - lr: 5.0000e-04
# Epoch 21/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9832 - f1_score: 0.7926 - binary_io_u: 0.8305
# Epoch 21: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0494 - accuracy: 0.9832 - f1_score: 0.7929 - binary_io_u: 0.8306 - val_loss: 0.0657 - val_accuracy: 0.9811 - val_f1_score: 0.7121 - val_binary_io_u: 0.8018 - lr: 5.0000e-04
# Epoch 22/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0478 - accuracy: 0.9836 - f1_score: 0.7991 - binary_io_u: 0.8339
# Epoch 22: val_binary_io_u did not improve from 0.81410
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0477 - accuracy: 0.9836 - f1_score: 0.7947 - binary_io_u: 0.8337 - val_loss: 0.0633 - val_accuracy: 0.9812 - val_f1_score: 0.7271 - val_binary_io_u: 0.8073 - lr: 5.0000e-04
# Epoch 23/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0450 - accuracy: 0.9845 - f1_score: 0.8063 - binary_io_u: 0.8415
# Epoch 23: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0449 - accuracy: 0.9845 - f1_score: 0.8066 - binary_io_u: 0.8415 - val_loss: 0.0657 - val_accuracy: 0.9804 - val_f1_score: 0.7333 - val_binary_io_u: 0.8082 - lr: 2.5000e-04
# Epoch 24/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0437 - accuracy: 0.9850 - f1_score: 0.8129 - binary_io_u: 0.8468
# Epoch 24: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0437 - accuracy: 0.9850 - f1_score: 0.8135 - binary_io_u: 0.8468 - val_loss: 0.0654 - val_accuracy: 0.9809 - val_f1_score: 0.7266 - val_binary_io_u: 0.8062 - lr: 2.5000e-04
# Epoch 25/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0425 - accuracy: 0.9853 - f1_score: 0.8227 - binary_io_u: 0.8485
# Epoch 25: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0427 - accuracy: 0.9852 - f1_score: 0.8206 - binary_io_u: 0.8478 - val_loss: 0.0714 - val_accuracy: 0.9795 - val_f1_score: 0.7261 - val_binary_io_u: 0.8014 - lr: 2.5000e-04
# Epoch 26/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0449 - accuracy: 0.9845 - f1_score: 0.8089 - binary_io_u: 0.8431
# Epoch 26: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0447 - accuracy: 0.9846 - f1_score: 0.8112 - binary_io_u: 0.8433 - val_loss: 0.0675 - val_accuracy: 0.9805 - val_f1_score: 0.7311 - val_binary_io_u: 0.8071 - lr: 2.5000e-04
# Epoch 27/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9856 - f1_score: 0.8225 - binary_io_u: 0.8526
# Epoch 27: val_binary_io_u did not improve from 0.81410
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0420 - accuracy: 0.9857 - f1_score: 0.8160 - binary_io_u: 0.8523 - val_loss: 0.0667 - val_accuracy: 0.9808 - val_f1_score: 0.7323 - val_binary_io_u: 0.8064 - lr: 2.5000e-04
# Epoch 28/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0399 - accuracy: 0.9863 - f1_score: 0.8279 - binary_io_u: 0.8586
# Epoch 28: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0400 - accuracy: 0.9862 - f1_score: 0.8271 - binary_io_u: 0.8583 - val_loss: 0.0681 - val_accuracy: 0.9798 - val_f1_score: 0.7330 - val_binary_io_u: 0.8047 - lr: 1.2500e-04
# Epoch 29/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9866 - f1_score: 0.8289 - binary_io_u: 0.8621
# Epoch 29: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 43ms/step - loss: 0.0389 - accuracy: 0.9867 - f1_score: 0.8271 - binary_io_u: 0.8620 - val_loss: 0.0704 - val_accuracy: 0.9802 - val_f1_score: 0.7270 - val_binary_io_u: 0.8021 - lr: 1.2500e-04
# Epoch 30/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9868 - f1_score: 0.8355 - binary_io_u: 0.8634
# Epoch 30: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0381 - accuracy: 0.9868 - f1_score: 0.8369 - binary_io_u: 0.8636 - val_loss: 0.0705 - val_accuracy: 0.9804 - val_f1_score: 0.7287 - val_binary_io_u: 0.8034 - lr: 1.2500e-04
# Epoch 31/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0375 - accuracy: 0.9870 - f1_score: 0.8402 - binary_io_u: 0.8656
# Epoch 31: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0377 - accuracy: 0.9870 - f1_score: 0.8399 - binary_io_u: 0.8654 - val_loss: 0.0704 - val_accuracy: 0.9804 - val_f1_score: 0.7288 - val_binary_io_u: 0.8035 - lr: 1.2500e-04
# Epoch 32/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0371 - accuracy: 0.9872 - f1_score: 0.8393 - binary_io_u: 0.8662
# Epoch 32: val_binary_io_u did not improve from 0.81410
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0371 - accuracy: 0.9872 - f1_score: 0.8416 - binary_io_u: 0.8671 - val_loss: 0.0711 - val_accuracy: 0.9804 - val_f1_score: 0.7226 - val_binary_io_u: 0.8013 - lr: 1.2500e-04
# Epoch 33/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9874 - f1_score: 0.8446 - binary_io_u: 0.8693
# Epoch 33: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0363 - accuracy: 0.9875 - f1_score: 0.8412 - binary_io_u: 0.8693 - val_loss: 0.0722 - val_accuracy: 0.9800 - val_f1_score: 0.7296 - val_binary_io_u: 0.8030 - lr: 6.2500e-05
# Epoch 34/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0355 - accuracy: 0.9877 - f1_score: 0.8498 - binary_io_u: 0.8725
# Epoch 34: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0355 - accuracy: 0.9877 - f1_score: 0.8497 - binary_io_u: 0.8725 - val_loss: 0.0740 - val_accuracy: 0.9801 - val_f1_score: 0.7207 - val_binary_io_u: 0.7984 - lr: 6.2500e-05
# Epoch 35/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9879 - f1_score: 0.8496 - binary_io_u: 0.8734
# Epoch 35: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0351 - accuracy: 0.9879 - f1_score: 0.8487 - binary_io_u: 0.8733 - val_loss: 0.0733 - val_accuracy: 0.9798 - val_f1_score: 0.7268 - val_binary_io_u: 0.8009 - lr: 6.2500e-05
# Epoch 36/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9880 - f1_score: 0.8569 - binary_io_u: 0.8749
# Epoch 36: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0345 - accuracy: 0.9880 - f1_score: 0.8586 - binary_io_u: 0.8753 - val_loss: 0.0741 - val_accuracy: 0.9800 - val_f1_score: 0.7241 - val_binary_io_u: 0.8002 - lr: 6.2500e-05
# Epoch 37/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9881 - f1_score: 0.8571 - binary_io_u: 0.8761
# Epoch 37: val_binary_io_u did not improve from 0.81410
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0343 - accuracy: 0.9882 - f1_score: 0.8590 - binary_io_u: 0.8763 - val_loss: 0.0737 - val_accuracy: 0.9800 - val_f1_score: 0.7256 - val_binary_io_u: 0.8001 - lr: 6.2500e-05
# Epoch 38/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9883 - f1_score: 0.8578 - binary_io_u: 0.8778
# Epoch 38: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0337 - accuracy: 0.9883 - f1_score: 0.8586 - binary_io_u: 0.8779 - val_loss: 0.0753 - val_accuracy: 0.9797 - val_f1_score: 0.7243 - val_binary_io_u: 0.7993 - lr: 3.1250e-05
# Epoch 39/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9884 - f1_score: 0.8558 - binary_io_u: 0.8787
# Epoch 39: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0333 - accuracy: 0.9884 - f1_score: 0.8565 - binary_io_u: 0.8788 - val_loss: 0.0756 - val_accuracy: 0.9798 - val_f1_score: 0.7230 - val_binary_io_u: 0.7982 - lr: 3.1250e-05
# Epoch 40/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0330 - accuracy: 0.9885 - f1_score: 0.8592 - binary_io_u: 0.8793
# Epoch 40: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0331 - accuracy: 0.9885 - f1_score: 0.8599 - binary_io_u: 0.8795 - val_loss: 0.0758 - val_accuracy: 0.9798 - val_f1_score: 0.7226 - val_binary_io_u: 0.7988 - lr: 3.1250e-05
# Epoch 41/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9886 - f1_score: 0.8571 - binary_io_u: 0.8800
# Epoch 41: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0329 - accuracy: 0.9885 - f1_score: 0.8581 - binary_io_u: 0.8802 - val_loss: 0.0763 - val_accuracy: 0.9796 - val_f1_score: 0.7226 - val_binary_io_u: 0.7980 - lr: 3.1250e-05
# Epoch 42/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9886 - f1_score: 0.8622 - binary_io_u: 0.8810
# Epoch 42: val_binary_io_u did not improve from 0.81410
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0326 - accuracy: 0.9887 - f1_score: 0.8634 - binary_io_u: 0.8811 - val_loss: 0.0764 - val_accuracy: 0.9798 - val_f1_score: 0.7226 - val_binary_io_u: 0.7985 - lr: 3.1250e-05
# Epoch 43/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9888 - f1_score: 0.8613 - binary_io_u: 0.8821
# Epoch 43: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0323 - accuracy: 0.9887 - f1_score: 0.8604 - binary_io_u: 0.8819 - val_loss: 0.0771 - val_accuracy: 0.9796 - val_f1_score: 0.7233 - val_binary_io_u: 0.7982 - lr: 1.5625e-05
# Epoch 44/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9888 - f1_score: 0.8625 - binary_io_u: 0.8829
# Epoch 44: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0322 - accuracy: 0.9888 - f1_score: 0.8607 - binary_io_u: 0.8827 - val_loss: 0.0771 - val_accuracy: 0.9797 - val_f1_score: 0.7216 - val_binary_io_u: 0.7976 - lr: 1.5625e-05
# Epoch 45/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9888 - f1_score: 0.8615 - binary_io_u: 0.8823
# Epoch 45: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0321 - accuracy: 0.9888 - f1_score: 0.8626 - binary_io_u: 0.8824 - val_loss: 0.0769 - val_accuracy: 0.9797 - val_f1_score: 0.7226 - val_binary_io_u: 0.7984 - lr: 1.5625e-05
# Epoch 46/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9888 - f1_score: 0.8644 - binary_io_u: 0.8833
# Epoch 46: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0319 - accuracy: 0.9889 - f1_score: 0.8655 - binary_io_u: 0.8834 - val_loss: 0.0774 - val_accuracy: 0.9797 - val_f1_score: 0.7221 - val_binary_io_u: 0.7981 - lr: 1.5625e-05
# Epoch 47/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9889 - f1_score: 0.8674 - binary_io_u: 0.8836
# Epoch 47: val_binary_io_u did not improve from 0.81410
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0318 - accuracy: 0.9889 - f1_score: 0.8664 - binary_io_u: 0.8835 - val_loss: 0.0775 - val_accuracy: 0.9797 - val_f1_score: 0.7220 - val_binary_io_u: 0.7979 - lr: 1.5625e-05
# Epoch 48/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9890 - f1_score: 0.8664 - binary_io_u: 0.8848
# Epoch 48: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0316 - accuracy: 0.9889 - f1_score: 0.8601 - binary_io_u: 0.8842 - val_loss: 0.0779 - val_accuracy: 0.9796 - val_f1_score: 0.7207 - val_binary_io_u: 0.7970 - lr: 7.8125e-06
# Epoch 49/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9890 - f1_score: 0.8693 - binary_io_u: 0.8846
# Epoch 49: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0316 - accuracy: 0.9890 - f1_score: 0.8615 - binary_io_u: 0.8840 - val_loss: 0.0777 - val_accuracy: 0.9796 - val_f1_score: 0.7225 - val_binary_io_u: 0.7980 - lr: 7.8125e-06
# Epoch 50/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9890 - f1_score: 0.8602 - binary_io_u: 0.8843
# Epoch 50: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0315 - accuracy: 0.9890 - f1_score: 0.8612 - binary_io_u: 0.8844 - val_loss: 0.0779 - val_accuracy: 0.9796 - val_f1_score: 0.7212 - val_binary_io_u: 0.7974 - lr: 7.8125e-06
# Epoch 51/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9890 - f1_score: 0.8635 - binary_io_u: 0.8846
# Epoch 51: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0315 - accuracy: 0.9890 - f1_score: 0.8632 - binary_io_u: 0.8845 - val_loss: 0.0780 - val_accuracy: 0.9796 - val_f1_score: 0.7217 - val_binary_io_u: 0.7973 - lr: 7.8125e-06
# Epoch 52/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9890 - f1_score: 0.8651 - binary_io_u: 0.8846
# Epoch 52: val_binary_io_u did not improve from 0.81410
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0314 - accuracy: 0.9890 - f1_score: 0.8659 - binary_io_u: 0.8848 - val_loss: 0.0782 - val_accuracy: 0.9796 - val_f1_score: 0.7212 - val_binary_io_u: 0.7971 - lr: 7.8125e-06
# Epoch 53/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8602 - binary_io_u: 0.8856
# Epoch 53: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0313 - accuracy: 0.9890 - f1_score: 0.8480 - binary_io_u: 0.8848 - val_loss: 0.0781 - val_accuracy: 0.9796 - val_f1_score: 0.7219 - val_binary_io_u: 0.7975 - lr: 3.9063e-06
# Epoch 54/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9890 - f1_score: 0.8679 - binary_io_u: 0.8848
# Epoch 54: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0313 - accuracy: 0.9891 - f1_score: 0.8697 - binary_io_u: 0.8851 - val_loss: 0.0782 - val_accuracy: 0.9796 - val_f1_score: 0.7212 - val_binary_io_u: 0.7973 - lr: 3.9063e-06
# Epoch 55/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9890 - f1_score: 0.8656 - binary_io_u: 0.8850
# Epoch 55: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0313 - accuracy: 0.9891 - f1_score: 0.8676 - binary_io_u: 0.8852 - val_loss: 0.0782 - val_accuracy: 0.9796 - val_f1_score: 0.7214 - val_binary_io_u: 0.7973 - lr: 3.9063e-06
# Epoch 56/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8697 - binary_io_u: 0.8852
# Epoch 56: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8696 - binary_io_u: 0.8851 - val_loss: 0.0783 - val_accuracy: 0.9796 - val_f1_score: 0.7214 - val_binary_io_u: 0.7973 - lr: 3.9063e-06
# Epoch 57/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8676 - binary_io_u: 0.8842
# Epoch 57: val_binary_io_u did not improve from 0.81410
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8696 - binary_io_u: 0.8853 - val_loss: 0.0783 - val_accuracy: 0.9795 - val_f1_score: 0.7218 - val_binary_io_u: 0.7972 - lr: 3.9063e-06
# Epoch 58/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8653 - binary_io_u: 0.8854
# Epoch 58: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8654 - binary_io_u: 0.8854 - val_loss: 0.0784 - val_accuracy: 0.9796 - val_f1_score: 0.7216 - val_binary_io_u: 0.7972 - lr: 1.9531e-06
# Epoch 59/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8627 - binary_io_u: 0.8853
# Epoch 59: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8637 - binary_io_u: 0.8855 - val_loss: 0.0784 - val_accuracy: 0.9796 - val_f1_score: 0.7216 - val_binary_io_u: 0.7972 - lr: 1.9531e-06
# Epoch 60/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8670 - binary_io_u: 0.8852
# Epoch 60: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8687 - binary_io_u: 0.8855 - val_loss: 0.0784 - val_accuracy: 0.9796 - val_f1_score: 0.7214 - val_binary_io_u: 0.7972 - lr: 1.9531e-06
# Epoch 61/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8675 - binary_io_u: 0.8858
# Epoch 61: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8614 - binary_io_u: 0.8856 - val_loss: 0.0784 - val_accuracy: 0.9796 - val_f1_score: 0.7216 - val_binary_io_u: 0.7973 - lr: 1.9531e-06
# Epoch 62/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8615 - binary_io_u: 0.8854
# Epoch 62: val_binary_io_u did not improve from 0.81410
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8633 - binary_io_u: 0.8856 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7215 - val_binary_io_u: 0.7972 - lr: 1.9531e-06
# Epoch 63/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8669 - binary_io_u: 0.8854
# Epoch 63: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 44ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8680 - binary_io_u: 0.8857 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7214 - val_binary_io_u: 0.7971 - lr: 9.7656e-07
# Epoch 64/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8604 - binary_io_u: 0.8857
# Epoch 64: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8612 - binary_io_u: 0.8857 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7215 - val_binary_io_u: 0.7972 - lr: 9.7656e-07
# Epoch 65/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8683 - binary_io_u: 0.8857
# Epoch 65: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8677 - binary_io_u: 0.8857 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7214 - val_binary_io_u: 0.7972 - lr: 9.7656e-07
# Epoch 66/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9892 - f1_score: 0.8674 - binary_io_u: 0.8855
# Epoch 66: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8683 - binary_io_u: 0.8858 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7213 - val_binary_io_u: 0.7971 - lr: 9.7656e-07
# Epoch 67/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9892 - f1_score: 0.8661 - binary_io_u: 0.8859
# Epoch 67: val_binary_io_u did not improve from 0.81410
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8657 - binary_io_u: 0.8857 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7213 - val_binary_io_u: 0.7971 - lr: 9.7656e-07
# Epoch 68/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9891 - f1_score: 0.8631 - binary_io_u: 0.8857
# Epoch 68: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0310 - accuracy: 0.9891 - f1_score: 0.8638 - binary_io_u: 0.8858 - val_loss: 0.0786 - val_accuracy: 0.9796 - val_f1_score: 0.7213 - val_binary_io_u: 0.7971 - lr: 4.8828e-07
# Epoch 69/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9891 - f1_score: 0.8669 - binary_io_u: 0.8852
# Epoch 69: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0310 - accuracy: 0.9891 - f1_score: 0.8685 - binary_io_u: 0.8858 - val_loss: 0.0785 - val_accuracy: 0.9796 - val_f1_score: 0.7213 - val_binary_io_u: 0.7971 - lr: 4.8828e-07
# Epoch 70/70
# 50/50 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9891 - f1_score: 0.8589 - binary_io_u: 0.8858
# Epoch 70: val_binary_io_u did not improve from 0.81410
# 50/50 [==============================] - 2s 45ms/step - loss: 0.0310 - accuracy: 0.9891 - f1_score: 0.8589 - binary_io_u: 0.8858 - val_loss: 0.0786 - val_accuracy: 0.9796 - val_f1_score: 0.7213 - val_binary_io_u: 0.7971 - lr: 4.8828e-07

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 18]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 1s 573ms/step - loss: 0.0389 - accuracy: 0.9892 - f1_score: 0.8530 - binary_io_u: 0.8662

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#                                      Model Name      Loss  Accuracy  \
# 0  Basic_Unet__without_drop_616_v3_without norm  0.038873  0.989168
#
#    Precision    Recall  F1-Score       IoU
# 0   0.863722  0.842456  0.852956  0.806135

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
