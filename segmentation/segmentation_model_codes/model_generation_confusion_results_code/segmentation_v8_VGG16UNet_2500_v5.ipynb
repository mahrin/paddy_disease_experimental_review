# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# from keras import ops# For deeplab3

# import keras_cv # basnet

from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Vgg16_unet_2500_v5'#'TransUNet'#'Vgg16_unet'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 70#100

TOTAL_DATA = 2500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 1234
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 3
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 2500/2500 [00:00<00:00, 19945.79it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 2500 original images into x_train
# Loaded 2500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )


    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### get_unet_vgg16

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x


from tensorflow.keras.applications import  VGG16

# Define the U-Net model with pre-trained VGG16 weights
def get_unet_vgg16(n_filters=16, batchnorm=True):
    # Load pre-trained VGG16 model (excluding top layers)
    vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=MODEL_INPUT_SIZE)

    # Encoder (Contracting Path)
    encoder = vgg16.get_layer('block4_pool').output

    # Bottleneck
    bottleneck = Conv2D(512, (3, 3), activation='relu', padding='same')(encoder)

    # Decoder (Expansive Path)
    x = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(bottleneck)
    x = Concatenate()([x, vgg16.get_layer('block3_pool').output])
    #x = Conv2D(n_filters * 16, (3, 3), activation='relu', padding='same')(x)
    x = conv2d_block(x, 256, kernel_size = 3, batchnorm = batchnorm)

    x = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(x)
    x = Concatenate()([x, vgg16.get_layer('block2_pool').output])
    #x = Conv2D(n_filters * 8, (3, 3), activation='relu', padding='same')(x)
    x = conv2d_block(x, 128, kernel_size = 3, batchnorm = batchnorm)

    x = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(x)
    x = Concatenate()([x, vgg16.get_layer('block1_pool').output])
    #x = Conv2D(n_filters * 4, (3, 3), activation='relu', padding='same')(x)
    x = conv2d_block(x, 64, kernel_size = 3, batchnorm = batchnorm)

    x = Conv2DTranspose(32, (3, 3), strides = (2, 2), padding = 'same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)

    # Output layer
    output = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(x)  #sigmoid because 2 classes, softmax for multiple class

    model = Model(inputs=vgg16.input, outputs=output)


    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],#, iou_score_binary, iou_score1],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 16, 16, 512)          2359808   ['block4_pool[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          1179904   ['conv2d[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'block3_pool[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 256)          1179904   ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 256)          1024      ['conv2d_1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 256)          0         ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 256)          590080    ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 256)          1024      ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          295040    ['activation_1[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'block2_pool[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)          295040    ['concatenate_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)          147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)         73792     ['activation_3[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'block1_pool[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 64)         73792     ['concatenate_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 128, 64)         256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)         36928     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 64)         256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 32)         18464     ['activation_5[0][0]']
#  Transpose)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 64)         18496     ['conv2d_transpose_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 1)          65        ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 13907745 (53.05 MB)
# Trainable params: 13905953 (53.05 MB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9727 - f1_score: 0.5013 - binary_io_u: 0.6906
# Epoch 1: val_binary_io_u improved from -inf to 0.72132, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 40s 111ms/step - loss: 0.0761 - accuracy: 0.9727 - f1_score: 0.5013 - binary_io_u: 0.6906 - val_loss: 0.0992 - val_accuracy: 0.9658 - val_f1_score: 0.6098 - val_binary_io_u: 0.7213 - lr: 0.0010
# Epoch 2/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9830 - f1_score: 0.7508 - binary_io_u: 0.8009
# Epoch 2: val_binary_io_u improved from 0.72132 to 0.79654, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0509 - accuracy: 0.9830 - f1_score: 0.7508 - binary_io_u: 0.8009 - val_loss: 0.0485 - val_accuracy: 0.9837 - val_f1_score: 0.7063 - val_binary_io_u: 0.7965 - lr: 0.0010
# Epoch 3/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9835 - f1_score: 0.7527 - binary_io_u: 0.8037
# Epoch 3: val_binary_io_u did not improve from 0.79654
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0487 - accuracy: 0.9835 - f1_score: 0.7527 - binary_io_u: 0.8037 - val_loss: 0.2313 - val_accuracy: 0.8953 - val_f1_score: 0.3909 - val_binary_io_u: 0.5688 - lr: 0.0010
# Epoch 4/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9844 - f1_score: 0.7659 - binary_io_u: 0.8147
# Epoch 4: val_binary_io_u improved from 0.79654 to 0.80391, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0462 - accuracy: 0.9844 - f1_score: 0.7659 - binary_io_u: 0.8147 - val_loss: 0.0511 - val_accuracy: 0.9833 - val_f1_score: 0.7272 - val_binary_io_u: 0.8039 - lr: 0.0010
# Epoch 5/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9848 - f1_score: 0.7743 - binary_io_u: 0.8188
# Epoch 5: val_binary_io_u improved from 0.80391 to 0.80854, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0448 - accuracy: 0.9848 - f1_score: 0.7743 - binary_io_u: 0.8188 - val_loss: 0.0451 - val_accuracy: 0.9849 - val_f1_score: 0.7229 - val_binary_io_u: 0.8085 - lr: 0.0010
# Epoch 6/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9849 - f1_score: 0.7777 - binary_io_u: 0.8204
# Epoch 6: val_binary_io_u did not improve from 0.80854
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0441 - accuracy: 0.9849 - f1_score: 0.7777 - binary_io_u: 0.8204 - val_loss: 0.0456 - val_accuracy: 0.9842 - val_f1_score: 0.6875 - val_binary_io_u: 0.7876 - lr: 0.0010
# Epoch 7/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9851 - f1_score: 0.7821 - binary_io_u: 0.8226
# Epoch 7: val_binary_io_u improved from 0.80854 to 0.82003, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0438 - accuracy: 0.9851 - f1_score: 0.7821 - binary_io_u: 0.8226 - val_loss: 0.0420 - val_accuracy: 0.9858 - val_f1_score: 0.7403 - val_binary_io_u: 0.8200 - lr: 0.0010
# Epoch 8/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9856 - f1_score: 0.7896 - binary_io_u: 0.8281
# Epoch 8: val_binary_io_u did not improve from 0.82003
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0422 - accuracy: 0.9856 - f1_score: 0.7896 - binary_io_u: 0.8281 - val_loss: 0.0497 - val_accuracy: 0.9832 - val_f1_score: 0.7291 - val_binary_io_u: 0.8072 - lr: 0.0010
# Epoch 9/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9859 - f1_score: 0.7914 - binary_io_u: 0.8318
# Epoch 9: val_binary_io_u did not improve from 0.82003
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0411 - accuracy: 0.9859 - f1_score: 0.7914 - binary_io_u: 0.8318 - val_loss: 0.0465 - val_accuracy: 0.9836 - val_f1_score: 0.6563 - val_binary_io_u: 0.7751 - lr: 0.0010
# Epoch 10/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9862 - f1_score: 0.7998 - binary_io_u: 0.8354
# Epoch 10: val_binary_io_u did not improve from 0.82003
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0401 - accuracy: 0.9862 - f1_score: 0.7998 - binary_io_u: 0.8354 - val_loss: 0.0425 - val_accuracy: 0.9855 - val_f1_score: 0.7077 - val_binary_io_u: 0.8060 - lr: 0.0010
# Epoch 11/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9870 - f1_score: 0.8118 - binary_io_u: 0.8443
# Epoch 11: val_binary_io_u improved from 0.82003 to 0.83514, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0372 - accuracy: 0.9870 - f1_score: 0.8118 - binary_io_u: 0.8443 - val_loss: 0.0376 - val_accuracy: 0.9871 - val_f1_score: 0.7512 - val_binary_io_u: 0.8351 - lr: 5.0000e-04
# Epoch 12/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9873 - f1_score: 0.8165 - binary_io_u: 0.8476
# Epoch 12: val_binary_io_u improved from 0.83514 to 0.83733, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0359 - accuracy: 0.9873 - f1_score: 0.8165 - binary_io_u: 0.8476 - val_loss: 0.0362 - val_accuracy: 0.9874 - val_f1_score: 0.7566 - val_binary_io_u: 0.8373 - lr: 5.0000e-04
# Epoch 13/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9876 - f1_score: 0.8181 - binary_io_u: 0.8505
# Epoch 13: val_binary_io_u did not improve from 0.83733
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0353 - accuracy: 0.9876 - f1_score: 0.8181 - binary_io_u: 0.8505 - val_loss: 0.0385 - val_accuracy: 0.9874 - val_f1_score: 0.7487 - val_binary_io_u: 0.8339 - lr: 5.0000e-04
# Epoch 14/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9877 - f1_score: 0.8191 - binary_io_u: 0.8516
# Epoch 14: val_binary_io_u improved from 0.83733 to 0.84256, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0347 - accuracy: 0.9877 - f1_score: 0.8191 - binary_io_u: 0.8516 - val_loss: 0.0364 - val_accuracy: 0.9877 - val_f1_score: 0.7684 - val_binary_io_u: 0.8426 - lr: 5.0000e-04
# Epoch 15/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9878 - f1_score: 0.8250 - binary_io_u: 0.8528
# Epoch 15: val_binary_io_u improved from 0.84256 to 0.84352, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0343 - accuracy: 0.9878 - f1_score: 0.8250 - binary_io_u: 0.8528 - val_loss: 0.0373 - val_accuracy: 0.9868 - val_f1_score: 0.7778 - val_binary_io_u: 0.8435 - lr: 5.0000e-04
# Epoch 16/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9884 - f1_score: 0.8309 - binary_io_u: 0.8597
# Epoch 16: val_binary_io_u improved from 0.84352 to 0.85002, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0325 - accuracy: 0.9884 - f1_score: 0.8309 - binary_io_u: 0.8597 - val_loss: 0.0342 - val_accuracy: 0.9883 - val_f1_score: 0.7761 - val_binary_io_u: 0.8500 - lr: 2.5000e-04
# Epoch 17/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9887 - f1_score: 0.8359 - binary_io_u: 0.8632
# Epoch 17: val_binary_io_u improved from 0.85002 to 0.85412, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0315 - accuracy: 0.9887 - f1_score: 0.8359 - binary_io_u: 0.8632 - val_loss: 0.0333 - val_accuracy: 0.9884 - val_f1_score: 0.7860 - val_binary_io_u: 0.8541 - lr: 2.5000e-04
# Epoch 18/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9888 - f1_score: 0.8415 - binary_io_u: 0.8648
# Epoch 18: val_binary_io_u did not improve from 0.85412
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0311 - accuracy: 0.9888 - f1_score: 0.8415 - binary_io_u: 0.8648 - val_loss: 0.0358 - val_accuracy: 0.9881 - val_f1_score: 0.7500 - val_binary_io_u: 0.8421 - lr: 2.5000e-04
# Epoch 19/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9889 - f1_score: 0.8367 - binary_io_u: 0.8651
# Epoch 19: val_binary_io_u improved from 0.85412 to 0.85439, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0308 - accuracy: 0.9889 - f1_score: 0.8367 - binary_io_u: 0.8651 - val_loss: 0.0322 - val_accuracy: 0.9885 - val_f1_score: 0.7869 - val_binary_io_u: 0.8544 - lr: 2.5000e-04
# Epoch 20/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9890 - f1_score: 0.8443 - binary_io_u: 0.8672
# Epoch 20: val_binary_io_u did not improve from 0.85439
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0303 - accuracy: 0.9890 - f1_score: 0.8443 - binary_io_u: 0.8672 - val_loss: 0.0351 - val_accuracy: 0.9875 - val_f1_score: 0.7397 - val_binary_io_u: 0.8313 - lr: 2.5000e-04
# Epoch 21/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9892 - f1_score: 0.8445 - binary_io_u: 0.8685
# Epoch 21: val_binary_io_u did not improve from 0.85439
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0298 - accuracy: 0.9892 - f1_score: 0.8445 - binary_io_u: 0.8685 - val_loss: 0.0338 - val_accuracy: 0.9882 - val_f1_score: 0.7900 - val_binary_io_u: 0.8536 - lr: 2.5000e-04
# Epoch 22/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9892 - f1_score: 0.8437 - binary_io_u: 0.8698
# Epoch 22: val_binary_io_u improved from 0.85439 to 0.85541, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0294 - accuracy: 0.9892 - f1_score: 0.8437 - binary_io_u: 0.8698 - val_loss: 0.0317 - val_accuracy: 0.9888 - val_f1_score: 0.7875 - val_binary_io_u: 0.8554 - lr: 2.5000e-04
# Epoch 23/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9893 - f1_score: 0.8436 - binary_io_u: 0.8702
# Epoch 23: val_binary_io_u did not improve from 0.85541
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0295 - accuracy: 0.9893 - f1_score: 0.8436 - binary_io_u: 0.8702 - val_loss: 0.0328 - val_accuracy: 0.9888 - val_f1_score: 0.7810 - val_binary_io_u: 0.8541 - lr: 2.5000e-04
# Epoch 24/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9895 - f1_score: 0.8462 - binary_io_u: 0.8723
# Epoch 24: val_binary_io_u did not improve from 0.85541
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0287 - accuracy: 0.9895 - f1_score: 0.8462 - binary_io_u: 0.8723 - val_loss: 0.0363 - val_accuracy: 0.9888 - val_f1_score: 0.7783 - val_binary_io_u: 0.8542 - lr: 2.5000e-04
# Epoch 25/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9896 - f1_score: 0.8495 - binary_io_u: 0.8734
# Epoch 25: val_binary_io_u improved from 0.85541 to 0.85864, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0283 - accuracy: 0.9896 - f1_score: 0.8495 - binary_io_u: 0.8734 - val_loss: 0.0311 - val_accuracy: 0.9890 - val_f1_score: 0.7936 - val_binary_io_u: 0.8586 - lr: 2.5000e-04
# Epoch 26/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9897 - f1_score: 0.8515 - binary_io_u: 0.8744
# Epoch 26: val_binary_io_u improved from 0.85864 to 0.85966, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0281 - accuracy: 0.9897 - f1_score: 0.8515 - binary_io_u: 0.8744 - val_loss: 0.0301 - val_accuracy: 0.9891 - val_f1_score: 0.7953 - val_binary_io_u: 0.8597 - lr: 2.5000e-04
# Epoch 27/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9898 - f1_score: 0.8545 - binary_io_u: 0.8760
# Epoch 27: val_binary_io_u did not improve from 0.85966
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0278 - accuracy: 0.9898 - f1_score: 0.8545 - binary_io_u: 0.8760 - val_loss: 0.0317 - val_accuracy: 0.9888 - val_f1_score: 0.7835 - val_binary_io_u: 0.8566 - lr: 2.5000e-04
# Epoch 28/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9898 - f1_score: 0.8556 - binary_io_u: 0.8757
# Epoch 28: val_binary_io_u did not improve from 0.85966
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0277 - accuracy: 0.9898 - f1_score: 0.8556 - binary_io_u: 0.8757 - val_loss: 0.0324 - val_accuracy: 0.9889 - val_f1_score: 0.7897 - val_binary_io_u: 0.8545 - lr: 2.5000e-04
# Epoch 29/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9900 - f1_score: 0.8543 - binary_io_u: 0.8780
# Epoch 29: val_binary_io_u did not improve from 0.85966
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0271 - accuracy: 0.9900 - f1_score: 0.8543 - binary_io_u: 0.8780 - val_loss: 0.0316 - val_accuracy: 0.9888 - val_f1_score: 0.7986 - val_binary_io_u: 0.8596 - lr: 2.5000e-04
# Epoch 30/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9904 - f1_score: 0.8600 - binary_io_u: 0.8824
# Epoch 30: val_binary_io_u improved from 0.85966 to 0.86378, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0257 - accuracy: 0.9904 - f1_score: 0.8600 - binary_io_u: 0.8824 - val_loss: 0.0294 - val_accuracy: 0.9895 - val_f1_score: 0.8000 - val_binary_io_u: 0.8638 - lr: 1.2500e-04
# Epoch 31/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9905 - f1_score: 0.8648 - binary_io_u: 0.8836
# Epoch 31: val_binary_io_u did not improve from 0.86378
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0254 - accuracy: 0.9905 - f1_score: 0.8648 - binary_io_u: 0.8836 - val_loss: 0.0293 - val_accuracy: 0.9896 - val_f1_score: 0.7985 - val_binary_io_u: 0.8634 - lr: 1.2500e-04
# Epoch 32/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9905 - f1_score: 0.8640 - binary_io_u: 0.8841
# Epoch 32: val_binary_io_u improved from 0.86378 to 0.86414, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0253 - accuracy: 0.9905 - f1_score: 0.8640 - binary_io_u: 0.8841 - val_loss: 0.0298 - val_accuracy: 0.9895 - val_f1_score: 0.8030 - val_binary_io_u: 0.8641 - lr: 1.2500e-04
# Epoch 33/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9906 - f1_score: 0.8649 - binary_io_u: 0.8846
# Epoch 33: val_binary_io_u improved from 0.86414 to 0.86499, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0251 - accuracy: 0.9906 - f1_score: 0.8649 - binary_io_u: 0.8846 - val_loss: 0.0296 - val_accuracy: 0.9896 - val_f1_score: 0.8035 - val_binary_io_u: 0.8650 - lr: 1.2500e-04
# Epoch 34/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9906 - f1_score: 0.8648 - binary_io_u: 0.8853
# Epoch 34: val_binary_io_u did not improve from 0.86499
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0249 - accuracy: 0.9906 - f1_score: 0.8648 - binary_io_u: 0.8853 - val_loss: 0.0310 - val_accuracy: 0.9894 - val_f1_score: 0.8010 - val_binary_io_u: 0.8645 - lr: 1.2500e-04
# Epoch 35/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9908 - f1_score: 0.8665 - binary_io_u: 0.8873
# Epoch 35: val_binary_io_u improved from 0.86499 to 0.86683, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0244 - accuracy: 0.9908 - f1_score: 0.8665 - binary_io_u: 0.8873 - val_loss: 0.0286 - val_accuracy: 0.9897 - val_f1_score: 0.8067 - val_binary_io_u: 0.8668 - lr: 6.2500e-05
# Epoch 36/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9908 - f1_score: 0.8680 - binary_io_u: 0.8881
# Epoch 36: val_binary_io_u improved from 0.86683 to 0.86732, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0242 - accuracy: 0.9908 - f1_score: 0.8680 - binary_io_u: 0.8881 - val_loss: 0.0288 - val_accuracy: 0.9897 - val_f1_score: 0.8080 - val_binary_io_u: 0.8673 - lr: 6.2500e-05
# Epoch 37/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9909 - f1_score: 0.8672 - binary_io_u: 0.8886
# Epoch 37: val_binary_io_u did not improve from 0.86732
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0240 - accuracy: 0.9909 - f1_score: 0.8672 - binary_io_u: 0.8886 - val_loss: 0.0286 - val_accuracy: 0.9897 - val_f1_score: 0.8047 - val_binary_io_u: 0.8664 - lr: 6.2500e-05
# Epoch 38/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9909 - f1_score: 0.8700 - binary_io_u: 0.8888
# Epoch 38: val_binary_io_u did not improve from 0.86732
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0239 - accuracy: 0.9909 - f1_score: 0.8700 - binary_io_u: 0.8888 - val_loss: 0.0289 - val_accuracy: 0.9897 - val_f1_score: 0.8083 - val_binary_io_u: 0.8667 - lr: 6.2500e-05
# Epoch 39/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9910 - f1_score: 0.8702 - binary_io_u: 0.8897
# Epoch 39: val_binary_io_u improved from 0.86732 to 0.86745, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0236 - accuracy: 0.9910 - f1_score: 0.8702 - binary_io_u: 0.8897 - val_loss: 0.0284 - val_accuracy: 0.9898 - val_f1_score: 0.8079 - val_binary_io_u: 0.8675 - lr: 3.1250e-05
# Epoch 40/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9910 - f1_score: 0.8687 - binary_io_u: 0.8896
# Epoch 40: val_binary_io_u improved from 0.86745 to 0.86803, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0236 - accuracy: 0.9910 - f1_score: 0.8687 - binary_io_u: 0.8896 - val_loss: 0.0284 - val_accuracy: 0.9898 - val_f1_score: 0.8093 - val_binary_io_u: 0.8680 - lr: 3.1250e-05
# Epoch 41/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9910 - f1_score: 0.8721 - binary_io_u: 0.8903
# Epoch 41: val_binary_io_u improved from 0.86803 to 0.86868, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0234 - accuracy: 0.9910 - f1_score: 0.8721 - binary_io_u: 0.8903 - val_loss: 0.0283 - val_accuracy: 0.9898 - val_f1_score: 0.8105 - val_binary_io_u: 0.8687 - lr: 3.1250e-05
# Epoch 42/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9910 - f1_score: 0.8699 - binary_io_u: 0.8904
# Epoch 42: val_binary_io_u did not improve from 0.86868
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0234 - accuracy: 0.9910 - f1_score: 0.8699 - binary_io_u: 0.8904 - val_loss: 0.0283 - val_accuracy: 0.9898 - val_f1_score: 0.8113 - val_binary_io_u: 0.8685 - lr: 3.1250e-05
# Epoch 43/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9911 - f1_score: 0.8675 - binary_io_u: 0.8907
# Epoch 43: val_binary_io_u did not improve from 0.86868
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0234 - accuracy: 0.9911 - f1_score: 0.8675 - binary_io_u: 0.8907 - val_loss: 0.0283 - val_accuracy: 0.9898 - val_f1_score: 0.8096 - val_binary_io_u: 0.8684 - lr: 3.1250e-05
# Epoch 44/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9911 - f1_score: 0.8711 - binary_io_u: 0.8904
# Epoch 44: val_binary_io_u did not improve from 0.86868
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0234 - accuracy: 0.9911 - f1_score: 0.8711 - binary_io_u: 0.8904 - val_loss: 0.0285 - val_accuracy: 0.9898 - val_f1_score: 0.8077 - val_binary_io_u: 0.8670 - lr: 3.1250e-05
# Epoch 45/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9911 - f1_score: 0.8707 - binary_io_u: 0.8914
# Epoch 45: val_binary_io_u did not improve from 0.86868
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0232 - accuracy: 0.9911 - f1_score: 0.8707 - binary_io_u: 0.8914 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8088 - val_binary_io_u: 0.8681 - lr: 1.5625e-05
# Epoch 46/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9911 - f1_score: 0.8721 - binary_io_u: 0.8913
# Epoch 46: val_binary_io_u did not improve from 0.86868
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0232 - accuracy: 0.9911 - f1_score: 0.8721 - binary_io_u: 0.8913 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8114 - val_binary_io_u: 0.8687 - lr: 1.5625e-05
# Epoch 47/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9911 - f1_score: 0.8690 - binary_io_u: 0.8915
# Epoch 47: val_binary_io_u did not improve from 0.86868
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0231 - accuracy: 0.9911 - f1_score: 0.8690 - binary_io_u: 0.8915 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8102 - val_binary_io_u: 0.8686 - lr: 1.5625e-05
# Epoch 48/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9912 - f1_score: 0.8744 - binary_io_u: 0.8919
# Epoch 48: val_binary_io_u did not improve from 0.86868
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0230 - accuracy: 0.9912 - f1_score: 0.8744 - binary_io_u: 0.8919 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8106 - val_binary_io_u: 0.8685 - lr: 7.8125e-06
# Epoch 49/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9912 - f1_score: 0.8736 - binary_io_u: 0.8918
# Epoch 49: val_binary_io_u did not improve from 0.86868
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0230 - accuracy: 0.9912 - f1_score: 0.8736 - binary_io_u: 0.8918 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8108 - val_binary_io_u: 0.8686 - lr: 7.8125e-06
# Epoch 50/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9912 - f1_score: 0.8727 - binary_io_u: 0.8918
# Epoch 50: val_binary_io_u improved from 0.86868 to 0.86868, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0230 - accuracy: 0.9912 - f1_score: 0.8727 - binary_io_u: 0.8918 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8687 - lr: 7.8125e-06
# Epoch 51/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8738 - binary_io_u: 0.8921
# Epoch 51: val_binary_io_u improved from 0.86868 to 0.86870, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8738 - binary_io_u: 0.8921 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 7.8125e-06
# Epoch 52/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8733 - binary_io_u: 0.8923
# Epoch 52: val_binary_io_u did not improve from 0.86870
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8733 - binary_io_u: 0.8923 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8108 - val_binary_io_u: 0.8686 - lr: 3.9063e-06
# Epoch 53/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8764 - binary_io_u: 0.8924
# Epoch 53: val_binary_io_u did not improve from 0.86870
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8764 - binary_io_u: 0.8924 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8686 - lr: 3.9063e-06
# Epoch 54/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8734 - binary_io_u: 0.8923
# Epoch 54: val_binary_io_u did not improve from 0.86870
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8734 - binary_io_u: 0.8923 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8109 - val_binary_io_u: 0.8686 - lr: 3.9063e-06
# Epoch 55/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8748 - binary_io_u: 0.8926
# Epoch 55: val_binary_io_u improved from 0.86870 to 0.86875, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8748 - binary_io_u: 0.8926 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 1.9531e-06
# Epoch 56/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8750 - binary_io_u: 0.8922
# Epoch 56: val_binary_io_u did not improve from 0.86875
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8750 - binary_io_u: 0.8922 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8113 - val_binary_io_u: 0.8687 - lr: 1.9531e-06
# Epoch 57/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8743 - binary_io_u: 0.8927
# Epoch 57: val_binary_io_u did not improve from 0.86875
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8743 - binary_io_u: 0.8927 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 1.9531e-06
# Epoch 58/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8752 - binary_io_u: 0.8925
# Epoch 58: val_binary_io_u did not improve from 0.86875
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8752 - binary_io_u: 0.8925 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8686 - lr: 9.7656e-07
# Epoch 59/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8751 - binary_io_u: 0.8925
# Epoch 59: val_binary_io_u did not improve from 0.86875
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8751 - binary_io_u: 0.8925 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8686 - lr: 9.7656e-07
# Epoch 60/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8742 - binary_io_u: 0.8923
# Epoch 60: val_binary_io_u did not improve from 0.86875
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8742 - binary_io_u: 0.8923 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8687 - lr: 9.7656e-07
# Epoch 61/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8741 - binary_io_u: 0.8924
# Epoch 61: val_binary_io_u did not improve from 0.86875
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8741 - binary_io_u: 0.8924 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8687 - lr: 4.8828e-07
# Epoch 62/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8743 - binary_io_u: 0.8928
# Epoch 62: val_binary_io_u improved from 0.86875 to 0.86876, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_2500_v5/saved_models/best_Vgg16_unet_2500_v5.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8743 - binary_io_u: 0.8928 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8112 - val_binary_io_u: 0.8688 - lr: 4.8828e-07
# Epoch 63/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8761 - binary_io_u: 0.8927
# Epoch 63: val_binary_io_u did not improve from 0.86876
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8761 - binary_io_u: 0.8927 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8112 - val_binary_io_u: 0.8687 - lr: 4.8828e-07
# Epoch 64/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8736 - binary_io_u: 0.8925
# Epoch 64: val_binary_io_u did not improve from 0.86876
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8736 - binary_io_u: 0.8925 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 2.4414e-07
# Epoch 65/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8760 - binary_io_u: 0.8925
# Epoch 65: val_binary_io_u did not improve from 0.86876
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8760 - binary_io_u: 0.8925 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8686 - lr: 2.4414e-07
# Epoch 66/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8760 - binary_io_u: 0.8926
# Epoch 66: val_binary_io_u did not improve from 0.86876
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8760 - binary_io_u: 0.8926 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 2.4414e-07
# Epoch 67/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8750 - binary_io_u: 0.8922
# Epoch 67: val_binary_io_u did not improve from 0.86876
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8750 - binary_io_u: 0.8922 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 1.2207e-07
# Epoch 68/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8737 - binary_io_u: 0.8926
# Epoch 68: val_binary_io_u did not improve from 0.86876
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8737 - binary_io_u: 0.8926 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 1.2207e-07
# Epoch 69/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8730 - binary_io_u: 0.8925
# Epoch 69: val_binary_io_u did not improve from 0.86876
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0229 - accuracy: 0.9912 - f1_score: 0.8730 - binary_io_u: 0.8925 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8111 - val_binary_io_u: 0.8687 - lr: 1.2207e-07
# Epoch 70/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8740 - binary_io_u: 0.8927
# Epoch 70: val_binary_io_u did not improve from 0.86876
# 200/200 [==============================] - 20s 101ms/step - loss: 0.0228 - accuracy: 0.9912 - f1_score: 0.8740 - binary_io_u: 0.8927 - val_loss: 0.0282 - val_accuracy: 0.9898 - val_f1_score: 0.8110 - val_binary_io_u: 0.8686 - lr: 6.1035e-08

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 17]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0355 - accuracy: 0.9895 - f1_score: 0.8531 - binary_io_u: 0.8665

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#            Model Name      Loss  Accuracy  Precision    Recall  F1-Score  \
# 0  Vgg16_unet_2500_v5  0.035517  0.989496    0.89134  0.818067  0.853133
#
#         IoU
# 0  0.868524

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
