# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Defining paths

# %%
model_name = 'Vgg16_unet_616'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 70#100

TOTAL_DATA = 616
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 1234
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 3
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 616/616 [00:00<00:00, 18196.29it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### get_unet_vgg16--works with batch30-augmented data (could not check with 40--memory issue)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x


from tensorflow.keras.applications import  VGG16

# Define the U-Net model with pre-trained VGG16 weights
def get_unet_vgg16(n_filters=16, batchnorm=True):
    # Load pre-trained VGG16 model (excluding top layers)
    vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=MODEL_INPUT_SIZE)

    # Encoder (Contracting Path)
    encoder = vgg16.get_layer('block4_pool').output

    # Bottleneck
    bottleneck = Conv2D(512, (3, 3), activation='relu', padding='same')(encoder)

    # Decoder (Expansive Path)
    x = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(bottleneck)
    x = Concatenate()([x, vgg16.get_layer('block3_pool').output])
    #x = Conv2D(n_filters * 16, (3, 3), activation='relu', padding='same')(x)
    x = conv2d_block(x, 256, kernel_size = 3, batchnorm = batchnorm)

    x = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(x)
    x = Concatenate()([x, vgg16.get_layer('block2_pool').output])
    #x = Conv2D(n_filters * 8, (3, 3), activation='relu', padding='same')(x)
    x = conv2d_block(x, 128, kernel_size = 3, batchnorm = batchnorm)

    x = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(x)
    x = Concatenate()([x, vgg16.get_layer('block1_pool').output])
    #x = Conv2D(n_filters * 4, (3, 3), activation='relu', padding='same')(x)
    x = conv2d_block(x, 64, kernel_size = 3, batchnorm = batchnorm)

    x = Conv2DTranspose(32, (3, 3), strides = (2, 2), padding = 'same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)

    # Output layer
    output = Conv2D(NUM_CLASSES-1, (1, 1), activation='sigmoid')(x)  #sigmoid because 2 classes, softmax for multiple class

    model = Model(inputs=vgg16.input, outputs=output)


    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],#, iou_score_binary, iou_score1],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
# model = get_ResUNet_v3() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)          0         ['block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 16, 16, 512)          2359808   ['block4_pool[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          1179904   ['conv2d[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'block3_pool[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 256)          1179904   ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 256)          1024      ['conv2d_1[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 256)          0         ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 256)          590080    ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 256)          1024      ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          295040    ['activation_1[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'block2_pool[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)          295040    ['concatenate_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)          147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)         73792     ['activation_3[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'block1_pool[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 64)         73792     ['concatenate_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 128, 64)         256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)         36928     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 64)         256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 32)         18464     ['activation_5[0][0]']
#  Transpose)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 64)         18496     ['conv2d_transpose_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 1)          65        ['conv2d_7[0][0]']
#
# ==================================================================================================
# Total params: 13907745 (53.05 MB)
# Trainable params: 13905953 (53.05 MB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/70
# 50/50 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9516 - f1_score: 0.5179 - binary_io_u: 0.6361
# Epoch 1: val_binary_io_u improved from -inf to 0.48015, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 29s 219ms/step - loss: 0.1271 - accuracy: 0.9516 - f1_score: 0.5179 - binary_io_u: 0.6361 - val_loss: 0.5586 - val_accuracy: 0.9548 - val_f1_score: 0.0086 - val_binary_io_u: 0.4802 - lr: 0.0010
# Epoch 2/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9787 - f1_score: 0.7408 - binary_io_u: 0.7885
# Epoch 2: val_binary_io_u improved from 0.48015 to 0.65747, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 6s 113ms/step - loss: 0.0639 - accuracy: 0.9787 - f1_score: 0.7426 - binary_io_u: 0.7888 - val_loss: 0.1597 - val_accuracy: 0.9373 - val_f1_score: 0.5364 - val_binary_io_u: 0.6575 - lr: 0.0010
# Epoch 3/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9805 - f1_score: 0.7636 - binary_io_u: 0.8035
# Epoch 3: val_binary_io_u improved from 0.65747 to 0.73019, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 6s 112ms/step - loss: 0.0577 - accuracy: 0.9804 - f1_score: 0.7643 - binary_io_u: 0.8036 - val_loss: 0.1065 - val_accuracy: 0.9624 - val_f1_score: 0.6354 - val_binary_io_u: 0.7302 - lr: 0.0010
# Epoch 4/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0550 - accuracy: 0.9815 - f1_score: 0.7743 - binary_io_u: 0.8138
# Epoch 4: val_binary_io_u improved from 0.73019 to 0.79172, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 6s 113ms/step - loss: 0.0549 - accuracy: 0.9815 - f1_score: 0.7745 - binary_io_u: 0.8138 - val_loss: 0.0701 - val_accuracy: 0.9793 - val_f1_score: 0.6851 - val_binary_io_u: 0.7917 - lr: 0.0010
# Epoch 5/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9815 - f1_score: 0.7741 - binary_io_u: 0.8141
# Epoch 5: val_binary_io_u did not improve from 0.79172
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0542 - accuracy: 0.9815 - f1_score: 0.7773 - binary_io_u: 0.8144 - val_loss: 0.0952 - val_accuracy: 0.9704 - val_f1_score: 0.6363 - val_binary_io_u: 0.7423 - lr: 0.0010
# Epoch 6/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9818 - f1_score: 0.7749 - binary_io_u: 0.8167
# Epoch 6: val_binary_io_u did not improve from 0.79172
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0535 - accuracy: 0.9818 - f1_score: 0.7740 - binary_io_u: 0.8167 - val_loss: 0.3523 - val_accuracy: 0.8453 - val_f1_score: 0.3493 - val_binary_io_u: 0.5257 - lr: 0.0010
# Epoch 7/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9827 - f1_score: 0.7902 - binary_io_u: 0.8241
# Epoch 7: val_binary_io_u did not improve from 0.79172
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0508 - accuracy: 0.9828 - f1_score: 0.7889 - binary_io_u: 0.8240 - val_loss: 0.0989 - val_accuracy: 0.9672 - val_f1_score: 0.6698 - val_binary_io_u: 0.7528 - lr: 0.0010
# Epoch 8/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0473 - accuracy: 0.9838 - f1_score: 0.8029 - binary_io_u: 0.8343
# Epoch 8: val_binary_io_u did not improve from 0.79172
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0474 - accuracy: 0.9838 - f1_score: 0.8026 - binary_io_u: 0.8342 - val_loss: 0.0754 - val_accuracy: 0.9745 - val_f1_score: 0.7073 - val_binary_io_u: 0.7820 - lr: 5.0000e-04
# Epoch 9/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9842 - f1_score: 0.8091 - binary_io_u: 0.8388
# Epoch 9: val_binary_io_u did not improve from 0.79172
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0463 - accuracy: 0.9842 - f1_score: 0.8073 - binary_io_u: 0.8385 - val_loss: 0.0773 - val_accuracy: 0.9769 - val_f1_score: 0.7204 - val_binary_io_u: 0.7911 - lr: 5.0000e-04
# Epoch 10/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9844 - f1_score: 0.8030 - binary_io_u: 0.8399
# Epoch 10: val_binary_io_u did not improve from 0.79172
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 [==============================] - 5s 102ms/step - loss: 0.0454 - accuracy: 0.9844 - f1_score: 0.8041 - binary_io_u: 0.8400 - val_loss: 0.0772 - val_accuracy: 0.9797 - val_f1_score: 0.6635 - val_binary_io_u: 0.7780 - lr: 5.0000e-04
# Epoch 11/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9855 - f1_score: 0.8278 - binary_io_u: 0.8500
# Epoch 11: val_binary_io_u did not improve from 0.79172
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0423 - accuracy: 0.9855 - f1_score: 0.8143 - binary_io_u: 0.8493 - val_loss: 0.0746 - val_accuracy: 0.9801 - val_f1_score: 0.6792 - val_binary_io_u: 0.7827 - lr: 2.5000e-04
# Epoch 12/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9859 - f1_score: 0.8229 - binary_io_u: 0.8507
# Epoch 12: val_binary_io_u did not improve from 0.79172
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0420 - accuracy: 0.9855 - f1_score: 0.8221 - binary_io_u: 0.8497 - val_loss: 0.0719 - val_accuracy: 0.9805 - val_f1_score: 0.6876 - val_binary_io_u: 0.7867 - lr: 2.5000e-04
# Epoch 13/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0430 - accuracy: 0.9853 - f1_score: 0.8209 - binary_io_u: 0.8493
# Epoch 13: val_binary_io_u improved from 0.79172 to 0.80987, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 7s 141ms/step - loss: 0.0430 - accuracy: 0.9853 - f1_score: 0.8228 - binary_io_u: 0.8497 - val_loss: 0.0638 - val_accuracy: 0.9803 - val_f1_score: 0.7391 - val_binary_io_u: 0.8099 - lr: 2.5000e-04
# Epoch 14/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9858 - f1_score: 0.8263 - binary_io_u: 0.8526
# Epoch 14: val_binary_io_u improved from 0.80987 to 0.81225, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 6s 117ms/step - loss: 0.0408 - accuracy: 0.9858 - f1_score: 0.8266 - binary_io_u: 0.8526 - val_loss: 0.0646 - val_accuracy: 0.9817 - val_f1_score: 0.7352 - val_binary_io_u: 0.8123 - lr: 2.5000e-04
# Epoch 15/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9863 - f1_score: 0.8336 - binary_io_u: 0.8569
# Epoch 15: val_binary_io_u improved from 0.81225 to 0.81707, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/Vgg16_unet_616/saved_models/best_Vgg16_unet_616.h5
# 50/50 [==============================] - 6s 113ms/step - loss: 0.0394 - accuracy: 0.9863 - f1_score: 0.8361 - binary_io_u: 0.8575 - val_loss: 0.0622 - val_accuracy: 0.9819 - val_f1_score: 0.7429 - val_binary_io_u: 0.8171 - lr: 2.5000e-04
# Epoch 16/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9862 - f1_score: 0.8291 - binary_io_u: 0.8577
# Epoch 16: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0396 - accuracy: 0.9863 - f1_score: 0.8287 - binary_io_u: 0.8577 - val_loss: 0.0657 - val_accuracy: 0.9817 - val_f1_score: 0.7185 - val_binary_io_u: 0.8042 - lr: 2.5000e-04
# Epoch 17/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9867 - f1_score: 0.8394 - binary_io_u: 0.8609
# Epoch 17: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0386 - accuracy: 0.9866 - f1_score: 0.8395 - binary_io_u: 0.8609 - val_loss: 0.0666 - val_accuracy: 0.9805 - val_f1_score: 0.7096 - val_binary_io_u: 0.7932 - lr: 2.5000e-04
# Epoch 18/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0375 - accuracy: 0.9870 - f1_score: 0.8393 - binary_io_u: 0.8625
# Epoch 18: val_binary_io_u did not improve from 0.81707
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0379 - accuracy: 0.9868 - f1_score: 0.8399 - binary_io_u: 0.8626 - val_loss: 0.0649 - val_accuracy: 0.9810 - val_f1_score: 0.7067 - val_binary_io_u: 0.7987 - lr: 2.5000e-04
# Epoch 19/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9868 - f1_score: 0.8435 - binary_io_u: 0.8623
# Epoch 19: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0378 - accuracy: 0.9867 - f1_score: 0.8446 - binary_io_u: 0.8626 - val_loss: 0.0633 - val_accuracy: 0.9807 - val_f1_score: 0.6935 - val_binary_io_u: 0.7905 - lr: 1.2500e-04
# Epoch 20/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9874 - f1_score: 0.8488 - binary_io_u: 0.8682
# Epoch 20: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0360 - accuracy: 0.9874 - f1_score: 0.8496 - binary_io_u: 0.8684 - val_loss: 0.0641 - val_accuracy: 0.9811 - val_f1_score: 0.7055 - val_binary_io_u: 0.7977 - lr: 1.2500e-04
# Epoch 21/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9873 - f1_score: 0.8429 - binary_io_u: 0.8675
# Epoch 21: val_binary_io_u did not improve from 0.81707
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0358 - accuracy: 0.9873 - f1_score: 0.8449 - binary_io_u: 0.8682 - val_loss: 0.0676 - val_accuracy: 0.9806 - val_f1_score: 0.6932 - val_binary_io_u: 0.7894 - lr: 1.2500e-04
# Epoch 22/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9880 - f1_score: 0.8530 - binary_io_u: 0.8737
# Epoch 22: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0339 - accuracy: 0.9880 - f1_score: 0.8532 - binary_io_u: 0.8737 - val_loss: 0.0686 - val_accuracy: 0.9811 - val_f1_score: 0.7061 - val_binary_io_u: 0.7968 - lr: 6.2500e-05
# Epoch 23/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9879 - f1_score: 0.8554 - binary_io_u: 0.8735
# Epoch 23: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0338 - accuracy: 0.9879 - f1_score: 0.8525 - binary_io_u: 0.8734 - val_loss: 0.0618 - val_accuracy: 0.9813 - val_f1_score: 0.7225 - val_binary_io_u: 0.8042 - lr: 6.2500e-05
# Epoch 24/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0338 - accuracy: 0.9879 - f1_score: 0.8525 - binary_io_u: 0.8731
# Epoch 24: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0338 - accuracy: 0.9879 - f1_score: 0.8539 - binary_io_u: 0.8734 - val_loss: 0.0669 - val_accuracy: 0.9811 - val_f1_score: 0.7086 - val_binary_io_u: 0.7979 - lr: 6.2500e-05
# Epoch 25/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0337 - accuracy: 0.9879 - f1_score: 0.8475 - binary_io_u: 0.8735
# Epoch 25: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0336 - accuracy: 0.9879 - f1_score: 0.8448 - binary_io_u: 0.8734 - val_loss: 0.0661 - val_accuracy: 0.9817 - val_f1_score: 0.7230 - val_binary_io_u: 0.8056 - lr: 6.2500e-05
# Epoch 26/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9882 - f1_score: 0.8579 - binary_io_u: 0.8769
# Epoch 26: val_binary_io_u did not improve from 0.81707
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0328 - accuracy: 0.9882 - f1_score: 0.8532 - binary_io_u: 0.8768 - val_loss: 0.0679 - val_accuracy: 0.9812 - val_f1_score: 0.7129 - val_binary_io_u: 0.7987 - lr: 6.2500e-05
# Epoch 27/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9884 - f1_score: 0.8586 - binary_io_u: 0.8779
# Epoch 27: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0322 - accuracy: 0.9884 - f1_score: 0.8595 - binary_io_u: 0.8780 - val_loss: 0.0637 - val_accuracy: 0.9815 - val_f1_score: 0.7263 - val_binary_io_u: 0.8066 - lr: 3.1250e-05
# Epoch 28/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9884 - f1_score: 0.8617 - binary_io_u: 0.8787
# Epoch 28: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0322 - accuracy: 0.9885 - f1_score: 0.8623 - binary_io_u: 0.8787 - val_loss: 0.0641 - val_accuracy: 0.9815 - val_f1_score: 0.7283 - val_binary_io_u: 0.8068 - lr: 3.1250e-05
# Epoch 29/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9884 - f1_score: 0.8589 - binary_io_u: 0.8790
# Epoch 29: val_binary_io_u did not improve from 0.81707
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0321 - accuracy: 0.9884 - f1_score: 0.8596 - binary_io_u: 0.8790 - val_loss: 0.0635 - val_accuracy: 0.9816 - val_f1_score: 0.7262 - val_binary_io_u: 0.8066 - lr: 3.1250e-05
# Epoch 30/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9886 - f1_score: 0.8641 - binary_io_u: 0.8784
# Epoch 30: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0318 - accuracy: 0.9885 - f1_score: 0.8656 - binary_io_u: 0.8792 - val_loss: 0.0633 - val_accuracy: 0.9816 - val_f1_score: 0.7298 - val_binary_io_u: 0.8080 - lr: 1.5625e-05
# Epoch 31/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9886 - f1_score: 0.8555 - binary_io_u: 0.8799
# Epoch 31: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0314 - accuracy: 0.9886 - f1_score: 0.8567 - binary_io_u: 0.8801 - val_loss: 0.0626 - val_accuracy: 0.9816 - val_f1_score: 0.7314 - val_binary_io_u: 0.8087 - lr: 1.5625e-05
# Epoch 32/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9886 - f1_score: 0.8619 - binary_io_u: 0.8805
# Epoch 32: val_binary_io_u did not improve from 0.81707
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0314 - accuracy: 0.9886 - f1_score: 0.8620 - binary_io_u: 0.8805 - val_loss: 0.0624 - val_accuracy: 0.9815 - val_f1_score: 0.7334 - val_binary_io_u: 0.8092 - lr: 1.5625e-05
# Epoch 33/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9885 - f1_score: 0.8654 - binary_io_u: 0.8797
# Epoch 33: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0314 - accuracy: 0.9886 - f1_score: 0.8586 - binary_io_u: 0.8797 - val_loss: 0.0624 - val_accuracy: 0.9815 - val_f1_score: 0.7339 - val_binary_io_u: 0.8098 - lr: 7.8125e-06
# Epoch 34/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0313 - accuracy: 0.9887 - f1_score: 0.8675 - binary_io_u: 0.8812
# Epoch 34: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0314 - accuracy: 0.9887 - f1_score: 0.8685 - binary_io_u: 0.8815 - val_loss: 0.0627 - val_accuracy: 0.9815 - val_f1_score: 0.7325 - val_binary_io_u: 0.8089 - lr: 7.8125e-06
# Epoch 35/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9887 - f1_score: 0.8633 - binary_io_u: 0.8810
# Epoch 35: val_binary_io_u did not improve from 0.81707
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0313 - accuracy: 0.9887 - f1_score: 0.8643 - binary_io_u: 0.8811 - val_loss: 0.0626 - val_accuracy: 0.9815 - val_f1_score: 0.7325 - val_binary_io_u: 0.8090 - lr: 7.8125e-06
# Epoch 36/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8625 - binary_io_u: 0.8806
# Epoch 36: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0312 - accuracy: 0.9887 - f1_score: 0.8640 - binary_io_u: 0.8812 - val_loss: 0.0624 - val_accuracy: 0.9815 - val_f1_score: 0.7326 - val_binary_io_u: 0.8091 - lr: 3.9063e-06
# Epoch 37/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8605 - binary_io_u: 0.8809
# Epoch 37: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8617 - binary_io_u: 0.8816 - val_loss: 0.0622 - val_accuracy: 0.9815 - val_f1_score: 0.7334 - val_binary_io_u: 0.8097 - lr: 3.9063e-06
# Epoch 38/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8592 - binary_io_u: 0.8809
# Epoch 38: val_binary_io_u did not improve from 0.81707
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8605 - binary_io_u: 0.8810 - val_loss: 0.0622 - val_accuracy: 0.9815 - val_f1_score: 0.7339 - val_binary_io_u: 0.8098 - lr: 3.9063e-06
# Epoch 39/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8665 - binary_io_u: 0.8822
# Epoch 39: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8558 - binary_io_u: 0.8816 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7350 - val_binary_io_u: 0.8103 - lr: 1.9531e-06
# Epoch 40/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9887 - f1_score: 0.8628 - binary_io_u: 0.8809
# Epoch 40: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0309 - accuracy: 0.9887 - f1_score: 0.8645 - binary_io_u: 0.8816 - val_loss: 0.0621 - val_accuracy: 0.9815 - val_f1_score: 0.7348 - val_binary_io_u: 0.8102 - lr: 1.9531e-06
# Epoch 41/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8592 - binary_io_u: 0.8814
# Epoch 41: val_binary_io_u did not improve from 0.81707
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8607 - binary_io_u: 0.8817 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7345 - val_binary_io_u: 0.8100 - lr: 1.9531e-06
# Epoch 42/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9888 - f1_score: 0.8618 - binary_io_u: 0.8822
# Epoch 42: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8580 - binary_io_u: 0.8817 - val_loss: 0.0621 - val_accuracy: 0.9815 - val_f1_score: 0.7347 - val_binary_io_u: 0.8102 - lr: 9.7656e-07
# Epoch 43/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0313 - accuracy: 0.9887 - f1_score: 0.8623 - binary_io_u: 0.8810
# Epoch 43: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0312 - accuracy: 0.9887 - f1_score: 0.8637 - binary_io_u: 0.8812 - val_loss: 0.0621 - val_accuracy: 0.9815 - val_f1_score: 0.7349 - val_binary_io_u: 0.8102 - lr: 9.7656e-07
# Epoch 44/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8679 - binary_io_u: 0.8819
# Epoch 44: val_binary_io_u did not improve from 0.81707
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8688 - binary_io_u: 0.8821 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7351 - val_binary_io_u: 0.8103 - lr: 9.7656e-07
# Epoch 45/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8630 - binary_io_u: 0.8819
# Epoch 45: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8621 - binary_io_u: 0.8819 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7353 - val_binary_io_u: 0.8104 - lr: 4.8828e-07
# Epoch 46/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9889 - f1_score: 0.8670 - binary_io_u: 0.8830
# Epoch 46: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0309 - accuracy: 0.9889 - f1_score: 0.8643 - binary_io_u: 0.8828 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7353 - val_binary_io_u: 0.8103 - lr: 4.8828e-07
# Epoch 47/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8584 - binary_io_u: 0.8806
# Epoch 47: val_binary_io_u did not improve from 0.81707
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0310 - accuracy: 0.9887 - f1_score: 0.8605 - binary_io_u: 0.8816 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7353 - val_binary_io_u: 0.8103 - lr: 4.8828e-07
# Epoch 48/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9889 - f1_score: 0.8690 - binary_io_u: 0.8831
# Epoch 48: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0308 - accuracy: 0.9889 - f1_score: 0.8660 - binary_io_u: 0.8828 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7354 - val_binary_io_u: 0.8103 - lr: 2.4414e-07
# Epoch 49/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9889 - f1_score: 0.8677 - binary_io_u: 0.8830
# Epoch 49: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0307 - accuracy: 0.9889 - f1_score: 0.8667 - binary_io_u: 0.8829 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7358 - val_binary_io_u: 0.8105 - lr: 2.4414e-07
# Epoch 50/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8648 - binary_io_u: 0.8816
# Epoch 50: val_binary_io_u did not improve from 0.81707
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8664 - binary_io_u: 0.8817 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7356 - val_binary_io_u: 0.8105 - lr: 2.4414e-07
# Epoch 51/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9889 - f1_score: 0.8664 - binary_io_u: 0.8829
# Epoch 51: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0308 - accuracy: 0.9888 - f1_score: 0.8549 - binary_io_u: 0.8821 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7356 - val_binary_io_u: 0.8104 - lr: 1.2207e-07
# Epoch 52/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9887 - f1_score: 0.8642 - binary_io_u: 0.8816
# Epoch 52: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8661 - binary_io_u: 0.8818 - val_loss: 0.0620 - val_accuracy: 0.9814 - val_f1_score: 0.7354 - val_binary_io_u: 0.8104 - lr: 1.2207e-07
# Epoch 53/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9889 - f1_score: 0.8679 - binary_io_u: 0.8831
# Epoch 53: val_binary_io_u did not improve from 0.81707
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0308 - accuracy: 0.9888 - f1_score: 0.8592 - binary_io_u: 0.8823 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7357 - val_binary_io_u: 0.8105 - lr: 1.2207e-07
# Epoch 54/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9889 - f1_score: 0.8687 - binary_io_u: 0.8836
# Epoch 54: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0308 - accuracy: 0.9888 - f1_score: 0.8554 - binary_io_u: 0.8826 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7358 - val_binary_io_u: 0.8105 - lr: 6.1035e-08
# Epoch 55/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0305 - accuracy: 0.9889 - f1_score: 0.8640 - binary_io_u: 0.8827
# Epoch 55: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0309 - accuracy: 0.9887 - f1_score: 0.8549 - binary_io_u: 0.8815 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7357 - val_binary_io_u: 0.8105 - lr: 6.1035e-08
# Epoch 56/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9889 - f1_score: 0.8669 - binary_io_u: 0.8827
# Epoch 56: val_binary_io_u did not improve from 0.81707
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0307 - accuracy: 0.9889 - f1_score: 0.8650 - binary_io_u: 0.8825 - val_loss: 0.0620 - val_accuracy: 0.9814 - val_f1_score: 0.7357 - val_binary_io_u: 0.8105 - lr: 6.1035e-08
# Epoch 57/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8591 - binary_io_u: 0.8812
# Epoch 57: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8610 - binary_io_u: 0.8817 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7355 - val_binary_io_u: 0.8104 - lr: 3.0518e-08
# Epoch 58/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9887 - f1_score: 0.8617 - binary_io_u: 0.8810
# Epoch 58: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0312 - accuracy: 0.9887 - f1_score: 0.8629 - binary_io_u: 0.8811 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7356 - val_binary_io_u: 0.8105 - lr: 3.0518e-08
# Epoch 59/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9887 - f1_score: 0.8619 - binary_io_u: 0.8813
# Epoch 59: val_binary_io_u did not improve from 0.81707
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8612 - binary_io_u: 0.8813 - val_loss: 0.0619 - val_accuracy: 0.9815 - val_f1_score: 0.7358 - val_binary_io_u: 0.8106 - lr: 3.0518e-08
# Epoch 60/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8618 - binary_io_u: 0.8825
# Epoch 60: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8583 - binary_io_u: 0.8822 - val_loss: 0.0619 - val_accuracy: 0.9815 - val_f1_score: 0.7359 - val_binary_io_u: 0.8106 - lr: 1.5259e-08
# Epoch 61/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9889 - f1_score: 0.8560 - binary_io_u: 0.8829
# Epoch 61: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8540 - binary_io_u: 0.8821 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7356 - val_binary_io_u: 0.8104 - lr: 1.5259e-08
# Epoch 62/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9888 - f1_score: 0.8586 - binary_io_u: 0.8823
# Epoch 62: val_binary_io_u did not improve from 0.81707
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1e-08.
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0306 - accuracy: 0.9888 - f1_score: 0.8595 - binary_io_u: 0.8824 - val_loss: 0.0620 - val_accuracy: 0.9814 - val_f1_score: 0.7358 - val_binary_io_u: 0.8105 - lr: 1.5259e-08
# Epoch 63/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9888 - f1_score: 0.8653 - binary_io_u: 0.8822
# Epoch 63: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0311 - accuracy: 0.9888 - f1_score: 0.8661 - binary_io_u: 0.8823 - val_loss: 0.0619 - val_accuracy: 0.9815 - val_f1_score: 0.7356 - val_binary_io_u: 0.8105 - lr: 1.0000e-08
# Epoch 64/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9888 - f1_score: 0.8651 - binary_io_u: 0.8826
# Epoch 64: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0311 - accuracy: 0.9888 - f1_score: 0.8485 - binary_io_u: 0.8817 - val_loss: 0.0620 - val_accuracy: 0.9814 - val_f1_score: 0.7355 - val_binary_io_u: 0.8104 - lr: 1.0000e-08
# Epoch 65/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8665 - binary_io_u: 0.8820
# Epoch 65: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8668 - binary_io_u: 0.8821 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7353 - val_binary_io_u: 0.8103 - lr: 1.0000e-08
# Epoch 66/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9886 - f1_score: 0.8642 - binary_io_u: 0.8808
# Epoch 66: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 100ms/step - loss: 0.0312 - accuracy: 0.9886 - f1_score: 0.8611 - binary_io_u: 0.8803 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7355 - val_binary_io_u: 0.8104 - lr: 1.0000e-08
# Epoch 67/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8674 - binary_io_u: 0.8819
# Epoch 67: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8652 - binary_io_u: 0.8817 - val_loss: 0.0620 - val_accuracy: 0.9814 - val_f1_score: 0.7355 - val_binary_io_u: 0.8104 - lr: 1.0000e-08
# Epoch 68/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9887 - f1_score: 0.8561 - binary_io_u: 0.8820
# Epoch 68: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8564 - binary_io_u: 0.8820 - val_loss: 0.0620 - val_accuracy: 0.9814 - val_f1_score: 0.7356 - val_binary_io_u: 0.8104 - lr: 1.0000e-08
# Epoch 69/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - accuracy: 0.9889 - f1_score: 0.8640 - binary_io_u: 0.8825
# Epoch 69: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0309 - accuracy: 0.9888 - f1_score: 0.8617 - binary_io_u: 0.8820 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7355 - val_binary_io_u: 0.8104 - lr: 1.0000e-08
# Epoch 70/70
# 49/50 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9887 - f1_score: 0.8597 - binary_io_u: 0.8816
# Epoch 70: val_binary_io_u did not improve from 0.81707
# 50/50 [==============================] - 5s 102ms/step - loss: 0.0310 - accuracy: 0.9888 - f1_score: 0.8609 - binary_io_u: 0.8817 - val_loss: 0.0620 - val_accuracy: 0.9815 - val_f1_score: 0.7355 - val_binary_io_u: 0.8104 - lr: 1.0000e-08

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 17]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
