# %% [markdown]
# ## Importing necessary modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
from tqdm import tqdm # Cool progress bar

import random
import numpy as np
import pandas as pd
import sys
import os # read and manipulate local files

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import cv2
import seaborn as sns

from PIL import Image

import tensorflow.keras as ks
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K # F1-score metric

from tensorflow.keras.callbacks import ModelCheckpoint, Callback, ReduceLROnPlateau
from tensorflow.keras.layers import   Lambda, Conv2D, MaxPool2D, UpSampling2D, BatchNormalization, Flatten
from tensorflow.keras.layers import  GlobalAveragePooling2D, Reshape, Multiply, Attention, add,Resizing,  Input, Dense
from tensorflow.keras.layers import Activation,AveragePooling2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate, UpSampling2D
from tensorflow.keras.models import Model, Sequential

# hide wornings
import warnings
warnings.filterwarnings('ignore')


from imgaug import augmenters as iaa ## for augmentation

# %% [markdown]
# ## Defining paths

# %%
model_name =  'deep_ResUNet_2500_batch10'

################################################################################################
## SETTING THE PATHS
PATH_TO_CODE ='/content/drive/MyDrive/TRIAL_v1/segmentation_task'
# PATH_TO_CODE =''
sys.path.append(PATH_TO_CODE)

# DATASET_PATH = r'C:\Users\ASUS\Desktop\segmentation & cropping\segmentation_task\segmentation_data43_resized_cropped_split'
DATASET_PATH = r'/content/drive/MyDrive/TRIAL_v1/segmentation_task/segmentation_data43_resized_cropped_split'
# DATASET_PATH = r'segmentation_data43_resized_cropped_split'
DATASET_PATH_TRAIN = os.path.join(DATASET_PATH, 'train')
DATASET_PATH_TEST = os.path.join(DATASET_PATH, 'test')


PATH_TO_SAVE_RESULT = os.path.join(PATH_TO_CODE, 'saved_outputs_segmentation', model_name)
PATH_BEST_SAVE_WEIGHT = os.path.join(PATH_TO_SAVE_RESULT,'saved_weights')
PATH_TO_SAVE_MODEL = os.path.join(PATH_TO_SAVE_RESULT, 'saved_models')
PATH_SAVE_HISTORY = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_history.csv')
PATH_SAVE_TIME = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_training_time.csv')
PATH_SAVE_AUGMENT_SAMPLE = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_augmented_sample.pdf')
PATH_SAVE_PIXEL_PERCENTAGE_PLOT = os.path.join(PATH_TO_SAVE_RESULT, model_name+'_pixel_percentage.pdf')
# PATH_TO_SAVE_TUNER = os.path.join(PATH_TO_RESULT, 'saved_tuner_model')
################################################################################################

if not os.path.exists(PATH_TO_SAVE_RESULT):
 # If it does not exist, create it
    os.makedirs(PATH_TO_SAVE_RESULT)
################################################################################################
IMG_HEIGHT = 256
IMG_WIDTH = 256
ORIGINAL_IMAGE_SIZE = (IMG_HEIGHT, IMG_WIDTH)
COLOR_CHANNEL = 3

RESIZE_SHAPE = ORIGINAL_IMAGE_SIZE #(128, 128) #ORIGINAL_IMAGE_SIZE#(128, 128)# # #ORIGINAL_IMAGE_SIZE# (128, 128)#
MODEL_INPUT_SIZE = (RESIZE_SHAPE[0], RESIZE_SHAPE[1], COLOR_CHANNEL)

VALIDATION_SPLIT= 0.2
NUM_CLASSES = 2 # Disease and not disease

BATCH_SIZE = 10
EPOCHS = 70#100

TOTAL_DATA = 2500
################################################################################################

################################################################################################

SAVE_RESULTS = True
SHOW_RESULTS = True

################################################################################################
# Setting the seed
SEED  = 123
RNG = np.random.default_rng(SEED) # Random number generator
tf.random.set_seed(SEED)

################################################################################################
# Checkpoint parameters val_binary_io_u
SCORE_TO_MONITOR = 'val_binary_io_u' # Score that checkpoints monitor during training
SCORE_OBJECTIVE  = 'max'          # 'max' or 'min', specifies whether the objective is to maximize the score or minimize it.
PATIENCE_LR_REDUCE = 5
MIN_LR = 1e-8
REDUCTION_FACTOR = 0.5            # Factor which lr will be reduced with at plateau
# COOLDOWN_EPOCHS  = 2 #cooldown: Integer. Number of epochs to wait before resuming normal operation after the learning rate has been reduced.

INITIAL_LR = 0.001

# %% [markdown]
# ## Defining performance metrics
#
# Official segmentation metrics by keras: https://ks.io/api/metrics/segmentation_metrics/

# %%
def f1_score(y_true, y_pred): # Dice coefficient
    """
    Calculate the F1 score, the harmonic mean of precision and recall, for binary classification.

    Args:
        y_true (Tensor): True binary labels.
        y_pred (Tensor): Predicted probabilities.

    Returns:
        float32: F1 score as a scalar.
    """
    # True Positives: round product of y_true and y_pred
    TP = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    # Actual Positives: round y_true
    P = K.sum(K.round(K.clip(y_true, 0, 1)))
    # Recall: TP / Actual Positives
    recall = TP / (P + K.epsilon())

    # Predicted Positives: round y_pred
    Pred_P = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Precision: TP / Predicted Positives
    precision = TP / (Pred_P + K.epsilon())

    # F1 Score: harmonic mean of precision and recall
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# source: https://www.tensorflow.org/api_docs/python/tf/keras/metrics/BinaryIoU
iou_score_binary = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)

def accuracy_score(y_true, y_pred):
    """
    Calculate accuracy score between two binary masks.
    """
    correct = np.sum(y_true == y_pred)  # Count correct predictions
    total = y_true.size  # Total number of pixels
    return correct / total  # Accuracy calculation

def precision_score(groundtruth_mask, pred_mask):
    """
    Calculate precision score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_pred = np.sum(pred_mask)  # Sum of predicted positives
    return np.mean(intersect / total_pixel_pred)  # Precision calculation

def recall_score(groundtruth_mask, pred_mask):
    """
    Calculate recall score between two binary masks.
    """
    intersect = np.sum(pred_mask * groundtruth_mask)  # Calculate intersection
    total_pixel_truth = np.sum(groundtruth_mask)  # Sum of actual positives
    return np.mean(intersect / total_pixel_truth)  # Recall calculation

# %% [markdown]
# ## Reading the data

# %%
# Function to read images from a directory using Pillow
def read_images_from_directory(directory_path):
    images = []
    for filename in sorted(os.listdir(directory_path)):
        # filename= filename.lower()

        if filename.endswith(('.png', '.jpg', '.JPG' )):  # Check for image file extensions
            img_path = os.path.join(directory_path, filename)
            img = Image.open(img_path)
            img_array = np.array(img)  # Convert the image to a numpy array if needed
            if img_array is not None:
                images.append(img_array)
    return images

# Paths to masks and original images within the dataset
masks_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_masks_binarised')
originals_path_train = os.path.join(DATASET_PATH_TRAIN, 'data43_original')

# Read images into variables
x_train = read_images_from_directory(originals_path_train)  # Original images
y_train = read_images_from_directory(masks_path_train)  # Masks

# Paths to masks and original images within the test dataset
masks_path_test = os.path.join(DATASET_PATH_TEST, 'data43_masks_binarised')
originals_path_test = os.path.join(DATASET_PATH_TEST, 'data43_original')

# Read images into variables
x_test = read_images_from_directory(originals_path_test)  # Original images
y_test = read_images_from_directory(masks_path_test)  # Masks

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 616 original images into x_train
# Loaded 616 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Augmentations

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),  # horizontally flip 50% of the images
    iaa.Flipud(0.2),  # vertically flip 20% of the images
    iaa.Affine(
        scale={"x": (0.8, 1.1), "y": (0.8, 1.1)},  # zoom in or out (80-120%)
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},  # width & height shift (-20 to +20%)
        rotate=(-15, 15),  # rotation (-45 to 45 degrees)
        shear=(-16, 16)  # shear (-16 to 16 degrees)
    ),
    iaa.ElasticTransformation(alpha=(0, 2.0), sigma=0.25),  # apply elastic deformations
    iaa.GaussianBlur(sigma=(0, 2.0))  # apply Gaussian blur
])

# %%
# Function to augment a batch of images and masks
def augment_batch(images, masks, seq, batch_size):
    augmented_images = []
    augmented_masks = []
    while len(augmented_images) < batch_size:
        aug_images, aug_masks = seq(images=images, segmentation_maps=np.expand_dims(masks, axis=-1))
        augmented_images.extend(aug_images)
        augmented_masks.extend(aug_masks)

        if len(augmented_images) >= batch_size:
            break

    # Ensure we only take as many as we need to reach the desired batch_size
    augmented_images = augmented_images[:batch_size]
    augmented_masks = augmented_masks[:batch_size]

    return np.array(augmented_images), np.squeeze(np.array(augmented_masks), axis=-1)

# %%
num_augmented_images_needed = TOTAL_DATA  - len(x_train)  # Calculate how many augmented images we need
if num_augmented_images_needed > 0:
    augmented_x, augmented_y = augment_batch(x_train, y_train, seq, num_augmented_images_needed)
    # Concatenate the original and augmented datasets
    combined_x_train = np.concatenate((x_train, augmented_x), axis=0)
    combined_y_train = np.concatenate((y_train, augmented_y), axis=0)
else:
    combined_x_train = x_train
    combined_y_train = y_train

# %%
x_train = combined_x_train
y_train = combined_y_train

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 255.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 255
        if np.any((image != 0) & (image != 255)):
            return "Has other pixel values"
    return "Only contains 0 and 255"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 255
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 255
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 255
# y_test: Only contains 0 and 255

# %% [markdown]
# ## Visualization

# %%
indices = np.array([i for i in range(len(x_train))])
plot_indices = RNG.choice(indices, size=4, replace=False)

fig, ax = plt.subplots(2,4, figsize=(10,5))
for i in range(len(plot_indices)):
    X_plot = x_train[plot_indices[i]]
    y_plot = y_train[plot_indices[i]]
    ax[0,i].imshow(X_plot)
    ax[1,i].imshow(y_plot, cmap = 'gray')

ax[0,0].set_title('Sample 1', fontsize=10)
ax[0,1].set_title('Sample 2', fontsize=10)
ax[0,2].set_title('Sample 3', fontsize=10)
ax[0,3].set_title('Sample 4', fontsize=10)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_AUGMENT_SAMPLE) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
positive_pixel_count = np.zeros(len(y_train))
#image_size = x_train.shape[1]*x_train.shape[2]
image_size = ORIGINAL_IMAGE_SIZE[0] * ORIGINAL_IMAGE_SIZE[1]#x_train.shape[1]*x_train.shape[2]
for i in tqdm(range(len(y_train))):
    single_y = y_train[i]
    positive_pixel_count[i] = np.sum(single_y != 0) / image_size * 100

fig, ax = plt.subplots(1,1,figsize=(8,4))
sns.histplot(positive_pixel_count, stat='percent', ax=ax)
ax.set_xlabel('Percentage of positive pixels in mask')
ax.set_title('Label distribution plot')
ax.grid('on')
plt.show()

if SAVE_RESULTS:
    # Save the plot to a PDF
    with PdfPages(PATH_SAVE_PIXEL_PERCENTAGE_PLOT) as pdf:
        pdf.savefig(fig)
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()
# Out:
# 100%|██████████| 2500/2500 [00:00<00:00, 18753.71it/s]

# %% [markdown]
# ## Preprocessing DO NOT RESIZE THE IMAGE-- IT GIVES FINE LINES IN THE OUTPUT

# %%
# # # Resizing
# x_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_train]
# y_train = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_train]

# x_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in x_test]
# y_test = [np.array(Image.fromarray(image).resize(RESIZE_SHAPE)) for image in y_test]

# Convert the list to a NumPy array
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)


# Normalizing input between [0,1]
x_train = x_train.astype("float32")/ np.max(x_train)
x_test  = x_test.astype("float32")/np.max(x_test)

y_train = y_train.astype("float32")/ np.max(y_train)
y_test  = y_test.astype("float32")/np.max(y_test)

# Now x_train contains original images, and y_train contains mask images
print(f"Loaded {len(x_train)} original images into x_train")
print(f"Loaded {len(y_train)} mask images into y_train")

# Similarly, for test images
print(f"Loaded {len(x_test)} original images into x_test")
print(f"Loaded {len(y_test)} mask images into y_test")
# Out:
# Loaded 2500 original images into x_train
# Loaded 2500 mask images into y_train
# Loaded 23 original images into x_test
# Loaded 23 mask images into y_test

# %% [markdown]
# ## Checking if the masks are correct

# %%
def has_other_values(images):
    """
    Check if the numpy array 'images' contains any pixel values other than 0 and 1.

    Parameters:
    images (list of numpy.ndarray): A list of numpy arrays, each containing image data.

    Returns:
    str: A message indicating whether other pixel values are present.
    """
    # Iterate through each image in the list
    for image in images:
        # Check if any value in the image is not equal to 0 or 1
        if np.any((image != 0) & (image != 1)):
            return "Has other pixel values"
    return "Only contains 0 and 1"

# Example usage with y_train and y_test (assumed to be lists of numpy arrays)

# Check y_train for any values other than 0 and 1
result_train = has_other_values(y_train)
print("y_train:", result_train)

# Check y_test for any values other than 0 and 1
result_test = has_other_values(y_test)
print("y_test:", result_test)
# Out:
# y_train: Only contains 0 and 1
# y_test: Only contains 0 and 1

# %% [markdown]
# ## Visualization after pre-processing for checking condition

# %%
Rand_Nub = RNG.integers(1,10,5)
fig, ax = plt.subplots(2, 5 ,figsize=(14,5))#width, h
for i in range(Rand_Nub.shape[0]):
    ax[0, i].imshow(x_train[Rand_Nub[i]])
    ax[0, i].axes.xaxis.set_ticklabels([])
    ax[0, i].axes.yaxis.set_ticklabels([])
    ax[0, i].set_title('Input: '+str(i), fontsize=11)
    ax[0, i].axis('off')

    ax[1, i].imshow(y_train[Rand_Nub[i]] ,cmap = 'gray')
    ax[1, i].axes.xaxis.set_ticklabels([])
    ax[1, i].axes.yaxis.set_ticklabels([])
    ax[1, i].set_title('Ground_Mask: '+str(i), fontsize=11)
    ax[1, i].axis('off')

# %% [markdown]
# ## Essential functions

# %%
def fit_and_save_best_model(model_name, model, epochs=EPOCHS):
    ##########################################################################################################
    saved_best_model_name = 'best_'+model_name+'.h5'

    model_saving_path = os.path.join(PATH_TO_SAVE_MODEL, saved_best_model_name)
    # Set up a model checkpoint to save the best model during training
    best_model_callback= ModelCheckpoint(model_saving_path,
                                          monitor=SCORE_TO_MONITOR,
                                          save_best_only=True,
                                          mode=SCORE_OBJECTIVE,
                                          verbose=1)

    reduce_LR = ReduceLROnPlateau(
        factor=REDUCTION_FACTOR,      # Factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=PATIENCE_LR_REDUCE, # original was 5      # Number of epochs with no improvement after which learning rate will be reduced.
        verbose=1,       # int. 0: quiet, 1: update messages.
        min_lr=MIN_LR   # Lower bound on the learning rate.
    )

    my_callbacks = [best_model_callback , reduce_LR]
    ##########################################################################################################

    start_time = time.time()

    # Fitting the model
    train_history = model.fit(
        x_train,
        y_train,
        epochs= epochs,
        batch_size=BATCH_SIZE,
        validation_split= VALIDATION_SPLIT,
        callbacks=my_callbacks,
    )
    total_time = time.time() - start_time

    return saved_best_model_name, train_history, total_time

# %%
def plot_training_history(training_history_object, list_of_metrics=None):
    """
    Input:
        training_history_object:: Object returned by model.fit() function in keras
        list_of_metrics        :: A list of metrics to be plotted. Use if you only
                                  want to plot a subset of the total set of metrics
                                  in the training history object. By Default it will
                                  plot all of them in individual subplots.
    """
    history_dict = training_history_object.history

    ###################addDED NEW################################################
    ###Remove 'lr' and 'val_lr' keys from history_dict if they exist
    history_dict.pop('lr', None)
    history_dict.pop('val_lr', None)
    #############################################################################

    if list_of_metrics is None:
        list_of_metrics = [key for key in list(history_dict.keys()) if 'val_' not in key]

    # print(list_of_metrics)
    trainHistDF = pd.DataFrame(history_dict)
    # trainHistDF.head()
    train_keys = list_of_metrics
    valid_keys = ['val_' + key for key in train_keys]
    nr_plots = len(train_keys)
    fig, ax = plt.subplots(1,nr_plots,figsize=(4*nr_plots,4))
    for i in range(len(train_keys)):
        ax[i].plot(np.array(trainHistDF[train_keys[i]]), label='Training')
        ax[i].plot(np.array(trainHistDF[valid_keys[i]]), label='Validation')
        ax[i].set_xlabel('Epoch')
        if train_keys[i] == 'binary_io_u':
             ax[i].set_title('IoU')
        else:
            ax[i].set_title(train_keys[i])
        ax[i].grid('on')
        ax[i].legend()
    fig.tight_layout()


    if SAVE_RESULTS:
        # Save the plot to a PDF
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_training_history.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig(fig)
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %% [markdown]
# ## Models
# ### Models worked
# - Model01: Basic basic_unet
# - Model02: unet_vgg16 (my own custom)
# - Model03: TransUNet
# - Model04: DeepLab-v3Plus
# - Model05: ResUNet
# - Model06: UNet_with_attention
# - Model07: Multi-resUnet
# - Model08: Inception_resnetV2 (my own custom)

# %% [markdown]
# ### ResUnet

# %%
############################# CONVOLUTIONAL BLOCK #############################

def conv_block(feature_map):

    # Main Path
    conv_1 = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(feature_map)
    bn = BatchNormalization()(conv_1)
    relu = Activation(activation='relu')(bn)
    conv_2 = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same')(relu)

    res_conn = Conv2D(filters=64, kernel_size=(1,1), strides=(1,1), padding='same')(feature_map)
    res_conn = BatchNormalization()(res_conn)
    addition = add([res_conn, conv_2])

    return addition

############################### RESIDUAL BLOCK ################################

def res_block(feature_map, conv_filter, stride):

    bn_1 = BatchNormalization()(feature_map)
    relu_1 = Activation(activation='relu')(bn_1)
    conv_1 = Conv2D(conv_filter, kernel_size=(3,3), strides=stride[0], padding='same')(relu_1)
    bn_2 = BatchNormalization()(conv_1)
    relu_2 = Activation(activation='relu')(bn_2)
    conv_2 = Conv2D(conv_filter, kernel_size=(3,3), strides=stride[1], padding='same')(relu_2)


    res_conn = Conv2D(conv_filter, kernel_size=(1,1), strides=stride[0], padding='same')(feature_map)
    res_conn = BatchNormalization()(res_conn)
    addition = add([res_conn, conv_2])

    return addition

################################### ENCODER ###################################

def encoder(feature_map):

    # Initialize the to_decoder connection
    to_decoder = []

    # Block 1 - Convolution Block
    path = conv_block(feature_map)
    to_decoder.append(path)

    # Block 2 - Residual Block 1
    path = res_block(path, 128, [(2, 2), (1, 1)])
    to_decoder.append(path)

    # Block 3 - Residual Block 2
    path = res_block(path, 256, [(2, 2), (1, 1)])
    to_decoder.append(path)

    return to_decoder

################################### DECODER ###################################

def decoder(feature_map, from_encoder):

    # Block 1: Up-sample, Concatenation + Residual Block 1
    main_path = UpSampling2D(size=(2,2), interpolation='bilinear')(feature_map)
    # main_path = Conv2DTranspose(filters=256, kernel_size=(2,2), strides=(2,2), padding='same')(feature_map)
    main_path = Concatenate()([main_path, from_encoder[2]])
    main_path = res_block(main_path, 256, [(1, 1), (1, 1)])

    # Block 2: Up-sample, Concatenation + Residual Block 2
    main_path = UpSampling2D(size=(2,2), interpolation='bilinear')(main_path)
    # main_path = Conv2DTranspose(filters=128, kernel_size=(2,2), strides=(2,2), padding='same')(main_path)
    main_path = Concatenate()([main_path, from_encoder[1]])
    main_path = res_block(main_path, 128, [(1, 1), (1, 1)])

    # Block 3: Up-sample, Concatenation + Residual Block 3
    main_path = UpSampling2D(size=(2,2), interpolation='bilinear')(main_path)
    # main_path = Conv2DTranspose(filters=64, kernel_size=(2,2), strides=(2,2), padding='same')(main_path)
    main_path = Concatenate()([main_path, from_encoder[0]])
    main_path = res_block(main_path, 64, [(1, 1), (1, 1)])

    return main_path

################################ RESIDUAL UNET ################################

def get_ResUNet():
    ## SOURCE: https://github.com/edwinpalegre/EE8204-ResUNet/blob/master/model_resunet.py

    # Input
    model_input = Input(shape=MODEL_INPUT_SIZE)

    # Encoder Path
    model_encoder = encoder(model_input)

    # Bottleneck
    model_bottleneck = res_block(model_encoder[2], 512, [(2, 2), (1, 1)])

    # Decoder Path
    model_decoder = decoder(model_bottleneck, model_encoder)

    # Output
    model_output = Conv2D(filters=1, kernel_size=(1, 1), strides=(1, 1), activation='sigmoid', padding='same')(model_decoder)

    model= Model(model_input, model_output)

    optimizer = Adam(learning_rate=INITIAL_LR)
    model.compile(loss='binary_crossentropy',
                  metrics=['accuracy', f1_score, iou_score_binary],
                  optimizer=optimizer)

    return model

# %% [markdown]
# ## Train and Results

# %%
# model= get_basic_unet() ## Model1
# model= get_unet_vgg16() ## Model2
# model= get_TransUNet() ## Model3
# model= get_DeepLabV3Plus() ## Model4
model = get_ResUNet() ## Model5
# model = UNet_with_attention() ## Model6
# model = get_multiresunet() ## Model7
# model = get_unet_InceptionResNetV2() ## Model8

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 64)         256       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 64)         0         ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 64)         256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36928     ['activation[0][0]']
#
#  add (Add)                   (None, 256, 256, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 64)         256       ['add[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)        73856     ['activation_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 128)        512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 128)        8320      ['add[0][0]']
#
#  activation_2 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 128, 128, 128)        512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 128)        147584    ['activation_2[0][0]']
#
#  add_1 (Add)                 (None, 128, 128, 128)        0         ['batch_normalization_4[0][0]'
#                                                                     , 'conv2d_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 128)        512       ['add_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 256)          295168    ['activation_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64, 64, 256)          1024      ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 256)          33024     ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 64, 64, 256)          1024      ['conv2d_8[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 256)          590080    ['activation_4[0][0]']
#
#  add_2 (Add)                 (None, 64, 64, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv2d_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 256)          1024      ['add_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 512)          1180160   ['activation_5[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 512)          2048      ['conv2d_9[0][0]']
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 512)          131584    ['add_2[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 512)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_10 (Ba  (None, 32, 32, 512)          2048      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_6[0][0]']
#
#  add_3 (Add)                 (None, 32, 32, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'conv2d_10[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 64, 64, 512)          0         ['add_3[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 64, 64, 768)          0         ['up_sampling2d[0][0]',
#                                                                      'add_2[0][0]']
#
#  batch_normalization_11 (Ba  (None, 64, 64, 768)          3072      ['concatenate[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 64, 64, 768)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)          1769728   ['activation_7[0][0]']
#
#  batch_normalization_12 (Ba  (None, 64, 64, 256)          1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 256)          196864    ['concatenate[0][0]']
#
#  activation_8 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 64, 64, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_8[0][0]']
#
#  add_4 (Add)                 (None, 64, 64, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'conv2d_13[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 128, 128, 256)        0         ['add_4[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_1[0][0]',
#  )                                                                   'add_1[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128, 128, 384)        1536      ['concatenate_1[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 128, 128, 384)        0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 128)        442496    ['activation_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 128)        512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 128)        49280     ['concatenate_1[0][0]']
#
#  activation_10 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 128, 128, 128)        512       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_10[0][0]']
#
#  add_5 (Add)                 (None, 128, 128, 128)        0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'conv2d_16[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 256, 256, 128)        0         ['add_5[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'add[0][0]']
#
#  batch_normalization_17 (Ba  (None, 256, 256, 192)        768       ['concatenate_2[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 256, 256, 192)        0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 64)         110656    ['activation_11[0][0]']
#
#  batch_normalization_18 (Ba  (None, 256, 256, 64)         256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 64)         12352     ['concatenate_2[0][0]']
#
#  activation_12 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 256, 256, 64)         256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_12[0][0]']
#
#  add_6 (Add)                 (None, 256, 256, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 256, 256, 1)          65        ['add_6[0][0]']
#
# ==================================================================================================
# Total params: 8233025 (31.41 MB)
# Trainable params: 8223809 (31.37 MB)
# Non-trainable params: 9216 (36.00 KB)
# __________________________________________________________________________________________________

# %%
# training the model and saving the best model as a check point
best_model_name, train_history, total_time = fit_and_save_best_model(model_name, model)
# Out:
# Epoch 1/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9730 - f1_score: 0.6488 - binary_io_u: 0.7171
# Epoch 1: val_binary_io_u improved from -inf to 0.48205, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 133s 494ms/step - loss: 0.0836 - accuracy: 0.9730 - f1_score: 0.6488 - binary_io_u: 0.7171 - val_loss: 0.1351 - val_accuracy: 0.9628 - val_f1_score: 0.0017 - val_binary_io_u: 0.4821 - lr: 0.0010
# Epoch 2/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9812 - f1_score: 0.7228 - binary_io_u: 0.7827
# Epoch 2: val_binary_io_u improved from 0.48205 to 0.57950, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 446ms/step - loss: 0.0569 - accuracy: 0.9812 - f1_score: 0.7228 - binary_io_u: 0.7827 - val_loss: 0.0955 - val_accuracy: 0.9695 - val_f1_score: 0.2798 - val_binary_io_u: 0.5795 - lr: 0.0010
# Epoch 3/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9819 - f1_score: 0.7379 - binary_io_u: 0.7908
# Epoch 3: val_binary_io_u improved from 0.57950 to 0.78616, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0542 - accuracy: 0.9819 - f1_score: 0.7379 - binary_io_u: 0.7908 - val_loss: 0.0566 - val_accuracy: 0.9830 - val_f1_score: 0.7022 - val_binary_io_u: 0.7862 - lr: 0.0010
# Epoch 4/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9830 - f1_score: 0.7551 - binary_io_u: 0.8028
# Epoch 4: val_binary_io_u improved from 0.78616 to 0.80703, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0509 - accuracy: 0.9830 - f1_score: 0.7551 - binary_io_u: 0.8028 - val_loss: 0.0469 - val_accuracy: 0.9843 - val_f1_score: 0.7252 - val_binary_io_u: 0.8070 - lr: 0.0010
# Epoch 5/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9835 - f1_score: 0.7650 - binary_io_u: 0.8075
# Epoch 5: val_binary_io_u did not improve from 0.80703
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0494 - accuracy: 0.9835 - f1_score: 0.7650 - binary_io_u: 0.8075 - val_loss: 0.0479 - val_accuracy: 0.9844 - val_f1_score: 0.7095 - val_binary_io_u: 0.8008 - lr: 0.0010
# Epoch 6/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9838 - f1_score: 0.7651 - binary_io_u: 0.8112
# Epoch 6: val_binary_io_u improved from 0.80703 to 0.81169, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0480 - accuracy: 0.9838 - f1_score: 0.7651 - binary_io_u: 0.8112 - val_loss: 0.0446 - val_accuracy: 0.9849 - val_f1_score: 0.7258 - val_binary_io_u: 0.8117 - lr: 0.0010
# Epoch 7/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9835 - f1_score: 0.7652 - binary_io_u: 0.8077
# Epoch 7: val_binary_io_u did not improve from 0.81169
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0488 - accuracy: 0.9835 - f1_score: 0.7652 - binary_io_u: 0.8077 - val_loss: 0.0490 - val_accuracy: 0.9836 - val_f1_score: 0.7341 - val_binary_io_u: 0.8110 - lr: 0.0010
# Epoch 8/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9845 - f1_score: 0.7748 - binary_io_u: 0.8181
# Epoch 8: val_binary_io_u improved from 0.81169 to 0.81620, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0461 - accuracy: 0.9845 - f1_score: 0.7748 - binary_io_u: 0.8181 - val_loss: 0.0437 - val_accuracy: 0.9850 - val_f1_score: 0.7330 - val_binary_io_u: 0.8162 - lr: 0.0010
# Epoch 9/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9845 - f1_score: 0.7760 - binary_io_u: 0.8181
# Epoch 9: val_binary_io_u did not improve from 0.81620
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0462 - accuracy: 0.9845 - f1_score: 0.7760 - binary_io_u: 0.8181 - val_loss: 0.1075 - val_accuracy: 0.9565 - val_f1_score: 0.5410 - val_binary_io_u: 0.6743 - lr: 0.0010
# Epoch 10/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9847 - f1_score: 0.7756 - binary_io_u: 0.8203
# Epoch 10: val_binary_io_u did not improve from 0.81620
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0458 - accuracy: 0.9847 - f1_score: 0.7756 - binary_io_u: 0.8203 - val_loss: 0.0461 - val_accuracy: 0.9844 - val_f1_score: 0.7312 - val_binary_io_u: 0.8117 - lr: 0.0010
# Epoch 11/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9847 - f1_score: 0.7783 - binary_io_u: 0.8205
# Epoch 11: val_binary_io_u did not improve from 0.81620
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0452 - accuracy: 0.9847 - f1_score: 0.7783 - binary_io_u: 0.8205 - val_loss: 0.0479 - val_accuracy: 0.9831 - val_f1_score: 0.7349 - val_binary_io_u: 0.8076 - lr: 0.0010
# Epoch 12/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9847 - f1_score: 0.7772 - binary_io_u: 0.8203
# Epoch 12: val_binary_io_u improved from 0.81620 to 0.82000, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 446ms/step - loss: 0.0454 - accuracy: 0.9847 - f1_score: 0.7772 - binary_io_u: 0.8203 - val_loss: 0.0424 - val_accuracy: 0.9858 - val_f1_score: 0.7397 - val_binary_io_u: 0.8200 - lr: 0.0010
# Epoch 13/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9850 - f1_score: 0.7805 - binary_io_u: 0.8237
# Epoch 13: val_binary_io_u improved from 0.82000 to 0.82102, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0442 - accuracy: 0.9850 - f1_score: 0.7805 - binary_io_u: 0.8237 - val_loss: 0.0451 - val_accuracy: 0.9856 - val_f1_score: 0.7413 - val_binary_io_u: 0.8210 - lr: 0.0010
# Epoch 14/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9852 - f1_score: 0.7863 - binary_io_u: 0.8258
# Epoch 14: val_binary_io_u did not improve from 0.82102
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0438 - accuracy: 0.9852 - f1_score: 0.7863 - binary_io_u: 0.8258 - val_loss: 0.0521 - val_accuracy: 0.9825 - val_f1_score: 0.7066 - val_binary_io_u: 0.7881 - lr: 0.0010
# Epoch 15/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9847 - f1_score: 0.7783 - binary_io_u: 0.8205
# Epoch 15: val_binary_io_u did not improve from 0.82102
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0456 - accuracy: 0.9847 - f1_score: 0.7783 - binary_io_u: 0.8205 - val_loss: 0.0427 - val_accuracy: 0.9855 - val_f1_score: 0.7350 - val_binary_io_u: 0.8156 - lr: 0.0010
# Epoch 16/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9856 - f1_score: 0.7911 - binary_io_u: 0.8298
# Epoch 16: val_binary_io_u improved from 0.82102 to 0.82308, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0427 - accuracy: 0.9856 - f1_score: 0.7911 - binary_io_u: 0.8298 - val_loss: 0.0414 - val_accuracy: 0.9860 - val_f1_score: 0.7382 - val_binary_io_u: 0.8231 - lr: 0.0010
# Epoch 17/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9852 - f1_score: 0.7854 - binary_io_u: 0.8255
# Epoch 17: val_binary_io_u did not improve from 0.82308
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0440 - accuracy: 0.9852 - f1_score: 0.7854 - binary_io_u: 0.8255 - val_loss: 0.0439 - val_accuracy: 0.9851 - val_f1_score: 0.7469 - val_binary_io_u: 0.8205 - lr: 0.0010
# Epoch 18/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9860 - f1_score: 0.7948 - binary_io_u: 0.8340
# Epoch 18: val_binary_io_u improved from 0.82308 to 0.82889, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0416 - accuracy: 0.9860 - f1_score: 0.7948 - binary_io_u: 0.8340 - val_loss: 0.0414 - val_accuracy: 0.9858 - val_f1_score: 0.7613 - val_binary_io_u: 0.8289 - lr: 0.0010
# Epoch 19/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9858 - f1_score: 0.7931 - binary_io_u: 0.8320
# Epoch 19: val_binary_io_u did not improve from 0.82889
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0417 - accuracy: 0.9858 - f1_score: 0.7931 - binary_io_u: 0.8320 - val_loss: 0.0436 - val_accuracy: 0.9850 - val_f1_score: 0.7378 - val_binary_io_u: 0.8159 - lr: 0.0010
# Epoch 20/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9862 - f1_score: 0.7985 - binary_io_u: 0.8355
# Epoch 20: val_binary_io_u did not improve from 0.82889
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0411 - accuracy: 0.9862 - f1_score: 0.7985 - binary_io_u: 0.8355 - val_loss: 0.0432 - val_accuracy: 0.9852 - val_f1_score: 0.7309 - val_binary_io_u: 0.8182 - lr: 0.0010
# Epoch 21/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9862 - f1_score: 0.8007 - binary_io_u: 0.8357
# Epoch 21: val_binary_io_u did not improve from 0.82889
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0408 - accuracy: 0.9862 - f1_score: 0.8007 - binary_io_u: 0.8357 - val_loss: 0.0422 - val_accuracy: 0.9855 - val_f1_score: 0.7511 - val_binary_io_u: 0.8287 - lr: 0.0010
# Epoch 22/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9870 - f1_score: 0.8121 - binary_io_u: 0.8450
# Epoch 22: val_binary_io_u did not improve from 0.82889
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0378 - accuracy: 0.9870 - f1_score: 0.8121 - binary_io_u: 0.8450 - val_loss: 0.0368 - val_accuracy: 0.9869 - val_f1_score: 0.7459 - val_binary_io_u: 0.8285 - lr: 5.0000e-04
# Epoch 23/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9875 - f1_score: 0.8165 - binary_io_u: 0.8498
# Epoch 23: val_binary_io_u improved from 0.82889 to 0.83863, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0364 - accuracy: 0.9875 - f1_score: 0.8165 - binary_io_u: 0.8498 - val_loss: 0.0363 - val_accuracy: 0.9873 - val_f1_score: 0.7652 - val_binary_io_u: 0.8386 - lr: 5.0000e-04
# Epoch 24/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9874 - f1_score: 0.8155 - binary_io_u: 0.8491
# Epoch 24: val_binary_io_u did not improve from 0.83863
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0367 - accuracy: 0.9874 - f1_score: 0.8155 - binary_io_u: 0.8491 - val_loss: 0.0370 - val_accuracy: 0.9872 - val_f1_score: 0.7588 - val_binary_io_u: 0.8367 - lr: 5.0000e-04
# Epoch 25/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9877 - f1_score: 0.8217 - binary_io_u: 0.8519
# Epoch 25: val_binary_io_u improved from 0.83863 to 0.84033, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0358 - accuracy: 0.9877 - f1_score: 0.8217 - binary_io_u: 0.8519 - val_loss: 0.0372 - val_accuracy: 0.9876 - val_f1_score: 0.7635 - val_binary_io_u: 0.8403 - lr: 5.0000e-04
# Epoch 26/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9877 - f1_score: 0.8218 - binary_io_u: 0.8523
# Epoch 26: val_binary_io_u improved from 0.84033 to 0.84506, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0359 - accuracy: 0.9877 - f1_score: 0.8218 - binary_io_u: 0.8523 - val_loss: 0.0365 - val_accuracy: 0.9878 - val_f1_score: 0.7747 - val_binary_io_u: 0.8451 - lr: 5.0000e-04
# Epoch 27/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0353 - accuracy: 0.9879 - f1_score: 0.8226 - binary_io_u: 0.8543
# Epoch 27: val_binary_io_u did not improve from 0.84506
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0353 - accuracy: 0.9879 - f1_score: 0.8226 - binary_io_u: 0.8543 - val_loss: 0.0380 - val_accuracy: 0.9867 - val_f1_score: 0.7611 - val_binary_io_u: 0.8395 - lr: 5.0000e-04
# Epoch 28/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9877 - f1_score: 0.8189 - binary_io_u: 0.8525
# Epoch 28: val_binary_io_u did not improve from 0.84506
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0355 - accuracy: 0.9877 - f1_score: 0.8189 - binary_io_u: 0.8525 - val_loss: 0.0377 - val_accuracy: 0.9874 - val_f1_score: 0.7496 - val_binary_io_u: 0.8340 - lr: 5.0000e-04
# Epoch 29/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9885 - f1_score: 0.8345 - binary_io_u: 0.8613
# Epoch 29: val_binary_io_u improved from 0.84506 to 0.84984, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0331 - accuracy: 0.9885 - f1_score: 0.8345 - binary_io_u: 0.8613 - val_loss: 0.0358 - val_accuracy: 0.9881 - val_f1_score: 0.7832 - val_binary_io_u: 0.8498 - lr: 2.5000e-04
# Epoch 30/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9876 - f1_score: 0.8218 - binary_io_u: 0.8515
# Epoch 30: val_binary_io_u did not improve from 0.84984
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0363 - accuracy: 0.9876 - f1_score: 0.8218 - binary_io_u: 0.8515 - val_loss: 0.0346 - val_accuracy: 0.9879 - val_f1_score: 0.7677 - val_binary_io_u: 0.8422 - lr: 2.5000e-04
# Epoch 31/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9887 - f1_score: 0.8375 - binary_io_u: 0.8635
# Epoch 31: val_binary_io_u improved from 0.84984 to 0.85539, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0326 - accuracy: 0.9887 - f1_score: 0.8375 - binary_io_u: 0.8635 - val_loss: 0.0325 - val_accuracy: 0.9886 - val_f1_score: 0.7909 - val_binary_io_u: 0.8554 - lr: 2.5000e-04
# Epoch 32/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9889 - f1_score: 0.8389 - binary_io_u: 0.8662
# Epoch 32: val_binary_io_u improved from 0.85539 to 0.85613, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0320 - accuracy: 0.9889 - f1_score: 0.8389 - binary_io_u: 0.8662 - val_loss: 0.0319 - val_accuracy: 0.9887 - val_f1_score: 0.7936 - val_binary_io_u: 0.8561 - lr: 2.5000e-04
# Epoch 33/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9890 - f1_score: 0.8423 - binary_io_u: 0.8671
# Epoch 33: val_binary_io_u did not improve from 0.85613
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0316 - accuracy: 0.9890 - f1_score: 0.8423 - binary_io_u: 0.8671 - val_loss: 0.0313 - val_accuracy: 0.9889 - val_f1_score: 0.7884 - val_binary_io_u: 0.8555 - lr: 2.5000e-04
# Epoch 34/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8438 - binary_io_u: 0.8678
# Epoch 34: val_binary_io_u did not improve from 0.85613
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0312 - accuracy: 0.9891 - f1_score: 0.8438 - binary_io_u: 0.8678 - val_loss: 0.0320 - val_accuracy: 0.9887 - val_f1_score: 0.7901 - val_binary_io_u: 0.8547 - lr: 2.5000e-04
# Epoch 35/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9893 - f1_score: 0.8429 - binary_io_u: 0.8703
# Epoch 35: val_binary_io_u did not improve from 0.85613
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0307 - accuracy: 0.9893 - f1_score: 0.8429 - binary_io_u: 0.8703 - val_loss: 0.0330 - val_accuracy: 0.9888 - val_f1_score: 0.7790 - val_binary_io_u: 0.8543 - lr: 2.5000e-04
# Epoch 36/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9895 - f1_score: 0.8484 - binary_io_u: 0.8724
# Epoch 36: val_binary_io_u improved from 0.85613 to 0.85688, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0301 - accuracy: 0.9895 - f1_score: 0.8484 - binary_io_u: 0.8724 - val_loss: 0.0308 - val_accuracy: 0.9891 - val_f1_score: 0.7897 - val_binary_io_u: 0.8569 - lr: 2.5000e-04
# Epoch 37/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9896 - f1_score: 0.8467 - binary_io_u: 0.8736
# Epoch 37: val_binary_io_u improved from 0.85688 to 0.86190, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0297 - accuracy: 0.9896 - f1_score: 0.8467 - binary_io_u: 0.8736 - val_loss: 0.0303 - val_accuracy: 0.9893 - val_f1_score: 0.8022 - val_binary_io_u: 0.8619 - lr: 2.5000e-04
# Epoch 38/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9897 - f1_score: 0.8515 - binary_io_u: 0.8750
# Epoch 38: val_binary_io_u did not improve from 0.86190
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0293 - accuracy: 0.9897 - f1_score: 0.8515 - binary_io_u: 0.8750 - val_loss: 0.0313 - val_accuracy: 0.9888 - val_f1_score: 0.7986 - val_binary_io_u: 0.8612 - lr: 2.5000e-04
# Epoch 39/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9897 - f1_score: 0.8497 - binary_io_u: 0.8743
# Epoch 39: val_binary_io_u did not improve from 0.86190
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0294 - accuracy: 0.9897 - f1_score: 0.8497 - binary_io_u: 0.8743 - val_loss: 0.0316 - val_accuracy: 0.9888 - val_f1_score: 0.7873 - val_binary_io_u: 0.8534 - lr: 2.5000e-04
# Epoch 40/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9898 - f1_score: 0.8501 - binary_io_u: 0.8757
# Epoch 40: val_binary_io_u improved from 0.86190 to 0.86504, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0289 - accuracy: 0.9898 - f1_score: 0.8501 - binary_io_u: 0.8757 - val_loss: 0.0296 - val_accuracy: 0.9894 - val_f1_score: 0.8043 - val_binary_io_u: 0.8650 - lr: 2.5000e-04
# Epoch 41/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9897 - f1_score: 0.8515 - binary_io_u: 0.8752
# Epoch 41: val_binary_io_u did not improve from 0.86504
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0290 - accuracy: 0.9897 - f1_score: 0.8515 - binary_io_u: 0.8752 - val_loss: 0.0316 - val_accuracy: 0.9891 - val_f1_score: 0.7907 - val_binary_io_u: 0.8585 - lr: 2.5000e-04
# Epoch 42/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9898 - f1_score: 0.8539 - binary_io_u: 0.8765
# Epoch 42: val_binary_io_u did not improve from 0.86504
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0286 - accuracy: 0.9898 - f1_score: 0.8539 - binary_io_u: 0.8765 - val_loss: 0.0340 - val_accuracy: 0.9883 - val_f1_score: 0.8003 - val_binary_io_u: 0.8564 - lr: 2.5000e-04
# Epoch 43/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9902 - f1_score: 0.8561 - binary_io_u: 0.8801
# Epoch 43: val_binary_io_u improved from 0.86504 to 0.86623, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0276 - accuracy: 0.9902 - f1_score: 0.8561 - binary_io_u: 0.8801 - val_loss: 0.0287 - val_accuracy: 0.9896 - val_f1_score: 0.8035 - val_binary_io_u: 0.8662 - lr: 2.5000e-04
# Epoch 44/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9902 - f1_score: 0.8578 - binary_io_u: 0.8807
# Epoch 44: val_binary_io_u did not improve from 0.86623
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0275 - accuracy: 0.9902 - f1_score: 0.8578 - binary_io_u: 0.8807 - val_loss: 0.0291 - val_accuracy: 0.9895 - val_f1_score: 0.7984 - val_binary_io_u: 0.8635 - lr: 2.5000e-04
# Epoch 45/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9904 - f1_score: 0.8602 - binary_io_u: 0.8829
# Epoch 45: val_binary_io_u did not improve from 0.86623
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0270 - accuracy: 0.9904 - f1_score: 0.8602 - binary_io_u: 0.8829 - val_loss: 0.0305 - val_accuracy: 0.9894 - val_f1_score: 0.7941 - val_binary_io_u: 0.8625 - lr: 2.5000e-04
# Epoch 46/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9904 - f1_score: 0.8607 - binary_io_u: 0.8829
# Epoch 46: val_binary_io_u improved from 0.86623 to 0.86715, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0269 - accuracy: 0.9904 - f1_score: 0.8607 - binary_io_u: 0.8829 - val_loss: 0.0289 - val_accuracy: 0.9898 - val_f1_score: 0.8086 - val_binary_io_u: 0.8672 - lr: 2.5000e-04
# Epoch 47/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9905 - f1_score: 0.8633 - binary_io_u: 0.8845
# Epoch 47: val_binary_io_u did not improve from 0.86715
# 200/200 [==============================] - 88s 438ms/step - loss: 0.0265 - accuracy: 0.9905 - f1_score: 0.8633 - binary_io_u: 0.8845 - val_loss: 0.0297 - val_accuracy: 0.9894 - val_f1_score: 0.8075 - val_binary_io_u: 0.8666 - lr: 2.5000e-04
# Epoch 48/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9906 - f1_score: 0.8612 - binary_io_u: 0.8847
# Epoch 48: val_binary_io_u did not improve from 0.86715
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 [==============================] - 88s 438ms/step - loss: 0.0261 - accuracy: 0.9906 - f1_score: 0.8612 - binary_io_u: 0.8847 - val_loss: 0.0301 - val_accuracy: 0.9896 - val_f1_score: 0.8146 - val_binary_io_u: 0.8670 - lr: 2.5000e-04
# Epoch 49/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9912 - f1_score: 0.8726 - binary_io_u: 0.8919
# Epoch 49: val_binary_io_u improved from 0.86715 to 0.87526, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 446ms/step - loss: 0.0241 - accuracy: 0.9912 - f1_score: 0.8726 - binary_io_u: 0.8919 - val_loss: 0.0264 - val_accuracy: 0.9903 - val_f1_score: 0.8218 - val_binary_io_u: 0.8753 - lr: 1.2500e-04
# Epoch 50/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9914 - f1_score: 0.8775 - binary_io_u: 0.8940
# Epoch 50: val_binary_io_u did not improve from 0.87526
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0235 - accuracy: 0.9914 - f1_score: 0.8775 - binary_io_u: 0.8940 - val_loss: 0.0265 - val_accuracy: 0.9903 - val_f1_score: 0.8164 - val_binary_io_u: 0.8728 - lr: 1.2500e-04
# Epoch 51/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9914 - f1_score: 0.8759 - binary_io_u: 0.8942
# Epoch 51: val_binary_io_u improved from 0.87526 to 0.87628, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0233 - accuracy: 0.9914 - f1_score: 0.8759 - binary_io_u: 0.8942 - val_loss: 0.0265 - val_accuracy: 0.9904 - val_f1_score: 0.8258 - val_binary_io_u: 0.8763 - lr: 1.2500e-04
# Epoch 52/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9915 - f1_score: 0.8799 - binary_io_u: 0.8959
# Epoch 52: val_binary_io_u improved from 0.87628 to 0.87849, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0228 - accuracy: 0.9915 - f1_score: 0.8799 - binary_io_u: 0.8959 - val_loss: 0.0262 - val_accuracy: 0.9904 - val_f1_score: 0.8304 - val_binary_io_u: 0.8785 - lr: 1.2500e-04
# Epoch 53/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9916 - f1_score: 0.8786 - binary_io_u: 0.8966
# Epoch 53: val_binary_io_u did not improve from 0.87849
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0227 - accuracy: 0.9916 - f1_score: 0.8786 - binary_io_u: 0.8966 - val_loss: 0.0257 - val_accuracy: 0.9905 - val_f1_score: 0.8240 - val_binary_io_u: 0.8775 - lr: 1.2500e-04
# Epoch 54/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9917 - f1_score: 0.8797 - binary_io_u: 0.8978
# Epoch 54: val_binary_io_u improved from 0.87849 to 0.88022, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0224 - accuracy: 0.9917 - f1_score: 0.8797 - binary_io_u: 0.8978 - val_loss: 0.0254 - val_accuracy: 0.9905 - val_f1_score: 0.8333 - val_binary_io_u: 0.8802 - lr: 1.2500e-04
# Epoch 55/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9917 - f1_score: 0.8823 - binary_io_u: 0.8984
# Epoch 55: val_binary_io_u improved from 0.88022 to 0.88104, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0222 - accuracy: 0.9917 - f1_score: 0.8823 - binary_io_u: 0.8984 - val_loss: 0.0251 - val_accuracy: 0.9907 - val_f1_score: 0.8332 - val_binary_io_u: 0.8810 - lr: 1.2500e-04
# Epoch 56/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9917 - f1_score: 0.8808 - binary_io_u: 0.8986
# Epoch 56: val_binary_io_u did not improve from 0.88104
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0220 - accuracy: 0.9917 - f1_score: 0.8808 - binary_io_u: 0.8986 - val_loss: 0.0255 - val_accuracy: 0.9905 - val_f1_score: 0.8254 - val_binary_io_u: 0.8773 - lr: 1.2500e-04
# Epoch 57/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9919 - f1_score: 0.8811 - binary_io_u: 0.9000
# Epoch 57: val_binary_io_u did not improve from 0.88104
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0218 - accuracy: 0.9919 - f1_score: 0.8811 - binary_io_u: 0.9000 - val_loss: 0.0257 - val_accuracy: 0.9907 - val_f1_score: 0.8312 - val_binary_io_u: 0.8793 - lr: 1.2500e-04
# Epoch 58/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9918 - f1_score: 0.8825 - binary_io_u: 0.8998
# Epoch 58: val_binary_io_u did not improve from 0.88104
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0216 - accuracy: 0.9918 - f1_score: 0.8825 - binary_io_u: 0.8998 - val_loss: 0.0255 - val_accuracy: 0.9906 - val_f1_score: 0.8286 - val_binary_io_u: 0.8788 - lr: 1.2500e-04
# Epoch 59/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9920 - f1_score: 0.8866 - binary_io_u: 0.9016
# Epoch 59: val_binary_io_u did not improve from 0.88104
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0213 - accuracy: 0.9920 - f1_score: 0.8866 - binary_io_u: 0.9016 - val_loss: 0.0253 - val_accuracy: 0.9907 - val_f1_score: 0.8341 - val_binary_io_u: 0.8809 - lr: 1.2500e-04
# Epoch 60/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9921 - f1_score: 0.8892 - binary_io_u: 0.9027
# Epoch 60: val_binary_io_u did not improve from 0.88104
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0209 - accuracy: 0.9921 - f1_score: 0.8892 - binary_io_u: 0.9027 - val_loss: 0.0258 - val_accuracy: 0.9908 - val_f1_score: 0.8316 - val_binary_io_u: 0.8798 - lr: 1.2500e-04
# Epoch 61/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9924 - f1_score: 0.8937 - binary_io_u: 0.9063
# Epoch 61: val_binary_io_u improved from 0.88104 to 0.88296, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0199 - accuracy: 0.9924 - f1_score: 0.8937 - binary_io_u: 0.9063 - val_loss: 0.0245 - val_accuracy: 0.9909 - val_f1_score: 0.8343 - val_binary_io_u: 0.8830 - lr: 6.2500e-05
# Epoch 62/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9925 - f1_score: 0.8926 - binary_io_u: 0.9072
# Epoch 62: val_binary_io_u did not improve from 0.88296
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0197 - accuracy: 0.9925 - f1_score: 0.8926 - binary_io_u: 0.9072 - val_loss: 0.0254 - val_accuracy: 0.9908 - val_f1_score: 0.8306 - val_binary_io_u: 0.8805 - lr: 6.2500e-05
# Epoch 63/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9925 - f1_score: 0.8965 - binary_io_u: 0.9082
# Epoch 63: val_binary_io_u improved from 0.88296 to 0.88521, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0194 - accuracy: 0.9925 - f1_score: 0.8965 - binary_io_u: 0.9082 - val_loss: 0.0241 - val_accuracy: 0.9911 - val_f1_score: 0.8409 - val_binary_io_u: 0.8852 - lr: 6.2500e-05
# Epoch 64/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9926 - f1_score: 0.8936 - binary_io_u: 0.9086
# Epoch 64: val_binary_io_u improved from 0.88521 to 0.88638, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0192 - accuracy: 0.9926 - f1_score: 0.8936 - binary_io_u: 0.9086 - val_loss: 0.0238 - val_accuracy: 0.9912 - val_f1_score: 0.8428 - val_binary_io_u: 0.8864 - lr: 6.2500e-05
# Epoch 65/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9927 - f1_score: 0.8960 - binary_io_u: 0.9098
# Epoch 65: val_binary_io_u did not improve from 0.88638
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0190 - accuracy: 0.9927 - f1_score: 0.8960 - binary_io_u: 0.9098 - val_loss: 0.0243 - val_accuracy: 0.9911 - val_f1_score: 0.8417 - val_binary_io_u: 0.8853 - lr: 6.2500e-05
# Epoch 66/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9927 - f1_score: 0.8956 - binary_io_u: 0.9097
# Epoch 66: val_binary_io_u did not improve from 0.88638
# 200/200 [==============================] - 87s 436ms/step - loss: 0.0190 - accuracy: 0.9927 - f1_score: 0.8956 - binary_io_u: 0.9097 - val_loss: 0.0242 - val_accuracy: 0.9912 - val_f1_score: 0.8439 - val_binary_io_u: 0.8858 - lr: 6.2500e-05
# Epoch 67/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9927 - f1_score: 0.8966 - binary_io_u: 0.9104
# Epoch 67: val_binary_io_u improved from 0.88638 to 0.88672, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0188 - accuracy: 0.9927 - f1_score: 0.8966 - binary_io_u: 0.9104 - val_loss: 0.0239 - val_accuracy: 0.9912 - val_f1_score: 0.8443 - val_binary_io_u: 0.8867 - lr: 6.2500e-05
# Epoch 68/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9927 - f1_score: 0.8967 - binary_io_u: 0.9104
# Epoch 68: val_binary_io_u did not improve from 0.88672
# 200/200 [==============================] - 87s 437ms/step - loss: 0.0189 - accuracy: 0.9927 - f1_score: 0.8967 - binary_io_u: 0.9104 - val_loss: 0.0238 - val_accuracy: 0.9912 - val_f1_score: 0.8430 - val_binary_io_u: 0.8865 - lr: 6.2500e-05
# Epoch 69/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9928 - f1_score: 0.8995 - binary_io_u: 0.9113
# Epoch 69: val_binary_io_u improved from 0.88672 to 0.88711, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 200/200 [==============================] - 89s 445ms/step - loss: 0.0186 - accuracy: 0.9928 - f1_score: 0.8995 - binary_io_u: 0.9113 - val_loss: 0.0238 - val_accuracy: 0.9912 - val_f1_score: 0.8439 - val_binary_io_u: 0.8871 - lr: 6.2500e-05
# Epoch 70/70
# 200/200 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9930 - f1_score: 0.8990 - binary_io_u: 0.9134
# Epoch 70: val_binary_io_u improved from 0.88711 to 0.88816, saving model to /content/drive/MyDrive/TRIAL_v1/segmentation_task/saved_outputs_segmentation/deep_ResUNet_2500_batch10/saved_models/best_deep_ResUNet_2500_batch10.h5
# 200/200 [==============================] - 89s 444ms/step - loss: 0.0180 - accuracy: 0.9930 - f1_score: 0.8990 - binary_io_u: 0.9134 - val_loss: 0.0235 - val_accuracy: 0.9913 - val_f1_score: 0.8458 - val_binary_io_u: 0.8882 - lr: 3.1250e-05

# %%
# Saving the time to be reused
time_data = {
    "model_name": [model_name],
    "run_time": [total_time]
}

# Convert the dictionary to a pandas DataFrame
time_df = pd.DataFrame(time_data)

# Save the DataFrame to a CSV file
time_df.to_csv(PATH_SAVE_TIME, index=False)

# %%
# Saving the history as csv file to be reused
history_df = pd.DataFrame(train_history.history)
history_df.to_csv(PATH_SAVE_HISTORY, index=False)

# %%
# plotting train history
plot_training_history(train_history)

# %% [markdown]
# ## Loading the best model

# %%
##Now, load the best model
best_model = ks.models.load_model(os.path.join(PATH_TO_SAVE_MODEL, best_model_name),
                                  custom_objects={'f1_score': f1_score,
                                                  'binary_io_u':iou_score_binary})

# best_model =model

# %% [markdown]
# ## Visualize model predictions

# %%
# Get predictions from the model
predictions = best_model.predict(x_test, verbose=1)

USER_DETERMINED_THRESHOLD = 0.5
thresholded_predictions  = (predictions  >= USER_DETERMINED_THRESHOLD)
# Removing the color channel
thresholded_predictions_without_color_channel = np.squeeze(thresholded_predictions, axis=-1)
# Out:
# 1/1 [==============================] - 23s 23s/step

# %%
############################################################################################################]

# Define the number of images to visualize
num_images = 4

# Create a figure with subplots
fig, axes = plt.subplots(num_images, 4, figsize=(12, 3 * num_images))

sample_indices = [0, 13, 4, 18]  #
# for i in range(num_images):
for i, chosen_index in enumerate(sample_indices):
    # Display original image
    axes[i, 0].imshow(x_test[chosen_index])
    axes[i, 0].set_title('Original Image ('+ str(i+1)+")", fontsize=11)

    # Display ground truth mask
    axes[i, 1].imshow(y_test[chosen_index], cmap='gray')
    axes[i, 1].set_title('Ground truth mask ('+ str(i+1)+")", fontsize=11)

    # Display predicted mask
    # axes[i, 2].imshow(thresholded_predictions[i], cmap='gray')
    axes[i, 2].imshow(thresholded_predictions[chosen_index], cmap='gray')
    axes[i, 2].set_title('Thresholded predicted mask ('+ str(i+1)+")", fontsize=11)

        # Display predicted mask
    axes[i, 3].imshow(predictions[chosen_index], cmap='gray')
    axes[i, 3].set_title('Initial predicted mask ('+ str(i+1)+")", fontsize=11)


    # Turn off axis labels
    for ax in axes[i]:
        ax.axis('off')

plt.tight_layout(pad=1.0, w_pad=1.5, h_pad=1.00)
# plt.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:

    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample01.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %%
def plot_samples(X, Y, predictions, sample_indices):
    """
    Plots the original image, prediction, and ground truth for given samples, with titles for each row.

    Parameters:
    - X: the test set images.
    - Y: the ground truth labels for the test set.
    - predictions: the model's predictions.
    - sample_indices: list of indices of the samples to plot.
    - SAVE_RESULTS: Boolean indicating if the results should be saved (default False).
    - PATH_TO_SAVE_RESULT: Path where the plot should be saved if SAVE_RESULTS is True.
    - model_name: Name of the model to use in the filename when saving results.
    """
    num_samples = len(sample_indices)
    fig, axes = plt.subplots(num_samples, 3, figsize=(9, num_samples * 3))  # Adjusted figsize for 3 columns
    plt.subplots_adjust(0, 0, 1, 1, hspace=0.1, wspace=0.1)

    # Titles for the first row
    titles = ['Original', 'Prediction (red for high probabilities)', 'Ground Truth']
    side_titles = ['Sample 1', 'Sample 2', 'Sample 3']  # Side titles for each sample

    for i, sample_index in enumerate(sample_indices):
        data = [
            X[sample_index, ...],
            predictions[sample_index, ..., 0],
            Y[sample_index, ...]
        ]

        cmaps = [None, plt.cm.jet, plt.cm.jet]

        for j, (datum, cmap) in enumerate(zip(data, cmaps)):
            ax = axes[i, j] if num_samples > 1 else axes[j]
            mesh = ax.pcolormesh(datum, cmap=cmap)
            if i == 0:
                ax.set_title(titles[j], fontsize=11)
            if j == 0:
                ax.set_ylabel(side_titles[i], fontsize=11)
            # ax.axis('off')

    for ax in axes.flatten():
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()

    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample02_color.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

sample_indices = [0, 13, 4]  # Indices of the samples you want to plot
plot_samples(x_test, y_test, predictions, sample_indices)

# %%
indices = np.array([i for i in range(len(x_test))])
rand_X_indices = RNG.choice(indices, size=4, replace=False)
rand_X = np.array([x_test[idx] for idx in rand_X_indices])
rand_y = np.array([y_test[idx] for idx in rand_X_indices])
rand_y_predictions = np.array([thresholded_predictions[idx] for idx in rand_X_indices])

fig, ax = plt.subplots(3,4, figsize=(10,7.5))
for i in range(4):
    ax[0,i].imshow(rand_X[i])
    ax[1,i].imshow(rand_y_predictions[i], cmap='gray')
    ax[2,i].imshow(rand_y[i], cmap='gray')

ax[0,0].set_title('Sample 1', fontsize=11)
ax[0,1].set_title('Sample 2', fontsize=11)
ax[0,2].set_title('Sample 3', fontsize=11)
ax[0,3].set_title('Sample 4', fontsize=11)

ax[0,0].set_ylabel('Images')
ax[1,0].set_ylabel('Predicted masks')
ax[2,0].set_ylabel('Ground truth masks')

for axes in ax.flatten():
    axes.set_xticks([])
    axes.set_yticks([])

fig.tight_layout()
# plt.show()

# Save the plot to a PDF
if SAVE_RESULTS:
    pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_prediction_sample03.pdf")
    with PdfPages(pdf_filename) as pdf:
        pdf.savefig()  # saves the current figure into a pdf page
        # plt.close()
        if SHOW_RESULTS:
            plt.show()
        else:
            plt.close()

# %% [markdown]
# ## Test evaluations

# %%
def calculate_test_performance_metrics_all(y_true, y_pred, test_loss ):

    y_test_tensor = tf.convert_to_tensor(y_test, dtype=tf.float32)
    y_pred_tensor = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    accuracy_value = accuracy_score(y_true, y_pred)
    precision_value = precision_score(y_true, y_pred)
    recall_value = recall_score(y_true, y_pred)
    f1_score_value = f1_score(y_test_tensor, y_pred_tensor).numpy()

    iou_score_binary.update_state(y_test, y_pred)
    iou_binary = iou_score_binary.result().numpy()

    # Create a dictionary to hold the metrics
    test_results = {
        'Model Name': model_name,
        'Loss': test_loss,
        'Accuracy': accuracy_value,
        'Precision': precision_value,
        'Recall': recall_value,
        'F1-Score': f1_score_value,
        'IoU': iou_binary
    }

        # Convert the dictionary to a DataFrame
    report_df = pd.DataFrame([test_results])

    if SHOW_RESULTS:
        display(report_df)

    if SAVE_RESULTS:
        path_to_save = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_model_all_test_performance.csv")
        # Save the DataFrame to a CSV file
        report_df.to_csv(path_to_save , index=False)

# %%
test_loss, test_accuracy, test_f1_score,  test_iou=best_model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 1s 947ms/step - loss: 0.0347 - accuracy: 0.9904 - f1_score: 0.8666 - binary_io_u: 0.8774

# %%
calculate_test_performance_metrics_all(y_true=y_test,
                                       y_pred=thresholded_predictions_without_color_channel,
                                       test_loss=test_loss)
# Out:
#                   Model Name      Loss  Accuracy  Precision    Recall  \
# 0  deep_ResUNet_2500_batch10  0.034688  0.990425   0.901932  0.833917
#
#    F1-Score       IoU
# 0  0.866592  0.887683

# %%
def calculate_confusion_matrix(y_true, y_pred):
    """
    Calculate the confusion matrix components for a segmentation task.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.

    Returns:
        tuple: A tuple containing the counts of TP, FP, FN, TN.
    """
    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return TP, FP, FN, TN


def plot_confusion_matrix(y_true, y_pred, model_name="default_name"): ## WORKS
    """
    Manually plot a confusion matrix for the results of a segmentation task, ensuring all elements are visible,
    with dividing lines between the rows and columns.

    Args:
        y_true (numpy.ndarray): The ground truth binary mask.
        y_pred (numpy.ndarray): The predicted binary mask.
        model_name (str): Optional. The name of the model for titling the plot.
        SAVE_RESULTS (bool): Optional. If True, saves the plot as a PNG file.
    """

    # Calculate the confusion matrix components
    TP, FP, FN, TN = calculate_confusion_matrix(y_true, y_pred)

    # Create the confusion matrix array
    confusion_matrix = np.array([[TP, FP], [FN, TN]])

    fig, ax = plt.subplots(figsize=(3, 3))
    cmap = plt.cm.Greens
    ax.imshow(np.zeros_like(confusion_matrix), cmap=cmap, vmin=0, vmax=1)

    # Annotate the cells with the confusion matrix counts
    for (i, j), val in np.ndenumerate(confusion_matrix):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=11)

    # Set tick labels
    ax.set_xticks([0, 1])
    ax.set_yticks([-0.2, 0.6])
    ax.set_xticklabels(['Disease', 'Background'], fontsize=11)
    ax.set_yticklabels(['Disease', 'Background'], fontsize=11)

    # Remove the ticks while keeping the labels
    ax.tick_params(axis='x', which='both', length=0) # Removes x-axis ticks
    ax.tick_params(axis='y', which='both', length=0) # Removes y-axis ticks

    # Rotate y-axis labels
    plt.yticks(rotation=90)

    # Set axis labels and title
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')

    # adding borders to the plot
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    # Draw dividing lines between the rows and columns
    ax.axhline(y=0.5, color='black', linewidth=1)
    ax.axvline(x=0.5, color='black', linewidth=1)

    plt.tight_layout()

    # Save the plot to a PDF
    if SAVE_RESULTS:
        pdf_filename = os.path.join(PATH_TO_SAVE_RESULT, f"{model_name}_confusion_matrix.pdf")
        with PdfPages(pdf_filename) as pdf:
            pdf.savefig()  # saves the current figure into a pdf page
            # plt.close()
            if SHOW_RESULTS:
                plt.show()
            else:
                plt.close()

# %%
plot_confusion_matrix(y_true=y_test,
                      y_pred=thresholded_predictions_without_color_channel,
                      model_name=model_name)
